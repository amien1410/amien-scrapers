# %% [markdown]
# <a href="https://colab.research.google.com/github/amien1410/amien-scrapers/blob/main/foursquare_scraper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
params = {
    'query': 'restaurant',
    'near': 'San Francisco, CA',
    'limit': 50
}

# %%
import requests

# TOKEN = "fsq3FwL8o3am2Zw//dg/GKQuZqXk/CDiPaHhjbB0VP/TCcw="
# TOKEN = "fsq3ATzZbmcGhdeFafr73wZcnJ+LlN6bK+4dh19a7ClS4u8="
# TOKEN = "fsq33Lsqz7rG2M8eRkSMm8kFXFQKo6EZ6ecw4ei5/ZD2Xf0="
# TOKEN = "fsq3T7SKdVMGwe+IQk+L/A1uyXQgk+w0ILNgWBUGmoeyld8="
TOKEN = "fsq3Tz0b7lh6LtcyoIl2kbZFHMuAxGaAXs9veBuPglC2LU8="

url = "https://api.foursquare.com/v3/places/search"
headers = {
    "Accept": "application/json",
    "Authorization": TOKEN
}

venues = []

response = requests.get(url, params=params, headers=headers)

if response.status_code == 200:
    data = response.json()
    venues = data.get('results', [])
else:
    print(f"Error: API request failed with status code {response.status_code}")
    print("Response text:", response.text)

venues
# Out:
# [{'fsq_id': '54a8b5d1498ef8abe40ce6b3',
#   'categories': [{'id': 13276,
#     'name': 'Sushi Restaurant',
#     'short_name': 'Sushi',
#     'plural_name': 'Sushi Restaurants',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#      'suffix': '.png'}}],
#   'chains': [],
#   'closed_bucket': 'Unsure',
#   'distance': 773,
#   'geocodes': {'drop_off': {'latitude': 37.768176, 'longitude': -122.421683},
#    'main': {'latitude': 37.768028, 'longitude': -122.421674},
#    'roof': {'latitude': 37.768028, 'longitude': -122.421674}},
#   'link': '/v3/places/54a8b5d1498ef8abe40ce6b3',
#   'location': {'address': '370 14th St',
#    'census_block': '060750201012010',
#    'country': 'US',
#    'cross_street': 'at Stevenson St',
#    'dma': 'San Francisco-Oakland-San Jose',
#    'formatted_address': '370 14th St (at Stevenson St), San Francisco, CA 94103',
#    'locality': 'San Francisco',
#    'postcode': '94103',
#    'region': 'CA'},
#   'name': 'Shizen',
# ...
