# %%
#@title Facebook - Rapidapi (facebook-pages-scraper2)
import requests

url = "https://facebook-pages-scraper2.p.rapidapi.com/get_facebook_marketplace_items_listing"
querystring = {"query":"cars","filter_location_latitude":"40.7142","filter_location_longitude":"-74.0064","filter_price_lower_bound":"0","filter_price_upper_bound":"214748364700","filter_radius_km":"65"}
headers = {
    "x-rapidapi-host": "facebook-pages-scraper2.p.rapidapi.com",
    "x-rapidapi-key": ""
}

response = requests.get(url, headers=headers, params=querystring)
response.json()
# Out:
# {'data': {'page_info': {'end_cursor': '{"pg":0,"b2c":{"br":"","it":0,"hmsr":false,"tbi":0},"c2c":{"br":"AbpZNJ0JKS295RBJPYLlu4cinG6tOKPyq4sS7gfPMp3fu57WpkuCoX7BVzPoT_9rYLrsC0NHkQc_Ve_F7TIX9jZs506AVF1X8KPNkYfnOjD0d0VTC_Gz420BvACRnalO_W-Jwg7bxPWmRIDCcc1g5ZelCicRVRFnYw1r-a5B8xplrjB5hiD251wGuKmC3Jyx-rfUtIiEJDyCXUZlhcSuAFdw1324eLtmUsstuf2-3T8_fbYDpTXIOV7OGqR31Fg8lj5DHsLFJ-skyKxGyORM9UGWm2RZyaemwF_Bn-xY3o6swEKUIQYWziJgcASllw_aIlpkaY6UrdYOXKNAxWP_hm_kqVkL3A8X5nTAaI0nwbbMUoOk_GgkYmQyyRwiM6kpGV_UYRru1_yM8DUvBKbmPZHQmMtflatm8ayZI2j2N-u-Ud2jCV8UX7MpAhgRDMqVL5EW7xCAQaCz8Kh8W0Txzj1iE1p0xaDvzfYVulh6vKoWLh8N1k0OpJzoJ5fOExltj7XjuUsxWNtu0Dab463eYbkUHctg2aY1w_dwZeZBrxQyOfearNwnVGsUW9lXCj8GN74","it":24,"rpbr":"","rphr":false,"rmhr":false},"irr":false,"serp_cta":false,"rui":[],"mpid":[],"ubp":null,"ncrnd":0,"irsr":false,"bmpr":[],"bmpeid":[],"nmbmp":false,"skrr":false,"ioour":false,"ise":true,"sms_cursor":{"page_index":0,"blended_ad_index":0,"organics_since_last_ad":0,"page_organic_count":0,"blended_organic_index":0,"returned_ad_index":0,"total_index":0}}',
#    'has_next': True},
#   'items': [{'listingUrl': 'https://www.facebook.com/marketplace/item/1741762096332479',
#     'id': '1741762096332479',
#     'primary_listing_photo': {'__typename': 'ProductImage',
#      'id': '2215271579290455',
#      'photo_image_url': 'https://scontent-atl3-1.xx.fbcdn.net/v/t39.84726-6/581756980_2215271589290454_940482917968549277_n.jpg?stp=c0.87.526.526a_dst-jpg_p526x395_tt6&_nc_cat=103&ccb=1-7&_nc_sid=92e707&_nc_ohc=r3TNqBPzUJUQ7kNvwFWp26n&_nc_oc=Adl5ehvJUtO_grJx4Ju3scIvelgU7kWGKs2t-1c3tl8bFaw4BDQkKzFctYgxf62Lri0&_nc_zt=14&_nc_ht=scontent-atl3-1.xx&_nc_gid=61999-3M_MMirGV1BWLb1g&oh=00_AfiAQk6RI31mmt7G4RSdR7FZk_3WM_bl9_9woFCr7CJSQA&oe=6917D243'},
#     'listing_price': {'formatted_amount': '$1',
#      'amount_with_offset_in_currency': '100',
#      'amount': '1.00'},
#     'strikethrough_price': None,
#     'comparable_price': None,
#     'comparable_price_type': None,
#     'location': {'reverse_geocode': {'city': 'Middle Village',
#       'state': 'NY',
#       'city_page': {'display_name': 'New York, New York',
#        'id': '108424279189115'}}},
#     'is_hidden': False,
#     'is_live': True,
#     'is_pending': False,
#     'is_sold': False,
#     'is_viewer_seller': False,
#     'min_listing_price': None,
#     'max_listing_price': None,
#     'marketplace_listing_category_id': '606456512821491',
#     'marketplace_listing_title': 'FRANKLIN MINT CARS 1/24 scale',
#     'custom_title': None,
#     'custom_sub_titles_with_rendering_flags': [],
#     'origin_group': None,
#     'listing_video': None,
#     'parent_listing': None,
#     'marketplace_listing_seller': {'__typename': 'User',
#      'name': None,
#      'id': None},
#     'delivery_types': ['IN_PERSON']},
#    {'listingUrl': 'https://www.facebook.com/marketplace/item/1557071462147975',
#     'id': '1557071462147975',
#     'primary_listing_photo': {'__typename': 'ProductImage',
#      'id': '3875423186083029',
#      'photo_image_url': 'https://scontent-atl3-2.xx.fbcdn.net/v/t39.84726-6/578994778_3875423216083026_8883187175915436563_n.jpg?stp=c0.305.526.526a_dst-jpg_p526x395_tt6&_nc_cat=102&ccb=1-7&_nc_sid=92e707&_nc_ohc=V1LkmTZbQfAQ7kNvwFXh48l&_nc_oc=AdmwS7XVclBn7_Yv98Y_Mlk8XEMjDrV4-E_W7oWvhoE6Gdw1QYHy03PH7grE0qruK8c&_nc_zt=14&_nc_ht=scontent-atl3-2.xx&_nc_gid=61999-3M_MMirGV1BWLb1g&oh=00_AfiYexerviZh9pf6m20HdHFxD6SD0kZFE6GIU-n7oe4pnA&oe=6917BE12'},
#     'listing_price': {'formatted_amount': '$999',
#      'amount_with_offset_in_currency': '99900',
#      'amount': '999.00'},
#     'strikethrough_price': None,
#     'comparable_price': None,
#     'comparable_price_type': None,
#     'location': {'reverse_geocode': {'city': 'Flushing',
#       'state': 'NY',
#       'city_page': {'display_name': 'New York, New York',
#        'id': '108424279189115'}}},
#     'is_hidden': False,
#     'is_live': True,
#     'is_pending': False,
#     'is_sold': False,
#     'is_viewer_seller': False,
#     'min_listing_price': None,
#     'max_listing_price': None,
#     'marketplace_listing_category_id': '757715671026531',
#     'marketplace_listing_title': 'We buy cars for cash best price',
#     'custom_title': None,
#     'custom_sub_titles_with_rendering_flags': [],
#     'origin_group': None,
#     'listing_video': None,
#     'parent_listing': None,
#     'marketplace_listing_seller': {'__typename': 'User',
#      'name': None,
#      'id': None},
#     'delivery_types': ['IN_PERSON']},
#    {'listingUrl': 'https://www.facebook.com/marketplace/item/697052899685431',
#     'id': '697052899685431',
#     'primary_listing_photo': {'__typename': 'ProductImage',
#      'id': '2107338970093680',
#      'photo_image_url': 'https://scontent-atl3-1.xx.fbcdn.net/v/t39.84726-6/577535978_2107339033427007_8767485564250177579_n.jpg?stp=c104.0.540.540a_dst-jpg_p180x540_tt6&_nc_cat=103&ccb=1-7&_nc_sid=92e707&_nc_ohc=WOOaWzEq-hQQ7kNvwGPNtIs&_nc_oc=AdmNUFAhshbmT2O_f5LbPxTaSo7pzND7DjB5RfrXuCKwpo9BePdGpqqE79PjpGom7y0&_nc_zt=14&_nc_ht=scontent-atl3-1.xx&_nc_gid=61999-3M_MMirGV1BWLb1g&oh=00_AfjUq-J0YKn5ytahqDbcxrCggVjJscialtug90G7MxLBzg&oe=6917C2A1'},
#     'listing_price': {'formatted_amount': '$5,995',
#      'amount_with_offset_in_currency': '599500',
#      'amount': '5995.00'},
#     'strikethrough_price': None,
#     'comparable_price': None,
#     'comparable_price_type': None,
#     'location': {'reverse_geocode': {'city': 'New York',
#       'state': 'NY',
#       'city_page': {'display_name': 'New York, New York',
#        'id': '108424279189115'}}},
#     'is_hidden': False,
#     'is_live': True,
#     'is_pending': False,
#     'is_sold': False,
#     'is_viewer_seller': False,
#     'min_listing_price': None,
#     'max_listing_price': None,
#     'marketplace_listing_category_id': '757715671026531',
#     'marketplace_listing_title': '2023',
#     'custom_title': None,
#     'custom_sub_titles_with_rendering_flags': [],
#     'origin_group': None,
#     'listing_video': None,
#     'parent_listing': None,
#     'marketplace_listing_seller': {'__typename': 'User',
#      'name': None,
#      'id': None},
#     'delivery_types': ['IN_PERSON']},
#    {'listingUrl': 'https://www.facebook.com/marketplace/item/1757411461593747',
#     'id': '1757411461593747',
#     'primary_listing_photo': {'__typename': 'ProductImage',
#      'id': '1354008336377194',
#      'photo_image_url': 'https://scontent-atl3-3.xx.fbcdn.net/v/t39.84726-6/577036470_1354008346377193_8514000367100473605_n.jpg?stp=c0.87.526.526a_dst-jpg_p526x395_tt6&_nc_cat=108&ccb=1-7&_nc_sid=92e707&_nc_ohc=98KKMIbMxHMQ7kNvwFSfVVv&_nc_oc=Adm_ItJRTkgZN8Ii0jHlledHjJZl9b2O1g_bD_KUAyMUvvC9MGkfkC3iCY0-j-qZfJA&_nc_zt=14&_nc_ht=scontent-atl3-3.xx&_nc_gid=61999-3M_MMirGV1BWLb1g&oh=00_AfhVEuSOPmConxRU-mFeNWKIljF8e1lbsK3r4TUMz2xU-Q&oe=6917C685'},
#     'listing_price': {'formatted_amount': '$30',
#      'amount_with_offset_in_currency': '3000',
#      'amount': '30.00'},
#     'strikethrough_price': None,
#     'comparable_price': None,
#     'comparable_price_type': None,
#     'location': {'reverse_geocode': {'city': 'Brooklyn',
#       'state': 'NY',
#       'city_page': {'display_name': 'New York, New York',
#        'id': '108424279189115'}}},
#     'is_hidden': False,
#     'is_live': True,
#     'is_pending': False,
#     'is_sold': False,
#     'is_viewer_seller': False,
#     'min_listing_price': None,
#     'max_listing_price': None,
#     'marketplace_listing_category_id': '606456512821491',
#     'marketplace_listing_title': 'Toys cars',
#     'custom_title': None,
#     'custom_sub_titles_with_rendering_flags': [],
#     'origin_group': None,
#     'listing_video': None,
#     'parent_listing': None,
#     'marketplace_listing_seller': {'__typename': 'User',
#      'name': None,
#      'id': None},
#     'delivery_types': ['IN_PERSON']},
#    {'listingUrl': 'https://www.facebook.com/marketplace/item/25565880036330104',
#     'id': '25565880036330104',
#     'primary_listing_photo': {'__typename': 'ProductImage',
#      'id': '711210881997246',
#      'photo_image_url': 'https://scontent-atl3-3.xx.fbcdn.net/v/t39.30808-6/578961261_711211065330561_530670597306307530_n.jpg?stp=dst-jpg_p526x296_tt6&_nc_cat=111&ccb=1-7&_nc_sid=454cf4&_nc_ohc=lM7o-Z0OPoQQ7kNvwGtqiYz&_nc_oc=Adk2VzkxGOLmBXOaUeKAp-CYrr7hLVLjeoygn-SDh2ERkFKHwo_gEkQIchhBXG-fs88&_nc_zt=23&_nc_ht=scontent-atl3-3.xx&_nc_gid=61999-3M_MMirGV1BWLb1g&oh=00_AfihMFWMgxpAW1Dq7fkb_OLAkU2jzeWZ6FVK2IhzVIQO4g&oe=6917A6C2'},
#     'listing_price': {'formatted_amount': '$4,000',
#      'amount_with_offset_in_currency': '400000',
#      'amount': '4000.00'},
#     'strikethrough_price': None,
#     'comparable_price': None,
#     'comparable_price_type': None,
#     'location': {'reverse_geocode': {'city': 'Jersey City',
#       'state': 'NJ',
#       'city_page': {'display_name': 'Jersey City, New Jersey',
#        'id': '105756796124329'}}},
#     'is_hidden': False,
#     'is_live': True,
#     'is_pending': False,
#     'is_sold': False,
#     'is_viewer_seller': False,
#     'min_listing_price': None,
#     'max_listing_price': None,
#     'marketplace_listing_category_id': '807311116002614',
#     'marketplace_listing_title': '2009 Toyota Corolla · XLE Sedan 4D',
#     'custom_title': '2009 Toyota corolla XLE Sedan 4D',
#     'custom_sub_titles_with_rendering_flags': [{'subtitle': '142K miles'}],
#     'origin_group': None,
#     'listing_video': {'id': '1487196525699388'},
#     'parent_listing': None,
#     'marketplace_listing_seller': {'__typename': 'User',
#      'name': None,
#      'id': None},
#     'delivery_types': ['IN_PERSON']},
#    {'listingUrl': 'https://www.facebook.com/marketplace/item/4178757919033811',
#     'id': '4178757919033811',
#     'primary_listing_photo': {'__typename': 'ProductImage',
#      'id': '4287468618201028',
#      'photo_image_url': 'https://scontent-atl3-1.xx.fbcdn.net/v/t39.30808-6/578334441_4287468708201019_7084829002966898573_n.jpg?stp=dst-jpg_p526x296_tt6&_nc_cat=106&ccb=1-7&_nc_sid=454cf4&_nc_ohc=mYPMHQgCf8AQ7kNvwFVPlMN&_nc_oc=AdkT4-Zb2ow0iJxFTe-tzVN__NwSP2wPEHD3Xh4Os7QaYXD_f7Yn2TtUlLA77oTvFsE&_nc_zt=23&_nc_ht=scontent-atl3-1.xx&_nc_gid=61999-3M_MMirGV1BWLb1g&oh=00_AfhJXTUKWhYb2YXKols8yiZe3VOPMrAEGbSbU_0bRsA5qw&oe=6917B969'},
#     'listing_price': {'formatted_amount': '$3,750',
#      'amount_with_offset_in_currency': '375000',
#      'amount': '3750.00'},
#     'strikethrough_price': None,
#     'comparable_price': None,
#     'comparable_price_type': None,
#     'location': {'reverse_geocode': {'city': 'Brooklyn',
#       'state': 'NY',
#       'city_page': {'display_name': 'New York, New York',
#        'id': '108424279189115'}}},
#     'is_hidden': False,
#     'is_live': True,
#     'is_pending': False,
#     'is_sold': False,
#     'is_viewer_seller': False,
#     'min_listing_price': None,
#     'max_listing_price': None,
#     'marketplace_listing_category_id': '807311116002614',
#     'marketplace_listing_title': '2007 Honda Accord · EX-L w/Navigation & Honda Sensing Sedan 4D',
#     'custom_title': '2007 Honda accord EX-L w/Navigation & Honda Sensing Sedan 4D',
#     'custom_sub_titles_with_rendering_flags': [{'subtitle': '129K miles'}],
#     'origin_group': None,
#     'listing_video': None,
#     'parent_listing': None,
#     'marketplace_listing_seller': {'__typename': 'User',
#      'name': None,
#      'id': None},
#     'delivery_types': ['IN_PERSON']},
#    {'listingUrl': 'https://www.facebook.com/marketplace/item/1884409599169079',
#     'id': '1884409599169079',
#     'primary_listing_photo': {'__typename': 'ProductImage',
#      'id': '4230592473933447',
#      'photo_image_url': 'https://scontent-atl3-3.xx.fbcdn.net/v/t39.30808-6/577489233_4230592550600106_1817010230745162966_n.jpg?stp=dst-jpg_p526x296_tt6&_nc_cat=109&ccb=1-7&_nc_sid=454cf4&_nc_ohc=Z3ioFK79BZgQ7kNvwFRGLFY&_nc_oc=AdkUDo807M1j980wwm3qGXpU9YNbrt2fpOc9EMd-08qDqxRcaIP8YLu3Q1Rs-VteI9s&_nc_zt=23&_nc_ht=scontent-atl3-3.xx&_nc_gid=61999-3M_MMirGV1BWLb1g&oh=00_AfgPrxsz4CEOMJlSlR9xZABbwrg5C271yOvlIKaqfi4BnA&oe=6917D30B'},
#     'listing_price': {'formatted_amount': '$2,000',
#      'amount_with_offset_in_currency': '200000',
#      'amount': '2000.00'},
#     'strikethrough_price': None,
#     'comparable_price': None,
#     'comparable_price_type': None,
#     'location': {'reverse_geocode': {'city': 'Richmond Hill',
#       'state': 'NY',
#       'city_page': {'display_name': 'New York, New York',
#        'id': '108424279189115'}}},
#     'is_hidden': False,
#     'is_live': True,
#     'is_pending': False,
#     'is_sold': False,
#     'is_viewer_seller': False,
#     'min_listing_price': None,
#     'max_listing_price': None,
#     'marketplace_listing_category_id': '807311116002614',
#     'marketplace_listing_title': '2004 Acura TL · 3.2 Sedan 4D',
#     'custom_title': '2004 Acura tl 3.2 Sedan 4D',
#     'custom_sub_titles_with_rendering_flags': [{'subtitle': '200K miles'}],
#     'origin_group': None,
#     'listing_video': None,
#     'parent_listing': None,
#     'marketplace_listing_seller': {'__typename': 'User',
#      'name': None,
#      'id': None},
#     'delivery_types': ['IN_PERSON']},
#    {'listingUrl': 'https://www.facebook.com/marketplace/item/1323455572329367',
#     'id': '1323455572329367',
#     'primary_listing_photo': {'__typename': 'ProductImage',
#      'id': '1226954886039680',
#      'photo_image_url': 'https://scontent-atl3-1.xx.fbcdn.net/v/t39.84726-6/577930628_1226954889373013_8456366428011785596_n.jpg?stp=c0.0.300.300a_dst-jpg_tt6&_nc_cat=103&ccb=1-7&_nc_sid=92e707&_nc_ohc=W_RsNyTLmz4Q7kNvwFpFjrL&_nc_oc=Adkvqlhyja-ioT7Ktbzcqm-pmrw21EXA7t4wOc-KVJkRXUuvyD3N5xZJYjA9whqf1Us&_nc_zt=14&_nc_ht=scontent-atl3-1.xx&_nc_gid=61999-3M_MMirGV1BWLb1g&oh=00_Afh6TiAdXBco9htffoZs_o7bU5fMSx555HDfkvKuEG2BkA&oe=6917CC98'},
#     'listing_price': {'formatted_amount': '$350',
#      'amount_with_offset_in_currency': '35000',
#      'amount': '350.00'},
#     'strikethrough_price': None,
#     'comparable_price': None,
#     'comparable_price_type': None,
#     'location': {'reverse_geocode': {'city': 'Asbury Park',
#       'state': 'NJ',
#       'city_page': {'display_name': 'Asbury Park, New Jersey',
#        'id': '109374039082348'}}},
#     'is_hidden': False,
#     'is_live': True,
#     'is_pending': False,
#     'is_sold': False,
#     'is_viewer_seller': False,
#     'min_listing_price': None,
#     'max_listing_price': None,
#     'marketplace_listing_category_id': '807311116002614',
#     'marketplace_listing_title': '2018 Kia Soul Soul',
#     'custom_title': '2018 Kia Soul',
#     'custom_sub_titles_with_rendering_flags': [{'subtitle': '300 miles'}],
#     'origin_group': None,
#     'listing_video': None,
#     'parent_listing': None,
#     'marketplace_listing_seller': {'__typename': 'User',
#      'name': None,
#      'id': None},
#     'delivery_types': ['IN_PERSON']},
#    {'listingUrl': 'https://www.facebook.com/marketplace/item/2658739071179021',
#     'id': '2658739071179021',
#     'primary_listing_photo': {'__typename': 'ProductImage',
#      'id': '2354775901606609',
#      'photo_image_url': 'https://scontent-atl3-1.xx.fbcdn.net/v/t39.84726-6/579215517_2354775908273275_2495795440450548078_n.jpg?stp=c0.87.526.526a_dst-jpg_p526x395_tt6&_nc_cat=100&ccb=1-7&_nc_sid=92e707&_nc_ohc=5cpsBqn9jqAQ7kNvwEt1tTd&_nc_oc=AdmNNSw5dFWXMAu0P4V_51vFcJgALoXua7B8dyOfXsfCkyxi_uy_4N7MYrTE2EDY6BY&_nc_zt=14&_nc_ht=scontent-atl3-1.xx&_nc_gid=61999-3M_MMirGV1BWLb1g&oh=00_AfiynVYyxhkOmwVteR8O0k7DW7CLf80MYl0hUmWTCrqxSA&oe=6917D21B'},
#     'listing_price': {'formatted_amount': '$15',
#      'amount_with_offset_in_currency': '1500',
#      'amount': '15.00'},
#     'strikethrough_price': None,
#     'comparable_price': None,
#     'comparable_price_type': None,
#     'location': {'reverse_geocode': {'city': 'Brooklyn',
#       'state': 'NY',
#       'city_page': {'display_name': 'New York, New York',
#        'id': '108424279189115'}}},
#     'is_hidden': False,
#     'is_live': True,
#     'is_pending': False,
#     'is_sold': False,
#     'is_viewer_seller': False,
#     'min_listing_price': None,
#     'max_listing_price': None,
#     'marketplace_listing_category_id': '606456512821491',
#     'marketplace_listing_title': 'Lot of cars',
#     'custom_title': None,
#     'custom_sub_titles_with_rendering_flags': [],
#     'origin_group': None,
#     'listing_video': None,
#     'parent_listing': None,
#     'marketplace_listing_seller': {'__typename': 'User',
#      'name': None,
#      'id': None},
#     'delivery_types': ['IN_PERSON']},
#    {'listingUrl': 'https://www.facebook.com/marketplace/item/836392662185261',
#     'id': '836392662185261',
#     'primary_listing_photo': {'__typename': 'ProductImage',
#      'id': '2289635564791488',
#      'photo_image_url': 'https://scontent-atl3-1.xx.fbcdn.net/v/t39.84726-6/578275807_2289635594791485_6622231049197765804_n.jpg?stp=c0.87.526.526a_dst-jpg_p526x395_tt6&_nc_cat=100&ccb=1-7&_nc_sid=92e707&_nc_ohc=TE-2o5TarhoQ7kNvwHMF-nN&_nc_oc=AdmEBV0ITFU5GAAXivXuGpymxKTTc6rR-Ax-QT5ibbPI8gju_iwvPHPggQlWx6hqx1s&_nc_zt=14&_nc_ht=scontent-atl3-1.xx&_nc_gid=61999-3M_MMirGV1BWLb1g&oh=00_Afjeqg70I4NVFaKa3CSi_Kmf_PYYb7g1djAa1tcUIM_RKA&oe=6917C036'},
#     'listing_price': {'formatted_amount': '$6',
#      'amount_with_offset_in_currency': '600',
#      'amount': '6.00'},
#     'strikethrough_price': None,
#     'comparable_price': None,
#     'comparable_price_type': None,
#     'location': {'reverse_geocode': {'city': 'Brooklyn',
#       'state': 'NY',
#       'city_page': {'display_name': 'New York, New York',
#        'id': '108424279189115'}}},
#     'is_hidden': False,
#     'is_live': True,
#     'is_pending': False,
#     'is_sold': False,
#     'is_viewer_seller': False,
#     'min_listing_price': None,
#     'max_listing_price': None,
#     'marketplace_listing_category_id': '1555452698044988',
#     'marketplace_listing_title': 'Cars shoe charms',
#     'custom_title': None,
#     'custom_sub_titles_with_rendering_flags': [],
#     'origin_group': None,
#     'listing_video': None,
#     'parent_listing': None,
#     'marketplace_listing_seller': {'__typename': 'User',
#      'name': None,
#      'id': None},
#     'delivery_types': ['IN_PERSON']},
#    {'listingUrl': 'https://www.facebook.com/marketplace/item/1800330533923041',
#     'id': '1800330533923041',
#     'primary_listing_photo': {'__typename': 'ProductImage',
#      'id': '1361869375542541',
#      'photo_image_url': 'https://scontent-atl3-1.xx.fbcdn.net/v/t45.5328-4/564186678_1361869378875874_3067075907780364488_n.jpg?stp=c89.0.540.540a_dst-jpg_p180x540_tt6&_nc_cat=103&ccb=1-7&_nc_sid=247b10&_nc_ohc=_wUT7C2NA5kQ7kNvwEWBkAu&_nc_oc=AdlqQce6m6NpnspfVItXoFXBhz8QT2teodKSX6BQuociDLu4jNjtS8afyGTFiK83ivY&_nc_zt=23&_nc_ht=scontent-atl3-1.xx&_nc_gid=61999-3M_MMirGV1BWLb1g&oh=00_AfgVNFIrzXXLw5sXui4mBkOmW37jPwzKA-mQ5GNzWOJ5eQ&oe=6917B760'},
#     'listing_price': {'formatted_amount': '$200',
#      'amount_with_offset_in_currency': '20000',
#      'amount': '200.00'},
#     'strikethrough_price': None,
#     'comparable_price': None,
#     'comparable_price_type': None,
#     'location': {'reverse_geocode': {'city': 'Brooklyn',
#       'state': 'NY',
#       'city_page': {'display_name': 'New York, New York',
#        'id': '108424279189115'}}},
#     'is_hidden': False,
#     'is_live': True,
#     'is_pending': False,
#     'is_sold': False,
#     'is_viewer_seller': False,
#     'min_listing_price': None,
#     'max_listing_price': None,
#     'marketplace_listing_category_id': '606456512821491',
#     'marketplace_listing_title': 'Die cast classic cars & trucks',
#     'custom_title': None,
#     'custom_sub_titles_with_rendering_flags': [],
#     'origin_group': None,
#     'listing_video': None,
#     'parent_listing': None,
#     'marketplace_listing_seller': {'__typename': 'User',
#      'name': None,
#      'id': None},
#     'delivery_types': ['IN_PERSON']},
#    {'listingUrl': 'https://www.facebook.com/marketplace/item/716445387566273',
#     'id': '716445387566273',
#     'primary_listing_photo': {'__typename': 'ProductImage',
#      'id': '1503687620869714',
#      'photo_image_url': 'https://scontent-atl3-2.xx.fbcdn.net/v/t39.30808-6/578366016_1503687714203038_1883244418228260914_n.jpg?stp=c0.169.1536.1536a_dst-jpg_s565x565_tt6&_nc_cat=105&ccb=1-7&_nc_sid=454cf4&_nc_ohc=_WCxv1F6rsAQ7kNvwGWg3Jx&_nc_oc=AdlSie3y95yJ60o6fzdlwAuDN4rfZ0h-BqkU7RefAZzMQ0IXDdQnuiSfWni9oeQ3MEo&_nc_zt=23&_nc_ht=scontent-atl3-2.xx&_nc_gid=61999-3M_MMirGV1BWLb1g&oh=00_AfhD4NG-5wgLkL4N6dn0yvv4__ErbtIsjBaBzKFTQ5ZwfQ&oe=6917BC87'},
#     'listing_price': {'formatted_amount': '$4,500',
#      'amount_with_offset_in_currency': '450000',
#      'amount': '4500.00'},
#     'strikethrough_price': None,
#     'comparable_price': None,
#     'comparable_price_type': None,
#     'location': {'reverse_geocode': {'city': 'Irvington',
#       'state': 'NY',
#       'city_page': {'display_name': 'Irvington, New York',
#        'id': '107631542593618'}}},
#     'is_hidden': False,
#     'is_live': True,
#     'is_pending': False,
#     'is_sold': False,
#     'is_viewer_seller': False,
#     'min_listing_price': None,
#     'max_listing_price': None,
#     'marketplace_listing_category_id': '807311116002614',
#     'marketplace_listing_title': '2016 Ford Focus · SE Sedan 4D',
#     'custom_title': '2016 Ford focus SE Sedan 4D',
#     'custom_sub_titles_with_rendering_flags': [{'subtitle': '126K miles'}],
#     'origin_group': None,
#     'listing_video': None,
#     'parent_listing': None,
#     'marketplace_listing_seller': {'__typename': 'User',
#      'name': None,
#      'id': None},
#     'delivery_types': ['IN_PERSON']},
#    {'listingUrl': 'https://www.facebook.com/marketplace/item/1916229589242999',
#     'id': '1916229589242999',
#     'primary_listing_photo': {'__typename': 'ProductImage',
#      'id': '2145645775841288',
#      'photo_image_url': 'https://scontent-atl3-3.xx.fbcdn.net/v/t39.84726-6/579643486_2145645785841287_4669727900159863677_n.jpg?stp=c0.87.526.526a_dst-jpg_p526x395_tt6&_nc_cat=109&ccb=1-7&_nc_sid=92e707&_nc_ohc=Ee7INKPNX4gQ7kNvwG8Fr7p&_nc_oc=AdmvgRX2iA5UdnplCBcIPvkpaTiF1i5XL8MieOao6VsqwklB6ilF2fCkeZsZvO6ZBbs&_nc_zt=14&_nc_ht=scontent-atl3-3.xx&_nc_gid=61999-3M_MMirGV1BWLb1g&oh=00_AfjsSRouM9iWOTC3b-wTEfVv107eUpmraN3lxyX3dWgn6Q&oe=6917B4BE'},
#     'listing_price': {'formatted_amount': '$3,400',
#      'amount_with_offset_in_currency': '340000',
#      'amount': '3400.00'},
#     'strikethrough_price': None,
#     'comparable_price': None,
#     'comparable_price_type': None,
#     'location': {'reverse_geocode': {'city': 'North Bergen',
#       'state': 'NJ',
#       'city_page': {'display_name': 'North Bergen, New Jersey',
#        'id': '111685032180118'}}},
#     'is_hidden': False,
#     'is_live': True,
#     'is_pending': False,
#     'is_sold': False,
#     'is_viewer_seller': False,
#     'min_listing_price': None,
#     'max_listing_price': None,
#     'marketplace_listing_category_id': '895487550471874',
#     'marketplace_listing_title': 'Cars',
#     'custom_title': None,
#     'custom_sub_titles_with_rendering_flags': [],
#     'origin_group': None,
#     'listing_video': {'id': '4205492546329262'},
#     'parent_listing': None,
#     'marketplace_listing_seller': {'__typename': 'User',
#      'name': None,
#      'id': None},
#     'delivery_types': ['IN_PERSON']},
#    {'listingUrl': 'https://www.facebook.com/marketplace/item/837069532593465',
#     'id': '837069532593465',
#     'primary_listing_photo': {'__typename': 'ProductImage',
#      'id': '836326548774332',
#      'photo_image_url': 'https://scontent-atl3-3.xx.fbcdn.net/v/t39.84726-6/580967761_836326562107664_5531081248010848766_n.jpg?stp=c0.87.526.526a_dst-jpg_p526x395_tt6&_nc_cat=109&ccb=1-7&_nc_sid=92e707&_nc_ohc=-d8HM3ND2YIQ7kNvwGPQlt7&_nc_oc=AdkAMSs0OnGb__AWVriJ9O9MRafF2cT_6qdBKI9Po4XLFNp629azfnonrz7yefHvGuE&_nc_zt=14&_nc_ht=scontent-atl3-3.xx&_nc_gid=61999-3M_MMirGV1BWLb1g&oh=00_Afh4kfxGTXwLnaqRDIoydboX6Wa_TF7AVfHMPz6aQt7sLQ&oe=6917C62C'},
#     'listing_price': {'formatted_amount': '$100',
#      'amount_with_offset_in_currency': '10000',
#      'amount': '100.00'},
#     'strikethrough_price': None,
#     'comparable_price': None,
#     'comparable_price_type': None,
#     'location': {'reverse_geocode': {'city': 'Monroe',
#       'state': 'NY',
#       'city_page': {'display_name': 'Monroe, New York',
#        'id': '107081872656509'}}},
#     'is_hidden': False,
#     'is_live': True,
#     'is_pending': False,
#     'is_sold': False,
#     'is_viewer_seller': False,
#     'min_listing_price': None,
#     'max_listing_price': None,
#     'marketplace_listing_category_id': '606456512821491',
#     'marketplace_listing_title': 'Toy cars for children',
#     'custom_title': None,
#     'custom_sub_titles_with_rendering_flags': [],
#     'origin_group': None,
#     'listing_video': None,
#     'parent_listing': None,
#     'marketplace_listing_seller': {'__typename': 'User',
#      'name': None,
#      'id': None},
#     'delivery_types': ['IN_PERSON']},
#    {'listingUrl': 'https://www.facebook.com/marketplace/item/1175161390615132',
#     'id': '1175161390615132',
#     'primary_listing_photo': {'__typename': 'ProductImage',
#      'id': '1166497188958832',
#      'photo_image_url': 'https://scontent-atl3-2.xx.fbcdn.net/v/t39.84726-6/581005249_1167298552212029_8659360566716539196_n.jpg?stp=c89.0.540.540a_dst-jpg_p180x540_tt6&_nc_cat=105&ccb=1-7&_nc_sid=92e707&_nc_ohc=AXq2lZqtG-EQ7kNvwF_02M9&_nc_oc=AdmTGlQDbgXsw-vLymgEu85Gat1XM547EwmnMDQERbDNejBhhKNp8tGoRuEzkNIi1wE&_nc_zt=14&_nc_ht=scontent-atl3-2.xx&_nc_gid=61999-3M_MMirGV1BWLb1g&oh=00_Afggx1l3txyxX0GdnRx1gHWMhw4_TW4Ameq_PSBMu5AfNw&oe=6917C081'},
#     'listing_price': {'formatted_amount': '$50',
#      'amount_with_offset_in_currency': '5000',
#      'amount': '50.00'},
#     'strikethrough_price': None,
#     'comparable_price': None,
#     'comparable_price_type': None,
#     'location': {'reverse_geocode': {'city': 'Union',
#       'state': 'NJ',
#       'city_page': {'display_name': 'Union Township',
#        'id': '111806958846634'}}},
#     'is_hidden': False,
#     'is_live': True,
#     'is_pending': False,
#     'is_sold': False,
#     'is_viewer_seller': False,
#     'min_listing_price': None,
#     'max_listing_price': None,
#     'marketplace_listing_category_id': '606456512821491',
#     'marketplace_listing_title': 'Kids cars',
#     'custom_title': None,
#     'custom_sub_titles_with_rendering_flags': [],
#     'origin_group': None,
#     'listing_video': None,
#     'parent_listing': None,
#     'marketplace_listing_seller': {'__typename': 'User',
#      'name': None,
#      'id': None},
#     'delivery_types': ['IN_PERSON']},
#    {'listingUrl': 'https://www.facebook.com/marketplace/item/834042675701520',
#     'id': '834042675701520',
#     'primary_listing_photo': {'__typename': 'ProductImage',
#      'id': '2034578454033531',
#      'photo_image_url': 'https://scontent-atl3-2.xx.fbcdn.net/v/t39.30808-6/579611595_2034578487366861_8338686917959355633_n.jpg?stp=dst-jpg_p526x296_tt6&_nc_cat=102&ccb=1-7&_nc_sid=454cf4&_nc_ohc=ZgJllj3AtPMQ7kNvwGBWL5M&_nc_oc=Adm0uAestFxuyj2HnRNPxI9P0EETXXLjACpfHKOb9uEWZQfUmsqb5juE4cILqXCygqg&_nc_zt=23&_nc_ht=scontent-atl3-2.xx&_nc_gid=61999-3M_MMirGV1BWLb1g&oh=00_Afhs3nfoADKO06kWFULFG8NlHlCqBm_cSI23fCDzr6xqAA&oe=6917B982'},
#     'listing_price': {'formatted_amount': '$4,500',
#      'amount_with_offset_in_currency': '450000',
#      'amount': '4500.00'},
#     'strikethrough_price': None,
#     'comparable_price': None,
#     'comparable_price_type': None,
#     'location': {'reverse_geocode': {'city': 'Wayne',
#       'state': 'NJ',
#       'city_page': {'display_name': 'Wayne, New Jersey',
#        'id': '103723296332578'}}},
#     'is_hidden': False,
#     'is_live': True,
#     'is_pending': False,
#     'is_sold': False,
#     'is_viewer_seller': False,
#     'min_listing_price': None,
#     'max_listing_price': None,
#     'marketplace_listing_category_id': '807311116002614',
#     'marketplace_listing_title': '2014 Honda Accord · Sport Special Edition Sedan 4D',
#     'custom_title': '2014 Honda accord Sport Special Edition Sedan 4D',
#     'custom_sub_titles_with_rendering_flags': [{'subtitle': '157K miles'}],
#     'origin_group': None,
#     'listing_video': {'id': '807792858764950'},
#     'parent_listing': None,
#     'marketplace_listing_seller': {'__typename': 'User',
#      'name': None,
#      'id': None},
#     'delivery_types': ['IN_PERSON']},
#    {'listingUrl': 'https://www.facebook.com/marketplace/item/4171848799704435',
#     'id': '4171848799704435',
#     'primary_listing_photo': {'__typename': 'ProductImage',
#      'id': '756949717366541',
#      'photo_image_url': 'https://scontent-atl3-3.xx.fbcdn.net/v/t39.84726-6/579516409_772177015843811_3097057712582828667_n.jpg?stp=c0.0.526.526a_dst-jpg_p526x395_tt6&_nc_cat=109&ccb=1-7&_nc_sid=92e707&_nc_ohc=BQkeWjD6ZngQ7kNvwG5Z0PQ&_nc_oc=AdmBkefHMFlEo6Re5t0B66wz1rk90korzHfFudSnvbCGx0l6Rj7utqSdZPgoK2o9wv8&_nc_zt=14&_nc_ht=scontent-atl3-3.xx&_nc_gid=61999-3M_MMirGV1BWLb1g&oh=00_Afjz0TheaY0VEoed2gG1HCdYB4pFaDddWIrjWRQFVxOVIQ&oe=6917B47F'},
#     'listing_price': {'formatted_amount': '$1',
#      'amount_with_offset_in_currency': '100',
#      'amount': '1.00'},
#     'strikethrough_price': None,
#     'comparable_price': None,
#     'comparable_price_type': None,
#     'location': {'reverse_geocode': {'city': 'Fresh Meadows',
#       'state': 'NY',
#       'city_page': {'display_name': 'New York, New York',
#        'id': '108424279189115'}}},
#     'is_hidden': False,
#     'is_live': True,
#     'is_pending': False,
#     'is_sold': False,
#     'is_viewer_seller': False,
#     'min_listing_price': None,
#     'max_listing_price': None,
#     'marketplace_listing_category_id': '895487550471874',
#     'marketplace_listing_title': 'Cars',
#     'custom_title': None,
#     'custom_sub_titles_with_rendering_flags': [],
#     'origin_group': None,
#     'listing_video': None,
#     'parent_listing': None,
#     'marketplace_listing_seller': {'__typename': 'User',
#      'name': None,
#      'id': None},
#     'delivery_types': ['IN_PERSON']},
#    {'listingUrl': 'https://www.facebook.com/marketplace/item/1195544565669062',
#     'id': '1195544565669062',
#     'primary_listing_photo': {'__typename': 'ProductImage',
#      'id': '1167404408683638',
#      'photo_image_url': 'https://scontent-atl3-2.xx.fbcdn.net/v/t39.84726-6/569396454_1167404438683635_3207584621792461437_n.jpg?stp=c90.0.540.540a_dst-jpg_p180x540_tt6&_nc_cat=101&ccb=1-7&_nc_sid=92e707&_nc_ohc=x3niGbyhSpMQ7kNvwGQFs4h&_nc_oc=AdlRIypLJIoPXDxzg_-FlnwdM1PtaWFEG9OdSblir6YfOmOw4ySqPXoSnqvs4xYib-c&_nc_zt=14&_nc_ht=scontent-atl3-2.xx&_nc_gid=61999-3M_MMirGV1BWLb1g&oh=00_Afh9Wy4dBFgDhdrxlPqdb4vAELSYPf0rpxXqykgV6pw-Aw&oe=6917CCC9'},
#     'listing_price': {'formatted_amount': '$5,000',
#      'amount_with_offset_in_currency': '500000',
#      'amount': '5000.00'},
#     'strikethrough_price': None,
#     'comparable_price': None,
#     'comparable_price_type': None,
#     'location': {'reverse_geocode': {'city': 'Bronx',
#       'state': 'NY',
#       'city_page': {'display_name': 'New York, New York',
#        'id': '108424279189115'}}},
#     'is_hidden': False,
#     'is_live': True,
#     'is_pending': False,
#     'is_sold': False,
#     'is_viewer_seller': False,
#     'min_listing_price': None,
#     'max_listing_price': None,
#     'marketplace_listing_category_id': '895487550471874',
#     'marketplace_listing_title': 'Cars',
#     'custom_title': None,
#     'custom_sub_titles_with_rendering_flags': [],
#     'origin_group': None,
#     'listing_video': {'id': '1969958057174791'},
#     'parent_listing': None,
#     'marketplace_listing_seller': {'__typename': 'User',
#      'name': None,
#      'id': None},
#     'delivery_types': ['IN_PERSON']},
#    {'listingUrl': 'https://www.facebook.com/marketplace/item/1099943842294140',
#     'id': '1099943842294140',
#     'primary_listing_photo': {'__typename': 'ProductImage',
#      'id': '1349180540266686',
#      'photo_image_url': 'https://scontent-atl3-2.xx.fbcdn.net/v/t39.84726-6/567695244_1349180670266673_835810387567396663_n.jpg?stp=c0.87.526.526a_dst-jpg_p526x395_tt6&_nc_cat=104&ccb=1-7&_nc_sid=92e707&_nc_ohc=L9kb5xrgRmYQ7kNvwEqdJB4&_nc_oc=AdmanIcBbBkEzxTZFZz6c_N0h-rX2OxVC1CxZPMwyAPDK7BryMvnYqS13S0Vc2U6fD4&_nc_zt=14&_nc_ht=scontent-atl3-2.xx&_nc_gid=61999-3M_MMirGV1BWLb1g&oh=00_AfjnFmXOvK7eXvgpUxxdRNzRfZLTxP3wa1gQ1oxWMwqupw&oe=6917A9B9'},
#     'listing_price': {'formatted_amount': '$1,600',
#      'amount_with_offset_in_currency': '160000',
#      'amount': '1600.00'},
#     'strikethrough_price': None,
#     'comparable_price': None,
#     'comparable_price_type': None,
#     'location': {'reverse_geocode': {'city': 'Islandia',
#       'state': 'NY',
#       'city_page': {'display_name': 'Islandia, New York',
#        'id': '108179882537407'}}},
#     'is_hidden': False,
#     'is_live': True,
#     'is_pending': False,
#     'is_sold': False,
#     'is_viewer_seller': False,
#     'min_listing_price': None,
#     'max_listing_price': None,
#     'marketplace_listing_category_id': '895487550471874',
#     'marketplace_listing_title': 'Cars',
#     'custom_title': None,
#     'custom_sub_titles_with_rendering_flags': [],
#     'origin_group': None,
#     'listing_video': None,
#     'parent_listing': None,
#     'marketplace_listing_seller': {'__typename': 'User',
#      'name': None,
#      'id': None},
#     'delivery_types': ['IN_PERSON']},
#    {'listingUrl': 'https://www.facebook.com/marketplace/item/3032642233593116',
#     'id': '3032642233593116',
#     'primary_listing_photo': {'__typename': 'ProductImage',
#      'id': '1988954488623351',
#      'photo_image_url': 'https://scontent-atl3-1.xx.fbcdn.net/v/t39.84726-6/563977224_1990080451844088_6472919519590397456_n.jpg?stp=c0.17.526.526a_dst-jpg_p526x395_tt6&_nc_cat=100&ccb=1-7&_nc_sid=92e707&_nc_ohc=n7DuVloFl8AQ7kNvwENDUMr&_nc_oc=AdldaRA2LWbWQc5mwCpysj7mtaQDZ1zS6Lffn4pZfNiId4MSzSTSxVQlbLPA9J65Fi0&_nc_zt=14&_nc_ht=scontent-atl3-1.xx&_nc_gid=61999-3M_MMirGV1BWLb1g&oh=00_Afhnrj0rauSp7TVGuMq8orjbfr7MzND1jBDiDhRGN6kTVA&oe=6917CC60'},
#     'listing_price': {'formatted_amount': '$1,350',
#      'amount_with_offset_in_currency': '135000',
#      'amount': '1350.00'},
#     'strikethrough_price': None,
#     'comparable_price': None,
#     'comparable_price_type': None,
#     'location': {'reverse_geocode': {'city': 'Elizabethport',
#       'state': 'NJ',
#       'city_page': {'display_name': 'Elizabeth, New Jersey',
#        'id': '105574016143908'}}},
#     'is_hidden': False,
#     'is_live': True,
#     'is_pending': False,
#     'is_sold': False,
#     'is_viewer_seller': False,
#     'min_listing_price': None,
#     'max_listing_price': None,
#     'marketplace_listing_category_id': '757715671026531',
#     'marketplace_listing_title': 'Multiple vehicles all for $1,350',
#     'custom_title': None,
#     'custom_sub_titles_with_rendering_flags': [],
#     'origin_group': None,
#     'listing_video': None,
#     'parent_listing': None,
#     'marketplace_listing_seller': {'__typename': 'User',
#      'name': None,
#      'id': None},
#     'delivery_types': ['IN_PERSON']},
#    {'listingUrl': 'https://www.facebook.com/marketplace/item/1532825097730538',
#     'id': '1532825097730538',
#     'primary_listing_photo': {'__typename': 'ProductImage',
#      'id': '1541253417003658',
#      'photo_image_url': 'https://scontent-atl3-3.xx.fbcdn.net/v/t39.84726-6/564613293_1541253490336984_6062496320057549283_n.jpg?stp=c90.0.540.540a_dst-jpg_p180x540_tt6&_nc_cat=109&ccb=1-7&_nc_sid=92e707&_nc_ohc=ZUPQV1hgm1QQ7kNvwE63i_Q&_nc_oc=Adk3VmDZTHb6p-IgPoVPBU2iyuC-9oC-O4u5EFL7DfMmTstD2Im4fyNkZ9AMdHdMO5w&_nc_zt=14&_nc_ht=scontent-atl3-3.xx&_nc_gid=61999-3M_MMirGV1BWLb1g&oh=00_Afi1qITJ1ZTkDvBvWky8hfzPOmjeUruhzZ1Rf9DgmstgyA&oe=6917B67E'},
#     'listing_price': {'formatted_amount': '$800',
#      'amount_with_offset_in_currency': '80000',
#      'amount': '800.00'},
#     'strikethrough_price': None,
#     'comparable_price': None,
#     'comparable_price_type': None,
#     'location': {'reverse_geocode': {'city': 'Newark',
#       'state': 'NJ',
#       'city_page': {'display_name': 'Newark, New Jersey',
#        'id': '108398645850982'}}},
#     'is_hidden': False,
#     'is_live': True,
#     'is_pending': False,
#     'is_sold': False,
#     'is_viewer_seller': False,
#     'min_listing_price': None,
#     'max_listing_price': None,
#     'marketplace_listing_category_id': '895487550471874',
#     'marketplace_listing_title': 'Car',
#     'custom_title': None,
#     'custom_sub_titles_with_rendering_flags': [],
#     'origin_group': None,
#     'listing_video': None,
#     'parent_listing': None,
#     'marketplace_listing_seller': {'__typename': 'User',
#      'name': None,
#      'id': None},
#     'delivery_types': ['IN_PERSON']},
#    {'listingUrl': 'https://www.facebook.com/marketplace/item/798037156317144',
#     'id': '798037156317144',
#     'primary_listing_photo': {'__typename': 'ProductImage',
#      'id': '1152677149685211',
#      'photo_image_url': 'https://scontent-atl3-2.xx.fbcdn.net/v/t39.84726-6/571241747_1152677206351872_7936208728667549449_n.jpg?stp=c0.204.526.526a_dst-jpg_p526x395_tt6&_nc_cat=102&ccb=1-7&_nc_sid=92e707&_nc_ohc=uhqJiqyIelwQ7kNvwEprTog&_nc_oc=Adl0kQLL5hqZ3SVwYwq0-GOWSuESHONydVTVgjr-T2sdbm5J-RfIpCI4ryaX56ni-M8&_nc_zt=14&_nc_ht=scontent-atl3-2.xx&_nc_gid=61999-3M_MMirGV1BWLb1g&oh=00_AfjVcTrR09qyKIK9N-vqbMxucdaUtsaKsI8OuxRy-aG7vw&oe=6917C8E2'},
#     'listing_price': {'formatted_amount': '$100',
#      'amount_with_offset_in_currency': '10000',
#      'amount': '100.00'},
#     'strikethrough_price': None,
#     'comparable_price': None,
#     'comparable_price_type': None,
#     'location': {'reverse_geocode': {'city': 'Perth Amboy',
#       'state': 'NJ',
#       'city_page': {'display_name': 'Perth Amboy, New Jersey',
#        'id': '105987266098708'}}},
#     'is_hidden': False,
#     'is_live': True,
#     'is_pending': False,
#     'is_sold': False,
#     'is_viewer_seller': False,
#     'min_listing_price': None,
#     'max_listing_price': None,
#     'marketplace_listing_category_id': '606456512821491',
#     'marketplace_listing_title': 'Lincoln mkt town car',
#     'custom_title': None,
#     'custom_sub_titles_with_rendering_flags': [],
#     'origin_group': None,
#     'listing_video': None,
#     'parent_listing': None,
#     'marketplace_listing_seller': {'__typename': 'User',
#      'name': None,
#      'id': None},
#     'delivery_types': ['IN_PERSON']},
#    {'listingUrl': 'https://www.facebook.com/marketplace/item/756304284113255',
#     'id': '756304284113255',
#     'primary_listing_photo': {'__typename': 'ProductImage',
#      'id': '1356092636023967',
#      'photo_image_url': 'https://scontent-atl3-2.xx.fbcdn.net/v/t39.30808-6/573543015_1356092662690631_101161405562047617_n.jpg?stp=dst-jpg_p526x296_tt6&_nc_cat=102&ccb=1-7&_nc_sid=454cf4&_nc_ohc=1gJZCwcdGuQQ7kNvwEU9B-p&_nc_oc=Adkjwvb8E3Enn3bwho0PCXF0Jv2yABSpcayMNyOulh40IEWbfCSmSVOof0jFIfCe0hk&_nc_zt=23&_nc_ht=scontent-atl3-2.xx&_nc_gid=61999-3M_MMirGV1BWLb1g&oh=00_AfjptFI_7PwYs8VS4MDru2QwLsmfHcgN3wdbtKiJ4GIeJQ&oe=6917D273'},
#     'listing_price': {'formatted_amount': '$1',
#      'amount_with_offset_in_currency': '100',
#      'amount': '1.00'},
#     'strikethrough_price': None,
#     'comparable_price': None,
#     'comparable_price_type': None,
#     'location': {'reverse_geocode': {'city': 'Glen Cove',
#       'state': 'NY',
#       'city_page': {'display_name': 'Glen Cove, New York',
#        'id': '105691409465261'}}},
#     'is_hidden': False,
#     'is_live': True,
#     'is_pending': False,
#     'is_sold': False,
#     'is_viewer_seller': False,
#     'min_listing_price': None,
#     'max_listing_price': None,
#     'marketplace_listing_category_id': '807311116002614',
#     'marketplace_listing_title': '2007 Nissan Altima · 3.5 SL (2017.5) Sedan 4D',
#     'custom_title': '2007 Nissan altima 3.5 SL (2017.5) Sedan 4D',
#     'custom_sub_titles_with_rendering_flags': [{'subtitle': '100K miles'}],
#     'origin_group': None,
#     'listing_video': None,
#     'parent_listing': None,
#     'marketplace_listing_seller': {'__typename': 'User',
#      'name': None,
#      'id': None},
#     'delivery_types': ['IN_PERSON']},
#    {'listingUrl': 'https://www.facebook.com/marketplace/item/730276190072526',
#     'id': '730276190072526',
#     'primary_listing_photo': {'__typename': 'ProductImage',
#      'id': '4266866220214702',
#      'photo_image_url': 'https://scontent-atl3-2.xx.fbcdn.net/v/t39.84726-6/568644765_4271477646420226_7784838447724172229_n.jpg?stp=c0.87.526.526a_dst-jpg_p526x395_tt6&_nc_cat=104&ccb=1-7&_nc_sid=92e707&_nc_ohc=RGx5ky0G4u0Q7kNvwERo-f-&_nc_oc=AdkJYjBE0UyfyJGaXE1ifPYlB1yQrwbdQSArTQKo7Y_DlysG6niO_WDS4A21gJ1iA_g&_nc_zt=14&_nc_ht=scontent-atl3-2.xx&_nc_gid=61999-3M_MMirGV1BWLb1g&oh=00_AfgMKIWAuTlYwCHa-COE7G0SwGPIk0sPD0vYadrN1_Hqow&oe=6917A2E3'},
#     'listing_price': {'formatted_amount': '$25',
#      'amount_with_offset_in_currency': '2500',
#      'amount': '25.00'},
#     'strikethrough_price': None,
#     'comparable_price': None,
#     'comparable_price_type': None,
#     'location': {'reverse_geocode': {'city': 'Linden',
#       'state': 'NJ',
#       'city_page': {'display_name': 'Linden, New Jersey',
#        'id': '104165982951951'}}},
#     'is_hidden': False,
#     'is_live': True,
#     'is_pending': False,
#     'is_sold': False,
#     'is_viewer_seller': False,
#     'min_listing_price': None,
#     'max_listing_price': None,
#     'marketplace_listing_category_id': '606456512821491',
#     'marketplace_listing_title': '1:14 Bugatti Chiron',
#     'custom_title': None,
#     'custom_sub_titles_with_rendering_flags': [],
#     'origin_group': None,
#     'listing_video': None,
#     'parent_listing': None,
#     'marketplace_listing_seller': {'__typename': 'User',
#      'name': None,
#      'id': None},
#     'delivery_types': ['IN_PERSON']}]}}
