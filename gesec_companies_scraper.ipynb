# %%
import json
import pprint
import requests
import pandas as pd

# %%
url1 = "https://www.gesec.fr/wp-json/sn/adherent/all"

# %%
res = requests.get(url1)
res.json()

# %%
data = res.json()
pprint(data[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_200/1049423207.py in <cell line: 0>()
#       1 data = res.json()
# ----> 2 pprint(data[0])
#
# TypeError: 'module' object is not callable. Did you mean: 'pprint.pprint(...)'?
