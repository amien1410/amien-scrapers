# %% [markdown]
# <a href="https://colab.research.google.com/github/amien1410/amien-scrapers/blob/main/Ulta_Cosmetics_Scraper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import requests
import pandas as pd

# %%
import requests

url = "https://www.ulta.com/dxl/graphql?ultasite=en-us"

headers = {
    "accept": "*/*",
    "accept-encoding": "gzip, deflate, br, zstd",
    "accept-language": "en-US,en;q=0.9,id;q=0.8,fa;q=0.7,ar;q=0.6,ms;q=0.5,ja;q=0.4,es;q=0.3",
    "content-type": "application/json",
    "cookie": "ulta-context=dsp; __ruid=438f1fdcd3f76e5b62442e132abb4253; X_ULTA_VISITOR_ID=438f1fdcd3f76e5b62442e132abb4253; ULTA_DSP_RT=eyJhbGciOiJIUzI1NiJ9..8hYqWrP8HS-8E_Ut8J1YifPEvafcra1A6pyvRPHWJcU; _mibhv=anon-1752467195240-798633441_8715; __tvpa=cf9503e3ca60eb5ff0d758cad88cba0a; OptanonAlertBoxClosed=2025-07-14T04:40:01.863Z; akaalb_alb_www_ulta=~op=WWW_ULTA_SITE_A:SiteA_Failover|~rv=4~m=SiteA_Failover:0|~os=6e40862a2abd586d46d773cd430ecffc~id=e1466a0152c951d12da3ddbe6322a9a0; ULTA_SITE=B; X_ULTA_SITE=B; akaalb_alb_www_dsp=~op=WWW_DSP_SITE_B:Prod_DSP_SiteB_Origin1|~rv=67~m=Prod_DSP_SiteB_Origin1:0|~os=6e40862a2abd586d46d773cd430ecffc~id=d032a0583884c87da37e32194de76792; User-Agent=gomez; ULTASITE=en-us; AMCVS_C218F16F55CC57607F000101%40AdobeOrg=1; s_cc=true; distinct_id=4bb744ca-3694-5d5c-b083-d1ac4a10d053; session_id=5e1df605-56f3-57ec-be08-0aac530ca872; salsify_session_id=c710d5fa-49fc-426d-ad3e-d4a3f909b3d9; OptanonConsent=isGpcEnabled=0&datestamp=Wed+Jul+16+2025+15%3A20%3A33+GMT%2B0800+(China+Standard+Time)&version=202408.1.0&browserGpcFlag=0&isIABGlobal=false&hosts=&consentId=abf571f3-acf4-43da-9325-e9f8f36c7391&interactionCount=1&isAnonUser=1&landingPath=NotLandingPage&groups=C0007%3A1%2CC0001%3A1%2CC0002%3A1&intType=3&geolocation=ID%3BKI&AwaitingReconsent=false; user_attributes=gtid:c35d1f5d-4e9a-45aa-abb7-a4fd841cd224|gtid_device:438f1fdcd3f76e5b62442e132abb4253; utag_ck_gtid=undefined; powerreviews_reviews=play everyday sunscreen stick spf 50 : supergoop!; utag_main=v_id:0198072f0cb8001ee49580b67fd40507d00250750086e$_sn:4$_se:16$_ss:0$_st:1752652239361$vapi_domain:ulta.com$ses_id:1752648428479%3Bexp-session$_pn:3%3Bexp-session; s_nr=1752650443229-Repeat; AMCV_C218F16F55CC57607F000101%40AdobeOrg=-1124106680%7CMCIDTS%7C20286%7CMCMID%7C37987910536205062506622977007775649781%7CMCAID%7CNONE%7CMCOPTOUT-1752657643s%7CNONE%7CvVersion%7C5.2.0; AKA_A2=A; ULTA_DSP_AT=eyJhbGciOiJIUzI1NiJ9..6JOvSCnBmsgG27_VPy67qmjl_XoqLvx6-j-N-pEkNeQ; dtCookie=v_4_srv_19_sn_33384BC8A7F3CB0C6F182E7204A93801_perc_100000_ol_0_mul_1_app-3Aea7c4b59f27d43eb_0_app-3A6fe4664190660d01_1_rcs-3Acss_0; akavpau_vp-www-ulta-com=1752652832~id=b1f9d2afe8a03666362a624153441a2e",
    "origin": "https://www.ulta.com",
    "referer": "https://www.ulta.com/dxl/graphql?ultasite=en-us",
    "sec-ch-ua": '"Not)A;Brand";v="8", "Chromium";v="138", "Microsoft Edge";v="138"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": '"Windows"',
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-origin",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36 Edg/138.0.0.0"
}

payload = {
    "operationName": "NonCachedPage",
    "query": """
        query NonCachedPage($stagingHost: String, $previewOptions: JSON, $moduleParams: JSON) {
          Page: NonCachedPage(
            stagingHost: $stagingHost,
            previewOptions: $previewOptions,
            moduleParams: $moduleParams,
            url: {path: "https://www.ulta.com/shop/makeup/face?page=1"},
            contentId: "cb7c0efb-8772-4abc-9be0-4dfaf1b625ee"
          ) {
            content
            customResponseAttributes
            meta
            __typename
          }
        }
    """,
    "variables": {
        "moduleParams": {
            "gti": "c35d1f5d-4e9a-45aa-abb7-a4fd841cd224",
            "loginStatus": "anonymous",
            "retailerVisitorId": "438f1fdcd3f76e5b62442e132abb4253",
            "breakpoint": "MD"
        }
    }
}

response = requests.post(url, headers=headers, json=payload)
print(response.status_code)
# print(response.json())
items = response.json()['data']['Page']['content']['items']
print(len(items))
# Out:
# 200
# 64

# %%
items[0]
# Out:
# {'dataCapture': {'category': 'Interaction',
#   'eventName': 'view_item_list',
#   'clientEvent': 'Viewport',
#   'moduleName': 'DataCaptureEvent',
#   'dataLayer': {'Tealium': {'results': '1567',
#     'product_id': ['xlsimpprod14641507'],
#     'product_sku': ['2309420'],
#     'product_name': ['double wear stay-in-place foundation'],
#     'product_brand': ['estée lauder'],
#     'product_price': ['52.00'],
#     'product_sale_price': [''],
#     'product_rating': ['4.6'],
#     'product_reviews_count': ['11064'],
#     'product_discount': [''],
#     'filter_group': [],
#     'filter_label': [],
#     'item_index': ['1'],
#     'product_category': [''],
#     'product_tag': [''],
#     'criteo_product_list_view_beacon': [''],
#     'component_type': 'productlistingresults',
#     'criteo_product_list_format_view_beacon': [''],
#     'tealium_event': 'view_item_list'}},
#   'unresolvedData': []},
#  'skuId': '2309420',
#  'action': {'label': None,
# ...
