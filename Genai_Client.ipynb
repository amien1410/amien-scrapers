# %%
import google.generativeai as genai
from google.colab import userdata

# %%
genai.configure(api_key="")
gemini_model = genai.GenerativeModel('gemini-pro-latest')
prompt = "A futuristic city with flying cars and towering skyscrapers at sunset."

response = gemini_model.generate_content(f"Describe an image of: {prompt}")

print("Prompt:", prompt)
print("\nModel's description/response:")
print(response.text)
# Out:
# Prompt: A futuristic city with flying cars and towering skyscrapers at sunset.
#
# Model's description/response:
# Of course. Here is a detailed description of an image of a futuristic city with flying cars and towering skyscrapers at sunset.
#
# ***
#
# The image captures a breathtaking, panoramic view of a futuristic megalopolis at the magical hour of sunset. The sky is a dramatic canvas, awash in a gradient of fiery orange, deep magenta, and soft violet near the horizon, fading upwards into an indigo night where the first stars begin to twinkle.
#
# **The Skyscrapers:**
# Dominating the landscape are the skyscrapers, colossal structures of impossible height and design that pierce the clouds. They are not mere rectangular towers but works of architectural art. Some spiral upwards like metallic DNA helices, their surfaces a mosaic of gleaming chrome and smart glass that reflects the sunset's vibrant colors. Others are sleek, blade-like structures with cascading waterfalls and vertical gardens clinging to their sides, adding a touch of organic life to the synthetic world. Many of the towers are interconnected by elegant, suspended sky-bridges, creating a web of pathways high above the ground. As the sun dips below the horizon, the buildings begin to come alive with their own light—bioluminescent panels pulse with a soft, cool glow, and massive holographic advertisements flicker into existence, displaying dynamic, colorful imagery against the darkening sky.
#
# **The Flying Cars:**
# Weaving through this vertical cityscape is the constant, silent ballet of flying vehicles. These are not clunky, retro-futuristic cars, but sleek, aerodynamic pods and crafts. Their polished chassis, in shades of pearl white, obsidian black, and liquid silver, catch the last rays of the sun, glinting like scattered jewels. They move with effortless grace along designated, multi-level sky-lanes, marked by faint, glowing energy fields. Their thrusters or anti-gravity engines leave behind ephemeral trails of light—streaks of crimson, white, and electric blue—creating a stunning long-exposure effect against the twilight. You can see a variety of vehicles: small, single-person pods zipping through narrow gaps, larger, more luxurious cruisers gliding majestically, and utilitarian cargo drones methodically navigating their routes.
#
# **The Atmosphere and Details:**
# The overall mood is one of awe-inspiring scale and serene energy. Despite the bustling activity of the flying cars, there's a sense of organized harmony. The long shadows cast by the colossal towers stretch across the city, creating a stark contrast between light and dark. On the lower levels, closer to the unseen ground, the city is already bathed in the cool glow of artificial lights. On the highest levels, rooftop gardens on some of the skyscrapers are still bathed in the warm, golden light of the setting sun, where tiny silhouettes of people can be seen enjoying the view from observation decks or open-air cafes.
#
# In essence, the image is a stunning juxtaposition of nature's beauty and humanity's technological ambition—a vision of a future that is both monumentally advanced and breathtakingly beautiful.

# %%
for m in genai.list_models():
  if "generateContent" in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-2.5-pro-preview-03-25
# models/gemini-2.5-flash
# models/gemini-2.5-pro-preview-05-06
# models/gemini-2.5-pro-preview-06-05
# models/gemini-2.5-pro
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-flash-lite-preview
# models/gemini-2.0-pro-exp
# models/gemini-2.0-pro-exp-02-05
# models/gemini-exp-1206
# models/gemini-2.0-flash-thinking-exp-01-21
# models/gemini-2.0-flash-thinking-exp
# models/gemini-2.0-flash-thinking-exp-1219
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/learnlm-2.0-flash-experimental
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/gemma-3n-e4b-it
# models/gemma-3n-e2b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image-preview
# models/gemini-2.5-flash-image
# models/gemini-2.5-flash-preview-09-2025
# models/gemini-2.5-flash-lite-preview-09-2025
# models/gemini-3-pro-preview
# models/gemini-3-pro-image-preview
# models/nano-banana-pro-preview
# models/gemini-robotics-er-1.5-preview
# models/gemini-2.5-computer-use-preview-10-2025
