# %% [markdown]
# # FEEL22.COM product scraper

# %%
import json

file_path = '/content/drive/MyDrive/Upwork/mahmoud/fell22_products.json'

# Read the JSON file
with open(file_path, 'r', encoding='utf-8') as f:
    data = json.load(f)

# Display the first product
if data and isinstance(data, list):
    print("First product from the JSON file:")
    print(json.dumps(data[0], indent=2))
elif data and isinstance(data, dict):
    print("JSON file contains a dictionary. Displaying it:")
    print(json.dumps(data, indent=2))
else:
    print("JSON file is empty or in an unexpected format.")
# Out:
# First product from the JSON file:
# {
#   "id": 8797514039434,
#   "title": "Revuele Perfect Hair Reboot Gift Set",
#   "handle": "revuele-perfect-hair-reboot-gift-set",
#   "body_html": "<p><strong>This Set Contains:</strong></p>\n<ul>\n<li>Revuele Perfect Hair Repair Shampoo</li>\n<li>Revuele Perfect Hair Repair Conditionar</li>\n<li>Revuele Argan Oil</li>\n<li>\n<strong>Free</strong> Revuele Ampoules</li>\n</ul>",
#   "published_at": "2025-12-12T15:35:00+02:00",
#   "created_at": "2025-12-09T20:40:29+02:00",
#   "updated_at": "2025-12-14T13:18:52+02:00",
#   "vendor": "Revuele",
#   "product_type": "Hair Care Gifts and Sets",
#   "tags": [
#     "XMASGIFTS25"
#   ],
#   "variants": [
#     {
#       "id": 47436758515850,
#       "title": "Default Title",
#       "option1": "Default Title",
#       "option2": null,
#       "option3": null,
#       "sku": "REVS18",
#       "requires_shipping": true,
#       "taxable": true,
#       "featured_image": null,
#       "available": true,
#       "price": "28.00",
#       "grams": 1,
#       "compare_at_price": null,
#       "position": 1,
#       "product_id": 8797514039434,
#       "created_at": "2025-12-09T20:40:29+02:00",
#       "updated_at": "2025-12-14T13:18:52+02:00"
#     }
#   ],
#   "images": [
#     {
#       "id": 39853972226186,
#       "created_at": "2025-12-09T21:04:40+02:00",
#       "position": 1,
#       "updated_at": "2025-12-09T21:06:51+02:00",
#       "product_id": 8797514039434,
#       "variant_ids": [],
#       "src": "https://cdn.shopify.com/s/files/1/1291/3633/files/RevuelePerfectHairRebootGiftSet.png?v=1765307211",
#       "width": 1080,
#       "height": 1080
#     },
#     {
#       "id": 39853972193418,
#       "created_at": "2025-12-09T21:04:40+02:00",
#       "position": 2,
#       "updated_at": "2025-12-09T21:06:51+02:00",
#       "product_id": 8797514039434,
#       "variant_ids": [],
#       "src": "https://cdn.shopify.com/s/files/1/1291/3633/files/RevuelePerfectHairRebootGiftSet_2.png?v=1765307211",
#       "width": 1080,
#       "height": 1080
#     }
#   ],
#   "options": [
#     {
#       "name": "Title",
#       "position": 1,
#       "values": [
#         "Default Title"
#       ]
#     }
#   ]
# }

# %%
BASE_URL = "https://feel22.com/products/"

# Ensure 'data' from daouk_products.json is loaded and is a list
if 'data' in globals() and isinstance(data, list):
    daouk_handles = [item['handle'] for item in data if 'handle' in item]
    FEEL22_URLS = [f"{BASE_URL}{handle}" for handle in daouk_handles]
    print(f"Generated {len(FEEL22_URLS)} URLs for Feel22.com.")
    # Display the first few generated URLs as a sanity check
    print("First 5 Feel22 URLs:")
    for i in range(min(5, len(FEEL22_URLS))):
        print(FEEL22_URLS[i])
else:
    print("Error: 'data' variable not found or not in expected format. Please ensure daouk_products.json was loaded correctly.")
    FEEL22_URLS = []
# Out:
# Generated 7930 URLs for Feel22.com.
# First 5 Feel22 URLs:
# https://feel22.com/products/revuele-perfect-hair-reboot-gift-set
# https://feel22.com/products/revuele-purifying-clear-skin-gift-set
# https://feel22.com/products/revuele-retinol-moonlift-gift-set
# https://feel22.com/products/babyliss-hair-straightner-st089e
# https://feel22.com/products/isdin-retinal-intense-holiday-gift-set

# %%
import requests
import re
import json
import html
import os
import time
from google.colab import files

# -----------------------------
# CONFIG
# -----------------------------
BACKUP_EVERY = 500
PROGRESS_FILE = "progress.txt"
BACKUP_PREFIX = "backup_"
FINAL_FILE = "final_results.json"
TIMEOUT = 15
DELAY = 0.25  # be polite

# -----------------------------
# FETCH FUNCTION
# -----------------------------
def fetch_product_data(url: str) -> dict:
    headers = {
        "User-Agent": "Mozilla/5.0",
        "Accept": "text/html",
    }

    res = requests.get(url, headers=headers, timeout=20)
    res.raise_for_status()
    html_text = res.text

    # Find ALL assignments
    pattern = re.compile(
        r'Shopify\.current_product\s*=\s*(\{[\s\S]*?\})\s*;',
        re.MULTILINE
    )

    matches = pattern.findall(html_text)
    if not matches:
        raise ValueError("Shopify.current_product not found")

    # Take the LAST meaningful assignment
    raw_obj = matches[-1]

    # Remove JS spread syntax {...{ JSON }}
    raw_obj = re.sub(r'^\{\s*\.\.\.\s*\{', '{', raw_obj)
    raw_obj = re.sub(r'\}\s*\}$', '}', raw_obj)

    # Decode HTML entities
    raw_obj = html.unescape(raw_obj)

    # Convert to Python dict
    product = json.loads(raw_obj)

    # Sanity check
    if not product.get("id"):
        raise ValueError("Parsed product is empty or invalid")

    return product

# -----------------------------
# LOAD PROGRESS
# -----------------------------
start_index = 0
if os.path.exists(PROGRESS_FILE):
    with open(PROGRESS_FILE, "r") as f:
        start_index = int(f.read().strip())

print(f"Starting from index: {start_index}")

# -----------------------------
# LOAD URL LIST
# -----------------------------
# urls = [...]  # YOUR 4100 URLs HERE
urls = FEEL22_URLS  # assume already defined

total = len(urls)
batch_data = []
all_files = []

# -----------------------------
# MAIN LOOP
# -----------------------------
for i in range(start_index, total):
    url = urls[i]
    print(f"Processing .... {url}")

    try:
        product = fetch_product_data(url)
        batch_data.append(product)
    except Exception:
        pass  # silent fail, resume-safe

    # Save progress
    with open(PROGRESS_FILE, "w") as f:
        f.write(str(i + 1))

    # Backup every N items
    if (i + 1) % BACKUP_EVERY == 0 or i == total - 1:
        batch_num = (i + 1) // BACKUP_EVERY + (1 if (i + 1) % BACKUP_EVERY else 0)
        backup_name = f"{BACKUP_PREFIX}{batch_num:03d}.json"

        with open(backup_name, "w", encoding="utf-8") as f:
            json.dump(batch_data, f, indent=2, ensure_ascii=False)

        files.download(backup_name)
        all_files.append(backup_name)
        batch_data = []

        print(f"Processed {i + 1}/{total}")

    time.sleep(DELAY)

# -----------------------------
# FINAL MERGE
# -----------------------------
final_results = []

for file in sorted(f for f in os.listdir() if f.startswith(BACKUP_PREFIX)):
    with open(file, "r", encoding="utf-8") as f:
        final_results.extend(json.load(f))

with open(FINAL_FILE, "w", encoding="utf-8") as f:
    json.dump(final_results, f, indent=2, ensure_ascii=False)

files.download(FINAL_FILE)

print(f"\n✅ DONE — {len(final_results)} products saved to {FINAL_FILE}")
# Out:
# Starting from index: 0
# Processing .... https://feel22.com/products/revuele-perfect-hair-reboot-gift-set
# Processing .... https://feel22.com/products/revuele-purifying-clear-skin-gift-set
# Processing .... https://feel22.com/products/revuele-retinol-moonlift-gift-set
# Processing .... https://feel22.com/products/children-cancer-center-of-lebanon-x-feel22-donation-voucher
# Processing .... https://feel22.com/products/potion-kitchen-nailed-it-cuticle-oil
# Processing .... https://feel22.com/products/potion-kitchen-lavender-body-oil
# Processing .... https://feel22.com/products/eucerin-skin-protection-shower-oil-ph5
# Processing .... https://feel22.com/products/bio-oil-scars-stretches-aging-and-dehydrated-skin
# Processing .... https://feel22.com/products/bio-oil-hydrating-dry-skin-gel
# Processing .... https://feel22.com/products/garnier-ultra-doux-almond-milk-and-agave-sap-normal-hair-shampoo
# Processing .... https://feel22.com/products/essie-659-home-grown-nail-polish
# Processing .... https://feel22.com/products/maybelline-tattoo-liner-long-wear-gel-eye-pencil
# Processing .... https://feel22.com/products/bourjois-rouge-fabuleux-lipstick
# Processing .... https://feel22.com/products/garnier-ultra-doux-mythic-olive-shampoo
# Processing .... https://feel22.com/products/samoa-ooh-la-lips-longwear-matte-liquid-lipstick
# Processing .... https://feel22.com/products/maybelline-color-sensational-powder-matte-lipstick
# Processed 7930/7930
# ✅ DONE — 7902 products saved to final_results.json

# %%
import shutil
import os

drive_path = "/content/drive/MyDrive/Upwork/mahmoud"

# Ensure the destination directory exists
os.makedirs(drive_path, exist_ok=True)

json_files_to_copy = [
    "/content/backup_001.json",
    "/content/backup_002.json",
    "/content/backup_003.json",
    "/content/backup_004.json",
    "/content/backup_005.json",
    "/content/backup_006.json",
    "/content/backup_007.json",
    "/content/backup_008.json",
    "/content/backup_009.json",
    "/content/backup_010.json",
    "/content/backup_011.json",
    "/content/backup_012.json",
    "/content/backup_013.json",
    "/content/backup_014.json",
    "/content/final_results.json"
]

for file_path in json_files_to_copy:
    if os.path.exists(file_path):
        try:
            shutil.copy(file_path, drive_path)
            print(f"Successfully copied: {file_path} to {drive_path}")
        except Exception as e:
            print(f"Error copying {file_path}: {e}")
    else:
        print(f"File not found: {file_path}")
# Out:
# Successfully copied: /content/backup_001.json to /content/drive/MyDrive/Upwork/mahmoud
# Successfully copied: /content/backup_002.json to /content/drive/MyDrive/Upwork/mahmoud
# Successfully copied: /content/backup_003.json to /content/drive/MyDrive/Upwork/mahmoud
# Successfully copied: /content/backup_004.json to /content/drive/MyDrive/Upwork/mahmoud
# Successfully copied: /content/backup_005.json to /content/drive/MyDrive/Upwork/mahmoud
# Successfully copied: /content/backup_006.json to /content/drive/MyDrive/Upwork/mahmoud
# Successfully copied: /content/backup_007.json to /content/drive/MyDrive/Upwork/mahmoud
# Successfully copied: /content/backup_008.json to /content/drive/MyDrive/Upwork/mahmoud
# Successfully copied: /content/backup_009.json to /content/drive/MyDrive/Upwork/mahmoud
# Successfully copied: /content/backup_010.json to /content/drive/MyDrive/Upwork/mahmoud
# Successfully copied: /content/backup_011.json to /content/drive/MyDrive/Upwork/mahmoud
# Successfully copied: /content/backup_012.json to /content/drive/MyDrive/Upwork/mahmoud
# Successfully copied: /content/backup_013.json to /content/drive/MyDrive/Upwork/mahmoud
# Successfully copied: /content/backup_014.json to /content/drive/MyDrive/Upwork/mahmoud
# Successfully copied: /content/final_results.json to /content/drive/MyDrive/Upwork/mahmoud

# %%
#@title FattalBeauty.com products scraper

import json

file_path = '/content/drive/MyDrive/Upwork/mahmoud/fattalbeauty_products.json'

# Read the JSON file
with open(file_path, 'r', encoding='utf-8') as f:
    data = json.load(f)

# Display the first product
if data and isinstance(data, list):
    print("First product from the JSON file:")
    print(json.dumps(data[0], indent=2))
elif data and isinstance(data, dict):
    print("JSON file contains a dictionary. Displaying it:")
    print(json.dumps(data, indent=2))
else:
    print("JSON file is empty or in an unexpected format.")

BASE_URL = "https://fattalbeauty.com/products/"

# Ensure 'data' from daouk_products.json is loaded and is a list
if 'data' in globals() and isinstance(data, list):
    fattalbeauty_handles = [item['handle'] for item in data if 'handle' in item]
    FATTALBEAUTY_URLS = [f"{BASE_URL}{handle}" for handle in fattalbeauty_handles]
    print(f"Generated {len(FATTALBEAUTY_URLS)} URLs for Fattalbeauty.com.")
    # Display the first few generated URLs as a sanity check
    print("First 5 Feel22 URLs:")
    for i in range(min(5, len(FATTALBEAUTY_URLS))):
        print(FATTALBEAUTY_URLS[i])
else:
    print("Error: 'data' variable not found or not in expected format. Please ensure Fattalbeauty_products.json was loaded correctly.")
    FATTALBEAUTY_URLS = []
# Out:
# First product from the JSON file:
# {
#   "id": 8881004937365,
#   "title": "Polo Exchange Accessories PXRI0210",
#   "handle": "polo-exchange-accessories-pxri0210",
#   "body_html": "<p>Polo Exchange Accessories PXRI0210</p>",
#   "published_at": "2025-12-13T09:14:28+02:00",
#   "created_at": "2025-08-26T12:09:22+03:00",
#   "updated_at": "2025-12-14T13:20:35+02:00",
#   "vendor": "Polo Exchange",
#   "product_type": "Watches & Accessories",
#   "tags": [
#     "Acc Discounts",
#     "Accessories for Her",
#     "Ring",
#     "Watches & Accessories"
#   ],
#   "variants": [
#     {
#       "id": 46341834375317,
#       "title": "Default Title",
#       "option1": "Default Title",
#       "option2": null,
#       "option3": null,
#       "sku": "276434",
#       "requires_shipping": true,
#       "taxable": false,
#       "featured_image": null,
#       "available": false,
#       "price": "25.00",
#       "grams": 0,
#       "compare_at_price": null,
#       "position": 1,
#       "product_id": 8881004937365,
#       "created_at": "2025-08-26T12:09:22+03:00",
#       "updated_at": "2025-12-14T13:20:35+02:00"
#     }
#   ],
#   "images": [
#     {
#       "id": 44249371246741,
#       "created_at": "2025-08-26T12:09:23+03:00",
#       "position": 1,
#       "updated_at": "2025-08-26T12:09:25+03:00",
#       "product_id": 8881004937365,
#       "variant_ids": [],
#       "src": "https://cdn.shopify.com/s/files/1/0602/5668/2133/files/276434_8c912249-ba68-46d8-a680-f80e4e310e7f.png?v=1756199365",
#       "width": 1000,
#       "height": 1000
#     }
#   ],
#   "options": [
#     {
#       "name": "Title",
#       "position": 1,
#       "values": [
#         "Default Title"
#       ]
#     }
#   ]
# }
# Generated 2603 URLs for Fattalbeauty.com.
# First 5 Feel22 URLs:
# https://fattalbeauty.com/products/polo-exchange-accessories-pxri0210
# https://fattalbeauty.com/products/versace-bright-crystal-gift-set
# https://fattalbeauty.com/products/versace-eros-energy-gift-set
# https://fattalbeauty.com/products/versace-pour-homme-gift-set
# https://fattalbeauty.com/products/versace-eros-flame-gift-set

# %%
# ============================================================
# FULL CONCURRENT SHOPIFY PRODUCT SCRAPER (COLAB READY)
# ============================================================

import os
import re
import json
import html
import requests
from concurrent.futures import ThreadPoolExecutor, as_completed
from threading import Lock
from google.colab import files

# ============================================================
# CONFIG
# ============================================================

BASE_DIR = "fattalbeauty_products"
os.makedirs(BASE_DIR, exist_ok=True)

BACKUP_EVERY = 500
PROGRESS_FILE = os.path.join(BASE_DIR, "progress.txt")
BACKUP_PREFIX = os.path.join(BASE_DIR, "backup_")
FINAL_FILE = os.path.join(BASE_DIR, "final_results.json")

TIMEOUT = 20
MAX_WORKERS = 8   # safe: 8–10

progress_lock = Lock()

# ============================================================
# FETCH FUNCTION (UNCHANGED LOGIC)
# ============================================================

def fetch_product_data(url: str) -> dict:
    headers = {
        "User-Agent": "Mozilla/5.0",
        "Accept": "text/html",
    }

    res = requests.get(url, headers=headers, timeout=20)
    res.raise_for_status()
    html_text = res.text

    # -------------------------------------------------
    # 1. QUICK AVAILABILITY CHECK
    # -------------------------------------------------
    if "window._themeProducts" not in html_text:
        return None

    # -------------------------------------------------
    # 2. EXTRACT JS OBJECT
    # window._themeProducts[ID] = { ... };
    # -------------------------------------------------
    pattern = re.compile(
        r'window\._themeProducts\[\d+\]\s*=\s*(\{[\s\S]*?\})\s*;',
        re.MULTILINE
    )

    match = pattern.search(html_text)
    if not match:
        return None

    raw_obj = match.group(1)

    # -------------------------------------------------
    # 3. CLEAN JS → JSON
    # -------------------------------------------------

    # Decode HTML entities
    raw_obj = html.unescape(raw_obj)

    # Remove trailing commas (JS allows it, JSON doesn't)
    raw_obj = re.sub(r',(\s*[}\]])', r'\1', raw_obj)

    # Quote object keys (id: -> "id":)
    raw_obj = re.sub(
        r'([{\s,])([a-zA-Z_][a-zA-Z0-9_]*)\s*:',
        r'\1"\2":',
        raw_obj
    )

    # Replace JS booleans/nulls
    raw_obj = raw_obj.replace("true", "true")
    raw_obj = raw_obj.replace("false", "false")
    raw_obj = raw_obj.replace("null", "null")

    # -------------------------------------------------
    # 4. PARSE JSON
    # -------------------------------------------------
    try:
        product = json.loads(raw_obj)
    except json.JSONDecodeError as e:
        raise ValueError(f"JSON parse failed: {e}")

    # -------------------------------------------------
    # 5. SANITY CHECK
    # -------------------------------------------------
    if not product.get("id") or not product.get("title"):
        return None

    return product

# ============================================================
# WORKER WRAPPER
# ============================================================

def fetch_worker(index, url):
    try:
        return index, fetch_product_data(url)
    except Exception:
        return index, None

# ============================================================
# LOAD PROGRESS
# ============================================================

start_index = 0
if os.path.exists(PROGRESS_FILE):
    with open(PROGRESS_FILE, "r") as f:
        start_index = int(f.read().strip())

print(f"Starting from index: {start_index}")

# ============================================================
# URL LIST
# ============================================================
urls = FATTALBEAUTY_URLS


total = len(urls)
batch_data = []

# ============================================================
# MAIN CONCURRENT LOOP
# ============================================================

with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
    futures = {
        executor.submit(fetch_worker, i, urls[i]): i
        for i in range(start_index, total)
    }

    for future in as_completed(futures):
        i, product = future.result()

        if product:
            batch_data.append(product)

        # ---- progress update ----
        with progress_lock:
            with open(PROGRESS_FILE, "w") as f:
                f.write(str(i + 1))

        # ---- backup ----
        if (i + 1) % BACKUP_EVERY == 0 or i == total - 1:
            batch_num = (i + 1) // BACKUP_EVERY + (1 if (i + 1) % BACKUP_EVERY else 0)
            backup_name = f"{BACKUP_PREFIX}{batch_num:03d}.json"

            with open(backup_name, "w", encoding="utf-8") as f:
                json.dump(batch_data, f, indent=2, ensure_ascii=False)

            files.download(backup_name)
            batch_data = []

            print(f"Processed {i + 1}/{total}")

# ============================================================
# FINAL MERGE
# ============================================================

final_results = []

for file in sorted(f for f in os.listdir(BASE_DIR) if f.startswith("backup_")):
    with open(os.path.join(BASE_DIR, file), "r", encoding="utf-8") as f:
        final_results.extend(json.load(f))

with open(FINAL_FILE, "w", encoding="utf-8") as f:
    json.dump(final_results, f, indent=2, ensure_ascii=False)

files.download(FINAL_FILE)

print(f"\n✅ DONE — {len(final_results)} products saved to {FINAL_FILE}")
# Out:
# Starting from index: 0
# Processed 500/2603
# Processed 1000/2603
# Processed 1500/2603
# Processed 2000/2603
# Processed 2500/2603
# Processed 2603/2603
# ✅ DONE — 2598 products saved to fattalbeauty_products/final_results.json

# %%
import shutil
import os

# SOURCE (Colab runtime)
SRC_FOLDER = "/content/fattalbeauty_products"

# DESTINATION (Google Drive)
DEST_PARENT = "/content/drive/MyDrive/Upwork/mahmoud"

# Safety check
if not os.path.isdir(SRC_FOLDER):
    raise FileNotFoundError(f"Source folder does not exist: {SRC_FOLDER}")

# Final destination path (folder itself is copied)
DEST_FOLDER = os.path.join(DEST_PARENT, os.path.basename(SRC_FOLDER))

# Remove existing folder (optional but recommended)
if os.path.exists(DEST_FOLDER):
    shutil.rmtree(DEST_FOLDER)

# Copy ENTIRE folder
shutil.copytree(SRC_FOLDER, DEST_FOLDER)

print("✅ Folder copied successfully")
print("📁 Location:", DEST_FOLDER)
# Out:
# ✅ Folder copied successfully
# 📁 Location: /content/drive/MyDrive/Upwork/mahmoud/fattalbeauty_products

# %%
import requests
import re
import json
import html

def fetch_product_data_themeproducts(url: str) -> dict | None:
    headers = {
        "User-Agent": "Mozilla/5.0",
        "Accept": "text/html",
    }

    res = requests.get(url, headers=headers, timeout=20)
    res.raise_for_status()
    html_text = res.text

    # -------------------------------------------------
    # 1. QUICK AVAILABILITY CHECK
    # -------------------------------------------------
    if "window._themeProducts" not in html_text:
        return None

    # -------------------------------------------------
    # 2. EXTRACT JS OBJECT
    # window._themeProducts[ID] = { ... };
    # -------------------------------------------------
    pattern = re.compile(
        r'window\._themeProducts\[\d+\]\s*=\s*(\{[\s\S]*?\})\s*;',
        re.MULTILINE
    )

    match = pattern.search(html_text)
    if not match:
        return None

    raw_obj = match.group(1)

    # -------------------------------------------------
    # 3. CLEAN JS → JSON
    # -------------------------------------------------

    # Decode HTML entities
    raw_obj = html.unescape(raw_obj)

    # Remove trailing commas (JS allows it, JSON doesn't)
    raw_obj = re.sub(r',(\s*[}\]])', r'\1', raw_obj)

    # Quote object keys (id: -> "id":)
    raw_obj = re.sub(
        r'([{\s,])([a-zA-Z_][a-zA-Z0-9_]*)\s*:',
        r'\1"\2":',
        raw_obj
    )

    # Replace JS booleans/nulls
    raw_obj = raw_obj.replace("true", "true")
    raw_obj = raw_obj.replace("false", "false")
    raw_obj = raw_obj.replace("null", "null")

    # -------------------------------------------------
    # 4. PARSE JSON
    # -------------------------------------------------
    try:
        product = json.loads(raw_obj)
    except json.JSONDecodeError as e:
        raise ValueError(f"JSON parse failed: {e}")

    # -------------------------------------------------
    # 5. SANITY CHECK
    # -------------------------------------------------
    if not product.get("id") or not product.get("title"):
        return None

    return product

product = fetch_product_data_themeproducts("https://fattalbeauty.com/products/calvin-klein-2-pack-modern-cotton-lounge-white-t-shirts")

if product:
    print(json.dumps(product, indent=2))
else:
    print("❌ No product data found")
# Out:
# {
#   "has_3d_model": false,
#   "id": 7934081925269,
#   "title": "Calvin Klein 2 Pack Modern Cotton Lounge White T-Shirts",
#   "available": true,
#   "handle": "calvin-klein-2-pack-modern-cotton-lounge-white-t-shirts",
#   "variants": [
#     {
#       "id": 43518768414869,
#       "title": "White / S",
#       "option1": "White",
#       "option2": "S",
#       "option3": null,
#       "sku": "206445",
#       "requires_shipping": true,
#       "taxable": false,
#       "featured_image": null,
#       "available": true,
#       "name": "Calvin Klein 2 Pack Modern Cotton Lounge White T-Shirts - White / S",
#       "public_title": "White / S",
#       "options": [
#         "White",
#         "S"
#       ],
#       "price": 6200,
#       "weight": 0,
#       "compare_at_price": null,
#       "inventory_management": "shopify",
#       "barcode": null,
#       "requires_selling_plan": false,
#       "selling_plan_allocations": []
#     },
#     {
#       "id": 43518768447637,
#       "title": "White / M",
#       "option1": "White",
#       "option2": "M",
#       "option3": null,
#       "sku": "206454",
#       "requires_shipping": true,
#       "taxable": false,
#       "featured_image": {
#         "id": 38188263604373,
#         "product_id": 7934081925269,
#         "position": 1,
#         "created_at": "2023-09-04T22:23:46+03:00",
#         "updated_at": "2023-09-04T22:23:47+03:00",
#         "alt": null,
#         "width": 1080,
#         "height": 1080,
#         "src": "//fattalbeauty.com/cdn/shop/files/206454_57d4761a-4c80-4047-ae84-ce64173dce18.png?v=1693855427",
#         "variant_ids": [
#           43518768447637
#         ]
#       },
#       "available": true,
#       "name": "Calvin Klein 2 Pack Modern Cotton Lounge White T-Shirts - White / M",
#       "public_title": "White / M",
#       "options": [
#         "White",
#         "M"
#       ],
#       "price": 6200,
#       "weight": 0,
#       "compare_at_price": null,
#       "inventory_management": "shopify",
#       "barcode": null,
#       "featured_media": {
#         "alt": null,
#         "id": 30663099711637,
#         "position": 1,
#         "preview_image": {
#           "aspect_ratio": 1.0,
#           "height": 1080,
#           "width": 1080,
#           "src": "//fattalbeauty.com/cdn/shop/files/206454_57d4761a-4c80-4047-ae84-ce64173dce18.png?v=1693855427"
#         }
#       },
#       "requires_selling_plan": false,
#       "selling_plan_allocations": []
#     },
#     {
#       "id": 43518768480405,
#       "title": "White / L",
#       "option1": "White",
#       "option2": "L",
#       "option3": null,
#       "sku": "206455",
#       "requires_shipping": true,
#       "taxable": false,
#       "featured_image": null,
#       "available": false,
#       "name": "Calvin Klein 2 Pack Modern Cotton Lounge White T-Shirts - White / L",
#       "public_title": "White / L",
#       "options": [
#         "White",
#         "L"
#       ],
#       "price": 6200,
#       "weight": 0,
#       "compare_at_price": null,
#       "inventory_management": "shopify",
#       "barcode": null,
#       "requires_selling_plan": false,
#       "selling_plan_allocations": []
#     },
#     {
#       "id": 43518768513173,
#       "title": "White / XL",
#       "option1": "White",
#       "option2": "XL",
#       "option3": null,
#       "sku": "206456",
#       "requires_shipping": true,
#       "taxable": false,
#       "featured_image": null,
#       "available": false,
#       "name": "Calvin Klein 2 Pack Modern Cotton Lounge White T-Shirts - White / XL",
#       "public_title": "White / XL",
#       "options": [
#         "White",
#         "XL"
#       ],
#       "price": 6200,
#       "weight": 0,
#       "compare_at_price": null,
#       "inventory_management": "shopify",
#       "barcode": null,
#       "requires_selling_plan": false,
#       "selling_plan_allocations": []
#     }
#   ],
#   "options": [
#     {
#       "name": "Color",
#       "position": 1,
#       "values": [
#         "White"
#       ]
#     },
#     {
#       "name": "Size",
#       "position": 2,
#       "values": [
#         "S",
#         "M",
#         "L",
#         "XL"
#       ]
#     }
#   ],
#   "selected_or_first_available_variant": {
#     "id": 43518768414869,
#     "title": "White / S",
#     "option1": "White",
#     "option2": "S",
#     "option3": null,
#     "sku": "206445",
#     "requires_shipping": true,
#     "taxable": false,
#     "featured_image": null,
#     "available": true,
#     "name": "Calvin Klein 2 Pack Modern Cotton Lounge White T-Shirts - White / S",
#     "public_title": "White / S",
#     "options": [
#       "White",
#       "S"
#     ],
#     "price": 6200,
#     "weight": 0,
#     "compare_at_price": null,
#     "inventory_management": "shopify",
#     "barcode": null,
#     "requires_selling_plan": false,
#     "selling_plan_allocations": []
#   },
#   "selected_variant": null,
#   "media": [
#     {
#       "alt": null,
#       "id": 30663099711637,
#       "position": 1,
#       "preview_image": {
#         "aspect_ratio": 1.0,
#         "height": 1080,
#         "width": 1080,
#         "src": "//fattalbeauty.com/cdn/shop/files/206454_57d4761a-4c80-4047-ae84-ce64173dce18.png?v=1693855427"
#       },
#       "aspect_ratio": 1.0,
#       "height": 1080,
#       "media_type": "image",
#       "src": "//fattalbeauty.com/cdn/shop/files/206454_57d4761a-4c80-4047-ae84-ce64173dce18.png?v=1693855427",
#       "width": 1080
#     }
#   ],
#   "featured_image": "//fattalbeauty.com/cdn/shop/files/206454_57d4761a-4c80-4047-ae84-ce64173dce18.png?v=1693855427",
#   "aspect_ratio": 1.0,
#   "images": [
#     "//fattalbeauty.com/cdn/shop/files/206454_57d4761a-4c80-4047-ae84-ce64173dce18.png?v=1693855427"
#   ],
#   "price": 6200
# }

# %% [markdown]
# # FATTALONLINE.COM SCRAPER

# %%
import requests
import json
from bs4 import BeautifulSoup

def fetch_product_data_productview(url: str) -> dict | None:
    headers = {
        "User-Agent": "Mozilla/5.0",
        "Accept": "text/html",
    }

    res = requests.get(url, headers=headers, timeout=20)
    res.raise_for_status()

    soup = BeautifulSoup(res.text, "lxml")

    # -------------------------------------------------
    # 1. FIND productView-options DIV
    # -------------------------------------------------
    options_div = soup.select_one("div.productView-options")
    if not options_div:
        return None

    # -------------------------------------------------
    # 2. FIND NEAREST JSON SCRIPT
    # -------------------------------------------------
    script_tag = options_div.find_next("script", type="application/json")
    if not script_tag or not script_tag.string:
        return None

    raw_json = script_tag.string.strip()

    # -------------------------------------------------
    # 3. PARSE JSON
    # -------------------------------------------------
    try:
        product = json.loads(raw_json)
    except json.JSONDecodeError as e:
        raise ValueError(f"JSON parse failed: {e}")

    # -------------------------------------------------
    # 5. SANITY CHECK
    # -------------------------------------------------
    if not product[0].get("id") or not product[0].get("title"):
        return None

    return product

# %%
product = fetch_product_data_productview("https://fattalonline.com/products/max-factor-lasting-performance")
print(json.dumps(product, indent=2))
# Out:
# [
#   {
#     "id": 44771271377189,
#     "title": "100-fair",
#     "option1": "100-fair",
#     "option2": null,
#     "option3": null,
#     "sku": "65448",
#     "requires_shipping": true,
#     "taxable": false,
#     "featured_image": {
#       "id": 41116622291237,
#       "product_id": 8190333124901,
#       "position": 1,
#       "created_at": "2023-03-27T17:44:16+03:00",
#       "updated_at": "2023-03-27T17:44:16+03:00",
#       "alt": null,
#       "width": 1080,
#       "height": 1080,
#       "src": "//fattalonline.com/cdn/shop/products/65448.png?v=1679928256",
#       "variant_ids": [
#         44771271377189
#       ]
#     },
#     "available": true,
#     "name": "Max Factor Lasting Performance - 100-fair",
#     "public_title": "100-fair",
#     "options": [
#       "100-fair"
#     ],
#     "price": 977,
#     "weight": 0,
#     "compare_at_price": 1221,
#     "inventory_management": "shopify",
#     "barcode": null,
#     "featured_media": {
#       "alt": null,
#       "id": 33468332179749,
#       "position": 1,
#       "preview_image": {
#         "aspect_ratio": 1.0,
#         "height": 1080,
#         "width": 1080,
#         "src": "//fattalonline.com/cdn/shop/products/65448.png?v=1679928256"
#       }
#     },
#     "requires_selling_plan": false,
#     "selling_plan_allocations": []
#   },
#   {
#     "id": 44771271475493,
#     "title": "101-beige",
#     "option1": "101-beige",
#     "option2": null,
#     "option3": null,
#     "sku": "65449",
#     "requires_shipping": true,
#     "taxable": false,
#     "featured_image": {
#       "id": 41116622324005,
#       "product_id": 8190333124901,
#       "position": 2,
#       "created_at": "2023-03-27T17:44:16+03:00",
#       "updated_at": "2023-03-27T17:44:16+03:00",
#       "alt": null,
#       "width": 1080,
#       "height": 1080,
#       "src": "//fattalonline.com/cdn/shop/products/65449.png?v=1679928256",
#       "variant_ids": [
#         44771271475493
#       ]
#     },
#     "available": false,
#     "name": "Max Factor Lasting Performance - 101-beige",
#     "public_title": "101-beige",
#     "options": [
#       "101-beige"
#     ],
#     "price": 977,
#     "weight": 0,
#     "compare_at_price": 1221,
#     "inventory_management": "shopify",
#     "barcode": null,
#     "featured_media": {
#       "alt": null,
#       "id": 33468332212517,
#       "position": 2,
#       "preview_image": {
#         "aspect_ratio": 1.0,
#         "height": 1080,
#         "width": 1080,
#         "src": "//fattalonline.com/cdn/shop/products/65449.png?v=1679928256"
#       }
#     },
#     "requires_selling_plan": false,
#     "selling_plan_allocations": []
#   },
#   {
#     "id": 44771271606565,
#     "title": "natural-beige",
#     "option1": "natural-beige",
#     "option2": null,
#     "option3": null,
#     "sku": "65451",
#     "requires_shipping": true,
#     "taxable": false,
#     "featured_image": {
#       "id": 41116622356773,
#       "product_id": 8190333124901,
#       "position": 3,
#       "created_at": "2023-03-27T17:44:16+03:00",
#       "updated_at": "2023-03-27T17:44:16+03:00",
#       "alt": null,
#       "width": 1080,
#       "height": 1080,
#       "src": "//fattalonline.com/cdn/shop/products/65451.png?v=1679928256",
#       "variant_ids": [
#         44771271606565
#       ]
#     },
#     "available": false,
#     "name": "Max Factor Lasting Performance - natural-beige",
#     "public_title": "natural-beige",
#     "options": [
#       "natural-beige"
#     ],
#     "price": 977,
#     "weight": 0,
#     "compare_at_price": 1221,
#     "inventory_management": "shopify",
#     "barcode": null,
#     "featured_media": {
#       "alt": null,
#       "id": 33468332245285,
#       "position": 3,
#       "preview_image": {
#         "aspect_ratio": 1.0,
#         "height": 1080,
#         "width": 1080,
#         "src": "//fattalonline.com/cdn/shop/products/65451.png?v=1679928256"
#       }
#     },
#     "requires_selling_plan": false,
#     "selling_plan_allocations": []
#   },
#   {
#     "id": 44771271672101,
#     "title": "honey-beige",
#     "option1": "honey-beige",
#     "option2": null,
#     "option3": null,
#     "sku": "65452",
#     "requires_shipping": true,
#     "taxable": false,
#     "featured_image": {
#       "id": 41116622389541,
#       "product_id": 8190333124901,
#       "position": 4,
#       "created_at": "2023-03-27T17:44:16+03:00",
#       "updated_at": "2023-03-27T17:44:16+03:00",
#       "alt": null,
#       "width": 1080,
#       "height": 1080,
#       "src": "//fattalonline.com/cdn/shop/products/65452.png?v=1679928256",
#       "variant_ids": [
#         44771271672101
#       ]
#     },
#     "available": false,
#     "name": "Max Factor Lasting Performance - honey-beige",
#     "public_title": "honey-beige",
#     "options": [
#       "honey-beige"
#     ],
#     "price": 977,
#     "weight": 0,
#     "compare_at_price": 1221,
#     "inventory_management": "shopify",
#     "barcode": null,
#     "featured_media": {
#       "alt": null,
#       "id": 33468332278053,
#       "position": 4,
#       "preview_image": {
#         "aspect_ratio": 1.0,
#         "height": 1080,
#         "width": 1080,
#         "src": "//fattalonline.com/cdn/shop/products/65452.png?v=1679928256"
#       }
#     },
#     "requires_selling_plan": false,
#     "selling_plan_allocations": []
#   },
#   {
#     "id": 44771271770405,
#     "title": "102-pastel",
#     "option1": "102-pastel",
#     "option2": null,
#     "option3": null,
#     "sku": "65450",
#     "requires_shipping": true,
#     "taxable": false,
#     "featured_image": {
#       "id": 41116622422309,
#       "product_id": 8190333124901,
#       "position": 5,
#       "created_at": "2023-03-27T17:44:16+03:00",
#       "updated_at": "2023-03-27T17:44:16+03:00",
#       "alt": null,
#       "width": 1080,
#       "height": 1080,
#       "src": "//fattalonline.com/cdn/shop/products/65450.png?v=1679928256",
#       "variant_ids": [
#         44771271770405
#       ]
#     },
#     "available": false,
#     "name": "Max Factor Lasting Performance - 102-pastel",
#     "public_title": "102-pastel",
#     "options": [
#       "102-pastel"
#     ],
#     "price": 977,
#     "weight": 0,
#     "compare_at_price": 1221,
#     "inventory_management": "shopify",
#     "barcode": null,
#     "featured_media": {
#       "alt": null,
#       "id": 33468332310821,
#       "position": 5,
#       "preview_image": {
#         "aspect_ratio": 1.0,
#         "height": 1080,
#         "width": 1080,
#         "src": "//fattalonline.com/cdn/shop/products/65450.png?v=1679928256"
#       }
#     },
#     "requires_selling_plan": false,
#     "selling_plan_allocations": []
#   },
#   {
#     "id": 44771271835941,
#     "title": "s.beige",
#     "option1": "s.beige",
#     "option2": null,
#     "option3": null,
#     "sku": "66874",
#     "requires_shipping": true,
#     "taxable": false,
#     "featured_image": {
#       "id": 41116622455077,
#       "product_id": 8190333124901,
#       "position": 6,
#       "created_at": "2023-03-27T17:44:16+03:00",
#       "updated_at": "2023-03-27T17:44:16+03:00",
#       "alt": null,
#       "width": 1080,
#       "height": 1080,
#       "src": "//fattalonline.com/cdn/shop/products/66874.png?v=1679928256",
#       "variant_ids": [
#         44771271835941
#       ]
#     },
#     "available": true,
#     "name": "Max Factor Lasting Performance - s.beige",
#     "public_title": "s.beige",
#     "options": [
#       "s.beige"
#     ],
#     "price": 977,
#     "weight": 0,
#     "compare_at_price": 1221,
#     "inventory_management": "shopify",
#     "barcode": null,
#     "featured_media": {
#       "alt": null,
#       "id": 33468332343589,
#       "position": 6,
#       "preview_image": {
#         "aspect_ratio": 1.0,
#         "height": 1080,
#         "width": 1080,
#         "src": "//fattalonline.com/cdn/shop/products/66874.png?v=1679928256"
#       }
#     },
#     "requires_selling_plan": false,
#     "selling_plan_allocations": []
#   }
# ]

# %%
# #@title Parsing the products json into dataframe

# import json

file_path = '/content/drive/MyDrive/Upwork/mahmoud/fattalbeauty/final_results.json'
# file_path = '/content/fattalbeauty_products.json'

# Read the JSON file
with open(file_path, 'r', encoding='utf-8') as f:
    data2 = json.load(f)

# print(json.dumps(data[0], indent=2))
len(data2)
# Out:
# 2598

# %%
import pandas as pd

product_info = []
for product in data:
    product_info.append({
        'product_id': product.get('id'),
        'vendor': product.get('vendor'),
        'product_type': product.get('product_type')
    })

df_product_vendor = pd.DataFrame(product_info)
display(df_product_vendor.head())
# Out:
#       product_id         vendor
# 0  8881004937365  Polo Exchange
# 1  8983808409749        Versace
# 2  8983808376981        Versace
# 3  8983808344213        Versace
# 4  8983808311445        Versace

# %%
print(json.dumps(data[2], indent=2))
# Out:
# {
#   "id": 8983808376981,
#   "title": "Versace Eros Energy Gift Set",
#   "handle": "versace-eros-energy-gift-set",
#   "body_html": "<p>Coffret Versace Eros Energy Edp100+Ts10+Gwp</p>",
#   "published_at": "2025-12-04T09:48:10+02:00",
#   "created_at": "2025-12-03T09:54:00+02:00",
#   "updated_at": "2025-12-14T13:20:35+02:00",
#   "vendor": "Versace",
#   "product_type": "Fragrances",
#   "tags": [
#     "Eau de Parfum",
#     "Frag Sets",
#     "Fragrances",
#     "Fragrances for Him",
#     "Gift Sets",
#     "Gifts for Him"
#   ],
#   "variants": [
#     {
#       "id": 46692083499157,
#       "title": "Default Title",
#       "option1": "Default Title",
#       "option2": null,
#       "option3": null,
#       "sku": "293147",
#       "requires_shipping": true,
#       "taxable": false,
#       "featured_image": null,
#       "available": true,
#       "price": "114.75",
#       "grams": 0,
#       "compare_at_price": "135.00",
#       "position": 1,
#       "product_id": 8983808376981,
#       "created_at": "2025-12-03T09:54:00+02:00",
#       "updated_at": "2025-12-14T13:20:35+02:00"
#     }
#   ],
#   "images": [
#     {
#       "id": 45039515730069,
#       "created_at": "2025-12-03T09:54:01+02:00",
#       "position": 1,
#       "updated_at": "2025-12-03T09:54:03+02:00",
#       "product_id": 8983808376981,
#       "variant_ids": [],
#       "src": "https://cdn.shopify.com/s/files/1/0602/5668/2133/files/293147_13d6265c-3ce5-437b-90f4-c9577367f2d8.png?v=1764748443",
#       "width": 1000,
#       "height": 1000
#     }
#   ],
#   "options": [
#     {
#       "name": "Title",
#       "position": 1,
#       "values": [
#         "Default Title"
#       ]
#     }
#   ]
# }

# %%
combined_data = []
data2_lookup = {product.get('id'): product for product in data2}

for product_from_data1 in data:
    product_id = product_from_data1.get('id')
    if product_id in data2_lookup:
        # Get the product from data2 using the lookup
        product_from_data2 = data2_lookup[product_id]

        # Create a copy of the product from data1 to modify
        modified_product = product_from_data1.copy()

        # Replace the 'variants' from data1 with those from data2
        if 'variants' in product_from_data2:
            modified_product['variants'] = product_from_data2['variants']

        combined_data.append(modified_product)
    else:
        # If no match in data2, just append the original product from data1
        combined_data.append(product_from_data1)

# Display the first few combined products to verify
print("First 3 combined products with updated variants:")
for i in range(min(3, len(combined_data))):
    print(json.dumps(combined_data[i], indent=2))

print(f"\nTotal combined products: {len(combined_data)}")
# Out:
# First 3 combined products with updated variants:
# {
#   "id": 8881004937365,
#   "title": "Polo Exchange Accessories PXRI0210",
#   "handle": "polo-exchange-accessories-pxri0210",
#   "body_html": "<p>Polo Exchange Accessories PXRI0210</p>",
#   "published_at": "2025-12-13T09:14:28+02:00",
#   "created_at": "2025-08-26T12:09:22+03:00",
#   "updated_at": "2025-12-14T13:20:35+02:00",
#   "vendor": "Polo Exchange",
#   "product_type": "Watches & Accessories",
#   "tags": [
#     "Acc Discounts",
#     "Accessories for Her",
#     "Ring",
#     "Watches & Accessories"
#   ],
#   "variants": [
#     {
#       "id": 46341834375317,
#       "title": "Default Title",
#       "option1": "Default Title",
#       "option2": null,
#       "option3": null,
#       "sku": "276434",
#       "requires_shipping": true,
#       "taxable": false,
#       "featured_image": null,
#       "available": false,
#       "name": "Polo Exchange Accessories PXRI0210",
#       "public_title": null,
#       "options": [
#         "Default Title"
#       ],
#       "price": 2500,
#       "weight": 0,
#       "compare_at_price": null,
#       "inventory_management": "shopify",
#       "barcode": null,
#       "requires_selling_plan": false,
#       "selling_plan_allocations": []
#     }
#   ],
#   "images": [
#     {
#       "id": 44249371246741,
#       "created_at": "2025-08-26T12:09:23+03:00",
#       "position": 1,
#       "updated_at": "2025-08-26T12:09:25+03:00",
#       "product_id": 8881004937365,
#       "variant_ids": [],
#       "src": "https://cdn.shopify.com/s/files/1/0602/5668/2133/files/276434_8c912249-ba68-46d8-a680-f80e4e310e7f.png?v=1756199365",
#       "width": 1000,
#       "height": 1000
#     }
#   ],
#   "options": [
#     {
#       "name": "Title",
#       "position": 1,
#       "values": [
#         "Default Title"
#       ]
#     }
#   ]
# }
# {
#   "id": 8983808409749,
#   "title": "Versace Bright Crystal Gift Set",
#   "handle": "versace-bright-crystal-gift-set",
#   "body_html": "<p>Coffret Versace Bright Crystal F. Edt90+Bsg100+Lbl100+Gwp</p>",
#   "published_at": "2025-12-04T09:48:10+02:00",
#   "created_at": "2025-12-03T09:54:00+02:00",
#   "updated_at": "2025-12-14T13:20:35+02:00",
#   "vendor": "Versace",
#   "product_type": "Fragrances",
#   "tags": [
#     "Eau de Parfum",
#     "Frag Sets",
#     "Fragrances",
#     "Fragrances for Her",
#     "Gift Sets",
#     "Gifts for Her"
#   ],
#   "variants": [
#     {
#       "id": 46692083531925,
#       "title": "Default Title",
#       "option1": "Default Title",
#       "option2": null,
#       "option3": null,
#       "sku": "293142",
#       "requires_shipping": true,
#       "taxable": false,
#       "featured_image": null,
#       "available": true,
#       "name": "Versace Bright Crystal Gift Set",
#       "public_title": null,
#       "options": [
#         "Default Title"
#       ],
#       "price": 11220,
#       "weight": 0,
#       "compare_at_price": 13200,
#       "inventory_management": "shopify",
#       "barcode": null,
#       "requires_selling_plan": false,
#       "selling_plan_allocations": []
#     }
#   ],
#   "images": [
#     {
#       "id": 45039515795605,
#       "created_at": "2025-12-03T09:54:02+02:00",
#       "position": 1,
#       "updated_at": "2025-12-03T09:54:03+02:00",
#       "product_id": 8983808409749,
#       "variant_ids": [],
#       "src": "https://cdn.shopify.com/s/files/1/0602/5668/2133/files/293142_cb4a04c4-65c6-4b68-a2c1-f3b710a5ebbc.png?v=1764748443",
#       "width": 1000,
#       "height": 1000
#     }
#   ],
#   "options": [
#     {
#       "name": "Title",
#       "position": 1,
#       "values": [
#         "Default Title"
#       ]
#     }
#   ]
# }
# {
#   "id": 8983808376981,
#   "title": "Versace Eros Energy Gift Set",
#   "handle": "versace-eros-energy-gift-set",
#   "body_html": "<p>Coffret Versace Eros Energy Edp100+Ts10+Gwp</p>",
#   "published_at": "2025-12-04T09:48:10+02:00",
#   "created_at": "2025-12-03T09:54:00+02:00",
#   "updated_at": "2025-12-14T13:20:35+02:00",
#   "vendor": "Versace",
#   "product_type": "Fragrances",
#   "tags": [
#     "Eau de Parfum",
#     "Frag Sets",
#     "Fragrances",
#     "Fragrances for Him",
#     "Gift Sets",
#     "Gifts for Him"
#   ],
#   "variants": [
#     {
#       "id": 46692083499157,
#       "title": "Default Title",
#       "option1": "Default Title",
#       "option2": null,
#       "option3": null,
#       "sku": "293147",
#       "requires_shipping": true,
#       "taxable": false,
#       "featured_image": null,
#       "available": true,
#       "name": "Versace Eros Energy Gift Set",
#       "public_title": null,
#       "options": [
#         "Default Title"
#       ],
#       "price": 11475,
#       "weight": 0,
#       "compare_at_price": 13500,
#       "inventory_management": "shopify",
#       "barcode": null,
#       "requires_selling_plan": false,
#       "selling_plan_allocations": []
#     }
#   ],
#   "images": [
#     {
#       "id": 45039515730069,
#       "created_at": "2025-12-03T09:54:01+02:00",
#       "position": 1,
#       "updated_at": "2025-12-03T09:54:03+02:00",
#       "product_id": 8983808376981,
#       "variant_ids": [],
#       "src": "https://cdn.shopify.com/s/files/1/0602/5668/2133/files/293147_13d6265c-3ce5-437b-90f4-c9577367f2d8.png?v=1764748443",
#       "width": 1000,
#       "height": 1000
#     }
#   ],
#   "options": [
#     {
#       "name": "Title",
#       "position": 1,
#       "values": [
#         "Default Title"
#       ]
#     }
#   ]
# }
#
# Total combined products: 2603

# %%
import pandas as pd

BASE_URL = "https://fattalbeauty.com/products/"

def flatten_products(products: list[dict]) -> pd.DataFrame:
    rows = []

    for product in products:
        product_id = product.get("id")
        product_title = product.get("title", "")
        vendor = product.get("vendor", "")
        product_type = product.get("product_type", "") # Corrected from 'type' to 'product_type'
        handle = BASE_URL + product.get("handle", "")
        description = product.get("body_html", "")

        # SAFELY resolve default image (product level image)
        images = product.get("images") or []
        default_image = images[0].get('src') if images and len(images) > 0 else None # Corrected to get 'src'

        # Prepare default values
        option_colors = []
        option_sizes = []

        # Options can be dict OR list
        options = product.get("options", {})

        if isinstance(options, dict):
            option_colors = options.get("color", [])
            option_sizes = options.get("size", [])
        elif isinstance(options, list):
            for opt in options:
                if isinstance(opt, dict): # Added check: Ensure 'opt' is a dictionary
                    name = (opt.get("name") or "").lower()
                    if name == "color":
                        option_colors = opt.get("values", [])
                    if name == "size":
                        option_sizes = opt.get("values", [])

        for variant in product.get("variants", []):
            variant_title = variant.get("title") or product_title

            # Replace default title
            if variant_title.lower() == "default title":
                variant_title = product_title

            # Fallback to product image (corrected logic)
            variant_featured_image_data = variant.get("featured_image")
            if variant_featured_image_data and variant_featured_image_data.get('src'):
                image = variant_featured_image_data.get('src')
            else:
                image = default_image

            color = variant_title if variant_title in option_colors else None
            size = variant_title if variant_title in option_sizes else None

            # Safely get and convert price
            raw_price = variant.get("price")
            try:
                price = float(raw_price) / 100 if raw_price is not None else 0.0
            except ValueError:
                price = 0.0 # Default to 0.0 if conversion fails

            rows.append({
                "product_id": product_id,
                "product_title": product_title,
                "vendor": vendor,
                "product_type": product_type,
                "handle": handle,
                "description": description,
                "variant_id": variant.get("id"), # Changed to use 'id' as 'variant_id'
                "variant_title": variant_title,
                "sku": variant.get("sku"),
                "price": price,
                "color": color,
                "size": size,
                "available": variant.get("available"),
                "barcode": variant.get("barcode"),
                "image": image
            })

    return pd.DataFrame(rows)


df = flatten_products(combined_data)

# Display as table in Colab (Excel-ready)
df.head(50)
# Out:
#        product_id                                      product_title  \
# 0   8881004937365                 Polo Exchange Accessories PXRI0210
# 1   8983808409749                    Versace Bright Crystal Gift Set
# 2   8983808376981                       Versace Eros Energy Gift Set
# 3   8983808344213                        Versace Pour Homme Gift Set
# 4   8983808311445                        Versace Eros Flame Gift Set
# 5   8983808245909                      Versace Dylan Purple Gift Set
# 6   8983808213141                        Versace Eros Femme Gift Set
# 7   8983808180373                        Versace Dylan Blue Gift Set
# 8   8983808147605                        Versace Eros Najim Gift Set
# 9   8983808082069                    Tommy Hilfiger For Men Gift Set
# 10  8983808049301              Tommy Hilfiger Forever Women Gift Set
# 11  8983808016533                Tommy Hilfiger Forever Men Gift Set
# 41                                                 S3   188797   59.00    S3
# 42                                                 S4   188799   59.00    S4
# 43                                                 S6   194781   59.00    S6
# 44                                                 S7   194782   59.00    S7
# 45    Bassam Fattouh The Essential Palette Eye Shadow   289795   71.00  None
# 46                Bassam Fattouh Christmas Beauty Box   293249  180.00  None
# 47  Fossil Harlow Three-Hand Two-Tone Stainless St...   283242  157.50  None
# 48  Fossil Raquel Watch Ring Two-Hand Rose Gold-To...   293104  107.80  None
# 49  Fossil Raquel Watch Ring Two-Hand Gold-Tone St...   293103  107.80  None
#
#     size  available barcode                                              image
# 0   None      False    None  https://cdn.shopify.com/s/files/1/0602/5668/21...
# 1   None       True    None  https://cdn.shopify.com/s/files/1/0602/5668/21...
# 2   None       True    None  https://cdn.shopify.com/s/files/1/0602/5668/21...
# 3   None       True    None  https://cdn.shopify.com/s/files/1/0602/5668/21...
# 4   None       True    None  https://cdn.shopify.com/s/files/1/0602/5668/21...
# 5   None       True    None  https://cdn.shopify.com/s/files/1/0602/5668/21...
# 6   None       True    None  https://cdn.shopify.com/s/files/1/0602/5668/21...
# 7   None       True    None  https://cdn.shopify.com/s/files/1/0602/5668/21...
# 8   None       True    None  https://cdn.shopify.com/s/files/1/0602/5668/21...
# 9   None       True    None  https://cdn.shopify.com/s/files/1/0602/5668/21...
# 10  None       True    None  https://cdn.shopify.com/s/files/1/0602/5668/21...
# 11  None       True    None  https://cdn.shopify.com/s/files/1/0602/5668/21...
# 12  None       True    None  https://cdn.shopify.com/s/files/1/0602/5668/21...
# 13  None       True    None  https://cdn.shopify.com/s/files/1/0602/5668/21...
# 14  None       True    None  https://cdn.shopify.com/s/files/1/0602/5668/21...
# 15  None       True    None  https://cdn.shopify.com/s/files/1/0602/5668/21...
# 16  None       True    None  https://cdn.shopify.com/s/files/1/0602/5668/21...
# 17  None       True    None  https://cdn.shopify.com/s/files/1/0602/5668/21...
# 18  None       True    None  https://cdn.shopify.com/s/files/1/0602/5668/21...
# 19  None       True    None  https://cdn.shopify.com/s/files/1/0602/5668/21...
# 20  None       True    None  https://cdn.shopify.com/s/files/1/0602/5668/21...
# 21  None       True    None  https://cdn.shopify.com/s/files/1/0602/5668/21...
# 22  None       True    None  https://cdn.shopify.com/s/files/1/0602/5668/21...
# 23  None       True    None  https://cdn.shopify.com/s/files/1/0602/5668/21...
# 24  None       True    None  https://cdn.shopify.com/s/files/1/0602/5668/21...
# 25  None       True    None  https://cdn.shopify.com/s/files/1/0602/5668/21...
# 26  None       True    None  https://cdn.shopify.com/s/files/1/0602/5668/21...
# 27  None       True    None  https://cdn.shopify.com/s/files/1/0602/5668/21...
# 28  None       True    None  https://cdn.shopify.com/s/files/1/0602/5668/21...
# 29  None       True    None  https://cdn.shopify.com/s/files/1/0602/5668/21...
# 30  None      False    None  https://cdn.shopify.com/s/files/1/0602/5668/21...
# 31  None      False    None  https://cdn.shopify.com/s/files/1/0602/5668/21...
# 32  None      False    None  https://cdn.shopify.com/s/files/1/0602/5668/21...
# 33  None      False    None  https://cdn.shopify.com/s/files/1/0602/5668/21...
# 34  None      False    None  https://cdn.shopify.com/s/files/1/0602/5668/21...
# 35  None      False    None  https://cdn.shopify.com/s/files/1/0602/5668/21...
# 36  None      False    None  https://cdn.shopify.com/s/files/1/0602/5668/21...
# 37  None       True    None  https://cdn.shopify.com/s/files/1/0602/5668/21...
# 38  None      False    None  https://cdn.shopify.com/s/files/1/0602/5668/21...
# 39  None      False    None  https://cdn.shopify.com/s/files/1/0602/5668/21...
# 40  None       True    None  //fattalbeauty.com/cdn/shop/files/188798_16c46...
# 41  None       True    None  //fattalbeauty.com/cdn/shop/files/188797_3d688...
# 42  None       True    None  //fattalbeauty.com/cdn/shop/files/188799_5b4cb...
# 43  None       True    None  //fattalbeauty.com/cdn/shop/files/194781_6b9bf...
# 44  None      False    None  //fattalbeauty.com/cdn/shop/files/194782_e7468...
# 45  None       True    None  https://cdn.shopify.com/s/files/1/0602/5668/21...
# 46  None       True          https://cdn.shopify.com/s/files/1/0602/5668/21...
# 47  None      False    None  https://cdn.shopify.com/s/files/1/0602/5668/21...
# 48  None       True    None  https://cdn.shopify.com/s/files/1/0602/5668/21...
# 49  None       True    None  https://cdn.shopify.com/s/files/1/0602/5668/21...

# %%
df.to_csv("fattalbeauty_products.csv", index=False)

# %%
product_id_to_find = 7934078353557
found_product = None

for product in combined_data:
    if product.get('id') == product_id_to_find:
        found_product = product
        break

if found_product:
    print(json.dumps(found_product, indent=2))
else:
    print(f"Product with ID {product_id_to_find} not found in combined_data.")
# Out:
# {
#   "id": 7934078353557,
#   "title": "Bassam Fattouh Two Way Cake Powder Foundation",
#   "handle": "bassam-fattouh-two-way-cake-powder-foundation",
#   "body_html": "<p>This revolutionary long lasting, creamy yet super light foundation seamlessly conceals fine lines and imperfections ensuring a naturally luminous and silky complexion complete with an impeccable matte finish.</p>",
#   "published_at": "2025-12-03T14:29:35+02:00",
#   "created_at": "2023-07-05T00:32:09+03:00",
#   "updated_at": "2025-12-14T13:20:35+02:00",
#   "vendor": "Bassam Fattouh",
#   "product_type": "Make up",
#   "tags": [
#     "Face",
#     "Foundation",
#     "Make up"
#   ],
#   "variants": [
#     {
#       "id": 43518758224021,
#       "title": "S2",
#       "option1": "S2",
#       "option2": null,
#       "option3": null,
#       "sku": "188798",
#       "requires_shipping": true,
#       "taxable": false,
#       "featured_image": {
#         "id": 37967424585877,
#         "product_id": 7934078353557,
#         "position": 1,
#         "created_at": "2023-08-09T20:53:17+03:00",
#         "updated_at": "2023-08-09T20:53:19+03:00",
#         "alt": null,
#         "width": 1080,
#         "height": 1080,
#         "src": "//fattalbeauty.com/cdn/shop/files/188798_16c4657d-bbbb-44c1-90b4-b1a8e13279b8.png?v=1691603599",
#         "variant_ids": [
#           43518758224021
#         ]
#       },
#       "available": true,
#       "name": "Bassam Fattouh Two Way Cake Powder Foundation - S2",
#       "public_title": "S2",
#       "options": [
#         "S2"
#       ],
#       "price": 5900,
#       "weight": 0,
#       "compare_at_price": null,
#       "inventory_management": "shopify",
#       "barcode": null,
#       "featured_media": {
#         "alt": null,
#         "id": 30440610758805,
#         "position": 1,
#         "preview_image": {
#           "aspect_ratio": 1.0,
#           "height": 1080,
#           "width": 1080,
#           "src": "//fattalbeauty.com/cdn/shop/files/188798_16c4657d-bbbb-44c1-90b4-b1a8e13279b8.png?v=1691603599"
#         }
#       },
#       "requires_selling_plan": false,
#       "selling_plan_allocations": []
#     },
#     {
#       "id": 43518758256789,
#       "title": "S3",
#       "option1": "S3",
#       "option2": null,
#       "option3": null,
#       "sku": "188797",
#       "requires_shipping": true,
#       "taxable": false,
#       "featured_image": {
#         "id": 37967424684181,
#         "product_id": 7934078353557,
#         "position": 2,
#         "created_at": "2023-08-09T20:53:17+03:00",
#         "updated_at": "2023-08-09T20:53:19+03:00",
#         "alt": null,
#         "width": 1080,
#         "height": 1080,
#         "src": "//fattalbeauty.com/cdn/shop/files/188797_3d688ac7-4120-43ba-962b-4cd4ba846333.png?v=1691603599",
#         "variant_ids": [
#           43518758256789
#         ]
#       },
#       "available": true,
#       "name": "Bassam Fattouh Two Way Cake Powder Foundation - S3",
#       "public_title": "S3",
#       "options": [
#         "S3"
#       ],
#       "price": 5900,
#       "weight": 0,
#       "compare_at_price": null,
#       "inventory_management": "shopify",
#       "barcode": null,
#       "featured_media": {
#         "alt": null,
#         "id": 30440610791573,
#         "position": 2,
#         "preview_image": {
#           "aspect_ratio": 1.0,
#           "height": 1080,
#           "width": 1080,
#           "src": "//fattalbeauty.com/cdn/shop/files/188797_3d688ac7-4120-43ba-962b-4cd4ba846333.png?v=1691603599"
#         }
#       },
#       "requires_selling_plan": false,
#       "selling_plan_allocations": []
#     },
#     {
#       "id": 43518758289557,
#       "title": "S4",
#       "option1": "S4",
#       "option2": null,
#       "option3": null,
#       "sku": "188799",
#       "requires_shipping": true,
#       "taxable": false,
#       "featured_image": {
#         "id": 37967424553109,
#         "product_id": 7934078353557,
#         "position": 3,
#         "created_at": "2023-08-09T20:53:17+03:00",
#         "updated_at": "2023-08-09T20:53:19+03:00",
#         "alt": null,
#         "width": 1080,
#         "height": 1080,
#         "src": "//fattalbeauty.com/cdn/shop/files/188799_5b4cb5ed-1834-4632-9fc0-c4a3e834c772.png?v=1691603599",
#         "variant_ids": [
#           43518758289557
#         ]
#       },
#       "available": true,
#       "name": "Bassam Fattouh Two Way Cake Powder Foundation - S4",
#       "public_title": "S4",
#       "options": [
#         "S4"
#       ],
#       "price": 5900,
#       "weight": 0,
#       "compare_at_price": null,
#       "inventory_management": "shopify",
#       "barcode": null,
#       "featured_media": {
#         "alt": null,
#         "id": 30440610824341,
#         "position": 3,
#         "preview_image": {
#           "aspect_ratio": 1.0,
#           "height": 1080,
#           "width": 1080,
#           "src": "//fattalbeauty.com/cdn/shop/files/188799_5b4cb5ed-1834-4632-9fc0-c4a3e834c772.png?v=1691603599"
#         }
#       },
#       "requires_selling_plan": false,
#       "selling_plan_allocations": []
#     },
#     {
#       "id": 43518758322325,
#       "title": "S6",
#       "option1": "S6",
#       "option2": null,
#       "option3": null,
#       "sku": "194781",
#       "requires_shipping": true,
#       "taxable": false,
#       "featured_image": {
#         "id": 37967424651413,
#         "product_id": 7934078353557,
#         "position": 4,
#         "created_at": "2023-08-09T20:53:17+03:00",
#         "updated_at": "2023-08-09T20:53:19+03:00",
#         "alt": null,
#         "width": 1080,
#         "height": 1080,
#         "src": "//fattalbeauty.com/cdn/shop/files/194781_6b9bf06c-6815-4fb8-8d34-586acd5c356c.png?v=1691603599",
#         "variant_ids": [
#           43518758322325
#         ]
#       },
#       "available": true,
#       "name": "Bassam Fattouh Two Way Cake Powder Foundation - S6",
#       "public_title": "S6",
#       "options": [
#         "S6"
#       ],
#       "price": 5900,
#       "weight": 0,
#       "compare_at_price": null,
#       "inventory_management": "shopify",
#       "barcode": null,
#       "featured_media": {
#         "alt": null,
#         "id": 30440610857109,
#         "position": 4,
#         "preview_image": {
#           "aspect_ratio": 1.0,
#           "height": 1080,
#           "width": 1080,
#           "src": "//fattalbeauty.com/cdn/shop/files/194781_6b9bf06c-6815-4fb8-8d34-586acd5c356c.png?v=1691603599"
#         }
#       },
#       "requires_selling_plan": false,
#       "selling_plan_allocations": []
#     },
#     {
#       "id": 43518758355093,
#       "title": "S7",
#       "option1": "S7",
#       "option2": null,
#       "option3": null,
#       "sku": "194782",
#       "requires_shipping": true,
#       "taxable": false,
#       "featured_image": {
#         "id": 37967424520341,
#         "product_id": 7934078353557,
#         "position": 5,
#         "created_at": "2023-08-09T20:53:17+03:00",
#         "updated_at": "2023-08-09T20:53:18+03:00",
#         "alt": null,
#         "width": 1080,
#         "height": 1080,
#         "src": "//fattalbeauty.com/cdn/shop/files/194782_e7468937-b5f7-420b-9c2b-15e94d74fa4e.png?v=1691603598",
#         "variant_ids": [
#           43518758355093
#         ]
#       },
#       "available": false,
#       "name": "Bassam Fattouh Two Way Cake Powder Foundation - S7",
#       "public_title": "S7",
#       "options": [
#         "S7"
#       ],
#       "price": 5900,
#       "weight": 0,
#       "compare_at_price": null,
#       "inventory_management": "shopify",
#       "barcode": null,
#       "featured_media": {
#         "alt": null,
#         "id": 30440610889877,
#         "position": 5,
#         "preview_image": {
#           "aspect_ratio": 1.0,
#           "height": 1080,
#           "width": 1080,
#           "src": "//fattalbeauty.com/cdn/shop/files/194782_e7468937-b5f7-420b-9c2b-15e94d74fa4e.png?v=1691603598"
#         }
#       },
#       "requires_selling_plan": false,
#       "selling_plan_allocations": []
#     }
#   ],
#   "images": [
#     {
#       "id": 37967424585877,
#       "created_at": "2023-08-09T20:53:17+03:00",
#       "position": 1,
#       "updated_at": "2023-08-09T20:53:19+03:00",
#       "product_id": 7934078353557,
#       "variant_ids": [
#         43518758224021
#       ],
#       "src": "https://cdn.shopify.com/s/files/1/0602/5668/2133/files/188798_16c4657d-bbbb-44c1-90b4-b1a8e13279b8.png?v=1691603599",
#       "width": 1080,
#       "height": 1080
#     },
#     {
#       "id": 37967424684181,
#       "created_at": "2023-08-09T20:53:17+03:00",
#       "position": 2,
#       "updated_at": "2023-08-09T20:53:19+03:00",
#       "product_id": 7934078353557,
#       "variant_ids": [
#         43518758256789
#       ],
#       "src": "https://cdn.shopify.com/s/files/1/0602/5668/2133/files/188797_3d688ac7-4120-43ba-962b-4cd4ba846333.png?v=1691603599",
#       "width": 1080,
#       "height": 1080
#     },
#     {
#       "id": 37967424553109,
#       "created_at": "2023-08-09T20:53:17+03:00",
#       "position": 3,
#       "updated_at": "2023-08-09T20:53:19+03:00",
#       "product_id": 7934078353557,
#       "variant_ids": [
#         43518758289557
#       ],
#       "src": "https://cdn.shopify.com/s/files/1/0602/5668/2133/files/188799_5b4cb5ed-1834-4632-9fc0-c4a3e834c772.png?v=1691603599",
#       "width": 1080,
#       "height": 1080
#     },
#     {
#       "id": 37967424651413,
#       "created_at": "2023-08-09T20:53:17+03:00",
#       "position": 4,
#       "updated_at": "2023-08-09T20:53:19+03:00",
#       "product_id": 7934078353557,
#       "variant_ids": [
#         43518758322325
#       ],
#       "src": "https://cdn.shopify.com/s/files/1/0602/5668/2133/files/194781_6b9bf06c-6815-4fb8-8d34-586acd5c356c.png?v=1691603599",
#       "width": 1080,
#       "height": 1080
#     },
#     {
#       "id": 37967424520341,
#       "created_at": "2023-08-09T20:53:17+03:00",
#       "position": 5,
#       "updated_at": "2023-08-09T20:53:18+03:00",
#       "product_id": 7934078353557,
#       "variant_ids": [
#         43518758355093
#       ],
#       "src": "https://cdn.shopify.com/s/files/1/0602/5668/2133/files/194782_e7468937-b5f7-420b-9c2b-15e94d74fa4e.png?v=1691603598",
#       "width": 1080,
#       "height": 1080
#     }
#   ],
#   "options": [
#     {
#       "name": "Color",
#       "position": 1,
#       "values": [
#         "S2",
#         "S3",
#         "S4",
#         "S6",
#         "S7"
#       ]
#     }
#   ]
# }

# %%
import requests
import json
import time

all_products = []
page_number = 1
page_limit = 250 # Shopify API default limit

while True:
    print(f"Fetching page {page_number}...")
    url = f"https://beirutfreezone.com//products.json?page={page_number}&limit={page_limit}"

    try:
        res = requests.get(url)
        res.raise_for_status() # Raise HTTPError for bad responses (4xx or 5xx)
        data = res.json()
        products = data.get('products', [])

        all_products.extend(products)

        if len(products) < page_limit:
            print(f"Found {len(products)} products on page {page_number}. Assuming this is the last page.")
            break

        print(f"Found {len(products)} products on page {page_number}.")
        page_number += 1
        time.sleep(0.5) # Be kind to the server

    except requests.exceptions.RequestException as e:
        print(f"Error fetching data from {url}: {e}")
        break
    except json.JSONDecodeError:
        print(f"Error decoding JSON from {url}. Response content: {res.text[:200]}...")
        break

print(f"\nTotal products scraped: {len(all_products)}")

# Optionally, save to a JSON file
file_path = 'beirutfreezone_products.json'
with open(file_path, 'w', encoding='utf-8') as f:
    json.dump(all_products, f, indent=4)
print(f"All products saved to {file_path}")
# Out:
# Fetching page 1...
# Found 250 products on page 1.
# Fetching page 2...
# Found 250 products on page 2.
# Fetching page 3...
# Found 250 products on page 3.
# Fetching page 4...
# Found 250 products on page 4.
# Fetching page 5...
# Found 250 products on page 5.
# Fetching page 6...
# Found 250 products on page 6.
# Fetching page 7...
# Found 250 products on page 7.
# Fetching page 8...
# Found 34 products on page 8. Assuming this is the last page.
#
# Total products scraped: 1784
# All products saved to beirutfreezone_products.json

# %% [markdown]
# ### Read `beirutfreezone_products.json` and display first 5 rows.

# %%
import json
import pandas as pd

file_path = '/content/beirutfreezone_products.json'

with open(file_path, 'r', encoding='utf-8') as f:
    data_beirutfreezone = json.load(f)

data_beirutfreezone[0]
# df_beirutfreezone = pd.DataFrame(data_beirutfreezone)
# display(df_beirutfreezone.head())
# Out:
# {'id': 8007851507800,
#  'title': 'Lacoste Original Eau De Toilette Pour Homme - 2 Sizes',
#  'handle': 'lacoste-original-eau-de-toilette-pour-homme-50ml',
#  'body_html': '<p>Experience the iconic scent of <strong>Lacoste Original Eau De Toilette</strong>. This 50ml bottle is perfect for the modern man, crafted with a blend of fresh and masculine notes. The perfect way to make a statement and exude confidence. Grab yours now and elevate your fragrance game.</p>',
#  'published_at': '2025-12-16T11:18:30+03:00',
#  'created_at': '2024-06-28T23:18:48+03:00',
#  'updated_at': '2025-12-19T18:36:49+03:00',
#  'vendor': 'lacoste',
#  'product_type': 'perfume',
#  'tags': ['All Products', 'for him', 'lacoste', 'men fragrance', 'perfume'],
#  'variants': [{'id': 43526761087064,
#    'title': '50ml',
#    'option1': '50ml',
#    'option2': None,
#    'option3': None,
#    'sku': None,
#    'requires_shipping': True,
#    'taxable': True,
#    'featured_image': None,
#    'available': False,
#    'price': '65.00',
#    'grams': 0,
#    'compare_at_price': '75.00',
#    'position': 1,
#    'product_id': 8007851507800,
#    'created_at': '2025-12-16T11:05:23+03:00',
#    'updated_at': '2025-12-19T18:36:49+03:00'},
#   {'id': 43526761119832,
#    'title': '100ml',
#    'option1': '100ml',
#    'option2': None,
#    'option3': None,
#    'sku': None,
#    'requires_shipping': True,
#    'taxable': True,
#    'featured_image': None,
#    'available': False,
#    'price': '95.00',
#    'grams': 0,
#    'compare_at_price': '110.00',
#    'position': 2,
#    'product_id': 8007851507800,
#    'created_at': '2025-12-16T11:05:23+03:00',
#    'updated_at': '2025-12-19T18:36:49+03:00'}],
#  'images': [{'id': 33179452571736,
#    'created_at': '2024-06-28T23:24:03+03:00',
#    'position': 1,
#    'updated_at': '2024-06-28T23:24:05+03:00',
#    'product_id': 8007851507800,
#    'variant_ids': [],
#    'src': 'https://cdn.shopify.com/s/files/1/0589/8613/5640/files/lacoste-original-EDT-50.png?v=1719606245',
#    'width': 1024,
#    'height': 1024}],
#  'options': [{'name': 'Size', 'position': 1, 'values': ['50ml', '100ml']}]}

# %%
import pandas as pd

BASE_URL = "https://beirutfreezone.com/products/"

def flatten_products(products: list[dict]) -> pd.DataFrame:
    rows = []

    for product in products:
        product_id = product.get("id")
        product_title = product.get("title", "")
        vendor = product.get("vendor", "")
        product_type = product.get("product_type", "") # Corrected from 'type' to 'product_type'
        handle = BASE_URL + product.get("handle", "")
        description = product.get("body_html", "")

        # SAFELY resolve default image (product level image)
        images = product.get("images") or []
        default_image = images[0].get('src') if images and len(images) > 0 else None # Corrected to get 'src'

        # Prepare default values
        option_colors = []
        option_sizes = []

        # Options can be dict OR list
        options = product.get("options", {})

        if isinstance(options, dict):
            option_colors = options.get("color", [])
            option_sizes = options.get("size", [])
        elif isinstance(options, list):
            for opt in options:
                if isinstance(opt, dict): # Added check: Ensure 'opt' is a dictionary
                    name = (opt.get("name") or "").lower()
                    if name == "color":
                        option_colors = opt.get("values", [])
                    if name == "size":
                        option_sizes = opt.get("values", [])

        for variant in product.get("variants", []):
            variant_title = variant.get("title") or product_title

            # Replace default title
            if variant_title.lower() == "default title":
                variant_title = product_title

            # Fallback to product image (corrected logic)
            variant_featured_image_data = variant.get("featured_image")
            if variant_featured_image_data and variant_featured_image_data.get('src'):
                image = variant_featured_image_data.get('src')
            else:
                image = default_image

            color = variant_title if variant_title in option_colors else None
            size = variant_title if variant_title in option_sizes else None

            # Safely get and convert price
            raw_price = variant.get("price")
            try:
                price = float(raw_price)
            except ValueError:
                price = 0.0 # Default to 0.0 if conversion fails

            rows.append({
                "product_id": product_id,
                "product_title": product_title,
                "vendor": vendor,
                "product_type": product_type,
                "handle": handle,
                "description": description,
                "variant_id": variant.get("id"), # Changed to use 'id' as 'variant_id'
                "variant_title": variant_title,
                "sku": variant.get("sku"),
                "price": price,
                "color": color,
                "size": size,
                "available": variant.get("available"),
                "barcode": variant.get("barcode"),
                "image": image
            })

    return pd.DataFrame(rows)


df = flatten_products(data_beirutfreezone)

# Display as table in Colab (Excel-ready)
df.head(50)
# Out:
#        product_id                                      product_title  \
# 0   8007851507800  Lacoste Original Eau De Toilette Pour Homme - ...
# 1   8007851507800  Lacoste Original Eau De Toilette Pour Homme - ...
# 2   8550740492376     Burberry Hero Eau De Parfum Pour Homme - 100ml
# 3   7813159223384       Bulgari Omnia Crystalline Women's Travel Set
# 4   8550740459608                        Jimmy Choo Women's Gift Set
# 5   7813027692632                  Givenchy Gentleman Men's Gift Set
# 6   8547034529880  Jean Paul Gaultier Divine Elixir Eau De Parfum...
# 7   8532532789336  Prada Luna Rossa Sport Eau De Toilette Pour Ho...
# 8   8547033677912                       Azzaro Wanted Men's Gift Set
# 9   8547033710680                      Trussardi Uomo Men's Gift Set
# 10  8547034103896          Bulgari Man Wood Essence Men's Travel Set
# 11  8547034300504  Carolina Herrera CH 212 VIP Rose Elixir Eau De...
# 12  8547034267736                  Carolina Herrera Women's Gift Set
# 13  8547034234968   Carolina Herrera Very Good Girl Women's Gift Set
# 14  8547034169432  Carolina Herrera Good Girl Blush Women's Gift Set
# 33          Calvin Klein My Euphoria Women's Gift Set  None  135.00  None
# 34  Armaf Club De Nuit Bling Perfume Pour Homme & ...  None   45.00  None
# 35                Gillette Fusion 5 Shave Gel - 200ml  None    5.50  None
# 36                     Lancome Idole Gift Set For Her        185.00  None
# 37          Yves Saint Laurent Libre Women's Gift Set  None  185.00  None
# 38    Prada La Femme Eau De Parfum Pour Femme - 100ml  None  155.00  None
# 39  Givenchy Hot Couture Eau De Parfum Pour Femme ...        120.00  None
# 40  Tom Ford Fabulous Eau De Parfum Pour Homme & F...  None  450.00  None
# 41  Xerjoff 1861 Naxos Eau De Parfum Pour Homme & ...  None  265.00  None
# 42  Amouage Love Tuberose Eau De Parfum Pour Femme...  None  295.00  None
# 43  Creed Oud Zarian Eau De Parfum Pour Homme & Fe...  None  550.00  None
# 44          Lancome La Vie Est Belle Women's Gift Set        175.00  None
# 45  Hermes L'Ombre Des Merveilles Eau De Parfum Po...  None  155.00  None
# 46  Loreal Men Expert Thermic Resist 45° Roll On D...  None    9.99  None
# 47  Loreal Men Expert Fresh Extreme 48H Roll On De...  None    9.99  None
# 48  Loreal Men Expert Carbon Protect 48H Roll On D...  None    9.99  None
# 49  Loreal Men Expert Shirt Protect 48H Roll On De...  None    9.99  None
#
#      size  available barcode  \
# 0    50ml      False    None
# 1   100ml      False    None
# 2    None       True    None
# 3    None       True    None
# 4    None       True    None
# 5    None       True    None
# 6    None       True    None
# 7    None       True    None
# 8    None       True    None
# 9    None       True    None
# 10   None       True    None
# 11   None       True    None
# 12   None       True    None
# 13   None       True    None
# 14   None       True    None
# 15   None       True    None
# 16   None       True    None
# 17   None       True    None
# 18   None       True    None
# 19   None       True    None
# 20   None       True    None
# 21   None       True    None
# 22   None       True    None
# 23   None       True    None
# 24   50ml       True    None
# 25  100ml       True    None
# 26  150ml      False    None
# 27  300ml       True    None
# 28  100ml      False    None
# 29  200ml       True    None
# 30   None      False    None
# 31   None       True    None
# 32   None       True    None
# 33   None       True    None
# 34   None       True    None
# 35   None       True    None
# 36   None       True    None
# 37   None       True    None
# 38   None       True    None
# 39   None       True    None
# 40   None       True    None
# 41   None       True    None
# 42   None       True    None
# 43   None       True    None
# 44   None       True    None
# 45   None       True    None
# 46   None       True    None
# 47   None       True    None
# 48   None       True    None
# 49   None       True    None
#
#                                                 image
# 0   https://cdn.shopify.com/s/files/1/0589/8613/56...
# 1   https://cdn.shopify.com/s/files/1/0589/8613/56...
# 2   https://cdn.shopify.com/s/files/1/0589/8613/56...
# 3   https://cdn.shopify.com/s/files/1/0589/8613/56...
# 4   https://cdn.shopify.com/s/files/1/0589/8613/56...
# 5   https://cdn.shopify.com/s/files/1/0589/8613/56...
# 6   https://cdn.shopify.com/s/files/1/0589/8613/56...
# 7   https://cdn.shopify.com/s/files/1/0589/8613/56...
# 8   https://cdn.shopify.com/s/files/1/0589/8613/56...
# 9   https://cdn.shopify.com/s/files/1/0589/8613/56...
# 10  https://cdn.shopify.com/s/files/1/0589/8613/56...
# 11  https://cdn.shopify.com/s/files/1/0589/8613/56...
# 12  https://cdn.shopify.com/s/files/1/0589/8613/56...
# 13  https://cdn.shopify.com/s/files/1/0589/8613/56...
# 14  https://cdn.shopify.com/s/files/1/0589/8613/56...
# 15  https://cdn.shopify.com/s/files/1/0589/8613/56...
# 16  https://cdn.shopify.com/s/files/1/0589/8613/56...
# 17  https://cdn.shopify.com/s/files/1/0589/8613/56...
# 18  https://cdn.shopify.com/s/files/1/0589/8613/56...
# 19  https://cdn.shopify.com/s/files/1/0589/8613/56...
# 20  https://cdn.shopify.com/s/files/1/0589/8613/56...
# 21  https://cdn.shopify.com/s/files/1/0589/8613/56...
# 22  https://cdn.shopify.com/s/files/1/0589/8613/56...
# 23  https://cdn.shopify.com/s/files/1/0589/8613/56...
# 24  https://cdn.shopify.com/s/files/1/0589/8613/56...
# 25  https://cdn.shopify.com/s/files/1/0589/8613/56...
# 26  https://cdn.shopify.com/s/files/1/0589/8613/56...
# 27  https://cdn.shopify.com/s/files/1/0589/8613/56...
# 28  https://cdn.shopify.com/s/files/1/0589/8613/56...
# 29  https://cdn.shopify.com/s/files/1/0589/8613/56...
# 30  https://cdn.shopify.com/s/files/1/0589/8613/56...
# 31  https://cdn.shopify.com/s/files/1/0589/8613/56...
# 32  https://cdn.shopify.com/s/files/1/0589/8613/56...
# 33  https://cdn.shopify.com/s/files/1/0589/8613/56...
# 34  https://cdn.shopify.com/s/files/1/0589/8613/56...
# 35  https://cdn.shopify.com/s/files/1/0589/8613/56...
# 36  https://cdn.shopify.com/s/files/1/0589/8613/56...
# 37  https://cdn.shopify.com/s/files/1/0589/8613/56...
# 38  https://cdn.shopify.com/s/files/1/0589/8613/56...
# 39  https://cdn.shopify.com/s/files/1/0589/8613/56...
# 40  https://cdn.shopify.com/s/files/1/0589/8613/56...
# 41  https://cdn.shopify.com/s/files/1/0589/8613/56...
# 42  https://cdn.shopify.com/s/files/1/0589/8613/56...
# 43  https://cdn.shopify.com/s/files/1/0589/8613/56...
# 44  https://cdn.shopify.com/s/files/1/0589/8613/56...
# 45  https://cdn.shopify.com/s/files/1/0589/8613/56...
# 46  https://cdn.shopify.com/s/files/1/0589/8613/56...
# 47  https://cdn.shopify.com/s/files/1/0589/8613/56...
# 48  https://cdn.shopify.com/s/files/1/0589/8613/56...
# 49  https://cdn.shopify.com/s/files/1/0589/8613/56...

# %%
# df.to_csv("beirutfreezone_products.csv", index=False)
df.to_excel("beirutfreezone_products.xlsx", index=False)
