# %% [markdown]
# <a href="https://colab.research.google.com/github/amien1410/amien-scrapers/blob/main/Tiktok_Scraper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import os
import pandas as pd
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import json
from google.oauth2 import service_account
from google.auth.transport.requests import Request
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
from google.auth.exceptions import RefreshError
from google.oauth2.credentials import Credentials
from datetime import datetime
import pytz
import tkinter as tk
from tkinter import messagebox
import threading
import time

# %%
status = ''
next_cursor = 1721643023000
sheetId = "1Aj1Hb_CJe2N1GHXML3aEZshaxfXR8D1oyboIYhk8uTk"

def convert_to_japanese_time(unix_timestamp):
    japan_tz = pytz.timezone('Asia/Tokyo')
    utc_time = datetime.fromtimestamp(unix_timestamp, tz=pytz.utc)
    japan_time = utc_time.astimezone(japan_tz)
    japan_time_str = japan_time.strftime('%Y-%m-%d %H:%M:%S %Z%z')
    return japan_time_str

def append_to_google_sheet(data_dict, sheet_id, file_name):
    creds_dict = {
        "type": "service_account",
        "project_id": "tiktok-431315",
        "private_key_id": "8a1a5f5dcc24d6424fb385f97802ad3e13030fae",
        "private_key": "-----BEGIN PRIVATE KEY-----\\ndoOnlEnSpp/nFyXBnF1rYF4U\n-----END PRIVATE KEY-----\n",
        "client_email": "haruki@tiktok-431315.iam.gserviceaccount.com",
        "client_id": "109338037940246631487",
        "auth_uri": "https://accounts.google.com/o/oauth2/auth",
        "token_uri": "https://oauth2.googleapis.com/token",
        "auth_provider_x509_cert_url": "https://www.googleapis.com/oauth2/v1/certs",
        "client_x509_cert_url": "https://www.googleapis.com/robot/v1/metadata/x509/haruki%40tiktok-431315.iam.gserviceaccount.com",
        "universe_domain": "googleapis.com"
    }

    """
    Appends rows to a Google Sheet based on the given dictionary.

    Parameters:
    data_dict (dict): The dictionary with data to append. Keys should be column names.
    sheet_id (str): The ID of the Google Sheet.
    file_name (str): The name of the sheet within the Google Sheet to append to.
    """

    # Use creds to create a client to interact with the Google Drive API
    scope = ["https://spreadsheets.google.com/feeds", 'https://www.googleapis.com/auth/spreadsheets',
             "https://www.googleapis.com/auth/drive.file", "https://www.googleapis.com/auth/drive"]


    creds = ServiceAccountCredentials.from_json_keyfile_dict(creds_dict, scope)
    client = gspread.authorize(creds)

    try:
        # Open the Google Sheet
        sheet = client.open_by_key(sheet_id)
        worksheet = sheet.worksheet(file_name)
    except gspread.WorksheetNotFound:
        # If the worksheet does not exist, create it
        worksheet = sheet.add_worksheet(title=file_name, rows="100", cols="20")

    # Convert dictionary to DataFrame
    df = pd.DataFrame(data_dict)

    # Check if worksheet already has data
    existing_data = worksheet.get_all_values()
    if existing_data:
        # If there is existing data, append new data
        existing_df = pd.DataFrame(existing_data[1:], columns=existing_data[0])
        new_df = pd.concat([existing_df, df], ignore_index=True)
    else:
        # If there is no existing data, use the new data
        new_df = df

    # Clear the existing worksheet
    worksheet.clear()

    # Write the new data to the worksheet
    worksheet.update([new_df.columns.values.tolist()] + new_df.values.tolist())

    print(f"Data appended to the sheet '{file_name}' successfully.")

def getPostInfo(username, cursor):
    url = "https://tiker.cc:443/api/tiktok"
    headers = {"Content-Type": "application/json", "Accept": "*/*", "Accept-Encoding": "gzip, deflate", "Accept-Language": "en-US,en;q=0.9,en-IN;q=0.8", "Priority": "u=1, i"}
    json={"max_cursor": cursor, "username": username}
    x=requests.post(url, headers=headers, json=json)
    data = x.json()
    if data['status_msg'] == "No more videos":
        return 0
    return [data, data["max_cursor"]]

def processData(data, username):
    json = {'投稿タイトル': data['desc'], '投稿日': convert_to_japanese_time(data['create_time']), '投稿URL': f'https://www.tiktok.com/@{username}/video/'+data['statistics']['aweme_id'], '再生数': data['statistics']['play_count'], 'いいね数': data['statistics']['digg_count'], 'コメント': data['statistics']['comment_count'], '保存数': data['statistics']['collect_count'], '共有数': data['statistics']['share_count']}
    return json

def start_process(username, sheetId):
    global next_cursor
    try:
        creds_dict = {
            "type": "service_account",
            "project_id": "tiktok-431315",
            "private_key_id": "8a1a5f5dcc24d6424fb385f97802ad3e13030fae",
            "private_key": "-----BEGIN PRIVATE KEY-----\\ndoOnlEnSpp/nFyXBnF1rYF4U\n-----END PRIVATE KEY-----\n",
            "client_email": "haruki@tiktok-431315.iam.gserviceaccount.com",
            "client_id": "109338037940246631487",
            "auth_uri": "https://accounts.google.com/o/oauth2/auth",
            "token_uri": "https://oauth2.googleapis.com/token",
            "auth_provider_x509_cert_url": "https://www.googleapis.com/oauth2/v1/certs",
            "client_x509_cert_url": "https://www.googleapis.com/robot/v1/metadata/x509/haruki%40tiktok-431315.iam.gserviceaccount.com",
            "universe_domain": "googleapis.com"
        }

        scope = ["https://spreadsheets.google.com/feeds", 'https://www.googleapis.com/auth/spreadsheets',
                 "https://www.googleapis.com/auth/drive.file", "https://www.googleapis.com/auth/drive"]

        creds = ServiceAccountCredentials.from_json_keyfile_dict(creds_dict, scope)
        client = gspread.authorize(creds)

        # Open the Google Sheet
        sheet = client.open_by_key(sheetId)

        # Clear existing data for the username
        try:
            worksheet = sheet.worksheet(username + '資料')
            worksheet.clear()  # Clear existing data for the username
        except gspread.WorksheetNotFound:
            # If the worksheet does not exist, create it
            worksheet = sheet.add_worksheet(title=username + '資料', rows="100", cols="20")

        videos = []

        while True:
            while status != "No more videos":
                result = getPostInfo(username, next_cursor)
                if result == 0:
                    break
                next_cursor = result[1]
                info = result[0]["aweme_list"]
                for subData in info:
                    # processedData = processData(subData, username)
                    subData = {
                        '投稿タイトル': subData['desc'],
                        '投稿日': convert_to_japanese_time(subData['create_time']),
                        '投稿URL': f'https://www.tiktok.com/@{username}/video/'+subData['statistics']['aweme_id'],
                        '再生数': subData['statistics']['play_count'], 'いいね数': subData['statistics']['digg_count'],
                        'コメント': subData['statistics']['comment_count'],
                        '保存数': subData['statistics']['collect_count'],
                        '共有数': subData['statistics']['share_count']
                    }
                    videos.append(subData)
                    # append_to_google_sheet(processedData, sheetId, username + '資料')
                    # time.sleep(3)

            # messagebox.showinfo("お知らせ", "正常に完了しました。")

            # # Reset GUI state
            # username_entry.delete(0, tk.END)  # Clear the username entry
            # sheet_id_entry.delete(0, tk.END)  # Clear the sheet ID entry
            # start_button.config(text="開始", state=tk.NORMAL)  # Reset button text and enable it
            # print("result: ", result)
            # print("status: ", status)
            # print("next_cursor: ", next_cursor)
            next_cursor = 1721643023000
            result = 1
            break

        append_to_google_sheet(videos, sheetId, username + '資料')
        print(f"Fetched {len(videos)} videos from {username} Tiktok account")
        print(f"The last video is: {videos[-1]['desc']}")

    except Exception as e:
        error_message = f"An error occurred: {e}"
        # messagebox.showerror("エラー", error_message)

# %%
data = start_process("kirakira_ccc", sheetId)
# Out:
# Data appended to the sheet 'kirakira_ccc資料' successfully.
# Fetched 15 videos from kirakira_ccc Tiktok account

# %%
uname = "kirakira_ccc"
cursor = 1721643023000
url = "https://tiker.cc/api/tiktok"
headers = {"Content-Type": "application/json", "Accept": "*/*", "Accept-Encoding": "gzip, deflate", "Accept-Language": "en-US,en;q=0.9,en-IN;q=0.8", "Priority": "u=1, i"}
json={"max_cursor": cursor, "username": uname}
x=requests.post(url, headers=headers, json=json)
data = x.json()
print(f"Status: {data['status_msg']}")
# data
# print(f"Next cursor: {data['max_cursor']}")
print(f"Video count: {len(data['aweme_list'])}")
# videos = data['aweme_list']
# next_curson = data["max_cursor"]
# Out:
# Status:
# Video count: 15

# %%
url = "https://tiker.cc/api/tiktok"
headers = {"Content-Type": "application/json", "Accept": "*/*", "Accept-Encoding": "gzip, deflate", "Accept-Language": "en-US,en;q=0.9,en-IN;q=0.8", "Priority": "u=1, i"}
json = {"username":"kirakira_ccc", "max_cursor": "1721643023000"}
tiktok = requests.post(url, json=json, headers=headers).json()
tiktok
# Out:
# {'aweme_list': [{'added_sound_music_info': {'album': '',
#     'artists': [],
#     'audition_duration': 6,
#     'author': 'きらら🎀',
#     'author_deleted': False,
#     'author_position': None,
#     'avatar_medium': {'height': 720,
#      'uri': 'tos-alisg-avt-0068/d996219371c670ee37c106654257d4ec',
#      'url_list': ['https://p77-sg.tiktokcdn.com/tos-alisg-avt-0068/d996219371c670ee37c106654257d4ec~tplv-tiktokx-cropcenter-q:720:720:q80.heic?dr=9607&idc=useast2a&nonce=51834&ps=87d6e48a&refresh_token=6c44b0184e7f82b76674d277d94b6fcf&s=PUBLISH&sc=avatar&shcp=132edbea&shp=45126217&t=223449c4',
#       'https://p77-sg.tiktokcdn.com/tos-alisg-avt-0068/d996219371c670ee37c106654257d4ec~tplv-tiktokx-cropcenter-q:720:720:q80.jpeg?dr=9607&idc=useast2a&nonce=59514&ps=87d6e48a&refresh_token=e3fb8718f5a3db2ec31e6910054610c0&s=PUBLISH&sc=avatar&shcp=132edbea&shp=45126217&t=223449c4'],
#      'url_prefix': None,
#      'width': 720},
#     'avatar_thumb': {'height': 720,
# ...

# %%
username = "kirakira_ccc"
cursor = "1721643023000"
url = "https://tiker.cc/api/tiktok"
status = ""
# headers = {"Content-Type": "application/json", "Accept": "*/*", "Accept-Encoding": "gzip, deflate", "Accept-Language": "en-US,en;q=0.9,en-IN;q=0.8", "Priority": "u=1, i"}
headers = {
    "Host": "tiker.cc",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:130.0) Gecko/20100101 Firefox/130.0",
    "Accept": "*/*",
    "Accept-Language": "en-US,en;q=0.5",
    "Accept-Encoding": "gzip, deflate, br, zstd",
    "Referer": "https://tiker.cc/",
    "Content-Type": "application/json",
    "Content-Length": "54",
    "Origin": "https://tiker.cc",
    "Alt-Used": "tiker.cc",
    "Connection": "keep-alive",
    "Cookie": "_ga_BD2F29G0V2=GS1.1.1727316415.1.1.1727316442.0.0.0; _ga=GA1.1.1276879653.1727316415",
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "same-origin",
    "Priority": "u=0"
}
videos = []
while True:
    json_data = {
        "token": "0.dxF0h-HsYnFr_-Ay--AWDOFuArx5dFz7R5DggHla5rP6uH2za_i-DzJeNgUwaoJ8ss-PEa-_XCoyNR5KnLrdy0mHm7ycioF3bnI5xYEr92S9kJXucIWzBvIz9WDD7Jxl5W67IhZNx43zR4Iv6I4UzUv69CxrazOVQQMi7tMUx1cMKGIlAKr71Avoos7Ec1mRZVdErZinjfKU_bmAfceN_-s2aLQ-wng25mRcjoNJwJxxr5YuITO3lswrYAZCwKNkGfbrtdzsRZayhIBue1TtI5rQ_Uf2A8X2btJ2uubxjSvkwfyKysC_T0e7L8cHysSB7JFk5bcm2ccIkmk4o1tV9xGRwjagR7IN8w50_4WHWAsz6Tv2Jo3Rw1tTstyQQYpO-klPGduwu1He5eElzFzYnTE9ixQshT4_-KIord3OtaBMnvK-VtB3abL4c_ZU0hpYmP4VOKSYkN6moVkr31yPAZLaI-ldhs-mKeAB2MEDaA5tLVNmVaNqBA9yvuimMAzJRF3icgMiCkWAHuIcQe5WWmjEv5D1VV5rekIxXF7749hkivsX_oSJP-hCO4-wxcFzSzcmw5utx5dsxten_mU5Grgst9yPVlKN_hq_kpk0SRt-TKCCrfQQmwzhnabQX38336mOuQ7IHP-3-Yn6vAgJYKz2gT_7dPRbMT6OEz5PSCrKrfkYLyvKDSHig2dViZrg.gyhffHIoLjUEzfiTnB6zMw.14f572248f166c42e8e3c5cf4b5792a210df5f054717a70ab5eea529dd397384",
        "username": username,
        "max_cursor": cursor
    }
    response = requests.post(url, headers=headers, json=json_data)
    data = response.json()
    status = data['status_msg']
    print(status)

    # Stop if there are less than 20 videos in the current batch
    # if data['status_msg'] == "No more videos":
    #     break

    # current_videos = data['aweme_list']
    # videos.extend(current_videos)

    # # Update cursor for next request
    # cursor = data["max_cursor"]

# At this point, `videos` contains all the fetched videos
print(f"Fetched {len(videos)} videos from {username} Tiktok account")
print(f"The last video is: {videos[-1]['desc']}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-8cdfcbba9f18> in <cell line: 25>()
#      29         "max_cursor": cursor
#      30     }
# ---> 31     response = requests.post(url, headers=headers, json=json_data)
#      32     data = response.json()
#      33     status = data['status_msg']
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in post(url, data, json, **kwargs)
#     113     """
#     114
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#     116
#     117
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# ...

# %%
videos[-1]['desc']
# Out:
# '疲れた時はこれ使えば復活できる\U0001f979'

# %%
urlbid = "https://urlebird.com/ajax/"
payload = {
    "action": "user",
    "data": {
        "user_id":"7d146c089bf3419fJzqebnYy0trzSif6W0Q3uWomn5HdePEqJB-Smwcx0UE",
        "sec_uid":"af9c9010ab9d6b81nyxEcnCrPk6qzDu9npJuiLB4_YnxfvVAqn1D4ztaD_p53Vk-tZ9I83dBh0n9V_0nlWbVyd9lr8DtWTAVjG9dRk_dK4j8Al0ROKdu59zeQ5mlrvya-Y7BdmSF4rfsoJIS",
        "cursor":"67d94d4a0c0e31f4zaMyO2jKx7bVbLXdW7IdrZkRWpLNdzZsJAUJzlbrCiY",
        "lang":"",
        "page":"3",
        "x":"e3a75ffe0a087d5c6IUhcBqkWcz6lMtgjnpbHbbr58HiQ280xGXNJB_aPtU"
        }}
headers = {
    "accept": "*/*",
    "accept-encoding": "gzip, deflate, br, zstd",
    "accept-language": "en-US,en;q=0.9,id;q=0.8,ar;q=0.7,fa;q=0.6",
    "content-length": "479",
    "content-type": "application/x-www-form-urlencoded; charset=UTF-8",
    "cookie": "_gid=GA1.2.849487941.1728299256; stpdOrigin={'origin':'organic'}; _sharedID=66ecee55-23ec-4228-bf90-f28dddc993f1; _sharedID_cst=kSylLAssaw%3D%3D; cf_clearance=6XQ.YctKwQDajF0qFhxDjgYayCGgp.npZ1kgyh8kKT4-1728299256-1.2.1.1-AcMHIm5dSYSydKyKFOlBZ3iicp.ceey_vYy4aFuuCjbVB1luEeBVZoeG1Jrxo6KqRTj_bWeMSqgWfSj1DeitsI6G76X6jKLL.a0WwrYpnsHfGo4mTjH2x0_kHg8BFSFOm61vY9ZepeKtjKNC2sXpv88gbq9Zsr.stcOYKCfDJJzCVCYSMFzdoqLKxT9JVcbvtsWlI.6ov_dEFxoYdZ_JBOUY4NuPIGmpNQT_M.HohBxBSCSYKFSZZ2KLsiPtxA5vjiPHhEgqYrnEWAvfzRO868o6mVGDP216pY9xEWmo1iefRIIMl0.e2dKiAUL8Hs9ahMy6lrrLqmdIgnZVJAvcA0JdXGmVVU3Li3JID9M1HTlwrvPpjWMl3zXwnHxWw4VWZXZhMVfIJl1AafCNhqLR4g; __gads=ID=0031281bc05ab928:T=1728299258:RT=1728299258:S=ALNI_MbTrQJmi9u5ypSA2yqnIQt3jcBiew; __gpi=UID=00000f38918d9d68:T=1728299258:RT=1728299258:S=ALNI_Mb8CAgrCGVwvN7C83jNj3jqXGBLaA; __eoi=ID=1fa90d05b1ca5391:T=1728299258:RT=1728299258:S=AA-AfjYm44X5h9qPWxlOTZCeaYuv; _ga=GA1.2.1370162040.1728299256; cto_bidid=nypKGl9Dem01VnA1T2FEbnZvVElzSjJ5WlR0MFUlMkZnSnpXMDdEelJ5eDMzSGVtTkx3aFFyb3Y4SlJsT05hUVNaaUNBR28zd3ZReXglMkZaekN5NTltdFZIZjlxdDBYJTJGcVBTMksxUHBhWHE0cktHeHJhVjVaa2lsUWNPTlQzdUhFV0k2ZnV1JTJCUjdaV0RtNW81dlJZQUQxZHFHVlE4QSUzRCUzRA; cto_dna_bundle=vezK4l91d1lCZjlqZ0ElMkJQbWFXNElKRWVHMEFLRm1OelFEZGNhZ21TUjBDMEk2VnNiOXpvbDRUUHk0eVBiWFBPeU9EZUdNRXFoVnJHNmFTJTJCdEVTeVM5d1ElMkJ4ZyUzRCUzRA; adh=1; cto_bundle=; _ga_LC23RQB8HX=GS1.1.1728299256.1.1.1728299409.0.0.0",
    "origin": "https://urlebird.com",
    "priority": "u=1, i",
    "referer": "https://urlebird.com/user/mrbeast/",
    "sec-ch-ua": '"Microsoft Edge";v="129", "Not=A?Brand";v="8", "Chromium";v="129"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": '"Windows"',
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-origin",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.0.0 Safari/537.36 Edg/129.0.0.0",
    "x-requested-with": "XMLHttpRequest"
}

# %%
res = requests.post(urlbid, data=payload)
res.text

# %%
import requests
from bs4 import BeautifulSoup

# %%
res = requests.get("https://www.thebluebook.com/search.html?region=33&searchsrc=&class=4704&searchTerm=Office+Relocation+%26+Logistics&page=1")
soup = BeautifulSoup(res.text, 'html.parser')
soup

# %%
companies = soup.find_all("div", class_="single_result_wrapper")
companies[0]

# %%
# !pip install "httpx[http2,brotli]" parsel
import re
import httpx
import json
import time
import string
import random
import datetime
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
headers = {
    "accept":"text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7",
    "accept-encoding":"gzip, deflate, br, zstd",
    "accept-language":"en-US,en;q=0.9,id;q=0.8,ar;q=0.7,fa;q=0.6",
    "cookie":'SSLB=1; bm_ss=ab8e18ef4e; language_preference=en-US; site_preference=en-US; companyInfo={"companyAddress":"1341 Horton Cir","companyCity":"Arlington","companyCountry":"US","companyName":"D.R. Horton, Inc.","companyState":"Texas","companyZip":"76011-4310","encryptedDuns":"53890f4828e079d340ea27fd3cfdd0ff","completedCreditSignalFlow":false}; SSID=CQCXaR0qAAAAAAAGBQVnrjrAHgYFBWcCAAAAAAAAAAAAkg8FZwB-5REwAQEVSiYAkg8FZwEAfSwBAYLyJQCSDwVnAQDXTAEBOwEpAJIPBWcBAA; SSSC=644.G7423345084633987758.2|76925.2486914:77841.2509333:85207.2687291; SSRT=kg8FZwADAA; SSOD=AOYbAAAAEgAjzDMABgAAAAYFBWeSDwVnAQAAAA; bm_s=; bm_sz=FD58B32BF1606738E14B88A7568AFBC5~~3617860~4277044; TAsessionID=ba006057-df12-46ec-977c-4758e5ce8772|NEW; notice_gdpr_prefs=0|1|2|3:; TAconsentID=37083097-97ac-41cc-9912-b82fba845e7e; notice_behavior=implied|as; notice_preferences=3:; HID=1728384921283; ak_bmsc=8CF5203E5F3598C22441D51C4E54049D~000000000000000000000000000000~; _cs_c=0; _cs_id=e242efb9-e37d-a3b3-9d99-0a39e8ce693e.1728384924.1.1728384924.1728384924.1717766230.1762548924513.1; _mkto_trk=id:080-UQJ-704&token:_mch-dnb.com-1728384924861-68540; s_nr30=1728384925441-New; _uetsid=8afbc490855d11ef850a4dbace820286; _uetvid=8afc3190855d11ef805b71ad1bde82af; AMCVS_8E4767C25245B0B80A490D4C%40AdobeOrg=1; _hjSessionUser_3331568=eyJpZCI6IjA5YWNhMGUzLWJiYzktNTRiNS1hMzhjLWMzMTk4YzhjNzUyNyIsImNyZWF0ZWQiOjE3MjgzODQ5MjU3NjEsImV4aXN0aW5nIjpmYWxzZX0=; _hjSession_3331568=eyJpZCI6ImMwMjUzYjZkLTg3MzUtNDViYi05NTdlLWNjYTdmZDk1NDYyYiIsImMiOjE3MjgzODQ5MjU3NjUsInMiOjAsInIiOjAsInNiIjowLCJzciI6MCwic2UiOjAsImZzIjoxLCJzcCI6MH0=; __exponea_etc__=68725086-668d-46ac-b393-ec8f3618befa; cmapi_gtm_bl=; cmapi_cookie_privacy=permit_1|2|3|4_; s_cc=true; __exponea_time2__=0.10238933563232422; AMCV_8E4767C25245B0B80A490D4C%40AdobeOrg=-1124106680%7CMCIDTS%7C20005%7CMCMID%7C08258202880935504035812300188268206286%7CMCOPTOUT-1728392128s%7CNONE%7CvVersion%7C5.2.0; drift_campaign_refresh=ccdd120e-6996-4289-b2a6-851588f44af2; drift_aid=0ff1093f-707b-45f1-9789-f0395a8466ef; driftt_aid=0ff1093f-707b-45f1-9789-f0395a8466ef; _abck=BC46B130933739119EFC6388E150C80C~0~...~-1~||0||~-1; invoca_session=%7B%22ttl%22%3A%222024-11-07T10%3A56%3A24.053Z%22%2C%22session%22%3A%7B%22invoca_id%22%3A%22i-e9de8122-528a-4271-e20e-12ff6a992d45%22%7D%2C%22config%22%3A%7B%22ce%22%3Atrue%2C%22fv%22%3Afalse%2C%22rn%22%3Afalse%7D%7D; _cs_s=1.0.0.1728386784793',
    "priority":"u=0, i",
    "referer":"https://www.dnb.com/",
    "sec-ch-ua":'"Microsoft Edge";v="129", "Not=A?Brand";v="8", "Chromium";v="129"',
    "sec-ch-ua-mobile":"?0",
    "sec-ch-ua-platform":"Windows",
    "sec-fetch-dest":"document",
    "sec-fetch-mode":'navigate',
    "sec-fetch-site":"same-origin",
    "sec-fetch-user":'?1',
    "upgrade-insecure-requests":"1",
    "user-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.0.0 Safari/537.36 Edg/129.0.0.0"
}

# %%
BASE_HEADERS = {
    "authority": "www.tripadvisor.com",
    "accept-language": "en-US,en;q=0.9",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.110 Safari/537.36",
    "accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8",
    "accept-language": "en-US;en;q=0.9",
    "accept-encoding": "gzip, deflate, br",
}
# start HTTP session client with our headers and HTTP2
client = httpx.AsyncClient(
    http2=True,  # http2 connections are significantly less likely to get blocked
    headers=BASE_HEADERS,
    timeout=httpx.Timeout(15.0),
    limits=httpx.Limits(max_connections=5),
)

# %%
# get the page with method POST and pass the payload and headers as the parameters
result = await client.get(
    url="https://www.dnb.com/business-directory/company-information.residential_building_construction.us.texas.html?page=2",
    headers=headers
)

# %%
soup = BeautifulSoup(result.content, 'html.parser')
companies = soup.find_all("div", class_="col-md-12 data")
companies[0]
# Out:
# <div class="col-md-12 data">
# <div class="col-md-6">
# <a href="/business-directory/company-profiles.castlerock_communities_lp.0808671a74625e8d6c2711a6c20d5b76.html">
#                         CastleRock Communities, L.P.</a>
# </div>
# <div class="col-md-4">
# <div class="show-mobile">
#                         Country:
#                     </div>
#
#                     Houston, Texas<br/>
#
#                     United States</div>
# <div class="col-md-2 last">
# <div class="show-mobile">
#                         Sales Revenue ($M):
#                     </div>
#
#                     $33.38M</div>
# </div>
