# %%
# !pip install -Uqq fastai 'duckduckgo_search>=6.2'
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 43.0 MB/s eta 0:00:00

# %% [markdown]
# ### 1. Install the Kaggle API client

# %%
# !pip install kaggle

# %% [markdown]
# ### 2. Upload your Kaggle API Token (kaggle.json)
#
# To download datasets, you need an API token from Kaggle. Follow these steps to get yours:
#
# 1. Go to [Kaggle](https://www.kaggle.com/).
# 2. Log in to your account.
# 3. Click on your profile picture (top right) and select "My Account".
# 4. Scroll down to the "API" section and click "Create New API Token". This will download a file named `kaggle.json`.
#
# Once you have `kaggle.json`, run the following cell and upload the file.

# %%
from google.colab import files

files.upload()

# %% [markdown]
# ### 3. Move kaggle.json to the correct directory and set permissions
#
# Colab needs `kaggle.json` to be in `~/.kaggle/` with appropriate permissions.

# %%
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# ### 4. Download the dataset
#
# Now you can use the Kaggle API to download the dataset. The dataset identifier is usually `username/dataset-name`. From the URL `https://www.kaggle.com/datasets/mahdisarbazi/qajar-dynasty-iranian-carpet-dataset`, the identifier is `mahdisarbazi/qajar-dynasty-iranian-carpet-dataset`.

# %%
# !kaggle datasets download -d mahdisarbazi/qajar-dynasty-iranian-carpet-dataset

# %% [markdown]
# ### 5. Unzip the dataset
#
# Kaggle datasets are often downloaded as zip files. You'll need to unzip them to access the contents.

# %%
# !unzip qajar-dynasty-iranian-carpet-dataset.zip -d qajar-rugs

# %% [markdown]
# The dataset should now be available in the `qajar-rugs` directory.

# %%
from duckduckgo_search import DDGS
from fastcore.all import *
from fastai.vision.all import *
from fastdownload import download_url
import time
from tqdm.notebook import tqdm

# %%
rug_categories = (
    'Persian',
    'Chinese',
    'Modern',
    'Traditional',
    'Bohemian',
    'Turkish',
    'Moroccan',
    'Indian',
    'Kilim',
    'Navajo'
)

# %%
def search_images(keywords, max_images=200): return L(DDGS().images(keywords, max_results=max_images)).itemgot('image')

# %%
rug_example = download_url(search_images('a nice rug photo', max_images=1)[0], 'rug.jpg', show_progress=False)
# Out:
# /tmp/ipykernel_173/82616099.py:1: RuntimeWarning: This package (`duckduckgo_search`) has been renamed to `ddgs`! Use `pip install ddgs` instead.
#   def search_images(keywords, max_images=200): return L(DDGS().images(keywords, max_results=max_images)).itemgot('image')
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ...
