# %%
#@title whatsapp-osint

import requests

url = "https://whatsapp-osint.p.rapidapi.com/bizos"

payload = { "phone": "+6281280842961" }
headers = {
    "x-rapidapi-key": "",
    "x-rapidapi-host": "whatsapp-osint.p.rapidapi.com",
    "Content-Type": "application/json"
}

response = requests.post(url, json=payload, headers=headers)

print(response.json())
# Out:
# [{'query': '+6281280842961', 'isBusiness': 'Not a Business Account', 'verifiedName': None}]
