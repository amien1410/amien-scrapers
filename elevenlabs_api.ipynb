# %%
# !pip install elevenlabs
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 16.1 MB/s eta 0:00:00
# ...

# %%
from elevenlabs.client import ElevenLabs
from elevenlabs.core import ApiError

def validate_elevenlabs_api_key(api_key: str) -> bool:
    """Validates an ElevenLabs API key by attempting to fetch voices."""
    client = ElevenLabs(
        api_key=api_key,
    )

    try:
        client.voices.search()
        # print("ElevenLabs API key is valid.")
        return True
    except ApiError as e:
        # if e.status_code == 401:
        #     # print(f"ElevenLabs API key is invalid: {e.body.get('detail', {}).get('message', 'Authentication failed')}")
        # else:
        #     print(f"An ElevenLabs API error occurred with status {e.status_code}: {e}")
        return False
    except Exception as e:
        print(f"An unexpected error occurred during API key validation: {e}")
        return False

# %%
# https://github.com/search?q=elevenlabs%20AND%20sk_3&type=code

from elevenlabs.client import ElevenLabs
from elevenlabs.core import ApiError

client = ElevenLabs(
  api_key="sk_15a6f8b03b54e6264e5309cb6f38d14957439229be8d0efd",
)

try:
    response = client.voices.search()
    print(response.voices)
except ApiError as e:
    print(f"An ElevenLabs API error occurred: {e}")
    print("Please check your API key and ensure it's valid.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# [Voice(voice_id='nDJIICjR9zfJExIFeSCN', name='Emmaline - young British girl', samples=None, category='professional', fine_tuning=FineTuningResponse(is_allowed_to_fine_tune=True, state={'eleven_multilingual_v2': 'fine_tuning', 'eleven_turbo_v2_5': 'fine_tuned', 'eleven_v2_flash': 'fine_tuned', 'eleven_flash_v2_5': 'fine_tuned', 'eleven_v2_5_flash': 'fine_tuned', 'eleven_turbo_v2': 'fine_tuned', 'eleven_flash_v2': 'fine_tuned', 'eleven_multilingual_sts_v2': 'fine_tuned'}, verification_failures=[], verification_attempts_count=0, manual_verification_requested=False, language='en', progress={}, message={}, dataset_duration_seconds=None, verification_attempts=None, slice_ids=None, manual_verification=None, max_verification_attempts=0, next_max_verification_attempts_reset_unix_ms=0, finetuning_state=None), labels={'language': 'en', 'descriptive': 'confident', 'age': 'young', 'gender': 'female', 'accent': 'british', 'use_case': 'characters_animation', 'locale': 'en-GB'}, description="Emmalin
# ...

# %%
mystring = r"""
Skip to content
code Search Results · elevenlabs AND sk_2 language:dart
Filter by
Repositories
Paths
Advanced
5 files
 (1 s)
5 files
Files with identical content are grouped together.


Idoo0/neurokit · lib/utils/constants.dart
Dart
·
7
 (7)
  // ElevenLabs API Configuration
  static const String elevenLabsBaseUrl = "https://api.elevenlabs.io/v1";
  static const String elevenLabsApiKey =
      "sk_2015ce1db20fffa9520fca6d6ca3337c4f66b48f491a2215"; // Ganti dengan API key yang valid
  // Voice ID untuk ElevenLabs (ini adalah voice ID default, bisa diganti)
Show 1 more match


LuisMario698/planmexicoHACKA · lib/service/tts_service.dart
Dart
·
62
 (62)

  // ⚠️ IMPORTANTE: Reemplaza con tu API Key de ElevenLabs
  // Obtén una gratis en: https://elevenlabs.io/
  static const String _elevenLabsApiKey = 'sk_21f5a952eaf133de154789e0f96d320c95b4be116c91f2de';

  // Voz de ElevenLabs - Jaider (masculina mexicana)
  static const Map<String, Map<String, dynamic>> _elevenLabsVoices = {
Show 56 more matches


Bieelx/Nexus · lib/service/voice_service.dart
Dart
·
4
 (4)
  // Guardamos a instância do player para evitar criar um novo a cada vez
  final AudioPlayer _audioPlayer = AudioPlayer();
  // Suas chaves e IDs da ElevenLabs
  static const String _apiKey = 'sk_2d130af3afb686a0ef513e6579ec77771cea46a58c959e77';
  static const String _voiceId = 'Sm1seazb4gs7RSlUVw7c';
  static const String _baseUrl = 'https://api.elevenlabs.io/v1/text-to-speech/';
Show 1 more match


Bieelx/Nexus · Nexus/lib/service/voice_service.dart


uchamod/flutter-travel-safty-app · lib/services/elevanlabs_service.dart
Dart
·
2
 (2)
import 'package:http/http.dart' as http;
class ElevanlabsService {
  final String _baseUrl = 'https://api.elevenlabs.io/v1';
  final String _apiKey =
      'sk_2f8c3a294d325db62bb65722d3b1e03c7e8a4dfee3163d00'; // Store securely
  //create and get voice model data

Skip to content
code Search Results · elevenlabs AND sk_2 language:javascript
Filter by
Repositories
Paths
Advanced
20 files
 (3 s)
20 files
Files with identical content are grouped together.


Baldnut/GreatUniHack25 · final_web/src/speech.js
JavaScript
·
11
 (11)
const GEMINI_API_KEY = 'AIzaSyA6MYmG27VkeIEpIBuaJ-TIIJrQV_E9Cp0';
const ELEVENLABS_API_KEY = "sk_2fa75eedf7674225add2b05aae2d7996de9c461b0a1cc51e"; // replace with your API key
const ELEVENLABS_VOICE_ID = "JBFqnCBsd6RMkjVDRZzb"; // you can get this from ElevenLabs dashboard
let isSpeaking = false;
let currentAudio = null;
Show 7 more matches


tsmeyer/mAIyer · api/index.js
JavaScript
·
6
 (6)
app.get('/api/get-signed-url', async (req, res) => {
  try {
    const AGENT_ID = 'agent_6301kf03t1b2f7e8dtte5dawdask';
    const API_KEY = process.env.ELEVENLABS_API_KEY || 'sk_23ecdb027f96e10b22b1b0d818aa39e8966c2fdb731feebf';
    const url = `https://api.elevenlabs.io/v1/convai/conversation/get-signed-url?agent_id=${AGENT_ID}`;
    const response = await fetch(url, {
Show 3 more matches


RazorDuraley/myGPT · ElevenLabsTTS/background.js
JavaScript
·
2
 (2)
    const apiKey = 'sk_2a985ff578af7f0ae81f12737fd7ec75cb0059a03af2675e';
    const voiceId = 'WAhoMTNdLdMoq1j3wf3I'; // можно изменить на свой
    try {
        const res = await fetch(`https://api.elevenlabs.io/v1/text-to-speech/${voiceId}`, {
            method: 'POST',
Show less


HaHeonchan/MindFlora · services/ttsService.js
JavaScript
·
6
 (6)
require('dotenv').config();
// ElevenLabs API 키와 음성 ID
const API_KEY = process.env.ELEVENLABS_API_KEY || 'sk_29c8a49d20abb32c049d23e2190a16ba7090bbd6cff6f3dd';
const DEFAULT_VOICE_ID = process.env.ELEVENLABS_VOICE_ID || '21m00Tcm4TlvDq8ikWAM';
// 감정에 따른 음성 파라미터 조정
Show 2 more matches


michelwdaccache/Avatar-Project · frontend/streaming-client-api.js
JavaScript
·
6
 (6)
        'Content-Type': 'application/json',
        'x-api-key-external': '{"elevenlabs": "sk_25dda9282930e22f7e91219ff58a13c71965c93629632cbd"}'
      },
        'Content-Type': 'application/json',
        'x-api-key-exteranl': '{"elevenlabs": "sk_25dda9282930e22f7e91219ff58a13c71965c93629632cbd"}'
      },
Show 2 more matches


GigaChannel2/Definitely-Not-A-Website · jason/jason.js
JavaScript
·
2
 (2)
  "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",
  "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"
];
//const voiceKey = "sk_24dfea9f09c731b4ddc06a669bc8fa1b3c2adf8377cf1f49" //ElevenLabs API Key
const API_URL = "https://openrouter.ai/api/v1/chat/completions";
const model = "deepseek/deepseek-chat:free";
let voiceActivation = false;


GigaChannel2/Definitely-Not-A-Website · jason/jason_debug.js


secretdon/messenger-bot · Priyansh/commands/Speak.js
JavaScript
·
3
 (3)
    credits: "Mirrykal",
    description: "Speak text using predefined ElevenLabs voices",
    commandCategory: "voice",
    const apiKey = "sk_20b1a5899d669aed061c48e8242efd55f43abf2445bfd0f3";
        `https://api.elevenlabs.io/v1/text-to-speech/${selectedVoice.id}`,
Show less


ELITEJ0E/workout-planner · script.js
JavaScript
·
8
 (8)
let synth = window.speechSynthesis || null;
let currentUtterance = null;
const ELEVENLABS_API_KEY = 'sk_26f7a33f44b9fdd92a9f99b70b86ceed3fd81528d0f92735';
const ELEVENLABS_VOICE_ID = 'EXAVITQu4vr4xnSDxMaL';
async function speakText(text) {
Show 5 more matches


marianacamacho12026-cell/mi-app-mindful · generate-self-compassion.js
JavaScript
·
5
 (5)
const __filename = fileURLToPath(import.meta.url);
const __dirname = path.dirname(__filename);
const ELEVENLABS_API_KEY = 'sk_20b68223a1a833e6f68384ce8544098c0efbd2ac4d83e127';
const VOICE_ID = 'KGZeK6FsnWQdrkDHnDNA'; // English female voice
// Script completo con pausas SSML
Show 3 more matches


Surjithk73/auraplus · LipSync/js/app.js
JavaScript
·
4
 (4)
        this.wordTimings = [];

        // ElevenLabs configuration
        this.ELEVENLABS_API_KEY = 'sk_2022d378e73a7afb42bfa52c2484d3ce36a3915052e8cac0';
        this.VOICE_ID = 'pNInz6obpgDQGcFmaJgB'; // Adam voice ID
        this.script = "Hello, I'm Mark, and these are my friends. How are you doing today?";

Show 1 more match


NICODUOC2023/fbmath-video-generator · scripts/generate-audio.mjs
JavaScript
·
13
 (13)
const ELEVENLABS_API_KEY = process.env.ELEVENLABS_API_KEY || 'sk_22f73d5ca3e38bbf31fd63675cc1ca2680d45755f09f60ef';
  mkdirSync('public', { recursive: true });
}
async function generateAudioWithElevenLabs(text, voiceId = VOICE_ID) {
  const response = await fetch(`https://api.elevenlabs.io/v1/text-to-speech/${voiceId}`, {
    method: 'POST',
    headers: {
      'xi-api-key': ELEVENLABS_API_KEY
    console.log('🎵 Generando audios con ElevenLabs...\n');
  const audioFileName = `question_${item.id}_elevenlabs.mp3`;
    const audio = await generateAudioWithElevenLabs(fullText, VOICE_ID);
  const audioFileName = `answer_${item.id}_elevenlabs.mp3`;
    const audio = await generateAudioWithElevenLabs(randomAnswerPhrase, VOICE_ID);
    const response = await fetch('https://api.elevenlabs.io/v1/sound-generation', {
        'xi-api-key': ELEVENLABS_API_KEY,
Show less


Artistsreach/Storos · src/pages/PodcastPage.jsx
JavaScript
·
2
 (2)
    const response = await fetch("https://api.elevenlabs.io/v1/text-to-speech/1SM7GgM6IMuvQlz2BwM3/stream", {
      method: "POST",
        "Content-Type": "application/json",
        "xi-api-key": "sk_2997175c9f408b4579a544d993417bb0069872fa26c748e8",
      },
Show less


Dhanush-prabhu06/Zen-AI · client/src/pages/ai/assitant.jsx
JavaScript
·
3
 (3)
    console.log(text);

    const voiceId = 'cgSgspJ2msm6clMCkdW9';
    const url = `https://api.elevenlabs.io/v1/text-to-speech/${voiceId}/stream`;
    const apiKey = 'sk_21320ddfcc940a85398ff696f757e74ffefe83a69d54b76a';

    const data = {
Show 1 more match


Kilauea-Tec-Lab/reelmotion-frontend-webapp · src/create_elements/functions.js
JavaScript
·
25
 (25)
// ELEVENLABS API FUNCTIONS
const ELEVENLABS_API_KEY =
  "sk_2255a4e8aaeaf2c8211f2ffc968686b602250cd260314f16";
const ELEVENLABS_BASE_URL = "https://api.elevenlabs.io/v1";
// Obtener voces disponibles de ElevenLabs
export async function getElevenLabsVoices() {
  try {
    console.log("Fetching voices from ElevenLabs API...");
    const response = await fetch(`${ELEVENLABS_BASE_URL}/voices`, {
        "xi-api-key": ELEVENLABS_API_KEY,
        `ElevenLabs API error: ${response.status} ${response.statusText}`
    console.log("ElevenLabs voices response:", data);
    // ElevenLabs devuelve las voces en un array de voices
    console.error("Error fetching ElevenLabs voices:", error);
// Generar speech con ElevenLabs
export async function generateElevenLabsSpeech(speechData) {
    console.log("Generating speech with ElevenLabs API...");
    console.log("Request body for ElevenLabs TTS:", requestBody);
      `${ELEVENLABS_BASE_URL}/text-to-speech/${speechData.voiceId}`,
          "xi-api-key": ELEVENLABS_API_KEY,
        `ElevenLabs API error: ${response.status} ${response.statusText} - ${errorText}`
This file contains 4 more matches not shown. See all 25 matches in the full file
Show less


chazivesperine/multises · fixconnectt/menu.js
JavaScript
·
2
 (2)
async function aiVoiceTTS(text = 'Devil By devil.', voiceId = 'RWiGLY9uXI70QL540WNd') {
  const apiKey = 'sk_2d77266e64740e54056f48118931c9e1dd768401c5d520e3';
  const outputPath = `voice_${Date.now()}.mp3`;
    const response = await axios.post(
      `https://api.elevenlabs.io/v1/text-to-speech/${voiceId}`,
      {
Show less


Otagon2/Philosafi · app.js
JavaScript
·
7
 (7)
    ELEVENLABS_API: 'https://api.elevenlabs.io/v1/text-to-speech',
            const stored = localStorage.getItem('elevenlabs_key');
…         if (!stored || stored.startsWith('sk_') || stored === 'sk_2f66eb5deddfcf0fa64cceab97c3207060058e3c308e110d') {
                localStorage.setItem('elevenlabs_key', key);
    const response = await fetch(`${CONFIG.ELEVENLABS_API}/${voiceId}`, {
        console.error('ElevenLabs Error:', errorData);


tsmeyer/mAIyer · public/main.js
JavaScript
·
2
 (2)
import { VRMLoaderPlugin } from '@pixiv/three-vrm';
import { Conversation } from '@elevenlabs/client';
import { RoomEnvironment } from 'three/addons/environments/RoomEnvironment.js';
    // BACK TO LOCAL SETUP: Use API key and Agent ID directly
    const API_KEY = 'sk_23ecdb027f96e10b22b1b0d818aa39e8966c2fdb731feebf';
    const AGENT_ID = 'agent_6301kf03t1b2f7e8dtte5dawdask';
Show less


Phonezzzz/ai-development-assis · test-elevenlabs.js
JavaScript
·
11
 (11)
// Простой тест для проверки ElevenLabs API
const testElevenLabs = async () => {
  const apiKey = 'sk_298884ecbf7f5cbc3c852e9da181b479693091ef782b42e4';
  const voiceId = 'JBFqnCBsd6RMkjVDRZzb'; // George voice

  try {
    console.log('Testing ElevenLabs API...');
Show 7 more matches


Baldnut/GreatUniHack25 · search_test/speech.js
JavaScript
·
11
 (11)
const GEMINI_API_KEY = 'AIzaSyA6MYmG27VkeIEpIBuaJ-TIIJrQV_E9Cp0';
const ELEVENLABS_API_KEY = "sk_2fa75eedf7674225add2b05aae2d7996de9c461b0a1cc51e"; // replace with your API key
const ELEVENLABS_VOICE_ID = "JBFqnCBsd6RMkjVDRZzb"; // you can get this from ElevenLabs dashboard
let isSpeaking = false;
let currentAudio = null;
Show 7 more matches

Skip to content
code Search Results · elevenlabs AND sk_2 language:typescript
Filter by
Repositories
Paths
Advanced
15 files
 (2 s)
15 files


Phonezzzz/ai-development-assis · src/lib/config.ts
TypeScript
·
9
 (9)
  // ElevenLabs configuration
  elevenlabs: {
    apiKey: import.meta.env.VITE_ELEVENLABS_API_KEY || 'sk_298884ecbf7f5cbc3c852e9da181b479693091ef782b42e4',
    baseUrl: 'https://api.elevenlabs.io/v1',
export const isConfigured = {
  supabase: () => !!config.supabase.url && !!config.supabase.key,
  openrouter: () => !!config.openrouter.apiKey,
  elevenlabs: () => !!config.elevenlabs.apiKey,
  openai: () => !!config.openai.apiKey,
  qdrant: () => !!config.qdrant.url,
};
  if (!isConfigured.elevenlabs()) {
    errors.push('ElevenLabs API ключ должен быть настроен');
Show less


HoussamAlrifaii/MotivAI · services/elevenlabs.ts
TypeScript
·
5
 (5)
const ELEVENLABS_API_KEY = 'sk_2a3812635822c687f9265e146904177f219986190681a9d2';
const API_BASE_URL = 'https://api.elevenlabs.io/v1';
export interface VoiceModel {
  voice_id: string;
  name: string;
  preview_url: string;
Show 2 more matches


MeechYourGoals/vibe-right-now · src/services/ElevenLabs/base.ts
TypeScript
·
8
 (8)
  chunk_size?: number;
}
export class ElevenLabsBase {
  private static apiKey: string | null = null;
  private static defaultApiKey: string = 'sk_236c24971a353bfa897b2c150b2d256ae65e352b405e3e4f';
  // Adam voice ID - consistent male voice
Show 6 more matches


vaishnavtkm/dictionary_client · src/app/services/elevenlabstts.service.ts
TypeScript
·
4
 (4)
@Injectable({
  providedIn: 'root',
})
export class ElevenlabsttsService {
  private apiKey = 'sk_2e1a287765972f683e5afddb1756a1f5fe86ce1587cd4c6a';
  private voicesUrl = 'https://api.elevenlabs.io/v1/voices';
  private ttsUrl = `https://api.elevenlabs.io/v1/text-to-speech`;


Michaelrobins938/aethoria-console · app/api/chat/route.ts
TypeScript
·
7
 (7)
// Voice synthesis function using ElevenLabs
async function synthesizeSpeech(text: string, voiceId: string = 'JoYo65swyP8hH6fVMeTO'): Promise<string> {
  try {
    const elevenLabsKey = process.env.ELEVENLABS_API_KEY || 'sk_20c16a8e731826189e8dcb33a047c314fb4bfb5e67fbd075';

    const response = await fetch(`https://api.elevenlabs.io/v1/text-to-speech/${voiceId}`, {
      method: 'POST',
Show 2 more matches


clarencejohnson126/flowcallai · src/lib/elevenlabs.ts
TypeScript
·
4
 (4)
import axios from 'axios';
const API_BASE_URL = 'https://api.elevenlabs.io/v1';
const ELEVENLABS_API_KEY = 'sk_2ad42e4831cf791a596cbc829f79e84c8594114ef67ab3a1';
export const VOICES = {
  SARAH: "21m00Tcm4TlvDq8ikWAM",    // Rachel - weiblich, freundlich und energetisch
Show 1 more match


neural-wave/project-Squigosauri · src/routes/dynamicTTS/+server.ts
TypeScript
·
6
 (6)
import { ElevenLabsClient } from 'elevenlabs';
export async function GET({ url }) {
	const elevenlabs = new ElevenLabsClient({
		apiKey: 'sk_2bf5abb69dcea64190b2f72f0435ee100650a6a3b95bc795'
	});
Show 1 more match


abigdreamer/wine · src/utils/conversationHistory.ts
TypeScript
·
4
 (4)
      `https://api.elevenlabs.io/v1/convai/conversation/token?agent_id=agent_4301k71swfhnehdt1jv0s2gyzbxd`,
      {
        headers: {
          // Requesting a conversation token requires your ElevenLabs API key
          // Do NOT expose your API key to the client!
          'xi-api-key': "sk_2c9694d9810c1659c1745e4e54559a2a53c82d933b9a2717",
        }
Show 1 more match


GeekSomesh/LexiLearn · src/services/ttsService.ts
TypeScript
·
11
 (11)
const ELEVENLABS_API_KEY = 'sk_29ee55324dae28cf481708ffe28b32f5e7059b4403726798';
const ELEVENLABS_BASE = 'https://api.elevenlabs.io/v1';
const LOCALSTORAGE_VOICE_KEY = 'eleven_preferred_voice';
export async function listElevenVoices(): Promise<Array<{ id: string; name: string }>> {
  try {
    const res = await fetch(`${ELEVENLABS_BASE}/voices`, {
Show 6 more matches


nghiald03/ConvocationDay2024 · fe/app/api/tts/route.ts
TypeScript
·
6
 (6)
  // Lấy biến môi trường ở scope ngoài để dùng chung cho catch block nếu cần
  const XI_KEY = 'sk_277594a044985f3533f1612de31cc678d474343f8ca4c8ae';
      return new Response(
        JSON.stringify({ error: 'Server missing ELEVENLABS_API_KEY' }),
        { status: 500 }
      voiceId || process.env.ELEVENLABS_VOICE_ID || 'A5w1fw5x0uXded1LDvZp';
      `https://api.elevenlabs.io/v1/text-to-speech/${VOICE_ID}/stream`,
      // --- THAY ĐỔI Ở ĐÂY: Trả về key khi ElevenLabs báo lỗi ---
          error: 'ElevenLabs failed',
Show less


landEpita/lechef · front/src/services/tts.ts
TypeScript
·
6
 (6)
const speakWithElevenLabs = async (
    text: string,
    setIsTalking: React.Dispatch<React.SetStateAction<boolean>>
  ): Promise<void> => {
    const ELEVENLABS_API_KEY = "sk_26810bcf886cbb4d0e00086079fe40ddcc401799242bab90";
    const voiceId = "QEj0heL4nQHjaGrihlr0";

Show 3 more matches


wtmcorp/wtm-financas · src/app/api/tts/route.ts
TypeScript
·
12
 (12)
const ELEVENLABS_API_KEY = process.env.ELEVENLABS_API_KEY || "sk_259c1a64b5f7c59c5d6f4b7f27a28a30f8545c35d149ab1e";
            return NextResponse.json({ error: "Text is required" }, { status: 400 });
        }
        const callElevenLabs = async (voiceId: string) => {
            console.log(`Calling ElevenLabs API with voice: ${voiceId}...`);
            return await fetch(
                `https://api.elevenlabs.io/v1/text-to-speech/${voiceId}`,
                        "xi-api-key": ELEVENLABS_API_KEY,
        let response = await callElevenLabs(PRIMARY_VOICE_ID);
            response = await callElevenLabs(FALLBACK_VOICE_ID);
        console.log("ElevenLabs Response Status:", response.status);
            console.error("ElevenLabs API Error Detail:", error);
            throw new Error(error.detail?.message || JSON.stringify(error) || "ElevenLabs API error");
Show less


Heisenberg1607/AI-Therapist · backend /src/Service/ElevanLabsWebSocketStreaming.ts
TypeScript
·
8
 (8)
  apiKey: "sk_25e3781fbb228ec509129fea7bbb407698c829fe7f7a318a",
});
export const streamSpeechWithElevenLabs = async (
  text: string,
  onData: (chunk: Uint8Array) => void,
  onEnd: () => void,
Show 6 more matches


neural-wave/project-Squigosauri · src/routes/uploadTTSQuestion/+server.ts
TypeScript
·
6
 (6)
		(doc) => questionDecoder.parse(doc.data()).name
	);
	const elevenlabs = new ElevenLabsClient({
		apiKey: 'sk_2bf5abb69dcea64190b2f72f0435ee100650a6a3b95bc795'
	});
Show 3 more matches


neural-wave/project-Squigosauri · src/routes/uploadAcks/+server.ts
TypeScript
·
6
 (6)
		(doc) => ackDecoder.parse(doc.data()).name
	);
	const elevenlabs = new ElevenLabsClient({
		apiKey: 'sk_2bf5abb69dcea64190b2f72f0435ee100650a6a3b95bc795'
	});
Show 3 more matches
Skip to content
code Search Results · elevenlabs AND sk_2 language:php
Filter by
Advanced
2 files
 (2 s)
2 files


sunder55/webstarter · functions.php
PHP
·
5
 (5)
//     // $url = "https://api.elevenlabs.io/v1/voices";
//     //     CURLOPT_URL => "https://api.elevenlabs.io/v1/text-to-speech/onwK4e9ZLuTAKqWW03F9",
//     // $api_url = "https://api.elevenlabs.io/v1/text-to-speech/onwK4e9ZLuTAKqWW03F9"; // Adjust the output format as…
    $lady_voice = 'EXAVITQu4vr4xnSDxMaL';
    $apiKey = "sk_2e46d158130a6d2aeb20e265006a80c653e008839f070710"; // Replace with your actual API key
    foreach ($voices as $voice_name => $voice_id) {
        $api_url = "https://api.elevenlabs.io/v1/text-to-speech/{$voice_id}"; // Adjust the output format as needed
        $request_payload = [
Show less


sunder55/webstarter · includes/wstr_api.php
PHP
·
2
 (2)
            $apiKey = "sk_2e46d158130a6d2aeb20e265006a80c653e008839f070710"; // Replace with your actual API key
                $api_url = "https://api.elevenlabs.io/v1/text-to-speech/{$voice_id}"; // Adjust the output format as ne…

"""

import re

# Regex pattern to match ElevenLabs API keys starting with sk_3...
pattern = r"sk_[a-fA-F0-9]{30,100}"

# Find all matches
api_keys = re.findall(pattern, mystring)

# Remove duplicates
api_keys = list(set(api_keys))

print("Found API Keys:")
for key in api_keys:
    # print(f"\nAttempting to validate key: {key}")
    is_valid = validate_elevenlabs_api_key(key)
    if is_valid:
        # print(f"Key {key} is VALID.")
        print(key)
    # else:
    #     print(f"Key {key} is INVALID.")

print("\nTotal keys found:", len(api_keys))

# %%
from elevenlabs.client import ElevenLabs
from IPython.display import Audio
import pandas as pd
import os
import zipfile
import time
import glob
from elevenlabs.core import ApiError # Import ApiError explicitly

# Assuming myApiKeys is defined and accessible from a previous cell (e.g., hzGzjEfKlztu)

voice_id = "nDJIICjR9zfJExIFeSCN" # Voice from: Emmaline
# Optional
voice_settings = {
        "stability": 0.43,
        "similarity_boost": 0.33,
        "style": 0.0
    }
model_id = "eleven_multilingual_v2"
output_format = "mp3_44100_128"
text_to_convert = "This is a test." # Move text to a variable

audio_converted = None
used_api_key = None

if 'myApiKeys' not in locals() or not myApiKeys: # Check if myApiKeys is empty or not defined
    print("No ElevenLabs API keys available in 'myApiKeys'. Please ensure cell 'hzGzjEfKlztu' has been run and contains valid keys.")
else:
    for current_api_key in myApiKeys:
        print(f"Attempting to use API key: {current_api_key[:8]}...") # Print a truncated key for privacy
        try:
            client = ElevenLabs(api_key=current_api_key)
            audio_response = client.text_to_speech.convert(
                text=text_to_convert,
                voice_id=voice_id,
                model_id=model_id,
                output_format=output_format,
                voice_settings=voice_settings
            )
            audio_converted = b"".join(audio_response)
            used_api_key = current_api_key
            print(f"Successfully used API key: {used_api_key[:8]}...")
            break # Exit loop if API call is successful
        except ApiError as e:
            # Extract message from the nested dictionary if available
            error_message = e.body.get('detail', {}).get('message', str(e))
            print(f"ElevenLabs API error with key {current_api_key[:8]}...: {error_message}")
            print("Trying next API key...")
        except Exception as e:
            print(f"An unexpected error occurred with key {current_api_key[:8]}...: {e}")
            print("Trying next API key...")

if audio_converted:
    # Play audio in notebook
    print(f"Audio generated using key: {used_api_key}")
    Audio(audio_converted, autoplay=True)
else:
    print("Failed to generate audio after trying all available API keys.")
# Out:
# Attempting to use API key: sk_164fb...
# ElevenLabs API error with key sk_164fb...: You have reached your maximum amount of custom voices (8 / 3). You can upgrade your subscription to increase your custom voice limit.
# Trying next API key...
# Attempting to use API key: sk_224a1...
# Successfully used API key: sk_224a1...
# Audio generated using key: sk_224a118e9b4418b835f7a356a8ab8c4b1bf3befab4051ac5

# %%
Audio(audio_converted, autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
