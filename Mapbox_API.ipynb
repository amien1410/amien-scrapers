# %%
# !pip install mapbox
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 kB 11.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.5/14.5 MB 58.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 7.4 MB/s eta 0:00:00
# ...

# %%
import os
import re
from mapbox import Geocoder

# TOKEN = "pk.eyJ1Ijoic3BpY3ljaGFpciIsImEiOiJja2Y4b2RpemwwZTVrMnJxZzJmeXoxMHA5In0.7DxKkZ9CCFER4n-PkAooHQ"

def test_mapbox_token(token):
    geocoder = Geocoder(access_token=token)
    response = geocoder.forward("Medan, Indonesia")
    if response.status_code != 200:
        # print("❌ Request failed — status:", response.status_code)
        # print("Response content:", response.content)
        return False

    data = response.json()
    if "features" in data and len(data["features"]) > 0:
        # first = data["features"][0]
        # print("✅ Token works! Sample result:")
        # print(" Place name:", first.get("place_name"))
        # print(" Coordinates:", first.get("center"))
        return True
    else:
        # print("⚠️ No features returned:", data)
        return False

def find_tokens(text):
    pattern = r"pk\.[A-Za-z0-9_\-]+\.[A-Za-z0-9_\-]+"
    tokens = re.findall(pattern, text)
    return set(list(tokens))

# %%
import time

myText = r"""
put your text here
"""

tokens = find_tokens(myText)
print(f"Found {len(tokens)} tokens")

for token in tokens:
    is_valid = test_mapbox_token(token)
    if is_valid:
        print(token)
    time.sleep(1)
# Out:
# Found 15 tokens
# pk.eyJ1Ijoia2F6dWtpMjIiLCJhIjoiY21ibWh3M2Z5MWQzODJyb2kzcTl4enJzNyJ9.YF09n4kZzhFER42CF9g--g
# pk.eyJ1Ijoia2hhdGFiMTIiLCJhIjoiY2xrYjFldDMxMGJidzNlcW81Z2NkMTNldSJ9.m6W03uCePI2N8Ay6fQ6VzQ
# pk.eyJ1Ijoia2lydGkwMSIsImEiOiJjbHJ3YWtpZmExMWdvMmltdWs2OXZianljIn0.ClbfxfD7flO7wbiKs0fP4A
# pk.eyJ1Ijoia2FuaXNoa3NvZ2FuaSIsImEiOiJjbWZtY2VianYwMGlrMmpzZmJ4MWhkZnhoIn0.1EO2A88s7KAsTut1uDaQQg
# pk.eyJ1Ijoia2F0bGVnb3BoYXNoYSIsImEiOiJjbTlpOTdzbmYwMGNsMmpzYWJtZzN4d3pqIn0.Zt-aSMEoahrV3zkiVVHbOw
# pk.eyJ1Ijoia2hhbGlkLXNheXllZCIsImEiOiJjbG95MDk3MWUxamdkMmpxZXE2NDJ4cHZuIn0.7CEQAUH56r7BTz46f5SnUw
# pk.eyJ1Ijoia2V2c3luZHJvbWUiLCJhIjoiY21icDVoNGtuMDB5dDJ2cTU4bms0aWttcCJ9.lW4Mf_0RgTSdhTpTCbC8MQ
# pk.eyJ1Ijoia2VqZGkxMSIsImEiOiJjbGp3b2czZ3UwdGx6M3VuMXRvbjF3OWVtIn0.ew4wW4Ab6CDcxyk9FycH8g
# pk.eyJ1Ijoia291aWRldiIsImEiOiJjbHB2ODBmamcwMnc1MmtrN3djMTRpb3I4In0.F4sguU3q6u3yKOXDLfP-rg
# pk.eyJ1Ijoia2lya2xhbmR3YXRlcmJvdCIsImEiOiJjbTY3YzA5bXYwMWlwMmtvZ2V5OTNpYTBlIn0.eQH5_U0kjIVYq-a64S3xwQ

# %%
# https://github.com/search?q=mapbox+AND+pk.eyJ1Ijoia2+language%3Adotenv&type=code&p=5
