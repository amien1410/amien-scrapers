# %% [markdown]
# <a href="https://colab.research.google.com/github/amien1410/amien-scrapers/blob/main/checkchildcare_scraper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime

# %%
url = "https://checkchildcare.com/Daycare/Index/001t0000007q98sAAA"
res = requests.get(url)
soup = BeautifulSoup(res.content, "html.parser")
soup

# %%
data = {}

# --- 1. Daycare Title/Name ---
title_tag = soup.select_one(".daycare-title")
data["daycare_title"] = title_tag.get_text(strip=True) if title_tag else None

# --- 2. Address ---
addr_tag = soup.select_one(".contact-item .fa-location-dot ~ .contact-content span")
data["address"] = addr_tag.get_text(strip=True) if addr_tag else None

# --- 3. Last Update (convert to date format) ---
update_tag = soup.find("span", string=lambda t: t and "Updated:" in t)
if not update_tag:
    update_tag = soup.select_one(".fa-calendar-check")  # backup
last_update = None
if update_tag:
    text = update_tag.parent.get_text(strip=True).replace("Updated:", "").strip()
    try:
        last_update = datetime.strptime(text, "%b %d, %Y").strftime("%Y-%m-%d")
    except ValueError:
        last_update = text
data["last_update"] = last_update

# --- 4. License Status ---
license_tag = soup.find("span", string=lambda t: t and "License:" in t)
if not license_tag:
    license_tag = soup.select_one(".fa-certificate")  # backup
license_text = None
if license_tag:
    license_text = license_tag.parent.get_text(strip=True).replace("License:", "").strip()
data["license"] = license_text

# --- 5. Inspections (list of dicts + url) ---
inspections = []
for row in soup.select("#inspectionstbl tbody tr"):
    cols = row.find_all("td")
    if len(cols) >= 3:
        # Extract the inspection link (if available)
        url_tag = row.select_one("a.btn-outline-primary")
        url = url_tag["href"] if url_tag and url_tag.has_attr("href") else None
        # Clean date
        date_text = cols[0].get_text(strip=True)
        try:
            date_iso = datetime.strptime(date_text, "%b %d, %Y").strftime("%Y-%m-%d")
        except ValueError:
            date_iso = date_text
        inspections.append({
            "date": date_iso,
            "risk_level": cols[1].get_text(strip=True),
            "observation": cols[2].get_text(" ", strip=True),
            "url": url
        })
data["inspections"] = inspections

# --- 6. Complaints (list or empty) ---
complaints_section = soup.select_one("#complaintstbl")
complaints = []
if complaints_section:
    rows = complaints_section.select("tbody tr")
    if not rows:
        text = complaints_section.get_text(strip=True)
        if "No provider complaints" in text:
            complaints = []
        else:
            complaints = [text]
    else:
        for row in rows:
            complaints.append(row.get_text(strip=True))
data["complaints"] = complaints

# --- 7. Program Information ---
program_info = {}
for item in soup.select("#programinfo .info-item"):
    label = item.select_one(".info-label")
    value = item.select_one(".info-value")
    if label and value:
        program_info[label.get_text(strip=True)] = value.get_text(strip=True)
data["program_information"] = program_info

# --- 8. Contact Information ---
contact_info = {}

for item in soup.select(".contact-card .contact-item"):
    label_tag = item.select_one("h5")
    value_tag = item.select_one("a, span")

    if label_tag and value_tag:
        key = label_tag.get_text(strip=True)

        # If Cloudflare-protected email is found
        cf_tag = value_tag.select_one("span.__cf_email__")
        if cf_tag and cf_tag.has_attr("data-cfemail"):
            encoded = cf_tag["data-cfemail"]
            value = decode_cfemail(encoded)
        else:
            value = value_tag.get_text(strip=True)

        contact_info[key] = value
data["contact_information"] = contact_info
data
# Out:
# {'daycare_title': 'Lil Peoples Bellevue – Infant Building',
#  'address': None,
#  'last_update': '2025-09-16',
#  'license': 'Open',
#  'inspections': [{'date': '2024-09-13',
#    'risk_level': 'Serious',
#    'observation': '110-300-0106(12) – It was observed that three staff members had expired Food Handler Permits. 110-30 ... Read More',
#    'url': '/Inspection/Index/18239/Lil%20Peoples%20Bellevue%20%E2%80%93%20Infant%20Building'},
#   {'date': '2024-09-13',
#    'risk_level': 'Serious',
#    'observation': '110-300-0260(1)(a) - The laundry detergent was observed stored under the sink in the bathroom. This ... Read More',
#    'url': '/Inspection/Index/18242/Lil%20Peoples%20Bellevue%20%E2%80%93%20Infant%20Building'},
#   {'date': '2024-09-13',
#    'risk_level': 'Serious',
#    'observation': 'The tree house on the playground was observed to be installed directly on open earth, without the re ... Read More',
#    'url': '/Inspection/Index/18240/Lil%20Peoples%20Bellevue%20%E2%80%93%20Infant%20Building'},
#   {'date': '2023-06-21',
#    'risk_level': 'Serious',
#    'observation': 'Ana needs a food handlers card.',
#    'url': '/Inspection/Index/18243/Lil%20Peoples%20Bellevue%20%E2%80%93%20Infant%20Building'},
#   {'date': '2019-11-19',
#    'risk_level': 'Immediate',
#    'observation': 'Carpet in Hidden Meadow is worn, soiled and not easily cleanable and should be replaced. Carpet text ... Read More',
#    'url': '/Inspection/Index/18247/Lil%20Peoples%20Bellevue%20%E2%80%93%20Infant%20Building'},
#   {'date': '2019-11-19',
#    'risk_level': 'Immediate',
#    'observation': 'Diaper changing mat in Whisper Creek needs to be replaced due to stains and marks.',
#    'url': '/Inspection/Index/18244/Lil%20Peoples%20Bellevue%20%E2%80%93%20Infant%20Building'},
#   {'date': '2019-11-19',
#    'risk_level': 'Immediate',
#    'observation': 'Document monthly carbon monoxide and smoke detector testing. Correction Correction',
#    'url': '/Inspection/Index/18245/Lil%20Peoples%20Bellevue%20%E2%80%93%20Infant%20Building'},
#   {'date': '2019-11-19',
#    'risk_level': 'Immediate',
#    'observation': 'Quarterly earthquake/disaster drill not documented.',
#    'url': '/Inspection/Index/18246/Lil%20Peoples%20Bellevue%20%E2%80%93%20Infant%20Building'}],
#  'complaints': [],
#  'program_information': {'License Number': 'PL-7949',
#   'Ages Served': '1 month - 2 years 6 months',
#   'Provider Type': 'Child Care Center',
#   'Days of Operation': 'Monday,Tuesday,Wednesday,Thursday,Friday',
#   'Hours of Operation': '7:30 AM - 5:30 PM,7:30 AM - 5:30 PM,7:30 AM - 5:30 PM,7:30 AM - 5:30 PM,7:30 AM - 5:30 PM',
#   'Accepts Subsidy': 'Yes'},
#  'contact_information': {'Address': '14205 SE 8th St, Bellevue, WA 98007, USA',
#   'Phone': '4257479056',
#   'Email': 'bellevue@lilpeoplesworld.com',
#   'Website': 'lilpeoplesworld.com'}}

# %%
def decode_cfemail(encoded_hex: str) -> str:
    # First byte is the key
    key = int(encoded_hex[:2], 16)
    # Decode every subsequent pair of hex digits
    email = ''.join(
        chr(int(encoded_hex[i:i+2], 16) ^ key)
        for i in range(2, len(encoded_hex), 2)
    )
    return email

# Example from your HTML:
encoded = "49282b3b286733202722092e24282025672a2624"
decoded_email = decode_cfemail(encoded)
print(decoded_email)
# Out:
# abra.zink@gmail.com

# %%
url2 = "https://checkchildcare.com/Inspection/Index/18239/Lil%20Peoples%20Bellevue%20%E2%80%93%20Infant%20Building"
res = requests.get(url2)
soup = BeautifulSoup(res.content, "html.parser")
soup

# %%
inspection_data = {}

# Loop through all rows that have labels and values
for row in soup.select(".detail-info-card .info-row"):
    label_tag = row.select_one(".detail-label")
    value_tag = row.select_one(".detail-value")
    if label_tag and value_tag:
        label = label_tag.get_text(strip=True)
        # Get the text inside, even if nested in span or badge
        value = value_tag.get_text(strip=True)
        inspection_data[label] = value

# Capture official document link
doc_link = soup.select_one(".detail-info-card .document-link")
if doc_link and doc_link.has_attr("href"):
    inspection_data["Official Document"] = doc_link["href"]

# Output the structured data
inspection_data
# Out:
# {'Observation': '110-300-0106(12) – It was observed that three staff members had expired Food Handler Permits. 110-300-0106(8) – It was observed that three staff members had expired Safe Sleep training.',
#  'Risk Level': 'Serious',
#  'Inspection Date': 'Sep 13, 2024',
#  'Correction Date': '',
#  'Disputed': '',
#  'Official Document': 'https://wa-del.my.salesforce.com/sfc/p/t00000008aPL/a/cs000005xtC6/crvMH4xpH5takBLTNpLn.eNB4EZYdRtv3mlAl6BcP0M'}

# %%
url3 = "https://checkchildcare.com/Search/UnifiedSearch?SearchText=Seattle,WA&Type=locationSearch&Page=2&ComplaintFilter=All&InspectionFilter=All&LicenseStatusFilter=All"
res = requests.get(url3)
soup = BeautifulSoup(res.content, "html.parser")
soup

# %%
url3 = "https://checkchildcare.com/Search/UnifiedSearch?SearchText=Seattle,WA&Type=locationSearch&Page=2&ComplaintFilter=All&InspectionFilter=All&LicenseStatusFilter=All"
res = requests.get(url3)
soup = BeautifulSoup(res.content, "html.parser")
providers_data = []

# Loop through all provider items
for item in soup.select(".provider-list-item"):
    provider = {}

    # Basic info
    name_tag = item.select_one(".provider-name a")
    address_tag = item.select_one(".provider-address")
    detail_link_tag = item.select_one(".text-end a.btn")

    provider["Name"] = name_tag.get_text(strip=True) if name_tag else None
    provider["Address"] = address_tag.get_text(strip=True) if address_tag else None
    provider["Details URL"] = (
        name_tag["href"] if name_tag and name_tag.has_attr("href") else None
    )

    # Extract provider info rows (like Early Achiever, License Status)
    for info_row in item.select(".provider-info-row"):
        label = info_row.select_one(".provider-info-label")
        value = info_row.select_one(".provider-info-value")
        if label and value:
            provider[label.get_text(strip=True)] = value.get_text(strip=True)

    # Extract complaints and inspection data
    for concern in item.select(".concerns-row"):
        concern_type = concern.select_one(".concerns-label a")
        if concern_type:
            section_title = concern_type.get_text(strip=True).replace(":", "")
            stats = {
                badge.get_text(strip=True).split(":")[0]:
                badge.get_text(strip=True).split(":")[1].strip()
                for badge in concern.select(".status-badge")
                if ":" in badge.get_text()
            }
            provider[section_title] = stats

    providers_data.append(provider)

# --- OUTPUT RESULTS ---
for p in providers_data:
    print(p)
    print("-" * 100)
# Out:
# {'Name': 'Queen Anne Community Center (Queen Anne Community Center)', 'Address': '1901 1st Ave W, Seattle, WA 98119, USA', 'Details URL': '/Daycare/Index/001t0000007qHuVAAU', 'Early Achiever:': 'Not Enrolled', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '2', 'Short': '1', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Yousuf Rukia (Suhaima childcare)', 'Address': 'Seattle, WA 98108, USA', 'Details URL': '/Daycare/Index/0018y000007NFCQAA4', 'Early Achiever:': 'Quality Level 3', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Rainier Community Center (Rainier Community Center SAC)', 'Address': '4600 38th Ave. S, Seattle, WA 98118, USA', 'Details URL': '/Daycare/Index/001t0000007qHuWAAU', 'Early Achiever:': 'Not Enrolled', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '1', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Afrah Fardowso A (RAYAN CHILDCARE LLC)', 'Address': '8517 S 119th St, Seattle, WA 98178, USA', 'Details URL': '/Daycare/Index/0018y0000049rhOAAQ', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '8', 'Short': '14', 'Long': '6'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Bakari Zahra (Kismaya Childcare LLC)', 'Address': 'Seattle, WA 98126, USA', 'Details URL': '/Daycare/Index/0018y0000049suuAAA', 'Early Achiever:': 'Quality Level 3', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Cortado Karie (Full STEAM Ahead)', 'Address': 'Seattle, WA 98117, USA', 'Details URL': '/Daycare/Index/0018y000004BHKGAA4', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '2', 'Short': '2', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': "Ali Hamdi (HAMDI'S CHILDCARE LLC)", 'Address': '6808 30th Ave S, Seattle, WA 98108, USA', 'Details URL': '/Daycare/Index/0018y000004c0gLAAQ', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '1', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'The Goldfinch School (The Goldfinch School)', 'Address': '4774 35th Ave NE, Seattle, WA 98105, USA', 'Details URL': '/Daycare/Index/0018y000004ClfcAAC', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '1', 'Short': '1', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Farah Ubah (Sagal Family Childcare)', 'Address': 'Seattle, WA 98118, USA', 'Details URL': '/Daycare/Index/0018y000004cprCAAQ', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '1', 'Short': '1', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Sanchez Lira Mirna (La Casita Bilingual School LLC)', 'Address': 'Seattle, WA 98178, USA', 'Details URL': '/Daycare/Index/0018y000004cTojAAE', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '3', 'Short': '3', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Ibrahim Amran Ali (Amran early learning program)', 'Address': 'Seattle, WA 98118, USA', 'Details URL': '/Daycare/Index/0018y000004eueCAAQ', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '1', 'Short': '1', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Mohamed Amran (Farhiya Childcare)', 'Address': 'Seattle, WA 98108, USA', 'Details URL': '/Daycare/Index/0018y000004EY2AAAW', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Fremont Community School (Child Care Center)', 'Address': '1408 N 36th St, Seattle, WA 98103, USA', 'Details URL': '/Daycare/Index/0018y000004mtFoAAI', 'Early Achiever:': 'Not Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '1', 'Short': '0', 'Long': '1'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Ali Amina Saleban (MOONLIGHT CHILDCARE LLC)', 'Address': 'Seattle, WA 98188, USA', 'Details URL': '/Daycare/Index/0018y000004QKoFAAW', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '1', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '10', 'Short': '17', 'Long': '7'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Crissey Soraya (KRe8 club)', 'Address': 'Seattle, WA 98115, USA', 'Details URL': '/Daycare/Index/0018y000004qRyMAAU', 'Early Achiever:': 'Not Participating', 'License Status:': 'Pending', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------

# %%
import time

BASE_URL = "https://checkchildcare.com/Search/UnifiedSearch"
params = {
    "SearchText": "Seattle,WA",
    "Type": "locationSearch",
    "ComplaintFilter": "All",
    "InspectionFilter": "All",
    "LicenseStatusFilter": "All",
}

providers_data = []
page = 1

while True:
    print(f"Scraping page {page}...")
    params["Page"] = page

    res = requests.get(BASE_URL, params=params)
    if res.status_code != 200:
        print(f"⚠️ Request failed on page {page} (status {res.status_code})")
        break

    soup = BeautifulSoup(res.content, "html.parser")
    items = soup.select(".provider-list-item")

    if not items:
        print("✅ No more provider data found — scraping complete.")
        break

    for item in items:
        provider = {}

        # Basic info
        name_tag = item.select_one(".provider-name a")
        address_tag = item.select_one(".provider-address")

        provider["Name"] = name_tag.get_text(strip=True) if name_tag else None
        provider["Address"] = address_tag.get_text(strip=True) if address_tag else None
        provider["Details URL"] = (
            name_tag["href"] if name_tag and name_tag.has_attr("href") else None
        )

        # Extract provider info rows (like Early Achiever, License Status)
        for info_row in item.select(".provider-info-row"):
            label = info_row.select_one(".provider-info-label")
            value = info_row.select_one(".provider-info-value")
            if label and value:
                provider[label.get_text(strip=True)] = value.get_text(strip=True)

        # Extract complaints and inspection data
        for concern in item.select(".concerns-row"):
            concern_type = concern.select_one(".concerns-label a")
            if concern_type:
                section_title = concern_type.get_text(strip=True).replace(":", "")
                stats = {
                    badge.get_text(strip=True).split(":")[0]:
                    badge.get_text(strip=True).split(":")[1].strip()
                    for badge in concern.select(".status-badge")
                    if ":" in badge.get_text()
                }
                provider[section_title] = stats

        providers_data.append(provider)

    # Wait a bit to avoid hammering the server
    time.sleep(1)
    page += 1

print(f"\n✅ Total providers scraped: {len(providers_data)}\n")

# --- OUTPUT RESULTS ---
for p in providers_data:
    print(p)
    print("-" * 100)
# Out:
# Scraping page 1...
# Scraping page 2...
# Scraping page 3...
# Scraping page 4...
# Scraping page 5...
# Scraping page 6...
# Scraping page 7...
# Scraping page 8...
# Scraping page 9...
# Scraping page 10...
# Scraping page 11...
# Scraping page 12...
# Scraping page 13...
# Scraping page 14...
# Scraping page 15...
# Scraping page 16...
# Scraping page 17...
# Scraping page 18...
# Scraping page 19...
# Scraping page 20...
# Scraping page 21...
# Scraping page 22...
# Scraping page 23...
# Scraping page 24...
# Scraping page 25...
# Scraping page 26...
# Scraping page 27...
# Scraping page 28...
# Scraping page 29...
# Scraping page 30...
# Scraping page 31...
# Scraping page 32...
# Scraping page 33...
# Scraping page 34...
# Scraping page 35...
# Scraping page 36...
# Scraping page 37...
# Scraping page 38...
# Scraping page 39...
# Scraping page 40...
# Scraping page 41...
# Scraping page 42...
# Scraping page 43...
# Scraping page 44...
# Scraping page 45...
# Scraping page 46...
# Scraping page 47...
# Scraping page 48...
# Scraping page 49...
# Scraping page 50...
# Scraping page 51...
# Scraping page 52...
# Scraping page 53...
# Scraping page 54...
# Scraping page 55...
# Scraping page 56...
# Scraping page 57...
# Scraping page 58...
# Scraping page 59...
# Scraping page 60...
# Scraping page 61...
# Scraping page 62...
# Scraping page 63...
# Scraping page 64...
# Scraping page 65...
# Scraping page 66...
# Scraping page 67...
# Scraping page 68...
# Scraping page 69...
# Scraping page 70...
# Scraping page 71...
# ✅ No more provider data found — scraping complete.
#
# ✅ Total providers scraped: 1037
#
# {'Name': 'Alemu Aster (Pacific NW Kids LLC)', 'Address': 'Seattle, WA 98188, USA', 'Details URL': '/Daycare/Index/0018y000002aeTtAAI', 'Early Achiever:': 'Not Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Jami Nesra (Jami Childcare)', 'Address': 'Seattle, WA 98108, USA', 'Details URL': '/Daycare/Index/0018y000002KcOLAA0', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'West Seattle Montessori School  Building 2', 'Address': '11220 16th Ave SW, Seattle, WA 98146, USA', 'Details URL': '/Daycare/Index/0018y000002LbqYAAS', 'Early Achiever:': 'Not Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': "Hilltop Children's Center at Fremont (Seattle Institute for Early Child Development)", 'Address': '3601 Fremont Ave N Suite 200, Seattle, WA 98103, USA', 'Details URL': '/Daycare/Index/0018y000002LIKyAAO', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '1'}, 'Inspections': {'Immediate': '0', 'Serious': '2', 'Short': '3', 'Long': '2'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Sheik-Mohamud Deqo (Tasliim Daycare)', 'Address': 'Seattle, WA 98108, USA', 'Details URL': '/Daycare/Index/0018y000002M2MnAAK', 'Early Achiever:': 'Quality Level 3', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '2', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Warsame Asha (Kiefs Childcare)', 'Address': 'Seattle, WA 98106, USA', 'Details URL': '/Daycare/Index/0018y000002Nl02AAC', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '7', 'Short': '2', 'Long': '1'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Mohamed Suad F (Little Hands Big Hearts)', 'Address': 'Seattle, WA 98126, USA', 'Details URL': '/Daycare/Index/0018y000002NLEIAA4', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '15', 'Short': '2', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Mars Early Learning Academy (MARS ELA)', 'Address': '9400 Rainier Ave S, Seattle, WA 98118, USA', 'Details URL': '/Daycare/Index/0018y000002NY80AAG', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '4', 'Short': '2', 'Long': '1'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Moga  Jamad (Learn and Play Family Daycare)', 'Address': 'Seattle, WA 98118, USA', 'Details URL': '/Daycare/Index/0018y000002OdxWAAS', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '4', 'Short': '4', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'KCE Champions LLC At Impact Salish Sea Elementary SA', 'Address': '3900 Holly Park Dr S, Seattle, WA 98118, USA', 'Details URL': '/Daycare/Index/0018y000002QfdEAAS', 'Early Achiever:': 'Not Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Ali Fatuma H (Green Park Home Daycare)', 'Address': 'Seattle, WA 98126, USA', 'Details URL': '/Daycare/Index/0018y000002WucQAAS', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '3', 'Short': '2', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Ali Fosia (Simran Early Learning)', 'Address': 'Seattle, WA 98126, USA', 'Details URL': '/Daycare/Index/0018y000003tsP0AAI', 'Early Achiever:': 'Quality Level 3', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '3', 'Short': '1', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Y Early Education at West Seattle Center (Y Early Education at West Seattle)', 'Address': '2515 SW Trenton St, Seattle, WA 98106, USA', 'Details URL': '/Daycare/Index/0018y000003xodGAAQ', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Tiny Tots Development Center Othello (Tiny Tots Development Center Org)', 'Address': '3939 S Othello St bldg c, Seattle, WA 98118, USA', 'Details URL': '/Daycare/Index/0018y0000041wblAAA', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '1', 'Short': '3', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Neighborhood House Seola Garden', 'Address': '11195 5th Ave SW, Seattle, WA 98146, USA', 'Details URL': '/Daycare/Index/0018y0000041wJ4AAI', 'Early Achiever:': 'Not Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Werede Suzanna (Forever Growing Child Care)', 'Address': 'Seattle, WA 98144, USA', 'Details URL': '/Daycare/Index/0018y0000042vTGAAY', 'Early Achiever:': 'Quality Level 3', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '1', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Hernandez Penaloza Esli N (Colores Spanish Immersion Child care and Preschool LLC)', 'Address': 'Seattle, WA 98125, USA', 'Details URL': '/Daycare/Index/001cs00000aQKETAA4', 'Early Achiever:': 'Not Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '1', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Ebro Fozia (HAYAT FAMILY DAYCARE LLC)', 'Address': 'Seattle, WA 98126, USA', 'Details URL': '/Daycare/Index/001cs00000AQT3rAAH', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '1', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Hussein Hani Abdullahi (MAMA AISHA CHILD CARE LLC)', 'Address': 'Seattle, WA 98108, USA', 'Details URL': '/Daycare/Index/001cs00000b5fEwAAI', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'WorldKids School Georgetown/SODO #2 (WorldKids School)', 'Address': '801 S Fidalgo St, Seattle, WA 98108, USA', 'Details URL': '/Daycare/Index/001cs00000C7dNWAAZ', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Aden Asha (Ayan Family Childcare LLC)', 'Address': 'Seattle, WA 98126, USA', 'Details URL': '/Daycare/Index/001cs00000c7KP8AAM', 'Early Achiever:': 'Not Participating', 'License Status:': 'Pending', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Liu Qian and Tan Yi Min (Tiny Talking Hands)', 'Address': 'Seattle, WA 98117, USA', 'Details URL': '/Daycare/Index/001cs00000cZ18QAAS', 'Early Achiever:': 'Not Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Ahmed Farhiya', 'Address': 'Seattle, WA 98108, USA', 'Details URL': '/Daycare/Index/001cs00000czYV8AAM', 'Early Achiever:': 'Not Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Mohamed Khadro (Emerald Childcare LLC)', 'Address': 'Seattle, WA 98108, USA', 'Details URL': '/Daycare/Index/001cs00000DayqzAAB', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Abdidahar Hibaq (Hadila Daycare LLC)', 'Address': 'Seattle, WA 98118, USA', 'Details URL': '/Daycare/Index/001cs00000drQM8AAM', 'Early Achiever:': 'Not Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '1', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Yasin Ubah (Adventure Childcare LLC)', 'Address': 'Seattle, WA 98118, USA', 'Details URL': '/Daycare/Index/001cs00000EGqKQAA1', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '1', 'Short': '1', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Fayzieva Sohiba (CURIOUS LITTLE WONDERS DAYCARE LLC)', 'Address': 'Seattle, WA 98125, USA', 'Details URL': '/Daycare/Index/001cs00000eMAuXAAW', 'Early Achiever:': 'Not Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Ahmed Maryan A (SUREYA LEARNING CHILDCARE LLC)', 'Address': 'Seattle, WA 98118, USA', 'Details URL': '/Daycare/Index/001cs00000EZNuXAAX', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Mohamud Fatuma', 'Address': 'Seattle, WA 98108, USA', 'Details URL': '/Daycare/Index/001cs00000fBrPaAAK', 'Early Achiever:': 'Not Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Nuno Gallegos Marina (Little Stars Bilingual)', 'Address': 'Seattle, WA 98108, USA', 'Details URL': '/Daycare/Index/001cs00000fIQz0AAG', 'Early Achiever:': 'Not Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '1', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'The Family Success Childcare Center', 'Address': '120 8th Ave, Seattle, WA 98104, USA', 'Details URL': '/Daycare/Index/001cs00000fJP6NAAW', 'Early Achiever:': 'Not Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': "A 4 Apple Learning Center (Today's Central)", 'Address': '900 Rainier Ave S #103, Seattle, WA 98144, USA', 'Details URL': '/Daycare/Index/001cs00000fPc7WAAS', 'Early Achiever:': 'Not Participating', 'License Status:': 'Pending', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Ghebreslasie Lwam Goitom (Delina Childcare)', 'Address': 'Seattle, WA 98188, USA', 'Details URL': '/Daycare/Index/001cs00000fUZojAAG', 'Early Achiever:': 'Not Participating', 'License Status:': 'Pending', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Mohamed Umukaltum', 'Address': 'Seattle, WA 98108, USA', 'Details URL': '/Daycare/Index/001cs00000GQ4RoAAL', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '2', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Meshalla Samira M (Sunshine Family LLC)', 'Address': 'Seattle, WA 98108, USA', 'Details URL': '/Daycare/Index/001cs00000GrEbVAAV', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '1', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Tadesse Meazash (Shiny Stars Childcare LLC)', 'Address': 'Seattle, WA 98188, USA', 'Details URL': '/Daycare/Index/001cs00000H8FL5AAN', 'Early Achiever:': 'Not Participating', 'License Status:': 'Pending', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Abdulle Fadumo Abdi (Mubarak Family Childcare)', 'Address': 'Seattle, WA 98108, USA', 'Details URL': '/Daycare/Index/001cs00000HVHdtAAH', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Awo Suada (DINA AND FAMILY CHILD CARE)', 'Address': '13029 37th Ave NE B, Seattle, WA 98125, USA', 'Details URL': '/Daycare/Index/001cs00000HXVkpAAH', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '1', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Fidow Halimo (ANZAL FAMILY CHILDCARE)', 'Address': 'Seattle, WA 98126, USA', 'Details URL': '/Daycare/Index/001cs00000I8PgQAAV', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': "Hussein Amina Abdi (Rahma's Early Learning Program)", 'Address': 'Seattle, WA 98108, USA', 'Details URL': '/Daycare/Index/001cs00000j93j7AAA', 'Early Achiever:': 'Not Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Aden Saida (Best Choice Family Childcare LLC)', 'Address': 'Seattle, WA 98108, USA', 'Details URL': '/Daycare/Index/001cs00000jakTpAAI', 'Early Achiever:': 'Not Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Ahmed Yasmin Mohamed (SAMI CHILDCARE)', 'Address': 'Seattle, WA 98188, USA', 'Details URL': '/Daycare/Index/001cs00000jBS8kAAG', 'Early Achiever:': 'Not Participating', 'License Status:': 'Pending', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Abdi Halimo I', 'Address': 'Seattle, WA 98118, USA', 'Details URL': '/Daycare/Index/001cs00000jQbjZAAS', 'Early Achiever:': 'Not Participating', 'License Status:': 'Pending', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Nuguse Rutha (DIANA CHILDCARE LLC)', 'Address': 'Seattle, WA 98108, USA', 'Details URL': '/Daycare/Index/001cs00000JU7CPAA1', 'Early Achiever:': 'Not Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '3', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Seed of Life Center for Early Learning and Preschool Inc at Metropole (Seed of Life Center for Early Learning and Preschool, Inc @ Metropole)', 'Address': '423 2nd Ave Ext S, Seattle, WA 98104, USA', 'Details URL': '/Daycare/Index/001cs00000k2EKlAAM', 'Early Achiever:': 'Not Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Idrissa Abdou (BRIGHT STAR CHILD CHILDCARE INC)', 'Address': 'Seattle, WA 98188, USA', 'Details URL': '/Daycare/Index/001cs00000kBQKuAAO', 'Early Achiever:': 'Not Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Yusuf Deqo Saleban', 'Address': 'Seattle, WA 98178, USA', 'Details URL': '/Daycare/Index/001cs00000kKaRRAA0', 'Early Achiever:': 'Not Participating', 'License Status:': 'Pending', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Abdulqadir Sahara (Barakahs Childcare LLC)', 'Address': 'Seattle, WA 98126, USA', 'Details URL': '/Daycare/Index/001cs00000LGmmEAAT', 'Early Achiever:': 'Not Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Ali Ayan A (Sweet Pea Family Childcare LLC)', 'Address': 'Seattle, WA 98108, USA', 'Details URL': '/Daycare/Index/001cs00000lIityAAC', 'Early Achiever:': 'Not Participating', 'License Status:': 'Pending', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Abdi Asha Farah', 'Address': 'Seattle, WA 98126, USA', 'Details URL': '/Daycare/Index/001cs00000LIz0wAAD', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Betancourt Carvajal Daniela', 'Address': 'Seattle, WA 98103, USA', 'Details URL': '/Daycare/Index/001cs00000lucnVAAQ', 'Early Achiever:': 'Not Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Yogol Jamal M (YOGOL GARDEN CHILDCARE)', 'Address': 'Seattle, WA 98188, USA', 'Details URL': '/Daycare/Index/001cs00000lwObkAAE', 'Early Achiever:': 'Not Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Ali Mohamed Gariye (Orbiting Stars Daycare LLC)', 'Address': 'Seattle, WA 98118, USA', 'Details URL': '/Daycare/Index/001cs00000MbjEQAAZ', 'Early Achiever:': 'Not Participating', 'License Status:': 'Pending', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Muhudin Hassan (Joyful Daycare)', 'Address': 'Seattle, WA 98118, USA', 'Details URL': '/Daycare/Index/001cs00000mC1xaAAC', 'Early Achiever:': 'Not Participating', 'License Status:': 'Pending', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Mohamed Katro Mohamud (Suman Childcare)', 'Address': 'Seattle, WA 98118, USA', 'Details URL': '/Daycare/Index/001cs00000MXOVAAA5', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Warsame Mohamed Adam (Manal Family Home Childcare)', 'Address': 'Seattle, WA 98118, USA', 'Details URL': '/Daycare/Index/001cs00000N86EIAAZ', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': "Shire Anab Hassan (Future's Stars Family Home Childcare)", 'Address': 'Seattle, WA 98104, USA', 'Details URL': '/Daycare/Index/001cs00000NdhnqAAB', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '2', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Tihar Hedja Wassu', 'Address': 'Seattle, WA 98188, USA', 'Details URL': '/Daycare/Index/001cs00000nHmSHAA0', 'Early Achiever:': 'Not Participating', 'License Status:': 'Pending', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Creative Kids Learning Center ONB (Creative Kids Learning Center ONB)', 'Address': '950 NW Carkeek Park Rd, Seattle, WA 98177, USA', 'Details URL': '/Daycare/Index/001cs00000nOKCfAAO', 'Early Achiever:': 'Not Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Omar Hibo (Dunya Early Learning Chilcare)', 'Address': 'Seattle, WA 98118, USA', 'Details URL': '/Daycare/Index/001cs00000nTkhaAAC', 'Early Achiever:': 'Not Participating', 'License Status:': 'Pending', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Noor Asli Aden (Caring Hearts Daycare LLC)', 'Address': 'Seattle, WA 98188, USA', 'Details URL': '/Daycare/Index/001cs00000o81gUAAQ', 'Early Achiever:': 'Not Participating', 'License Status:': 'Pending', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': "Ahmed Sabontu (Adam's Childcare LLC)", 'Address': 'Seattle, WA 98118, USA', 'Details URL': '/Daycare/Index/001cs00000oN1ZhAAK', 'Early Achiever:': 'Not Participating', 'License Status:': 'Pending', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': "Jama Katra (Jama's Daycare)", 'Address': 'Seattle, WA 98144, USA', 'Details URL': '/Daycare/Index/001cs00000pcnjuAAA', 'Early Achiever:': 'Not Participating', 'License Status:': 'Pending', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Mohamed Barka (Barka Childcare LLC)', 'Address': 'Seattle, WA 98178, USA', 'Details URL': '/Daycare/Index/001cs00000pd9PRAAY', 'Early Achiever:': 'Not Participating', 'License Status:': 'Pending', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Harvard Avenue School Madison Valley', 'Address': '1608 Martin Luther King Jr Way, Seattle, WA 98122, USA', 'Details URL': '/Daycare/Index/001cs00000pRi4PAAS', 'Early Achiever:': 'Not Participating', 'License Status:': 'Pending', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Hassan Halima Awil (lucky childcare)', 'Address': 'Seattle, WA 98118, USA', 'Details URL': '/Daycare/Index/001cs00000PyMnLAAV', 'Early Achiever:': 'Not Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '2', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Abu Fartun A (Adna Family Childcare)', 'Address': 'Seattle, WA 98188, USA', 'Details URL': '/Daycare/Index/001cs00000RkZPpAAN', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Mahamud Mahamud (Salaam Childcare)', 'Address': 'Seattle, WA 98188, USA', 'Details URL': '/Daycare/Index/001cs00000Ry1DDAAZ', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Little Woods Preschool (Meadow Early Learning Center LLC)', 'Address': '13025 37th Ave NE, Seattle, WA 98125, USA', 'Details URL': '/Daycare/Index/001cs00000s7YNdAAM', 'Early Achiever:': 'Not Participating', 'License Status:': 'Pending', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Rashid Risaalo A (Liban Childcare)', 'Address': 'Seattle, WA 98188, USA', 'Details URL': '/Daycare/Index/001cs00000sCpFmAAK', 'Early Achiever:': 'Not Participating', 'License Status:': 'Pending', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Abshir Hayat (ALRAZAQ HOME CHILD CARE LLC)', 'Address': 'Seattle, WA 98188, USA', 'Details URL': '/Daycare/Index/001cs00000SSTmxAAH', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Nguyen Hoa Kim and Nguyen Loc Ba (Hoa Nguyen)', 'Address': 'Seattle, WA 98108, USA', 'Details URL': '/Daycare/Index/001t0000007qEurAAE', 'Early Achiever:': 'Quality Level 3', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Taffesse Bruk (Vision For Kids Child Care)', 'Address': 'Seattle, WA 98188, USA', 'Details URL': '/Daycare/Index/001t0000007qJMsAAM', 'Early Achiever:': 'Quality Level 3', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '1', 'Serious': '3', 'Short': '2', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Boys and Girls Club Lawton', 'Address': '4017 26th Ave W, Seattle, WA 98199, USA', 'Details URL': '/Daycare/Index/001t0000007qEuyAAE', 'Early Achiever:': 'Not Enrolled', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '6', 'Short': '5', 'Long': '2'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Boys and Girls Club Coe', 'Address': '2424 7th Ave W, Seattle, WA 98119, USA', 'Details URL': '/Daycare/Index/001t0000007qEuzAAE', 'Early Achiever:': 'Not Enrolled', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '6', 'Short': '1', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Boys and Girls Club Ballard', 'Address': '1767 NW 64th St, Seattle, WA 98107, USA', 'Details URL': '/Daycare/Index/001t0000007qEv1AAE', 'Early Achiever:': 'Not Enrolled', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '2', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '7', 'Short': '2', 'Long': '1'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'ABSHIR Nadifo (HOPE FAMILY CHILDCARE)', 'Address': 'Seattle, WA 98108, USA', 'Details URL': '/Daycare/Index/001t0000007qEwPAAU', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '2', 'Short': '1', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Gamez Ibarra Columba (THE LITTLE GENIUS WORLD LLC)', 'Address': 'Seattle, WA 98188, USA', 'Details URL': '/Daycare/Index/001t0000007qEx3AAE', 'Early Achiever:': 'Quality Level 3', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '4', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Tran Hoa K', 'Address': 'Seattle, WA 98118, USA', 'Details URL': '/Daycare/Index/001t0000007qEzRAAU', 'Early Achiever:': 'Quality Level 3', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': "Causeys Learning (Causey's Learning Center)", 'Address': '527 23rd Ave, Seattle, WA 98122, USA', 'Details URL': '/Daycare/Index/001t0000007qF3RAAU', 'Early Achiever:': 'Quality Level 4', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '1', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '6', 'Short': '1', 'Long': '1'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': "TAYLOR Diane (Diane's Daycare)", 'Address': 'Seattle, WA 98122, USA', 'Details URL': '/Daycare/Index/001t0000007qF4LAAU', 'Early Achiever:': 'Quality Level 3', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '2', 'Short': '1', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'ABUKAR Kerta A (Maqsumi Family Childcare)', 'Address': 'Seattle, WA 98118, USA', 'Details URL': '/Daycare/Index/001t0000007qF9BAAU', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '1', 'Short': '1', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Nguyen Kim Hong T and Nguyen Quynh-Nhu T', 'Address': 'Seattle, WA 98108, USA', 'Details URL': '/Daycare/Index/001t0000007qF9sAAE', 'Early Achiever:': 'Quality Level Expired', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '3', 'Short': '1', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Young Child Academy at Greenwood (Young Child Academy)', 'Address': '9218 Greenwood Ave N, Seattle, WA 98103, USA', 'Details URL': '/Daycare/Index/001t0000007qFanAAE', 'Early Achiever:': 'Not Enrolled', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '9', 'Short': '7', 'Long': '3'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'MANSOUR Amneh', 'Address': 'Seattle, WA 98125, USA', 'Details URL': '/Daycare/Index/001t0000007qFBcAAM', 'Early Achiever:': 'Quality Level 3', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'KILLOUGH CASSIE (Cassie’s Daycare)', 'Address': 'Seattle, WA 98126, USA', 'Details URL': '/Daycare/Index/001t0000007qFBHAA2', 'Early Achiever:': 'Quality Level 3', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '7', 'Short': '2', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'ABDULLE Maryan', 'Address': 'Seattle, WA 98108, USA', 'Details URL': '/Daycare/Index/001t0000007qFH2AAM', 'Early Achiever:': 'Quality Level 3+', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '1', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Seed of Life Center for Early Learning and Preschool Inc (Seed of Life Center for Early Learning and Preschool Inc Org)', 'Address': '4728 Rainier Ave S, Seattle, WA 98118, USA', 'Details URL': '/Daycare/Index/001t0000007qFI3AAM', 'Early Achiever:': 'Quality Level 3', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '3', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'St Benedict School (St Benedict School Kids Club)', 'Address': '4811 Wallingford Ave N, Seattle, WA 98103, USA', 'Details URL': '/Daycare/Index/001t0000007qFJsAAM', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '6', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Horton Deshon Renee', 'Address': 'Seattle, WA 98118, USA', 'Details URL': '/Daycare/Index/001t0000007qFLBAA2', 'Early Achiever:': 'Quality Level Expired', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '1', 'Short': '1', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'YMCA WEST SEATTLE/CONCORD (YMCA West Seattle/Concord Elementary School)', 'Address': '723 S Concord St, Seattle, WA 98108, USA', 'Details URL': '/Daycare/Index/001t0000007qFLeAAM', 'Early Achiever:': 'Quality Level Expired', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '1', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '1', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'DAILEY Denise M', 'Address': 'Seattle, WA 98178, USA', 'Details URL': '/Daycare/Index/001t0000007qFmAAAU', 'Early Achiever:': 'Quality Level 3', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '7', 'Short': '3', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Yusuf Sahra', 'Address': 'Seattle, WA 98178, USA', 'Details URL': '/Daycare/Index/001t0000007qFN0AAM', 'Early Achiever:': 'Quality Level 3', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '2', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'ISMAIL FARHIYA (Highpoint Family Childcare LLC)', 'Address': 'Seattle, WA 98126, USA', 'Details URL': '/Daycare/Index/001t0000007qFp5AAE', 'Early Achiever:': 'Quality Level 3', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '4', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Kulmiye Amina S', 'Address': 'Seattle, WA 98108, USA', 'Details URL': '/Daycare/Index/001t0000007qFQpAAM', 'Early Achiever:': 'Quality Level 3', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'KUNDIL Hafiza', 'Address': 'Seattle, WA 98125, USA', 'Details URL': '/Daycare/Index/001t0000007qFSzAAM', 'Early Achiever:': 'Quality Level 3', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '3', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Campbell Faiza (Furaha Family Childcare & Preschool)', 'Address': 'Seattle, WA 98115, USA', 'Details URL': '/Daycare/Index/001t0000007qFtqAAE', 'Early Achiever:': 'Not Enrolled', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '1', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'HASSAN FATHIYA (Naseem Home Childcare LLC)', 'Address': 'Seattle, WA 98126, USA', 'Details URL': '/Daycare/Index/001t0000007qFukAAE', 'Early Achiever:': 'Quality Level 3+', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '3', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'GOLDENBERG Yaneth (Step By Step Daycare)', 'Address': '2120 48th Ave SW, Seattle, WA 98116, USA', 'Details URL': '/Daycare/Index/001t0000007qFwnAAE', 'Early Achiever:': 'Not Enrolled', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '1', 'Short': '1', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# ...
# ----------------------------------------------------------------------------------------------------
# {'Name': 'CDSA Launch at Miller Community Center Annex', 'Address': '301 20th Ave E, Seattle, WA 98112, USA', 'Details URL': '/Daycare/Index/001t000000AzH2qAAF', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '5', 'Short': '1', 'Long': '1'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Abdi Zainab A (Hooyo Bibi Family Child Care)', 'Address': 'Seattle, WA 98178, USA', 'Details URL': '/Daycare/Index/001t000000B0IIwAAN', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '2', 'Short': '2', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Sofiatun Umi (SOFIA FAMILY CHILDCARE)', 'Address': 'Seattle, WA 98118, USA', 'Details URL': '/Daycare/Index/001t000000B6lVbAAJ', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Jeylani Zahra', 'Address': '5010 39th Ave NE, Seattle, WA 98105, USA', 'Details URL': '/Daycare/Index/001t000000b7ZVgAAM', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Osman Barni (Tawakal Family Childcare)', 'Address': 'Seattle, WA 98108, USA', 'Details URL': '/Daycare/Index/001t000000b8ZJ2AAM', 'Early Achiever:': 'Quality Level 3', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Hassan Fatima (Riham Family Childcare)', 'Address': 'Seattle, WA 98108, USA', 'Details URL': '/Daycare/Index/001t000000b9ZUAAA2', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Southwest Boys and Girls Club (Boys and Girls of King County)', 'Address': '9800 8th Ave SW #105, Seattle, WA 98106, USA', 'Details URL': '/Daycare/Index/001t000000BFjO5AAL', 'Early Achiever:': 'Not Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '5', 'Short': '2', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Abucar Zahra (Wani Family Childcare LLC)', 'Address': 'Seattle, WA 98118, USA', 'Details URL': '/Daycare/Index/001t000000BFRkNAAX', 'Early Achiever:': 'Quality Level 3', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '1', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Abdu Fatuma M. (Grandmas Daycare LLC)', 'Address': 'Seattle, WA 98108, USA', 'Details URL': '/Daycare/Index/001t000000BGAd5AAH', 'Early Achiever:': 'Quality Level 3', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '1', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Hussein Safia A (Sunnyside Family childcare)', 'Address': '6503 Shaffer Ave S, Seattle, WA 98108, USA', 'Details URL': '/Daycare/Index/001t000000BGmGDAA1', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '1', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Hashi Faisa D (Faisa Home Childcare LLC)', 'Address': 'Seattle, WA 98188, USA', 'Details URL': '/Daycare/Index/001t000000BGnaOAAT', 'Early Achiever:': 'Quality Level 3', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '7', 'Short': '1', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Hersi Nimo M (Nimo Childcare)', 'Address': 'Seattle, WA 98199, USA', 'Details URL': '/Daycare/Index/001t000000BGQAwAAP', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '1', 'Short': '1', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Hitchcock Colleen (Alki Beach Academy)', 'Address': 'Seattle, WA 98116, USA', 'Details URL': '/Daycare/Index/001t000000BGQDWAA5', 'Early Achiever:': 'Not Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '2', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Valdes Marianne', 'Address': '909 SW Holden St b, Seattle, WA 98106, USA', 'Details URL': '/Daycare/Index/001t000000BHtqPAAT', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '3', 'Short': '3', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Yusuf Shukri (Eagles Childcare LLC)', 'Address': 'Seattle, WA 98188, USA', 'Details URL': '/Daycare/Index/001t000000BIKgtAAH', 'Early Achiever:': 'Quality Level 3', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '2', 'Short': '0', 'Long': '1'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Ahmed Haboon (BARAKA EARLY LEARNING PROGRAM)', 'Address': 'Seattle, WA 98188, USA', 'Details URL': '/Daycare/Index/001t000000BIXWwAAP', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'International Montessori Academy of Capitol Hill', 'Address': '1715 E Olive Wy, Seattle, WA 98102, USA', 'Details URL': '/Daycare/Index/001t000000DpRHnAAN', 'Early Achiever:': 'Not Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '15', 'Short': '4', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Voices of Tomorrow Child and Family Center (Voice Of Tomorrow Org)', 'Address': '9242 Martin Luther King Jr Way S, Seattle, WA 98118, USA', 'Details URL': '/Daycare/Index/001t000000blqduAAA', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '1', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '5', 'Short': '1', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Co Kathleen and Co Stephanie (Little Trailblazers West Queen Anne)', 'Address': 'Seattle, WA 98119, USA', 'Details URL': '/Daycare/Index/001t000000bOGX6AAO', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '4', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'HOUSSOU RADIA (ANGELS NEST CHILDCARE LLC)', 'Address': '936 N 89th St, Seattle, WA 98103, USA', 'Details URL': '/Daycare/Index/001t000000BvdrOAAR', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '5', 'Short': '1', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Right at School at Lakeridge Elementary', 'Address': '7400 S 115th St, Seattle, WA 98178, USA', 'Details URL': '/Daycare/Index/001t000000BwIduAAF', 'Early Achiever:': 'Not Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Ali Jamila M (khair)', 'Address': 'Seattle, WA 98108, USA', 'Details URL': '/Daycare/Index/001t000000BwkFrAAJ', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Our Lady of Fatima Parish School', 'Address': '3301 W Dravus St, Seattle, WA 98199, USA', 'Details URL': '/Daycare/Index/001t000000Bxz98AAB', 'Early Achiever:': 'Not Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '1', 'Short': '1', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'YMCA of Greater Seattle at Rainier View', 'Address': '11650 Beacon Ave S, Seattle, WA 98178, USA', 'Details URL': '/Daycare/Index/001t000000By0WuAAJ', 'Early Achiever:': 'Not Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '2', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Our Lady of Guadalupe Early Learning Center', 'Address': '3401 SW Myrtle St, Seattle, WA 98126, USA', 'Details URL': '/Daycare/Index/001t000000ByzXeAAJ', 'Early Achiever:': 'Not Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '1', 'Short': '2', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Nurturing Knowledge Schools at Loyal Heights', 'Address': '7735 25th Ave NW, Seattle, WA 98117, USA', 'Details URL': '/Daycare/Index/001t000000Cd9yzAAB', 'Early Achiever:': 'Not Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '2', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Little Steamers Academy', 'Address': '12620 Renton Ave S #5, Seattle, WA 98178, USA', 'Details URL': '/Daycare/Index/001t000000CiCPqAAN', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '1', 'Short': '2', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Ali Amina O (Amina Family Child Care LLC)', 'Address': 'Seattle, WA 98118, USA', 'Details URL': '/Daycare/Index/001t000000CilFgAAJ', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '1', 'Short': '1', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Elosegui Mayte', 'Address': 'Seattle, WA 98112, USA', 'Details URL': '/Daycare/Index/001t000000CiZHcAAN', 'Early Achiever:': 'Not Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Abtidon Fadumo A. (Sabriin Family Childcare)', 'Address': 'Seattle, WA 98108, USA', 'Details URL': '/Daycare/Index/001t000000CjG2ZAAV', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '1', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'REWA Lake City Early Learning Center', 'Address': '2828 NE 127th St, Seattle, WA 98125, USA', 'Details URL': '/Daycare/Index/001t000000DbBbxAAF', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '2', 'Short': '0', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Rios De Forbes Mayra (Babies N Tots Daycare)', 'Address': 'Seattle, WA 98116, USA', 'Details URL': '/Daycare/Index/001t000000Dc0rvAAB', 'Early Achiever:': 'Not Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '1', 'Short': '2', 'Long': '0'}, 'Inspections': {'Immediate': '1', 'Serious': '1', 'Short': '1', 'Long': '2'}}
# ----------------------------------------------------------------------------------------------------
# {'Name': 'Adam Walala A (Bright Start Family Home Child Care)', 'Address': '9824 55th Ave S, Seattle, WA 98178, USA', 'Details URL': '/Daycare/Index/001t000000Dc2WGAAZ', 'Early Achiever:': 'Participating', 'License Status:': 'Open', 'Complaints': {'Immediate': '0', 'Serious': '0', 'Short': '0', 'Long': '0'}, 'Inspections': {'Immediate': '0', 'Serious': '6', 'Short': '6', 'Long': '0'}}
# ----------------------------------------------------------------------------------------------------
