# %%
import pprint
import requests

url = "https://api.apollo.io/api/v1/mixed_people/api_search?q_organization_domains_list[]=csl.com"
apiKey = ""

headers = {
    "accept": "application/json",
    "Cache-Control": "no-cache",
    "Content-Type": "application/json",
    "x-api-key": apiKey
}

response = requests.post(url, headers=headers)

pprint.pprint(response.text)
# Out:
# ('{"total_entries":12024,"people":[{"id":"6205ec445e6d430001c7321d","first_name":"Ryne","last_name_obfuscated":"Be***r","title":"Production '
#  'Management","last_refreshed_at":"2026-01-06T17:13:30.397+00:00","has_email":true,"has_city":true,"has_state":true,"has_country":true,"has_direct_phone":"Yes","organization":{"name":"CSL","has_industry":true,"has_phone":true,"has_city":true,"has_state":true,"has_country":true,"has_zip_code":true,"has_revenue":true,"has_employee_count":true}},{"id":"60f162ec8b182800019f2f6b","first_name":"Gordon","last_name_obfuscated":"Jo***n","title":"Director '
#  'APAC, Talent Acquisition, Early Careers \\u0026 Enabling '
#  'Functions","last_refreshed_at":"2026-01-12T09:56:02.027+00:00","has_email":true,"has_city":true,"has_state":true,"has_country":true,"has_direct_phone":"Yes","organization":{"name":"CSL","has_industry":true,"has_phone":true,"has_city":true,"has_state":true,"has_country":true,"has_zip_code":true,"has_revenue":true,"has_employee_count":true}},{"id":"6598d3d58fef8a00014cdfae","first_name":"Sumitha","last_name_obfuscated":"Th***s","title":"Talent '
#  'Acquisition '
#  'Partner","last_refreshed_at":"2026-01-14T01:13:04.189+00:00","has_email":true,"has_city":true,"has_state":true,"has_country":true,"has_direct_phone":"Yes","organization":{"name":"CSL","has_industry":true,"has_phone":true,"has_city":true,"has_state":true,"has_country":true,"has_zip_code":true,"has_revenue":true,"has_employee_count":true}},{"id":"54c2073974686916392a066e","first_name":"Keith","last_name_obfuscated":"Tr***e","title":"Senior '
#  'Talent Acquisition '
#  'Partner","last_refreshed_at":"2026-01-12T03:22:56.000+00:00","has_email":true,"has_city":true,"has_state":true,"has_country":true,"has_direct_phone":"Yes","organization":{"name":"CSL","has_industry":true,"has_phone":true,"has_city":true,"has_state":true,"has_country":true,"has_zip_code":true,"has_revenue":true,"has_employee_count":true}},{"id":"66ed586451e45b0001b5a3c6","first_name":"Tim","last_name_obfuscated":"Wa***f","title":"Talent '
#  'Acquisition Partner '
#  '(Interim)","last_refreshed_at":"2026-01-15T13:26:46.691+00:00","has_email":true,"has_city":true,"has_state":true,"has_country":true,"has_direct_phone":"Yes","organization":{"name":"CSL","has_industry":true,"has_phone":true,"has_city":true,"has_state":true,"has_country":true,"has_zip_code":true,"has_revenue":true,"has_employee_count":true}},{"id":"60831aac8157ec00015a03dc","first_name":"Hassan","last_name_obfuscated":"He***u","title":"General '
#  'Manager Middle East '
#  'Africa","last_refreshed_at":"2026-01-08T08:29:18.873+00:00","has_email":true,"has_city":false,"has_state":false,"has_country":true,"has_direct_phone":"Yes","organization":{"name":"CSL","has_industry":true,"has_phone":true,"has_city":true,"has_state":true,"has_country":true,"has_zip_code":true,"has_revenue":true,"has_employee_count":true}},{"id":"67adb07c62c6bb000109828a","first_name":"Prof","last_name_obfuscated":"We***l","title":"Vice '
#  'President, Head of Therapeutic Areas, Global Medical '
#  'Affairs","last_refreshed_at":"2026-01-12T14:34:56.000+00:00","has_email":true,"has_city":true,"has_state":true,"has_country":true,"has_direct_phone":"Maybe: '
#  'please request direct dial via '
#  'people/bulk_match","organization":{"name":"CSL","has_industry":true,"has_phone":true,"has_city":true,"has_state":true,"has_country":true,"has_zip_code":true,"has_revenue":true,"has_employee_count":true}},{"id":"681709b24d04e30001f3dfb9","first_name":"Andy","last_name_obfuscated":"Sc***z","title":"Chief '
#  'Commercial Officer '
#  '(CCO)","last_refreshed_at":"2026-01-15T20:18:17.846+00:00","has_email":true,"has_city":true,"has_state":true,"has_country":true,"has_direct_phone":"Maybe: '
#  'please request direct dial via '
#  'people/bulk_match","organization":{"name":"CSL","has_industry":true,"has_phone":true,"has_city":true,"has_state":true,"has_country":true,"has_zip_code":true,"has_revenue":true,"has_employee_count":true}},{"id":"66f762ed27096c00012e88ba","first_name":"Sebastian","last_name_obfuscated":"So***u","title":"VP, '
#  'Head of US '
#  'Medical","last_refreshed_at":"2026-01-16T15:59:46.668+00:00","has_email":true,"has_city":true,"has_state":true,"has_country":true,"has_direct_phone":"Yes","organization":{"name":"CSL","has_industry":true,"has_phone":true,"has_city":true,"has_state":true,"has_country":true,"has_zip_code":true,"has_revenue":true,"has_employee_count":true}},{"id":"61833ef90cfcaf00013439df","first_name":"Sophie","last_name_obfuscated":"Sa***a","title":"Senior '
#  'Manager, Learning \\u0026 Development, '
#  'APAC","last_refreshed_at":"2025-11-04T02:24:34.891+00:00","has_email":true,"has_city":true,"has_state":true,"has_country":true,"has_direct_phone":"Yes","organization":{"name":"CSL","has_industry":true,"has_phone":true,"has_city":true,"has_state":true,"has_country":true,"has_zip_code":true,"has_revenue":true,"has_employee_count":true}}]}')
