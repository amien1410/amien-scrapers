# %%
import requests

url = "https://redfin-com-data.p.rapidapi.com/properties/search-sale"
querystring = {"regionId":"6_2446"}

headers = {
    "x-rapidapi-host": "redfin-com-data.p.rapidapi.com",
    'x-rapidapi-key': ''
}

response = requests.get(url, headers=headers, params=querystring)
response.json()
# Out:
# {'data': [{'homeData': {'propertyId': '178773346',
#     'listingId': '208986424',
#     'listingDisplayLevel': 1,
#     'mlsId': '2451208',
#     'url': '/WA/Camas/4311-NW-Water-Lily-Pl-98607/home/178773346',
#     'dataSourceId': '1',
#     'marketId': '10',
#     'businessMarketId': '7',
#     'mlsStatusId': '3492',
#     'servicePolicyId': '28',
#     'listingMetadata': {'searchStatus': 1,
#      'listingType': 1,
#      'isRedfin': True,
#      'hasVirtualTour': True},
#     'propertyType': 6,
#     'beds': 3,
#     'baths': 2.5,
#     'priceInfo': {'amount': '899900',
#      'displayLevel': 1,
#      'priceType': 1,
#      'homePrice': {'displayLevel': 1, 'int64Value': '899900'}},
#     'sqftInfo': {'amount': '2696', 'displayLevel': 1},
#     'photosInfo': {'photoRanges': [{'startPos': 0,
#        'endPos': 2,
#        'version': '1'},
#       {'startPos': 3, 'endPos': 32, 'version': '0'},
#       {'startPos': 33, 'endPos': 36, 'version': '1'},
# ...
