# %%
headers = {
    'accept': '*/*',
    'accept-encoding': 'gzip, deflate, br, zstd',
    'accept-language': 'en-US,en;q=0.9,id;q=0.8,fa;q=0.7,ar;q=0.6,ms;q=0.5,ja;q=0.4,es;q=0.3',
    'apollographql-client-name': 'company-explorer-next',
    'apollographql-client-version': '1.52.0',
    'content-length': '1498',
    'content-type': 'application/json',
    'cookie': 'rl_page_init_referrer=RudderEncrypt%3AU2FsdGVkX18ZkKHvMmXdAIfaMYd5wkBO3E19Dg7KxyXWD%2F1dE0OqHAcakfEr2UGb; rl_page_init_referring_domain=RudderEncrypt%3AU2FsdGVkX19NPpTROk4XncedOkBLuXVosfx1iEpI5yx%2Fg8dNciUFrZTWBeCVIEf6; gdId=9b552c11-cd85-4a40-8ca3-7f069b7332a9; asst=1768620645.0; __cf_bm=HdMvfxcf_B0fvuOjx4sirW9DeR5X1G2z67DlFs7Z3sw-1768620646-1.0.1.1-DZbHPlDBf4q8wnRAqFnE00ZQ9JnNaZIoZF6xaJQr52r1_MhdenGEamu3eGn0hTmcvhqWBUozwJO37BchPCUTzHJ0s18hcNvBx2A2LKxOzUGidG8xkV5bNJeKJPLsEa2U; _cfuvid=NI88AU36Hv3nLomY0ijtYYNw4qtxqfmjyNiZyjPQqP0-1768620646105-0.0.1.1-604800000; AWSALB=+1EpD9h/dSg06IB+/Y0mY1+1SuVJiMlvMYKbA/G+jZV1Np2mXgFWvqkIJVBkfN+DUHUnzlaotUdiLHNiQqFxT3VxEM6dMKJ/C1WIYlZYZc9hzWSBXFmGelyKY6oY; AWSALBCORS=+1EpD9h/dSg06IB+/Y0mY1+1SuVJiMlvMYKbA/G+jZV1Np2mXgFWvqkIJVBkfN+DUHUnzlaotUdiLHNiQqFxT3VxEM6dMKJ/C1WIYlZYZc9hzWSBXFmGelyKY6oY; JSESSIONID=E5915B021CCF53BECEDBD4AB1ED1E35C; GSESSIONID=E5915B021CCF53BECEDBD4AB1ED1E35C; cass=0; g_state={"i_l":0,"i_ll":1768620681231}; at=eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9..nhuHLeHeGPULMHT-bz-FJfjXQVRSxA87zxogU0KafZq51Cre39ZVkyWBrdkq4-s_10holHIEhwP7ICrb3S0xQfK1Nz0QXcD8o6hvf2BkqO-fyWCAFgZZKVNrEtxkAKSHL3Vu7DotKWZ8B7K2psFogSVn0K-Jc00jTyfa6h-TtytWol26g04YXmxR1Dz7l85jggfuOvqX14tlspb5BTzU5ZCpB8PvmB7IaE1a7EnLugNQYXFjZAPDpvQhTbo1lrrbuTGWdr24j0TRvPDs3QCOL91yncuslrYKfu1vZs8wQcHbMqSbRJYWrFzg9I_CxHF_i4R3CbViFMxQeKLiLxcvlg; rl_session=RudderEncrypt%3AU2FsdGVkX19TeaUqrsC%2BHoweJE3ukzGx9NfgU6vmNIhmwt91q6eAzGPUkPVoKIO9O%2FWB6NPHgQSFiJSaRR6ufiLPzjXvs5t%2FW5gb39utH4KIxbk78GwsVnZ%2BksSWBQTcoCRBb6bqr6t6MoY%2Bn5NScg%3D%3D; rl_user_id=RudderEncrypt%3AU2FsdGVkX19XNgq2Mggma%2F80q%2BU9LTystM9a28eILpo%3D; rl_trait=RudderEncrypt%3AU2FsdGVkX1%2FZ65sQv%2BW%2BpR6zOg1tqp6KHbbbOY5YtBs%3D; rl_group_id=RudderEncrypt%3AU2FsdGVkX190t%2F0Ml2cwOquWddMIjr5Nah1ojKdBflw%3D; rl_group_trait=RudderEncrypt%3AU2FsdGVkX1%2BQkcpSTK23USDUc3EGZ3%2Fcs2iA%2FbKNrVA%3D; rl_anonymous_id=RudderEncrypt%3AU2FsdGVkX1%2BQlFeY5FghdiXf0R7SFhfk3LjgOlpwKk4DBFwPmLJZpZlzuM632hW0dTPc868CmCOk9I%2F0Wh9u8w%3D%3D; cf_clearance=IpyQC.0S4mQ6UBZ9g1Hjq0vDcsledhEiAkV6ZiSYjxs-1768620810-1.2.1.1-kbMc.N_Iukp1swv4QUIvovWm_f5Qa06g2km1ja6qJaj.mUXboJ_acliEgiNwwMZVILw7nV99BaaE0iPoZEBiSnhWS6dE.i3YoVQqJZpV1CyRCuxd3NNFgeD0XEasPgxtwOb0qQHUmJ2TekPGhvn9kCW83noZUusOjti7g1zXjllkA98yFocwKfoh2yXx4wqXexaifb7h4m71lzaLvNzJLFukkMXNQHX_Tl89aY_5T7x2sGnWFzZ01QOaibYKJcYq; gdsid=1768620645628:1768621043820:B0CB7A0034C2A7EC10868078B4E247CE',
    'gd-csrf-token': 'Vsk3Z6TJSlb9pnWmKLb8Zg:GYECLV9wrHHcdsl75HTXw8nvFSxG9oj0NFEr_A1GaDcTnwU0NdwBH-q9dgHwNGre24iMdmGqYQF_DrmgYGfOUA:atQfD8PBlhB5RSi79CDtJryK4Nq-3IRvuEnaJc2piZk',
    'origin': 'https://www.glassdoor.com',
    'priority': 'u=1, i',
    'referer': 'https://www.glassdoor.com/',
    'sec-ch-ua': '"Microsoft Edge";v="143", "Chromium";v="143", "Not A(Brand";v="24"',
    'sec-ch-ua-arch': "x86",
    'sec-ch-ua-bitness': "64",
    'sec-ch-ua-full-version': "143.0.3650.139",
    'sec-ch-ua-full-version-list': '"Microsoft Edge";v="143.0.3650.139", "Chromium";v="143.0.7499.193", "Not A(Brand";v="24.0.0.0"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-model': '',
    'sec-ch-ua-platform': "Windows",
    'sec-ch-ua-platform-version': '8.0.0',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/143.0.0.0 Safari/537.36 Edg/143.0.0.0'
}

# %%
import requests
import json

url = "https://www.glassdoor.com/graph"
payload = [{
    "operationName": "EmployerSearchRG",
    "variables": {
        "employerSearchInput": {
            "employerName": "",
            "employerSearchRangeFilters": [
                {"filterType": "RATING_OVERALL", "minInclusive": 4, "maxInclusive": 5}
            ],
            "industries": [],
            "location": {"locationId": 16, "locationType": "N"},
            "pageRequested": 2,
            "sectors": [{"id": 10012}],
            "jobTitle": "",
            "sGocIds": []
        }
    },
    "query": "query EmployerSearchRG($employerSearchInput: EmployerSearchInput) {\n  employerSearchRG(employerSearchInput: $employerSearchInput) {\n    employerResults {\n      demographicRatings {\n        category\n        categoryRatings {\n          categoryValue\n          ratings {\n            overallRating\n            __typename\n          }\n          __typename\n        }\n        __typename\n      }\n      employer {\n        bestProfile {\n          id\n          __typename\n        }\n        bestPlacesToWork {\n          isCurrent\n          startDate\n          tldId\n          __typename\n        }\n        bestLedCompanies {\n          id\n          isCurrent\n          __typename\n        }\n        id\n        shortName\n        ratings {\n          overallRating\n          careerOpportunitiesRating\n          compensationAndBenefitsRating\n          cultureAndValuesRating\n          diversityAndInclusionRating\n          seniorManagementRating\n          workLifeBalanceRating\n          __typename\n        }\n        __typename\n      }\n      __typename\n    }\n    numOfPagesAvailable\n    numOfRecordsAvailable\n    __typename\n  }\n}\
"
}]

try:
    response = requests.post(url, headers=headers, json=payload)
    response.raise_for_status()  # Raise an exception for HTTP errors
    print(json.dumps(response.json(), indent=2))
except requests.exceptions.RequestException as e:
    print(f"Request failed: {e}")
except json.JSONDecodeError:
    print(f"Failed to decode JSON from response: {response.text}")
# Out:
# [
#   {
#     "data": {
#       "employerSearchRG": {
#         "__typename": "UgcSearchV3EmployerResultWrapper",
#         "employerResults": [
#           {
#             "__typename": "UgcSearchV3EmployerResult",
#             "demographicRatings": [
#               {
#                 "__typename": "DemographicRatings",
#                 "category": "gender",
#                 "categoryRatings": [
#                   {
#                     "__typename": "DemographicCategoryValueRatings",
#                     "categoryValue": "man",
#                     "ratings": {
#                       "__typename": "EmployerRatings",
#                       "overallRating": 4.6
#                     }
#                   },
#                   {
#                     "__typename": "DemographicCategoryValueRatings",
#                     "categoryValue": "woman",
#                     "ratings": {
#                       "__typename": "EmployerRatings",
# ...
