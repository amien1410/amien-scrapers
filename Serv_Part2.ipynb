# %% [markdown]
# <a href="https://colab.research.google.com/github/amien1410/amien-scrapers/blob/main/Serv_Part2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install trafilatura
import os
import re
import requests
import trafilatura
from urllib.parse import urlparse
import shutil
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.6/132.6 kB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 837.9/837.9 kB 16.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 315.5/315.5 kB 17.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.7/274.7 kB 17.8 MB/s eta 0:00:00
# ...

# %%
# @title seconds array
seconds = [
    "https://secondhandforklifts.com.au/",
    "https://secondhandforklifts.com.au/",
    "https://secondhandforklifts.com.au/heli/",
    "https://secondhandforklifts.com.au/forklift/heli-g3-4-tonne-5-5-tonne-g3-internal-combustion-forklift/",
    "https://secondhandforklifts.com.au/forklift/heli-h3-series-2-2-8-tonne-lpg-forklift/",
    "https://secondhandforklifts.com.au/forklift/heli-g3-3-wheel-lithium-battery-electric-forklift/",
    "https://secondhandforklifts.com.au/forklift/heli-g2-series-4-wheel-lithium-battery-electric-forklifts/",
    "https://secondhandforklifts.com.au/forklift/heli-cqd15-80v-lithium-compact-reach-truck/",
    "https://secondhandforklifts.com.au/used-forklifts/",
    "https://secondhandforklifts.com.au/used-forklifts/",
    "https://secondhandforklifts.com.au/all-terrain-forklifts/",
    "https://secondhandforklifts.com.au/diesel-forklifts/",
    "https://secondhandforklifts.com.au/lpg-petrol-diesel-used-forklifts/",
    "https://secondhandforklifts.com.au/lpg-petrol-diesel-used-forklifts/0-2-tonne-forklifts/",
    "https://secondhandforklifts.com.au/lpg-petrol-diesel-used-forklifts/2-5-4-tonne-forklifts/",
    "https://secondhandforklifts.com.au/lpg-petrol-diesel-used-forklifts/4-5-tonne-and-over-forklifts/",
    "https://secondhandforklifts.com.au/electric-forklift-sales/",
    "https://secondhandforklifts.com.au/electric-forklift-sales/electric-ride-on-forklifts/",
    "https://secondhandforklifts.com.au/electric-forklift-sales/walkie-stackers-and-pallet-movers/",
    "https://secondhandforklifts.com.au/electric-forklift-sales/reach-trucks-and-order-pickers/",
    "https://secondhandforklifts.com.au/speciality-forklifts/",
    "https://secondhandforklifts.com.au/shop-by-price/",
    "https://secondhandforklifts.com.au/forklifts-up-to-5000/",
    "https://secondhandforklifts.com.au/forklifts-from-5001-to-10000/",
    "https://secondhandforklifts.com.au/forklifts-from-10001-to-20000/",
    "https://secondhandforklifts.com.au/forklifts-over-20001/",
    "https://secondhandforklifts.com.au/forklift-hire-and-forklift-rental/",
    "https://secondhandforklifts.com.au/forklift-hire-and-forklift-rental/",
    "https://secondhandforklifts.com.au/container-ramp-for-sale-or-hire/#containerramphire",
    "https://secondhandforklifts.com.au/pallet-trucks-for-sale-or-hire/#pallettruckhire",
    "https://secondhandforklifts.com.au/forklift-servicing/",
    "https://secondhandforklifts.com.au/forklift-servicing/",
    "https://secondhandforklifts.com.au/forklift-servicing/forklift-battery-rejuvenation-services/",
    "https://secondhandforklifts.com.au/forklift-tyres/",
    "https://secondhandforklifts.com.au/forklift-parts/",
    "https://secondhandforklifts.com.au/forklift-servicing/wheelchair-car-access-ramp-servicing/",
    "https://secondhandforklifts.com.au/accessories/",
    "https://secondhandforklifts.com.au/pallet-trucks-for-sale-or-hire/",
    "https://secondhandforklifts.com.au/container-ramp-for-sale-or-hire/",
    "https://secondhandforklifts.com.au/forklift-servicing/forklift-weight-scales-weight-gauges/",
    "https://secondhandforklifts.com.au/forklift-attachments/",
    "https://secondhandforklifts.com.au/articles/",
    "https://secondhandforklifts.com.au/articles/",
    "https://secondhandforklifts.com.au/forklift-warranty/",
    "https://secondhandforklifts.com.au/articles/free-melbourne-forklift-delivery/",
    "https://secondhandforklifts.com.au/contact-us/",
    "https://secondhandforklifts.com.au/contact-us/",
    "https://secondhandforklifts.com.au/contact/location/",
    "https://secondhandforklifts.com.au/forklift-jobs/",
    "https://secondhandforklifts.com.au/forklift-jobs/forklift-mechanic/",
    "https://secondhandforklifts.com.au/used-forklifts/",
    "https://secondhandforklifts.com.au/heli/",
    "https://secondhandforklifts.com.au/forklift/used-toyota-5-tonne-lpg-forklift-fully-serviced-02-7fga50-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-toyota-5-tonne-lpg-forklift-fully-serviced-02-7fga50-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-toyota-5-tonne-lpg-forklift-fully-serviced-02-7fga50-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-crown-walkie-stacker-current-model-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-crown-walkie-stacker-current-model-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-crown-walkie-stacker-current-model-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-hyster-3-5-tonne-lpg-forklift-compact-model-s80ft-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-hyster-3-5-tonne-lpg-forklift-compact-model-s80ft-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-hyster-3-5-tonne-lpg-forklift-compact-model-s80ft-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-tcm-2-5t-lpg-forklift-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-tcm-2-5t-lpg-forklift-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-tcm-2-5t-lpg-forklift-buy-now/",
    "https://secondhandforklifts.com.au/forklift/new-heli-16-tonne-forklift-cpcd160-yc-06iiig-buy-now/",
    "https://secondhandforklifts.com.au/forklift/new-heli-16-tonne-forklift-cpcd160-yc-06iiig-buy-now/",
    "https://secondhandforklifts.com.au/forklift/new-heli-16-tonne-forklift-cpcd160-yc-06iiig-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-hyster-16-tonne-2008-forklift-eofy-sale/",
    "https://secondhandforklifts.com.au/forklift/used-hyster-16-tonne-2008-forklift-eofy-sale/",
    "https://secondhandforklifts.com.au/forklift/used-hyster-16-tonne-2008-forklift-eofy-sale/",
    "https://secondhandforklifts.com.au/forklift/secondhand-toyota-2-tonne-5-series-forklift-buy-now/",
    "https://secondhandforklifts.com.au/forklift/secondhand-toyota-2-tonne-5-series-forklift-buy-now/",
    "https://secondhandforklifts.com.au/forklift/secondhand-toyota-2-tonne-5-series-forklift-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-crown-5200-series-electric-forklift-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-crown-5200-series-electric-forklift-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-crown-5200-series-electric-forklift-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-toyota-3-5t-diesel-forklift-low-hours-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-toyota-3-5t-diesel-forklift-low-hours-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-toyota-3-5t-diesel-forklift-low-hours-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-crown-2-0t-lpg-forklift-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-crown-2-0t-lpg-forklift-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-crown-2-0t-lpg-forklift-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-toyota-1-8t-lpg-forklift-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-toyota-1-8t-lpg-forklift-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-toyota-1-8t-lpg-forklift-buy-now/",
    "https://secondhandforklifts.com.au/forklift/toyota4-5tonneforklift/",
    "https://secondhandforklifts.com.au/forklift/toyota4-5tonneforklift/",
    "https://secondhandforklifts.com.au/forklift/toyota4-5tonneforklift/",
    "https://secondhandforklifts.com.au/forklift/used-toyota-3-5t-lpg-forklift-3-stage-container-mast-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-toyota-3-5t-lpg-forklift-3-stage-container-mast-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-toyota-3-5t-lpg-forklift-3-stage-container-mast-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-toyota-2-5-tonne-compact-forklift-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-toyota-2-5-tonne-compact-forklift-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-toyota-2-5-tonne-compact-forklift-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-yale-12t-diesel-forklift-gdp280db-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-yale-12t-diesel-forklift-gdp280db-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-yale-12t-diesel-forklift-gdp280db-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-toyota-32-8fg25-container-mast-2-5t-forklift-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-toyota-32-8fg25-container-mast-2-5t-forklift-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-toyota-32-8fg25-container-mast-2-5t-forklift-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-toyota-2-5-tonne-lpg-forklift-32-8fg25-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-toyota-2-5-tonne-lpg-forklift-32-8fg25-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-toyota-2-5-tonne-lpg-forklift-32-8fg25-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-toyota-3t-lpg-forklift-8fg30-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-toyota-3t-lpg-forklift-8fg30-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-toyota-3t-lpg-forklift-8fg30-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-toyota-2-5-tonne-lpg-forklift-32-8fg25-buy-now-2/",
    "https://secondhandforklifts.com.au/forklift/used-toyota-2-5-tonne-lpg-forklift-32-8fg25-buy-now-2/",
    "https://secondhandforklifts.com.au/forklift/used-toyota-2-5-tonne-lpg-forklift-32-8fg25-buy-now-2/",
    "https://secondhandforklifts.com.au/forklift/used-osko-max-g25-4-5tri-ss-2-2-tonne-forklift-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-osko-max-g25-4-5tri-ss-2-2-tonne-forklift-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-osko-max-g25-4-5tri-ss-2-2-tonne-forklift-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-crown-1-8-tonne-3-wheel-container-mast-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-crown-1-8-tonne-3-wheel-container-mast-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-crown-1-8-tonne-3-wheel-container-mast-buy-now/",
    "https://secondhandforklifts.com.au/forklift/toyota-electric-forklift-1-5-tonne/",
    "https://secondhandforklifts.com.au/forklift/toyota-electric-forklift-1-5-tonne/",
    "https://secondhandforklifts.com.au/forklift/toyota-electric-forklift-1-5-tonne/",
    "https://secondhandforklifts.com.au/forklift/linde-1-5-tonne-electric-used-forklift/",
    "https://secondhandforklifts.com.au/forklift/linde-1-5-tonne-electric-used-forklift/",
    "https://secondhandforklifts.com.au/forklift/linde-1-5-tonne-electric-used-forklift/",
    "https://secondhandforklifts.com.au/forklift/used-nissan-1-8-tonne-forklift-pif1a18du-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-nissan-1-8-tonne-forklift-pif1a18du-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-nissan-1-8-tonne-forklift-pif1a18du-buy-now/",
    "https://secondhandforklifts.com.au/forklift/new-ep-cpd18tvl-1-8-tonne-lithium-electric-forklift/",
    "https://secondhandforklifts.com.au/forklift/new-ep-cpd18tvl-1-8-tonne-lithium-electric-forklift/",
    "https://secondhandforklifts.com.au/forklift/new-ep-cpd18tvl-1-8-tonne-lithium-electric-forklift/",
    "https://secondhandforklifts.com.au/forklift/used-toyota-8fg70n-7-tonne-forklift-enquire-today/",
    "https://secondhandforklifts.com.au/forklift/used-toyota-8fg70n-7-tonne-forklift-enquire-today/",
    "https://secondhandforklifts.com.au/forklift/used-toyota-8fg70n-7-tonne-forklift-enquire-today/",
    "https://secondhandforklifts.com.au/forklift/manitou-4-tonne-off-road-forklift-with-roll-over-protection/",
    "https://secondhandforklifts.com.au/forklift/manitou-4-tonne-off-road-forklift-with-roll-over-protection/",
    "https://secondhandforklifts.com.au/forklift/manitou-4-tonne-off-road-forklift-with-roll-over-protection/",
    "https://secondhandforklifts.com.au/forklift/used-linde-3-5t-container-mast-forklift-low-hours-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-linde-3-5t-container-mast-forklift-low-hours-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-linde-3-5t-container-mast-forklift-low-hours-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-toyota-2-tonne-lpg-forklift-compact-model-8fgk20-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-toyota-2-tonne-lpg-forklift-compact-model-8fgk20-buy-now/",
    "https://secondhandforklifts.com.au/forklift/used-toyota-2-tonne-lpg-forklift-compact-model-8fgk20-buy-now/",
    "https://secondhandforklifts.com.au/forklift/2018-toyota-2-5-tonne-compact-unit/",
    "https://secondhandforklifts.com.au/forklift/2018-toyota-2-5-tonne-compact-unit/",
    "https://secondhandforklifts.com.au/forklift/2018-toyota-2-5-tonne-compact-unit/",
    "https://secondhandforklifts.com.au/forklift/new-heli-16-tonne-forklift-cpcd160-yc-06iiig-buy-now/",
    "https://secondhandforklifts.com.au/forklift/new-heli-16-tonne-forklift-cpcd160-yc-06iiig-buy-now/",
    "https://secondhandforklifts.com.au/forklift/new-heli-16-tonne-forklift-cpcd160-yc-06iiig-buy-now/",
    "https://secondhandforklifts.com.au/forklift/new-ep-cpd18tvl-1-8-tonne-lithium-electric-forklift/",
    "https://secondhandforklifts.com.au/forklift/new-ep-cpd18tvl-1-8-tonne-lithium-electric-forklift/",
    "https://secondhandforklifts.com.au/forklift/new-ep-cpd18tvl-1-8-tonne-lithium-electric-forklift/",
    "https://secondhandforklifts.com.au/forklift/ep-efl303-3-0-tonne-lithium-electric-forklift/",
    "https://secondhandforklifts.com.au/forklift/ep-efl303-3-0-tonne-lithium-electric-forklift/",
    "https://secondhandforklifts.com.au/forklift/ep-efl303-3-0-tonne-lithium-electric-forklift/",
    "https://secondhandforklifts.com.au/forklift/new-ep-cpd50l1-5-0-tonne-lithium-electric-forklift/",
    "https://secondhandforklifts.com.au/forklift/new-ep-cpd50l1-5-0-tonne-lithium-electric-forklift/",
    "https://secondhandforklifts.com.au/forklift/new-ep-cpd50l1-5-0-tonne-lithium-electric-forklift/",
    "https://secondhandforklifts.com.au/forklift/new-ep-es16-rs-1-6-tonne-lithium-walkie-stacker/",
    "https://secondhandforklifts.com.au/forklift/new-ep-es16-rs-1-6-tonne-lithium-walkie-stacker/",
    "https://secondhandforklifts.com.au/forklift/new-ep-es16-rs-1-6-tonne-lithium-walkie-stacker/",
    "https://secondhandforklifts.com.au/forklift/new-ep-cqd20l-2-0-tonne-lithium-electric-reach-truck/",
    "https://secondhandforklifts.com.au/forklift/new-ep-cqd20l-2-0-tonne-lithium-electric-reach-truck/",
    "https://secondhandforklifts.com.au/forklift/new-ep-cqd20l-2-0-tonne-lithium-electric-reach-truck/",
    "https://secondhandforklifts.com.au/forklift/new-ep-efxz301-3-0-tonne-lithium-electric-forklift/",
    "https://secondhandforklifts.com.au/forklift/new-ep-efxz301-3-0-tonne-lithium-electric-forklift/",
    "https://secondhandforklifts.com.au/forklift/new-ep-efxz301-3-0-tonne-lithium-electric-forklift/",
    "https://secondhandforklifts.com.au/forklift/new-ep-tdl201-2-0-tonne-lithium-electric-forklift/",
    "https://secondhandforklifts.com.au/forklift/new-ep-tdl201-2-0-tonne-lithium-electric-forklift/",
    "https://secondhandforklifts.com.au/forklift/new-ep-tdl201-2-0-tonne-lithium-electric-forklift/",
    "https://secondhandforklifts.com.au/forklift/new-ep-tcl101-1-0-tonne-lithium-electric-forklift/",
    "https://secondhandforklifts.com.au/forklift/new-ep-tcl101-1-0-tonne-lithium-electric-forklift/",
    "https://secondhandforklifts.com.au/forklift/new-ep-tcl101-1-0-tonne-lithium-electric-forklift/",
    "https://secondhandforklifts.com.au/forklift/new-ep-efl353-3-5-tonne-lithium-electric-forklift/",
    "https://secondhandforklifts.com.au/forklift/new-ep-efl353-3-5-tonne-lithium-electric-forklift/",
    "https://secondhandforklifts.com.au/forklift/new-ep-efl353-3-5-tonne-lithium-electric-forklift/",
    "https://secondhandforklifts.com.au/forklift/new-ep-efl181-1-8-tonne-lithium-electric-forklift/",
    "https://secondhandforklifts.com.au/forklift/new-ep-efl181-1-8-tonne-lithium-electric-forklift/",
    "https://secondhandforklifts.com.au/forklift/new-ep-efl181-1-8-tonne-lithium-electric-forklift/",
    "https://secondhandforklifts.com.au/forklift/new-ep-efl253-2-5-tonne-lithium-electric-forklift/",
    "https://secondhandforklifts.com.au/forklift/new-ep-efl253-2-5-tonne-lithium-electric-forklift/",
    "https://secondhandforklifts.com.au/forklift/new-ep-efl253-2-5-tonne-lithium-electric-forklift/",
    "https://secondhandforklifts.com.au/forklift/new-ep-efl253p-2-5-tonne-lithium-electric-forklift/",
    "https://secondhandforklifts.com.au/forklift/new-ep-efl253p-2-5-tonne-lithium-electric-forklift/",
    "https://secondhandforklifts.com.au/forklift/new-ep-efl253p-2-5-tonne-lithium-electric-forklift/",
    "https://secondhandforklifts.com.au/forklift/new-ride-on-floor-sweeper-s4-buy-now/",
    "https://secondhandforklifts.com.au/forklift/new-ride-on-floor-sweeper-s4-buy-now/",
    "https://secondhandforklifts.com.au/forklift/new-ride-on-floor-sweeper-s4-buy-now/",
    "https://secondhandforklifts.com.au/forklift/new-pallet-jack-allterain-electric-buy-now/",
    "https://secondhandforklifts.com.au/forklift/new-pallet-jack-allterain-electric-buy-now/",
    "https://secondhandforklifts.com.au/forklift/new-pallet-jack-allterain-electric-buy-now/",
    "https://secondhandforklifts.com.au/forklift/new-heli-1-5-tonne/",
    "https://secondhandforklifts.com.au/forklift/new-heli-1-5-tonne/",
    "https://secondhandforklifts.com.au/forklift/new-heli-1-5-tonne/",
    "https://secondhandforklifts.com.au/forklift/new-heli-4x4-3-5-tonne-all-terrain-forklift-buy-now/",
    "https://secondhandforklifts.com.au/forklift/new-heli-4x4-3-5-tonne-all-terrain-forklift-buy-now/",
    "https://secondhandforklifts.com.au/forklift/new-heli-4x4-3-5-tonne-all-terrain-forklift-buy-now/",
    "https://secondhandforklifts.com.au/forklift/brand-new-heli-7-tonne-4-5m-forklift-buy-now/",
    "https://secondhandforklifts.com.au/forklift/brand-new-heli-7-tonne-4-5m-forklift-buy-now/",
    "https://secondhandforklifts.com.au/forklift/brand-new-heli-7-tonne-4-5m-forklift-buy-now/",
    "https://secondhandforklifts.com.au/forklift/brand-new-heli-5-tonne-4-5m-forklift-buy-now/",
    "https://secondhandforklifts.com.au/forklift/brand-new-heli-5-tonne-4-5m-forklift-buy-now/",
    "https://secondhandforklifts.com.au/forklift/brand-new-heli-5-tonne-4-5m-forklift-buy-now/",
    "https://secondhandforklifts.com.au/forklift/heli-diesel-2-5-tonne-forklift/",
    "https://secondhandforklifts.com.au/forklift/heli-diesel-2-5-tonne-forklift/",
    "https://secondhandforklifts.com.au/forklift/heli-diesel-2-5-tonne-forklift/",
    "https://secondhandforklifts.com.au/new/",
    "https://secondhandforklifts.com.au/affordable/",
    "https://secondhandforklifts.com.au/lpg-petrol-diesel-used-forklifts/",
    "https://secondhandforklifts.com.au/diesel-forklifts/",
    "https://secondhandforklifts.com.au/lpg-petrol-diesel-used-forklifts/0-2-tonne-forklifts/",
    "https://secondhandforklifts.com.au/lpg-petrol-diesel-used-forklifts/2-5-4-tonne-forklifts/",
    "https://secondhandforklifts.com.au/lpg-petrol-diesel-used-forklifts/4-5-tonne-and-over-forklifts/",
    "https://secondhandforklifts.com.au/speciality-forklifts/",
    "https://secondhandforklifts.com.au/heli",
    "https://secondhandforklifts.com.au/toyota",
    "https://secondhandforklifts.com.au/hyster",
    "https://secondhandforklifts.com.au/crown/",
    "https://secondhandforklifts.com.au/yale/",
    "https://secondhandforklifts.com.au/mitsubishi/",
    "https://secondhandforklifts.com.au/used-forklifts/",
    "https://secondhandforklifts.com.au/used-forklifts/",
    "https://secondhandforklifts.com.au
://secondhandforklifts.com.au/lpg-petrol-diesel-used-forklifts/
# https://secondhandforklifts.com.au/lpg-petrol-diesel-used-forklifts/0-2-tonne-forklifts/
# ...

# %%
import os
import re
import requests
import trafilatura
from urllib.parse import urlparse
from bs4 import BeautifulSoup

def clean_filename(url):
    """Convert URL to a safe filename"""
    parsed = urlparse(url)
    filename = parsed.netloc + parsed.path
    filename = re.sub(r'[^a-zA-Z0-9_-]', '_', filename)  # replace unsafe chars
    return filename.strip("_") + ".txt"

def extract_text_with_title(url, html_text, output_dir):
    """Extract readable text and prepend the page title as header"""
    # Parse title using BeautifulSoup
    soup = BeautifulSoup(html_text, "html.parser")
    title = soup.title.string.strip() if soup.title and soup.title.string else "No Title Found"

    # Extract main readable text
    extracted_text = trafilatura.extract(html_text)
    if not extracted_text:
        print(f"[WARN] Could not extract main content from {url}")
        extracted_text = ""

    # Prepare full text (Title + separator + content)
    final_text = f"{title}\n{'=' * len(title)}\n\n{extracted_text}"

    # Create file name based on URL
    filename = clean_filename(url)
    filepath = os.path.join(output_dir, filename)

    # Save extracted text
    with open(filepath, "w", encoding="utf-8") as f:
        f.write(final_text)

    print(f"[OK] Saved: {filepath}")

# === Main Config ===
output_dir = "secondhandforklifts"

os.makedirs(output_dir, exist_ok=True)

# Assume unique_urls is defined elsewhere
for url in unique_urls:
    try:
        print(f"[INFO] Fetching: {url}")
        response = requests.get(url, timeout=10)
        response.raise_for_status()

        # Extract and save with title
        extract_text_with_title(url, response.text, output_dir)

    except requests.exceptions.RequestException as e:
        print(f"[ERROR] Failed to fetch {url} -> {e}")
# Out:
# [INFO] Fetching: https://secondhandforklifts.com.au/
# [OK] Saved: secondhandforklifts/secondhandforklifts_com_au.txt
# [INFO] Fetching: https://secondhandforklifts.com.au/heli/
# [OK] Saved: secondhandforklifts/secondhandforklifts_com_au_heli.txt
# [INFO] Fetching: https://secondhandforklifts.com.au/forklift/heli-g3-4-tonne-5-5-tonne-g3-internal-combustion-forklift/
# [OK] Saved: secondhandforklifts/secondhandforklifts_com_au_forklift_heli-g3-4-tonne-5-5-tonne-g3-internal-combustion-forklift.txt
# [INFO] Fetching: https://secondhandforklifts.com.au/forklift/heli-h3-series-2-2-8-tonne-lpg-forklift/
# [OK] Saved: secondhandforklifts/secondhandforklifts_com_au_forklift_heli-h3-series-2-2-8-tonne-lpg-forklift.txt
# [INFO] Fetching: https://secondhandforklifts.com.au/forklift/heli-g3-3-wheel-lithium-battery-electric-forklift/
# [OK] Saved: secondhandforklifts/secondhandforklifts_com_au_forklift_heli-g3-3-wheel-lithium-battery-electric-forklift.txt
# ...

# %%
import os

def merge_text_files(folder_path, output_file):
    """
    Merge all .txt files in the specified folder into a single text file.
    Each file's content is separated by a header (the filename).
    """
    # Get all text files in folder
    text_files = [f for f in os.listdir(folder_path) if f.endswith(".txt")]

    if not text_files:
        print("No text files found in the folder.")
        return

    with open(output_file, "w", encoding="utf-8") as outfile:
        for filename in text_files:
            file_path = os.path.join(folder_path, filename)

            # Write file content
            with open(file_path, "r", encoding="utf-8") as infile:
                content = infile.read()
                outfile.write(content)

    print(f"✅ Successfully merged {len(text_files)} files into '{output_file}'")

if __name__ == "__main__":
    # Example usage:
    folder = "secondhandforklifts"          # Folder containing text files
    output = "secondhandforklifts.txt" # Output file name
    merge_text_files(folder, output)
# Out:
# ✅ Successfully merged 438 files into 'secondhandforklifts.txt'

# %%
shutil.make_archive("secondhandforklifts", 'zip', "secondhandforklifts")
print(f"\n[FINAL] All extracted pages have been zipped into: {zip_name}.zip")
# Out:
# [FINAL] All extracted pages have been zipped into: secondhandforklifts.zip
