# %%
#

import requests

url = "https://api.rocketreach.co/api/v2/person/search"

payload = { "query": { "company_domain": ["calvarycare.org.au"] } }
headers = {
    "accept": "application/json",
    "content-type": "application/json",
    "Api-Key": ""
}

response = requests.post(url, json=payload, headers=headers)

print(response.text)
# Out:
# {"pagination":{"start":1,"next":11,"total":1796},"profiles":[{"id":825402040,"status":"not queued","name":"Sj B","profile_pic":"https://d2gjqh9j26unp0.cloudfront.net/profilepic/cead40c82ecf974503402505f831b8df","links":null,"linkedin_url":"https://www.linkedin.com/in/sj-b-0a5b0b295","location":"Mount Stuart, TAS, AU","city":"Mount Stuart","region":"TAS","country":"Australia","country_code":"AU","current_title":"After Hours Hospital Coordinator","current_employer":"Calvary Health Care","current_employer_domain":"calvarycare.org.au","current_employer_website":"https://www.calvarycare.org.au/retirement-communities/","teaser":{"emails":[],"phones":[],"preview":["calvarycare.org.au","gmail.com"],"is_premium_phone_available":false,"personal_emails":[],"professional_emails":[]},"birth_year":null,"current_employer_id":1264937,"current_employer_linkedin_url":"https://www.linkedin.com/company/calvaryretirement","region_latitude":-42.8729302,"region_longitude":147.3013674,"suppressed":false,"npi_data":null,"update_time":"2026-01-14T09:57:37.824441"},{"id":843118619,"status":"progress","name":"Ria McEwan","profile_pic":"https://s3.amazonaws.com/media.mixrank.com/profilepic/b2b3dc12d74767b73a9fdd089663c0a0","links":null,"linkedin_url":"https://www.linkedin.com/in/ria-mcewan-3aa39395","location":"Darwin, NT, AU","city":"Darwin","region":"NT ","country":"Australia","country_code":"AU","current_title":"Client Services Coordinator","current_employer":"Calvary Health Care","current_employer_domain":"calvarycare.org.au","current_employer_website":"https://www.calvarycare.org.au/retirement-communities/","teaser":{"emails":["calvarycare.org.au"],"phones":[],"preview":[],"is_premium_phone_available":false,"personal_emails":[],"professional_emails":["calvarycare.org.au"]},"birth_year":null,"current_employer_id":1264937,"current_employer_linkedin_url":"https://www.linkedin.com/company/calvaryretirement","region_latitude":-12.4634403,"region_longitude":130.8456418,"suppressed":false,"npi_data":null,"update_time":"2025-09-10T09:36:38.579984"},{"id":846910961,"status":"progress","name":"Justine Johnston","profile_pic":"https://s3.amazonaws.com/media.mixrank.com/profilepic/d639ec29152873fa6ba5501c5512e98f","links":null,"linkedin_url":"https://www.linkedin.com/in/justine-johnston-a3b7322b9","location":"Canberra, ACT, AU","city":"Canberra","region":"ACT","country":"Australia","country_code":"AU","current_title":"Registered Nurse","current_employer":"Calvary Health Care","current_employer_domain":"calvarycare.org.au","current_employer_website":"https://www.calvarycare.org.au/retirement-communities/","teaser":{"emails":["calvarycare.org.au"],"phones":[],"preview":[],"is_premium_phone_available":false,"personal_emails":[],"professional_emails":["calvarycare.org.au"]},"birth_year":null,"current_employer_id":1264937,"current_employer_linkedin_url":"https://www.linkedin.com/company/calvaryretirement","region_latitude":-35.2809368,"region_longitude":149.1300092,"suppressed":false,"npi_data":null,"update_time":"2025-09-10T11:56:46.110938"},{"id":32077654,"status":"complete","name":"Tony Cusack","profile_pic":"https://d2gjqh9j26unp0.cloudfront.net/profilepic/884e78e53574ce782bbb4aa455701f1d","links":null,"linkedin_url":"https://www.linkedin.com/in/tony-cusack-672a1569","location":"Adelaide, SA, AU","city":"Adelaide","region":"SA ","country":"Australia","country_code":"AU","current_title":"Hospitality Services Manager","current_employer":"Calvary Health Care","current_employer_domain":"calvarycare.org.au","current_employer_website":"https://www.calvarycare.org.au/retirement-communities/","teaser":{"emails":["calvarycare.org.au"],"phones":[],"preview":[],"is_premium_phone_available":false,"personal_emails":[],"professional_emails":["calvarycare.org.au"]},"birth_year":1963,"current_employer_id":1264937,"current_employer_linkedin_url":"https://www.linkedin.com/company/calvaryretirement","region_latitude":-34.9284989,"region_longitude":138.6007456,"suppressed":false,"np ...
