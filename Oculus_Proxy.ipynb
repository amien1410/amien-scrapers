# %%
import requests
from bs4 import BeautifulSoup

# Proxy setup with authentication
proxy = {
    "http": f"{username}:{password}@{host}:{port}",
    "https": f"{username}:{password}@{host}:{port}",
}

# Target URL to verify the proxy
url = "https://httpbin.org/ip"  # Returns the IP address of the request

try:
    # Make the request using the proxy
    response = requests.get(url, proxies=proxy, timeout=10)
    response.raise_for_status()  # Raise an error for HTTP issues

    # Parse the content with BeautifulSoup
    soup = BeautifulSoup(response.text, "html.parser")

    # Print the response
    print("Response Content (IP Address):")
    print(soup.prettify())

except requests.exceptions.RequestException as e:
    print("Error occurred while using the proxy:", e)
# Out:
# Error occurred while using the proxy: Please check proxy URL. It is malformed and could be missing the host.

# %%
import random
session_id = random.randint(0, 99999)
print(f"Generated session ID: {session_id}")
# Out:
# Generated session ID: 90777

# %%
username = "oc-3a10ab7b1e3ab933925212b309211af5ade61c54faaedaccc18d7743a8bccf38-country-US-session-90777"
password = "bm9ncutd1e97"
host = "proxy.oculus-proxy.com"
port = "31111"

# %%
import requests

# URL to scrape
url = 'https://www.homedepot.com/'  # Replace with the desired website URL

# Proxy configuration with login and password
proxy_host = "gw.dataimpulse.com"
proxy_port = 823
proxy_login = "f1bdc8e207aafe131216"
proxy_password = "6c1b9cdd85f65f0b"
proxy = f'http://35bf745b8966f72d1df5:356e064773a532ee@gw.dataimpulse.com:823'

proxies = {
    'http': proxy,
    'https': proxy
}

# Send a GET request using the proxy
response = requests.get(url, proxies=proxies)

# Check if the request was successful
if response.status_code == 200:
    # Process the response content
    print(response.text)
else:
    print('Request failed with status code:', response.status_code)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     772                 try:
# --> 773                     self._prepare_proxy(conn)
#     774                 except (BaseSSLError, OSError, SocketTimeout) as e:
#
# /usr/local/lib/python3.12/dist-packages/urllib3/connectionpool.py in _prepare_proxy(self, conn)
#    1041         )
# -> 1042         conn.connect()
#    1043
#
# /usr/local/lib/python3.12/dist-packages/urllib3/connection.py in connect(self)
#     769
# --> 770                 self._tunnel()
#     771                 # Override the host with the one we're requesting data from.
#
# ...

# %%
import requests
import time

# !pip install fake_useragent

from fake_useragent import UserAgent

def fetch_and_save_to_file(url, path, proxies, headers):
    # r = requests.get(url)
    r = session.get(url, proxies=proxies, headers=headers)
    with open(path, "w",  encoding="utf-8") as file:
        file.write(r.text)


session = requests.Session()
headers = {

    'User-Agent': UserAgent().random,
    'Accept-Language': 'en-Us,en;q=0.9',
    'Accept-Encoding': 'gzip . deflate, br',
    'Connection': 'keep-alive',
    'Referer': 'https://www.google.com'
}



proxy_auth = "791149d37c1c6ba881cb__cr.ca,in,cl,au:8e900@gw.dataimpulse.com:823"
proxies = {
    "http" : f"http://{proxy_auth}",
    "https": f"https://{proxy_auth}"

}
path = "data.html"
url = "https://www.amazon.in/s?bbn=81107433031&rh=n%3A81107433031%2Cp_85%3A10440599031&_encoding=UTF8&content-id=amzn1.sym.58c90a12-100b-4a2f-8e15-7c06f1abe2be&pd_rd_r=1aac9c1e-e0c4-4e49-9fc5-dfd3a794e45f&pd_rd_w=yiHZj&pd_rd_wg=hKXbq&pf_rd_p=58c90a12-100b-4a2f-8e15-7c06f1abe2be&pf_rd_r=JKJK7ZVX68HV54TGNKDS&ref=pd_hp_d_atf_unk"


fetch_and_save_to_file(url, path, proxies, headers)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     772                 try:
# --> 773                     self._prepare_proxy(conn)
#     774                 except (BaseSSLError, OSError, SocketTimeout) as e:
#
# /usr/local/lib/python3.12/dist-packages/urllib3/connectionpool.py in _prepare_proxy(self, conn)
#    1041         )
# -> 1042         conn.connect()
#    1043
#
# /usr/local/lib/python3.12/dist-packages/urllib3/connection.py in connect(self)
#     769
# --> 770                 self._tunnel()
#     771                 # Override the host with the one we're requesting data from.
#
# ...
