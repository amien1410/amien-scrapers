# %%
#@title Tripadvisor - Rapidapi


import requests
import json

headers = {
    'x-rapidapi-key': '943aa62b88msha1ca6ea2b408db1p1e2547jsnd725cfd16499',
    "x-rapidapi-host": "tripadvisor16.p.rapidapi.com"
}
# querystring = {"query":"Banjarmasin"}
# response = requests.get(url, headers=headers, params=querystring)

url = "https://tripadvisor16.p.rapidapi.com/api/v1/hotels/getHotelsFilter"
querystring = {
    "geoId": "303950",
    "checkIn": "2025-11-10",
    "checkOut": "2025-11-14"
}
response = requests.get(url, headers=headers, params=querystring)

print(json.dumps(response.json(), indent=2))
# Out:
# {
#   "message": "You are not subscribed to this API."
# }

# %%
#@title Booking-Rapidapi

import requests
search_url = "https://booking-com15.p.rapidapi.com/api/v1/hotels/searchDestination"
search_querystring = {"query": "budapest", "filter_by_currency": "BDT", "checkin_date": "2025-10-10", "checkout_date": "2025-10-15", "adults_number": "2", "room_number": "1", "order_by": "popularity"}
headers = {
    "x-rapidapi-key": "",
    "x-rapidapi-host": "booking-com15.p.rapidapi.com"
}

# Send GET request to the API
response = requests.get(search_url, headers=headers, params=search_querystring)
response.json()
# Out:
# {'status': True,
#  'message': 'Success',
#  'timestamp': 1762473802529,
#  'data': [{'dest_id': '-850553',
#    'search_type': 'city',
#    'cc1': 'hu',
#    'label': 'Budapest, Central Hungary, Hungary',
#    'city_name': 'Budapest',
#    'city_ufi': None,
#    'longitude': 19.0559,
#    'type': 'ci',
#    'latitude': 47.4974,
#    'lc': 'en',
#    'name': 'Budapest',
#    'roundtrip': 'GhA0MmE5MDA2NWY3M2QwMmQ1IAAoATICZW46CGJ1ZGFwZXN0QABKAFAA',
#    'image_url': 'https://cf.bstatic.com/xdata/images/city/150x150/977212.jpg?k=44557e7dca8e827b14aac8e152ee8b20a1cd4e17215e0dc75a6cb4cdedc78311&o=',
#    'nr_hotels': 8920,
#    'dest_type': 'city',
#    'hotels': 8920,
#    'region': 'Central Hungary',
#    'country': 'Hungary'},
#   {'dest_id': '2279',
#    'search_type': 'district',
#    'lc': 'en',
#    'name': 'Budapest City Centre',
#    'roundtrip': 'GhA0MmE5MDA2NWY3M2QwMmQ1IAEoATICZW46CGJ1ZGFwZXN0QABKAFAA',
#    'nr_hotels': 6081,
# ...
