# %%
#@title Tripadvisor - Rapidapi
# cecc5c6906msh1af22ff87f0f34ap105724jsn22ee0fec224a
# f6486da12amsh6bb194f4a42c4a2p1df1b9jsn07dd8eb24961
# bffcc9a048mshe59ea5b3089de14p1f41b1jsn84b09936a31a
# 0916e7c493mshac98414bf7ef0dcp10608ajsn34ef6e8d81d7
# e2262991e2mshd620a6a0d79a320p19181djsn46bab34a1096
# 0e83f699f5mshc8cc46315bd29a8p107b6cjsndade9a613caa
# e6d19a3739msh53938220f885404p113e5ajsn11ed19d0cb54
# 4103f73080msh91a9a41eaedc05cp151552jsncfbd53686894
# 676eb17295msh8225b8583bc5643p16ec41jsnff933a681d72
# 1094431a69msh94d0bb0346f032fp11055ejsnb4ac28ef5ea2



import requests
import json

headers = {
    'x-rapidapi-key': '943aa62b88msha1ca6ea2b408db1p1e2547jsnd725cfd16499',
    "x-rapidapi-host": "tripadvisor16.p.rapidapi.com"
}
# querystring = {"query":"Banjarmasin"}
# response = requests.get(url, headers=headers, params=querystring)

url = "https://tripadvisor16.p.rapidapi.com/api/v1/hotels/getHotelsFilter"
querystring = {
    "geoId": "303950",
    "checkIn": "2025-11-10",
    "checkOut": "2025-11-14"
}
response = requests.get(url, headers=headers, params=querystring)

print(json.dumps(response.json(), indent=2))
# Out:
# {
#   "message": "You are not subscribed to this API."
# }

# %%
#@title Booking-Rapidapi
# q=booking-com15.p.rapidapi.com%20AND%20jsn&type=code&p=2
# 0ec75bfd4bmsh619d22cc21e2e29p13405ejsn8bdaab1b2017
# e7d0b588bbmsh6c4bc37116d55c3p1aa48ejsn36b0635317f0
# 4ca67c45e8msh550d34947a5a148p1718abjsnfed5a3b51096
# 81357f4e6amshd9747382dea2034p13a7f2jsn886ab9aa5f60
# a1c077e666mshaf95f0491cb17aap16aed6jsn1c2d8f67b04b
# 505effbf24msh417b1aeaeb14b0ap1a3803jsne7b48bea444e
# 85d8f6762dmshe27a1db3a9a4bfdp12ecf5jsncf7acbce2f5f
# 97c6cac96amshf7cfe7731f1f3e4p184c8ejsn586eed84dc6b
# 48bbb58dfdmshb1718674f5b879ap105aaajsn5936fc8b7282
# d216cd50fcmshab7d60facfefe23p1462d3jsn1f28ca135bd8
# 47aa077e79msh3aa641c74b24ecep1c9291jsned53c1e5db74
# 18e9c4d049msh55d12aa03a6b9f3p16b6cdjsn642a94cca2b0
# 745f5cc62bmsh01d2f1add8bad25p1381c0jsn8dfda3ce0e55
# b8bf90b99bmsh9540311617cb430p197706jsna1b29936408f
# 558ebf66bemshe6714643ab3108cp1c2522jsn12e0690dd16f
# 3469f8d188msh02d68401d560291p168f15jsn453451bf3405
# 2e7aa97237msh89ce8f771546c47p1fe7acjsn105dde33f0df
# e5f65929a5mshe3264eb6a810caep120bb5jsndf623e4e3242
# 3fe9c36100mshd1053ab965460bfp12ba87jsndec9dd624d16


import requests
search_url = "https://booking-com15.p.rapidapi.com/api/v1/hotels/searchDestination"
search_querystring = {"query": "budapest", "filter_by_currency": "BDT", "checkin_date": "2025-10-10", "checkout_date": "2025-10-15", "adults_number": "2", "room_number": "1", "order_by": "popularity"}
headers = {
    "x-rapidapi-key": "",
    "x-rapidapi-host": "booking-com15.p.rapidapi.com"
}

# Send GET request to the API
response = requests.get(search_url, headers=headers, params=search_querystring)
response.json()
# Out:
# {'status': True,
#  'message': 'Success',
#  'timestamp': 1762473802529,
#  'data': [{'dest_id': '-850553',
#    'search_type': 'city',
#    'cc1': 'hu',
#    'label': 'Budapest, Central Hungary, Hungary',
#    'city_name': 'Budapest',
#    'city_ufi': None,
#    'longitude': 19.0559,
#    'type': 'ci',
#    'latitude': 47.4974,
#    'lc': 'en',
#    'name': 'Budapest',
#    'roundtrip': 'GhA0MmE5MDA2NWY3M2QwMmQ1IAAoATICZW46CGJ1ZGFwZXN0QABKAFAA',
#    'image_url': 'https://cf.bstatic.com/xdata/images/city/150x150/977212.jpg?k=44557e7dca8e827b14aac8e152ee8b20a1cd4e17215e0dc75a6cb4cdedc78311&o=',
#    'nr_hotels': 8920,
#    'dest_type': 'city',
#    'hotels': 8920,
#    'region': 'Central Hungary',
#    'country': 'Hungary'},
#   {'dest_id': '2279',
#    'search_type': 'district',
#    'lc': 'en',
#    'name': 'Budapest City Centre',
#    'roundtrip': 'GhA0MmE5MDA2NWY3M2QwMmQ1IAEoATICZW46CGJ1ZGFwZXN0QABKAFAA',
#    'nr_hotels': 6081,
# ...

# %%
#@title Airbnb - Rapidapi

import requests

url = "https://airbnb19.p.rapidapi.com/api/v2/searchPropertyByPlaceId"
querystring = {"placeId":"ChIJ7cv00DwsDogRAMDACa2m4K8","adults":"1","guestFavorite":"false","ib":"false","currency":"USD"}
headers = {
    "x-rapidapi-key": "",
    "x-rapidapi-host": "airbnb19.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
response.json()
# Out:
# {'status': True,
#  'message': 'Success',
#  'timestamp': 1762475462702,
#  'data': {'pageTitle': 'Over 1,000 homes',
#   'hasNextPage': True,
#   'nextPageCursor': 'eyJzZWN0aW9uX29mZnNldCI6MCwiaXRlbXNfb2Zmc2V0Ijo0MCwidmVyc2lvbiI6MX0=',
#   'list': [{'__typename': 'StaySearchResult',
#     'listing': {'availabilityDescription': None,
#      'legacyCity': 'Chicago',
#      'legacyCoordinate': {'longitude': -87.62635, 'latitude': 41.89161},
#      'currentHydrationInfo': {'listingHydrationUuid': '-723246145',
#       'originalFederatedSearchId': '96eb0c73-50b1-4d60-97dc-54f0ef8667b2'},
#      'id': '1538630607971669322',
#      'legacyIsAutoTranslated': False,
#      'legacyLocalizedCityName': 'Chicago',
#      'legacyName': 'Convenient Stay In The Heart of River North',
#      'primaryHostPassport': None,
#      'legacyPDPType': 'MARKETPLACE',
#      'title': 'Shared hotel room in Chicago',
#      'titleLocale': 'en'},
#     'demandStayListing': {'location': {'city': 'Chicago',
# ...
