# %%
import requests

url = "https://zillow-working-api.p.rapidapi.com/graph_charts"
querystring = {"recent_first":"True","which":"zestimate_history","byzpid":"30907787","byurl":"https://www.zillow.com/homedetails/3-W-Forest-Dr-Rochester-NY-14624/30907787_zpid/","byaddress":"3 W Forest Dr, Rochester, NY 14624"}

headers = {
    "x-rapidapi-host": "zillow-working-api.p.rapidapi.com",
    "x-rapidapi-key": ""
}

response = requests.get(url, headers=headers, params=querystring)
response.json()
# Out:
# {'message': '200: Success',
#  'source': '9vrc_ws',
#  'GraphType': 'zestimate_history',
#  'RecentFirst': True,
#  'DataPoints': {'city': 'Rochester',
#   'state': 'NY',
#   'streetAddress': '3 W Forest Dr',
#   'zipcode': '14624',
#   'homeValueChartData': [{'points': [{'x': 1762416000000, 'y': 325100},
#      {'x': 1761894000000, 'y': 327700},
#      {'x': 1759215600000, 'y': 335000},
#      {'x': 1756623600000, 'y': 332900},
#      {'x': 1753945200000, 'y': 337700},
#      {'x': 1751266800000, 'y': 335800},
#      {'x': 1748674800000, 'y': 344100},
#      {'x': 1745996400000, 'y': 340100},
#      {'x': 1743404400000, 'y': 329800},
#      {'x': 1740729600000, 'y': 321300},
#      {'x': 1738310400000, 'y': 320900},
#      {'x': 1735632000000, 'y': 317500},
#      {'x': 1732953600000, 'y': 317800},
#      {'x': 1730358000000, 'y': 316600},
#      {'x': 1727679600000, 'y': 321300},
#      {'x': 1725087600000, 'y': 329000},
#      {'x': 1722409200000, 'y': 325800},
# ...
