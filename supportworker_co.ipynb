# %%
urls = [
    "https://supportworker.co/",
    "https://supportworker.co/",
    "https://supportworker.co/services/",
    "https://supportworker.co/industries/",
    "https://supportworker.co/resources/",
    "https://supportworker.co/about-us/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact",
    "https://supportworker.co/services/",
    "https://supportworker.co/industries/",
    "https://supportworker.co/resources/",
    "https://supportworker.co/about-us/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact",
    "https://supportworker.co/services/",
    "https://supportworker.co/staffing-solutions/",
    "https://supportworker.co/rostering-services/",
    "https://supportworker.co/recruitment-services/",
    "https://supportworker.co/industries/",
    "https://supportworker.co/disability-support/",
    "https://supportworker.co/residential-care/",
    "https://supportworker.co/aged-care/",
    "https://supportworker.co/resources/",
    "https://supportworker.co/about-us/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact",
    "https://supportworker.co/services/",
    "https://supportworker.co/staffing-solutions/",
    "https://supportworker.co/rostering-services/",
    "https://supportworker.co/recruitment-services/",
    "https://supportworker.co/industries/",
    "https://supportworker.co/disability-support/",
    "https://supportworker.co/residential-care/",
    "https://supportworker.co/aged-care/",
    "https://supportworker.co/resources/",
    "https://supportworker.co/about-us/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/staffing-agency/",
    "https://supportworker.co/rostering-services/",
    "https://supportworker.co/recruitment-services/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/",
    "https://supportworker.co/#",
    "https://supportworker.co/#",
    "https://supportworker.co/resources/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/#",
    "https://supportworker.co/#"
    "https://supportworker.co/",
    "https://supportworker.co/",
    "https://supportworker.co/services/",
    "https://supportworker.co/industries/",
    "https://supportworker.co/resources/",
    "https://supportworker.co/about-us/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact",
    "https://supportworker.co/services/",
    "https://supportworker.co/staffing-solutions/",
    "https://supportworker.co/rostering-services/",
    "https://supportworker.co/recruitment-services/",
    "https://supportworker.co/industries/",
    "https://supportworker.co/disability-support/",
    "https://supportworker.co/residential-care/",
    "https://supportworker.co/aged-care/",
    "https://supportworker.co/resources/",
    "https://supportworker.co/about-us/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/",
    "https://supportworker.co/staffing-solutions/#",
    "https://supportworker.co/staffing-solutions/#",
    "https://supportworker.co/resources/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/staffing-solutions/#",
    "https://supportworker.co/staffing-solutions/#"
    "https://supportworker.co/",
    "https://supportworker.co/",
    "https://supportworker.co/services/",
    "https://supportworker.co/industries/",
    "https://supportworker.co/resources/",
    "https://supportworker.co/about-us/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact",
    "https://supportworker.co/services/",
    "https://supportworker.co/industries/",
    "https://supportworker.co/resources/",
    "https://supportworker.co/about-us/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact",
    "https://supportworker.co/services/",
    "https://supportworker.co/staffing-solutions/",
    "https://supportworker.co/rostering-services/",
    "https://supportworker.co/recruitment-services/",
    "https://supportworker.co/industries/",
    "https://supportworker.co/disability-support/",
    "https://supportworker.co/residential-care/",
    "https://supportworker.co/aged-care/",
    "https://supportworker.co/resources/",
    "https://supportworker.co/about-us/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact",
    "https://supportworker.co/services/",
    "https://supportworker.co/staffing-solutions/",
    "https://supportworker.co/rostering-services/",
    "https://supportworker.co/recruitment-services/",
    "https://supportworker.co/industries/",
    "https://supportworker.co/disability-support/",
    "https://supportworker.co/residential-care/",
    "https://supportworker.co/aged-care/",
    "https://supportworker.co/resources/",
    "https://supportworker.co/about-us/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/",
    "https://supportworker.co/rostering-services/#",
    "https://supportworker.co/rostering-services/#",
    "https://supportworker.co/resources/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/rostering-services/#",
    "https://supportworker.co/rostering-services/#"
    "https://supportworker.co/",
    "https://supportworker.co/",
    "https://supportworker.co/services/",
    "https://supportworker.co/industries/",
    "https://supportworker.co/resources/",
    "https://supportworker.co/about-us/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact",
    "https://supportworker.co/services/",
    "https://supportworker.co/industries/",
    "https://supportworker.co/resources/",
    "https://supportworker.co/about-us/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact",
    "https://supportworker.co/services/",
    "https://supportworker.co/staffing-solutions/",
    "https://supportworker.co/rostering-services/",
    "https://supportworker.co/recruitment-services/",
    "https://supportworker.co/industries/",
    "https://supportworker.co/disability-support/",
    "https://supportworker.co/residential-care/",
    "https://supportworker.co/aged-care/",
    "https://supportworker.co/resources/",
    "https://supportworker.co/about-us/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact",
    "https://supportworker.co/services/",
    "https://supportworker.co/staffing-solutions/",
    "https://supportworker.co/rostering-services/",
    "https://supportworker.co/recruitment-services/",
    "https://supportworker.co/industries/",
    "https://supportworker.co/disability-support/",
    "https://supportworker.co/residential-care/",
    "https://supportworker.co/aged-care/",
    "https://supportworker.co/resources/",
    "https://supportworker.co/about-us/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/",
    "https://supportworker.co/recruitment-services/#",
    "https://supportworker.co/recruitment-services/#",
    "https://supportworker.co/resources/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/recruitment-services/#",
    "https://supportworker.co/recruitment-services/#"
    "https://supportworker.co/",
    "https://supportworker.co/",
    "https://supportworker.co/services/",
    "https://supportworker.co/industries/",
    "https://supportworker.co/resources/",
    "https://supportworker.co/about-us/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact",
    "https://supportworker.co/services/",
    "https://supportworker.co/industries/",
    "https://supportworker.co/resources/",
    "https://supportworker.co/about-us/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact",
    "https://supportworker.co/services/",
    "https://supportworker.co/staffing-solutions/",
    "https://supportworker.co/rostering-services/",
    "https://supportworker.co/recruitment-services/",
    "https://supportworker.co/industries/",
    "https://supportworker.co/disability-support/",
    "https://supportworker.co/residential-care/",
    "https://supportworker.co/aged-care/",
    "https://supportworker.co/resources/",
    "https://supportworker.co/about-us/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact",
    "https://supportworker.co/services/",
    "https://supportworker.co/staffing-solutions/",
    "https://supportworker.co/rostering-services/",
    "https://supportworker.co/recruitment-services/",
    "https://supportworker.co/industries/",
    "https://supportworker.co/disability-support/",
    "https://supportworker.co/residential-care/",
    "https://supportworker.co/aged-care/",
    "https://supportworker.co/resources/",
    "https://supportworker.co/about-us/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/staffing-agency/",
    "https://supportworker.co/rostering-services/",
    "https://supportworker.co/recruitment-services/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/",
    "https://supportworker.co/disability-support/#",
    "https://supportworker.co/disability-support/#",
    "https://supportworker.co/resources/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/disability-support/#",
    "https://supportworker.co/disability-support/#"
    "https://supportworker.co/",
    "https://supportworker.co/",
    "https://supportworker.co/services/",
    "https://supportworker.co/industries/",
    "https://supportworker.co/resources/",
    "https://supportworker.co/about-us/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact",
    "https://supportworker.co/services/",
    "https://supportworker.co/industries/",
    "https://supportworker.co/resources/",
    "https://supportworker.co/about-us/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact",
    "https://supportworker.co/services/",
    "https://supportworker.co/staffing-solutions/",
    "https://supportworker.co/rostering-services/",
    "https://supportworker.co/recruitment-services/",
    "https://supportworker.co/industries/",
    "https://supportworker.co/disability-support/",
    "https://supportworker.co/residential-care/",
    "https://supportworker.co/aged-care/",
    "https://supportworker.co/resources/",
    "https://supportworker.co/about-us/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact",
    "https://supportworker.co/services/",
    "https://supportworker.co/staffing-solutions/",
    "https://supportworker.co/rostering-services/",
    "https://supportworker.co/recruitment-services/",
    "https://supportworker.co/industries/",
    "https://supportworker.co/disability-support/",
    "https://supportworker.co/residential-care/",
    "https://supportworker.co/aged-care/",
    "https://supportworker.co/resources/",
    "https://supportworker.co/about-us/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/staffing-agency/",
    "https://supportworker.co/rostering-services/",
    "https://supportworker.co/recruitment-services/",
    "https://supportworker.co/",
    "https://supportworker.co/residential-care/#",
    "https://supportworker.co/residential-care/#",
    "https://supportworker.co/resources/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/residential-care/#",
    "https://supportworker.co/residential-care/#"
    "https://supportworker.co/",
    "https://supportworker.co/",
    "https://supportworker.co/services/",
    "https://supportworker.co/industries/",
    "https://supportworker.co/resources/",
    "https://supportworker.co/about-us/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact",
    "https://supportworker.co/services/",
    "https://supportworker.co/industries/",
    "https://supportworker.co/resources/",
    "https://supportworker.co/about-us/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact",
    "https://supportworker.co/services/",
    "https://supportworker.co/staffing-solutions/",
    "https://supportworker.co/rostering-services/",
    "https://supportworker.co/recruitment-services/",
    "https://supportworker.co/industries/",
    "https://supportworker.co/disability-support/",
    "https://supportworker.co/residential-care/",
    "https://supportworker.co/aged-care/",
    "https://supportworker.co/resources/",
    "https://supportworker.co/about-us/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact",
    "https://supportworker.co/services/",
    "https://supportworker.co/staffing-solutions/",
    "https://supportworker.co/rostering-services/",
    "https://supportworker.co/recruitment-services/",
    "https://supportworker.co/industries/",
    "https://supportworker.co/disability-support/",
    "https://supportworker.co/residential-care/",
    "https://supportworker.co/aged-care/",
    "https://supportworker.co/resources/",
    "https://supportworker.co/about-us/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/staffing-agency/",
    "https://supportworker.co/rostering-services/",
    "https://supportworker.co/recruitment-services/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/",
    "https://supportworker.co/aged-care/#",
    "https://supportworker.co/aged-care/#",
    "https://supportworker.co/resources/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/aged-care/#",
    "https://supportworker.co/aged-care/#"
    "https://supportworker.co/",
    "https://supportworker.co/",
    "https://supportworker.co/services/",
    "https://supportworker.co/industries/",
    "https://supportworker.co/resources/",
    "https://supportworker.co/about-us/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact",
    "https://supportworker.co/services/",
    "https://supportworker.co/industries/",
    "https://supportworker.co/resources/",
    "https://supportworker.co/about-us/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact",
    "https://supportworker.co/services/",
    "https://supportworker.co/staffing-solutions/",
    "https://supportworker.co/rostering-services/",
    "https://supportworker.co/recruitment-services/",
    "https://supportworker.co/industries/",
    "https://supportworker.co/disability-support/",
    "https://supportworker.co/residential-care/",
    "https://supportworker.co/aged-care/",
    "https://supportworker.co/resources/",
    "https://supportworker.co/about-us/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact",
    "https://supportworker.co/services/",
    "https://supportworker.co/staffing-solutions/",
    "https://supportworker.co/rostering-services/",
    "https://supportworker.co/recruitment-services/",
    "https://supportworker.co/industries/",
    "https://supportworker.co/disability-support/",
    "https://supportworker.co/residential-care/",
    "https://supportworker.co/aged-care/",
    "https://supportworker.co/resources/",
    "https://supportworker.co/about-us/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/resources/#",
    "https://supportworker.co/resources/#",
    "https://supportworker.co/resources/#",
    "https://supportworker.co/resources/#",
    "https://supportworker.co/resources/#",
    "https://supportworker.co/how-flexible-staffing-solutions-improve-service-delivery-in-the-support-sector/",
    "https://supportworker.co/how-flexible-staffing-solutions-improve-service-delivery-in-the-support-sector/",
    "https://supportworker.co/category/article/",
    "https://supportworker.co/how-flexible-staffing-solutions-improve-service-delivery-in-the-support-sector/",
    "https://supportworker.co/workforce-compliance-audits-why-ceos-cant-afford-to-overlook-them/",
    "https://supportworker.co/workforce-compliance-audits-why-ceos-cant-afford-to-overlook-them/",
    "https://supportworker.co/category/article/",
    "https://supportworker.co/workforce-compliance-audits-why-ceos-cant-afford-to-overlook-them/",
    "https://supportworker.co/how-support-worker-cos-services-transform-organisational-health/",
    "https://supportworker.co/how-support-worker-cos-services-transform-organisational-health/",
    "https://supportworker.co/category/article/",
    "https://supportworker.co/how-support-worker-cos-services-transform-organisational-health/",
    "https://supportworker.co/from-adversity-to-advocacy-a-support-workers-journey/",
    "https://supportworker.co/from-adversity-to-advocacy-a-support-workers-journey/",
    "https://supportworker.co/category/article/",
    "https://supportworker.co/from-adversity-to-advocacy-a-support-workers-journey/",
    "https://supportworker.co/achieving-operational-excellence-the-power-of-the-right-rostering-system-for-support-services/",
    "https://supportworker.co/achieving-operational-excellence-the-power-of-the-right-rostering-system-for-support-services/",
    "https://supportworker.co/category/article/",
    "https://supportworker.co/achieving-operational-excellence-the-power-of-the-right-rostering-system-for-support-services/",
    "https://supportworker.co/specialised-training-for-support-workers-a-strategic-advantage-for-ceos/",
    "https://supportworker.co/specialised-training-for-support-workers-a-strategic-advantage-for-ceos/",
    "https://supportworker.co/category/article/",
    "https://supportworker.co/specialised-training-for-support-workers-a-strategic-advantage-for-ceos/",
    "https://supportworker.co/investing-into-the-wellbeing-and-health-of-the-support-workforce/",
    "https://supportworker.co/investing-into-the-wellbeing-and-health-of-the-support-workforce/",
    "https://supportworker.co/category/article/",
    "https://supportworker.co/investing-into-the-wellbeing-and-health-of-the-support-workforce/",
    "https://supportworker.co/rostering-is-an-artform-a-system-is-not-the-panacea/",
    "https://supportworker.co/rostering-is-an-artform-a-system-is-not-the-panacea/",
    "https://supportworker.co/category/insights/",
    "https://supportworker.co/rostering-is-an-artform-a-system-is-not-the-panacea/",
    "https://supportworker.co/time-is-now-the-killer-in-support-worker-recruitment/",
    "https://supportworker.co/time-is-now-the-killer-in-support-worker-recruitment/",
    "https://supportworker.co/category/insights/",
    "https://supportworker.co/time-is-now-the-killer-in-support-worker-recruitment/",
    "https://supportworker.co/what-does-it-take-to-be-exceptional-as-a-support-worker-how-do-you-stack-up-assess-yourself/",
    "https://supportworker.co/what-does-it-take-to-be-exceptional-as-a-support-worker-how-do-you-stack-up-assess-yourself/",
    "https://supportworker.co/category/insights/",
    "https://supportworker.co/what-does-it-take-to-be-exceptional-as-a-support-worker-how-do-you-stack-up-assess-yourself/",
    "https://supportworker.co/case-study-our-rostering-function-is-broken/",
    "https://supportworker.co/case-study-our-rostering-function-is-broken/",
    "https://supportworker.co/category/case-study/",
    "https://supportworker.co/case-study-our-rostering-function-is-broken/",
    "https://supportworker.co/ndis-support-workers-employee-vs-independent-contractor-who-is-better-off/",
    "https://supportworker.co/ndis-support-workers-employee-vs-independent-contractor-who-is-better-off/",
    "https://supportworker.co/category/insights/",
    "https://supportworker.co/ndis-support-workers-employee-vs-independent-contractor-who-is-better-off/",
    "https://supportworker.co/speed-is-the-winner-in-the-battle-for-support-workers/",
    "https://supportworker.co/speed-is-the-winner-in-the-battle-for-support-workers/",
    "https://supportworker.co/category/insights/",
    "https://supportworker.co/speed-is-the-winner-in-the-battle-for-support-workers/",
    "https://supportworker.co/how-to-mentor-support-workers/",
    "https://supportworker.co/how-to-mentor-support-workers/",
    "https://supportworker.co/category/insights/",
    "https://supportworker.co/how-to-mentor-support-workers/",
    "https://supportworker.co/what-does-an-effective-support-worker-supervision-framework-constitute/",
    "https://supportworker.co/what-does-an-effective-support-worker-supervision-framework-constitute/",
    "https://supportworker.co/category/insights/",
    "https://supportworker.co/what-does-an-effective-support-worker-supervision-framework-constitute/",
    "https://supportworker.co/what-are-providers-doing-to-improve-support-worker-engagement-levels-latest-trends/",
    "https://supportworker.co/what-are-providers-doing-to-improve-support-worker-engagement-levels-latest-trends/",
    "https://supportworker.co/category/insights/",
    "https://supportworker.co/what-are-providers-doing-to-improve-support-worker-engagement-levels-latest-trends/",
    "https://supportworker.co/debriefing-support-workers-post-incident/",
    "https://supportworker.co/debriefing-support-workers-post-incident/",
    "https://supportworker.co/category/insights/",
    "https://supportworker.co/debriefing-support-workers-post-incident/",
    "https://supportworker.co/now-is-not-the-time-to-zombie-out/",
    "https://supportworker.co/now-is-not-the-time-to-zombie-out/",
    "https://supportworker.co/category/insights/",
    "https://supportworker.co/now-is-not-the-time-to-zombie-out/",
    "https://supportworker.co/ndis-providers-unleash-your-organisations-potential/",
    "https://supportworker.co/ndis-providers-unleash-your-organisations-potential/",
    "https://supportworker.co/category/insights/",
    "https://supportworker.co/ndis-providers-unleash-your-organisations-potential/",
    "https://supportworker.co/case-study-im-sick-of-fricking-agencies/",
    "https://supportworker.co/case-study-im-sick-of-fricking-agencies/",
    "https://supportworker.co/category/case-study/",
    "https://supportworker.co/case-study-im-sick-of-fricking-agencies/",
    "https://supportworker.co/rostering-is-an-artform-a-system-is-not-the-panacea-2/",
    "https://supportworker.co/rostering-is-an-artform-a-system-is-not-the-panacea-2/",
    "https://supportworker.co/category/insights/",
    "https://supportworker.co/rostering-is-an-artform-a-system-is-not-the-panacea-2/",
    "https://supportworker.co/time-is-now-the-killer-in-support-worker-recruitment-2/",
    "https://supportworker.co/time-is-now-the-killer-in-support-worker-recruitment-2/",
    "https://supportworker.co/category/insights/",
    "https://supportworker.co/time-is-now-the-killer-in-support-worker-recruitment-2/",
    "https://supportworker.co/we-agree-vanilla-recruitment-agency-models-dont-work/",
    "https://supportworker.co/we-agree-vanilla-recruitment-agency-models-dont-work/",
    "https://supportworker.co/category/insights/",
    "https://supportworker.co/we-agree-vanilla-recruitment-agency-models-dont-work/",
    "https://supportworker.co/its-all-about-communication-communication-communication/",
    "https://supportworker.co/its-all-about-communication-communication-communication/",
    "https://supportworker.co/category/knowledge-resource/",
    "https://supportworker.co/its-all-about-communication-communication-communication/",
    "https://supportworker.co/what-are-professional-boundaries/",
    "https://supportworker.co/what-are-professional-boundaries/",
    "https://supportworker.co/category/knowledge-resource/",
    "https://supportworker.co/what-are-professional-boundaries/",
    "https://supportworker.co/how-you-can-provide-superior-practice-excellence-as-a-ndis-support-worker/",
    "https://supportworker.co/how-you-can-provide-superior-practice-excellence-as-a-ndis-support-worker/",
    "https://supportworker.co/category/knowledge-resource/",
    "https://supportworker.co/how-you-can-provide-superior-practice-excellence-as-a-ndis-support-worker/",
    "https://supportworker.co/how-flexible-staffing-solutions-improve-service-delivery-in-the-support-sector/",
    "https://supportworker.co/how-flexible-staffing-solutions-improve-service-delivery-in-the-support-sector/",
    "https://supportworker.co/category/article/",
    "https://supportworker.co/how-flexible-staffing-solutions-improve-service-delivery-in-the-support-sector/",
    "https://supportworker.co/workforce-compliance-audits-why-ceos-cant-afford-to-overlook-them/",
    "https://supportworker.co/workforce-compliance-audits-why-ceos-cant-afford-to-overlook-them/",
    "https://supportworker.co/category/article/",
    "https://supportworker.co/workforce-compliance-audits-why-ceos-cant-afford-to-overlook-them/",
    "https://supportworker.co/how-support-worker-cos-services-transform-organisational-health/",
    "https://supportworker.co/how-support-worker-cos-services-transform-organisational-health/",
    "https://supportworker.co/category/article/",
    "https://supportworker.co/how-support-worker-cos-services-transform-organisational-health/",
    "https://supportworker.co/from-adversity-to-advocacy-a-support-workers-journey/",
    "https://supportworker.co/from-adversity-to-advocacy-a-support-workers-journey/",
    "https://supportworker.co/category/article/",
    "https://supportworker.co/from-adversity-to-advocacy-a-support-workers-journey/",
    "https://supportworker.co/achieving-operational-excellence-the-power-of-the-right-rostering-system-for-support-services/",
    "https://supportworker.co/achieving-operational-excellence-the-power-of-the-right-rostering-system-for-support-services/",
    "https://supportworker.co/category/article/",
    "https://supportworker.co/achieving-operational-excellence-the-power-of-the-right-rostering-system-for-support-services/",
    "https://supportworker.co/specialised-training-for-support-workers-a-strategic-advantage-for-ceos/",
    "https://supportworker.co/specialised-training-for-support-workers-a-strategic-advantage-for-ceos/",
    "https://supportworker.co/category/article/",
    "https://supportworker.co/specialised-training-for-support-workers-a-strategic-advantage-for-ceos/",
    "https://supportworker.co/investing-into-the-wellbeing-and-health-of-the-support-workforce/",
    "https://supportworker.co/investing-into-the-wellbeing-and-health-of-the-support-workforce/",
    "https://supportworker.co/category/article/",
    "https://supportworker.co/investing-into-the-wellbeing-and-health-of-the-support-workforce/",
    "https://supportworker.co/case-study-our-rostering-function-is-broken/",
    "https://supportworker.co/case-study-our-rostering-function-is-broken/",
    "https://supportworker.co/category/case-study/",
    "https://supportworker.co/case-study-our-rostering-function-is-broken/",
    "https://supportworker.co/case-study-im-sick-of-fricking-agencies/",
    "https://supportworker.co/case-study-im-sick-of-fricking-agencies/",
    "https://supportworker.co/category/case-study/",
    "https://supportworker.co/case-study-im-sick-of-fricking-agencies/",
    "https://supportworker.co/rostering-is-an-artform-a-system-is-not-the-panacea/",
    "https://supportworker.co/rostering-is-an-artform-a-system-is-not-the-panacea/",
    "https://supportworker.co/category/insights/",
    "https://supportworker.co/rostering-is-an-artform-a-system-is-not-the-panacea/",
    "https://supportworker.co/time-is-now-the-killer-in-support-worker-recruitment/",
    "https://supportworker.co/time-is-now-the-killer-in-support-worker-recruitment/",
    "https://supportworker.co/category/insights/",
    "https://supportworker.co/time-is-now-the-killer-in-support-worker-recruitment/",
    "https://supportworker.co/what-does-it-take-to-be-exceptional-as-a-support-worker-how-do-you-stack-up-assess-yourself/",
    "https://supportworker.co/what-does-it-take-to-be-exceptional-as-a-support-worker-how-do-you-stack-up-assess-yourself/",
    "https://supportworker.co/category/insights/",
    "https://supportworker.co/what-does-it-take-to-be-exceptional-as-a-support-worker-how-do-you-stack-up-assess-yourself/",
    "https://supportworker.co/ndis-support-workers-employee-vs-independent-contractor-who-is-better-off/",
    "https://supportworker.co/ndis-support-workers-employee-vs-independent-contractor-who-is-better-off/",
    "https://supportworker.co/category/insights/",
    "https://supportworker.co/ndis-support-workers-employee-vs-independent-contractor-who-is-better-off/",
    "https://supportworker.co/speed-is-the-winner-in-the-battle-for-support-workers/",
    "https://supportworker.co/speed-is-the-winner-in-the-battle-for-support-workers/",
    "https://supportworker.co/category/insights/",
    "https://supportworker.co/speed-is-the-winner-in-the-battle-for-support-workers/",
    "https://supportworker.co/how-to-mentor-support-workers/",
    "https://supportworker.co/how-to-mentor-support-workers/",
    "https://supportworker.co/category/insights/",
    "https://supportworker.co/how-to-mentor-support-workers/",
    "https://supportworker.co/what-does-an-effective-support-worker-supervision-framework-constitute/",
    "https://supportworker.co/what-does-an-effective-support-worker-supervision-framework-constitute/",
    "https://supportworker.co/category/insights/",
    "https://supportworker.co/what-does-an-effective-support-worker-supervision-framework-constitute/",
    "https://supportworker.co/what-are-providers-doing-to-improve-support-worker-engagement-levels-latest-trends/",
    "https://supportworker.co/what-are-providers-doing-to-improve-support-worker-engagement-levels-latest-trends/",
    "https://supportworker.co/category/insights/",
    "https://supportworker.co/what-are-providers-doing-to-improve-support-worker-engagement-levels-latest-trends/",
    "https://supportworker.co/debriefing-support-workers-post-incident/",
    "https://supportworker.co/debriefing-support-workers-post-incident/",
    "https://supportworker.co/category/insights/",
    "https://supportworker.co/debriefing-support-workers-post-incident/",
    "https://supportworker.co/now-is-not-the-time-to-zombie-out/",
    "https://supportworker.co/now-is-not-the-time-to-zombie-out/",
    "https://supportworker.co/category/insights/",
    "https://supportworker.co/now-is-not-the-time-to-zombie-out/",
    "https://supportworker.co/ndis-providers-unleash-your-organisations-potential/",
    "https://supportworker.co/ndis-providers-unleash-your-organisations-potential/",
    "https://supportworker.co/category/insights/",
    "https://supportworker.co/ndis-providers-unleash-your-organisations-potential/",
    "https://supportworker.co/rostering-is-an-artform-a-system-is-not-the-panacea-2/",
    "https://supportworker.co/rostering-is-an-artform-a-system-is-not-the-panacea-2/",
    "https://supportworker.co/category/insights/",
    "https://supportworker.co/rostering-is-an-artform-a-system-is-not-the-panacea-2/",
    "https://supportworker.co/time-is-now-the-killer-in-support-worker-recruitment-2/",
    "https://supportworker.co/time-is-now-the-killer-in-support-worker-recruitment-2/",
    "https://supportworker.co/category/insights/",
    "https://supportworker.co/time-is-now-the-killer-in-support-worker-recruitment-2/",
    "https://supportworker.co/we-agree-vanilla-recruitment-agency-models-dont-work/",
    "https://supportworker.co/we-agree-vanilla-recruitment-agency-models-dont-work/",
    "https://supportworker.co/category/insights/",
    "https://supportworker.co/we-agree-vanilla-recruitment-agency-models-dont-work/",
    "https://supportworker.co/its-all-about-communication-communication-communication/",
    "https://supportworker.co/its-all-about-communication-communication-communication/",
    "https://supportworker.co/category/knowledge-resource/",
    "https://supportworker.co/its-all-about-communication-communication-communication/",
    "https://supportworker.co/what-are-professional-boundaries/",
    "https://supportworker.co/what-are-professional-boundaries/",
    "https://supportworker.co/category/knowledge-resource/",
    "https://supportworker.co/what-are-professional-boundaries/",
    "https://supportworker.co/how-you-can-provide-superior-practice-excellence-as-a-ndis-support-worker/",
    "https://supportworker.co/how-you-can-provide-superior-practice-excellence-as-a-ndis-support-worker/",
    "https://supportworker.co/category/knowledge-resource/",
    "https://supportworker.co/how-you-can-provide-superior-practice-excellence-as-a-ndis-support-worker/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/",
    "https://supportworker.co/resources/#",
    "https://supportworker.co/resources/#",
    "https://supportworker.co/resources/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/resources/#",
    "https://supportworker.co/resources/#"
    "https://supportworker.co/",
    "https://supportworker.co/",
    "https://supportworker.co/services/",
    "https://supportworker.co/industries/",
    "https://supportworker.co/resources/",
    "https://supportworker.co/about-us/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact",
    "https://supportworker.co/services/",
    "https://supportworker.co/industries/",
    "https://supportworker.co/resources/",
    "https://supportworker.co/about-us/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact",
    "https://supportworker.co/services/",
    "https://supportworker.co/staffing-solutions/",
    "https://supportworker.co/rostering-services/",
    "https://supportworker.co/recruitment-services/",
    "https://supportworker.co/industries/",
    "https://supportworker.co/disability-support/",
    "https://supportworker.co/residential-care/",
    "https://supportworker.co/aged-care/",
    "https://supportworker.co/resources/",
    "https://supportworker.co/about-us/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact",
    "https://supportworker.co/services/",
    "https://supportworker.co/staffing-solutions/",
    "https://supportworker.co/rostering-services/",
    "https://supportworker.co/recruitment-services/",
    "https://supportworker.co/industries/",
    "https://supportworker.co/disability-support/",
    "https://supportworker.co/residential-care/",
    "https://supportworker.co/aged-care/",
    "https://supportworker.co/resources/",
    "https://supportworker.co/about-us/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/",
    "https://supportworker.co/about-us/#",
    "https://supportworker.co/about-us/#",
    "https://supportworker.co/resources/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/about-us/#",
    "https://supportworker.co/about-us/#"
    "https://supportworker.co/",
    "https://supportworker.co/",
    "https://supportworker.co/services/",
    "https://supportworker.co/industries/",
    "https://supportworker.co/resources/",
    "https://supportworker.co/about-us/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact",
    "https://supportworker.co/services/",
    "https://supportworker.co/industries/",
    "https://supportworker.co/resources/",
    "https://supportworker.co/about-us/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact",
    "https://supportworker.co/services/",
    "https://supportworker.co/staffing-solutions/",
    "https://supportworker.co/rostering-services/",
    "https://supportworker.co/recruitment-services/",
    "https://supportworker.co/industries/",
    "https://supportworker.co/disability-support/",
    "https://supportworker.co/residential-care/",
    "https://supportworker.co/aged-care/",
    "https://supportworker.co/resources/",
    "https://supportworker.co/about-us/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact",
    "https://supportworker.co/services/",
    "https://supportworker.co/staffing-solutions/",
    "https://supportworker.co/rostering-services/",
    "https://supportworker.co/recruitment-services/",
    "https://supportworker.co/industries/",
    "https://supportworker.co/disability-support/",
    "https://supportworker.co/residential-care/",
    "https://supportworker.co/aged-care/",
    "https://supportworker.co/resources/",
    "https://supportworker.co/about-us/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/",
    "https://supportworker.co/contact/#",
    "https://supportworker.co/contact/#",
    "https://supportworker.co/resources/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact/#",
    "https://supportworker.co/contact/#"
]

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
urls = [
    "https://supportworker.co/",
    "https://supportworker.co/services/",
    "https://supportworker.co/industries/",
    "https://supportworker.co/resources/",
    "https://supportworker.co/about-us/",
    "https://supportworker.co/contact/",
    "https://supportworker.co/contact",
    "https://supportworker.co/staffing-solutions/",
    "https://supportworker.co/rostering-services/",
    "https://supportworker.co/recruitment-services/",
    "https://supportworker.co/disability-support/",
    "https://supportworker.co/residential-care/",
    "https://supportworker.co/aged-care/",
    "https://supportworker.co/staffing-agency/",
    "https://supportworker.co/#",
    "https://supportworker.co/staffing-solutions/#",
    "https://supportworker.co/rostering-services/#",
    "https://supportworker.co/recruitment-services/#",
    "https://supportworker.co/disability-support/#",
    "https://supportworker.co/residential-care/#",
    "https://supportworker.co/aged-care/#",
    "https://supportworker.co/how-flexible-staffing-solutions-improve-service-delivery-in-the-support-sector/",
    "https://supportworker.co/category/article/",
    "https://supportworker.co/workforce-compliance-audits-why-ceos-cant-afford-to-overlook-them/",
    "https://supportworker.co/how-support-worker-cos-services-transform-organisational-health/",
    "https://supportworker.co/from-adversity-to-advocacy-a-support-workers-journey/",
    "https://supportworker.co/achieving-operational-excellence-the-power-of-the-right-rostering-system-for-support-services/",
    "https://supportworker.co/specialised-training-for-support-workers-a-strategic-advantage-for-ceos/",
    "https://supportworker.co/investing-into-the-wellbeing-and-health-of-the-support-workforce/",
    "https://supportworker.co/rostering-is-an-artform-a-system-is-not-the-panacea/",
    "https://supportworker.co/category/insights/",
    "https://supportworker.co/time-is-now-the-killer-in-support-worker-recruitment/",
    "https://supportworker.co/what-does-it-take-to-be-exceptional-as-a-support-worker-how-do-you-stack-up-assess-yourself/",
    "https://supportworker.co/case-study-our-rostering-function-is-broken/",
    "https://supportworker.co/category/case-study/",
    "https://supportworker.co/ndis-support-workers-employee-vs-independent-contractor-who-is-better-off/",
    "https://supportworker.co/speed-is-the-winner-in-the-battle-for-support-workers/",
    "https://supportworker.co/how-to-mentor-support-workers/",
    "https://supportworker.co/what-does-an-effective-support-worker-supervision-framework-constitute/",
    "https://supportworker.co/what-are-providers-doing-to-improve-support-worker-engagement-levels-latest-trends/",
    "https://supportworker.co/debriefing-support-workers-post-incident/",
    "https://supportworker.co/now-is-not-the-time-to-zombie-out/",
    "https://supportworker.co/ndis-providers-unleash-your-organisations-potential/",
    "https://supportworker.co/case-study-im-sick-of-fricking-agencies/",
    "https://supportworker.co/rostering-is-an-artform-a-system-is-not-the-panacea-2/",
    "https://supportworker.co/time-is-now-the-killer-in-support-worker-recruitment-2/",
    "https://supportworker.co/we-agree-vanilla-recruitment-agency-models-dont-work/",
    "https://supportworker.co/its-all-about-communication-communication-communication/",
    "https://supportworker.co/category/knowledge-resource/",
    "https://supportworker.co/what-are-professional-boundaries/",
    "https://supportworker.co/how-you-can-provide-superior-practice-excellence-as-a-ndis-support-worker/",
    "https://supportworker.co/about-us/#",
    "https://supportworker.co/contact/#"
]
urls = list(set(urls))

# %%
# !pip install trafilatura
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.6/132.6 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 837.9/837.9 kB 22.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.7/318.7 kB 26.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.7/296.7 kB 25.4 MB/s eta 0:00:00
# ...

# %%
#@title pages extractor
import os
import re
import requests
import trafilatura
from bs4 import BeautifulSoup
from urllib.parse import urlparse
import shutil

# -----------------------------
# Helpers
# -----------------------------
def clean_filename(name):
    """Clean a string so it is safe as a filename."""
    name = re.sub(r'[^a-zA-Z0-9_-]', '_', name)
    name = re.sub(r'_+', '_', name)
    return name.strip("_")


def title_from_html(html):
    """Extract <title> and clean it."""
    soup = BeautifulSoup(html, "html.parser")
    title = soup.title.string if soup.title else "untitled_page"
    return clean_filename(title)


# -----------------------------
# Main Extraction Logic
# -----------------------------
output_dir = "supportworker"
zip_name = "supportworker"

os.makedirs(output_dir, exist_ok=True)

for url in urls:
    try:
        print(f"[INFO] Fetching: {url}")
        response = requests.get(url, timeout=10)
        response.raise_for_status()

        html_source = response.text

        # Extract title for both filenames
        title_clean = title_from_html(html_source)

        # -----------------------------
        # Save Raw HTML (title.html)
        # -----------------------------
        html_filename = f"{title_clean}.html"
        html_filepath = os.path.join(output_dir, html_filename)

        with open(html_filepath, "w", encoding="utf-8") as f:
            f.write(html_source)

        print(f"[HTML] Saved: {html_filepath}")

        # -----------------------------
        # Save Extracted Text (title.txt)
        # -----------------------------
        extracted_text = trafilatura.extract(html_source)
        if not extracted_text:
            print(f"[WARN] Could not extract main content from {url}")
            continue

        txt_filename = f"{title_clean}.txt"
        txt_filepath = os.path.join(output_dir, txt_filename)

        with open(txt_filepath, "w", encoding="utf-8") as f:
            f.write(f"{title_clean}\n\n")  # also add title inside the text
            f.write(extracted_text)

        print(f"[TEXT] Saved: {txt_filepath}")

    except requests.exceptions.RequestException as e:
        print(f"[ERROR] Failed to fetch {url} -> {e}")

# -----------------------------
# Zip the output directory
# -----------------------------
shutil.make_archive(zip_name, 'zip', output_dir)
print(f"\n[FINAL] All extracted files zipped into: {zip_name}.zip")
# Out:
# [INFO] Fetching: https://supportworker.co/resources/
# [HTML] Saved: supportworker/Resources_-_Support_Worker_Co.html
# [TEXT] Saved: supportworker/Resources_-_Support_Worker_Co.txt
# [INFO] Fetching: https://supportworker.co/residential-care/
# [HTML] Saved: supportworker/Residential_Care_-_Support_Worker_Co.html
# [TEXT] Saved: supportworker/Residential_Care_-_Support_Worker_Co.txt
# [INFO] Fetching: https://supportworker.co/how-flexible-staffing-solutions-improve-service-delivery-in-the-support-sector/
# [HTML] Saved: supportworker/How_Flexible_Staffing_Solutions_Improve_Service_Delivery_in_the_Support_Sector_-_Support_Worker_Co.html
# [TEXT] Saved: supportworker/How_Flexible_Staffing_Solutions_Improve_Service_Delivery_in_the_Support_Sector_-_Support_Worker_Co.txt
# [INFO] Fetching: https://supportworker.co/what-are-professional-boundaries/
# [HTML] Saved: supportworker/What_are_Professional_Boundaries_-_Support_Worker_Co.html
# ...

# %%
import os

def merge_text_files(folder_path, output_file):
    """
    Merge all .txt files in the specified folder into a single text file.
    Each file's content is separated by a header (the filename).
    """
    # Get all text files in folder
    text_files = [f for f in os.listdir(folder_path) if f.endswith(".txt")]

    if not text_files:
        print("No text files found in the folder.")
        return

    with open(output_file, "w", encoding="utf-8") as outfile:
        for filename in text_files:
            file_path = os.path.join(folder_path, filename)

            # Write header
            header = f"\n\n===== {filename} =====\n\n"
            outfile.write(header)

            # Write file content
            with open(file_path, "r", encoding="utf-8") as infile:
                content = infile.read()
                outfile.write(content)

    print(f"✅ Successfully merged {len(text_files)} files into '{output_file}'")

if __name__ == "__main__":
    # Example usage:
    folder = "/content/supportworker"          # Folder containing text files
    output = "supportworker.txt" # Output file name
    merge_text_files(folder, output)
# Out:
# ✅ Successfully merged 40 files into 'supportworker.txt'
