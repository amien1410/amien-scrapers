# %%
import re
import requests

def validate_api_key(apikey):
    url = 'https://httpbin.io/anything'
    apikey = '99db25a61c60394a8f8377108e13d2a0b6bf87ca'
    params = {
        'url': url,
        'apikey': apikey,
    }
    response = requests.get('https://api.zenrows.com/v1/', params=params)
    return response.json()

def find_api_keys(text):
    api_keys = re.findall(r'\b[a-f0-9]{40}\b', text)
    return set(list(api_keys))

# %%
myText = r"""

Skip to content
Navigation Menu
Search GitHub:
api.zenrows.com/v1/?apikey=
code Search Results · api.zenrows.com/v1/?apikey=
Filter by
Languages
Repositories
Paths
Advanced
70 files
 (762 ms)
70 files


osirislab/LeakyPastes-V2 · pastes/pastes_20240430120617.csv
CSV
·
main
…      String response = example.run(""https://api.zenrows.com/v1/?apikey=<YOUR_ZENROWS_API_KEY>&url=https%3A%2F%2Fwww.…


osirislab/LeakyPastes-V2 · pastes/pastes_20240328120802.csv
CSV
·
main
        String apiUrl = ""https://api.zenrows.com/v1/?apikey=<YOUR_ZENROWS_API_KEY>&url=https%3A%2F%2Fscrapeme.live%2Fs…


osirislab/LeakyPastes-V2 · pastes/pastes_20240328060545.csv
CSV
·
main
        String apiUrl = ""https://api.zenrows.com/v1/?apikey=<YOUR_ZENROWS_API_KEY>&url=https%3A%2F%2Fscrapeme.live%2Fs…


osirislab/LeakyPastes-V2 · pastes/pastes_20240316060511.csv
CSV
·
main
            string apiUrl = ""https://api.zenrows.com/v1/?apikey=<YOUR_ZENROWS_API_KEY>&url=https%3A%2F%2Fwww.g2.com%2F…


osirislab/LeakyPastes-V2 · pastes/pastes_20240410120643.csv
CSV
·
main
…eq, err := http.NewRequest(""GET"", ""https://api.zenrows.com/v1/?apikey=<YOUR_ZENROWS_API_KEY>&url=https%3A%2F%2Fwww.…


zimmmz21/Prizepicks.API_Scraper · server.js
JavaScript
·
main
async function fetchViaZenRows() {
  if (!ZENROWS_API_KEY) throw new Error("ZENROWS_API_KEY not set");
  const zenUrl =
    `https://api.zenrows.com/v1/?apikey=${encodeURIComponent(ZENROWS_API_KEY)}` +
    `&url=${encodeURIComponent(TARGET_URL)}` +
    `&js_render=true&smart_proxy=true&premium_proxy=true`;
  const resp = await axios.get(zenUrl, { headers: DEFAULT_HEADERS, timeout: 25000 });


gabriellegtw/DeepTechCategorisation · active_vcs.py
Python
·
main
        # TODO
        # Type new ZenRows API Key here
        api_key = 'e63f59e54aa1acb46e6e94a9ffde8956d0a93c16'
        response = requests.get(f'https://api.zenrows.com/v1/?apikey={api_key}&url={url}')
        soup = BeautifulSoup(response.text, 'lxml')
        return soup
    except:


antPinot/sum-it-backend · src/main/java/com/pinot/sumitbackend/services/SERPService.java
Java
·
main
		RestTemplate restTemplate = new RestTemplate();
		String response = restTemplate.getForObject(
				"https://api.zenrows.com/v1/?apikey=" + zenRowsAPIKey + "&url=https%3A%2F%2Fhttpbin.io%2Fanything",
				String.class);
		System.out.println(response);
	}


mohammed1210/propnexus-platform · scripts/sources/rightmove.ts
TypeScript
·
main
const ZENROWS = process.env.ZENROWS_API_KEY ? {
  name: 'zenrows',
  url: (target: string, render: boolean) =>
    `https://api.zenrows.com/v1/?apikey=${process.env.ZENROWS_API_KEY}` +
    `&url=${encodeURIComponent(target)}${render ? '&js_render=true' : ''}&premium_proxy=true`,
} : null;


vishnudas-bluefox/panda_website · backend/instagram/views.py
Python
·
master
    format_link = f"https://api.zenrows.com/v1/?apikey=4c231f11b73d3297335473dfa6d95be3eeac9b2b&url=https%3A%2F%2Fwww.i…


aungthuhein13/Canadian_limo_taxi_data_extractor · Extracting_emails.ipynb
Jupyter Notebook
·
main
        "        print(f\"Scraping page {page}...\")\n",
        "        target_url = f\"{base_url}?page={page}\"\n",
        "\n",
        "    zenrows_url = f\"https://api.zenrows.com/v1/?apikey={API_KEY}&url={target_url}&js_render=true\"\n",
        "\n",
        "    res = requests.get(zenrows_url)\n",
        "\n",


liqzz/vultrap · rules/nuclei/http/token-spray/api-zenrows.yaml
YAML
·
main
traps:
- request:
    method: GET
    path: https://api.zenrows.com/v1/?apikey=&url=https://example.com
    headers: null
    body: null
  response:


Arvinthksrct/alltemplate · api-zenrows.yaml
YAML
·
main
requests:
  - method: GET
    path:
      - "https://api.zenrows.com/v1/?apikey={{token}}&url=https://example.com"
    matchers:
      - type: word
        part: body


chrldb/localimmo · url.php
PHP
·
main
        if ($_SERVER['REQUEST_METHOD'] === 'POST' && !empty($_POST['url'])):
            $url = $_POST['url'];
            $api_key = getenv('ZENROWS_API_KEY');
            $proxy_url = 'https://api.zenrows.com/v1/?apikey=' . $api_key .
                '&url=' . urlencode($url) .
                '&premium_proxy=true&js_render=true';


SecureStackCo/nuclei-templates · http/token-spray/api-zenrows.yaml
YAML
·
main
http:
  - method: GET
    path:
      - "https://api.zenrows.com/v1/?apikey={{token}}&url=https://example.com"
    matchers:
      - type: word


Anton3413/Reverso-Java-API · src/main/java/reverso/Reverso.java
Java
·
master
        }
        String contextURL = CONTEXT_URL + sourceLanguage + "-" + targetLanguage + "/" + word;
        String APIURL = "https://api.zenrows.com/v1/?apikey=" + apiKey + "&url=" + contextURL + "&js_render=true" +
                "&original_status=true";
        Document document;
        Map<String, String> contextMap;


Dream10319/API-Solver · index.js
JavaScript
·
main
    // Send the JSON data as response
    // res.end(JSON.stringify(jsonData));
    res.end("https://api.zenrows.com/v1/?apikey=ceee97e6fd728e56a0154af05ebc6a968db06a67&url=")
})
app.use("/v1/cardsales/solver", (req, res) => {


towoju5/pocketapp · storage/logs/laravel.log
·
main
…9:58:05] local.INFO: getAssetData:  ["https://api.zenrows.com/v1/?apikey=a413cf12845e3864a1187ba8434bb6735a0a0a2b&url=…
…6:23:35] local.INFO: getAssetData:  ["https://api.zenrows.com/v1/?apikey=a413cf12845e3864a1187ba8434bb6735a0a0a2b&url=…
…6:23:36] local.INFO: getAssetData:  ["https://api.zenrows.com/v1/?apikey=a413cf12845e3864a1187ba8434bb6735a0a0a2b&url=…


rvguha/nlweb · code/scrapper/tripadvisor.py
Python
·
main
    os.makedirs(output_dir, exist_ok=True)

    # ZenRows API endpoint
    api_url = f"https://api.zenrows.com/v1/?apikey={zenrows_api_key}&js_render=true&wait=2000"

    # Read URLs from input file
    with open(input_file, 'r') as f:


osirislab/LeakyPastes-V2 · pastes/pastes_20240323180541.csv
CSV
·
main
…        var client = new RestClient(""https://api.zenrows.com/v1/?apikey=<YOUR_ZENROWS_API_KEY>&url=https%3A%2F%2Fscra…
…        var client = new RestClient(""https://api.zenrows.com/v1/?apikey=key&url=https%3A%2F%2Fhttpbin.io%2Fanything""…

"""

api_keys = find_api_keys(myText)
print(f"Found api keys: {len(api_keys)}")

for key in api_keys:
    is_valid = validate_api_key(key)
    print(key)
    print(is_valid)
# Out:
# Found api keys: 4
# ceee97e6fd728e56a0154af05ebc6a968db06a67
# {'code': 'AUTH005', 'detail': 'This account has reached its validity period. Purchase a new subscription to continue using the service.', 'instance': '/v1', 'status': 402, 'title': 'Account is not longer valid (AUTH005)', 'type': 'https://docs.zenrows.com/api-error-codes#AUTH005'}
# a413cf12845e3864a1187ba8434bb6735a0a0a2b
# {'code': 'AUTH005', 'detail': 'This account has reached its validity period. Purchase a new subscription to continue using the service.', 'instance': '/v1', 'status': 402, 'title': 'Account is not longer valid (AUTH005)', 'type': 'https://docs.zenrows.com/api-error-codes#AUTH005'}
# e63f59e54aa1acb46e6e94a9ffde8956d0a93c16
# ...

# %%
import requests

# build the proxy URL
proxy_url = "http://BrWVsMGdBrtN:4Px5lrFgpWhL@superproxy.zenrows.com:1338"

# configure proxy protocols
proxies = {
    "http": proxy_url,
    "https": proxy_url,
}

response = requests.get("https://httpbin.io/ip", proxies=proxies)
if response.status_code != 200:
    print(f"An error occurred with {response.status_code}")
else:
    print(response.text)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3979097227.py in <cell line: 0>()
#      10 }
#      11
# ---> 12 response = requests.get("https://httpbin.io/ip", proxies=proxies)
#      13 if response.status_code != 200:
#      14     print(f"An error occurred with {response.status_code}")
#
# /usr/local/lib/python3.12/dist-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /usr/local/lib/python3.12/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# ...
