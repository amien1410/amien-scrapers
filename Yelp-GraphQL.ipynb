# %% [markdown]
# <a href="https://colab.research.google.com/github/amien1410/amien-scrapers/blob/main/Yelp-GraphQL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# %%
payload = [
    {
      "operationName":"GetRecentActivityFeedData",
      "variables":{
          "resultsPerPage":60,
          "after":None,
          "feed":"FRIENDS",
          "nearbyFeed":True,
          "reactionsSourceFlow":"activityFeed"
          },
      "extensions":{
          "operationType":"query",
          "documentId":"2d23ef16b7b29bc39c2c2b51a4561136a65a9cd8c8d832e94b62856ae03778bb"
          }
    },
    {
      "operationName":"GetConsumerFooterCopyrightData",
      "variables":{},
      "extensions":{
          "operationType":"query",
          "documentId":"7afdec92e3e0c56c236ac65165bcf2d8c6bd183b1f232703501e65f295108b7a"
          }
    }
]

headers = {
    "Accept": "*/*",
    "Accept-Language": "en-US,en;q=0.5",
    "Accept-Encoding": "gzip, deflate, br, zstd",
    "content-type": "application/json",
    "x-apollo-operation-name": "GetRecentActivityFeedData,GetConsumerFooterCopyrightData",
    "Content-Length": "470",
    "Origin": "https://www.yelp.com",
    "Alt-Used": "www.yelp.com",
    "Connection": "keep-alive",
    "Referer": "https://www.yelp.com/",
    "Cookie": "bsi=1%7C9df34936-04c3-5a51-bcff-740ff0149c82%7C1727763055258%7C1727763055258%7C1%7Cf073b6661d7f71ab; wdi=2|037F0FE972D5069A|0x1.9bee49bd07393p+30|06218c6920740fde; bse=7bf01946856c40549aebe0cbeb0fd08f; location=%7B%22city%22%3A+%22San+Francisco%22%2C+%22state%22%3A+%22CA%22%2C+%22country%22%3A+%22US%22%2C+%22latitude%22%3A+37.775123%2C+%22longitude%22%3A+-122.41932%2C+%22max_latitude%22%3A+37.81602226140252%2C+%22min_latitude%22%3A+37.706368356809776%2C+%22max_longitude%22%3A+-122.3550796508789%2C+%22min_longitude%22%3A+-122.51781463623047%2C+%22zip%22%3A+%22%22%2C+%22address1%22%3A+%22%22%2C+%22address2%22%3A+%22%22%2C+%22address3%22%3A+null%2C+%22neighborhood%22%3A+null%2C+%22borough%22%3A+null%2C+%22provenance%22%3A+%22YELP_GEOCODING_ENGINE%22%2C+%22display%22%3A+%22San+Francisco%2C+CA%22%2C+%22unformatted%22%3A+%22San+Francisco%2C+CA%22%2C+%22isGoogleHood%22%3A+null%2C+%22usingDefaultZip%22%3A+null%2C+%22accuracy%22%3A+4.0%2C+%22language%22%3A+null%7D; hl=en_US; xcj=1|pk7CCs-92JeS_JbYkf5zxHj_sJWoX2qfMNqMCoG3O9o; spses.d161=*; spid.d161=839286c2-155e-49d2-9b77-7779c82239b4.1727763071.1.1727763071..33d8fb89-ff95-4ce4-9ade-dd2e65bbb4bf..e6b00869-2520-4faa-aab6-d0bc773b64bc.1727763071048.1; _ga_K9Z2ZEVC8C=GS1.2.1727763071.1.0.1727763071.0.0.0; _ga=GA1.2.037F0FE972D5069A",
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "same-origin",
    "TE": "trailers"
}

# %%
url = "https://www.yelp.com/gql/batch"
res = requests.post(url, json=payload)
data = res.json()[0]['data']['nearbyActivityFeed']

# %%
data['edges'][0]
# data['pageInfo']['endCursor']
# Out:
# {'node': {'__typename': 'ActivityFeedBusinessPhotoGroup',
#   'occurredAt': {'utcDateTime': '2024-10-01T07:44:43Z',
#    '__typename': 'DateTime'},
#   'items': [{'businessPhoto': {'__typename': 'BusinessPhoto',
#      'encid': 'AJrgBv9RI3x8SfLJg9L7Ww',
#      'viewerPhotoUrl': {'url': 'https://s3-media0.fl.yelpcdn.com/bphoto/AJrgBv9RI3x8SfLJg9L7Ww/o.jpg',
#       '__typename': 'BusinessPhotoUrl'},
#      'width': 1126,
#      'height': 2000,
#      'photoBusiness': {'encid': 'jJi2lgFXcGbOTe_MqlesRg',
#       'name': 'Archer Nail Bar',
#       'alias': 'archer-nail-bar-san-francisco-3',
#       'primaryPhoto': {'encid': 'msNIPHDGHNJ76_RjcV0erw',
#        'photoUrl': {'url1x': 'https://s3-media0.fl.yelpcdn.com/bphoto/msNIPHDGHNJ76_RjcV0erw/xs.jpg',
#         'url2x': 'https://s3-media0.fl.yelpcdn.com/bphoto/msNIPHDGHNJ76_RjcV0erw/s.jpg',
#         '__typename': 'BusinessPhotoUrl'},
#        '__typename': 'BusinessPhoto'},
#       '__typename': 'Business'},
# ...
