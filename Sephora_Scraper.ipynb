# %% [markdown]
# <a href="https://colab.research.google.com/github/amien1410/amien-scrapers/blob/main/Sephora_Scraper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas
import json

# %%
headers = {
    "accept": "*/*",
    "accept-encoding": "gzip, deflate, br, zstd",
    "accept-language": "en-US,en;q=0.9,id;q=0.8,fa;q=0.7,ar;q=0.6,ms;q=0.5,ja;q=0.4,es;q=0.3",
    "cookie": "akamweb=H; device_type=desktop; site_locale=us; site_language=en; rcps_cc=true; rcps_po=true; rcps_ss=true; current_country=ID; rcps_product=true; rcps_profile_account_group=true; rcps_profile_bi_group=true; rcps_profile_info_group=true; rcps_profile_shipping_group=true; rcps_sls=true; rcps_profile_userprofile_group=false; rcps_beauty_offers=true; rcps_ccap=true; rcps_full_profile_group=true; rcps_basket=true; adbanners=on; bm_ss=ab8e18ef4e; PIM-SESSION-ID=w3qXHIGCGpui81rY; at_check=true; AMCVS_F6281253512D2BB50A490D45%40AdobeOrg=1; AMCV_F6281253512D2BB50A490D45%40AdobeOrg=1585540135%7CMCIDTS%7C20281%7CMCMID%7C64813312480874074080442810305116705934%7CMCAID%7CNONE%7CMCOPTOUT-1752284752s%7CNONE%7CvVersion%7C4.4.0; mbox=session#649db9f06caa4d5f8bb6aec91cd50ccf#1752279423; ngp_userreg=false; bm_lso=406CCC414D9E72D5F5D70977040895AB8DDB9B2E80D4DB4AB4BAB3AD018B2490~...^1752277563416; SephSession=c915c413-ba3b-4cfc-80ad-337310253149; AKA_A2=A; forterToken=0eaa0cf79718466d906969752580f6c7_1752277549316_3344_UAS9_23ck; trackIntlPopup=true; preferredStore=undefined; ADID=154a7c8426065e1fdc3219aa851ca28fde328c8c3bf602c2c3d7c293c7d11844; akavpau_akaau=1752278200~id=efecde3335934825c8fd3176e99d3bac; ak_bmsc-kp-ssn=02QMSeQzwdOQmcA3UXzDO42EhREnBkSKl8LpF3EMb2TbgQMxG6btYngdl3oWpqpVuveGoepSkoRpQMhyMEbbLP405QpkjLea9Ni6VtkJVY3OOmQoWb5iQXMlLAcgprld9Vz0gYh9XNxxSLk7mEgVnrhtqd5DYak2mPUnbaAdvH; ak_bmsc-kp=02QMSeQzwdOQmcA3UXzDO42EhREnBkSKl8LpF3EMb2TbgQMxG6btYngdl3oWpqpVuveGoepSkoRpQMhyMEbbLP405QpkjLea9Ni6VtkJVY3OOmQoWb5iQXMlLAcgprld9Vz0gYh9XNxxSLk7mEgVnrhtqd5DYak2mPUnbaAdvH; ATG_ORDER_CONTENT=; CNC_ORDER_CONTENT=; kampyle_userid=96d4-b5f3-4c62-9ed0-6c64-ea81-f5ad-cea6; kampyleUserSession=1752277609434; kampyleUserSessionsCount=1; kampyleUserPercentile=6.858017040459174; kampyleSessionPageCounter=1; bm_s=...; bm_so=12DE75030F9E43C50D633B7530032D8D282ECCAAF3434D89D9485D906EF4F0EA~...; bm_sz=E58DE218A05F9F4363F32E4AFE377331~...~4277827~4474425; _abck=DC32528FD75C8148204CFCB9AE28D9FE~-1~...~-1~||0||~1752281155",
    "exclude_personalized_content": "true",
    "priority": "u=1, i",
    "referer": "https://www.sephora.com/shop/makeup-cosmetics",
    "sec-ch-ua": '"Not)A;Brand";v="8", "Chromium";v="138", "Microsoft Edge";v="138"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": "Windows",
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-origin",
    "seph-access-token": "eyJhbGciOiJSUzI1NiJ9..UvPpS_4FLuHHccbLFhjy9nptvhvlILWoKfIrB_Kr-CyF9_3O5BdkXoxWfWpw8Tz1Tu8bOVqUKD465Ocx3tvBplsP7TF_3IYif7LY-jBUgm8mKv5leY7hKvfyraC_t7nc3m_rHSNreF2TzuKM1r_kWL03d4aDH6MJhZnkI7h56ehLAroRHA2RwcOzlDV-D0DueN80OfNvJvJHlfsAgVFExty2A_P1VOnzgzBSyGw9rH_Rvs2BcvJwvTSVVl4F9Sj2rfl_BMuNwOZraO0n45JuqIMMPPTmSly53nS2dpfTXSKTsgWy939y8UaSwLkoebGGQ_SboRbLmZgLuiAXyqK4rAw3v5FuVBIJUh5jpgx8cgCz4sJZ_7GLnmuODmhPTz5Ru9eMmHha4U38LJ69KVtFY6paDSZ_1DEGe7cShspwTJ0hM8CwLYrmLMuyfv1Z5f4NSfN6IYNIh5zmBIBwJLSwogdTmGkV_mgGW7smBY8Rhm3DMDbTEHbxxDX5yTf3fzCvnhPaKtoTxZIzaU80Qp-pgsMup6xqdQAvR0fZjkwWmgnHBqBcge7Pz66qVU_ItPyNwYsC86J7x6J4d8gym-4iDAZm03sjRacvA_nMd9lSAauC0vvwfSvIiTsBWe3VX2bcECRX4xeELPZCrRwK72qYl2nY3uf-EK4a2M57SaNrAII",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36 Edg/138.0.0.0",
    "x-api-key": "nQc7BFt78yJBvfYDKtle9APd5RrX984i",
    "x-requested-source": "rwd",
    "x-timestamp": "1752277671047"
}

# %%
url = "https://www.sephora.com/api/v2/catalog/categories/makeup-cosmetics/seo?content=true&includeRegionsMap=true&targetSearchEngine=nlp&countryCode=US&pickupRampup=true&sddRampup=true&includeEDD=true&callAdSvc=true&adSvcSlot=2502111&adSvcSession=c915c413-ba3b-4cfc-80ad-337310253149&loc=en-US&ch=rwd"
res = requests.get(url, headers=headers)
res
# Out:
# <Response [200]>

# %%
# !pip install "httpx[http2,brotli]" parsel
# !pip install loguru

# import modules
import re
import httpx
import json
import random
import string
import difflib
import math
import numpy as np
import requests
import pandas as pd
from google.colab import files
from loguru import logger as log
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 35.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 2.5 MB/s eta 0:00:00
# ...

# %%
BASE_HEADERS = {
    "authority": "www.sephora.com",
    "accept": "*/*",
    "accept-encoding": "gzip, deflate, br, zstd",
    "accept-language": "en-US,en;q=0.9,id;q=0.8,fa;q=0.7,ar;q=0.6,ms;q=0.5,ja;q=0.4,es;q=0.3",
    "cookie": "akamweb=H; device_type=desktop; site_locale=us; site_language=en; rcps_cc=true; rcps_po=true; rcps_ss=true; current_country=ID; rcps_product=true; rcps_profile_account_group=true; rcps_profile_bi_group=true; rcps_profile_info_group=true; rcps_profile_shipping_group=true; rcps_sls=true; rcps_profile_userprofile_group=false; rcps_beauty_offers=true; rcps_ccap=true; rcps_full_profile_group=true; rcps_basket=true; adbanners=on; bm_ss=ab8e18ef4e; PIM-SESSION-ID=w3qXHIGCGpui81rY; at_check=true; AMCVS_F6281253512D2BB50A490D45%40AdobeOrg=1; AMCV_F6281253512D2BB50A490D45%40AdobeOrg=1585540135%7CMCIDTS%7C20281%7CMCMID%7C64813312480874074080442810305116705934%7CMCAID%7CNONE%7CMCOPTOUT-1752284752s%7CNONE%7CvVersion%7C4.4.0; mbox=session#649db9f06caa4d5f8bb6aec91cd50ccf#1752279423; ngp_userreg=false; bm_lso=406CCC414D9E72D5F5D70977040895AB8DDB9B2E80D4DB4AB4BAB3AD018B2490~...^1752277563416; SephSession=c915c413-ba3b-4cfc-80ad-337310253149; AKA_A2=A; forterToken=0eaa0cf79718466d906969752580f6c7_1752277549316_3344_UAS9_23ck; trackIntlPopup=true; preferredStore=undefined; ADID=154a7c8426065e1fdc3219aa851ca28fde328c8c3bf602c2c3d7c293c7d11844; akavpau_akaau=1752278200~id=efecde3335934825c8fd3176e99d3bac; ak_bmsc-kp-ssn=02QMSeQzwdOQmcA3UXzDO42EhREnBkSKl8LpF3EMb2TbgQMxG6btYngdl3oWpqpVuveGoepSkoRpQMhyMEbbLP405QpkjLea9Ni6VtkJVY3OOmQoWb5iQXMlLAcgprld9Vz0gYh9XNxxSLk7mEgVnrhtqd5DYak2mPUnbaAdvH; ak_bmsc-kp=02QMSeQzwdOQmcA3UXzDO42EhREnBkSKl8LpF3EMb2TbgQMxG6btYngdl3oWpqpVuveGoepSkoRpQMhyMEbbLP405QpkjLea9Ni6VtkJVY3OOmQoWb5iQXMlLAcgprld9Vz0gYh9XNxxSLk7mEgVnrhtqd5DYak2mPUnbaAdvH; ATG_ORDER_CONTENT=; CNC_ORDER_CONTENT=; kampyle_userid=96d4-b5f3-4c62-9ed0-6c64-ea81-f5ad-cea6; kampyleUserSession=1752277609434; kampyleUserSessionsCount=1; kampyleUserPercentile=6.858017040459174; kampyleSessionPageCounter=1; bm_s=...; bm_so=12DE75030F9E43C50D633B7530032D8D282ECCAAF3434D89D9485D906EF4F0EA~...; bm_sz=E58DE218A05F9F4363F32E4AFE377331~...~4277827~4474425; _abck=DC32528FD75C8148204CFCB9AE28D9FE~-1~...~-1~||0||~1752281155",
    "exclude_personalized_content": "true",
    "priority": "u=1, i",
    "referer": "https://www.sephora.com/shop/makeup-cosmetics",
    "sec-ch-ua": '"Not)A;Brand";v="8", "Chromium";v="138", "Microsoft Edge";v="138"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": "Windows",
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-origin",
    "seph-access-token": "eyJhbGciOiJSUzI1NiJ9..UvPpS_4FLuHHccbLFhjy9nptvhvlILWoKfIrB_Kr-CyF9_3O5BdkXoxWfWpw8Tz1Tu8bOVqUKD465Ocx3tvBplsP7TF_3IYif7LY-jBUgm8mKv5leY7hKvfyraC_t7nc3m_rHSNreF2TzuKM1r_kWL03d4aDH6MJhZnkI7h56ehLAroRHA2RwcOzlDV-D0DueN80OfNvJvJHlfsAgVFExty2A_P1VOnzgzBSyGw9rH_Rvs2BcvJwvTSVVl4F9Sj2rfl_BMuNwOZraO0n45JuqIMMPPTmSly53nS2dpfTXSKTsgWy939y8UaSwLkoebGGQ_SboRbLmZgLuiAXyqK4rAw3v5FuVBIJUh5jpgx8cgCz4sJZ_7GLnmuODmhPTz5Ru9eMmHha4U38LJ69KVtFY6paDSZ_1DEGe7cShspwTJ0hM8CwLYrmLMuyfv1Z5f4NSfN6IYNIh5zmBIBwJLSwogdTmGkV_mgGW7smBY8Rhm3DMDbTEHbxxDX5yTf3fzCvnhPaKtoTxZIzaU80Qp-pgsMup6xqdQAvR0fZjkwWmgnHBqBcge7Pz66qVU_ItPyNwYsC86J7x6J4d8gym-4iDAZm03sjRacvA_nMd9lSAauC0vvwfSvIiTsBWe3VX2bcECRX4xeELPZCrRwK72qYl2nY3uf-EK4a2M57SaNrAII",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36 Edg/138.0.0.0",
    "x-api-key": "nQc7BFt78yJBvfYDKtle9APd5RrX984i",
    "x-requested-source": "rwd",
    "x-timestamp": "1752277671047"
}
# start HTTP session client with our headers and HTTP2
client = httpx.AsyncClient(
    http2=True,  # http2 connections are significantly less likely to get blocked
    headers=BASE_HEADERS,
    timeout=httpx.Timeout(15.0),
    limits=httpx.Limits(max_connections=5),
)

# %%
# get the page with method POST and pass the payload and headers as the parameters
# filters[Ingredient Preferences]=Cruelty-Free
# filters[Ingredient Preferences]=Fragrance Free
# filters[Ingredient Preferences]=Vegan


url = "https://www.sephora.com/api/v2/catalog/categories/makeup-cosmetics/seo?ref=filters[Ingredient%20Preferences]=Cruelty-Free&content=true&includeRegionsMap=true&targetSearchEngine=nlp&countryCode=US&pickupRampup=true&sddRampup=true&includeEDD=true&callAdSvc=true&adSvcSlot=2502111&adSvcSession=c915c413-ba3b-4cfc-80ad-337310253149&loc=en-US&ch=rwd&currentPage=1"
result = await client.get(
    url=url,
    headers=headers,
)
data = json.loads(result.content)
# print(len(data['products']))
# data['products'][0]
data

# %%
data['pageSize']
# Out:
# 60

# %%
apiUrl = "https://api-developer.sephora.com/v1/browseSearchProduct"
payload = {
    "session":"c915c413-ba3b-4cfc-80ad-337310253149",
    "internal":False,
    "locale":"us-en",
    "targets":{
        "category":["makeup-cosmetics"]
        },
    "category_id":"cat140006",
    "slot":"2502111",
    "count":100,
    "count_fill": 4
}
payload2 = {
    "session":"c915c413-ba3b-4cfc-80ad-337310253149",
    "internal":False,
    "locale":"us-en",
    "width":970,
    "height":90,
    "targets":{
        "category":["makeup-cosmetics"]
        },
    "category_id":"cat140006",
    "slot":"2502123",
    "count":2,
    "count_fill":2
}
result = await client.post(
    url=apiUrl,
    json=payload,
    headers=headers
)
data = json.loads(result.content)
print(len(data))
data[0]

# %%
all_products = []
current_page = 1
while True:
    url = f"https://www.sephora.com/api/v2/catalog/categories/makeup-cosmetics/seo?ref=filters[Ingredient%20Preferences]=Vegan&content=true&includeRegionsMap=true&targetSearchEngine=nlp&countryCode=US&pickupRampup=true&sddRampup=true&includeEDD=true&callAdSvc=true&adSvcSlot=2502111&adSvcSession=c915c413-ba3b-4cfc-80ad-337310253149&loc=en-US&ch=rwd&currentPage={current_page}"
    result = await client.get(
        url=url,
        headers=headers,
    )
    data = json.loads(result.content)
    if not data['products']:
        break
    all_products.extend(data['products'])
    current_page += 1

print(f"Collected {len(all_products)} products.")
# You can now work with the 'all_products' list
# For example, convert it to a pandas DataFrame:
# df = pd.DataFrame(all_products)
# display(df.head())
# Out:
# Collected 1289 products.

# %%
products_list = []
for product in all_products:
    brand_name = product.get('brandName')
    display_name = product.get('displayName')
    product_id = product.get('productId')
    rating = product.get('rating')
    reviews = product.get('reviews')
    more_colors = product.get('moreColors')
    price = product.get('currentSku', {}).get('listPrice')
    sku_id = product.get('currentSku', {}).get('skuId')

    products_list.append({
        'Brand Name': brand_name,
        'Display Name': display_name,
        'Product ID': product_id,
        'Rating': rating,
        'Reviews': reviews,
        'More Colors': more_colors,
        'Price': price,
        'SKU ID': sku_id
    })

df = pd.DataFrame(products_list)
df
# Out:
#                       Brand Name  \
# 0                Tower 28 Beauty
# 1                           Saie
# 2                 Summer Fridays
# 3    Rare Beauty by Selena Gomez
# 4                    HUDA BEAUTY
# ..                           ...
# 636            iNNBEAUTY PROJECT
# 637             First Aid Beauty
# 638                     NUDESTIX
# 639            Peter Thomas Roth
# 640                        Kosas
#
#                                           Display Name Product ID  Rating  \
# 0       ShineOn Lip Jelly Hydrating Non-Sticky Lip Oil    P448854  4.4791
# 1                         Dew Blush Liquid Cream Blush    P469825  4.4532
# 2      Sheer Skin Tint with Hyaluronic Acid + Squalane    P501777  4.1242
# 3           Warm Wishes Effortless Cream Bronzer Stick    P479343  4.4789
# 4     Easy Bake Blurring Loose Baking & Setting Powder    P433402  4.6892
# ..                                                 ...        ...     ...
# ...

# %%
df.to_csv('fragrance-free-products.csv', index=False)
