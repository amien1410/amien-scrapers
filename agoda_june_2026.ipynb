# %% [markdown]
# ## Resources

# %%
import requests

url = "https://www.agoda.com/activities/api/cronos/GetResultSuggestion/1?searchText=new%20york"
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    print("Request successful!")
    print(response.json()) # Print the JSON response
else:
    print(f"Request failed with status code: {response.status_code}")
    print(response.text) # Print the error message or content
# Out:
# Request successful!
# ...

# %%
import requests
import json

url = "https://www.agoda.com/api/activities/graphql?operation=search&cityId=318&pageNumber=1&key=Search"
payload = {
    "queryString": "?operation=search&cityId=318&pageNumber=1",
    "variables": {
        "SearchRequest": {
            "context": {
                "currency": "IDR",
                "experimentInfo": {
                    "forcedExperiments": [
                        {
                            "experiment": "EXP-ISOLATION",
                            "variant": "A"
                        },
                        {
                            "experiment": "ACT-4175",
                            "variant": "B"
                        },
                        {
                            "experiment": "ACT-4559",
                            "variant": "B"
                        },
                        {
                            "experiment": "ACT-4602",
                            "variant": "B"
                        },
                        {
                            "experiment": "ACT-4606",
                            "variant": "B"
                        },
                        {
                            "experiment": "ACT-4712",
                            "variant": "A"
                        },
                        {
                            "experiment": "ACT-4968",
                            "variant": "A"
                        },
                        {
                            "experiment": "ACT-5038",
                            "variant": "A"
                        },
                        {
                            "experiment": "ACT-5130",
                            "variant": "A"
                        },
                        {
                            "experiment": "ACT-5137",
                            "variant": "B"
                        },
                        {
                            "experiment": "ACT-5182",
                            "variant": "B"
                        },
                        {
                            "experiment": "ACT-5210",
                            "variant": "B"
                        },
                        {
                            "experiment": "ACT-5340",
                            "variant": "B"
                        },
                        {
                            "experiment": "ACT-5328",
                            "variant": "A"
                        },
                        {
                            "experiment": "ACT-5289",
                            "variant": "B"
                        },
                        {
                            "experiment": "ACT-4527",
                            "variant": "A"
                        },
                        {
                            "experiment": "ACT-5475",
                            "variant": "A"
                        },
                        {
                            "experiment": "ACT-6100",
                            "variant": "A"
                        },
                        {
                            "experiment": "CXPMIG-159",
                            "variant": "A"
                        },
                        {
                            "experiment": "CXPMIG-167-IOS",
                            "variant": "A"
                        },
                        {
                            "experiment": "ACT-6268",
                            "variant": "B"
                        },
                        {
                            "experiment": "ACT-6283",
                            "variant": "B"
                        },
                        {
                            "experiment": "ACT-6384",
                            "variant": "A"
                        },
                        {
                            "experiment": "ACT-6436",
                            "variant": "A"
                        },
                        {
                            "experiment": "ACT-6570",
                            "variant": "A"
                        },
                        {
                            "experiment": "ACT-6846",
                            "variant": "B"
                        },
                        {
                            "experiment": "ACT-6961",
                            "variant": "A"
                        },
                        {
                            "experiment": "ACT-6712",
                            "variant": "B"
                        },
                        {
                            "experiment": "ACT-6723",
                            "variant": "B"
                        },
                        {
                            "experiment": "ACT-6958",
                            "variant": "A"
                        },
                        {
                            "experiment": "ACT-6994",
                            "variant": "B"
                        },
                        {
                            "experiment": "ACT-6996",
                            "variant": "B"
                        },
                        {
                            "experiment": "ACT-6869-AT",
                            "variant": "A"
                        },
                        {
                            "experiment": "ACT-7028",
                            "variant": "B"
                        },
                        {
                            "experiment": "ACT-7042",
                            "variant": "A"
                        },
                        {
                            "experiment": "ACT-7110",
                            "variant": "A"
                        },
                        {
                            "experiment": "ACT-7114",
                            "variant": "B"
                        },
                        {
                            "experiment": "ACT-6962",
                            "variant": "A"
                        },
                        {
                            "experiment": "ACT-7287",
                            "variant": "A"
                        },
                        {
                            "experiment": "ACTD-5",
                            "variant": "B"
                        },
                        {
                            "experiment": "ACTD-8",
                            "variant": "B"
                        },
                        {
                            "experiment": "ACTD-9",
                            "variant": "A"
                        },
                        {
                            "experiment": "ACTD-101",
                            "variant": "A"
                        },
                        {
                            "experiment": "ACTD-112",
                            "variant": "B"
                        },
                        {
                            "experiment": "ACTD-157",
                            "variant": "B"
                        },
                        {
                            "experiment": "ACTD-190",
                            "variant": "B"
                        },
                        {
                            "experiment": "ACTD-158",
                            "variant": "A"
                        },
                        {
                            "experiment": "ACTD-332",
                            "variant": "A"
                        },
                        {
                            "experiment": "ACTD-205",
                            "variant": "A"
                        },
                        {
                            "experiment": "ACTD-209",
                            "variant": "B"
                        },
                        {
                            "experiment": "ACTD-308",
                            "variant": "A"
                        },
                        {
                            "experiment": "ACTD-329",
                            "variant": "B"
                        },
                        {
                            "experiment": "ACTD-367",
                            "variant": "B"
                        },
                        {
                            "experiment": "ACTD-420",
                            "variant": "B"
                        },
                        {
                            "experiment": "ACTD-437",
                            "variant": "B"
                        },
                        {
                            "experiment": "ACTD-471",
                            "variant": "B"
                        },
                        {
                            "experiment": "ACTD-488",
                            "variant": "B"
                        },
                        {
                            "experiment": "ACTD-492",
                            "variant": "B"
                        },
                        {
                            "experiment": "ACTD-538",
                            "variant": "A"
                        },
                        {
                            "experiment": "ACTD-489",
                            "variant": "A"
                        },
                        {
                            "experiment": "MPW-2721",
                            "variant": "A"
                        },
                        {
                            "experiment": "UNISAVE-HIDE-ATC-WEB",
                            "variant": "B"
                        },
                        {
                            "experiment": "UNISAVE-1306",
                            "variant": "A"
                        },
                        {
                            "experiment": "UNISAVE-1859",
                            "variant": "B"
                        },
                        {
                            "experiment": "WLBE-73",
                            "variant": "A"
                        },
                        {
                            "experiment": "WLBE-75",
                            "variant": "A"
                        },
                        {
                            "experiment": "WLBE-79",
                            "variant": "A"
                        },
                        {
                            "experiment": "WLBE-1422",
                            "variant": "A"
                        },
                        {
                            "experiment": "WLBE-1421",
                            "variant": "A"
                        },
                        {
                            "experiment": "TMKTWEB-UNLOCK-TS-HPEBPTYP",
                            "variant": "A"
                        },
                        {
                            "experiment": "WLBC-915",
                            "variant": "A"
                        },
                        {
                            "experiment": "WLBC-1059",
                            "variant": "A"
                        },
                        {
                            "experiment": "ACTB-685",
                            "variant": "A"
                        },
                        {
                            "experiment": "ACTB-SEO-KILLSWITCH",
                            "variant": "B"
                        },
                        {
                            "experiment": "ACTB-1906",
                            "variant": "B"
                        },
                        {
                            "experiment": "AFT-1351",
                            "variant": "A"
                        },
                        {
                            "experiment": "AFT-1709",
                            "variant": "A"
                        },
                        {
                            "experiment": "TRIPWL-501",
                            "variant": "A"
                        },
                        {
                            "experiment": "ACCWL-967",
                            "variant": "A"
                        },
                        {
                            "experiment": "ABE-4553",
                            "variant": "B"
                        },
                        {
                            "experiment": "ABE-6117",
                            "variant": "A"
                        },
                        {
                            "experiment": "ABE-6019",
                            "variant": "A"
                        },
                        {
                            "experiment": "AVENGERS-1655",
                            "variant": "B"
                        },
                        {
                            "experiment": "ADSEFF-1333",
                            "variant": "B"
                        },
                        {
                            "experiment": "ACT-6686",
                            "variant": "B"
                        },
                        {
                            "experiment": "WLBE-402",
                            "variant": "B"
                        },
                        {
                            "experiment": "ADSEFF-309",
                            "variant": "B"
                        },
                        {
                            "experiment": "ADSEFF-448",
                            "variant": "B"
                        },
                        {
                            "experiment": "ADSEFF-834",
                            "variant": "B"
                        },
                        {
                            "experiment": "ADSREQ-1614",
                            "variant": "B"
                        },
                        {
                            "experiment": "ADSEFF-316",
                            "variant": "B"
                        },
                        {
                            "experiment": "ADSEFF-1429",
                            "variant": "B"
                        },
                        {
                            "experiment": "ADSEFF-539",
                            "variant": "B"
                        },
                        {
                            "experiment": "ADSEFF-597",
                            "variant": "B"
                        },
                        {
                            "experiment": "AVENGERS-2732",
                            "variant": "A"
                        },
                        {
                            "experiment": "ADSEFF-720",
                            "variant": "B"
                        },
                        {
                            "experiment": "ADSEFF-745",
                            "variant": "B"
                        },
                        {
                            "experiment": "ADSFNDN-443",
                            "variant": "A"
                        },
                        {
                            "experiment": "JTBFP-1733",
                            "variant": "A"
                        },
                        {
                            "experiment": "JTBFP-1734",
                            "variant": "A"
                        },
                        {
                            "experiment": "ADSEFF-831",
                            "variant": "A"
                        },
                        {
                            "experiment": "ADSEFF-910",
                            "variant": "B"
                        },
                        {
                            "experiment": "ADSEFF-708",
                            "variant": "B"
                        },
                        {
                            "experiment": "ADSEFF-981",
                            "variant": "B"
                        },
                        {
                            "experiment": "ADSEFF-968",
                            "variant": "A"
                        },
                        {
                            "experiment": "ADSFNDN-594",
                            "variant": "A"
                        },
                        {
                            "experiment": "ADSEFF-994",
                            "variant": "A"
                        },
                        {
                            "experiment": "ADSEFF-717",
                            "variant": "B"
                        },
                        {
                            "experiment": "ADSEFF-1050",
                            "variant": "B"
                        },
                        {
                            "experiment": "ADSEFF-919",
                            "variant": "B"
                        },
                        {
                            "experiment": "SKYA-10159",
                            "variant": "A"
                        },
                        {
                            "experiment": "ADSFNDN-479",
                            "variant": "A"
                        },
                        {
                            "experiment": "ADSEFF-1092",
                            "variant": "B"
                        },
                        {
                            "experiment": "ADSEFF-676",
                            "variant": "B"
                        },
                        {
                            "experiment": "AVENGERS-3410",
                            "variant": "A"
                        },
                        {
                            "experiment": "ADSEFF-1194",
                            "variant": "A"
                        },
                        {
                            "experiment": "ADSEFF-686",
                            "variant": "B"
                        },
                        {
                            "experiment": "ADSFNDN-698",
                            "variant": "B"
                        },
                        {
                            "experiment": "ADSEFF-1198",
                            "variant": "B"
                        },
                        {
                            "experiment": "ADSEFF-663",
                            "variant": "A"
                        },
                        {
                            "experiment": "ADSEFF-1201",
                            "variant": "A"
                        },
                        {
                            "experiment": "AVENGERS-3503",
                            "variant": "A"
                        },
                        {
                            "experiment": "ADSFNDN-800",
                            "variant": "A"
                        },
                        {
                            "experiment": "ADSEFF-508",
                            "variant": "B"
                        },
                        {
                            "experiment": "ADSEFF-693",
                            "variant": "B"
                        },
                        {
                            "experiment": "ADSEFF-704",
                            "variant": "B"
                        },
                        {
                            "experiment": "ADSEFF-1277",
                            "variant": "A"
                        },
                        {
                            "experiment": "ADSFNDN-841",
                            "variant": "A"
                        },
                        {
                            "experiment": "ADSEFF-1396",
                            "variant": "A"
                        },
                        {
                            "experiment": "ADSEFF-1330",
                            "variant": "A"
                        },
                        {
                            "experiment": "ADSFNDN-776",
                            "variant": "B"
                        },
                        {
                            "experiment": "ADSEFF-1385",
                            "variant": "A"
                        },
                        {
                            "experiment": "ADSEFF-1438",
                            "variant": "B"
                        },
                        {
                            "experiment": "ADSEFF-1435",
                            "variant": "B"
                        },
                        {
                            "experiment": "ADSFNDN-661",
                            "variant": "B"
                        },
                        {
                            "experiment": "ADSFNDN-835",
                            "variant": "B"
                        },
                        {
                            "experiment": "ADSFNDN-1130",
                            "variant": "A"
                        },
                        {
                            "experiment": "ADSEFF-1467",
                            "variant": "A"
                        },
                        {
                            "experiment": "ADSFNDN-1069",
                            "variant": "A"
                        },
                        {
                            "experiment": "ADSFNDN-840",
                            "variant": "B"
                        },
                        {
                            "experiment": "ADSEFF-474",
                            "variant": "A"
                        },
                        {
                            "experiment": "ADSEFF-1655",
                            "variant": "A"
                        },
                        {
                            "experiment": "ACT-4093",
                            "variant": "A"
                        }
                    ]
                }
            },
            "searchRequest": {
                "searchType": "CITY",
                "searchValue": "318",
                "searchCriteria": {
                    "pagination": {
                        "size": 24,
                        "number": 1
                    },
                    "sort": {
                        "code": "ActivitiesSsr",
                        "order": "Descending"
                    },
                    "filters": {
                        "valueFilters": [],
                        "rangeFilters": [],
                        "dynamicFilters": [
                            {
                                "filters": []
                            }
                        ]
                    }
                }
            }
        }
    },
    "query": "query search ($SearchRequest: SearchRequest!) { search (SearchRequest: $SearchRequest) { isSuccess, result { isCompleted, resultInfo { totalActivities, totalFilteredActivities, pagination { number, size, hasMore }, selectedActivityId }, activities { masterActivityId, masterSupplierId, rankScore { value }, activityRepresentativeInfo { activityId, activityToken, pricingSummary { pricing { currency, display { perBook { displayType, quantity, total { exclusive { chargeTotal, crossedOut }, allInclusive { chargeTotal, crossedOut } }, loyaltyOffers { loyaltyOfferType, loyaltyToken, earnOffer { points }, burnOffer { points, userPayableAmount, itemPriceInPoints } }, promocodeItems { promotionCode, discountedValue, isApplied, isAllowPricePeek, isAutoApply }, badges { activityHighlights { badgeType, enrichmentData }, deals { badgeType, enrichmentData }, bookingInfo { badgeType, enrichmentData }, keyAttributes { badgeType, enrichmentData }, promocodes { badgeType, enrichmentData } } }, perPax { displayType, paxCode, quantity, total { exclusive { chargeTotal, crossedOut }, allInclusive { chargeTotal, crossedOut } }, loyaltyOffers { loyaltyOfferType, loyaltyToken, earnOffer { points }, burnOffer { points, userPayableAmount, itemPriceInPoints } } } } } }, supplierActivityCode, cancellationPolicy { cancellationType, policies { hoursFrom, hoursUntil, penaltyCode } } }, content { activity { title, categories, description, duration { minutes, minutesUntil, durationType }, location { city { id, name }, addressLine, geo { lat, long }, country { id, name }, postalCode } }, images { url, description, imageType, imageSize { height, width } }, reviewSummary { averageScore, totalCount }, detail { offerDetails { supplierInfo { providerName } } }, contentLocale, badges { bookingInfo { badgeType, enrichmentData }, activityHighlights { badgeType, enrichmentData }, deals { badgeType, enrichmentData }, keyAttributes { badgeType, enrichmentData }, promocodes { badgeType, enrichmentData } } } }, matrix { sort { availableCode, availableOrder }, filter { rangeFilterMatrix { code, min, max, bucket { count, min, max } }, valueFilterMatrix { availableValue { count, id, priority }, code }, dynamicFilterMatrix { code, id, count, order, name, availableValues { code, id, count, order, name, resolverType } } } }, pointOfInterests { id, name, nameTranslated, imageUrl, activities { masterActivityId, masterSupplierId, rankScore { value }, activityRepresentativeInfo { activityId, activityToken, pricingSummary { pricing { currency, display { perBook { displayType, quantity, total { exclusive { chargeTotal, crossedOut }, allInclusive { chargeTotal, crossedOut } }, loyaltyOffers { loyaltyOfferType, loyaltyToken, earnOffer { points }, burnOffer { points, userPayableAmount, itemPriceInPoints } }, promocodeItems { promotionCode, discountedValue, isApplied, isAllowPricePeek, isAutoApply }, badges { activityHighlights { badgeType, enrichmentData }, deals { badgeType, enrichmentData }, bookingInfo { badgeType, enrichmentData }, keyAttributes { badgeType, enrichmentData }, promocodes { badgeType, enrichmentData } } }, perPax { displayType, paxCode, quantity, total { exclusive { chargeTotal, crossedOut }, allInclusive { chargeTotal, crossedOut } }, loyaltyOffers { loyaltyOfferType, loyaltyToken, earnOffer { points }, burnOffer { points, userPayableAmount, itemPriceInPoints } } } } } }, supplierActivityCode, cancellationPolicy { cancellationType, policies { hoursFrom, hoursUntil, penaltyCode } } }, content { activity { title, categories, description, duration { minutes, minutesUntil, durationType }, location { city { id, name }, addressLine, geo { lat, long }, country { id, name }, postalCode } }, images { url, description, imageType, imageSize { height, width } }, reviewSummary { averageScore, totalCount }, detail { offerDetails { supplierInfo { providerName } } }, contentLocale, badges { bookingInfo { badgeType, enrichmentData }, activityHighlights { badgeType, enrichmentData }, deals { badgeType, enrichmentData }, keyAttributes { badgeType, enrichmentData }, promocodes { badgeType, enrichmentData } } } } } }, errors { errorCode, subErrorCode, message } } } ",
    "logTags": {
        "id": "318",
        "name": "New York (NY)",
        "activityId": "0",
        "cityId": "318",
        "cityName": "New York (NY)",
        "countryId": "181",
        "countryName": "United States",
        "countryISO2": "US",
        "areaId": "0",
        "areaName": "undefined",
        "stateName": "New York State",
        "operation": "search",
        "selectedActivity": "",
        "searchType": "CITY",
        "pageSize": "24",
        "pageNumber": "1",
        "sortCode": "ActivitiesSsr",
        "sortOrder": "Descending",
        "isPopularActivities": "false",
        "keyword": ""
    },
    "pageTypeId": 9101
}

headers = {
    'accept': 'application/json, text/plain, */*',
    'accept-encoding': 'gzip, deflate, br, zstd',
    'accept-language': 'en-US,en;q=0.9,id;q=0.8,ms;q=0.7',
    'access-control-max-age': '7200',
    'ag-activities-client-context-id': '9101',
    'ag-activities-client-id': 'activities-web',
    'ag-activities-identity-token': 'eyJhbGciOiJkaXIiLCJlbmMiOiJBMjU2R0NNIn0..yH4xf6qfpNBcZaan.kM7SfA30VnZ9VvHPeUM8Kgg0UvBNOIi7gNC3t7PAggAmV35e4A1j3qexx4M4e2BQrAxHOIWDJqT3o77xI6MhE0S5Gq_Kx6MQ0n5tMIYItDOXrJ7aKaPX9QbYjb2NC0Ol7c4z32XINfqdNTrDM8p9flWx9DDsvckQj6RdkhkF97AeXvTXR9_uSC0wtf85XWaqNjad5h030qnBbMonfOdP6Jhqb8ifkEllhBwHHH2XwIObaFQpB8KkOGkilEGIjNxIUEgSDh5aHaIFTUkZLtJdBgpwgj8.NxYxfZ5RsmlrJ4WxARE_dQ',
    'ag-analytics-session-id': '1907171690167623479',
    'ag-cid': '1953630',
    'ag-correlation-id': '4ab1141b-5b21-4f12-9053-fe37ad698eee',
    'ag-language-group-id': '1',
    'ag-language-id': '1',
    'ag-language-locale': 'en-us',
    'ag-mse-pricing-token': '',
    'ag-origin': 'ID',
    'ag-platform-id': '1',
    'ag-request-attempt': '1',
    'ag-request-id': '7b372c71-dfc0-43df-9e98-c621e967b2e2',
    'ag-retry-attempt': '0',
    'ag-traffic-group': '5',
    'ag-traffic-sub-group': '132',
    'ag-use-mock': 'false',
    'ag-whitelabel-id': '1',
    'ag-whitelabel-token': 'F1A5905F-9620-45E5-9D91-D251C07E0B42',
    'content-length': '10985',
    'content-type': 'application/json',
    'cookie': 'agoda.landings=1953630|77d1fac8-9540-4909-b98b-ee5ab80aeb13||pi2pswvdfcfa0pvsbhpfknf2|2026-06-27T17:12:27|True|19----1953630|77d1fac8-9540-4909-b98b-ee5ab80aeb13||pi2pswvdfcfa0pvsbhpfknf2|2026-06-27T17:12:27|True|20----1953630|77d1fac8-9540-4909-b98b-ee5ab80aeb13||pi2pswvdfcfa0pvsbhpfknf2|2026-06-27T17:12:27|True|99; agoda.user.03=UserId=cb56db72-db56-4163-b956-23ec71663a92; ASP.NET_SessionId=pi2pswvdfcfa0pvsbhpfknf2; agoda.version.03=CookieId=61a1a244-57b8-4e79-b5be-ba48d5c2fe6d&DLang=en-us&CurLabel=IDR; agoda.cid=1953630; agoda.familyMode=Mode=0; agoda.search.01=SHist=4$442736$9317$1$1$1$0$0$1782555150$$0&H=9308|0$442736; agoda.price.trk.01=PriceView=1; agoda.price.01=PriceView=1; xsrf_token=CfDJ8Dkuqwv-0VhLoFfD8dw7lYw2fvmEyXb7PslxLKDRJO6fDCp-tYwH2xLoQ_nmR9chmVYMpJwsA2n2uTuRvbTsjgwSLECwzPbwO220AM30fE-lWQnUFxw0_Cy6o0bRSNCPSq-xGAy1l0ZCz4pUk3AuzE; agoda.prius=PriusID=0&PointsMaxTraffic=Agoda; _ab50group=GroupB; _40-40-20Split=Group40A; utag_main=v_id:019f03c025960099cfaa4c854ba80507d015207500870$_sn:2$_se:1$_ss:1$_st:1782557013025$ses_id:1782555213025%3Bexp-session$_pn:1%3Bexp-session; t_pp=C4Q1zIVYMLJhjZ/E:Vzf+hzWcHw/tXn+Kp1gU1g==:0nyHdk/t/SNWSuO/KliW0nGe8qRvfje6A3s/ONGf+5YM70zasoN2onJVchq1sJdFY7DRI02sD2miyHsgP7d3P+3NMr1SgOAwiVJnGYNNql62mlxmjMm+TQtjMwDcT5oLgl24v0SM29rxkyZDBTJH10HGHtklp2C66Ccad+64VOgqa70A9JP4HYrr5GBRHH135Ig3qTlJuCqUYDCF3Jhd2uUweF24cPcWXN5ERG+zm+UH/KNe5Nhtsw5E7hkTL; agoda.consent=ID||2026-06-27 12:05:55Z; agoda.analytics=Id=1907171690167623479&Signature=7039073834015886605&Expiry=1782565716205; t_rc=dD0yNSZ1aWQ9Y2I1NmRiNzItZGI1Ni00MTYzLWI5NTYtMjNlYzcxNjYzYTky.i+ryjjQKzlye8CNLpjiDas/sTYUEzQlOQeNhAP7Lx+8=',
    'origin': 'https://www.agoda.com',
    'priority': 'u=1, i',
    'referer': 'https://www.agoda.com/activities/search?cityId=318&cid=1953630&tag=77d1fac8-9540-4909-b98b-ee5ab80aeb13',
    'sec-ch-ua': '"Microsoft Edge";v="149", "Chromium";v="149", "Not)A;Brand";v="24"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/149.0.0.0 Safari/537.36 Edg/149.0.0.0'
}

response = requests.post(url, headers=headers, data=json.dumps(payload))

# Check if the request was successful
if response.status_code == 200:
    print("Request successful!")
    print(response.json()) # Print the JSON response
else:
    print(f"Request failed with status code: {response.status_code}")
    print(response.text) # Print the error message or content
# Out:
# Request successful!
# ...
