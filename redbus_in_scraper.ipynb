# %%
import requests

url = "https://www.redbus.in/rpw/api/searchResults?fromCity=122&toCity=123&DOJ=12-May-2026&limit=100&offset=100&meta=true&groupId=0&sectionId=0&sort=0&sortOrder=0&from=initialLoad&getUuid=true&bT=1&clearLMBFilter=undefined&isFilterApplied=false"

headers = {
    "Host": "www.redbus.in",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:150.0) Gecko/20100101 Firefox/150.0",
    "Accept": "*/*",
    "Accept-Language": "en-US,en;q=0.9",
    "Accept-Encoding": "gzip, deflate, br, zstd",
    "Referer": "https://www.redbus.in/bus-tickets/bangalore-to-chennai?fromCityName=Bangalore&fromCityId=122&srcCountry=India&fromCityType=CITY&toCityName=Chennai&toCityId=123&destCountry=India&toCityType=CITY&onward=12-May-2026&doj=12-May-2026&ref=home",
    "Content-Type": "application/json",
    "Origin": "https://www.redbus.in",
    "Alt-Used": "www.redbus.in",
    "Connection": "keep-alive",
    "Cookie": """funnelVariant=RESPONSIVE; country=IND; currency=INR; defaultlanguage=en; language=en; selectedCurrency=INR; _abck=8D43AE465D1C8BF7B77161847AD1CD50~-1~...~-1~-1~-1~-1~-1; ak_bmsc=670A57BD9F4385160324DB248E934331~000000000000000000000000000000~...; bm_sz=6F1F2AA35CCD308D00485F5B69AB974B~...~4407878~4535863; rayHomeAB=V0; abExpsVariantsForMri=["priceRangeAB:V0","geolocationAB:V1","leanerFunnelAB:V2","paymentBackAB:V3"]; channel=TAB; defaultLanguage=en; rbuuid=d8479290-4db3-11f1-942a-9b289e9b773a; mriClientId=BRd8479291-4db3-11f1-942a-9b289e9b773a; mriSessionId=BRd8479291-4db3-11f1-942a-9b289e9b773a; env=PROD; buildVersion=PROD_5a21c69fc7; bm_sv=8F402128FAD84F2677CEA1413F6B848E~~1; _ga_W2P7QGN8S2=GS2.1.s1778557034$o1$g1$t1778557104$j59$l0$h1234156605; _ga=GA1.1.236494880.1778557035; rb_fpData=%7B%22userAgent%22%3A%22Mozilla%2F5.0%20(Windows%20NT%2010.0%3B%20Win64%3B%20x64%3B%20rv%3A150.0)%20Gecko%2F20100101%20Firefox%2F150.0%22%2C%22browser%22%3A%22Firefox%22%2C%22version%22%3A%22150.0%22%2C%22os%22%3A%22Windows%22%2C%22osVersion%22%3A%2210.0%22%2C%22deviceType%22%3A%22Desktop%22%2C%22screenSize%22%3A%221366%2C728%22%2C%22screenDPI%22%3A1%2C%22screenResolution%22%3A%221366x768%22%2C%22screenColorDepth%22%3A24%2C%22aspectRatio%22%3A%22683%3A384%22%2C%22systemLanguage%22%3A%22en-US%22%2C%22connection%22%3A%22Unknown%22%2C%22effectiveConnection%22%3A%22Unknown%22%2C%22timeZone%22%3A8%7D; prev_mriSessionId=BRd8479291-4db3-11f1-942a-9b289e9b773a; rayBetaAB=V1; priceRangeAB=V0; geolocationAB=V1; leanerFunnelAB=V2; paymentBackAB=V3; unifiedSrpTabsAB=V1; referrer=home; sessionUserType=GUEST""",
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "same-origin",
    "Priority": "u=4",
    "TE": "trailers"
}

# The Content-Length header implies a request body, but no body content was provided.
# Assuming an empty JSON object for the body since Content-Type is application/json.
json_data = {}

try:
    response = requests.post(url, headers=headers, json=json_data)
    response.raise_for_status() # Raise an exception for HTTP errors

    print(f"Status Code: {response.status_code}")
    print("Response JSON:")
    display(response.json())
except requests.exceptions.RequestException as e:
    print(f"An error occurred: {e}")
    if hasattr(e, 'response') and e.response is not None:
        print(f"Response content: {e.response.text}")
# Out:
# Status Code: 200
# Response JSON:
# {'success': True,
#  'data': {'metaData': {'totalCount': 149,
#    'sections': [{'sectionId': 0,
#      'totalCount': 149,
#      'privateCount': 149,
#      'sectionInvCount': 149}],
#    'busLogoBaseUrl': 'https://origin-st.redbus.in/buslogos/country/',
#    'busImageBaseUrl': 'https://s3-ap-southeast-1.amazonaws.com/rbplus/BusImage/Domestic',
#    'primoCount': 25,
#    'nudge': {'imgURL': 'Nudges/social',
#     'title': '1924 seats sold on this route in the last 24 hours',
#     'bgColor': '#fff5e5',
#     'borderColor': '#ff9f1c'}},
#   'inventories': [{'operatorId': 23971,
#     'travelsName': 'NueGo',
#     'routeId': 28963864,
#     'busType': 'Electric A/C Seater/Sleeper (2+1)',
#     'busTypeId': 1944,
#     'serviceName': 'Bangalore To Chennai, NueGo',
#     'serviceId': '744',
#     'cancellationPolicy': '0:8:118:0;8:12:59:0;12:-1:30:0',
#     'operatorLogoPath': 'ind/logo/23971.png',
#     'totalRatings': 4.1,
# ...

# %%
data = response.json()
buses = data['data']['inventories']
len(buses)
# Out:
# 49

# %%
import requests

url = "https://www.redbus.in/rpw/api/perzCitySuggestion"

try:
    response = requests.get(url)
    response.raise_for_status()  # Raise an exception for HTTP errors

    print(f"Status Code: {response.status_code}")
    print("Response JSON:")
    display(response.json())
except requests.exceptions.RequestException as e:
    print(f"An error occurred: {e}")
    if hasattr(e, 'response') and e.response is not None:
        print(f"Response content: {e.response.text}")
# Out:
# Status Code: 200
# Response JSON:
# {'success': True,
#  'popular': [{'rank': 1,
#    'parentLocationName': 'Karnataka',
#    'parentLocation': 4,
#    'Name': 'Bangalore',
#    'locationType': 'CITY',
#    'cc': 'India',
#    'ID': 122,
#    'region': 'Karnataka'},
#   {'rank': 2,
#    'parentLocationName': 'Telangana',
#    'parentLocation': 193423,
#    'Name': 'Hyderabad',
#    'locationType': 'CITY',
#    'cc': 'India',
#    'ID': 124,
#    'region': 'Andhra Pradesh'},
#   {'rank': 3,
#    'parentLocationName': 'Tamil Nadu',
#    'parentLocation': 14,
#    'Name': 'Chennai',
#    'locationType': 'CITY',
#    'cc': 'India',
#    'ID': 123,
#    'region': 'Tamil Nadu'},
#   {'rank': 4,
#    'parentLocationName': 'Maharashtra',
#    'parentLocation': 13,
#    'Name': 'Pune',
#    'locationType': 'CITY',
#    'cc': 'India',
#    'ID': 130,
#    'region': 'Maharashtra and Goa'},
#   {'rank': 5,
#    'parentLocationName': 'Maharashtra',
#    'parentLocation': 13,
# ...
