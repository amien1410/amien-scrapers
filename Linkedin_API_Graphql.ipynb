# %%
# @title
data1 = [
    {
    "data": {
        "data": {
            "searchDashClustersByAll": {
                "metadata": {
                    "entityResultAttributes": null,
                    "bserpPaginationContext": null,
                    "totalResultCount": 5032,
                    "searchAlert": null,
                    "blockedQueryError": null,
                    "secondaryFilterCluster": null,
                    "$recipeTypes": [
                        "com.linkedin.dfce49e2c6bb412fb4161cbbc7190d0d"
                    ],
                    "lazyRightRail": null,
                    "queryType": null,
                    "$type": "com.linkedin.voyager.dash.search.SearchClusterCollectionMetadata",
                    "primaryResultType": "COMPANIES",
                    "paginationToken": null,
                    "primaryFilterCluster": null,
                    "blockedQuery": false,
                    "entityActionButtonStyle": null,
                    "searchId": "0f373d94-310b-4477-aeda-ef6f178350d9",
                    "filterAppliedCount": 0,
                    "clusterTitleFontSize": null,
                    "simpleInsightAttributes": null,
                    "desktopNavigationPanelTrackingId": null,
                    "knowledgeCardRightRail": null
                },
                "paging": {
                    "count": 10,
                    "start": 0,
                    "total": 1000,
                    "$recipeTypes": [
                        "com.linkedin.81b214c2cdd4f02cdb7d827958d2f3a1"
                    ],
                    "$type": "com.linkedin.restli.common.CollectionMetadata"
                },
                "$recipeTypes": [
                    "com.linkedin.5f1d22f924ecb6a031ee124b8b767900"
                ],
                "elements": [
                    {
                        "image": null,
                        "quickFilterActions": [],
                        "clusterRenderType": "LIST",
                        "dismissable": false,
                        "totalResultCount": null,
                        "controlName": null,
                        "description": null,
                        "title": null,
                        "$recipeTypes": [
                            "com.linkedin.5c853aba2154c55483e72bf6cdfaaf3e"
                        ],
                        "$type": "com.linkedin.voyager.dash.search.SearchClusterViewModel",
                        "actionTypeName": null,
                        "navigationText": null,
                        "feature": null,
                        "navigationCardAction": null,
                        "position": 1,
                        "items": [
                            {
                                "item": {
                                    "entityResult": null,
                                    "cluster": null,
                                    "bannerCard": null,
                                    "searchAlert": null,
                                    "upsellSlot": null,
                                    "coachRealtimeResponse": null,
                                    "searchSuggestionCard": null,
                                    "coachPromptCluster": null,
                                    "feedbackCard": null,
                                    "knowledgeCardV2": null,
                                    "keywordsSuggestionCard": null,
                                    "queryClarificationCard": null,
                                    "topicalQuestionCard": null,
                                    "simpleTextV2": {
                                        "showDashes": false,
                                        "textAlignment": "LEFT",
                                        "numDashes": 0,
                                        "text": {
                                            "textDirection": "USER_LOCALE",
                                            "text": "About 5,000 results",
                                            "attributesV2": [],
                                            "accessibilityTextAttributesV2": [],
                                            "accessibilityText": null,
                                            "$recipeTypes": [
                                                "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                                            ],
                                            "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
                                        },
                                        "$recipeTypes": [
                                            "com.linkedin.5bbb553a55f0e4d13343716ac69b5f48"
                                        ],
                                        "renderStyle": "PLAIN",
                                        "$type": "com.linkedin.voyager.dash.search.SimpleText"
                                    },
                                    "promoCard": null,
                                    "searchFeedUpdate": null,
                                    "searchQuestionAndAnswerCard": null,
                                    "centeredText": null,
                                    "simpleImage": null
                                },
                                "position": 1,
                                "$recipeTypes": [
                                    "com.linkedin.edd11a570456ce19ca1f5ec3c9bb03c1"
                                ],
                                "$type": "com.linkedin.voyager.dash.search.SearchItem"
                            }
                        ],
                        "results": [],
                        "trackingId": "ôd\u000eLÜÖGì¥Åë!2¾"
                    },
                    {
                        "image": null,
                        "quickFilterActions": [],
                        "clusterRenderType": "LIST",
                        "dismissable": false,
                        "totalResultCount": null,
                        "controlName": null,
                        "description": null,
                        "title": null,
                        "$recipeTypes": [
                            "com.linkedin.5c853aba2154c55483e72bf6cdfaaf3e"
                        ],
                        "$type": "com.linkedin.voyager.dash.search.SearchClusterViewModel",
                        "actionTypeName": null,
                        "navigationText": null,
                        "feature": null,
                        "navigationCardAction": null,
                        "position": 2,
                        "items": [
                            {
                                "item": {
                                    "cluster": null,
                                    "bannerCard": null,
                                    "searchAlert": null,
                                    "upsellSlot": null,
                                    "coachRealtimeResponse": null,
                                    "searchSuggestionCard": null,
                                    "coachPromptCluster": null,
                                    "feedbackCard": null,
                                    "knowledgeCardV2": null,
                                    "keywordsSuggestionCard": null,
                                    "queryClarificationCard": null,
                                    "topicalQuestionCard": null,
                                    "*entityResult": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:74122547,SEARCH_SRP,DEFAULT)",
                                    "simpleTextV2": null,
                                    "promoCard": null,
                                    "searchFeedUpdate": null,
                                    "searchQuestionAndAnswerCard": null,
                                    "centeredText": null,
                                    "simpleImage": null
                                },
                                "position": 1,
                                "$recipeTypes": [
                                    "com.linkedin.edd11a570456ce19ca1f5ec3c9bb03c1"
                                ],
                                "$type": "com.linkedin.voyager.dash.search.SearchItem"
                            },
                            {
                                "item": {
                                    "cluster": null,
                                    "bannerCard": null,
                                    "searchAlert": null,
                                    "upsellSlot": null,
                                    "coachRealtimeResponse": null,
                                    "searchSuggestionCard": null,
                                    "coachPromptCluster": null,
                                    "feedbackCard": null,
                                    "knowledgeCardV2": null,
                                    "keywordsSuggestionCard": null,
                                    "queryClarificationCard": null,
                                    "topicalQuestionCard": null,
                                    "*entityResult": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:1386373,SEARCH_SRP,DEFAULT)",
                                    "simpleTextV2": null,
                                    "promoCard": null,
                                    "searchFeedUpdate": null,
                                    "searchQuestionAndAnswerCard": null,
                                    "centeredText": null,
                                    "simpleImage": null
                                },
                                "position": 2,
                                "$recipeTypes": [
                                    "com.linkedin.edd11a570456ce19ca1f5ec3c9bb03c1"
                                ],
                                "$type": "com.linkedin.voyager.dash.search.SearchItem"
                            },
                            {
                                "item": {
                                    "entityResult": null,
                                    "cluster": null,
                                    "bannerCard": null,
                                    "searchAlert": null,
                                    "coachRealtimeResponse": null,
                                    "searchSuggestionCard": null,
                                    "coachPromptCluster": null,
                                    "feedbackCard": null,
                                    "knowledgeCardV2": null,
                                    "keywordsSuggestionCard": null,
                                    "*upsellSlot": "urn:li:fsd_premiumUpsellSlot:ADVANCED_COMPANY_SEARCH_FILTER_INLINE_RESULT",
                                    "queryClarificationCard": null,
                                    "topicalQuestionCard": null,
                                    "simpleTextV2": null,
                                    "promoCard": null,
                                    "searchFeedUpdate": null,
                                    "searchQuestionAndAnswerCard": null,
                                    "centeredText": null,
                                    "simpleImage": null
                                },
                                "position": 3,
                                "$recipeTypes": [
                                    "com.linkedin.edd11a570456ce19ca1f5ec3c9bb03c1"
                                ],
                                "$type": "com.linkedin.voyager.dash.search.SearchItem"
                            },
                            {
                                "item": {
                                    "cluster": null,
                                    "bannerCard": null,
                                    "searchAlert": null,
                                    "upsellSlot": null,
                                    "coachRealtimeResponse": null,
                                    "searchSuggestionCard": null,
                                    "coachPromptCluster": null,
                                    "feedbackCard": null,
                                    "knowledgeCardV2": null,
                                    "keywordsSuggestionCard": null,
                                    "queryClarificationCard": null,
                                    "topicalQuestionCard": null,
                                    "*entityResult": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:71605911,SEARCH_SRP,DEFAULT)",
                                    "simpleTextV2": null,
                                    "promoCard": null,
                                    "searchFeedUpdate": null,
                                    "searchQuestionAndAnswerCard": null,
                                    "centeredText": null,
                                    "simpleImage": null
                                },
                                "position": 4,
                                "$recipeTypes": [
                                    "com.linkedin.edd11a570456ce19ca1f5ec3c9bb03c1"
                                ],
                                "$type": "com.linkedin.voyager.dash.search.SearchItem"
                            },
                            {
                                "item": {
                                    "cluster": null,
                                    "bannerCard": null,
                                    "searchAlert": null,
                                    "upsellSlot": null,
                                    "coachRealtimeResponse": null,
                                    "searchSuggestionCard": null,
                                    "coachPromptCluster": null,
                                    "feedbackCard": null,
                                    "knowledgeCardV2": null,
                                    "keywordsSuggestionCard": null,
                                    "queryClarificationCard": null,
                                    "topicalQuestionCard": null,
                                    "*entityResult": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:2441750,SEARCH_SRP,DEFAULT)",
                                    "simpleTextV2": null,
                                    "promoCard": null,
                                    "searchFeedUpdate": null,
                                    "searchQuestionAndAnswerCard": null,
                                    "centeredText": null,
                                    "simpleImage": null
                                },
                                "position": 5,
                                "$recipeTypes": [
                                    "com.linkedin.edd11a570456ce19ca1f5ec3c9bb03c1"
                                ],
                                "$type": "com.linkedin.voyager.dash.search.SearchItem"
                            },
                            {
                                "item": {
                                    "cluster": null,
                                    "bannerCard": null,
                                    "searchAlert": null,
                                    "upsellSlot": null,
                                    "coachRealtimeResponse": null,
                                    "searchSuggestionCard": null,
                                    "coachPromptCluster": null,
                                    "feedbackCard": null,
                                    "knowledgeCardV2": null,
                                    "keywordsSuggestionCard": null,
                                    "queryClarificationCard": null,
                                    "topicalQuestionCard": null,
                                    "*entityResult": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:82778753,SEARCH_SRP,DEFAULT)",
                                    "simpleTextV2": null,
                                    "promoCard": null,
                                    "searchFeedUpdate": null,
                                    "searchQuestionAndAnswerCard": null,
                                    "centeredText": null,
                                    "simpleImage": null
                                },
                                "position": 6,
                                "$recipeTypes": [
                                    "com.linkedin.edd11a570456ce19ca1f5ec3c9bb03c1"
                                ],
                                "$type": "com.linkedin.voyager.dash.search.SearchItem"
                            },
                            {
                                "item": {
                                    "cluster": null,
                                    "bannerCard": null,
                                    "searchAlert": null,
                                    "upsellSlot": null,
                                    "coachRealtimeResponse": null,
                                    "searchSuggestionCard": null,
                                    "coachPromptCluster": null,
                                    "feedbackCard": null,
                                    "knowledgeCardV2": null,
                                    "keywordsSuggestionCard": null,
                                    "queryClarificationCard": null,
                                    "topicalQuestionCard": null,
                                    "*entityResult": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:3541653,SEARCH_SRP,DEFAULT)",
                                    "simpleTextV2": null,
                                    "promoCard": null,
                                    "searchFeedUpdate": null,
                                    "searchQuestionAndAnswerCard": null,
                                    "centeredText": null,
                                    "simpleImage": null
                                },
                                "position": 7,
                                "$recipeTypes": [
                                    "com.linkedin.edd11a570456ce19ca1f5ec3c9bb03c1"
                                ],
                                "$type": "com.linkedin.voyager.dash.search.SearchItem"
                            },
                            {
                                "item": {
                                    "cluster": null,
                                    "bannerCard": null,
                                    "searchAlert": null,
                                    "upsellSlot": null,
                                    "coachRealtimeResponse": null,
                                    "searchSuggestionCard": null,
                                    "coachPromptCluster": null,
                                    "feedbackCard": null,
                                    "knowledgeCardV2": null,
                                    "keywordsSuggestionCard": null,
                                    "queryClarificationCard": null,
                                    "topicalQuestionCard": null,
                                    "*entityResult": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:13644897,SEARCH_SRP,DEFAULT)",
                                    "simpleTextV2": null,
                                    "promoCard": null,
                                    "searchFeedUpdate": null,
                                    "searchQuestionAndAnswerCard": null,
                                    "centeredText": null,
                                    "simpleImage": null
                                },
                                "position": 8,
                                "$recipeTypes": [
                                    "com.linkedin.edd11a570456ce19ca1f5ec3c9bb03c1"
                                ],
                                "$type": "com.linkedin.voyager.dash.search.SearchItem"
                            },
                            {
                                "item": {
                                    "cluster": null,
                                    "bannerCard": null,
                                    "searchAlert": null,
                                    "upsellSlot": null,
                                    "coachRealtimeResponse": null,
                                    "searchSuggestionCard": null,
                                    "coachPromptCluster": null,
                                    "feedbackCard": null,
                                    "knowledgeCardV2": null,
                                    "keywordsSuggestionCard": null,
                                    "queryClarificationCard": null,
                                    "topicalQuestionCard": null,
                                    "*entityResult": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:18128605,SEARCH_SRP,DEFAULT)",
                                    "simpleTextV2": null,
                                    "promoCard": null,
                                    "searchFeedUpdate": null,
                                    "searchQuestionAndAnswerCard": null,
                                    "centeredText": null,
                                    "simpleImage": null
                                },
                                "position": 9,
                                "$recipeTypes": [
                                    "com.linkedin.edd11a570456ce19ca1f5ec3c9bb03c1"
                                ],
                                "$type": "com.linkedin.voyager.dash.search.SearchItem"
                            },
                            {
                                "item": {
                                    "cluster": null,
                                    "bannerCard": null,
                                    "searchAlert": null,
                                    "upsellSlot": null,
                                    "coachRealtimeResponse": null,
                                    "searchSuggestionCard": null,
                                    "coachPromptCluster": null,
                                    "feedbackCard": null,
                                    "knowledgeCardV2": null,
                                    "keywordsSuggestionCard": null,
                                    "queryClarificationCard": null,
                                    "topicalQuestionCard": null,
                                    "*entityResult": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:488891,SEARCH_SRP,DEFAULT)",
                                    "simpleTextV2": null,
                                    "promoCard": null,
                                    "searchFeedUpdate": null,
                                    "searchQuestionAndAnswerCard": null,
                                    "centeredText": null,
                                    "simpleImage": null
                                },
                                "position": 10,
                                "$recipeTypes": [
                                    "com.linkedin.edd11a570456ce19ca1f5ec3c9bb03c1"
                                ],
                                "$type": "com.linkedin.voyager.dash.search.SearchItem"
                            },
                            {
                                "item": {
                                    "cluster": null,
                                    "bannerCard": null,
                                    "searchAlert": null,
                                    "upsellSlot": null,
                                    "coachRealtimeResponse": null,
                                    "searchSuggestionCard": null,
                                    "coachPromptCluster": null,
                                    "feedbackCard": null,
                                    "knowledgeCardV2": null,
                                    "keywordsSuggestionCard": null,
                                    "queryClarificationCard": null,
                                    "topicalQuestionCard": null,
                                    "*entityResult": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:97427935,SEARCH_SRP,DEFAULT)",
                                    "simpleTextV2": null,
                                    "promoCard": null,
                                    "searchFeedUpdate": null,
                                    "searchQuestionAndAnswerCard": null,
                                    "centeredText": null,
                                    "simpleImage": null
                                },
                                "position": 11,
                                "$recipeTypes": [
                                    "com.linkedin.edd11a570456ce19ca1f5ec3c9bb03c1"
                                ],
                                "$type": "com.linkedin.voyager.dash.search.SearchItem"
                            }
                        ],
                        "results": [],
                        "trackingId": "®\u0011Â§?G¢\u0003wïÓ"
                    },
                    {
                        "image": null,
                        "quickFilterActions": [],
                        "clusterRenderType": "LIST",
                        "dismissable": false,
                        "totalResultCount": null,
                        "controlName": null,
                        "description": null,
                        "title": null,
                        "$recipeTypes": [
                            "com.linkedin.5c853aba2154c55483e72bf6cdfaaf3e"
                        ],
                        "$type": "com.linkedin.voyager.dash.search.SearchClusterViewModel",
                        "actionTypeName": null,
                        "navigationText": null,
                        "feature": null,
                        "navigationCardAction": null,
                        "position": 3,
                        "items": [
                            {
                                "item": {
                                    "entityResult": null,
                                    "cluster": null,
                                    "bannerCard": null,
                                    "searchAlert": null,
                                    "*feedbackCard": "urn:li:fsd_feedbackCard:SRP_FEEDBACK_COMPANIES",
                                    "upsellSlot": null,
                                    "coachRealtimeResponse": null,
                                    "searchSuggestionCard": null,
                                    "coachPromptCluster": null,
                                    "knowledgeCardV2": null,
                                    "keywordsSuggestionCard": null,
                                    "queryClarificationCard": null,
                                    "topicalQuestionCard": null,
                                    "simpleTextV2": null,
                                    "promoCard": null,
                                    "searchFeedUpdate": null,
                                    "searchQuestionAndAnswerCard": null,
                                    "centeredText": null,
                                    "simpleImage": null
                                },
                                "position": 12,
                                "$recipeTypes": [
                                    "com.linkedin.edd11a570456ce19ca1f5ec3c9bb03c1"
                                ],
                                "$type": "com.linkedin.voyager.dash.search.SearchItem"
                            }
                        ],
                        "results": [],
                        "trackingId": "\u0013²OP\u00128A#\u001eÕU6ßT"
                    }
                ],
                "$type": "com.linkedin.restli.common.CollectionResponse"
            },
            "$recipeTypes": [
                "com.linkedin.c293aa010e51bae32433eeb13b1682fa"
            ],
            "$type": "com.linkedin.c293aa010e51bae32433eeb13b1682fa"
        }
    },
    "included": [
        {
            "entityUrn": "urn:li:fsd_company:1386373",
            "$recipeTypes": [
                "com.linkedin.2c2374bef3eaba3e079b4a11e2f7bea8"
            ],
            "$type": "com.linkedin.voyager.dash.organization.Company"
        },
        {
            "entityUrn": "urn:li:fsd_company:82778753",
            "$recipeTypes": [
                "com.linkedin.2c2374bef3eaba3e079b4a11e2f7bea8"
            ],
            "$type": "com.linkedin.voyager.dash.organization.Company"
        },
        {
            "entityUrn": "urn:li:fsd_company:71605911",
            "$recipeTypes": [
                "com.linkedin.2c2374bef3eaba3e079b4a11e2f7bea8"
            ],
            "$type": "com.linkedin.voyager.dash.organization.Company"
        },
        {
            "entityUrn": "urn:li:fsd_company:2441750",
            "$recipeTypes": [
                "com.linkedin.2c2374bef3eaba3e079b4a11e2f7bea8"
            ],
            "$type": "com.linkedin.voyager.dash.organization.Company"
        },
        {
            "entityUrn": "urn:li:fsd_company:74122547",
            "$recipeTypes": [
                "com.linkedin.2c2374bef3eaba3e079b4a11e2f7bea8"
            ],
            "$type": "com.linkedin.voyager.dash.organization.Company"
        },
        {
            "entityUrn": "urn:li:fsd_company:13644897",
            "$recipeTypes": [
                "com.linkedin.2c2374bef3eaba3e079b4a11e2f7bea8"
            ],
            "$type": "com.linkedin.voyager.dash.organization.Company"
        },
        {
            "entityUrn": "urn:li:fsd_company:97427935",
            "$recipeTypes": [
                "com.linkedin.2c2374bef3eaba3e079b4a11e2f7bea8"
            ],
            "$type": "com.linkedin.voyager.dash.organization.Company"
        },
        {
            "entityUrn": "urn:li:fsd_company:488891",
            "$recipeTypes": [
                "com.linkedin.2c2374bef3eaba3e079b4a11e2f7bea8"
            ],
            "$type": "com.linkedin.voyager.dash.organization.Company"
        },
        {
            "entityUrn": "urn:li:fsd_company:3541653",
            "$recipeTypes": [
                "com.linkedin.2c2374bef3eaba3e079b4a11e2f7bea8"
            ],
            "$type": "com.linkedin.voyager.dash.organization.Company"
        },
        {
            "entityUrn": "urn:li:fsd_company:18128605",
            "$recipeTypes": [
                "com.linkedin.2c2374bef3eaba3e079b4a11e2f7bea8"
            ],
            "$type": "com.linkedin.voyager.dash.organization.Company"
        },
        {
            "entityUrn": "urn:li:fsd_premiumUpsellSlot:ADVANCED_COMPANY_SEARCH_FILTER_INLINE_RESULT",
            "$recipeTypes": [
                "com.linkedin.0b2f76bd70fd4528e6bb2b0121d2241f"
            ],
            "upsellCard": null,
            "$type": "com.linkedin.voyager.dash.premium.PremiumUpsellSlotContent"
        },
        {
            "template": "UNIVERSAL",
            "actorNavigationContext": null,
            "bserpEntityNavigationalUrl": "https://www.linkedin.com/search/results/all/?keywords=Medical%20%2B%20Optical%20Instruments%20Australia&origin=ENTITY_SEARCH_HOME_HISTORY&heroEntityKey=urn%3Ali%3Aorganization%3A71605911",
            "trackingUrn": "urn:li:company:71605911",
            "controlName": null,
            "interstitialComponent": null,
            "primaryActions": [],
            "entityCustomTrackingInfo": null,
            "badgeData": null,
            "title": {
                "textDirection": "USER_LOCALE",
                "text": "Medical + Optical Instruments Australia",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "overflowActions": [],
            "*lazyLoadedActions": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:71605911,COMPANIES,SEARCH_SRP)",
            "searchActionType": null,
            "actorInsights": [],
            "insightsResolutionResults": [],
            "badgeIcon": null,
            "entityUrn": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:71605911,SEARCH_SRP,DEFAULT)",
            "showAdditionalCluster": false,
            "ringStatus": null,
            "primarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "Medical Equipment Manufacturing • Artarmon, New South Wales",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "badgeText": null,
            "trackingId": "UdMfecdURn2ivwlF1R+cwQ==",
            "summary": {
                "textDirection": "USER_LOCALE",
                "text": "Medical + Optical is a quality specialist provider to the health care market supporting the Australian medical industry nation-wide. We are committed to exceeding expectations of our customers by providing high quality products and exceptional service. We specialise in orthopaedics, medical imaging, surgical...",
                "attributesV2": [
                    {
                        "start": 0,
                        "length": 7,
                        "detailData": {
                            "jobPostingName": null,
                            "hyperlink": null,
                            "profileFamiliarName": null,
                            "color": null,
                            "companyName": null,
                            "icon": null,
                            "epoch": null,
                            "systemImage": null,
                            "textLink": null,
                            "listItemStyle": null,
                            "groupName": null,
                            "hyperlinkOpenExternally": null,
                            "listStyle": null,
                            "profileFullName": null,
                            "stringFieldReference": null,
                            "learningCourseName": null,
                            "profileMention": null,
                            "style": "BOLD",
                            "schoolName": null,
                            "hashtag": null
                        },
                        "$recipeTypes": [
                            "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                        ],
                        "$type": "com.linkedin.voyager.dash.common.text.TextAttribute"
                    },
                    {
                        "start": 103,
                        "length": 7,
                        "detailData": {
                            "jobPostingName": null,
                            "hyperlink": null,
                            "profileFamiliarName": null,
                            "color": null,
                            "companyName": null,
                            "icon": null,
                            "epoch": null,
                            "systemImage": null,
                            "textLink": null,
                            "listItemStyle": null,
                            "groupName": null,
                            "hyperlinkOpenExternally": null,
                            "listStyle": null,
                            "profileFullName": null,
                            "stringFieldReference": null,
                            "learningCourseName": null,
                            "profileMention": null,
                            "style": "BOLD",
                            "schoolName": null,
                            "hashtag": null
                        },
                        "$recipeTypes": [
                            "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                        ],
                        "$type": "com.linkedin.voyager.dash.common.text.TextAttribute"
                    },
                    {
                        "start": 284,
                        "length": 7,
                        "detailData": {
                            "jobPostingName": null,
                            "hyperlink": null,
                            "profileFamiliarName": null,
                            "color": null,
                            "companyName": null,
                            "icon": null,
                            "epoch": null,
                            "systemImage": null,
                            "textLink": null,
                            "listItemStyle": null,
                            "groupName": null,
                            "hyperlinkOpenExternally": null,
                            "listStyle": null,
                            "profileFullName": null,
                            "stringFieldReference": null,
                            "learningCourseName": null,
                            "profileMention": null,
                            "style": "BOLD",
                            "schoolName": null,
                            "hashtag": null
                        },
                        "$recipeTypes": [
                            "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                        ],
                        "$type": "com.linkedin.voyager.dash.common.text.TextAttribute"
                    }
                ],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "addEntityToSearchHistory": true,
            "actorNavigationUrl": null,
            "image": {
                "attributes": [
                    {
                        "scalingType": null,
                        "detailData": {
                            "profilePictureWithoutFrame": null,
                            "profilePictureWithRingStatus": null,
                            "companyLogo": null,
                            "icon": null,
                            "systemImage": null,
                            "nonEntityGroupLogo": null,
                            "vectorImage": null,
                            "nonEntityProfessionalEventLogo": null,
                            "profilePicture": null,
                            "imageUrl": null,
                            "professionalEventLogo": null,
                            "nonEntityCompanyLogo": {
                                "*company": "urn:li:fsd_company:71605911",
                                "$recipeTypes": [
                                    "com.linkedin.3be27b5a0eb7edd91e98b14c0290096c"
                                ],
                                "vectorImage": {
                                    "digitalmediaAsset": null,
                                    "attribution": null,
                                    "c2paManifestData": null,
                                    "$recipeTypes": [
                                        "com.linkedin.28db8575bcf1c65bdc4bc15948d50ee9"
                                    ],
                                    "artifacts": [
                                        {
                                            "width": 100,
                                            "$recipeTypes": [
                                                "com.linkedin.f0f435b4425ee2990eba8f0a4d614944"
                                            ],
                                            "fileIdentifyingUrlPathSegment": "https://media.licdn.com/dms/image/v2/C560BAQG4VOHKkY8jXw/company-logo_100_100/company-logo_100_100/0/1630663251787?e=1769644800&v=beta&t=Byglx14nSDAT18Cek_ymrk1rd2BqJleaTZpvaUNZz_E",
                                            "expiresAt": 1769644800000,
                                            "height": 100,
                                            "$type": "com.linkedin.common.VectorArtifact"
                                        }
                                    ],
                                    "rootUrl": "",
                                    "$type": "com.linkedin.common.VectorImage"
                                },
                                "$type": "com.linkedin.voyager.dash.common.image.NonEntityCompanyLogo"
                            },
                            "nonEntitySchoolLogo": null,
                            "groupLogo": null,
                            "schoolLogo": null,
                            "ghostImage": null,
                            "nonEntityProfilePicture": null
                        },
                        "tintColor": null,
                        "$recipeTypes": [
                            "com.linkedin.eb94fbb1518f790c4545aafdf571c64e"
                        ],
                        "tapTargets": [],
                        "displayAspectRatio": null,
                        "$type": "com.linkedin.voyager.dash.common.image.ImageAttribute"
                    }
                ],
                "editableAccessibilityText": false,
                "actionTarget": null,
                "accessibilityTextAttributes": [],
                "totalCount": null,
                "accessibilityText": "Medical + Optical Instruments Australia",
                "$recipeTypes": [
                    "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                ],
                "$type": "com.linkedin.voyager.dash.common.image.ImageViewModel"
            },
            "secondarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "1K followers",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "navigationUrl": "https://www.linkedin.com/company/medical-optical/",
            "entityEmbeddedObject": null,
            "unreadIndicatorDetails": null,
            "$recipeTypes": [
                "com.linkedin.cf4b25c18907ea8eafe915c8bfa24109"
            ],
            "target": null,
            "$type": "com.linkedin.voyager.dash.search.EntityResultViewModel",
            "actorTrackingUrn": null,
            "navigationContext": {
                "openExternally": false,
                "$recipeTypes": [
                    "com.linkedin.55ee9afd4182671fe7e271f615659525"
                ],
                "url": "https://www.linkedin.com/company/medical-optical/",
                "$type": "com.linkedin.voyager.dash.search.NavigationContext"
            }
        },
        {
            "template": "UNIVERSAL",
            "actorNavigationContext": null,
            "bserpEntityNavigationalUrl": "https://www.linkedin.com/search/results/all/?keywords=Medical%20One&origin=ENTITY_SEARCH_HOME_HISTORY&heroEntityKey=urn%3Ali%3Aorganization%3A3541653",
            "trackingUrn": "urn:li:company:3541653",
            "controlName": null,
            "interstitialComponent": null,
            "primaryActions": [],
            "entityCustomTrackingInfo": null,
            "badgeData": null,
            "title": {
                "textDirection": "USER_LOCALE",
                "text": "Medical One",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "overflowActions": [],
            "*lazyLoadedActions": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:3541653,COMPANIES,SEARCH_SRP)",
            "searchActionType": null,
            "actorInsights": [],
            "insightsResolutionResults": [
                {
                    "jobPostingInsight": null,
                    "relationshipsInsight": null,
                    "serviceProviderRatingInsight": null,
                    "simpleInsight": null,
                    "jobPostingFooterInsight": null,
                    "socialActivityCountsInsight": null,
                    "premiumCustomCtaInsight": {
                        "searchActionType": "PREMIUM_VISIT_WEBSITE",
                        "titleFontSize": "SMALL",
                        "navigationContext": {
                            "openExternally": false,
                            "$recipeTypes": [
                                "com.linkedin.55ee9afd4182671fe7e271f615659525"
                            ],
                            "url": "https://www.medicalone.com.au/",
                            "$type": "com.linkedin.voyager.dash.search.NavigationContext"
                        },
                        "title": {
                            "textDirection": "USER_LOCALE",
                            "text": "Visit website",
                            "attributesV2": [
                                {
                                    "start": 0,
                                    "length": 13,
                                    "detailData": {
                                        "jobPostingName": null,
                                        "hyperlink": null,
                                        "profileFamiliarName": null,
                                        "color": null,
                                        "companyName": null,
                                        "icon": null,
                                        "epoch": null,
                                        "systemImage": null,
                                        "textLink": null,
                                        "listItemStyle": null,
                                        "groupName": null,
                                        "hyperlinkOpenExternally": null,
                                        "listStyle": null,
                                        "profileFullName": null,
                                        "stringFieldReference": null,
                                        "learningCourseName": null,
                                        "profileMention": null,
                                        "style": "BOLD",
                                        "schoolName": null,
                                        "hashtag": null
                                    },
                                    "$recipeTypes": [
                                        "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                                    ],
                                    "$type": "com.linkedin.voyager.dash.common.text.TextAttribute"
                                }
                            ],
                            "accessibilityTextAttributesV2": [],
                            "accessibilityText": "Visit website",
                            "$recipeTypes": [
                                "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                            ],
                            "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
                        },
                        "$recipeTypes": [
                            "com.linkedin.e7255825e31731ce221bd0a581bbdd47"
                        ],
                        "titleMaxNumLines": 1,
                        "$type": "com.linkedin.voyager.dash.search.premium.PremiumCustomCtaInsight"
                    },
                    "labelsInsight": null
                }
            ],
            "badgeIcon": {
                "attributes": [
                    {
                        "scalingType": null,
                        "detailData": {
                            "profilePictureWithoutFrame": null,
                            "profilePictureWithRingStatus": null,
                            "companyLogo": null,
                            "icon": "IC_LINKEDIN_PREMIUM_GOLD_ICON_16DP",
                            "systemImage": null,
                            "nonEntityGroupLogo": null,
                            "vectorImage": null,
                            "nonEntityProfessionalEventLogo": null,
                            "profilePicture": null,
                            "imageUrl": null,
                            "professionalEventLogo": null,
                            "nonEntityCompanyLogo": null,
                            "nonEntitySchoolLogo": null,
                            "groupLogo": null,
                            "schoolLogo": null,
                            "ghostImage": null,
                            "nonEntityProfilePicture": null
                        },
                        "tintColor": null,
                        "$recipeTypes": [
                            "com.linkedin.eb94fbb1518f790c4545aafdf571c64e"
                        ],
                        "tapTargets": [],
                        "displayAspectRatio": null,
                        "$type": "com.linkedin.voyager.dash.common.image.ImageAttribute"
                    }
                ],
                "editableAccessibilityText": false,
                "actionTarget": null,
                "accessibilityTextAttributes": [],
                "totalCount": null,
                "accessibilityText": "Premium page",
                "$recipeTypes": [
                    "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                ],
                "$type": "com.linkedin.voyager.dash.common.image.ImageViewModel"
            },
            "entityUrn": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:3541653,SEARCH_SRP,DEFAULT)",
            "showAdditionalCluster": false,
            "ringStatus": null,
            "primarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "Medical Practices • South Melbourne, VIC",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "badgeText": null,
            "trackingId": "F6viTQHUQmeNDSx2hI7fEQ==",
            "summary": {
                "textDirection": "USER_LOCALE",
                "text": "At Medical One, we believe in providing exceptional healthcare by embracing our mantra, \"Care for every step of your journey\".   We are dedicated to fostering an environment of care, commitment, and communication, ensuring that both patients, consulting GPs and support teams feel supported and valued.  For GP...",
                "attributesV2": [
                    {
                        "start": 3,
                        "length": 7,
                        "detailData": {
                            "jobPostingName": null,
                            "hyperlink": null,
                            "profileFamiliarName": null,
                            "color": null,
                            "companyName": null,
                            "icon": null,
                            "epoch": null,
                            "systemImage": null,
                            "textLink": null,
                            "listItemStyle": null,
                            "groupName": null,
                            "hyperlinkOpenExternally": null,
                            "listStyle": null,
                            "profileFullName": null,
                            "stringFieldReference": null,
                            "learningCourseName": null,
                            "profileMention": null,
                            "style": "BOLD",
                            "schoolName": null,
                            "hashtag": null
                        },
                        "$recipeTypes": [
                            "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                        ],
                        "$type": "com.linkedin.voyager.dash.common.text.TextAttribute"
                    }
                ],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "addEntityToSearchHistory": true,
            "actorNavigationUrl": null,
            "image": {
                "attributes": [
                    {
                        "scalingType": null,
                        "detailData": {
                            "profilePictureWithoutFrame": null,
                            "profilePictureWithRingStatus": null,
                            "companyLogo": null,
                            "icon": null,
                            "systemImage": null,
                            "nonEntityGroupLogo": null,
                            "vectorImage": null,
                            "nonEntityProfessionalEventLogo": null,
                            "profilePicture": null,
                            "imageUrl": null,
                            "professionalEventLogo": null,
                            "nonEntityCompanyLogo": {
                                "*company": "urn:li:fsd_company:3541653",
                                "$recipeTypes": [
                                    "com.linkedin.3be27b5a0eb7edd91e98b14c0290096c"
                                ],
                                "vectorImage": {
                                    "digitalmediaAsset": null,
                                    "attribution": null,
                                    "c2paManifestData": null,
                                    "$recipeTypes": [
                                        "com.linkedin.28db8575bcf1c65bdc4bc15948d50ee9"
                                    ],
                                    "artifacts": [
                                        {
                                            "width": 100,
                                            "$recipeTypes": [
                                                "com.linkedin.f0f435b4425ee2990eba8f0a4d614944"
                                            ],
                                            "fileIdentifyingUrlPathSegment": "https://media.licdn.com/dms/image/v2/C560BAQGZ3dDAG9dqtA/company-logo_100_100/company-logo_100_100/0/1630615202517/medicalone_logo?e=1769644800&v=beta&t=jQYsxXFOVuF0O5wJJZm5z-37L7wpG8xR-j5XnrEwij8",
                                            "expiresAt": 1769644800000,
                                            "height": 100,
                                            "$type": "com.linkedin.common.VectorArtifact"
                                        }
                                    ],
                                    "rootUrl": "",
                                    "$type": "com.linkedin.common.VectorImage"
                                },
                                "$type": "com.linkedin.voyager.dash.common.image.NonEntityCompanyLogo"
                            },
                            "nonEntitySchoolLogo": null,
                            "groupLogo": null,
                            "schoolLogo": null,
                            "ghostImage": null,
                            "nonEntityProfilePicture": null
                        },
                        "tintColor": null,
                        "$recipeTypes": [
                            "com.linkedin.eb94fbb1518f790c4545aafdf571c64e"
                        ],
                        "tapTargets": [],
                        "displayAspectRatio": null,
                        "$type": "com.linkedin.voyager.dash.common.image.ImageAttribute"
                    }
                ],
                "editableAccessibilityText": false,
                "actionTarget": null,
                "accessibilityTextAttributes": [],
                "totalCount": null,
                "accessibilityText": "Medical One",
                "$recipeTypes": [
                    "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                ],
                "$type": "com.linkedin.voyager.dash.common.image.ImageViewModel"
            },
            "secondarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "4K followers",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "navigationUrl": "https://www.linkedin.com/company/medicalonegp/",
            "entityEmbeddedObject": null,
            "unreadIndicatorDetails": null,
            "$recipeTypes": [
                "com.linkedin.cf4b25c18907ea8eafe915c8bfa24109"
            ],
            "target": null,
            "$type": "com.linkedin.voyager.dash.search.EntityResultViewModel",
            "actorTrackingUrn": null,
            "navigationContext": {
                "openExternally": false,
                "$recipeTypes": [
                    "com.linkedin.55ee9afd4182671fe7e271f615659525"
                ],
                "url": "https://www.linkedin.com/company/medicalonegp/",
                "$type": "com.linkedin.voyager.dash.search.NavigationContext"
            }
        },
        {
            "template": "UNIVERSAL",
            "actorNavigationContext": null,
            "bserpEntityNavigationalUrl": "https://www.linkedin.com/search/results/all/?keywords=Medical%20Devices%20Pty%20Ltd&origin=ENTITY_SEARCH_HOME_HISTORY&heroEntityKey=urn%3Ali%3Aorganization%3A74122547",
            "trackingUrn": "urn:li:company:74122547",
            "controlName": null,
            "interstitialComponent": null,
            "primaryActions": [],
            "entityCustomTrackingInfo": null,
            "badgeData": null,
            "title": {
                "textDirection": "USER_LOCALE",
                "text": "Medical Devices Pty Ltd",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "overflowActions": [],
            "*lazyLoadedActions": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:74122547,COMPANIES,SEARCH_SRP)",
            "searchActionType": null,
            "actorInsights": [],
            "insightsResolutionResults": [],
            "badgeIcon": null,
            "entityUrn": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:74122547,SEARCH_SRP,DEFAULT)",
            "showAdditionalCluster": false,
            "ringStatus": null,
            "primarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "Medical Equipment Manufacturing • Breakfast Point, New South Wales",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "badgeText": null,
            "trackingId": "6t6PCXFlRJygY+jpnBxKjg==",
            "summary": {
                "textDirection": "USER_LOCALE",
                "text": "Australian company committed to the supply and support of high quality surgical and medical equipment to Hospitals.",
                "attributesV2": [
                    {
                        "start": 84,
                        "length": 7,
                        "detailData": {
                            "jobPostingName": null,
                            "hyperlink": null,
                            "profileFamiliarName": null,
                            "color": null,
                            "companyName": null,
                            "icon": null,
                            "epoch": null,
                            "systemImage": null,
                            "textLink": null,
                            "listItemStyle": null,
                            "groupName": null,
                            "hyperlinkOpenExternally": null,
                            "listStyle": null,
                            "profileFullName": null,
                            "stringFieldReference": null,
                            "learningCourseName": null,
                            "profileMention": null,
                            "style": "BOLD",
                            "schoolName": null,
                            "hashtag": null
                        },
                        "$recipeTypes": [
                            "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                        ],
                        "$type": "com.linkedin.voyager.dash.common.text.TextAttribute"
                    }
                ],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "addEntityToSearchHistory": true,
            "actorNavigationUrl": null,
            "image": {
                "attributes": [
                    {
                        "scalingType": null,
                        "detailData": {
                            "profilePictureWithoutFrame": null,
                            "profilePictureWithRingStatus": null,
                            "companyLogo": null,
                            "icon": null,
                            "systemImage": null,
                            "nonEntityGroupLogo": null,
                            "vectorImage": null,
                            "nonEntityProfessionalEventLogo": null,
                            "profilePicture": null,
                            "imageUrl": null,
                            "professionalEventLogo": null,
                            "nonEntityCompanyLogo": {
                                "*company": "urn:li:fsd_company:74122547",
                                "$recipeTypes": [
                                    "com.linkedin.3be27b5a0eb7edd91e98b14c0290096c"
                                ],
                                "vectorImage": {
                                    "digitalmediaAsset": null,
                                    "attribution": null,
                                    "c2paManifestData": null,
                                    "$recipeTypes": [
                                        "com.linkedin.28db8575bcf1c65bdc4bc15948d50ee9"
                                    ],
                                    "artifacts": [
                                        {
                                            "width": 100,
                                            "$recipeTypes": [
                                                "com.linkedin.f0f435b4425ee2990eba8f0a4d614944"
                                            ],
                                            "fileIdentifyingUrlPathSegment": "https://media.licdn.com/dms/image/v2/C560BAQHG0sJVBfpXKQ/company-logo_100_100/company-logo_100_100/0/1630637975529?e=1769644800&v=beta&t=7ny5aey5ZJD8pkVR0fxcMN00Kd5GE74EDdxleNUR3zQ",
                                            "expiresAt": 1769644800000,
                                            "height": 100,
                                            "$type": "com.linkedin.common.VectorArtifact"
                                        }
                                    ],
                                    "rootUrl": "",
                                    "$type": "com.linkedin.common.VectorImage"
                                },
                                "$type": "com.linkedin.voyager.dash.common.image.NonEntityCompanyLogo"
                            },
                            "nonEntitySchoolLogo": null,
                            "groupLogo": null,
                            "schoolLogo": null,
                            "ghostImage": null,
                            "nonEntityProfilePicture": null
                        },
                        "tintColor": null,
                        "$recipeTypes": [
                            "com.linkedin.eb94fbb1518f790c4545aafdf571c64e"
                        ],
                        "tapTargets": [],
                        "displayAspectRatio": null,
                        "$type": "com.linkedin.voyager.dash.common.image.ImageAttribute"
                    }
                ],
                "editableAccessibilityText": false,
                "actionTarget": null,
                "accessibilityTextAttributes": [],
                "totalCount": null,
                "accessibilityText": "Medical Devices Pty Ltd",
                "$recipeTypes": [
                    "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                ],
                "$type": "com.linkedin.voyager.dash.common.image.ImageViewModel"
            },
            "secondarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "2K followers",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "navigationUrl": "https://www.linkedin.com/company/medical-devices-pty-ltd/",
            "entityEmbeddedObject": null,
            "unreadIndicatorDetails": null,
            "$recipeTypes": [
                "com.linkedin.cf4b25c18907ea8eafe915c8bfa24109"
            ],
            "target": null,
            "$type": "com.linkedin.voyager.dash.search.EntityResultViewModel",
            "actorTrackingUrn": null,
            "navigationContext": {
                "openExternally": false,
                "$recipeTypes": [
                    "com.linkedin.55ee9afd4182671fe7e271f615659525"
                ],
                "url": "https://www.linkedin.com/company/medical-devices-pty-ltd/",
                "$type": "com.linkedin.voyager.dash.search.NavigationContext"
            }
        },
        {
            "template": "UNIVERSAL",
            "actorNavigationContext": null,
            "bserpEntityNavigationalUrl": "https://www.linkedin.com/search/results/all/?keywords=Medical%20Technology%20Association%20of%20Australia%20%28MTAA%29&origin=ENTITY_SEARCH_HOME_HISTORY&heroEntityKey=urn%3Ali%3Aorganization%3A2441750",
            "trackingUrn": "urn:li:company:2441750",
            "controlName": null,
            "interstitialComponent": null,
            "primaryActions": [],
            "entityCustomTrackingInfo": null,
            "badgeData": null,
            "title": {
                "textDirection": "USER_LOCALE",
                "text": "Medical Technology Association of Australia (MTAA)",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "overflowActions": [],
            "*lazyLoadedActions": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:2441750,COMPANIES,SEARCH_SRP)",
            "searchActionType": null,
            "actorInsights": [],
            "insightsResolutionResults": [],
            "badgeIcon": null,
            "entityUrn": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:2441750,SEARCH_SRP,DEFAULT)",
            "showAdditionalCluster": false,
            "ringStatus": null,
            "primarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "Medical Equipment Manufacturing • Sydney, New South Wales",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "badgeText": null,
            "trackingId": "ncTi9TinSJqIas8yjh2Vjw==",
            "summary": {
                "textDirection": "USER_LOCALE",
                "text": "Medical Technology Association of Australia (MTAA) is the national association representing MedTech companies.",
                "attributesV2": [
                    {
                        "start": 0,
                        "length": 7,
                        "detailData": {
                            "jobPostingName": null,
                            "hyperlink": null,
                            "profileFamiliarName": null,
                            "color": null,
                            "companyName": null,
                            "icon": null,
                            "epoch": null,
                            "systemImage": null,
                            "textLink": null,
                            "listItemStyle": null,
                            "groupName": null,
                            "hyperlinkOpenExternally": null,
                            "listStyle": null,
                            "profileFullName": null,
                            "stringFieldReference": null,
                            "learningCourseName": null,
                            "profileMention": null,
                            "style": "BOLD",
                            "schoolName": null,
                            "hashtag": null
                        },
                        "$recipeTypes": [
                            "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                        ],
                        "$type": "com.linkedin.voyager.dash.common.text.TextAttribute"
                    }
                ],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "addEntityToSearchHistory": true,
            "actorNavigationUrl": null,
            "image": {
                "attributes": [
                    {
                        "scalingType": null,
                        "detailData": {
                            "profilePictureWithoutFrame": null,
                            "profilePictureWithRingStatus": null,
                            "companyLogo": null,
                            "icon": null,
                            "systemImage": null,
                            "nonEntityGroupLogo": null,
                            "vectorImage": null,
                            "nonEntityProfessionalEventLogo": null,
                            "profilePicture": null,
                            "imageUrl": null,
                            "professionalEventLogo": null,
                            "nonEntityCompanyLogo": {
                                "*company": "urn:li:fsd_company:2441750",
                                "$recipeTypes": [
                                    "com.linkedin.3be27b5a0eb7edd91e98b14c0290096c"
                                ],
                                "vectorImage": {
                                    "digitalmediaAsset": null,
                                    "attribution": null,
                                    "c2paManifestData": null,
                                    "$recipeTypes": [
                                        "com.linkedin.28db8575bcf1c65bdc4bc15948d50ee9"
                                    ],
                                    "artifacts": [
                                        {
                                            "width": 100,
                                            "$recipeTypes": [
                                                "com.linkedin.f0f435b4425ee2990eba8f0a4d614944"
                                            ],
                                            "fileIdentifyingUrlPathSegment": "https://media.licdn.com/dms/image/v2/C560BAQE_RUUfmv9Mhw/company-logo_100_100/company-logo_100_100/0/1631255268544/medtechaus_logo?e=1769644800&v=beta&t=ouSJRF22d4UhomFu4vfAircTffwvapqoGIbsN_UMxtE",
                                            "expiresAt": 1769644800000,
                                            "height": 100,
                                            "$type": "com.linkedin.common.VectorArtifact"
                                        }
                                    ],
                                    "rootUrl": "",
                                    "$type": "com.linkedin.common.VectorImage"
                                },
                                "$type": "com.linkedin.voyager.dash.common.image.NonEntityCompanyLogo"
                            },
                            "nonEntitySchoolLogo": null,
                            "groupLogo": null,
                            "schoolLogo": null,
                            "ghostImage": null,
                            "nonEntityProfilePicture": null
                        },
                        "tintColor": null,
                        "$recipeTypes": [
                            "com.linkedin.eb94fbb1518f790c4545aafdf571c64e"
                        ],
                        "tapTargets": [],
                        "displayAspectRatio": null,
                        "$type": "com.linkedin.voyager.dash.common.image.ImageAttribute"
                    }
                ],
                "editableAccessibilityText": false,
                "actionTarget": null,
                "accessibilityTextAttributes": [],
                "totalCount": null,
                "accessibilityText": "Medical Technology Association of Australia (MTAA)",
                "$recipeTypes": [
                    "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                ],
                "$type": "com.linkedin.voyager.dash.common.image.ImageViewModel"
            },
            "secondarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "17K followers",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "navigationUrl": "https://www.linkedin.com/company/medtechaus/",
            "entityEmbeddedObject": null,
            "unreadIndicatorDetails": null,
            "$recipeTypes": [
                "com.linkedin.cf4b25c18907ea8eafe915c8bfa24109"
            ],
            "target": null,
            "$type": "com.linkedin.voyager.dash.search.EntityResultViewModel",
            "actorTrackingUrn": null,
            "navigationContext": {
                "openExternally": false,
                "$recipeTypes": [
                    "com.linkedin.55ee9afd4182671fe7e271f615659525"
                ],
                "url": "https://www.linkedin.com/company/medtechaus/",
                "$type": "com.linkedin.voyager.dash.search.NavigationContext"
            }
        },
        {
            "template": "UNIVERSAL",
            "actorNavigationContext": null,
            "bserpEntityNavigationalUrl": "https://www.linkedin.com/search/results/all/?keywords=Medical%20Supplierz&origin=ENTITY_SEARCH_HOME_HISTORY&heroEntityKey=urn%3Ali%3Aorganization%3A97427935",
            "trackingUrn": "urn:li:company:97427935",
            "controlName": null,
            "interstitialComponent": null,
            "primaryActions": [],
            "entityCustomTrackingInfo": null,
            "badgeData": null,
            "title": {
                "textDirection": "USER_LOCALE",
                "text": "Medical Supplierz",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "overflowActions": [],
            "*lazyLoadedActions": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:97427935,COMPANIES,SEARCH_SRP)",
            "searchActionType": null,
            "actorInsights": [],
            "insightsResolutionResults": [],
            "badgeIcon": null,
            "entityUrn": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:97427935,SEARCH_SRP,DEFAULT)",
            "showAdditionalCluster": false,
            "ringStatus": null,
            "primarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "Medical Equipment Manufacturing • Kuwait City",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "badgeText": null,
            "trackingId": "qL9CM8GVQDW9XfTCWj5Vqw==",
            "summary": {
                "textDirection": "USER_LOCALE",
                "text": "Your trusted source for all things medical supplies!",
                "attributesV2": [
                    {
                        "start": 35,
                        "length": 7,
                        "detailData": {
                            "jobPostingName": null,
                            "hyperlink": null,
                            "profileFamiliarName": null,
                            "color": null,
                            "companyName": null,
                            "icon": null,
                            "epoch": null,
                            "systemImage": null,
                            "textLink": null,
                            "listItemStyle": null,
                            "groupName": null,
                            "hyperlinkOpenExternally": null,
                            "listStyle": null,
                            "profileFullName": null,
                            "stringFieldReference": null,
                            "learningCourseName": null,
                            "profileMention": null,
                            "style": "BOLD",
                            "schoolName": null,
                            "hashtag": null
                        },
                        "$recipeTypes": [
                            "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                        ],
                        "$type": "com.linkedin.voyager.dash.common.text.TextAttribute"
                    }
                ],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "addEntityToSearchHistory": true,
            "actorNavigationUrl": null,
            "image": {
                "attributes": [
                    {
                        "scalingType": null,
                        "detailData": {
                            "profilePictureWithoutFrame": null,
                            "profilePictureWithRingStatus": null,
                            "companyLogo": null,
                            "icon": null,
                            "systemImage": null,
                            "nonEntityGroupLogo": null,
                            "vectorImage": null,
                            "nonEntityProfessionalEventLogo": null,
                            "profilePicture": null,
                            "imageUrl": null,
                            "professionalEventLogo": null,
                            "nonEntityCompanyLogo": {
                                "*company": "urn:li:fsd_company:97427935",
                                "$recipeTypes": [
                                    "com.linkedin.3be27b5a0eb7edd91e98b14c0290096c"
                                ],
                                "vectorImage": {
                                    "digitalmediaAsset": null,
                                    "attribution": null,
                                    "c2paManifestData": null,
                                    "$recipeTypes": [
                                        "com.linkedin.28db8575bcf1c65bdc4bc15948d50ee9"
                                    ],
                                    "artifacts": [
                                        {
                                            "width": 100,
                                            "$recipeTypes": [
                                                "com.linkedin.f0f435b4425ee2990eba8f0a4d614944"
                                            ],
                                            "fileIdentifyingUrlPathSegment": "https://media.licdn.com/dms/image/v2/D560BAQEhiRNln5MUuw/company-logo_100_100/company-logo_100_100/0/1709624295208/medicalsupplierz_logo?e=1769644800&v=beta&t=4xualhFL4KT20z_FPny9yyVxaShopaisr2w6XZVrg9U",
                                            "expiresAt": 1769644800000,
                                            "height": 100,
                                            "$type": "com.linkedin.common.VectorArtifact"
                                        }
                                    ],
                                    "rootUrl": "",
                                    "$type": "com.linkedin.common.VectorImage"
                                },
                                "$type": "com.linkedin.voyager.dash.common.image.NonEntityCompanyLogo"
                            },
                            "nonEntitySchoolLogo": null,
                            "groupLogo": null,
                            "schoolLogo": null,
                            "ghostImage": null,
                            "nonEntityProfilePicture": null
                        },
                        "tintColor": null,
                        "$recipeTypes": [
                            "com.linkedin.eb94fbb1518f790c4545aafdf571c64e"
                        ],
                        "tapTargets": [],
                        "displayAspectRatio": null,
                        "$type": "com.linkedin.voyager.dash.common.image.ImageAttribute"
                    }
                ],
                "editableAccessibilityText": false,
                "actionTarget": null,
                "accessibilityTextAttributes": [],
                "totalCount": null,
                "accessibilityText": "Medical Supplierz",
                "$recipeTypes": [
                    "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                ],
                "$type": "com.linkedin.voyager.dash.common.image.ImageViewModel"
            },
            "secondarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "323 followers",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "navigationUrl": "https://www.linkedin.com/company/medicalsupplierz/",
            "entityEmbeddedObject": null,
            "unreadIndicatorDetails": null,
            "$recipeTypes": [
                "com.linkedin.cf4b25c18907ea8eafe915c8bfa24109"
            ],
            "target": null,
            "$type": "com.linkedin.voyager.dash.search.EntityResultViewModel",
            "actorTrackingUrn": null,
            "navigationContext": {
                "openExternally": false,
                "$recipeTypes": [
                    "com.linkedin.55ee9afd4182671fe7e271f615659525"
                ],
                "url": "https://www.linkedin.com/company/medicalsupplierz/",
                "$type": "com.linkedin.voyager.dash.search.NavigationContext"
            }
        },
        {
            "template": "UNIVERSAL",
            "actorNavigationContext": null,
            "bserpEntityNavigationalUrl": "https://www.linkedin.com/search/results/all/?keywords=Medical%20Device%20Partnering%20Program&origin=ENTITY_SEARCH_HOME_HISTORY&heroEntityKey=urn%3Ali%3Aorganization%3A13644897",
            "trackingUrn": "urn:li:company:13644897",
            "controlName": null,
            "interstitialComponent": null,
            "primaryActions": [],
            "entityCustomTrackingInfo": null,
            "badgeData": null,
            "title": {
                "textDirection": "USER_LOCALE",
                "text": "Medical Device Partnering Program",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "overflowActions": [],
            "*lazyLoadedActions": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:13644897,COMPANIES,SEARCH_SRP)",
            "searchActionType": null,
            "actorInsights": [],
            "insightsResolutionResults": [],
            "badgeIcon": null,
            "entityUrn": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:13644897,SEARCH_SRP,DEFAULT)",
            "showAdditionalCluster": false,
            "ringStatus": null,
            "primarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "Medical Equipment Manufacturing • Tonsley, South Australia",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "badgeText": null,
            "trackingId": "1ceCSFI+R/W5/tp97E3QvA==",
            "summary": {
                "textDirection": "USER_LOCALE",
                "text": "An initiative of Flinders University, MDPP is an Ideas Incubator for medical devices & assistive technologies",
                "attributesV2": [
                    {
                        "start": 69,
                        "length": 7,
                        "detailData": {
                            "jobPostingName": null,
                            "hyperlink": null,
                            "profileFamiliarName": null,
                            "color": null,
                            "companyName": null,
                            "icon": null,
                            "epoch": null,
                            "systemImage": null,
                            "textLink": null,
                            "listItemStyle": null,
                            "groupName": null,
                            "hyperlinkOpenExternally": null,
                            "listStyle": null,
                            "profileFullName": null,
                            "stringFieldReference": null,
                            "learningCourseName": null,
                            "profileMention": null,
                            "style": "BOLD",
                            "schoolName": null,
                            "hashtag": null
                        },
                        "$recipeTypes": [
                            "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                        ],
                        "$type": "com.linkedin.voyager.dash.common.text.TextAttribute"
                    }
                ],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "addEntityToSearchHistory": true,
            "actorNavigationUrl": null,
            "image": {
                "attributes": [
                    {
                        "scalingType": null,
                        "detailData": {
                            "profilePictureWithoutFrame": null,
                            "profilePictureWithRingStatus": null,
                            "companyLogo": null,
                            "icon": null,
                            "systemImage": null,
                            "nonEntityGroupLogo": null,
                            "vectorImage": null,
                            "nonEntityProfessionalEventLogo": null,
                            "profilePicture": null,
                            "imageUrl": null,
                            "professionalEventLogo": null,
                            "nonEntityCompanyLogo": {
                                "*company": "urn:li:fsd_company:13644897",
                                "$recipeTypes": [
                                    "com.linkedin.3be27b5a0eb7edd91e98b14c0290096c"
                                ],
                                "vectorImage": {
                                    "digitalmediaAsset": null,
                                    "attribution": null,
                                    "c2paManifestData": null,
                                    "$recipeTypes": [
                                        "com.linkedin.28db8575bcf1c65bdc4bc15948d50ee9"
                                    ],
                                    "artifacts": [
                                        {
                                            "width": 100,
                                            "$recipeTypes": [
                                                "com.linkedin.f0f435b4425ee2990eba8f0a4d614944"
                                            ],
                                            "fileIdentifyingUrlPathSegment": "https://media.licdn.com/dms/image/v2/C560BAQG8cpEpVgEI7A/company-logo_100_100/company-logo_100_100/0/1631388056667?e=1769644800&v=beta&t=rBc2OaepUwAgmuGGXtDynE4QESqdL7DIdtuZ5hmEHBg",
                                            "expiresAt": 1769644800000,
                                            "height": 100,
                                            "$type": "com.linkedin.common.VectorArtifact"
                                        }
                                    ],
                                    "rootUrl": "",
                                    "$type": "com.linkedin.common.VectorImage"
                                },
                                "$type": "com.linkedin.voyager.dash.common.image.NonEntityCompanyLogo"
                            },
                            "nonEntitySchoolLogo": null,
                            "groupLogo": null,
                            "schoolLogo": null,
                            "ghostImage": null,
                            "nonEntityProfilePicture": null
                        },
                        "tintColor": null,
                        "$recipeTypes": [
                            "com.linkedin.eb94fbb1518f790c4545aafdf571c64e"
                        ],
                        "tapTargets": [],
                        "displayAspectRatio": null,
                        "$type": "com.linkedin.voyager.dash.common.image.ImageAttribute"
                    }
                ],
                "editableAccessibilityText": false,
                "actionTarget": null,
                "accessibilityTextAttributes": [],
                "totalCount": null,
                "accessibilityText": "Medical Device Partnering Program",
                "$recipeTypes": [
                    "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                ],
                "$type": "com.linkedin.voyager.dash.common.image.ImageViewModel"
            },
            "secondarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "3K followers",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "navigationUrl": "https://www.linkedin.com/company/mdpp/",
            "entityEmbeddedObject": null,
            "unreadIndicatorDetails": null,
            "$recipeTypes": [
                "com.linkedin.cf4b25c18907ea8eafe915c8bfa24109"
            ],
            "target": null,
            "$type": "com.linkedin.voyager.dash.search.EntityResultViewModel",
            "actorTrackingUrn": null,
            "navigationContext": {
                "openExternally": false,
                "$recipeTypes": [
                    "com.linkedin.55ee9afd4182671fe7e271f615659525"
                ],
                "url": "https://www.linkedin.com/company/mdpp/",
                "$type": "com.linkedin.voyager.dash.search.NavigationContext"
            }
        },
        {
            "template": "UNIVERSAL",
            "actorNavigationContext": null,
            "bserpEntityNavigationalUrl": "https://www.linkedin.com/search/results/all/?keywords=Medical%20Device%20Components%20LLC&origin=ENTITY_SEARCH_HOME_HISTORY&heroEntityKey=urn%3Ali%3Aorganization%3A82778753",
            "trackingUrn": "urn:li:company:82778753",
            "controlName": null,
            "interstitialComponent": null,
            "primaryActions": [],
            "entityCustomTrackingInfo": null,
            "badgeData": null,
            "title": {
                "textDirection": "USER_LOCALE",
                "text": "Medical Device Components LLC",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "overflowActions": [],
            "*lazyLoadedActions": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:82778753,COMPANIES,SEARCH_SRP)",
            "searchActionType": null,
            "actorInsights": [],
            "insightsResolutionResults": [
                {
                    "jobPostingInsight": null,
                    "relationshipsInsight": null,
                    "serviceProviderRatingInsight": null,
                    "simpleInsight": {
                        "image": {
                            "attributes": [
                                {
                                    "scalingType": "ASPECT_FIT",
                                    "detailData": {
                                        "profilePictureWithoutFrame": null,
                                        "profilePictureWithRingStatus": null,
                                        "companyLogo": null,
                                        "icon": "IC_BRIEFCASE_16DP",
                                        "systemImage": null,
                                        "nonEntityGroupLogo": null,
                                        "vectorImage": null,
                                        "nonEntityProfessionalEventLogo": null,
                                        "profilePicture": null,
                                        "imageUrl": null,
                                        "professionalEventLogo": null,
                                        "nonEntityCompanyLogo": null,
                                        "nonEntitySchoolLogo": null,
                                        "groupLogo": null,
                                        "schoolLogo": null,
                                        "ghostImage": null,
                                        "nonEntityProfilePicture": null
                                    },
                                    "tintColor": null,
                                    "$recipeTypes": [
                                        "com.linkedin.eb94fbb1518f790c4545aafdf571c64e"
                                    ],
                                    "tapTargets": [],
                                    "displayAspectRatio": null,
                                    "$type": "com.linkedin.voyager.dash.common.image.ImageAttribute"
                                }
                            ],
                            "editableAccessibilityText": false,
                            "actionTarget": null,
                            "accessibilityTextAttributes": [],
                            "totalCount": null,
                            "accessibilityText": null,
                            "$recipeTypes": [
                                "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                            ],
                            "$type": "com.linkedin.voyager.dash.common.image.ImageViewModel"
                        },
                        "controlName": null,
                        "navigationUrl": "https://www.linkedin.com/jobs/search?geoId=92000000&f_C=82778753",
                        "title": {
                            "textDirection": "USER_LOCALE",
                            "text": "1 job",
                            "attributesV2": [],
                            "accessibilityTextAttributesV2": [],
                            "accessibilityText": null,
                            "$recipeTypes": [
                                "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                            ],
                            "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
                        },
                        "$recipeTypes": [
                            "com.linkedin.bd9a707a5b119c1f331373113f57344a"
                        ],
                        "$type": "com.linkedin.voyager.dash.search.SimpleInsight",
                        "searchActionType": "SEE_JOBS_AT_COMPANY",
                        "subtitleMaxNumLines": 1,
                        "titleFontSize": null,
                        "subtitle": null,
                        "subtitleFontSize": null,
                        "titleMaxNumLines": 1
                    },
                    "jobPostingFooterInsight": null,
                    "socialActivityCountsInsight": null,
                    "labelsInsight": null,
                    "premiumCustomCtaInsight": null
                }
            ],
            "badgeIcon": null,
            "entityUrn": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:82778753,SEARCH_SRP,DEFAULT)",
            "showAdditionalCluster": false,
            "ringStatus": null,
            "primarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "Medical Equipment Manufacturing • San Diego, CA",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "badgeText": null,
            "trackingId": "4OSSXexHRhWuDjUom3F/nQ==",
            "summary": {
                "textDirection": "USER_LOCALE",
                "text": "Lighteum Medical is a global leader in the development and manufacture of precision medical components, uniting the legacies of Medical Device Components LLC...",
                "attributesV2": [
                    {
                        "start": 9,
                        "length": 7,
                        "detailData": {
                            "jobPostingName": null,
                            "hyperlink": null,
                            "profileFamiliarName": null,
                            "color": null,
                            "companyName": null,
                            "icon": null,
                            "epoch": null,
                            "systemImage": null,
                            "textLink": null,
                            "listItemStyle": null,
                            "groupName": null,
                            "hyperlinkOpenExternally": null,
                            "listStyle": null,
                            "profileFullName": null,
                            "stringFieldReference": null,
                            "learningCourseName": null,
                            "profileMention": null,
                            "style": "BOLD",
                            "schoolName": null,
                            "hashtag": null
                        },
                        "$recipeTypes": [
                            "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                        ],
                        "$type": "com.linkedin.voyager.dash.common.text.TextAttribute"
                    },
                    {
                        "start": 84,
                        "length": 7,
                        "detailData": {
                            "jobPostingName": null,
                            "hyperlink": null,
                            "profileFamiliarName": null,
                            "color": null,
                            "companyName": null,
                            "icon": null,
                            "epoch": null,
                            "systemImage": null,
                            "textLink": null,
                            "listItemStyle": null,
                            "groupName": null,
                            "hyperlinkOpenExternally": null,
                            "listStyle": null,
                            "profileFullName": null,
                            "stringFieldReference": null,
                            "learningCourseName": null,
                            "profileMention": null,
                            "style": "BOLD",
                            "schoolName": null,
                            "hashtag": null
                        },
                        "$recipeTypes": [
                            "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                        ],
                        "$type": "com.linkedin.voyager.dash.common.text.TextAttribute"
                    },
                    {
                        "start": 128,
                        "length": 7,
                        "detailData": {
                            "jobPostingName": null,
                            "hyperlink": null,
                            "profileFamiliarName": null,
                            "color": null,
                            "companyName": null,
                            "icon": null,
                            "epoch": null,
                            "systemImage": null,
                            "textLink": null,
                            "listItemStyle": null,
                            "groupName": null,
                            "hyperlinkOpenExternally": null,
                            "listStyle": null,
                            "profileFullName": null,
                            "stringFieldReference": null,
                            "learningCourseName": null,
                            "profileMention": null,
                            "style": "BOLD",
                            "schoolName": null,
                            "hashtag": null
                        },
                        "$recipeTypes": [
                            "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                        ],
                        "$type": "com.linkedin.voyager.dash.common.text.TextAttribute"
                    }
                ],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "addEntityToSearchHistory": true,
            "actorNavigationUrl": null,
            "image": {
                "attributes": [
                    {
                        "scalingType": null,
                        "detailData": {
                            "profilePictureWithoutFrame": null,
                            "profilePictureWithRingStatus": null,
                            "companyLogo": null,
                            "icon": null,
                            "systemImage": null,
                            "nonEntityGroupLogo": null,
                            "vectorImage": null,
                            "nonEntityProfessionalEventLogo": null,
                            "profilePicture": null,
                            "imageUrl": null,
                            "professionalEventLogo": null,
                            "nonEntityCompanyLogo": {
                                "*company": "urn:li:fsd_company:82778753",
                                "$recipeTypes": [
                                    "com.linkedin.3be27b5a0eb7edd91e98b14c0290096c"
                                ],
                                "vectorImage": {
                                    "digitalmediaAsset": null,
                                    "attribution": null,
                                    "c2paManifestData": null,
                                    "$recipeTypes": [
                                        "com.linkedin.28db8575bcf1c65bdc4bc15948d50ee9"
                                    ],
                                    "artifacts": [
                                        {
                                            "width": 100,
                                            "$recipeTypes": [
                                                "com.linkedin.f0f435b4425ee2990eba8f0a4d614944"
                                            ],
                                            "fileIdentifyingUrlPathSegment": "https://media.licdn.com/dms/image/v2/D560BAQH-QfjssjFy8g/company-logo_100_100/B56Zrr5IGMLMAQ-/0/1764894212841/lighteummedical_logo?e=1769644800&v=beta&t=HM-Dn6jG0enShOpq2p9IO-rkZ4JNpPGzUCF77TL7fwk",
                                            "expiresAt": 1769644800000,
                                            "height": 100,
                                            "$type": "com.linkedin.common.VectorArtifact"
                                        }
                                    ],
                                    "rootUrl": "",
                                    "$type": "com.linkedin.common.VectorImage"
                                },
                                "$type": "com.linkedin.voyager.dash.common.image.NonEntityCompanyLogo"
                            },
                            "nonEntitySchoolLogo": null,
                            "groupLogo": null,
                            "schoolLogo": null,
                            "ghostImage": null,
                            "nonEntityProfilePicture": null
                        },
                        "tintColor": null,
                        "$recipeTypes": [
                            "com.linkedin.eb94fbb1518f790c4545aafdf571c64e"
                        ],
                        "tapTargets": [],
                        "displayAspectRatio": null,
                        "$type": "com.linkedin.voyager.dash.common.image.ImageAttribute"
                    }
                ],
                "editableAccessibilityText": false,
                "actionTarget": null,
                "accessibilityTextAttributes": [],
                "totalCount": null,
                "accessibilityText": "Medical Device Components LLC",
                "$recipeTypes": [
                    "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                ],
                "$type": "com.linkedin.voyager.dash.common.image.ImageViewModel"
            },
            "secondarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "3K followers",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "navigationUrl": "https://www.linkedin.com/company/mdclighteum/",
            "entityEmbeddedObject": null,
            "unreadIndicatorDetails": null,
            "$recipeTypes": [
                "com.linkedin.cf4b25c18907ea8eafe915c8bfa24109"
            ],
            "target": null,
            "$type": "com.linkedin.voyager.dash.search.EntityResultViewModel",
            "actorTrackingUrn": null,
            "navigationContext": {
                "openExternally": false,
                "$recipeTypes": [
                    "com.linkedin.55ee9afd4182671fe7e271f615659525"
                ],
                "url": "https://www.linkedin.com/company/mdclighteum/",
                "$type": "com.linkedin.voyager.dash.search.NavigationContext"
            }
        },
        {
            "template": "UNIVERSAL",
            "actorNavigationContext": null,
            "bserpEntityNavigationalUrl": "https://www.linkedin.com/search/results/all/?keywords=Medical%20Equipment%20Services&origin=ENTITY_SEARCH_HOME_HISTORY&heroEntityKey=urn%3Ali%3Aorganization%3A488891",
            "trackingUrn": "urn:li:company:488891",
            "controlName": null,
            "interstitialComponent": null,
            "primaryActions": [],
            "entityCustomTrackingInfo": null,
            "badgeData": null,
            "title": {
                "textDirection": "USER_LOCALE",
                "text": "Medical Equipment Services",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "overflowActions": [],
            "*lazyLoadedActions": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:488891,COMPANIES,SEARCH_SRP)",
            "searchActionType": null,
            "actorInsights": [],
            "insightsResolutionResults": [],
            "badgeIcon": null,
            "entityUrn": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:488891,SEARCH_SRP,DEFAULT)",
            "showAdditionalCluster": false,
            "ringStatus": null,
            "primarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "Medical Equipment Manufacturing • Keilor Park, Victoria",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "badgeText": null,
            "trackingId": "YqWFCaoBQOWdpp7TocVMKg==",
            "summary": {
                "textDirection": "USER_LOCALE",
                "text": "Medical Equipment Services Pty Ltd (MES) was established in 1952 to supply medical and physical therapy professionals with their electro-medical and electro-therapeutic requirements.    Today, MES have sales teams servicing three distinctdivisions of the market; hospitals, primary care, allied health and sports...",
                "attributesV2": [
                    {
                        "start": 0,
                        "length": 7,
                        "detailData": {
                            "jobPostingName": null,
                            "hyperlink": null,
                            "profileFamiliarName": null,
                            "color": null,
                            "companyName": null,
                            "icon": null,
                            "epoch": null,
                            "systemImage": null,
                            "textLink": null,
                            "listItemStyle": null,
                            "groupName": null,
                            "hyperlinkOpenExternally": null,
                            "listStyle": null,
                            "profileFullName": null,
                            "stringFieldReference": null,
                            "learningCourseName": null,
                            "profileMention": null,
                            "style": "BOLD",
                            "schoolName": null,
                            "hashtag": null
                        },
                        "$recipeTypes": [
                            "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                        ],
                        "$type": "com.linkedin.voyager.dash.common.text.TextAttribute"
                    },
                    {
                        "start": 75,
                        "length": 7,
                        "detailData": {
                            "jobPostingName": null,
                            "hyperlink": null,
                            "profileFamiliarName": null,
                            "color": null,
                            "companyName": null,
                            "icon": null,
                            "epoch": null,
                            "systemImage": null,
                            "textLink": null,
                            "listItemStyle": null,
                            "groupName": null,
                            "hyperlinkOpenExternally": null,
                            "listStyle": null,
                            "profileFullName": null,
                            "stringFieldReference": null,
                            "learningCourseName": null,
                            "profileMention": null,
                            "style": "BOLD",
                            "schoolName": null,
                            "hashtag": null
                        },
                        "$recipeTypes": [
                            "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                        ],
                        "$type": "com.linkedin.voyager.dash.common.text.TextAttribute"
                    },
                    {
                        "start": 137,
                        "length": 7,
                        "detailData": {
                            "jobPostingName": null,
                            "hyperlink": null,
                            "profileFamiliarName": null,
                            "color": null,
                            "companyName": null,
                            "icon": null,
                            "epoch": null,
                            "systemImage": null,
                            "textLink": null,
                            "listItemStyle": null,
                            "groupName": null,
                            "hyperlinkOpenExternally": null,
                            "listStyle": null,
                            "profileFullName": null,
                            "stringFieldReference": null,
                            "learningCourseName": null,
                            "profileMention": null,
                            "style": "BOLD",
                            "schoolName": null,
                            "hashtag": null
                        },
                        "$recipeTypes": [
                            "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                        ],
                        "$type": "com.linkedin.voyager.dash.common.text.TextAttribute"
                    }
                ],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "addEntityToSearchHistory": true,
            "actorNavigationUrl": null,
            "image": {
                "attributes": [
                    {
                        "scalingType": null,
                        "detailData": {
                            "profilePictureWithoutFrame": null,
                            "profilePictureWithRingStatus": null,
                            "companyLogo": null,
                            "icon": null,
                            "systemImage": null,
                            "nonEntityGroupLogo": null,
                            "vectorImage": null,
                            "nonEntityProfessionalEventLogo": null,
                            "profilePicture": null,
                            "imageUrl": null,
                            "professionalEventLogo": null,
                            "nonEntityCompanyLogo": {
                                "*company": "urn:li:fsd_company:488891",
                                "$recipeTypes": [
                                    "com.linkedin.3be27b5a0eb7edd91e98b14c0290096c"
                                ],
                                "vectorImage": {
                                    "digitalmediaAsset": null,
                                    "attribution": null,
                                    "c2paManifestData": null,
                                    "$recipeTypes": [
                                        "com.linkedin.28db8575bcf1c65bdc4bc15948d50ee9"
                                    ],
                                    "artifacts": [
                                        {
                                            "width": 100,
                                            "$recipeTypes": [
                                                "com.linkedin.f0f435b4425ee2990eba8f0a4d614944"
                                            ],
                                            "fileIdentifyingUrlPathSegment": "https://media.licdn.com/dms/image/v2/C560BAQGHiQYjEqtd0w/company-logo_100_100/company-logo_100_100/0/1631392380345?e=1769644800&v=beta&t=0t1zolDi69ll-61RIVJt1jnN9psuURrf3YTmcH5lHFI",
                                            "expiresAt": 1769644800000,
                                            "height": 100,
                                            "$type": "com.linkedin.common.VectorArtifact"
                                        }
                                    ],
                                    "rootUrl": "",
                                    "$type": "com.linkedin.common.VectorImage"
                                },
                                "$type": "com.linkedin.voyager.dash.common.image.NonEntityCompanyLogo"
                            },
                            "nonEntitySchoolLogo": null,
                            "groupLogo": null,
                            "schoolLogo": null,
                            "ghostImage": null,
                            "nonEntityProfilePicture": null
                        },
                        "tintColor": null,
                        "$recipeTypes": [
                            "com.linkedin.eb94fbb1518f790c4545aafdf571c64e"
                        ],
                        "tapTargets": [],
                        "displayAspectRatio": null,
                        "$type": "com.linkedin.voyager.dash.common.image.ImageAttribute"
                    }
                ],
                "editableAccessibilityText": false,
                "actionTarget": null,
                "accessibilityTextAttributes": [],
                "totalCount": null,
                "accessibilityText": "Medical Equipment Services",
                "$recipeTypes": [
                    "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                ],
                "$type": "com.linkedin.voyager.dash.common.image.ImageViewModel"
            },
            "secondarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "357 followers",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "navigationUrl": "https://www.linkedin.com/company/medical-equipment-services/",
            "entityEmbeddedObject": null,
            "unreadIndicatorDetails": null,
            "$recipeTypes": [
                "com.linkedin.cf4b25c18907ea8eafe915c8bfa24109"
            ],
            "target": null,
            "$type": "com.linkedin.voyager.dash.search.EntityResultViewModel",
            "actorTrackingUrn": null,
            "navigationContext": {
                "openExternally": false,
                "$recipeTypes": [
                    "com.linkedin.55ee9afd4182671fe7e271f615659525"
                ],
                "url": "https://www.linkedin.com/company/medical-equipment-services/",
                "$type": "com.linkedin.voyager.dash.search.NavigationContext"
            }
        },
        {
            "template": "UNIVERSAL",
            "actorNavigationContext": null,
            "bserpEntityNavigationalUrl": "https://www.linkedin.com/search/results/all/?keywords=Medical%20Sales%20%26%20Service%20Pty%20Ltd%20-%20Ceased%20Trading%2030th%20June%202024&origin=ENTITY_SEARCH_HOME_HISTORY&heroEntityKey=urn%3Ali%3Aorganization%3A1386373",
            "trackingUrn": "urn:li:company:1386373",
            "controlName": null,
            "interstitialComponent": null,
            "primaryActions": [],
            "entityCustomTrackingInfo": null,
            "badgeData": null,
            "title": {
                "textDirection": "USER_LOCALE",
                "text": "Medical Sales & Service Pty Ltd - Ceased Trading 30th June 2024",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "overflowActions": [],
            "*lazyLoadedActions": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:1386373,COMPANIES,SEARCH_SRP)",
            "searchActionType": null,
            "actorInsights": [],
            "insightsResolutionResults": [],
            "badgeIcon": null,
            "entityUrn": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:1386373,SEARCH_SRP,DEFAULT)",
            "showAdditionalCluster": false,
            "ringStatus": null,
            "primarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "Medical Equipment Manufacturing • Perth",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "badgeText": null,
            "trackingId": "C8yMNJYPSMmB90nyUGMUHw==",
            "summary": {
                "textDirection": "USER_LOCALE",
                "text": "Australian medical equipment & consumables supplier with 40+ years of experience!",
                "attributesV2": [
                    {
                        "start": 11,
                        "length": 7,
                        "detailData": {
                            "jobPostingName": null,
                            "hyperlink": null,
                            "profileFamiliarName": null,
                            "color": null,
                            "companyName": null,
                            "icon": null,
                            "epoch": null,
                            "systemImage": null,
                            "textLink": null,
                            "listItemStyle": null,
                            "groupName": null,
                            "hyperlinkOpenExternally": null,
                            "listStyle": null,
                            "profileFullName": null,
                            "stringFieldReference": null,
                            "learningCourseName": null,
                            "profileMention": null,
                            "style": "BOLD",
                            "schoolName": null,
                            "hashtag": null
                        },
                        "$recipeTypes": [
                            "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                        ],
                        "$type": "com.linkedin.voyager.dash.common.text.TextAttribute"
                    }
                ],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "addEntityToSearchHistory": true,
            "actorNavigationUrl": null,
            "image": {
                "attributes": [
                    {
                        "scalingType": null,
                        "detailData": {
                            "profilePictureWithoutFrame": null,
                            "profilePictureWithRingStatus": null,
                            "companyLogo": null,
                            "icon": null,
                            "systemImage": null,
                            "nonEntityGroupLogo": null,
                            "vectorImage": null,
                            "nonEntityProfessionalEventLogo": null,
                            "profilePicture": null,
                            "imageUrl": null,
                            "professionalEventLogo": null,
                            "nonEntityCompanyLogo": {
                                "*company": "urn:li:fsd_company:1386373",
                                "$recipeTypes": [
                                    "com.linkedin.3be27b5a0eb7edd91e98b14c0290096c"
                                ],
                                "vectorImage": {
                                    "digitalmediaAsset": null,
                                    "attribution": null,
                                    "c2paManifestData": null,
                                    "$recipeTypes": [
                                        "com.linkedin.28db8575bcf1c65bdc4bc15948d50ee9"
                                    ],
                                    "artifacts": [
                                        {
                                            "width": 100,
                                            "$recipeTypes": [
                                                "com.linkedin.f0f435b4425ee2990eba8f0a4d614944"
                                            ],
                                            "fileIdentifyingUrlPathSegment": "https://media.licdn.com/dms/image/v2/C560BAQENxfROhRq4yg/company-logo_100_100/company-logo_100_100/0/1670292057016/medical_sales_and_service_logo?e=1769644800&v=beta&t=UiMA8VmZ6IJ_OsqUe6l_YTAmq3aQzua8MK1BD__AdPk",
                                            "expiresAt": 1769644800000,
                                            "height": 100,
                                            "$type": "com.linkedin.common.VectorArtifact"
                                        }
                                    ],
                                    "rootUrl": "",
                                    "$type": "com.linkedin.common.VectorImage"
                                },
                                "$type": "com.linkedin.voyager.dash.common.image.NonEntityCompanyLogo"
                            },
                            "nonEntitySchoolLogo": null,
                            "groupLogo": null,
                            "schoolLogo": null,
                            "ghostImage": null,
                            "nonEntityProfilePicture": null
                        },
                        "tintColor": null,
                        "$recipeTypes": [
                            "com.linkedin.eb94fbb1518f790c4545aafdf571c64e"
                        ],
                        "tapTargets": [],
                        "displayAspectRatio": null,
                        "$type": "com.linkedin.voyager.dash.common.image.ImageAttribute"
                    }
                ],
                "editableAccessibilityText": false,
                "actionTarget": null,
                "accessibilityTextAttributes": [],
                "totalCount": null,
                "accessibilityText": "Medical Sales & Service Pty Ltd - Ceased Trading 30th June 2024",
                "$recipeTypes": [
                    "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                ],
                "$type": "com.linkedin.voyager.dash.common.image.ImageViewModel"
            },
            "secondarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "2K followers",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "navigationUrl": "https://www.linkedin.com/company/medical-sales-and-service/",
            "entityEmbeddedObject": null,
            "unreadIndicatorDetails": null,
            "$recipeTypes": [
                "com.linkedin.cf4b25c18907ea8eafe915c8bfa24109"
            ],
            "target": null,
            "$type": "com.linkedin.voyager.dash.search.EntityResultViewModel",
            "actorTrackingUrn": null,
            "navigationContext": {
                "openExternally": false,
                "$recipeTypes": [
                    "com.linkedin.55ee9afd4182671fe7e271f615659525"
                ],
                "url": "https://www.linkedin.com/company/medical-sales-and-service/",
                "$type": "com.linkedin.voyager.dash.search.NavigationContext"
            }
        },
        {
            "template": "UNIVERSAL",
            "actorNavigationContext": null,
            "bserpEntityNavigationalUrl": "https://www.linkedin.com/search/results/all/?keywords=Medical%20Software%20Industry%20Association&origin=ENTITY_SEARCH_HOME_HISTORY&heroEntityKey=urn%3Ali%3Aorganization%3A18128605",
            "trackingUrn": "urn:li:company:18128605",
            "controlName": null,
            "interstitialComponent": null,
            "primaryActions": [],
            "entityCustomTrackingInfo": null,
            "badgeData": null,
            "title": {
                "textDirection": "USER_LOCALE",
                "text": "Medical Software Industry Association",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "overflowActions": [],
            "*lazyLoadedActions": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:18128605,COMPANIES,SEARCH_SRP)",
            "searchActionType": null,
            "actorInsights": [],
            "insightsResolutionResults": [],
            "badgeIcon": null,
            "entityUrn": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:18128605,SEARCH_SRP,DEFAULT)",
            "showAdditionalCluster": false,
            "ringStatus": null,
            "primarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "Medical Equipment Manufacturing • Crows Nest , NSW",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "badgeText": null,
            "trackingId": "XEHXKw68SjaEJIJ/iMM2xw==",
            "summary": {
                "textDirection": "USER_LOCALE",
                "text": "The Medical Software Industry Association (MSIA) provides you with all the resources required for your organisation to navigate the complex digital health environment in Australasia. The MSIA is a conduit between the numerous health sector stakeholders, government departments and industry bodies, acting as your one...",
                "attributesV2": [
                    {
                        "start": 4,
                        "length": 7,
                        "detailData": {
                            "jobPostingName": null,
                            "hyperlink": null,
                            "profileFamiliarName": null,
                            "color": null,
                            "companyName": null,
                            "icon": null,
                            "epoch": null,
                            "systemImage": null,
                            "textLink": null,
                            "listItemStyle": null,
                            "groupName": null,
                            "hyperlinkOpenExternally": null,
                            "listStyle": null,
                            "profileFullName": null,
                            "stringFieldReference": null,
                            "learningCourseName": null,
                            "profileMention": null,
                            "style": "BOLD",
                            "schoolName": null,
                            "hashtag": null
                        },
                        "$recipeTypes": [
                            "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                        ],
                        "$type": "com.linkedin.voyager.dash.common.text.TextAttribute"
                    }
                ],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "addEntityToSearchHistory": true,
            "actorNavigationUrl": null,
            "image": {
                "attributes": [
                    {
                        "scalingType": null,
                        "detailData": {
                            "profilePictureWithoutFrame": null,
                            "profilePictureWithRingStatus": null,
                            "companyLogo": null,
                            "icon": null,
                            "systemImage": null,
                            "nonEntityGroupLogo": null,
                            "vectorImage": null,
                            "nonEntityProfessionalEventLogo": null,
                            "profilePicture": null,
                            "imageUrl": null,
                            "professionalEventLogo": null,
                            "nonEntityCompanyLogo": {
                                "*company": "urn:li:fsd_company:18128605",
                                "$recipeTypes": [
                                    "com.linkedin.3be27b5a0eb7edd91e98b14c0290096c"
                                ],
                                "vectorImage": {
                                    "digitalmediaAsset": null,
                                    "attribution": null,
                                    "c2paManifestData": null,
                                    "$recipeTypes": [
                                        "com.linkedin.28db8575bcf1c65bdc4bc15948d50ee9"
                                    ],
                                    "artifacts": [
                                        {
                                            "width": 100,
                                            "$recipeTypes": [
                                                "com.linkedin.f0f435b4425ee2990eba8f0a4d614944"
                                            ],
                                            "fileIdentifyingUrlPathSegment": "https://media.licdn.com/dms/image/v2/C510BAQF_u4-bgLfOgQ/company-logo_100_100/company-logo_100_100/0/1631334735872?e=1769644800&v=beta&t=HoUpwiZyVMJGsLnlkDFLcAjM_hcNsiDWYL2a2LNWgUk",
                                            "expiresAt": 1769644800000,
                                            "height": 100,
                                            "$type": "com.linkedin.common.VectorArtifact"
                                        }
                                    ],
                                    "rootUrl": "",
                                    "$type": "com.linkedin.common.VectorImage"
                                },
                                "$type": "com.linkedin.voyager.dash.common.image.NonEntityCompanyLogo"
                            },
                            "nonEntitySchoolLogo": null,
                            "groupLogo": null,
                            "schoolLogo": null,
                            "ghostImage": null,
                            "nonEntityProfilePicture": null
                        },
                        "tintColor": null,
                        "$recipeTypes": [
                            "com.linkedin.eb94fbb1518f790c4545aafdf571c64e"
                        ],
                        "tapTargets": [],
                        "displayAspectRatio": null,
                        "$type": "com.linkedin.voyager.dash.common.image.ImageAttribute"
                    }
                ],
                "editableAccessibilityText": false,
                "actionTarget": null,
                "accessibilityTextAttributes": [],
                "totalCount": null,
                "accessibilityText": "Medical Software Industry Association",
                "$recipeTypes": [
                    "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                ],
                "$type": "com.linkedin.voyager.dash.common.image.ImageViewModel"
            },
            "secondarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "2K followers",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "navigationUrl": "https://www.linkedin.com/company/medical-software-industry-association/",
            "entityEmbeddedObject": null,
            "unreadIndicatorDetails": null,
            "$recipeTypes": [
                "com.linkedin.cf4b25c18907ea8eafe915c8bfa24109"
            ],
            "target": null,
            "$type": "com.linkedin.voyager.dash.search.EntityResultViewModel",
            "actorTrackingUrn": null,
            "navigationContext": {
                "openExternally": false,
                "$recipeTypes": [
                    "com.linkedin.55ee9afd4182671fe7e271f615659525"
                ],
                "url": "https://www.linkedin.com/company/medical-software-industry-association/",
                "$type": "com.linkedin.voyager.dash.search.NavigationContext"
            }
        },
        {
            "entityUrn": "urn:li:fsd_feedbackCard:SRP_FEEDBACK_COMPANIES",
            "$recipeTypes": [
                "com.linkedin.2d3e7b4bccc9c85f103b0dc9fdfd3669"
            ],
            "trackingId": "\u0012tX}G¬ eà°¸®p©",
            "$type": "com.linkedin.voyager.dash.search.FeedbackCard"
        },
        {
            "entityUrn": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:18128605,COMPANIES,SEARCH_SRP)",
            "$recipeTypes": [
                "com.linkedin.92ece182782ae4412e712925cd97f9fe"
            ],
            "$type": "com.linkedin.voyager.dash.search.LazyLoadedActions"
        },
        {
            "entityUrn": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:74122547,COMPANIES,SEARCH_SRP)",
            "$recipeTypes": [
                "com.linkedin.92ece182782ae4412e712925cd97f9fe"
            ],
            "$type": "com.linkedin.voyager.dash.search.LazyLoadedActions"
        },
        {
            "entityUrn": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:2441750,COMPANIES,SEARCH_SRP)",
            "$recipeTypes": [
                "com.linkedin.92ece182782ae4412e712925cd97f9fe"
            ],
            "$type": "com.linkedin.voyager.dash.search.LazyLoadedActions"
        },
        {
            "entityUrn": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:488891,COMPANIES,SEARCH_SRP)",
            "$recipeTypes": [
                "com.linkedin.92ece182782ae4412e712925cd97f9fe"
            ],
            "$type": "com.linkedin.voyager.dash.search.LazyLoadedActions"
        },
        {
            "entityUrn": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:71605911,COMPANIES,SEARCH_SRP)",
            "$recipeTypes": [
                "com.linkedin.92ece182782ae4412e712925cd97f9fe"
            ],
            "$type": "com.linkedin.voyager.dash.search.LazyLoadedActions"
        },
        {
            "entityUrn": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:97427935,COMPANIES,SEARCH_SRP)",
            "$recipeTypes": [
                "com.linkedin.92ece182782ae4412e712925cd97f9fe"
            ],
            "$type": "com.linkedin.voyager.dash.search.LazyLoadedActions"
        },
        {
            "entityUrn": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:82778753,COMPANIES,SEARCH_SRP)",
            "$recipeTypes": [
                "com.linkedin.92ece182782ae4412e712925cd97f9fe"
            ],
            "$type": "com.linkedin.voyager.dash.search.LazyLoadedActions"
        },
        {
            "entityUrn": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:13644897,COMPANIES,SEARCH_SRP)",
            "$recipeTypes": [
                "com.linkedin.92ece182782ae4412e712925cd97f9fe"
            ],
            "$type": "com.linkedin.voyager.dash.search.LazyLoadedActions"
        },
        {
            "entityUrn": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:3541653,COMPANIES,SEARCH_SRP)",
            "$recipeTypes": [
                "com.linkedin.92ece182782ae4412e712925cd97f9fe"
            ],
            "$type": "com.linkedin.voyager.dash.search.LazyLoadedActions"
        },
        {
            "entityUrn": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:1386373,COMPANIES,SEARCH_SRP)",
            "$recipeTypes": [
                "com.linkedin.92ece182782ae4412e712925cd97f9fe"
            ],
            "$type": "com.linkedin.voyager.dash.search.LazyLoadedActions"
        }
    ]
},
    {
    "data": {
        "data": {
            "searchDashClustersByAll": {
                "metadata": {
                    "entityResultAttributes": null,
                    "bserpPaginationContext": null,
                    "totalResultCount": 5032,
                    "searchAlert": null,
                    "blockedQueryError": null,
                    "secondaryFilterCluster": null,
                    "$recipeTypes": [
                        "com.linkedin.dfce49e2c6bb412fb4161cbbc7190d0d"
                    ],
                    "lazyRightRail": null,
                    "queryType": null,
                    "$type": "com.linkedin.voyager.dash.search.SearchClusterCollectionMetadata",
                    "primaryResultType": "COMPANIES",
                    "paginationToken": null,
                    "primaryFilterCluster": null,
                    "blockedQuery": false,
                    "entityActionButtonStyle": null,
                    "searchId": "08c0dcea-7b01-4bc5-99fb-4a929560ba98",
                    "filterAppliedCount": 0,
                    "clusterTitleFontSize": null,
                    "simpleInsightAttributes": null,
                    "desktopNavigationPanelTrackingId": null,
                    "knowledgeCardRightRail": null
                },
                "paging": {
                    "count": 10,
                    "start": 10,
                    "total": 1000,
                    "$recipeTypes": [
                        "com.linkedin.81b214c2cdd4f02cdb7d827958d2f3a1"
                    ],
                    "$type": "com.linkedin.restli.common.CollectionMetadata"
                },
                "$recipeTypes": [
                    "com.linkedin.5f1d22f924ecb6a031ee124b8b767900"
                ],
                "elements": [
                    {
                        "image": null,
                        "quickFilterActions": [],
                        "clusterRenderType": "LIST",
                        "dismissable": false,
                        "totalResultCount": null,
                        "controlName": null,
                        "description": null,
                        "title": null,
                        "$recipeTypes": [
                            "com.linkedin.5c853aba2154c55483e72bf6cdfaaf3e"
                        ],
                        "$type": "com.linkedin.voyager.dash.search.SearchClusterViewModel",
                        "actionTypeName": null,
                        "navigationText": null,
                        "feature": null,
                        "navigationCardAction": null,
                        "position": 11,
                        "items": [
                            {
                                "item": {
                                    "entityResult": null,
                                    "cluster": null,
                                    "bannerCard": null,
                                    "searchAlert": null,
                                    "upsellSlot": null,
                                    "coachRealtimeResponse": null,
                                    "searchSuggestionCard": null,
                                    "coachPromptCluster": null,
                                    "feedbackCard": null,
                                    "knowledgeCardV2": null,
                                    "keywordsSuggestionCard": null,
                                    "queryClarificationCard": null,
                                    "topicalQuestionCard": null,
                                    "simpleTextV2": {
                                        "showDashes": false,
                                        "textAlignment": "LEFT",
                                        "numDashes": 0,
                                        "text": {
                                            "textDirection": "USER_LOCALE",
                                            "text": "About 5,000 results",
                                            "attributesV2": [],
                                            "accessibilityTextAttributesV2": [],
                                            "accessibilityText": null,
                                            "$recipeTypes": [
                                                "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                                            ],
                                            "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
                                        },
                                        "$recipeTypes": [
                                            "com.linkedin.5bbb553a55f0e4d13343716ac69b5f48"
                                        ],
                                        "renderStyle": "PLAIN",
                                        "$type": "com.linkedin.voyager.dash.search.SimpleText"
                                    },
                                    "promoCard": null,
                                    "searchFeedUpdate": null,
                                    "searchQuestionAndAnswerCard": null,
                                    "centeredText": null,
                                    "simpleImage": null
                                },
                                "position": 1,
                                "$recipeTypes": [
                                    "com.linkedin.edd11a570456ce19ca1f5ec3c9bb03c1"
                                ],
                                "$type": "com.linkedin.voyager.dash.search.SearchItem"
                            }
                        ],
                        "results": [],
                        "trackingId": "÷§®\u0013\\·J\n©±%È\u001a(ç"
                    },
                    {
                        "image": null,
                        "quickFilterActions": [],
                        "clusterRenderType": "LIST",
                        "dismissable": false,
                        "totalResultCount": null,
                        "controlName": null,
                        "description": null,
                        "title": null,
                        "$recipeTypes": [
                            "com.linkedin.5c853aba2154c55483e72bf6cdfaaf3e"
                        ],
                        "$type": "com.linkedin.voyager.dash.search.SearchClusterViewModel",
                        "actionTypeName": null,
                        "navigationText": null,
                        "feature": null,
                        "navigationCardAction": null,
                        "position": 12,
                        "items": [
                            {
                                "item": {
                                    "cluster": null,
                                    "bannerCard": null,
                                    "searchAlert": null,
                                    "upsellSlot": null,
                                    "coachRealtimeResponse": null,
                                    "searchSuggestionCard": null,
                                    "coachPromptCluster": null,
                                    "feedbackCard": null,
                                    "knowledgeCardV2": null,
                                    "keywordsSuggestionCard": null,
                                    "queryClarificationCard": null,
                                    "topicalQuestionCard": null,
                                    "*entityResult": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:7603629,SEARCH_SRP,DEFAULT)",
                                    "simpleTextV2": null,
                                    "promoCard": null,
                                    "searchFeedUpdate": null,
                                    "searchQuestionAndAnswerCard": null,
                                    "centeredText": null,
                                    "simpleImage": null
                                },
                                "position": 1,
                                "$recipeTypes": [
                                    "com.linkedin.edd11a570456ce19ca1f5ec3c9bb03c1"
                                ],
                                "$type": "com.linkedin.voyager.dash.search.SearchItem"
                            },
                            {
                                "item": {
                                    "cluster": null,
                                    "bannerCard": null,
                                    "searchAlert": null,
                                    "upsellSlot": null,
                                    "coachRealtimeResponse": null,
                                    "searchSuggestionCard": null,
                                    "coachPromptCluster": null,
                                    "feedbackCard": null,
                                    "knowledgeCardV2": null,
                                    "keywordsSuggestionCard": null,
                                    "queryClarificationCard": null,
                                    "topicalQuestionCard": null,
                                    "*entityResult": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:74355062,SEARCH_SRP,DEFAULT)",
                                    "simpleTextV2": null,
                                    "promoCard": null,
                                    "searchFeedUpdate": null,
                                    "searchQuestionAndAnswerCard": null,
                                    "centeredText": null,
                                    "simpleImage": null
                                },
                                "position": 2,
                                "$recipeTypes": [
                                    "com.linkedin.edd11a570456ce19ca1f5ec3c9bb03c1"
                                ],
                                "$type": "com.linkedin.voyager.dash.search.SearchItem"
                            },
                            {
                                "item": {
                                    "cluster": null,
                                    "bannerCard": null,
                                    "searchAlert": null,
                                    "upsellSlot": null,
                                    "coachRealtimeResponse": null,
                                    "searchSuggestionCard": null,
                                    "coachPromptCluster": null,
                                    "feedbackCard": null,
                                    "knowledgeCardV2": null,
                                    "keywordsSuggestionCard": null,
                                    "queryClarificationCard": null,
                                    "topicalQuestionCard": null,
                                    "*entityResult": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:14381845,SEARCH_SRP,DEFAULT)",
                                    "simpleTextV2": null,
                                    "promoCard": null,
                                    "searchFeedUpdate": null,
                                    "searchQuestionAndAnswerCard": null,
                                    "centeredText": null,
                                    "simpleImage": null
                                },
                                "position": 3,
                                "$recipeTypes": [
                                    "com.linkedin.edd11a570456ce19ca1f5ec3c9bb03c1"
                                ],
                                "$type": "com.linkedin.voyager.dash.search.SearchItem"
                            },
                            {
                                "item": {
                                    "cluster": null,
                                    "bannerCard": null,
                                    "searchAlert": null,
                                    "upsellSlot": null,
                                    "coachRealtimeResponse": null,
                                    "searchSuggestionCard": null,
                                    "coachPromptCluster": null,
                                    "feedbackCard": null,
                                    "knowledgeCardV2": null,
                                    "keywordsSuggestionCard": null,
                                    "queryClarificationCard": null,
                                    "topicalQuestionCard": null,
                                    "*entityResult": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:104377301,SEARCH_SRP,DEFAULT)",
                                    "simpleTextV2": null,
                                    "promoCard": null,
                                    "searchFeedUpdate": null,
                                    "searchQuestionAndAnswerCard": null,
                                    "centeredText": null,
                                    "simpleImage": null
                                },
                                "position": 4,
                                "$recipeTypes": [
                                    "com.linkedin.edd11a570456ce19ca1f5ec3c9bb03c1"
                                ],
                                "$type": "com.linkedin.voyager.dash.search.SearchItem"
                            },
                            {
                                "item": {
                                    "cluster": null,
                                    "bannerCard": null,
                                    "searchAlert": null,
                                    "upsellSlot": null,
                                    "coachRealtimeResponse": null,
                                    "searchSuggestionCard": null,
                                    "coachPromptCluster": null,
                                    "feedbackCard": null,
                                    "knowledgeCardV2": null,
                                    "keywordsSuggestionCard": null,
                                    "queryClarificationCard": null,
                                    "topicalQuestionCard": null,
                                    "*entityResult": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:10233669,SEARCH_SRP,DEFAULT)",
                                    "simpleTextV2": null,
                                    "promoCard": null,
                                    "searchFeedUpdate": null,
                                    "searchQuestionAndAnswerCard": null,
                                    "centeredText": null,
                                    "simpleImage": null
                                },
                                "position": 5,
                                "$recipeTypes": [
                                    "com.linkedin.edd11a570456ce19ca1f5ec3c9bb03c1"
                                ],
                                "$type": "com.linkedin.voyager.dash.search.SearchItem"
                            },
                            {
                                "item": {
                                    "cluster": null,
                                    "bannerCard": null,
                                    "searchAlert": null,
                                    "upsellSlot": null,
                                    "coachRealtimeResponse": null,
                                    "searchSuggestionCard": null,
                                    "coachPromptCluster": null,
                                    "feedbackCard": null,
                                    "knowledgeCardV2": null,
                                    "keywordsSuggestionCard": null,
                                    "queryClarificationCard": null,
                                    "topicalQuestionCard": null,
                                    "*entityResult": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:7627848,SEARCH_SRP,DEFAULT)",
                                    "simpleTextV2": null,
                                    "promoCard": null,
                                    "searchFeedUpdate": null,
                                    "searchQuestionAndAnswerCard": null,
                                    "centeredText": null,
                                    "simpleImage": null
                                },
                                "position": 6,
                                "$recipeTypes": [
                                    "com.linkedin.edd11a570456ce19ca1f5ec3c9bb03c1"
                                ],
                                "$type": "com.linkedin.voyager.dash.search.SearchItem"
                            },
                            {
                                "item": {
                                    "cluster": null,
                                    "bannerCard": null,
                                    "searchAlert": null,
                                    "upsellSlot": null,
                                    "coachRealtimeResponse": null,
                                    "searchSuggestionCard": null,
                                    "coachPromptCluster": null,
                                    "feedbackCard": null,
                                    "knowledgeCardV2": null,
                                    "keywordsSuggestionCard": null,
                                    "queryClarificationCard": null,
                                    "topicalQuestionCard": null,
                                    "*entityResult": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:71056408,SEARCH_SRP,DEFAULT)",
                                    "simpleTextV2": null,
                                    "promoCard": null,
                                    "searchFeedUpdate": null,
                                    "searchQuestionAndAnswerCard": null,
                                    "centeredText": null,
                                    "simpleImage": null
                                },
                                "position": 7,
                                "$recipeTypes": [
                                    "com.linkedin.edd11a570456ce19ca1f5ec3c9bb03c1"
                                ],
                                "$type": "com.linkedin.voyager.dash.search.SearchItem"
                            },
                            {
                                "item": {
                                    "cluster": null,
                                    "bannerCard": null,
                                    "searchAlert": null,
                                    "upsellSlot": null,
                                    "coachRealtimeResponse": null,
                                    "searchSuggestionCard": null,
                                    "coachPromptCluster": null,
                                    "feedbackCard": null,
                                    "knowledgeCardV2": null,
                                    "keywordsSuggestionCard": null,
                                    "queryClarificationCard": null,
                                    "topicalQuestionCard": null,
                                    "*entityResult": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:28209,SEARCH_SRP,DEFAULT)",
                                    "simpleTextV2": null,
                                    "promoCard": null,
                                    "searchFeedUpdate": null,
                                    "searchQuestionAndAnswerCard": null,
                                    "centeredText": null,
                                    "simpleImage": null
                                },
                                "position": 8,
                                "$recipeTypes": [
                                    "com.linkedin.edd11a570456ce19ca1f5ec3c9bb03c1"
                                ],
                                "$type": "com.linkedin.voyager.dash.search.SearchItem"
                            },
                            {
                                "item": {
                                    "cluster": null,
                                    "bannerCard": null,
                                    "searchAlert": null,
                                    "upsellSlot": null,
                                    "coachRealtimeResponse": null,
                                    "searchSuggestionCard": null,
                                    "coachPromptCluster": null,
                                    "feedbackCard": null,
                                    "knowledgeCardV2": null,
                                    "keywordsSuggestionCard": null,
                                    "queryClarificationCard": null,
                                    "topicalQuestionCard": null,
                                    "*entityResult": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:65590919,SEARCH_SRP,DEFAULT)",
                                    "simpleTextV2": null,
                                    "promoCard": null,
                                    "searchFeedUpdate": null,
                                    "searchQuestionAndAnswerCard": null,
                                    "centeredText": null,
                                    "simpleImage": null
                                },
                                "position": 9,
                                "$recipeTypes": [
                                    "com.linkedin.edd11a570456ce19ca1f5ec3c9bb03c1"
                                ],
                                "$type": "com.linkedin.voyager.dash.search.SearchItem"
                            },
                            {
                                "item": {
                                    "cluster": null,
                                    "bannerCard": null,
                                    "searchAlert": null,
                                    "upsellSlot": null,
                                    "coachRealtimeResponse": null,
                                    "searchSuggestionCard": null,
                                    "coachPromptCluster": null,
                                    "feedbackCard": null,
                                    "knowledgeCardV2": null,
                                    "keywordsSuggestionCard": null,
                                    "queryClarificationCard": null,
                                    "topicalQuestionCard": null,
                                    "*entityResult": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:18174916,SEARCH_SRP,DEFAULT)",
                                    "simpleTextV2": null,
                                    "promoCard": null,
                                    "searchFeedUpdate": null,
                                    "searchQuestionAndAnswerCard": null,
                                    "centeredText": null,
                                    "simpleImage": null
                                },
                                "position": 10,
                                "$recipeTypes": [
                                    "com.linkedin.edd11a570456ce19ca1f5ec3c9bb03c1"
                                ],
                                "$type": "com.linkedin.voyager.dash.search.SearchItem"
                            }
                        ],
                        "results": [],
                        "trackingId": "m6\u0007õDåÿEoÌ$G"
                    }
                ],
                "$type": "com.linkedin.restli.common.CollectionResponse"
            },
            "$recipeTypes": [
                "com.linkedin.c293aa010e51bae32433eeb13b1682fa"
            ],
            "$type": "com.linkedin.c293aa010e51bae32433eeb13b1682fa"
        }
    },
    "included": [
        {
            "entityUrn": "urn:li:fsd_company:10233669",
            "$recipeTypes": [
                "com.linkedin.2c2374bef3eaba3e079b4a11e2f7bea8"
            ],
            "$type": "com.linkedin.voyager.dash.organization.Company"
        },
        {
            "entityUrn": "urn:li:fsd_company:18174916",
            "$recipeTypes": [
                "com.linkedin.2c2374bef3eaba3e079b4a11e2f7bea8"
            ],
            "$type": "com.linkedin.voyager.dash.organization.Company"
        },
        {
            "entityUrn": "urn:li:fsd_company:65590919",
            "$recipeTypes": [
                "com.linkedin.2c2374bef3eaba3e079b4a11e2f7bea8"
            ],
            "$type": "com.linkedin.voyager.dash.organization.Company"
        },
        {
            "entityUrn": "urn:li:fsd_company:7603629",
            "$recipeTypes": [
                "com.linkedin.2c2374bef3eaba3e079b4a11e2f7bea8"
            ],
            "$type": "com.linkedin.voyager.dash.organization.Company"
        },
        {
            "entityUrn": "urn:li:fsd_company:104377301",
            "$recipeTypes": [
                "com.linkedin.2c2374bef3eaba3e079b4a11e2f7bea8"
            ],
            "$type": "com.linkedin.voyager.dash.organization.Company"
        },
        {
            "entityUrn": "urn:li:fsd_company:7627848",
            "$recipeTypes": [
                "com.linkedin.2c2374bef3eaba3e079b4a11e2f7bea8"
            ],
            "$type": "com.linkedin.voyager.dash.organization.Company"
        },
        {
            "entityUrn": "urn:li:fsd_company:14381845",
            "$recipeTypes": [
                "com.linkedin.2c2374bef3eaba3e079b4a11e2f7bea8"
            ],
            "$type": "com.linkedin.voyager.dash.organization.Company"
        },
        {
            "entityUrn": "urn:li:fsd_company:28209",
            "$recipeTypes": [
                "com.linkedin.2c2374bef3eaba3e079b4a11e2f7bea8"
            ],
            "$type": "com.linkedin.voyager.dash.organization.Company"
        },
        {
            "entityUrn": "urn:li:fsd_company:74355062",
            "$recipeTypes": [
                "com.linkedin.2c2374bef3eaba3e079b4a11e2f7bea8"
            ],
            "$type": "com.linkedin.voyager.dash.organization.Company"
        },
        {
            "entityUrn": "urn:li:fsd_company:71056408",
            "$recipeTypes": [
                "com.linkedin.2c2374bef3eaba3e079b4a11e2f7bea8"
            ],
            "$type": "com.linkedin.voyager.dash.organization.Company"
        },
        {
            "template": "UNIVERSAL",
            "actorNavigationContext": null,
            "bserpEntityNavigationalUrl": "https://www.linkedin.com/search/results/all/?keywords=Medical%20Operations%20Consultancy&origin=ENTITY_SEARCH_HOME_HISTORY&heroEntityKey=urn%3Ali%3Aorganization%3A71056408",
            "trackingUrn": "urn:li:company:71056408",
            "controlName": null,
            "interstitialComponent": null,
            "primaryActions": [],
            "entityCustomTrackingInfo": null,
            "badgeData": null,
            "title": {
                "textDirection": "USER_LOCALE",
                "text": "Medical Operations Consultancy",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "overflowActions": [],
            "*lazyLoadedActions": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:71056408,COMPANIES,SEARCH_SRP)",
            "searchActionType": null,
            "actorInsights": [],
            "insightsResolutionResults": [],
            "badgeIcon": null,
            "entityUrn": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:71056408,SEARCH_SRP,DEFAULT)",
            "showAdditionalCluster": false,
            "ringStatus": null,
            "primarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "Medical Practices • Coogee, NSW",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "badgeText": null,
            "trackingId": "jQnX/+GXRb+KX9abULol4A==",
            "summary": {
                "textDirection": "USER_LOCALE",
                "text": "Marcia brings a wealth of practice management expertise to every client’s project. In addition to her 20 years’ experience as a Registered Nurse, Marcia built, ran and sold her own successful medical practice. She is now an Area Operations Manager, overseeing multiple medical practices, allied health and specialists...",
                "attributesV2": [
                    {
                        "start": 192,
                        "length": 7,
                        "detailData": {
                            "jobPostingName": null,
                            "hyperlink": null,
                            "profileFamiliarName": null,
                            "color": null,
                            "companyName": null,
                            "icon": null,
                            "epoch": null,
                            "systemImage": null,
                            "textLink": null,
                            "listItemStyle": null,
                            "groupName": null,
                            "hyperlinkOpenExternally": null,
                            "listStyle": null,
                            "profileFullName": null,
                            "stringFieldReference": null,
                            "learningCourseName": null,
                            "profileMention": null,
                            "style": "BOLD",
                            "schoolName": null,
                            "hashtag": null
                        },
                        "$recipeTypes": [
                            "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                        ],
                        "$type": "com.linkedin.voyager.dash.common.text.TextAttribute"
                    },
                    {
                        "start": 269,
                        "length": 7,
                        "detailData": {
                            "jobPostingName": null,
                            "hyperlink": null,
                            "profileFamiliarName": null,
                            "color": null,
                            "companyName": null,
                            "icon": null,
                            "epoch": null,
                            "systemImage": null,
                            "textLink": null,
                            "listItemStyle": null,
                            "groupName": null,
                            "hyperlinkOpenExternally": null,
                            "listStyle": null,
                            "profileFullName": null,
                            "stringFieldReference": null,
                            "learningCourseName": null,
                            "profileMention": null,
                            "style": "BOLD",
                            "schoolName": null,
                            "hashtag": null
                        },
                        "$recipeTypes": [
                            "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                        ],
                        "$type": "com.linkedin.voyager.dash.common.text.TextAttribute"
                    }
                ],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "addEntityToSearchHistory": true,
            "actorNavigationUrl": null,
            "image": {
                "attributes": [
                    {
                        "scalingType": null,
                        "detailData": {
                            "profilePictureWithoutFrame": null,
                            "profilePictureWithRingStatus": null,
                            "companyLogo": null,
                            "icon": null,
                            "systemImage": null,
                            "nonEntityGroupLogo": null,
                            "vectorImage": null,
                            "nonEntityProfessionalEventLogo": null,
                            "profilePicture": null,
                            "imageUrl": null,
                            "professionalEventLogo": null,
                            "nonEntityCompanyLogo": {
                                "*company": "urn:li:fsd_company:71056408",
                                "$recipeTypes": [
                                    "com.linkedin.3be27b5a0eb7edd91e98b14c0290096c"
                                ],
                                "vectorImage": {
                                    "digitalmediaAsset": null,
                                    "attribution": null,
                                    "c2paManifestData": null,
                                    "$recipeTypes": [
                                        "com.linkedin.28db8575bcf1c65bdc4bc15948d50ee9"
                                    ],
                                    "artifacts": [
                                        {
                                            "width": 100,
                                            "$recipeTypes": [
                                                "com.linkedin.f0f435b4425ee2990eba8f0a4d614944"
                                            ],
                                            "fileIdentifyingUrlPathSegment": "https://media.licdn.com/dms/image/v2/C560BAQFyL0r1gzq89A/company-logo_100_100/company-logo_100_100/0/1630648707944/medical_operations_consultancy_logo?e=1769644800&v=beta&t=DhdhWyI1xWKyChGLzYynUUC-3dbHbdCJuvU_R0UTGps",
                                            "expiresAt": 1769644800000,
                                            "height": 100,
                                            "$type": "com.linkedin.common.VectorArtifact"
                                        }
                                    ],
                                    "rootUrl": "",
                                    "$type": "com.linkedin.common.VectorImage"
                                },
                                "$type": "com.linkedin.voyager.dash.common.image.NonEntityCompanyLogo"
                            },
                            "nonEntitySchoolLogo": null,
                            "groupLogo": null,
                            "schoolLogo": null,
                            "ghostImage": null,
                            "nonEntityProfilePicture": null
                        },
                        "tintColor": null,
                        "$recipeTypes": [
                            "com.linkedin.eb94fbb1518f790c4545aafdf571c64e"
                        ],
                        "tapTargets": [],
                        "displayAspectRatio": null,
                        "$type": "com.linkedin.voyager.dash.common.image.ImageAttribute"
                    }
                ],
                "editableAccessibilityText": false,
                "actionTarget": null,
                "accessibilityTextAttributes": [],
                "totalCount": null,
                "accessibilityText": "Medical Operations Consultancy",
                "$recipeTypes": [
                    "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                ],
                "$type": "com.linkedin.voyager.dash.common.image.ImageViewModel"
            },
            "secondarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "68 followers",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "navigationUrl": "https://www.linkedin.com/company/medical-operations-consultancy/",
            "entityEmbeddedObject": null,
            "unreadIndicatorDetails": null,
            "$recipeTypes": [
                "com.linkedin.cf4b25c18907ea8eafe915c8bfa24109"
            ],
            "target": null,
            "$type": "com.linkedin.voyager.dash.search.EntityResultViewModel",
            "actorTrackingUrn": null,
            "navigationContext": {
                "openExternally": false,
                "$recipeTypes": [
                    "com.linkedin.55ee9afd4182671fe7e271f615659525"
                ],
                "url": "https://www.linkedin.com/company/medical-operations-consultancy/",
                "$type": "com.linkedin.voyager.dash.search.NavigationContext"
            }
        },
        {
            "template": "UNIVERSAL",
            "actorNavigationContext": null,
            "bserpEntityNavigationalUrl": "https://www.linkedin.com/search/results/all/?keywords=Medical%20Billing%20WA&origin=ENTITY_SEARCH_HOME_HISTORY&heroEntityKey=urn%3Ali%3Aorganization%3A18174916",
            "trackingUrn": "urn:li:company:18174916",
            "controlName": null,
            "interstitialComponent": null,
            "primaryActions": [],
            "entityCustomTrackingInfo": null,
            "badgeData": null,
            "title": {
                "textDirection": "USER_LOCALE",
                "text": "Medical Billing WA",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "overflowActions": [],
            "*lazyLoadedActions": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:18174916,COMPANIES,SEARCH_SRP)",
            "searchActionType": null,
            "actorInsights": [],
            "insightsResolutionResults": [],
            "badgeIcon": null,
            "entityUrn": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:18174916,SEARCH_SRP,DEFAULT)",
            "showAdditionalCluster": false,
            "ringStatus": null,
            "primarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "Medical Practices • Churchlands, WA",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "badgeText": null,
            "trackingId": "w5XMf4o1SDmU7rhZh8UtlA==",
            "summary": {
                "textDirection": "USER_LOCALE",
                "text": "Inpatient medical claiming and patient co-payment collection service, specialising in Known-Gap health fund claims.",
                "attributesV2": [
                    {
                        "start": 10,
                        "length": 7,
                        "detailData": {
                            "jobPostingName": null,
                            "hyperlink": null,
                            "profileFamiliarName": null,
                            "color": null,
                            "companyName": null,
                            "icon": null,
                            "epoch": null,
                            "systemImage": null,
                            "textLink": null,
                            "listItemStyle": null,
                            "groupName": null,
                            "hyperlinkOpenExternally": null,
                            "listStyle": null,
                            "profileFullName": null,
                            "stringFieldReference": null,
                            "learningCourseName": null,
                            "profileMention": null,
                            "style": "BOLD",
                            "schoolName": null,
                            "hashtag": null
                        },
                        "$recipeTypes": [
                            "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                        ],
                        "$type": "com.linkedin.voyager.dash.common.text.TextAttribute"
                    }
                ],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "addEntityToSearchHistory": true,
            "actorNavigationUrl": null,
            "image": {
                "attributes": [
                    {
                        "scalingType": null,
                        "detailData": {
                            "profilePictureWithoutFrame": null,
                            "profilePictureWithRingStatus": null,
                            "companyLogo": null,
                            "icon": null,
                            "systemImage": null,
                            "nonEntityGroupLogo": null,
                            "vectorImage": null,
                            "nonEntityProfessionalEventLogo": null,
                            "profilePicture": null,
                            "imageUrl": null,
                            "professionalEventLogo": null,
                            "nonEntityCompanyLogo": {
                                "*company": "urn:li:fsd_company:18174916",
                                "$recipeTypes": [
                                    "com.linkedin.3be27b5a0eb7edd91e98b14c0290096c"
                                ],
                                "vectorImage": {
                                    "digitalmediaAsset": null,
                                    "attribution": null,
                                    "c2paManifestData": null,
                                    "$recipeTypes": [
                                        "com.linkedin.28db8575bcf1c65bdc4bc15948d50ee9"
                                    ],
                                    "artifacts": [
                                        {
                                            "width": 100,
                                            "$recipeTypes": [
                                                "com.linkedin.f0f435b4425ee2990eba8f0a4d614944"
                                            ],
                                            "fileIdentifyingUrlPathSegment": "https://media.licdn.com/dms/image/v2/C560BAQH16V63jNweqg/company-logo_100_100/company-logo_100_100/0/1630623292715/medical_billing_wa_logo?e=1769644800&v=beta&t=Y8lohGtwnLyu8hnplVGXINh8Pl11rhBj_xJe6qQZ6jI",
                                            "expiresAt": 1769644800000,
                                            "height": 100,
                                            "$type": "com.linkedin.common.VectorArtifact"
                                        }
                                    ],
                                    "rootUrl": "",
                                    "$type": "com.linkedin.common.VectorImage"
                                },
                                "$type": "com.linkedin.voyager.dash.common.image.NonEntityCompanyLogo"
                            },
                            "nonEntitySchoolLogo": null,
                            "groupLogo": null,
                            "schoolLogo": null,
                            "ghostImage": null,
                            "nonEntityProfilePicture": null
                        },
                        "tintColor": null,
                        "$recipeTypes": [
                            "com.linkedin.eb94fbb1518f790c4545aafdf571c64e"
                        ],
                        "tapTargets": [],
                        "displayAspectRatio": null,
                        "$type": "com.linkedin.voyager.dash.common.image.ImageAttribute"
                    }
                ],
                "editableAccessibilityText": false,
                "actionTarget": null,
                "accessibilityTextAttributes": [],
                "totalCount": null,
                "accessibilityText": "Medical Billing WA",
                "$recipeTypes": [
                    "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                ],
                "$type": "com.linkedin.voyager.dash.common.image.ImageViewModel"
            },
            "secondarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "26 followers",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "navigationUrl": "https://www.linkedin.com/company/medical-billing-wa/",
            "entityEmbeddedObject": null,
            "unreadIndicatorDetails": null,
            "$recipeTypes": [
                "com.linkedin.cf4b25c18907ea8eafe915c8bfa24109"
            ],
            "target": null,
            "$type": "com.linkedin.voyager.dash.search.EntityResultViewModel",
            "actorTrackingUrn": null,
            "navigationContext": {
                "openExternally": false,
                "$recipeTypes": [
                    "com.linkedin.55ee9afd4182671fe7e271f615659525"
                ],
                "url": "https://www.linkedin.com/company/medical-billing-wa/",
                "$type": "com.linkedin.voyager.dash.search.NavigationContext"
            }
        },
        {
            "template": "UNIVERSAL",
            "actorNavigationContext": null,
            "bserpEntityNavigationalUrl": "https://www.linkedin.com/search/results/all/?keywords=ICU%20Medical&origin=ENTITY_SEARCH_HOME_HISTORY&heroEntityKey=urn%3Ali%3Aorganization%3A28209",
            "trackingUrn": "urn:li:company:28209",
            "controlName": null,
            "interstitialComponent": null,
            "primaryActions": [],
            "entityCustomTrackingInfo": null,
            "badgeData": null,
            "title": {
                "textDirection": "USER_LOCALE",
                "text": "ICU Medical",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "overflowActions": [],
            "*lazyLoadedActions": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:28209,COMPANIES,SEARCH_SRP)",
            "searchActionType": null,
            "actorInsights": [],
            "insightsResolutionResults": [
                {
                    "jobPostingInsight": null,
                    "relationshipsInsight": null,
                    "serviceProviderRatingInsight": null,
                    "simpleInsight": {
                        "image": {
                            "attributes": [
                                {
                                    "scalingType": "ASPECT_FIT",
                                    "detailData": {
                                        "profilePictureWithoutFrame": null,
                                        "profilePictureWithRingStatus": null,
                                        "companyLogo": null,
                                        "icon": "IC_BRIEFCASE_16DP",
                                        "systemImage": null,
                                        "nonEntityGroupLogo": null,
                                        "vectorImage": null,
                                        "nonEntityProfessionalEventLogo": null,
                                        "profilePicture": null,
                                        "imageUrl": null,
                                        "professionalEventLogo": null,
                                        "nonEntityCompanyLogo": null,
                                        "nonEntitySchoolLogo": null,
                                        "groupLogo": null,
                                        "schoolLogo": null,
                                        "ghostImage": null,
                                        "nonEntityProfilePicture": null
                                    },
                                    "tintColor": null,
                                    "$recipeTypes": [
                                        "com.linkedin.eb94fbb1518f790c4545aafdf571c64e"
                                    ],
                                    "tapTargets": [],
                                    "displayAspectRatio": null,
                                    "$type": "com.linkedin.voyager.dash.common.image.ImageAttribute"
                                }
                            ],
                            "editableAccessibilityText": false,
                            "actionTarget": null,
                            "accessibilityTextAttributes": [],
                            "totalCount": null,
                            "accessibilityText": null,
                            "$recipeTypes": [
                                "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                            ],
                            "$type": "com.linkedin.voyager.dash.common.image.ImageViewModel"
                        },
                        "controlName": null,
                        "navigationUrl": "https://www.linkedin.com/jobs/search?geoId=92000000&f_C=28209%2C8044",
                        "title": {
                            "textDirection": "USER_LOCALE",
                            "text": "98 jobs",
                            "attributesV2": [],
                            "accessibilityTextAttributesV2": [],
                            "accessibilityText": null,
                            "$recipeTypes": [
                                "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                            ],
                            "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
                        },
                        "$recipeTypes": [
                            "com.linkedin.bd9a707a5b119c1f331373113f57344a"
                        ],
                        "$type": "com.linkedin.voyager.dash.search.SimpleInsight",
                        "searchActionType": "SEE_JOBS_AT_COMPANY",
                        "subtitleMaxNumLines": 1,
                        "titleFontSize": null,
                        "subtitle": null,
                        "subtitleFontSize": null,
                        "titleMaxNumLines": 1
                    },
                    "jobPostingFooterInsight": null,
                    "socialActivityCountsInsight": null,
                    "labelsInsight": null,
                    "premiumCustomCtaInsight": null
                }
            ],
            "badgeIcon": null,
            "entityUrn": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:28209,SEARCH_SRP,DEFAULT)",
            "showAdditionalCluster": false,
            "ringStatus": null,
            "primarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "Medical Equipment Manufacturing • San Clemente, CA",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "badgeText": null,
            "trackingId": "10L5aIsAREKmTHfhSYt45A==",
            "summary": {
                "textDirection": "USER_LOCALE",
                "text": "ICU Medical connects patients and caregivers through safe, life-saving, life-enhancing IV therapy systems, software, solutions, and consumables.  Since IV therapy is our only business, meeting your IV needs with quality products and consistent supply is our only concern. We are 100% focused on bringing you intuitive...",
                "attributesV2": [
                    {
                        "start": 4,
                        "length": 7,
                        "detailData": {
                            "jobPostingName": null,
                            "hyperlink": null,
                            "profileFamiliarName": null,
                            "color": null,
                            "companyName": null,
                            "icon": null,
                            "epoch": null,
                            "systemImage": null,
                            "textLink": null,
                            "listItemStyle": null,
                            "groupName": null,
                            "hyperlinkOpenExternally": null,
                            "listStyle": null,
                            "profileFullName": null,
                            "stringFieldReference": null,
                            "learningCourseName": null,
                            "profileMention": null,
                            "style": "BOLD",
                            "schoolName": null,
                            "hashtag": null
                        },
                        "$recipeTypes": [
                            "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                        ],
                        "$type": "com.linkedin.voyager.dash.common.text.TextAttribute"
                    }
                ],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "addEntityToSearchHistory": true,
            "actorNavigationUrl": null,
            "image": {
                "attributes": [
                    {
                        "scalingType": null,
                        "detailData": {
                            "profilePictureWithoutFrame": null,
                            "profilePictureWithRingStatus": null,
                            "companyLogo": null,
                            "icon": null,
                            "systemImage": null,
                            "nonEntityGroupLogo": null,
                            "vectorImage": null,
                            "nonEntityProfessionalEventLogo": null,
                            "profilePicture": null,
                            "imageUrl": null,
                            "professionalEventLogo": null,
                            "nonEntityCompanyLogo": {
                                "*company": "urn:li:fsd_company:28209",
                                "$recipeTypes": [
                                    "com.linkedin.3be27b5a0eb7edd91e98b14c0290096c"
                                ],
                                "vectorImage": {
                                    "digitalmediaAsset": null,
                                    "attribution": null,
                                    "c2paManifestData": null,
                                    "$recipeTypes": [
                                        "com.linkedin.28db8575bcf1c65bdc4bc15948d50ee9"
                                    ],
                                    "artifacts": [
                                        {
                                            "width": 100,
                                            "$recipeTypes": [
                                                "com.linkedin.f0f435b4425ee2990eba8f0a4d614944"
                                            ],
                                            "fileIdentifyingUrlPathSegment": "https://media.licdn.com/dms/image/v2/D560BAQH85LvcqCdtAg/company-logo_100_100/B56ZqTmORLJkAQ-/0/1763412862335/icu_medical_logo?e=1769644800&v=beta&t=Qu8fvZ-tp6lgwHedgGjQwmgYQgZpb5IcD6XaVozmrZ0",
                                            "expiresAt": 1769644800000,
                                            "height": 100,
                                            "$type": "com.linkedin.common.VectorArtifact"
                                        }
                                    ],
                                    "rootUrl": "",
                                    "$type": "com.linkedin.common.VectorImage"
                                },
                                "$type": "com.linkedin.voyager.dash.common.image.NonEntityCompanyLogo"
                            },
                            "nonEntitySchoolLogo": null,
                            "groupLogo": null,
                            "schoolLogo": null,
                            "ghostImage": null,
                            "nonEntityProfilePicture": null
                        },
                        "tintColor": null,
                        "$recipeTypes": [
                            "com.linkedin.eb94fbb1518f790c4545aafdf571c64e"
                        ],
                        "tapTargets": [],
                        "displayAspectRatio": null,
                        "$type": "com.linkedin.voyager.dash.common.image.ImageAttribute"
                    }
                ],
                "editableAccessibilityText": false,
                "actionTarget": null,
                "accessibilityTextAttributes": [],
                "totalCount": null,
                "accessibilityText": "ICU Medical",
                "$recipeTypes": [
                    "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                ],
                "$type": "com.linkedin.voyager.dash.common.image.ImageViewModel"
            },
            "secondarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "124K followers",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "navigationUrl": "https://www.linkedin.com/company/icu-medical/",
            "entityEmbeddedObject": null,
            "unreadIndicatorDetails": null,
            "$recipeTypes": [
                "com.linkedin.cf4b25c18907ea8eafe915c8bfa24109"
            ],
            "target": null,
            "$type": "com.linkedin.voyager.dash.search.EntityResultViewModel",
            "actorTrackingUrn": null,
            "navigationContext": {
                "openExternally": false,
                "$recipeTypes": [
                    "com.linkedin.55ee9afd4182671fe7e271f615659525"
                ],
                "url": "https://www.linkedin.com/company/icu-medical/",
                "$type": "com.linkedin.voyager.dash.search.NavigationContext"
            }
        },
        {
            "template": "UNIVERSAL",
            "actorNavigationContext": null,
            "bserpEntityNavigationalUrl": "https://www.linkedin.com/search/results/all/?keywords=Medical%20Esoterics&origin=ENTITY_SEARCH_HOME_HISTORY&heroEntityKey=urn%3Ali%3Aorganization%3A65590919",
            "trackingUrn": "urn:li:company:65590919",
            "controlName": null,
            "interstitialComponent": null,
            "primaryActions": [],
            "entityCustomTrackingInfo": null,
            "badgeData": null,
            "title": {
                "textDirection": "USER_LOCALE",
                "text": "Medical Esoterics",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "overflowActions": [],
            "*lazyLoadedActions": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:65590919,COMPANIES,SEARCH_SRP)",
            "searchActionType": null,
            "actorInsights": [],
            "insightsResolutionResults": [],
            "badgeIcon": null,
            "entityUrn": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:65590919,SEARCH_SRP,DEFAULT)",
            "showAdditionalCluster": false,
            "ringStatus": null,
            "primarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "Medical Equipment Manufacturing • Brisbane, Queensland",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "badgeText": null,
            "trackingId": "e/dGEuXMTwOADGhFOtmlRg==",
            "summary": {
                "textDirection": "USER_LOCALE",
                "text": "A boutique medical and scientific distributor/agency for medical devices, capital equipment and consumables.",
                "attributesV2": [
                    {
                        "start": 11,
                        "length": 7,
                        "detailData": {
                            "jobPostingName": null,
                            "hyperlink": null,
                            "profileFamiliarName": null,
                            "color": null,
                            "companyName": null,
                            "icon": null,
                            "epoch": null,
                            "systemImage": null,
                            "textLink": null,
                            "listItemStyle": null,
                            "groupName": null,
                            "hyperlinkOpenExternally": null,
                            "listStyle": null,
                            "profileFullName": null,
                            "stringFieldReference": null,
                            "learningCourseName": null,
                            "profileMention": null,
                            "style": "BOLD",
                            "schoolName": null,
                            "hashtag": null
                        },
                        "$recipeTypes": [
                            "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                        ],
                        "$type": "com.linkedin.voyager.dash.common.text.TextAttribute"
                    },
                    {
                        "start": 57,
                        "length": 7,
                        "detailData": {
                            "jobPostingName": null,
                            "hyperlink": null,
                            "profileFamiliarName": null,
                            "color": null,
                            "companyName": null,
                            "icon": null,
                            "epoch": null,
                            "systemImage": null,
                            "textLink": null,
                            "listItemStyle": null,
                            "groupName": null,
                            "hyperlinkOpenExternally": null,
                            "listStyle": null,
                            "profileFullName": null,
                            "stringFieldReference": null,
                            "learningCourseName": null,
                            "profileMention": null,
                            "style": "BOLD",
                            "schoolName": null,
                            "hashtag": null
                        },
                        "$recipeTypes": [
                            "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                        ],
                        "$type": "com.linkedin.voyager.dash.common.text.TextAttribute"
                    }
                ],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "addEntityToSearchHistory": true,
            "actorNavigationUrl": null,
            "image": {
                "attributes": [
                    {
                        "scalingType": null,
                        "detailData": {
                            "profilePictureWithoutFrame": null,
                            "profilePictureWithRingStatus": null,
                            "companyLogo": null,
                            "icon": null,
                            "systemImage": null,
                            "nonEntityGroupLogo": null,
                            "vectorImage": null,
                            "nonEntityProfessionalEventLogo": null,
                            "profilePicture": null,
                            "imageUrl": null,
                            "professionalEventLogo": null,
                            "nonEntityCompanyLogo": {
                                "*company": "urn:li:fsd_company:65590919",
                                "$recipeTypes": [
                                    "com.linkedin.3be27b5a0eb7edd91e98b14c0290096c"
                                ],
                                "vectorImage": {
                                    "digitalmediaAsset": null,
                                    "attribution": null,
                                    "c2paManifestData": null,
                                    "$recipeTypes": [
                                        "com.linkedin.28db8575bcf1c65bdc4bc15948d50ee9"
                                    ],
                                    "artifacts": [
                                        {
                                            "width": 100,
                                            "$recipeTypes": [
                                                "com.linkedin.f0f435b4425ee2990eba8f0a4d614944"
                                            ],
                                            "fileIdentifyingUrlPathSegment": "https://media.licdn.com/dms/image/v2/C560BAQHo1e8Sj58eqw/company-logo_100_100/company-logo_100_100/0/1630639070083/medical_esoterics_logo?e=1769644800&v=beta&t=3IXGXJXWyJ2JYSZNvTkf4qEzF390CXYQsHmTf7ZNeUQ",
                                            "expiresAt": 1769644800000,
                                            "height": 100,
                                            "$type": "com.linkedin.common.VectorArtifact"
                                        }
                                    ],
                                    "rootUrl": "",
                                    "$type": "com.linkedin.common.VectorImage"
                                },
                                "$type": "com.linkedin.voyager.dash.common.image.NonEntityCompanyLogo"
                            },
                            "nonEntitySchoolLogo": null,
                            "groupLogo": null,
                            "schoolLogo": null,
                            "ghostImage": null,
                            "nonEntityProfilePicture": null
                        },
                        "tintColor": null,
                        "$recipeTypes": [
                            "com.linkedin.eb94fbb1518f790c4545aafdf571c64e"
                        ],
                        "tapTargets": [],
                        "displayAspectRatio": null,
                        "$type": "com.linkedin.voyager.dash.common.image.ImageAttribute"
                    }
                ],
                "editableAccessibilityText": false,
                "actionTarget": null,
                "accessibilityTextAttributes": [],
                "totalCount": null,
                "accessibilityText": "Medical Esoterics",
                "$recipeTypes": [
                    "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                ],
                "$type": "com.linkedin.voyager.dash.common.image.ImageViewModel"
            },
            "secondarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "43 followers",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "navigationUrl": "https://www.linkedin.com/company/medical-esoterics/",
            "entityEmbeddedObject": null,
            "unreadIndicatorDetails": null,
            "$recipeTypes": [
                "com.linkedin.cf4b25c18907ea8eafe915c8bfa24109"
            ],
            "target": null,
            "$type": "com.linkedin.voyager.dash.search.EntityResultViewModel",
            "actorTrackingUrn": null,
            "navigationContext": {
                "openExternally": false,
                "$recipeTypes": [
                    "com.linkedin.55ee9afd4182671fe7e271f615659525"
                ],
                "url": "https://www.linkedin.com/company/medical-esoterics/",
                "$type": "com.linkedin.voyager.dash.search.NavigationContext"
            }
        },
        {
            "template": "UNIVERSAL",
            "actorNavigationContext": null,
            "bserpEntityNavigationalUrl": "https://www.linkedin.com/search/results/all/?keywords=Medical%20First%20Group&origin=ENTITY_SEARCH_HOME_HISTORY&heroEntityKey=urn%3Ali%3Aorganization%3A74355062",
            "trackingUrn": "urn:li:company:74355062",
            "controlName": null,
            "interstitialComponent": null,
            "primaryActions": [],
            "entityCustomTrackingInfo": null,
            "badgeData": null,
            "title": {
                "textDirection": "USER_LOCALE",
                "text": "Medical First Group",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "overflowActions": [],
            "*lazyLoadedActions": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:74355062,COMPANIES,SEARCH_SRP)",
            "searchActionType": null,
            "actorInsights": [],
            "insightsResolutionResults": [],
            "badgeIcon": null,
            "entityUrn": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:74355062,SEARCH_SRP,DEFAULT)",
            "showAdditionalCluster": false,
            "ringStatus": null,
            "primarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "Medical Practices • Narre Warren, Victoria",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "badgeText": null,
            "trackingId": "UcELq4/XR5iem5vsEQupWw==",
            "summary": {
                "textDirection": "USER_LOCALE",
                "text": "A primary healthcare network, bringing resources to the local family practice. Good Medicine, Great Future.",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "addEntityToSearchHistory": true,
            "actorNavigationUrl": null,
            "image": {
                "attributes": [
                    {
                        "scalingType": null,
                        "detailData": {
                            "profilePictureWithoutFrame": null,
                            "profilePictureWithRingStatus": null,
                            "companyLogo": null,
                            "icon": null,
                            "systemImage": null,
                            "nonEntityGroupLogo": null,
                            "vectorImage": null,
                            "nonEntityProfessionalEventLogo": null,
                            "profilePicture": null,
                            "imageUrl": null,
                            "professionalEventLogo": null,
                            "nonEntityCompanyLogo": {
                                "*company": "urn:li:fsd_company:74355062",
                                "$recipeTypes": [
                                    "com.linkedin.3be27b5a0eb7edd91e98b14c0290096c"
                                ],
                                "vectorImage": {
                                    "digitalmediaAsset": null,
                                    "attribution": null,
                                    "c2paManifestData": null,
                                    "$recipeTypes": [
                                        "com.linkedin.28db8575bcf1c65bdc4bc15948d50ee9"
                                    ],
                                    "artifacts": [
                                        {
                                            "width": 100,
                                            "$recipeTypes": [
                                                "com.linkedin.f0f435b4425ee2990eba8f0a4d614944"
                                            ],
                                            "fileIdentifyingUrlPathSegment": "https://media.licdn.com/dms/image/v2/C560BAQH9yiBtGs1cEg/company-logo_100_100/company-logo_100_100/0/1668650628159/medical_first_group_logo?e=1769644800&v=beta&t=CjHVQLGd4-6wavcNJ3ocf6VxVqOy48jMk6MvhV-PPr4",
                                            "expiresAt": 1769644800000,
                                            "height": 100,
                                            "$type": "com.linkedin.common.VectorArtifact"
                                        }
                                    ],
                                    "rootUrl": "",
                                    "$type": "com.linkedin.common.VectorImage"
                                },
                                "$type": "com.linkedin.voyager.dash.common.image.NonEntityCompanyLogo"
                            },
                            "nonEntitySchoolLogo": null,
                            "groupLogo": null,
                            "schoolLogo": null,
                            "ghostImage": null,
                            "nonEntityProfilePicture": null
                        },
                        "tintColor": null,
                        "$recipeTypes": [
                            "com.linkedin.eb94fbb1518f790c4545aafdf571c64e"
                        ],
                        "tapTargets": [],
                        "displayAspectRatio": null,
                        "$type": "com.linkedin.voyager.dash.common.image.ImageAttribute"
                    }
                ],
                "editableAccessibilityText": false,
                "actionTarget": null,
                "accessibilityTextAttributes": [],
                "totalCount": null,
                "accessibilityText": "Medical First Group",
                "$recipeTypes": [
                    "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                ],
                "$type": "com.linkedin.voyager.dash.common.image.ImageViewModel"
            },
            "secondarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "447 followers",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "navigationUrl": "https://www.linkedin.com/company/medical-first-group/",
            "entityEmbeddedObject": null,
            "unreadIndicatorDetails": null,
            "$recipeTypes": [
                "com.linkedin.cf4b25c18907ea8eafe915c8bfa24109"
            ],
            "target": null,
            "$type": "com.linkedin.voyager.dash.search.EntityResultViewModel",
            "actorTrackingUrn": null,
            "navigationContext": {
                "openExternally": false,
                "$recipeTypes": [
                    "com.linkedin.55ee9afd4182671fe7e271f615659525"
                ],
                "url": "https://www.linkedin.com/company/medical-first-group/",
                "$type": "com.linkedin.voyager.dash.search.NavigationContext"
            }
        },
        {
            "template": "UNIVERSAL",
            "actorNavigationContext": null,
            "bserpEntityNavigationalUrl": "https://www.linkedin.com/search/results/all/?keywords=Medical%20Learning%20Journeys&origin=ENTITY_SEARCH_HOME_HISTORY&heroEntityKey=urn%3Ali%3Aorganization%3A104377301",
            "trackingUrn": "urn:li:company:104377301",
            "controlName": null,
            "interstitialComponent": null,
            "primaryActions": [],
            "entityCustomTrackingInfo": null,
            "badgeData": null,
            "title": {
                "textDirection": "USER_LOCALE",
                "text": "Medical Learning Journeys",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "overflowActions": [],
            "*lazyLoadedActions": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:104377301,COMPANIES,SEARCH_SRP)",
            "searchActionType": null,
            "actorInsights": [],
            "insightsResolutionResults": [],
            "badgeIcon": null,
            "entityUrn": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:104377301,SEARCH_SRP,DEFAULT)",
            "showAdditionalCluster": false,
            "ringStatus": null,
            "primarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "Medical Practices • MacKay, Hamilton Island",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "badgeText": null,
            "trackingId": "F9D2WZLsQ3ezN+xXFRXS1g==",
            "summary": {
                "textDirection": "USER_LOCALE",
                "text": "GPs earn vital CPD points in paradise while honouring their need to relax and restore.",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "addEntityToSearchHistory": true,
            "actorNavigationUrl": null,
            "image": {
                "attributes": [
                    {
                        "scalingType": null,
                        "detailData": {
                            "profilePictureWithoutFrame": null,
                            "profilePictureWithRingStatus": null,
                            "companyLogo": null,
                            "icon": null,
                            "systemImage": null,
                            "nonEntityGroupLogo": null,
                            "vectorImage": null,
                            "nonEntityProfessionalEventLogo": null,
                            "profilePicture": null,
                            "imageUrl": null,
                            "professionalEventLogo": null,
                            "nonEntityCompanyLogo": {
                                "*company": "urn:li:fsd_company:104377301",
                                "$recipeTypes": [
                                    "com.linkedin.3be27b5a0eb7edd91e98b14c0290096c"
                                ],
                                "vectorImage": {
                                    "digitalmediaAsset": null,
                                    "attribution": null,
                                    "c2paManifestData": null,
                                    "$recipeTypes": [
                                        "com.linkedin.28db8575bcf1c65bdc4bc15948d50ee9"
                                    ],
                                    "artifacts": [
                                        {
                                            "width": 100,
                                            "$recipeTypes": [
                                                "com.linkedin.f0f435b4425ee2990eba8f0a4d614944"
                                            ],
                                            "fileIdentifyingUrlPathSegment": "https://media.licdn.com/dms/image/v2/D560BAQFchwgt1RI1kg/company-logo_100_100/company-logo_100_100/0/1724253050441?e=1769644800&v=beta&t=hHu4B3qc_4cn4Uc3_LJg3BcdWrftUu1bvltHHdNHylU",
                                            "expiresAt": 1769644800000,
                                            "height": 100,
                                            "$type": "com.linkedin.common.VectorArtifact"
                                        }
                                    ],
                                    "rootUrl": "",
                                    "$type": "com.linkedin.common.VectorImage"
                                },
                                "$type": "com.linkedin.voyager.dash.common.image.NonEntityCompanyLogo"
                            },
                            "nonEntitySchoolLogo": null,
                            "groupLogo": null,
                            "schoolLogo": null,
                            "ghostImage": null,
                            "nonEntityProfilePicture": null
                        },
                        "tintColor": null,
                        "$recipeTypes": [
                            "com.linkedin.eb94fbb1518f790c4545aafdf571c64e"
                        ],
                        "tapTargets": [],
                        "displayAspectRatio": null,
                        "$type": "com.linkedin.voyager.dash.common.image.ImageAttribute"
                    }
                ],
                "editableAccessibilityText": false,
                "actionTarget": null,
                "accessibilityTextAttributes": [],
                "totalCount": null,
                "accessibilityText": "Medical Learning Journeys",
                "$recipeTypes": [
                    "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                ],
                "$type": "com.linkedin.voyager.dash.common.image.ImageViewModel"
            },
            "secondarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "368 followers",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "navigationUrl": "https://www.linkedin.com/company/medical-learning-journeys/",
            "entityEmbeddedObject": null,
            "unreadIndicatorDetails": null,
            "$recipeTypes": [
                "com.linkedin.cf4b25c18907ea8eafe915c8bfa24109"
            ],
            "target": null,
            "$type": "com.linkedin.voyager.dash.search.EntityResultViewModel",
            "actorTrackingUrn": null,
            "navigationContext": {
                "openExternally": false,
                "$recipeTypes": [
                    "com.linkedin.55ee9afd4182671fe7e271f615659525"
                ],
                "url": "https://www.linkedin.com/company/medical-learning-journeys/",
                "$type": "com.linkedin.voyager.dash.search.NavigationContext"
            }
        },
        {
            "template": "UNIVERSAL",
            "actorNavigationContext": null,
            "bserpEntityNavigationalUrl": "https://www.linkedin.com/search/results/all/?keywords=Medical%20Accessories%20of%20Australia%20-%20brand%20owner%20of%20Orthobrace%20Bracing%20%26%20Supports%20products&origin=ENTITY_SEARCH_HOME_HISTORY&heroEntityKey=urn%3Ali%3Aorganization%3A7627848",
            "trackingUrn": "urn:li:company:7627848",
            "controlName": null,
            "interstitialComponent": null,
            "primaryActions": [],
            "entityCustomTrackingInfo": null,
            "badgeData": null,
            "title": {
                "textDirection": "USER_LOCALE",
                "text": "Medical Accessories of Australia - brand owner of Orthobrace Bracing & Supports products",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "overflowActions": [],
            "*lazyLoadedActions": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:7627848,COMPANIES,SEARCH_SRP)",
            "searchActionType": null,
            "actorInsights": [],
            "insightsResolutionResults": [],
            "badgeIcon": null,
            "entityUrn": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:7627848,SEARCH_SRP,DEFAULT)",
            "showAdditionalCluster": false,
            "ringStatus": null,
            "primarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "Medical Device • Milton, Queensland",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "badgeText": null,
            "trackingId": "w4Vr3BSWS76IaKrd+aslJg==",
            "summary": {
                "textDirection": "USER_LOCALE",
                "text": "Medical Accessories of Australia is an industry leading healthcare supplier. We are specialist in compression stockings, lymphoedema garments, orthopaedic bracing and supports, cosmetic and maternity garments.  Medical Accessories of Australia provides an extensive product range, catering for many healthcare needs...",
                "attributesV2": [
                    {
                        "start": 0,
                        "length": 7,
                        "detailData": {
                            "jobPostingName": null,
                            "hyperlink": null,
                            "profileFamiliarName": null,
                            "color": null,
                            "companyName": null,
                            "icon": null,
                            "epoch": null,
                            "systemImage": null,
                            "textLink": null,
                            "listItemStyle": null,
                            "groupName": null,
                            "hyperlinkOpenExternally": null,
                            "listStyle": null,
                            "profileFullName": null,
                            "stringFieldReference": null,
                            "learningCourseName": null,
                            "profileMention": null,
                            "style": "BOLD",
                            "schoolName": null,
                            "hashtag": null
                        },
                        "$recipeTypes": [
                            "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                        ],
                        "$type": "com.linkedin.voyager.dash.common.text.TextAttribute"
                    },
                    {
                        "start": 211,
                        "length": 7,
                        "detailData": {
                            "jobPostingName": null,
                            "hyperlink": null,
                            "profileFamiliarName": null,
                            "color": null,
                            "companyName": null,
                            "icon": null,
                            "epoch": null,
                            "systemImage": null,
                            "textLink": null,
                            "listItemStyle": null,
                            "groupName": null,
                            "hyperlinkOpenExternally": null,
                            "listStyle": null,
                            "profileFullName": null,
                            "stringFieldReference": null,
                            "learningCourseName": null,
                            "profileMention": null,
                            "style": "BOLD",
                            "schoolName": null,
                            "hashtag": null
                        },
                        "$recipeTypes": [
                            "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                        ],
                        "$type": "com.linkedin.voyager.dash.common.text.TextAttribute"
                    }
                ],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "addEntityToSearchHistory": true,
            "actorNavigationUrl": null,
            "image": {
                "attributes": [
                    {
                        "scalingType": null,
                        "detailData": {
                            "profilePictureWithoutFrame": null,
                            "profilePictureWithRingStatus": null,
                            "companyLogo": null,
                            "icon": null,
                            "systemImage": null,
                            "nonEntityGroupLogo": null,
                            "vectorImage": null,
                            "nonEntityProfessionalEventLogo": null,
                            "profilePicture": null,
                            "imageUrl": null,
                            "professionalEventLogo": null,
                            "nonEntityCompanyLogo": {
                                "*company": "urn:li:fsd_company:7627848",
                                "$recipeTypes": [
                                    "com.linkedin.3be27b5a0eb7edd91e98b14c0290096c"
                                ],
                                "vectorImage": {
                                    "digitalmediaAsset": null,
                                    "attribution": null,
                                    "c2paManifestData": null,
                                    "$recipeTypes": [
                                        "com.linkedin.28db8575bcf1c65bdc4bc15948d50ee9"
                                    ],
                                    "artifacts": [
                                        {
                                            "width": 100,
                                            "$recipeTypes": [
                                                "com.linkedin.f0f435b4425ee2990eba8f0a4d614944"
                                            ],
                                            "fileIdentifyingUrlPathSegment": "https://media.licdn.com/dms/image/v2/C4E0BAQEaMYVlyJ2mUQ/company-logo_100_100/company-logo_100_100/0/1660788543023/medical_accessories_of_australia_logo?e=1769644800&v=beta&t=gnUj9bns2giiAJill2X2VNwAiqE-1l7-863NLXK-TBk",
                                            "expiresAt": 1769644800000,
                                            "height": 100,
                                            "$type": "com.linkedin.common.VectorArtifact"
                                        }
                                    ],
                                    "rootUrl": "",
                                    "$type": "com.linkedin.common.VectorImage"
                                },
                                "$type": "com.linkedin.voyager.dash.common.image.NonEntityCompanyLogo"
                            },
                            "nonEntitySchoolLogo": null,
                            "groupLogo": null,
                            "schoolLogo": null,
                            "ghostImage": null,
                            "nonEntityProfilePicture": null
                        },
                        "tintColor": null,
                        "$recipeTypes": [
                            "com.linkedin.eb94fbb1518f790c4545aafdf571c64e"
                        ],
                        "tapTargets": [],
                        "displayAspectRatio": null,
                        "$type": "com.linkedin.voyager.dash.common.image.ImageAttribute"
                    }
                ],
                "editableAccessibilityText": false,
                "actionTarget": null,
                "accessibilityTextAttributes": [],
                "totalCount": null,
                "accessibilityText": "Medical Accessories of Australia - brand owner of Orthobrace Bracing & Supports products",
                "$recipeTypes": [
                    "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                ],
                "$type": "com.linkedin.voyager.dash.common.image.ImageViewModel"
            },
            "secondarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "76 followers",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "navigationUrl": "https://www.linkedin.com/company/medical-accessories-of-australia/",
            "entityEmbeddedObject": null,
            "unreadIndicatorDetails": null,
            "$recipeTypes": [
                "com.linkedin.cf4b25c18907ea8eafe915c8bfa24109"
            ],
            "target": null,
            "$type": "com.linkedin.voyager.dash.search.EntityResultViewModel",
            "actorTrackingUrn": null,
            "navigationContext": {
                "openExternally": false,
                "$recipeTypes": [
                    "com.linkedin.55ee9afd4182671fe7e271f615659525"
                ],
                "url": "https://www.linkedin.com/company/medical-accessories-of-australia/",
                "$type": "com.linkedin.voyager.dash.search.NavigationContext"
            }
        },
        {
            "template": "UNIVERSAL",
            "actorNavigationContext": null,
            "bserpEntityNavigationalUrl": "https://www.linkedin.com/search/results/all/?keywords=Medical%20on%20Miami&origin=ENTITY_SEARCH_HOME_HISTORY&heroEntityKey=urn%3Ali%3Aorganization%3A14381845",
            "trackingUrn": "urn:li:company:14381845",
            "controlName": null,
            "interstitialComponent": null,
            "primaryActions": [],
            "entityCustomTrackingInfo": null,
            "badgeData": null,
            "title": {
                "textDirection": "USER_LOCALE",
                "text": "Medical on Miami",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "overflowActions": [],
            "*lazyLoadedActions": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:14381845,COMPANIES,SEARCH_SRP)",
            "searchActionType": null,
            "actorInsights": [],
            "insightsResolutionResults": [],
            "badgeIcon": null,
            "entityUrn": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:14381845,SEARCH_SRP,DEFAULT)",
            "showAdditionalCluster": false,
            "ringStatus": null,
            "primarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "Medical Practices • Miami, Queensland",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "badgeText": null,
            "trackingId": "yd2yrmBsReaybZ9XS/ekXA==",
            "summary": {
                "textDirection": "USER_LOCALE",
                "text": "Our team at Medical On Miami are dedicated to providing our community with the highest level of healthcare.",
                "attributesV2": [
                    {
                        "start": 12,
                        "length": 7,
                        "detailData": {
                            "jobPostingName": null,
                            "hyperlink": null,
                            "profileFamiliarName": null,
                            "color": null,
                            "companyName": null,
                            "icon": null,
                            "epoch": null,
                            "systemImage": null,
                            "textLink": null,
                            "listItemStyle": null,
                            "groupName": null,
                            "hyperlinkOpenExternally": null,
                            "listStyle": null,
                            "profileFullName": null,
                            "stringFieldReference": null,
                            "learningCourseName": null,
                            "profileMention": null,
                            "style": "BOLD",
                            "schoolName": null,
                            "hashtag": null
                        },
                        "$recipeTypes": [
                            "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                        ],
                        "$type": "com.linkedin.voyager.dash.common.text.TextAttribute"
                    }
                ],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "addEntityToSearchHistory": true,
            "actorNavigationUrl": null,
            "image": {
                "attributes": [
                    {
                        "scalingType": null,
                        "detailData": {
                            "profilePictureWithoutFrame": null,
                            "profilePictureWithRingStatus": null,
                            "companyLogo": null,
                            "icon": null,
                            "systemImage": null,
                            "nonEntityGroupLogo": null,
                            "vectorImage": null,
                            "nonEntityProfessionalEventLogo": null,
                            "profilePicture": null,
                            "imageUrl": null,
                            "professionalEventLogo": null,
                            "nonEntityCompanyLogo": {
                                "*company": "urn:li:fsd_company:14381845",
                                "$recipeTypes": [
                                    "com.linkedin.3be27b5a0eb7edd91e98b14c0290096c"
                                ],
                                "vectorImage": {
                                    "digitalmediaAsset": null,
                                    "attribution": null,
                                    "c2paManifestData": null,
                                    "$recipeTypes": [
                                        "com.linkedin.28db8575bcf1c65bdc4bc15948d50ee9"
                                    ],
                                    "artifacts": [
                                        {
                                            "width": 100,
                                            "$recipeTypes": [
                                                "com.linkedin.f0f435b4425ee2990eba8f0a4d614944"
                                            ],
                                            "fileIdentifyingUrlPathSegment": "https://media.licdn.com/dms/image/v2/C4E0BAQH9FBs8eXBMdw/company-logo_100_100/company-logo_100_100/0/1630604665623?e=1769644800&v=beta&t=MwUyJOegYw0GUXiL0ne4jmlz_5xuNc5rKXJDIxuP47A",
                                            "expiresAt": 1769644800000,
                                            "height": 100,
                                            "$type": "com.linkedin.common.VectorArtifact"
                                        }
                                    ],
                                    "rootUrl": "",
                                    "$type": "com.linkedin.common.VectorImage"
                                },
                                "$type": "com.linkedin.voyager.dash.common.image.NonEntityCompanyLogo"
                            },
                            "nonEntitySchoolLogo": null,
                            "groupLogo": null,
                            "schoolLogo": null,
                            "ghostImage": null,
                            "nonEntityProfilePicture": null
                        },
                        "tintColor": null,
                        "$recipeTypes": [
                            "com.linkedin.eb94fbb1518f790c4545aafdf571c64e"
                        ],
                        "tapTargets": [],
                        "displayAspectRatio": null,
                        "$type": "com.linkedin.voyager.dash.common.image.ImageAttribute"
                    }
                ],
                "editableAccessibilityText": false,
                "actionTarget": null,
                "accessibilityTextAttributes": [],
                "totalCount": null,
                "accessibilityText": "Medical on Miami",
                "$recipeTypes": [
                    "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                ],
                "$type": "com.linkedin.voyager.dash.common.image.ImageViewModel"
            },
            "secondarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "261 followers",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "navigationUrl": "https://www.linkedin.com/company/medical-on-miami/",
            "entityEmbeddedObject": null,
            "unreadIndicatorDetails": null,
            "$recipeTypes": [
                "com.linkedin.cf4b25c18907ea8eafe915c8bfa24109"
            ],
            "target": null,
            "$type": "com.linkedin.voyager.dash.search.EntityResultViewModel",
            "actorTrackingUrn": null,
            "navigationContext": {
                "openExternally": false,
                "$recipeTypes": [
                    "com.linkedin.55ee9afd4182671fe7e271f615659525"
                ],
                "url": "https://www.linkedin.com/company/medical-on-miami/",
                "$type": "com.linkedin.voyager.dash.search.NavigationContext"
            }
        },
        {
            "template": "UNIVERSAL",
            "actorNavigationContext": null,
            "bserpEntityNavigationalUrl": "https://www.linkedin.com/search/results/all/?keywords=Medical%20Career%20Planning&origin=ENTITY_SEARCH_HOME_HISTORY&heroEntityKey=urn%3Ali%3Aorganization%3A7603629",
            "trackingUrn": "urn:li:company:7603629",
            "controlName": null,
            "interstitialComponent": null,
            "primaryActions": [],
            "entityCustomTrackingInfo": null,
            "badgeData": null,
            "title": {
                "textDirection": "USER_LOCALE",
                "text": "Medical Career Planning",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "overflowActions": [],
            "*lazyLoadedActions": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:7603629,COMPANIES,SEARCH_SRP)",
            "searchActionType": null,
            "actorInsights": [],
            "insightsResolutionResults": [],
            "badgeIcon": null,
            "entityUrn": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:7603629,SEARCH_SRP,DEFAULT)",
            "showAdditionalCluster": false,
            "ringStatus": null,
            "primarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "Medical Practices • Townsville",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "badgeText": null,
            "trackingId": "UvOWaPV5T/+KclBGdFK/cw==",
            "summary": {
                "textDirection": "USER_LOCALE",
                "text": "Are you looking for Medical Career Advice?  Medical Career Planning will assist you to create solutions.  Medical Career Planning is a career planning service to assist doctors and medical students to create a fulfilling career.  Medicine is a lifelong journey with the potential to be a very fulfilling career...",
                "attributesV2": [
                    {
                        "start": 20,
                        "length": 7,
                        "detailData": {
                            "jobPostingName": null,
                            "hyperlink": null,
                            "profileFamiliarName": null,
                            "color": null,
                            "companyName": null,
                            "icon": null,
                            "epoch": null,
                            "systemImage": null,
                            "textLink": null,
                            "listItemStyle": null,
                            "groupName": null,
                            "hyperlinkOpenExternally": null,
                            "listStyle": null,
                            "profileFullName": null,
                            "stringFieldReference": null,
                            "learningCourseName": null,
                            "profileMention": null,
                            "style": "BOLD",
                            "schoolName": null,
                            "hashtag": null
                        },
                        "$recipeTypes": [
                            "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                        ],
                        "$type": "com.linkedin.voyager.dash.common.text.TextAttribute"
                    },
                    {
                        "start": 44,
                        "length": 7,
                        "detailData": {
                            "jobPostingName": null,
                            "hyperlink": null,
                            "profileFamiliarName": null,
                            "color": null,
                            "companyName": null,
                            "icon": null,
                            "epoch": null,
                            "systemImage": null,
                            "textLink": null,
                            "listItemStyle": null,
                            "groupName": null,
                            "hyperlinkOpenExternally": null,
                            "listStyle": null,
                            "profileFullName": null,
                            "stringFieldReference": null,
                            "learningCourseName": null,
                            "profileMention": null,
                            "style": "BOLD",
                            "schoolName": null,
                            "hashtag": null
                        },
                        "$recipeTypes": [
                            "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                        ],
                        "$type": "com.linkedin.voyager.dash.common.text.TextAttribute"
                    },
                    {
                        "start": 106,
                        "length": 7,
                        "detailData": {
                            "jobPostingName": null,
                            "hyperlink": null,
                            "profileFamiliarName": null,
                            "color": null,
                            "companyName": null,
                            "icon": null,
                            "epoch": null,
                            "systemImage": null,
                            "textLink": null,
                            "listItemStyle": null,
                            "groupName": null,
                            "hyperlinkOpenExternally": null,
                            "listStyle": null,
                            "profileFullName": null,
                            "stringFieldReference": null,
                            "learningCourseName": null,
                            "profileMention": null,
                            "style": "BOLD",
                            "schoolName": null,
                            "hashtag": null
                        },
                        "$recipeTypes": [
                            "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                        ],
                        "$type": "com.linkedin.voyager.dash.common.text.TextAttribute"
                    },
                    {
                        "start": 181,
                        "length": 7,
                        "detailData": {
                            "jobPostingName": null,
                            "hyperlink": null,
                            "profileFamiliarName": null,
                            "color": null,
                            "companyName": null,
                            "icon": null,
                            "epoch": null,
                            "systemImage": null,
                            "textLink": null,
                            "listItemStyle": null,
                            "groupName": null,
                            "hyperlinkOpenExternally": null,
                            "listStyle": null,
                            "profileFullName": null,
                            "stringFieldReference": null,
                            "learningCourseName": null,
                            "profileMention": null,
                            "style": "BOLD",
                            "schoolName": null,
                            "hashtag": null
                        },
                        "$recipeTypes": [
                            "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                        ],
                        "$type": "com.linkedin.voyager.dash.common.text.TextAttribute"
                    }
                ],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "addEntityToSearchHistory": true,
            "actorNavigationUrl": null,
            "image": {
                "attributes": [
                    {
                        "scalingType": null,
                        "detailData": {
                            "profilePictureWithoutFrame": null,
                            "profilePictureWithRingStatus": null,
                            "companyLogo": null,
                            "icon": null,
                            "systemImage": null,
                            "nonEntityGroupLogo": null,
                            "vectorImage": null,
                            "nonEntityProfessionalEventLogo": null,
                            "profilePicture": null,
                            "imageUrl": null,
                            "professionalEventLogo": null,
                            "nonEntityCompanyLogo": {
                                "*company": "urn:li:fsd_company:7603629",
                                "$recipeTypes": [
                                    "com.linkedin.3be27b5a0eb7edd91e98b14c0290096c"
                                ],
                                "vectorImage": {
                                    "digitalmediaAsset": null,
                                    "attribution": null,
                                    "c2paManifestData": null,
                                    "$recipeTypes": [
                                        "com.linkedin.28db8575bcf1c65bdc4bc15948d50ee9"
                                    ],
                                    "artifacts": [
                                        {
                                            "width": 100,
                                            "$recipeTypes": [
                                                "com.linkedin.f0f435b4425ee2990eba8f0a4d614944"
                                            ],
                                            "fileIdentifyingUrlPathSegment": "https://media.licdn.com/dms/image/v2/C560BAQER2_rwXMlF2w/company-logo_100_100/company-logo_100_100/0/1631340377124?e=1769644800&v=beta&t=-txxymvOL7YwvGakxreDzCr9z4SMgpZsGNiE1tDVmf8",
                                            "expiresAt": 1769644800000,
                                            "height": 100,
                                            "$type": "com.linkedin.common.VectorArtifact"
                                        }
                                    ],
                                    "rootUrl": "",
                                    "$type": "com.linkedin.common.VectorImage"
                                },
                                "$type": "com.linkedin.voyager.dash.common.image.NonEntityCompanyLogo"
                            },
                            "nonEntitySchoolLogo": null,
                            "groupLogo": null,
                            "schoolLogo": null,
                            "ghostImage": null,
                            "nonEntityProfilePicture": null
                        },
                        "tintColor": null,
                        "$recipeTypes": [
                            "com.linkedin.eb94fbb1518f790c4545aafdf571c64e"
                        ],
                        "tapTargets": [],
                        "displayAspectRatio": null,
                        "$type": "com.linkedin.voyager.dash.common.image.ImageAttribute"
                    }
                ],
                "editableAccessibilityText": false,
                "actionTarget": null,
                "accessibilityTextAttributes": [],
                "totalCount": null,
                "accessibilityText": "Medical Career Planning",
                "$recipeTypes": [
                    "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                ],
                "$type": "com.linkedin.voyager.dash.common.image.ImageViewModel"
            },
            "secondarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "169 followers",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "navigationUrl": "https://www.linkedin.com/company/medical-career-planning/",
            "entityEmbeddedObject": null,
            "unreadIndicatorDetails": null,
            "$recipeTypes": [
                "com.linkedin.cf4b25c18907ea8eafe915c8bfa24109"
            ],
            "target": null,
            "$type": "com.linkedin.voyager.dash.search.EntityResultViewModel",
            "actorTrackingUrn": null,
            "navigationContext": {
                "openExternally": false,
                "$recipeTypes": [
                    "com.linkedin.55ee9afd4182671fe7e271f615659525"
                ],
                "url": "https://www.linkedin.com/company/medical-career-planning/",
                "$type": "com.linkedin.voyager.dash.search.NavigationContext"
            }
        },
        {
            "template": "UNIVERSAL",
            "actorNavigationContext": null,
            "bserpEntityNavigationalUrl": "https://www.linkedin.com/search/results/all/?keywords=Medical%20Resale%20International&origin=ENTITY_SEARCH_HOME_HISTORY&heroEntityKey=urn%3Ali%3Aorganization%3A10233669",
            "trackingUrn": "urn:li:company:10233669",
            "controlName": null,
            "interstitialComponent": null,
            "primaryActions": [],
            "entityCustomTrackingInfo": null,
            "badgeData": null,
            "title": {
                "textDirection": "USER_LOCALE",
                "text": "Medical Resale International",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "overflowActions": [],
            "*lazyLoadedActions": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:10233669,COMPANIES,SEARCH_SRP)",
            "searchActionType": null,
            "actorInsights": [],
            "insightsResolutionResults": [],
            "badgeIcon": null,
            "entityUrn": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:10233669,SEARCH_SRP,DEFAULT)",
            "showAdditionalCluster": false,
            "ringStatus": null,
            "primarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "Medical Equipment Manufacturing • Auckland, New Zealand",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "badgeText": null,
            "trackingId": "+5t9e+oGSnqSbRwTncVBwA==",
            "summary": {
                "textDirection": "USER_LOCALE",
                "text": "Medical Resale International are used medical equipment management specialists with over 30 years industry experience.  We have offices in New Zealand & Australia.   Medical Resale International currently provides exclusive equipment management solutions to over 200 Healthcare institutions worldwide.  Our team...",
                "attributesV2": [
                    {
                        "start": 0,
                        "length": 7,
                        "detailData": {
                            "jobPostingName": null,
                            "hyperlink": null,
                            "profileFamiliarName": null,
                            "color": null,
                            "companyName": null,
                            "icon": null,
                            "epoch": null,
                            "systemImage": null,
                            "textLink": null,
                            "listItemStyle": null,
                            "groupName": null,
                            "hyperlinkOpenExternally": null,
                            "listStyle": null,
                            "profileFullName": null,
                            "stringFieldReference": null,
                            "learningCourseName": null,
                            "profileMention": null,
                            "style": "BOLD",
                            "schoolName": null,
                            "hashtag": null
                        },
                        "$recipeTypes": [
                            "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                        ],
                        "$type": "com.linkedin.voyager.dash.common.text.TextAttribute"
                    },
                    {
                        "start": 38,
                        "length": 7,
                        "detailData": {
                            "jobPostingName": null,
                            "hyperlink": null,
                            "profileFamiliarName": null,
                            "color": null,
                            "companyName": null,
                            "icon": null,
                            "epoch": null,
                            "systemImage": null,
                            "textLink": null,
                            "listItemStyle": null,
                            "groupName": null,
                            "hyperlinkOpenExternally": null,
                            "listStyle": null,
                            "profileFullName": null,
                            "stringFieldReference": null,
                            "learningCourseName": null,
                            "profileMention": null,
                            "style": "BOLD",
                            "schoolName": null,
                            "hashtag": null
                        },
                        "$recipeTypes": [
                            "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                        ],
                        "$type": "com.linkedin.voyager.dash.common.text.TextAttribute"
                    },
                    {
                        "start": 166,
                        "length": 7,
                        "detailData": {
                            "jobPostingName": null,
                            "hyperlink": null,
                            "profileFamiliarName": null,
                            "color": null,
                            "companyName": null,
                            "icon": null,
                            "epoch": null,
                            "systemImage": null,
                            "textLink": null,
                            "listItemStyle": null,
                            "groupName": null,
                            "hyperlinkOpenExternally": null,
                            "listStyle": null,
                            "profileFullName": null,
                            "stringFieldReference": null,
                            "learningCourseName": null,
                            "profileMention": null,
                            "style": "BOLD",
                            "schoolName": null,
                            "hashtag": null
                        },
                        "$recipeTypes": [
                            "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                        ],
                        "$type": "com.linkedin.voyager.dash.common.text.TextAttribute"
                    }
                ],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "addEntityToSearchHistory": true,
            "actorNavigationUrl": null,
            "image": {
                "attributes": [
                    {
                        "scalingType": null,
                        "detailData": {
                            "profilePictureWithoutFrame": null,
                            "profilePictureWithRingStatus": null,
                            "companyLogo": null,
                            "icon": null,
                            "systemImage": null,
                            "nonEntityGroupLogo": null,
                            "vectorImage": null,
                            "nonEntityProfessionalEventLogo": null,
                            "profilePicture": null,
                            "imageUrl": null,
                            "professionalEventLogo": null,
                            "nonEntityCompanyLogo": {
                                "*company": "urn:li:fsd_company:10233669",
                                "$recipeTypes": [
                                    "com.linkedin.3be27b5a0eb7edd91e98b14c0290096c"
                                ],
                                "vectorImage": {
                                    "digitalmediaAsset": null,
                                    "attribution": null,
                                    "c2paManifestData": null,
                                    "$recipeTypes": [
                                        "com.linkedin.28db8575bcf1c65bdc4bc15948d50ee9"
                                    ],
                                    "artifacts": [
                                        {
                                            "width": 100,
                                            "$recipeTypes": [
                                                "com.linkedin.f0f435b4425ee2990eba8f0a4d614944"
                                            ],
                                            "fileIdentifyingUrlPathSegment": "https://media.licdn.com/dms/image/v2/C4E0BAQGdkK96ogy9AA/company-logo_100_100/company-logo_100_100/0/1631338734727?e=1769644800&v=beta&t=HELwWpmWTxLMhoSza_P3Nn7Yn-DK22wc26e7XNb7yTs",
                                            "expiresAt": 1769644800000,
                                            "height": 100,
                                            "$type": "com.linkedin.common.VectorArtifact"
                                        }
                                    ],
                                    "rootUrl": "",
                                    "$type": "com.linkedin.common.VectorImage"
                                },
                                "$type": "com.linkedin.voyager.dash.common.image.NonEntityCompanyLogo"
                            },
                            "nonEntitySchoolLogo": null,
                            "groupLogo": null,
                            "schoolLogo": null,
                            "ghostImage": null,
                            "nonEntityProfilePicture": null
                        },
                        "tintColor": null,
                        "$recipeTypes": [
                            "com.linkedin.eb94fbb1518f790c4545aafdf571c64e"
                        ],
                        "tapTargets": [],
                        "displayAspectRatio": null,
                        "$type": "com.linkedin.voyager.dash.common.image.ImageAttribute"
                    }
                ],
                "editableAccessibilityText": false,
                "actionTarget": null,
                "accessibilityTextAttributes": [],
                "totalCount": null,
                "accessibilityText": "Medical Resale International",
                "$recipeTypes": [
                    "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                ],
                "$type": "com.linkedin.voyager.dash.common.image.ImageViewModel"
            },
            "secondarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "88 followers",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "navigationUrl": "https://www.linkedin.com/company/medical-resale-international/",
            "entityEmbeddedObject": null,
            "unreadIndicatorDetails": null,
            "$recipeTypes": [
                "com.linkedin.cf4b25c18907ea8eafe915c8bfa24109"
            ],
            "target": null,
            "$type": "com.linkedin.voyager.dash.search.EntityResultViewModel",
            "actorTrackingUrn": null,
            "navigationContext": {
                "openExternally": false,
                "$recipeTypes": [
                    "com.linkedin.55ee9afd4182671fe7e271f615659525"
                ],
                "url": "https://www.linkedin.com/company/medical-resale-international/",
                "$type": "com.linkedin.voyager.dash.search.NavigationContext"
            }
        },
        {
            "entityUrn": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:28209,COMPANIES,SEARCH_SRP)",
            "$recipeTypes": [
                "com.linkedin.92ece182782ae4412e712925cd97f9fe"
            ],
            "$type": "com.linkedin.voyager.dash.search.LazyLoadedActions"
        },
        {
            "entityUrn": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:10233669,COMPANIES,SEARCH_SRP)",
            "$recipeTypes": [
                "com.linkedin.92ece182782ae4412e712925cd97f9fe"
            ],
            "$type": "com.linkedin.voyager.dash.search.LazyLoadedActions"
        },
        {
            "entityUrn": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:65590919,COMPANIES,SEARCH_SRP)",
            "$recipeTypes": [
                "com.linkedin.92ece182782ae4412e712925cd97f9fe"
            ],
            "$type": "com.linkedin.voyager.dash.search.LazyLoadedActions"
        },
        {
            "entityUrn": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:7603629,COMPANIES,SEARCH_SRP)",
            "$recipeTypes": [
                "com.linkedin.92ece182782ae4412e712925cd97f9fe"
            ],
            "$type": "com.linkedin.voyager.dash.search.LazyLoadedActions"
        },
        {
            "entityUrn": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:71056408,COMPANIES,SEARCH_SRP)",
            "$recipeTypes": [
                "com.linkedin.92ece182782ae4412e712925cd97f9fe"
            ],
            "$type": "com.linkedin.voyager.dash.search.LazyLoadedActions"
        },
        {
            "entityUrn": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:18174916,COMPANIES,SEARCH_SRP)",
            "$recipeTypes": [
                "com.linkedin.92ece182782ae4412e712925cd97f9fe"
            ],
            "$type": "com.linkedin.voyager.dash.search.LazyLoadedActions"
        },
        {
            "entityUrn": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:7627848,COMPANIES,SEARCH_SRP)",
            "$recipeTypes": [
                "com.linkedin.92ece182782ae4412e712925cd97f9fe"
            ],
            "$type": "com.linkedin.voyager.dash.search.LazyLoadedActions"
        },
        {
            "entityUrn": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:104377301,COMPANIES,SEARCH_SRP)",
            "$recipeTypes": [
                "com.linkedin.92ece182782ae4412e712925cd97f9fe"
            ],
            "$type": "com.linkedin.voyager.dash.search.LazyLoadedActions"
        },
        {
            "entityUrn": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:14381845,COMPANIES,SEARCH_SRP)",
            "$recipeTypes": [
                "com.linkedin.92ece182782ae4412e712925cd97f9fe"
            ],
            "$type": "com.linkedin.voyager.dash.search.LazyLoadedActions"
        },
        {
            "entityUrn": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:74355062,COMPANIES,SEARCH_SRP)",
            "$recipeTypes": [
                "com.linkedin.92ece182782ae4412e712925cd97f9fe"
            ],
            "$type": "com.linkedin.voyager.dash.search.LazyLoadedActions"
        }
    ]
},
    {
    "data": {
        "data": {
            "searchDashClustersByAll": {
                "metadata": {
                    "entityResultAttributes": null,
                    "bserpPaginationContext": null,
                    "totalResultCount": 5032,
                    "searchAlert": null,
                    "blockedQueryError": null,
                    "secondaryFilterCluster": null,
                    "$recipeTypes": [
                        "com.linkedin.dfce49e2c6bb412fb4161cbbc7190d0d"
                    ],
                    "lazyRightRail": null,
                    "queryType": null,
                    "$type": "com.linkedin.voyager.dash.search.SearchClusterCollectionMetadata",
                    "primaryResultType": "COMPANIES",
                    "paginationToken": null,
                    "primaryFilterCluster": null,
                    "blockedQuery": false,
                    "entityActionButtonStyle": null,
                    "searchId": "b186dbac-c048-479c-a1a6-3c709aa2164f",
                    "filterAppliedCount": 0,
                    "clusterTitleFontSize": null,
                    "simpleInsightAttributes": null,
                    "desktopNavigationPanelTrackingId": null,
                    "knowledgeCardRightRail": null
                },
                "paging": {
                    "count": 10,
                    "start": 20,
                    "total": 1000,
                    "$recipeTypes": [
                        "com.linkedin.81b214c2cdd4f02cdb7d827958d2f3a1"
                    ],
                    "$type": "com.linkedin.restli.common.CollectionMetadata"
                },
                "$recipeTypes": [
                    "com.linkedin.5f1d22f924ecb6a031ee124b8b767900"
                ],
                "elements": [
                    {
                        "image": null,
                        "quickFilterActions": [],
                        "clusterRenderType": "LIST",
                        "dismissable": false,
                        "totalResultCount": null,
                        "controlName": null,
                        "description": null,
                        "title": null,
                        "$recipeTypes": [
                            "com.linkedin.5c853aba2154c55483e72bf6cdfaaf3e"
                        ],
                        "$type": "com.linkedin.voyager.dash.search.SearchClusterViewModel",
                        "actionTypeName": null,
                        "navigationText": null,
                        "feature": null,
                        "navigationCardAction": null,
                        "position": 21,
                        "items": [
                            {
                                "item": {
                                    "entityResult": null,
                                    "cluster": null,
                                    "bannerCard": null,
                                    "searchAlert": null,
                                    "upsellSlot": null,
                                    "coachRealtimeResponse": null,
                                    "searchSuggestionCard": null,
                                    "coachPromptCluster": null,
                                    "feedbackCard": null,
                                    "knowledgeCardV2": null,
                                    "keywordsSuggestionCard": null,
                                    "queryClarificationCard": null,
                                    "topicalQuestionCard": null,
                                    "simpleTextV2": {
                                        "showDashes": false,
                                        "textAlignment": "LEFT",
                                        "numDashes": 0,
                                        "text": {
                                            "textDirection": "USER_LOCALE",
                                            "text": "About 5,000 results",
                                            "attributesV2": [],
                                            "accessibilityTextAttributesV2": [],
                                            "accessibilityText": null,
                                            "$recipeTypes": [
                                                "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                                            ],
                                            "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
                                        },
                                        "$recipeTypes": [
                                            "com.linkedin.5bbb553a55f0e4d13343716ac69b5f48"
                                        ],
                                        "renderStyle": "PLAIN",
                                        "$type": "com.linkedin.voyager.dash.search.SimpleText"
                                    },
                                    "promoCard": null,
                                    "searchFeedUpdate": null,
                                    "searchQuestionAndAnswerCard": null,
                                    "centeredText": null,
                                    "simpleImage": null
                                },
                                "position": 1,
                                "$recipeTypes": [
                                    "com.linkedin.edd11a570456ce19ca1f5ec3c9bb03c1"
                                ],
                                "$type": "com.linkedin.voyager.dash.search.SearchItem"
                            }
                        ],
                        "results": [],
                        "trackingId": "¢üUÌD\u000f@e® Â\u0007L0"
                    },
                    {
                        "image": null,
                        "quickFilterActions": [],
                        "clusterRenderType": "LIST",
                        "dismissable": false,
                        "totalResultCount": null,
                        "controlName": null,
                        "description": null,
                        "title": null,
                        "$recipeTypes": [
                            "com.linkedin.5c853aba2154c55483e72bf6cdfaaf3e"
                        ],
                        "$type": "com.linkedin.voyager.dash.search.SearchClusterViewModel",
                        "actionTypeName": null,
                        "navigationText": null,
                        "feature": null,
                        "navigationCardAction": null,
                        "position": 22,
                        "items": [
                            {
                                "item": {
                                    "cluster": null,
                                    "bannerCard": null,
                                    "searchAlert": null,
                                    "upsellSlot": null,
                                    "coachRealtimeResponse": null,
                                    "searchSuggestionCard": null,
                                    "coachPromptCluster": null,
                                    "feedbackCard": null,
                                    "knowledgeCardV2": null,
                                    "keywordsSuggestionCard": null,
                                    "queryClarificationCard": null,
                                    "topicalQuestionCard": null,
                                    "*entityResult": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:134456,SEARCH_SRP,DEFAULT)",
                                    "simpleTextV2": null,
                                    "promoCard": null,
                                    "searchFeedUpdate": null,
                                    "searchQuestionAndAnswerCard": null,
                                    "centeredText": null,
                                    "simpleImage": null
                                },
                                "position": 1,
                                "$recipeTypes": [
                                    "com.linkedin.edd11a570456ce19ca1f5ec3c9bb03c1"
                                ],
                                "$type": "com.linkedin.voyager.dash.search.SearchItem"
                            },
                            {
                                "item": {
                                    "cluster": null,
                                    "bannerCard": null,
                                    "searchAlert": null,
                                    "upsellSlot": null,
                                    "coachRealtimeResponse": null,
                                    "searchSuggestionCard": null,
                                    "coachPromptCluster": null,
                                    "feedbackCard": null,
                                    "knowledgeCardV2": null,
                                    "keywordsSuggestionCard": null,
                                    "queryClarificationCard": null,
                                    "topicalQuestionCard": null,
                                    "*entityResult": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:74884576,SEARCH_SRP,DEFAULT)",
                                    "simpleTextV2": null,
                                    "promoCard": null,
                                    "searchFeedUpdate": null,
                                    "searchQuestionAndAnswerCard": null,
                                    "centeredText": null,
                                    "simpleImage": null
                                },
                                "position": 2,
                                "$recipeTypes": [
                                    "com.linkedin.edd11a570456ce19ca1f5ec3c9bb03c1"
                                ],
                                "$type": "com.linkedin.voyager.dash.search.SearchItem"
                            },
                            {
                                "item": {
                                    "cluster": null,
                                    "bannerCard": null,
                                    "searchAlert": null,
                                    "upsellSlot": null,
                                    "coachRealtimeResponse": null,
                                    "searchSuggestionCard": null,
                                    "coachPromptCluster": null,
                                    "feedbackCard": null,
                                    "knowledgeCardV2": null,
                                    "keywordsSuggestionCard": null,
                                    "queryClarificationCard": null,
                                    "topicalQuestionCard": null,
                                    "*entityResult": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:27182818,SEARCH_SRP,DEFAULT)",
                                    "simpleTextV2": null,
                                    "promoCard": null,
                                    "searchFeedUpdate": null,
                                    "searchQuestionAndAnswerCard": null,
                                    "centeredText": null,
                                    "simpleImage": null
                                },
                                "position": 3,
                                "$recipeTypes": [
                                    "com.linkedin.edd11a570456ce19ca1f5ec3c9bb03c1"
                                ],
                                "$type": "com.linkedin.voyager.dash.search.SearchItem"
                            },
                            {
                                "item": {
                                    "cluster": null,
                                    "bannerCard": null,
                                    "searchAlert": null,
                                    "upsellSlot": null,
                                    "coachRealtimeResponse": null,
                                    "searchSuggestionCard": null,
                                    "coachPromptCluster": null,
                                    "feedbackCard": null,
                                    "knowledgeCardV2": null,
                                    "keywordsSuggestionCard": null,
                                    "queryClarificationCard": null,
                                    "topicalQuestionCard": null,
                                    "*entityResult": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:6346618,SEARCH_SRP,DEFAULT)",
                                    "simpleTextV2": null,
                                    "promoCard": null,
                                    "searchFeedUpdate": null,
                                    "searchQuestionAndAnswerCard": null,
                                    "centeredText": null,
                                    "simpleImage": null
                                },
                                "position": 4,
                                "$recipeTypes": [
                                    "com.linkedin.edd11a570456ce19ca1f5ec3c9bb03c1"
                                ],
                                "$type": "com.linkedin.voyager.dash.search.SearchItem"
                            },
                            {
                                "item": {
                                    "cluster": null,
                                    "bannerCard": null,
                                    "searchAlert": null,
                                    "upsellSlot": null,
                                    "coachRealtimeResponse": null,
                                    "searchSuggestionCard": null,
                                    "coachPromptCluster": null,
                                    "feedbackCard": null,
                                    "knowledgeCardV2": null,
                                    "keywordsSuggestionCard": null,
                                    "queryClarificationCard": null,
                                    "topicalQuestionCard": null,
                                    "*entityResult": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:437912,SEARCH_SRP,DEFAULT)",
                                    "simpleTextV2": null,
                                    "promoCard": null,
                                    "searchFeedUpdate": null,
                                    "searchQuestionAndAnswerCard": null,
                                    "centeredText": null,
                                    "simpleImage": null
                                },
                                "position": 5,
                                "$recipeTypes": [
                                    "com.linkedin.edd11a570456ce19ca1f5ec3c9bb03c1"
                                ],
                                "$type": "com.linkedin.voyager.dash.search.SearchItem"
                            },
                            {
                                "item": {
                                    "cluster": null,
                                    "bannerCard": null,
                                    "searchAlert": null,
                                    "upsellSlot": null,
                                    "coachRealtimeResponse": null,
                                    "searchSuggestionCard": null,
                                    "coachPromptCluster": null,
                                    "feedbackCard": null,
                                    "knowledgeCardV2": null,
                                    "keywordsSuggestionCard": null,
                                    "queryClarificationCard": null,
                                    "topicalQuestionCard": null,
                                    "*entityResult": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:18652742,SEARCH_SRP,DEFAULT)",
                                    "simpleTextV2": null,
                                    "promoCard": null,
                                    "searchFeedUpdate": null,
                                    "searchQuestionAndAnswerCard": null,
                                    "centeredText": null,
                                    "simpleImage": null
                                },
                                "position": 6,
                                "$recipeTypes": [
                                    "com.linkedin.edd11a570456ce19ca1f5ec3c9bb03c1"
                                ],
                                "$type": "com.linkedin.voyager.dash.search.SearchItem"
                            },
                            {
                                "item": {
                                    "cluster": null,
                                    "bannerCard": null,
                                    "searchAlert": null,
                                    "upsellSlot": null,
                                    "coachRealtimeResponse": null,
                                    "searchSuggestionCard": null,
                                    "coachPromptCluster": null,
                                    "feedbackCard": null,
                                    "knowledgeCardV2": null,
                                    "keywordsSuggestionCard": null,
                                    "queryClarificationCard": null,
                                    "topicalQuestionCard": null,
                                    "*entityResult": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:40674246,SEARCH_SRP,DEFAULT)",
                                    "simpleTextV2": null,
                                    "promoCard": null,
                                    "searchFeedUpdate": null,
                                    "searchQuestionAndAnswerCard": null,
                                    "centeredText": null,
                                    "simpleImage": null
                                },
                                "position": 7,
                                "$recipeTypes": [
                                    "com.linkedin.edd11a570456ce19ca1f5ec3c9bb03c1"
                                ],
                                "$type": "com.linkedin.voyager.dash.search.SearchItem"
                            },
                            {
                                "item": {
                                    "cluster": null,
                                    "bannerCard": null,
                                    "searchAlert": null,
                                    "upsellSlot": null,
                                    "coachRealtimeResponse": null,
                                    "searchSuggestionCard": null,
                                    "coachPromptCluster": null,
                                    "feedbackCard": null,
                                    "knowledgeCardV2": null,
                                    "keywordsSuggestionCard": null,
                                    "queryClarificationCard": null,
                                    "topicalQuestionCard": null,
                                    "*entityResult": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:18733434,SEARCH_SRP,DEFAULT)",
                                    "simpleTextV2": null,
                                    "promoCard": null,
                                    "searchFeedUpdate": null,
                                    "searchQuestionAndAnswerCard": null,
                                    "centeredText": null,
                                    "simpleImage": null
                                },
                                "position": 8,
                                "$recipeTypes": [
                                    "com.linkedin.edd11a570456ce19ca1f5ec3c9bb03c1"
                                ],
                                "$type": "com.linkedin.voyager.dash.search.SearchItem"
                            },
                            {
                                "item": {
                                    "cluster": null,
                                    "bannerCard": null,
                                    "searchAlert": null,
                                    "upsellSlot": null,
                                    "coachRealtimeResponse": null,
                                    "searchSuggestionCard": null,
                                    "coachPromptCluster": null,
                                    "feedbackCard": null,
                                    "knowledgeCardV2": null,
                                    "keywordsSuggestionCard": null,
                                    "queryClarificationCard": null,
                                    "topicalQuestionCard": null,
                                    "*entityResult": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:3317828,SEARCH_SRP,DEFAULT)",
                                    "simpleTextV2": null,
                                    "promoCard": null,
                                    "searchFeedUpdate": null,
                                    "searchQuestionAndAnswerCard": null,
                                    "centeredText": null,
                                    "simpleImage": null
                                },
                                "position": 9,
                                "$recipeTypes": [
                                    "com.linkedin.edd11a570456ce19ca1f5ec3c9bb03c1"
                                ],
                                "$type": "com.linkedin.voyager.dash.search.SearchItem"
                            },
                            {
                                "item": {
                                    "cluster": null,
                                    "bannerCard": null,
                                    "searchAlert": null,
                                    "upsellSlot": null,
                                    "coachRealtimeResponse": null,
                                    "searchSuggestionCard": null,
                                    "coachPromptCluster": null,
                                    "feedbackCard": null,
                                    "knowledgeCardV2": null,
                                    "keywordsSuggestionCard": null,
                                    "queryClarificationCard": null,
                                    "topicalQuestionCard": null,
                                    "*entityResult": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:12590830,SEARCH_SRP,DEFAULT)",
                                    "simpleTextV2": null,
                                    "promoCard": null,
                                    "searchFeedUpdate": null,
                                    "searchQuestionAndAnswerCard": null,
                                    "centeredText": null,
                                    "simpleImage": null
                                },
                                "position": 10,
                                "$recipeTypes": [
                                    "com.linkedin.edd11a570456ce19ca1f5ec3c9bb03c1"
                                ],
                                "$type": "com.linkedin.voyager.dash.search.SearchItem"
                            }
                        ],
                        "results": [],
                        "trackingId": "©¿ÏpMÄ§ixQç."
                    }
                ],
                "$type": "com.linkedin.restli.common.CollectionResponse"
            },
            "$recipeTypes": [
                "com.linkedin.c293aa010e51bae32433eeb13b1682fa"
            ],
            "$type": "com.linkedin.c293aa010e51bae32433eeb13b1682fa"
        },
        "extensions": {
            "webMetadata": {}
        }
    },
    "meta": {
        "microSchema": {
            "isGraphQL": true,
            "version": "2.1",
            "types": {
                "com.linkedin.bb9a15e3b05ba04c5e385ae638d7c325": {
                    "fields": {
                        "controlName": {
                            "type": "com.linkedin.voyager.dash.common.tracking.ControlName"
                        },
                        "appearance": {
                            "type": "com.linkedin.3b0c42a23baf5421629e62972e26b58b"
                        },
                        "openExternally": {
                            "type": "boolean"
                        },
                        "accessibilityText": {
                            "type": "string"
                        },
                        "disable": {
                            "type": "boolean"
                        },
                        "url": {
                            "type": "com.linkedin.common.Url"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.premium.PremiumButton"
                },
                "com.linkedin.75f2a2c151047532fd7bb6314306feae": {
                    "fields": {
                        "icon": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "header": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "subheader": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.premium.PremiumUpsellValueProp"
                },
                "com.linkedin.e49fee013ecbe8034dac8d0f31d5b5a7": {
                    "fields": {
                        "carousel": {
                            "type": "com.linkedin.65639836cc74b8482ec44d3ccce257cf"
                        },
                        "carouselV2": {
                            "type": "com.linkedin.5c853aba2154c55483e72bf6cdfaaf3e"
                        },
                        "heroEntity": {
                            "type": "com.linkedin.cf4b25c18907ea8eafe915c8bfa24109"
                        },
                        "trackingUrn": {
                            "type": "com.linkedin.common.Urn"
                        },
                        "trackingId": {
                            "type": "com.linkedin.common.TrackingId"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.KnowledgeCardV2"
                },
                "com.linkedin.6a224ca38654a84754a1eb3e97c0f846": {
                    "fields": {
                        "textDirection": {
                            "type": "com.linkedin.voyager.dash.common.text.TextDirection"
                        },
                        "attributesV2": {
                            "type": {
                                "array": "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                            }
                        },
                        "text": {
                            "type": "string"
                        },
                        "accessibilityTextAttributesV2": {
                            "type": {
                                "array": "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                            }
                        },
                        "accessibilityText": {
                            "type": "string"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.common.text.TextViewModel"
                },
                "com.linkedin.86e9a3cd31f8dd276b8f2ceffc1d92ca": {
                    "fields": {
                        "titleSupplementaryInfo": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "showDivider": {
                            "type": "boolean"
                        },
                        "contextualTitleSupplementaryInfo": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "subtitle": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "actionButton": {
                            "type": "com.linkedin.280548a5c822f61a54f7d2022f1e02a5"
                        },
                        "icon": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "navigationContext": {
                            "type": "com.linkedin.8a612b4e445851d55ecf8b09571a05ee"
                        },
                        "supplementaryImage": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "contextualTitle": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "title": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.contextualheader.ContextualHeaderComponent"
                },
                "com.linkedin.8a612b4e445851d55ecf8b09571a05ee": {
                    "fields": {
                        "sponsoredOriginalUrl": {
                            "type": "com.linkedin.common.Url"
                        },
                        "urlViewingBehavior": {
                            "type": "com.linkedin.voyager.dash.common.ux.UrlViewingBehavior"
                        },
                        "actionTarget": {
                            "type": "com.linkedin.common.Url"
                        },
                        "trackingActionType": {
                            "type": "string"
                        },
                        "sponsoredUrlAttributes": {
                            "type": "com.linkedin.d853c03d4547334c4f244bc136796f0b"
                        },
                        "accessibilityText": {
                            "type": "string"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.navigation.FeedNavigationContext"
                },
                "com.linkedin.7d211d7e5c235f2e6b597ae8905543f1": {
                    "fields": {
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.HashtagUrn"
                        },
                        "trackingUrn": {
                            "type": "com.linkedin.common.Urn"
                        },
                        "actionTarget": {
                            "type": "com.linkedin.common.Url"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.Hashtag"
                },
                "com.linkedin.f1b2492c05b41398477b887761d337a9": {
                    "fields": {
                        "saved": {
                            "type": "boolean"
                        },
                        "preDashEntityUrn": {
                            "type": "com.linkedin.voyager.dash.common.PreDashUrn"
                        },
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.SaveStateUrn"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.SaveState"
                },
                "com.linkedin.2f0e7770d0de272d04414cf40edf03da": {
                    "fields": {
                        "titleImage": {
                            "type": "com.linkedin.voyager.dash.common.SystemImageName"
                        },
                        "description": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "titleText": {
                            "type": "string"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.survey.SurveyConfirmationContent"
                },
                "com.linkedin.0686b967e27484975f7b854a8c3258d4": {
                    "fields": {
                        "tooltipLegoTrackingToken": {
                            "type": "string"
                        },
                        "tooltipText": {
                            "type": "string"
                        },
                        "coachPrompts": {
                            "type": {
                                "array": "com.linkedin.241029e8a1f14aef50bb8177094701e9"
                            }
                        },
                        "trackingId": {
                            "type": "com.linkedin.common.TrackingId"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.coachprompt.CoachPromptComponent"
                },
                "com.linkedin.241029e8a1f14aef50bb8177094701e9": {
                    "fields": {
                        "coachAction": {
                            "type": "com.linkedin.ff4c51d111da4ffaaae179a2eaf9a303"
                        },
                        "text": {
                            "type": "string"
                        },
                        "trackingId": {
                            "type": "com.linkedin.common.TrackingId"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.coachprompt.CoachPrompt"
                },
                "com.linkedin.ce17b3b18736cc798de33ecc17836156": {
                    "fields": {
                        "confirmationContent": {
                            "type": "com.linkedin.2f0e7770d0de272d04414cf40edf03da"
                        },
                        "surveyContent": {
                            "type": "com.linkedin.3364fdf0c31e8944591cc641a1757061"
                        },
                        "legoTrackingId": {
                            "type": "string"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.survey.DetailedSurveyComponent"
                },
                "com.linkedin.68fad358e2fc4bf4a75296c8e83879a4": {
                    "fields": {
                        "reviewSla": {
                            "type": "int"
                        },
                        "status": {
                            "type": "com.linkedin.voyager.dash.jobs.JobPostingTrustReviewStatus"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.jobs.JobPostingTrustReview"
                },
                "com.linkedin.f72668082d3f0ea7feb3a402e4555a6f": {
                    "fields": {
                        "url": {
                            "type": "com.linkedin.common.Url"
                        },
                        "text": {
                            "type": "string"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.common.Link"
                },
                "com.linkedin.ad074a161dc3cbca5463a3d8566bf68f": {
                    "fields": {
                        "timeUntilNextEntity": {
                            "type": "long"
                        },
                        "image": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.slideshow.ImageSlide"
                },
                "com.linkedin.16d7d07baef648aa182105f6f1c2da66": {
                    "fields": {
                        "titleFontSize": {
                            "type": "com.linkedin.voyager.dash.search.FontSize"
                        },
                        "subtitleFontSize": {
                            "type": "com.linkedin.voyager.dash.search.FontSize"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.SimpleInsightAttributes"
                },
                "com.linkedin.7f12f9be2e6b0e371ad2f98ce1324e16": {
                    "fields": {
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.GroupMembershipUrn"
                        },
                        "joinedAt": {
                            "type": "long"
                        },
                        "profile": {
                            "resolvedFrom": "profileUrn",
                            "type": "com.linkedin.e0372afc4a18480b00ca7e4906904fd7"
                        },
                        "groupUrn": {
                            "type": "string"
                        },
                        "profileUrn": {
                            "type": "string"
                        },
                        "group": {
                            "resolvedFrom": "groupUrn",
                            "type": "com.linkedin.c8f5bf5a9d5e0dbbc3c824c2dfd751a8"
                        },
                        "status": {
                            "type": "com.linkedin.voyager.dash.groups.GroupMembershipStatus"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.groups.GroupMembership"
                },
                "com.linkedin.cfe97a2796732c7129fc01f295e6b6bb": {
                    "fields": {
                        "searchActionType": {
                            "type": "string"
                        },
                        "controlName": {
                            "type": "com.linkedin.voyager.dash.common.tracking.ControlName"
                        },
                        "title": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "values": {
                            "type": {
                                "array": "com.linkedin.14a475ec64857ded5e4565d932f4f2cc"
                            }
                        },
                        "trackingId": {
                            "type": "com.linkedin.common.TrackingId"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.KeywordsSuggestionCard"
                },
                "com.linkedin.0da2d18a70c6934158f5d9caa1264add": {
                    "fields": {
                        "textOption": {
                            "type": "string"
                        },
                        "type": {
                            "type": "com.linkedin.voyager.dash.sponsoredcontent.leadgen.MultipleChoiceQuestionOptionsType"
                        },
                        "selected": {
                            "type": "boolean"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.sponsoredcontent.leadgen.MultipleChoiceQuestionOptions"
                },
                "com.linkedin.2aa0f2389f8b1f7666d3ba41965d9958": {
                    "fields": {
                        "connectAction": {
                            "type": "com.linkedin.c97d64dfd15204616a896fea6339d850"
                        },
                        "description": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "instantGratificationText": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "followAction": {
                            "type": "com.linkedin.d50733b664c8019ae5d38b1804596f0b"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.contextualaction.ContextualActionComponent"
                },
                "com.linkedin.5c853aba2154c55483e72bf6cdfaaf3e": {
                    "fields": {
                        "image": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "quickFilterActions": {
                            "type": {
                                "array": "com.linkedin.30dee75e249786a8e1ceb4c1d056ab57"
                            }
                        },
                        "dismissable": {
                            "type": "boolean"
                        },
                        "clusterRenderType": {
                            "type": "com.linkedin.voyager.dash.search.ClusterRenderType"
                        },
                        "totalResultCount": {
                            "type": "long"
                        },
                        "controlName": {
                            "type": "com.linkedin.voyager.dash.common.tracking.ControlName"
                        },
                        "description": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "title": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "navigationText": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "actionTypeName": {
                            "type": "string"
                        },
                        "feature": {
                            "derivedFrom": "featureUnion",
                            "type": {
                                "union": {
                                    "keywordsSuggestionCard": "com.linkedin.cfe97a2796732c7129fc01f295e6b6bb",
                                    "knowledgeCard": "com.linkedin.dfac8c8d5d692ba68fedb94e12f20ffc",
                                    "queryClarificationCard": "com.linkedin.d81debcec40db70c10df9aafd5fc6fdb",
                                    "bannerCard": "com.linkedin.6a3fa261802e4186dff97b17e0a2a17d",
                                    "heroEntityCard": "com.linkedin.544f3f6642d8f7a8ebf2647e5655495a",
                                    "promoCard": "com.linkedin.eac81a502f37713c69cdf36d1c92ee0b",
                                    "centeredText": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846",
                                    "simpleImage": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b",
                                    "searchSuggestionCard": "com.linkedin.0cf29c4912dd382688cfe0e6d63f710a",
                                    "knowledgeCardV2": "com.linkedin.e49fee013ecbe8034dac8d0f31d5b5a7",
                                    "feedbackCard": "com.linkedin.2d3e7b4bccc9c85f103b0dc9fdfd3669"
                                }
                            }
                        },
                        "navigationCardAction": {
                            "type": "com.linkedin.30dee75e249786a8e1ceb4c1d056ab57"
                        },
                        "featureUnion": {
                            "type": {
                                "union": {
                                    "keywordsSuggestionCard": "com.linkedin.cfe97a2796732c7129fc01f295e6b6bb",
                                    "knowledgeCard": "com.linkedin.dfac8c8d5d692ba68fedb94e12f20ffc",
                                    "queryClarificationCard": "com.linkedin.d81debcec40db70c10df9aafd5fc6fdb",
                                    "bannerCard": "com.linkedin.6a3fa261802e4186dff97b17e0a2a17d",
                                    "heroEntityCard": "com.linkedin.544f3f6642d8f7a8ebf2647e5655495a",
                                    "promoCard": "com.linkedin.eac81a502f37713c69cdf36d1c92ee0b",
                                    "centeredText": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846",
                                    "simpleImage": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b",
                                    "searchSuggestionCard": "com.linkedin.0cf29c4912dd382688cfe0e6d63f710a",
                                    "knowledgeCardV2": "com.linkedin.e49fee013ecbe8034dac8d0f31d5b5a7",
                                    "feedbackCard": "com.linkedin.2d3e7b4bccc9c85f103b0dc9fdfd3669"
                                }
                            }
                        },
                        "position": {
                            "type": "int"
                        },
                        "items": {
                            "type": {
                                "array": "com.linkedin.edd11a570456ce19ca1f5ec3c9bb03c1"
                            }
                        },
                        "results": {
                            "type": {
                                "array": "com.linkedin.cf4b25c18907ea8eafe915c8bfa24109"
                            }
                        },
                        "trackingId": {
                            "type": "com.linkedin.common.TrackingId"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.SearchClusterViewModel"
                },
                "com.linkedin.65639836cc74b8482ec44d3ccce257cf": {
                    "fields": {
                        "hits": {
                            "type": {
                                "array": {
                                    "union": {
                                        "entityHit": "com.linkedin.cf4b25c18907ea8eafe915c8bfa24109"
                                    }
                                }
                            }
                        },
                        "title": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "hitsResolutionResults": {
                            "derivedFrom": "hits",
                            "type": {
                                "array": {
                                    "union": {
                                        "entityHit": "com.linkedin.cf4b25c18907ea8eafe915c8bfa24109"
                                    }
                                }
                            }
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.CarouselViewModel"
                },
                "com.linkedin.daa3a2cada5a579731c11a78fbd82e2d": {
                    "fields": {
                        "name": {
                            "type": "string"
                        },
                        "logo": {
                            "type": {
                                "union": {
                                    "url": "com.linkedin.common.Url",
                                    "vectorImage": "com.linkedin.28db8575bcf1c65bdc4bc15948d50ee9"
                                }
                            }
                        },
                        "logoResolutionResult": {
                            "derivedFrom": "logo",
                            "type": {
                                "union": {
                                    "url": "com.linkedin.common.Url",
                                    "vectorImage": "com.linkedin.28db8575bcf1c65bdc4bc15948d50ee9"
                                }
                            }
                        },
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.SchoolUrn"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.organization.School"
                },
                "com.linkedin.82568376c49f8a966ad23174692c2071": {
                    "fields": {
                        "accessoryTrackingId": {
                            "type": "com.linkedin.common.TrackingId"
                        },
                        "legoTrackingToken": {
                            "type": "string"
                        },
                        "inlineFeedbackView": {
                            "type": "com.linkedin.c8bd17969c41cd526ddc4a7b36c8cdbe"
                        },
                        "visibility": {
                            "type": "com.linkedin.voyager.dash.feed.component.gentleprompt.GentlePromptComponentVisibility"
                        },
                        "socialActivityCounts": {
                            "type": "com.linkedin.60216d4fa134df147fcc8c39e71c7139"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.gentleprompt.GentlePromptComponent"
                },
                "com.linkedin.0cf29c4912dd382688cfe0e6d63f710a": {
                    "fields": {
                        "verticalRender": {
                            "type": "boolean"
                        },
                        "values": {
                            "type": {
                                "array": "com.linkedin.a6388bc756287a778617ae66ac0b9806"
                            }
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.SearchSuggestionCard"
                },
                "com.linkedin.827d2df06cbbd8888b228aac56a99cb5": {
                    "fields": {
                        "ctaButton": {
                            "type": "com.linkedin.280548a5c822f61a54f7d2022f1e02a5"
                        },
                        "subtitle": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "insightImage": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "description": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "navigationContext": {
                            "type": "com.linkedin.8a612b4e445851d55ecf8b09571a05ee"
                        },
                        "logo": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "banner": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "shareUrl": {
                            "type": "com.linkedin.common.Url"
                        },
                        "insightText": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "title": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "titleContext": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.event.EventComponent"
                },
                "com.linkedin.c8dbbe57bac604879f990ffdec11ee89": {
                    "fields": {
                        "navigationContext": {
                            "type": "com.linkedin.8a612b4e445851d55ecf8b09571a05ee"
                        },
                        "text": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.contextualdescription.ContextualDescriptionComponent"
                },
                "com.linkedin.757852411fb0feeedcbd4df1cbcfcd54": {
                    "fields": {
                        "metadata": {
                            "type": "com.linkedin.d6ed2ae9c1ec5545f0d810302f1c2b7d"
                        },
                        "socialContent": {
                            "type": "com.linkedin.6eee18f6ca0e23d5f86fb04aa22c5516"
                        },
                        "showSocialDetail": {
                            "type": "boolean"
                        },
                        "footer": {
                            "derivedFrom": "footerUnion",
                            "type": {
                                "union": {
                                    "toggleButtonComponent": "com.linkedin.0f36f2dc6be4ed6af3361a6356cb19e0",
                                    "feedDividerComponent": "com.linkedin.fd4f461137d628e214f2c67640064f40",
                                    "articleComponent": "com.linkedin.86b903c46b5240b03037ec8656976681",
                                    "eventComponent": "com.linkedin.827d2df06cbbd8888b228aac56a99cb5",
                                    "conversationsComponent": "com.linkedin.65bd51e43ed8142eb9d37a29845f6c04",
                                    "conversationStartersComponent": "com.linkedin.ed74e3ca52f62abc923f3cfacd4628e0",
                                    "promoComponent": "com.linkedin.8ff002aafcb203f2b95c57c175c2f91c",
                                    "seeMoreComponent": "com.linkedin.dbe3dc7ec313938618c482695c80e952",
                                    "reviewComponent": "com.linkedin.74024cf712e3b910b92188d657a36b48",
                                    "feedDiscoveryGridComponent": "com.linkedin.dacb8097355f9a4b84257dcd4a72e01d",
                                    "gentlePromptComponent": "com.linkedin.82568376c49f8a966ad23174692c2071",
                                    "followPromptComponent": "com.linkedin.7f0cc4bcf6aef643d5c454ff48c96941",
                                    "jobComponent": "com.linkedin.292ed207e90e51c83f267296fa0c7940",
                                    "learningRecommendationComponent": "com.linkedin.b023a540cfe197e815b01a45eebe74b3",
                                    "surveyComponent": "com.linkedin.3a88e7bf8b5e1c81be38f30d05a7155c",
                                    "buttonComponent": "com.linkedin.280548a5c822f61a54f7d2022f1e02a5",
                                    "celebrationComponent": "com.linkedin.a61eaf39f1cf127adaf1233791804a39",
                                    "actorComponent": "com.linkedin.71b94ae4069ecc57933235cd51a72aee",
                                    "documentComponent": "com.linkedin.3623b786d2323fb52c13099cf2752b53",
                                    "creationStatusComponent": "com.linkedin.1734179c2744199ea6708a6613bdcede",
                                    "dynamicPollComponent": "com.linkedin.38c32cf9808204fff187465f6ac6683c",
                                    "newsletterComponent": "com.linkedin.cd89160de71b547693b54b81d054de0b",
                                    "postCtaComponent": "com.linkedin.3f4ae0934d738b90cbec63f10776b7ae",
                                    "scheduledLiveContentComponent": "com.linkedin.0af9905c7ec2db45db6070cde87109b5",
                                    "entityComponent": "com.linkedin.4f55a752e41ac24988f152a28efd3398",
                                    "externalVideoComponent": "com.linkedin.56ed1d753079896e9ad350e6f461c483",
                                    "linkedInVideoComponent": "com.linkedin.833e5a7fd479a007d026abce564deea5",
                                    "textOverlayImageComponent": "com.linkedin.c3576e4eb1959675613cf442c15650b9",
                                    "annotationComponent": "com.linkedin.d067ea339aae1c25da65a9f86eb786ad",
                                    "detailedSurveyComponent": "com.linkedin.ce17b3b18736cc798de33ecc17836156",
                                    "imageComponent": "com.linkedin.d388328a98f556cd5d952549ba61eff0",
                                    "showcaseComponent": "com.linkedin.499a0be5e49d2be9202b331ff124e675",
                                    "pollComponent": "com.linkedin.e3bf41d90ee4ffc0edf0c6e16c6a18c1",
                                    "feedDiscoveryEntityComponent": "com.linkedin.5b82b762410287f21f34b3d755f164dc",
                                    "nudgeComponent": "com.linkedin.d76ca50a521fc6f378c056280cb05897",
                                    "promptComponent": "com.linkedin.37da0dcf9c4df3c725740cceef3f71e1",
                                    "contextualActionComponent": "com.linkedin.2aa0f2389f8b1f7666d3ba41965d9958",
                                    "commentaryComponent": "com.linkedin.5ce31f49adf6bd8cb496962bdde69707",
                                    "announcementComponent": "com.linkedin.f6c622cdcd9214c3ee563a8875d24fb3",
                                    "slideshowComponent": "com.linkedin.f70de4d604689acbffc0dcd8115c319d",
                                    "callToActionComponent": "com.linkedin.17602d9bd6fd3c2435cab1748e7900cf"
                                }
                            }
                        },
                        "debugInfo": {
                            "type": "com.linkedin.efdd020b9332e11832dc0f931a05622c"
                        },
                        "carouselContent": {
                            "type": "com.linkedin.85452cafea09accebe0a8082a8d9898f"
                        },
                        "content": {
                            "derivedFrom": "contentUnion",
                            "type": {
                                "union": {
                                    "toggleButtonComponent": "com.linkedin.0f36f2dc6be4ed6af3361a6356cb19e0",
                                    "feedDividerComponent": "com.linkedin.fd4f461137d628e214f2c67640064f40",
                                    "articleComponent": "com.linkedin.86b903c46b5240b03037ec8656976681",
                                    "eventComponent": "com.linkedin.827d2df06cbbd8888b228aac56a99cb5",
                                    "conversationsComponent": "com.linkedin.65bd51e43ed8142eb9d37a29845f6c04",
                                    "promoComponent": "com.linkedin.8ff002aafcb203f2b95c57c175c2f91c",
                                    "seeMoreComponent": "com.linkedin.dbe3dc7ec313938618c482695c80e952",
                                    "reviewComponent": "com.linkedin.74024cf712e3b910b92188d657a36b48",
                                    "feedDiscoveryGridComponent": "com.linkedin.dacb8097355f9a4b84257dcd4a72e01d",
                                    "gentlePromptComponent": "com.linkedin.82568376c49f8a966ad23174692c2071",
                                    "miniUpdateContentComponent": "com.linkedin.e461eb42e2668e3b6817d743d334f60d",
                                    "followPromptComponent": "com.linkedin.7f0cc4bcf6aef643d5c454ff48c96941",
                                    "jobComponent": "com.linkedin.292ed207e90e51c83f267296fa0c7940",
                                    "learningRecommendationComponent": "com.linkedin.b023a540cfe197e815b01a45eebe74b3",
                                    "surveyComponent": "com.linkedin.3a88e7bf8b5e1c81be38f30d05a7155c",
                                    "buttonComponent": "com.linkedin.280548a5c822f61a54f7d2022f1e02a5",
                                    "celebrationComponent": "com.linkedin.a61eaf39f1cf127adaf1233791804a39",
                                    "actorComponent": "com.linkedin.71b94ae4069ecc57933235cd51a72aee",
                                    "documentComponent": "com.linkedin.3623b786d2323fb52c13099cf2752b53",
                                    "creationStatusComponent": "com.linkedin.1734179c2744199ea6708a6613bdcede",
                                    "dynamicPollComponent": "com.linkedin.38c32cf9808204fff187465f6ac6683c",
                                    "newsletterComponent": "com.linkedin.cd89160de71b547693b54b81d054de0b",
                                    "postCtaComponent": "com.linkedin.3f4ae0934d738b90cbec63f10776b7ae",
                                    "scheduledLiveContentComponent": "com.linkedin.0af9905c7ec2db45db6070cde87109b5",
                                    "entityComponent": "com.linkedin.4f55a752e41ac24988f152a28efd3398",
                                    "externalVideoComponent": "com.linkedin.56ed1d753079896e9ad350e6f461c483",
                                    "videoCarouselItemComponent": "com.linkedin.6ad8529dd2cb1e17dae165dbe981c7ff",
                                    "linkedInVideoComponent": "com.linkedin.833e5a7fd479a007d026abce564deea5",
                                    "textOverlayImageComponent": "com.linkedin.c3576e4eb1959675613cf442c15650b9",
                                    "annotationComponent": "com.linkedin.d067ea339aae1c25da65a9f86eb786ad",
                                    "detailedSurveyComponent": "com.linkedin.ce17b3b18736cc798de33ecc17836156",
                                    "imageComponent": "com.linkedin.d388328a98f556cd5d952549ba61eff0",
                                    "showcaseComponent": "com.linkedin.499a0be5e49d2be9202b331ff124e675",
                                    "pollComponent": "com.linkedin.e3bf41d90ee4ffc0edf0c6e16c6a18c1",
                                    "feedDiscoveryEntityComponent": "com.linkedin.5b82b762410287f21f34b3d755f164dc",
                                    "promptComponent": "com.linkedin.37da0dcf9c4df3c725740cceef3f71e1",
                                    "contextualActionComponent": "com.linkedin.2aa0f2389f8b1f7666d3ba41965d9958",
                                    "commentaryComponent": "com.linkedin.5ce31f49adf6bd8cb496962bdde69707",
                                    "announcementComponent": "com.linkedin.f6c622cdcd9214c3ee563a8875d24fb3",
                                    "miniUpdateCommentaryComponent": "com.linkedin.4aad72588c95348a1c39f08789b66191",
                                    "slideshowComponent": "com.linkedin.f70de4d604689acbffc0dcd8115c319d",
                                    "callToActionComponent": "com.linkedin.17602d9bd6fd3c2435cab1748e7900cf"
                                }
                            }
                        },
                        "contentUnion": {
                            "type": {
                                "union": {
                                    "toggleButtonComponent": "com.linkedin.0f36f2dc6be4ed6af3361a6356cb19e0",
                                    "feedDividerComponent": "com.linkedin.fd4f461137d628e214f2c67640064f40",
                                    "articleComponent": "com.linkedin.86b903c46b5240b03037ec8656976681",
                                    "eventComponent": "com.linkedin.827d2df06cbbd8888b228aac56a99cb5",
                                    "conversationsComponent": "com.linkedin.65bd51e43ed8142eb9d37a29845f6c04",
                                    "promoComponent": "com.linkedin.8ff002aafcb203f2b95c57c175c2f91c",
                                    "seeMoreComponent": "com.linkedin.dbe3dc7ec313938618c482695c80e952",
                                    "reviewComponent": "com.linkedin.74024cf712e3b910b92188d657a36b48",
                                    "feedDiscoveryGridComponent": "com.linkedin.dacb8097355f9a4b84257dcd4a72e01d",
                                    "gentlePromptComponent": "com.linkedin.82568376c49f8a966ad23174692c2071",
                                    "miniUpdateContentComponent": "com.linkedin.e461eb42e2668e3b6817d743d334f60d",
                                    "followPromptComponent": "com.linkedin.7f0cc4bcf6aef643d5c454ff48c96941",
                                    "jobComponent": "com.linkedin.292ed207e90e51c83f267296fa0c7940",
                                    "learningRecommendationComponent": "com.linkedin.b023a540cfe197e815b01a45eebe74b3",
                                    "surveyComponent": "com.linkedin.3a88e7bf8b5e1c81be38f30d05a7155c",
                                    "buttonComponent": "com.linkedin.280548a5c822f61a54f7d2022f1e02a5",
                                    "celebrationComponent": "com.linkedin.a61eaf39f1cf127adaf1233791804a39",
                                    "actorComponent": "com.linkedin.71b94ae4069ecc57933235cd51a72aee",
                                    "documentComponent": "com.linkedin.3623b786d2323fb52c13099cf2752b53",
                                    "creationStatusComponent": "com.linkedin.1734179c2744199ea6708a6613bdcede",
                                    "dynamicPollComponent": "com.linkedin.38c32cf9808204fff187465f6ac6683c",
                                    "newsletterComponent": "com.linkedin.cd89160de71b547693b54b81d054de0b",
                                    "postCtaComponent": "com.linkedin.3f4ae0934d738b90cbec63f10776b7ae",
                                    "scheduledLiveContentComponent": "com.linkedin.0af9905c7ec2db45db6070cde87109b5",
                                    "entityComponent": "com.linkedin.4f55a752e41ac24988f152a28efd3398",
                                    "externalVideoComponent": "com.linkedin.56ed1d753079896e9ad350e6f461c483",
                                    "videoCarouselItemComponent": "com.linkedin.6ad8529dd2cb1e17dae165dbe981c7ff",
                                    "linkedInVideoComponent": "com.linkedin.833e5a7fd479a007d026abce564deea5",
                                    "textOverlayImageComponent": "com.linkedin.c3576e4eb1959675613cf442c15650b9",
                                    "annotationComponent": "com.linkedin.d067ea339aae1c25da65a9f86eb786ad",
                                    "detailedSurveyComponent": "com.linkedin.ce17b3b18736cc798de33ecc17836156",
                                    "imageComponent": "com.linkedin.d388328a98f556cd5d952549ba61eff0",
                                    "showcaseComponent": "com.linkedin.499a0be5e49d2be9202b331ff124e675",
                                    "pollComponent": "com.linkedin.e3bf41d90ee4ffc0edf0c6e16c6a18c1",
                                    "feedDiscoveryEntityComponent": "com.linkedin.5b82b762410287f21f34b3d755f164dc",
                                    "promptComponent": "com.linkedin.37da0dcf9c4df3c725740cceef3f71e1",
                                    "contextualActionComponent": "com.linkedin.2aa0f2389f8b1f7666d3ba41965d9958",
                                    "commentaryComponent": "com.linkedin.5ce31f49adf6bd8cb496962bdde69707",
                                    "announcementComponent": "com.linkedin.f6c622cdcd9214c3ee563a8875d24fb3",
                                    "miniUpdateCommentaryComponent": "com.linkedin.4aad72588c95348a1c39f08789b66191",
                                    "slideshowComponent": "com.linkedin.f70de4d604689acbffc0dcd8115c319d",
                                    "callToActionComponent": "com.linkedin.17602d9bd6fd3c2435cab1748e7900cf"
                                }
                            }
                        },
                        "detailHeader": {
                            "type": "com.linkedin.57397516101a62ce38ea32c68aecdfab"
                        },
                        "attachment": {
                            "type": "com.linkedin.21842cae337b7d35a349900ddee48af6"
                        },
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.UpdateUrn"
                        },
                        "footerUnion": {
                            "type": {
                                "union": {
                                    "toggleButtonComponent": "com.linkedin.0f36f2dc6be4ed6af3361a6356cb19e0",
                                    "feedDividerComponent": "com.linkedin.fd4f461137d628e214f2c67640064f40",
                                    "articleComponent": "com.linkedin.86b903c46b5240b03037ec8656976681",
                                    "eventComponent": "com.linkedin.827d2df06cbbd8888b228aac56a99cb5",
                                    "conversationsComponent": "com.linkedin.65bd51e43ed8142eb9d37a29845f6c04",
                                    "conversationStartersComponent": "com.linkedin.ed74e3ca52f62abc923f3cfacd4628e0",
                                    "promoComponent": "com.linkedin.8ff002aafcb203f2b95c57c175c2f91c",
                                    "seeMoreComponent": "com.linkedin.dbe3dc7ec313938618c482695c80e952",
                                    "reviewComponent": "com.linkedin.74024cf712e3b910b92188d657a36b48",
                                    "feedDiscoveryGridComponent": "com.linkedin.dacb8097355f9a4b84257dcd4a72e01d",
                                    "gentlePromptComponent": "com.linkedin.82568376c49f8a966ad23174692c2071",
                                    "followPromptComponent": "com.linkedin.7f0cc4bcf6aef643d5c454ff48c96941",
                                    "jobComponent": "com.linkedin.292ed207e90e51c83f267296fa0c7940",
                                    "learningRecommendationComponent": "com.linkedin.b023a540cfe197e815b01a45eebe74b3",
                                    "surveyComponent": "com.linkedin.3a88e7bf8b5e1c81be38f30d05a7155c",
                                    "buttonComponent": "com.linkedin.280548a5c822f61a54f7d2022f1e02a5",
                                    "celebrationComponent": "com.linkedin.a61eaf39f1cf127adaf1233791804a39",
                                    "actorComponent": "com.linkedin.71b94ae4069ecc57933235cd51a72aee",
                                    "documentComponent": "com.linkedin.3623b786d2323fb52c13099cf2752b53",
                                    "creationStatusComponent": "com.linkedin.1734179c2744199ea6708a6613bdcede",
                                    "dynamicPollComponent": "com.linkedin.38c32cf9808204fff187465f6ac6683c",
                                    "newsletterComponent": "com.linkedin.cd89160de71b547693b54b81d054de0b",
                                    "postCtaComponent": "com.linkedin.3f4ae0934d738b90cbec63f10776b7ae",
                                    "scheduledLiveContentComponent": "com.linkedin.0af9905c7ec2db45db6070cde87109b5",
                                    "entityComponent": "com.linkedin.4f55a752e41ac24988f152a28efd3398",
                                    "externalVideoComponent": "com.linkedin.56ed1d753079896e9ad350e6f461c483",
                                    "linkedInVideoComponent": "com.linkedin.833e5a7fd479a007d026abce564deea5",
                                    "textOverlayImageComponent": "com.linkedin.c3576e4eb1959675613cf442c15650b9",
                                    "annotationComponent": "com.linkedin.d067ea339aae1c25da65a9f86eb786ad",
                                    "detailedSurveyComponent": "com.linkedin.ce17b3b18736cc798de33ecc17836156",
                                    "imageComponent": "com.linkedin.d388328a98f556cd5d952549ba61eff0",
                                    "showcaseComponent": "com.linkedin.499a0be5e49d2be9202b331ff124e675",
                                    "pollComponent": "com.linkedin.e3bf41d90ee4ffc0edf0c6e16c6a18c1",
                                    "feedDiscoveryEntityComponent": "com.linkedin.5b82b762410287f21f34b3d755f164dc",
                                    "nudgeComponent": "com.linkedin.d76ca50a521fc6f378c056280cb05897",
                                    "promptComponent": "com.linkedin.37da0dcf9c4df3c725740cceef3f71e1",
                                    "contextualActionComponent": "com.linkedin.2aa0f2389f8b1f7666d3ba41965d9958",
                                    "commentaryComponent": "com.linkedin.5ce31f49adf6bd8cb496962bdde69707",
                                    "announcementComponent": "com.linkedin.f6c622cdcd9214c3ee563a8875d24fb3",
                                    "slideshowComponent": "com.linkedin.f70de4d604689acbffc0dcd8115c319d",
                                    "callToActionComponent": "com.linkedin.17602d9bd6fd3c2435cab1748e7900cf"
                                }
                            }
                        },
                        "leadGenFormContent": {
                            "type": "com.linkedin.25e46f67641278b642032923b20f3538"
                        },
                        "annotation": {
                            "type": "com.linkedin.d067ea339aae1c25da65a9f86eb786ad"
                        },
                        "contextualHeader": {
                            "type": "com.linkedin.86e9a3cd31f8dd276b8f2ceffc1d92ca"
                        },
                        "resharedUpdate": {
                            "type": "com.linkedin.757852411fb0feeedcbd4df1cbcfcd54"
                        },
                        "interstitial": {
                            "type": "com.linkedin.830169c9243be1975114d187616fcf29"
                        },
                        "additionalContentsUnions": {
                            "type": {
                                "array": {
                                    "union": {
                                        "toggleButtonComponent": "com.linkedin.0f36f2dc6be4ed6af3361a6356cb19e0",
                                        "feedDividerComponent": "com.linkedin.fd4f461137d628e214f2c67640064f40",
                                        "articleComponent": "com.linkedin.86b903c46b5240b03037ec8656976681",
                                        "eventComponent": "com.linkedin.827d2df06cbbd8888b228aac56a99cb5",
                                        "conversationsComponent": "com.linkedin.65bd51e43ed8142eb9d37a29845f6c04",
                                        "promoComponent": "com.linkedin.8ff002aafcb203f2b95c57c175c2f91c",
                                        "seeMoreComponent": "com.linkedin.dbe3dc7ec313938618c482695c80e952",
                                        "reviewComponent": "com.linkedin.74024cf712e3b910b92188d657a36b48",
                                        "feedDiscoveryGridComponent": "com.linkedin.dacb8097355f9a4b84257dcd4a72e01d",
                                        "gentlePromptComponent": "com.linkedin.82568376c49f8a966ad23174692c2071",
                                        "followPromptComponent": "com.linkedin.7f0cc4bcf6aef643d5c454ff48c96941",
                                        "jobComponent": "com.linkedin.292ed207e90e51c83f267296fa0c7940",
                                        "learningRecommendationComponent": "com.linkedin.b023a540cfe197e815b01a45eebe74b3",
                                        "surveyComponent": "com.linkedin.3a88e7bf8b5e1c81be38f30d05a7155c",
                                        "buttonComponent": "com.linkedin.280548a5c822f61a54f7d2022f1e02a5",
                                        "celebrationComponent": "com.linkedin.a61eaf39f1cf127adaf1233791804a39",
                                        "actorComponent": "com.linkedin.71b94ae4069ecc57933235cd51a72aee",
                                        "documentComponent": "com.linkedin.3623b786d2323fb52c13099cf2752b53",
                                        "creationStatusComponent": "com.linkedin.1734179c2744199ea6708a6613bdcede",
                                        "dynamicPollComponent": "com.linkedin.38c32cf9808204fff187465f6ac6683c",
                                        "newsletterComponent": "com.linkedin.cd89160de71b547693b54b81d054de0b",
                                        "postCtaComponent": "com.linkedin.3f4ae0934d738b90cbec63f10776b7ae",
                                        "scheduledLiveContentComponent": "com.linkedin.0af9905c7ec2db45db6070cde87109b5",
                                        "entityComponent": "com.linkedin.4f55a752e41ac24988f152a28efd3398",
                                        "externalVideoComponent": "com.linkedin.56ed1d753079896e9ad350e6f461c483",
                                        "linkedInVideoComponent": "com.linkedin.833e5a7fd479a007d026abce564deea5",
                                        "textOverlayImageComponent": "com.linkedin.c3576e4eb1959675613cf442c15650b9",
                                        "annotationComponent": "com.linkedin.d067ea339aae1c25da65a9f86eb786ad",
                                        "detailedSurveyComponent": "com.linkedin.ce17b3b18736cc798de33ecc17836156",
                                        "imageComponent": "com.linkedin.d388328a98f556cd5d952549ba61eff0",
                                        "showcaseComponent": "com.linkedin.499a0be5e49d2be9202b331ff124e675",
                                        "pollComponent": "com.linkedin.e3bf41d90ee4ffc0edf0c6e16c6a18c1",
                                        "coachPromptComponent": "com.linkedin.0686b967e27484975f7b854a8c3258d4",
                                        "feedDiscoveryEntityComponent": "com.linkedin.5b82b762410287f21f34b3d755f164dc",
                                        "promptComponent": "com.linkedin.37da0dcf9c4df3c725740cceef3f71e1",
                                        "contextualActionComponent": "com.linkedin.2aa0f2389f8b1f7666d3ba41965d9958",
                                        "commentaryComponent": "com.linkedin.5ce31f49adf6bd8cb496962bdde69707",
                                        "announcementComponent": "com.linkedin.f6c622cdcd9214c3ee563a8875d24fb3",
                                        "slideshowComponent": "com.linkedin.f70de4d604689acbffc0dcd8115c319d",
                                        "callToActionComponent": "com.linkedin.17602d9bd6fd3c2435cab1748e7900cf"
                                    }
                                }
                            }
                        },
                        "contextualDescription": {
                            "type": "com.linkedin.c8dbbe57bac604879f990ffdec11ee89"
                        },
                        "aggregatedContent": {
                            "type": "com.linkedin.7ffe66f430e869d947d257aaf7c1e2b8"
                        },
                        "socialDetail": {
                            "type": "com.linkedin.c3ca265f1d14f57e9246103e6f28929a"
                        },
                        "actor": {
                            "type": "com.linkedin.71b94ae4069ecc57933235cd51a72aee"
                        },
                        "boostHeader": {
                            "type": "com.linkedin.63dce7437c938cc483a7449c237eac59"
                        },
                        "header": {
                            "type": "com.linkedin.57397516101a62ce38ea32c68aecdfab"
                        },
                        "highlightedComments": {
                            "type": {
                                "array": "com.linkedin.89bd4e6ae57b7564ed65f21b35c3301f"
                            }
                        },
                        "preDashEntityUrn": {
                            "type": "com.linkedin.voyager.dash.common.PreDashUrn"
                        },
                        "commentary": {
                            "type": "com.linkedin.5ce31f49adf6bd8cb496962bdde69707"
                        },
                        "additionalContents": {
                            "derivedFrom": "additionalContentsUnions",
                            "type": {
                                "array": {
                                    "union": {
                                        "toggleButtonComponent": "com.linkedin.0f36f2dc6be4ed6af3361a6356cb19e0",
                                        "feedDividerComponent": "com.linkedin.fd4f461137d628e214f2c67640064f40",
                                        "articleComponent": "com.linkedin.86b903c46b5240b03037ec8656976681",
                                        "eventComponent": "com.linkedin.827d2df06cbbd8888b228aac56a99cb5",
                                        "conversationsComponent": "com.linkedin.65bd51e43ed8142eb9d37a29845f6c04",
                                        "promoComponent": "com.linkedin.8ff002aafcb203f2b95c57c175c2f91c",
                                        "seeMoreComponent": "com.linkedin.dbe3dc7ec313938618c482695c80e952",
                                        "reviewComponent": "com.linkedin.74024cf712e3b910b92188d657a36b48",
                                        "feedDiscoveryGridComponent": "com.linkedin.dacb8097355f9a4b84257dcd4a72e01d",
                                        "gentlePromptComponent": "com.linkedin.82568376c49f8a966ad23174692c2071",
                                        "followPromptComponent": "com.linkedin.7f0cc4bcf6aef643d5c454ff48c96941",
                                        "jobComponent": "com.linkedin.292ed207e90e51c83f267296fa0c7940",
                                        "learningRecommendationComponent": "com.linkedin.b023a540cfe197e815b01a45eebe74b3",
                                        "surveyComponent": "com.linkedin.3a88e7bf8b5e1c81be38f30d05a7155c",
                                        "buttonComponent": "com.linkedin.280548a5c822f61a54f7d2022f1e02a5",
                                        "celebrationComponent": "com.linkedin.a61eaf39f1cf127adaf1233791804a39",
                                        "actorComponent": "com.linkedin.71b94ae4069ecc57933235cd51a72aee",
                                        "documentComponent": "com.linkedin.3623b786d2323fb52c13099cf2752b53",
                                        "creationStatusComponent": "com.linkedin.1734179c2744199ea6708a6613bdcede",
                                        "dynamicPollComponent": "com.linkedin.38c32cf9808204fff187465f6ac6683c",
                                        "newsletterComponent": "com.linkedin.cd89160de71b547693b54b81d054de0b",
                                        "postCtaComponent": "com.linkedin.3f4ae0934d738b90cbec63f10776b7ae",
                                        "scheduledLiveContentComponent": "com.linkedin.0af9905c7ec2db45db6070cde87109b5",
                                        "entityComponent": "com.linkedin.4f55a752e41ac24988f152a28efd3398",
                                        "externalVideoComponent": "com.linkedin.56ed1d753079896e9ad350e6f461c483",
                                        "linkedInVideoComponent": "com.linkedin.833e5a7fd479a007d026abce564deea5",
                                        "textOverlayImageComponent": "com.linkedin.c3576e4eb1959675613cf442c15650b9",
                                        "annotationComponent": "com.linkedin.d067ea339aae1c25da65a9f86eb786ad",
                                        "detailedSurveyComponent": "com.linkedin.ce17b3b18736cc798de33ecc17836156",
                                        "imageComponent": "com.linkedin.d388328a98f556cd5d952549ba61eff0",
                                        "showcaseComponent": "com.linkedin.499a0be5e49d2be9202b331ff124e675",
                                        "pollComponent": "com.linkedin.e3bf41d90ee4ffc0edf0c6e16c6a18c1",
                                        "coachPromptComponent": "com.linkedin.0686b967e27484975f7b854a8c3258d4",
                                        "feedDiscoveryEntityComponent": "com.linkedin.5b82b762410287f21f34b3d755f164dc",
                                        "promptComponent": "com.linkedin.37da0dcf9c4df3c725740cceef3f71e1",
                                        "contextualActionComponent": "com.linkedin.2aa0f2389f8b1f7666d3ba41965d9958",
                                        "commentaryComponent": "com.linkedin.5ce31f49adf6bd8cb496962bdde69707",
                                        "announcementComponent": "com.linkedin.f6c622cdcd9214c3ee563a8875d24fb3",
                                        "slideshowComponent": "com.linkedin.f70de4d604689acbffc0dcd8115c319d",
                                        "callToActionComponent": "com.linkedin.17602d9bd6fd3c2435cab1748e7900cf"
                                    }
                                }
                            }
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.Update"
                },
                "com.linkedin.d2f69f81cddf8b512448d332a9bf5d15": {
                    "fields": {
                        "checked": {
                            "type": "boolean"
                        },
                        "text": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.sponsoredcontent.leadgen.CheckboxComponent"
                },
                "com.linkedin.ff4c51d111da4ffaaae179a2eaf9a303": {
                    "fields": {
                        "legoTrackingToken": {
                            "type": "string"
                        },
                        "promptText": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "coachFeedUrn": {
                            "type": "com.linkedin.voyager.dash.common.CoachFeedUrn"
                        },
                        "dwellTimeAnimationDuration": {
                            "type": "int"
                        },
                        "serverIntent": {
                            "type": "string"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.coachaction.CoachAction"
                },
                "com.linkedin.c0eb7f9edecfa9e869f6b58f4a26bc93": {
                    "fields": {
                        "unread": {
                            "type": "boolean"
                        },
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.JobActivityCardUrn"
                        },
                        "readIndicatorAccessibilityText": {
                            "type": "string"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.jobs.JobActivityCard"
                },
                "com.linkedin.eb94fbb1518f790c4545aafdf571c64e": {
                    "fields": {
                        "detailData": {
                            "resolvedFrom": "detailDataUnion",
                            "type": {
                                "union": {
                                    "profilePictureWithoutFrame": "com.linkedin.e0372afc4a18480b00ca7e4906904fd7",
                                    "profilePictureWithRingStatus": "com.linkedin.e0372afc4a18480b00ca7e4906904fd7",
                                    "companyLogo": "com.linkedin.2c2374bef3eaba3e079b4a11e2f7bea8",
                                    "icon": "com.linkedin.voyager.dash.common.ArtDecoIconName",
                                    "systemImage": "com.linkedin.voyager.dash.common.SystemImageName",
                                    "nonEntityGroupLogo": "com.linkedin.14537f958f34fe6d11e2a5ec02e5ca16",
                                    "vectorImage": "com.linkedin.28db8575bcf1c65bdc4bc15948d50ee9",
                                    "nonEntityProfessionalEventLogo": "com.linkedin.ec44aca6a639309aabe15e50093f4e6a",
                                    "profilePicture": "com.linkedin.e0372afc4a18480b00ca7e4906904fd7",
                                    "imageUrl": "com.linkedin.f2e92768122faa3236a3da8d98ae1bad",
                                    "professionalEventLogo": "com.linkedin.a780c129a85db3680157820ba19315f2",
                                    "nonEntitySchoolLogo": "com.linkedin.40aec9fadea85bb6c6cc433e84fa91b7",
                                    "nonEntityCompanyLogo": "com.linkedin.3be27b5a0eb7edd91e98b14c0290096c",
                                    "schoolLogo": "com.linkedin.daa3a2cada5a579731c11a78fbd82e2d",
                                    "groupLogo": "com.linkedin.c8f5bf5a9d5e0dbbc3c824c2dfd751a8",
                                    "ghostImage": "com.linkedin.voyager.dash.common.image.GhostImageType",
                                    "nonEntityProfilePicture": "com.linkedin.4b009c1d6ea192a94bda77fb9ace3a7d"
                                }
                            }
                        },
                        "tintColor": {
                            "type": "com.linkedin.voyager.dash.common.SystemImageTintColor"
                        },
                        "detailDataUnion": {
                            "type": {
                                "union": {
                                    "profilePictureWithoutFrame": "string",
                                    "profilePictureWithRingStatus": "string",
                                    "companyLogo": "string",
                                    "icon": "com.linkedin.voyager.dash.common.ArtDecoIconName",
                                    "systemImage": "com.linkedin.voyager.dash.common.SystemImageName",
                                    "nonEntityGroupLogo": "com.linkedin.14537f958f34fe6d11e2a5ec02e5ca16",
                                    "vectorImage": "com.linkedin.28db8575bcf1c65bdc4bc15948d50ee9",
                                    "nonEntityProfessionalEventLogo": "com.linkedin.ec44aca6a639309aabe15e50093f4e6a",
                                    "profilePicture": "string",
                                    "imageUrl": "com.linkedin.f2e92768122faa3236a3da8d98ae1bad",
                                    "professionalEventLogo": "string",
                                    "nonEntitySchoolLogo": "com.linkedin.40aec9fadea85bb6c6cc433e84fa91b7",
                                    "nonEntityCompanyLogo": "com.linkedin.3be27b5a0eb7edd91e98b14c0290096c",
                                    "schoolLogo": "string",
                                    "groupLogo": "string",
                                    "ghostImage": "com.linkedin.voyager.dash.common.image.GhostImageType",
                                    "nonEntityProfilePicture": "com.linkedin.4b009c1d6ea192a94bda77fb9ace3a7d"
                                }
                            }
                        },
                        "tapTargets": {
                            "type": {
                                "array": "com.linkedin.c47b47d5266a72a0c07dc72ecee637c0"
                            }
                        },
                        "scalingType": {
                            "type": "com.linkedin.voyager.dash.common.image.ScalingType"
                        },
                        "displayAspectRatio": {
                            "type": "double"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.common.image.ImageAttribute"
                },
                "com.linkedin.bc0bbec78a9509f86af3f11c12b1caee": {
                    "fields": {
                        "streamingLocations": {
                            "type": {
                                "array": "com.linkedin.b75375948b8af489d842205d21abee34"
                            }
                        },
                        "size": {
                            "type": "long"
                        },
                        "bitRate": {
                            "type": "int"
                        },
                        "width": {
                            "type": "int"
                        },
                        "mediaType": {
                            "type": "string"
                        },
                        "mimeType": {
                            "type": "com.linkedin.videocontent.MimeType"
                        },
                        "height": {
                            "type": "int"
                        }
                    },
                    "baseType": "com.linkedin.videocontent.ProgressiveDownloadMetadata"
                },
                "com.linkedin.3364fdf0c31e8944591cc641a1757061": {
                    "fields": {
                        "options": {
                            "type": {
                                "array": "com.linkedin.abb1b649ad52210bbeb6ed9916741aa1"
                            }
                        },
                        "titleImage": {
                            "type": "com.linkedin.voyager.dash.common.SystemImageName"
                        },
                        "titleA11yText": {
                            "type": "string"
                        },
                        "titleText": {
                            "type": "string"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.survey.SingleSelectSurveyContent"
                },
                "com.linkedin.6923f8904eacad15ebec50462e5cb990": {
                    "fields": {
                        "type": {
                            "type": "com.linkedin.voyager.dash.common.text.EpochFormat"
                        },
                        "epochAt": {
                            "type": "com.linkedin.common.Time"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.common.text.EpochTime"
                },
                "com.linkedin.6bf32d88af325c3a70ac92d1594add6d": {
                    "fields": {
                        "sponsoredTracking": {
                            "type": "com.linkedin.5afa622044b87152ca004741a0def2a9"
                        },
                        "backendUrn": {
                            "type": "com.linkedin.common.Urn"
                        },
                        "requestId": {
                            "type": "string"
                        },
                        "trackingId": {
                            "type": "com.linkedin.voyager.dash.common.Base64String"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.metadata.TrackingData"
                },
                "com.linkedin.791d0c903911aab58f40e6744715af71": {
                    "fields": {
                        "footerItems": {
                            "type": {
                                "array": "com.linkedin.ae028897a212c87f2a4f1a573b71652d"
                            }
                        },
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.JobPostingCardUrn"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.jobs.JobPostingCard"
                },
                "com.linkedin.f0ea208d22501bf7318e3df763a071db": {
                    "fields": {
                        "image": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "text": {
                            "type": "string"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.common.coach.LoadingMessage"
                },
                "com.linkedin.f6c622cdcd9214c3ee563a8875d24fb3": {
                    "fields": {
                        "actor": {
                            "type": "com.linkedin.71b94ae4069ecc57933235cd51a72aee"
                        },
                        "navigationContext": {
                            "type": "com.linkedin.8a612b4e445851d55ecf8b09571a05ee"
                        },
                        "title": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "subtitle": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.announcement.AnnouncementComponent"
                },
                "com.linkedin.d5750a45700fb234845060fc6e66e87d": {
                    "fields": {
                        "companyUrn": {
                            "type": "string"
                        },
                        "company": {
                            "resolvedFrom": "companyUrn",
                            "type": "com.linkedin.2c2374bef3eaba3e079b4a11e2f7bea8"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.relationships.MemberToCompanyFollowMetadata"
                },
                "com.linkedin.6f5340bf6dde14897b3d4dde77e536d0": {
                    "fields": {
                        "subscribed": {
                            "type": "boolean"
                        },
                        "subscribeConfirmationMessage": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.SubscribeActionUrn"
                        },
                        "subscriberCount": {
                            "type": "int"
                        },
                        "unsubscribeConfirmationMessage": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "type": {
                            "type": "com.linkedin.voyager.dash.publishing.SubscribeActionType"
                        },
                        "preDashEntityUrn": {
                            "type": "com.linkedin.voyager.dash.common.PreDashUrn"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.publishing.SubscribeAction"
                },
                "com.linkedin.9f8aac2973836344836ca4eae9664da3": {
                    "fields": {
                        "controlName": {
                            "type": "com.linkedin.voyager.dash.common.tracking.ControlName"
                        },
                        "viewingBehavior": {
                            "type": "com.linkedin.voyager.dash.common.ux.UrlViewingBehavior"
                        },
                        "sponsoredUrlAttributes": {
                            "type": "com.linkedin.d853c03d4547334c4f244bc136796f0b"
                        },
                        "url": {
                            "type": "com.linkedin.common.Url"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.common.text.TextLink"
                },
                "com.linkedin.e0f66be580bd7d47ebba01fec6a204e4": {
                    "fields": {
                        "lineStartAt": {
                            "type": "long"
                        },
                        "caption": {
                            "type": "string"
                        },
                        "lineEndAt": {
                            "type": "long"
                        }
                    },
                    "baseType": "com.linkedin.videocontent.TranscriptLine"
                },
                "com.linkedin.5f1d22f924ecb6a031ee124b8b767900": {
                    "fields": {
                        "paging": {
                            "type": "com.linkedin.81b214c2cdd4f02cdb7d827958d2f3a1"
                        },
                        "metadata": {
                            "type": "com.linkedin.dfce49e2c6bb412fb4161cbbc7190d0d"
                        },
                        "elements": {
                            "type": {
                                "array": "com.linkedin.5c853aba2154c55483e72bf6cdfaaf3e"
                            }
                        }
                    },
                    "baseType": "com.linkedin.restli.common.CollectionResponse"
                },
                "com.linkedin.0fbb066482da3106482c7cfb8f69e70f": {
                    "fields": {
                        "composeNavigationContext": {
                            "type": "com.linkedin.dbc196cb1403f434db1f269623b4a620"
                        },
                        "icon": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "displayText": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "textStartIcon": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "composeOptionType": {
                            "type": "com.linkedin.voyager.dash.messaging.compose.ComposeOptionType"
                        },
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.ComposeOptionUrn"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.messaging.compose.ComposeOption"
                },
                "com.linkedin.28bac58e0d18d7324652c1411b75d180": {
                    "fields": {
                        "votedPollOptionUrns": {
                            "type": {
                                "array": "com.linkedin.voyager.dash.common.PollOptionUrn"
                            }
                        },
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.PollSummaryUrn"
                        },
                        "remainingDuration": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "closed": {
                            "type": "boolean"
                        },
                        "uniqueVotersCount": {
                            "type": "long"
                        },
                        "preDashVotedPollOptionUrns": {
                            "type": {
                                "array": "com.linkedin.voyager.dash.common.PreDashUrn"
                            }
                        },
                        "preDashEntityUrn": {
                            "type": "com.linkedin.voyager.dash.common.PreDashUrn"
                        },
                        "pollOptionSummaries": {
                            "type": {
                                "array": "com.linkedin.d9d0d5044f5a15e3db4ff2b1e0a84438"
                            }
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.polls.PollSummary"
                },
                "com.linkedin.833e5a7fd479a007d026abce564deea5": {
                    "fields": {
                        "headlineBackgroundColor": {
                            "type": "com.linkedin.voyager.dash.feed.palette.ux.HeadlineBackgroundColor"
                        },
                        "embedUrl": {
                            "type": "com.linkedin.common.Url"
                        },
                        "headlineAnimation": {
                            "type": "com.linkedin.voyager.dash.feed.component.linkedinvideo.LinkedInVideoAnimationType"
                        },
                        "saveState": {
                            "type": "com.linkedin.f1b2492c05b41398477b887761d337a9"
                        },
                        "bannerType": {
                            "type": "com.linkedin.voyager.dash.video.VideoBannerType"
                        },
                        "viewerState": {
                            "resolvedFrom": "viewerStateUrn",
                            "type": "com.linkedin.795aca8b0690435f405c793a8ffcf615"
                        },
                        "videoPlayMetadata": {
                            "type": "com.linkedin.762fc611b9734ba7fde2123ce919a75e"
                        },
                        "concurrentViewerCountTopicUrn": {
                            "type": "com.linkedin.common.ConcurrentViewerCountTopicUrn"
                        },
                        "emitPromoTracking": {
                            "type": "boolean"
                        },
                        "concurrentViewerCount": {
                            "type": "int"
                        },
                        "title": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "titleContext": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "shouldDisplayLiveIndicator": {
                            "type": "boolean"
                        },
                        "swapTitleAndSubtitle": {
                            "type": "boolean"
                        },
                        "sponsoredVideoCompletionCta": {
                            "type": "com.linkedin.0a96d009c911ac54d5adcea16e939124"
                        },
                        "inStreamAds": {
                            "type": {
                                "array": "com.linkedin.ad971ca555acf30934fdee34cee9d67d"
                            }
                        },
                        "insightImage": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "showSmallTitle": {
                            "type": "boolean"
                        },
                        "viewerTrackingTopicUrn": {
                            "type": "com.linkedin.common.ViewerTrackingTopicUrn"
                        },
                        "tapTargets": {
                            "type": {
                                "array": "com.linkedin.c47b47d5266a72a0c07dc72ecee637c0"
                            }
                        },
                        "videoPreviewMetadata": {
                            "type": "com.linkedin.fd159a3b501495478a862571293c7307"
                        },
                        "overlayTexts": {
                            "type": {
                                "array": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                            }
                        },
                        "preEventRegistrationImage": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "largeCtaButton": {
                            "type": "com.linkedin.280548a5c822f61a54f7d2022f1e02a5"
                        },
                        "descriptionContainerNavigationContext": {
                            "type": "com.linkedin.8a612b4e445851d55ecf8b09571a05ee"
                        },
                        "trimOffsetEnd": {
                            "type": "long"
                        },
                        "inlineCtaButton": {
                            "type": "com.linkedin.280548a5c822f61a54f7d2022f1e02a5"
                        },
                        "containerAspectRatio": {
                            "type": "float"
                        },
                        "trimOffsetStart": {
                            "type": "long"
                        },
                        "sponsoredLandingUrlViewingBehavior": {
                            "type": "com.linkedin.voyager.dash.common.ux.UrlViewingBehavior"
                        },
                        "viewerStateUrn": {
                            "type": "string"
                        },
                        "inPlayerCta": {
                            "type": "com.linkedin.02ae76f0e0810b81c62a4dd5f1cc509f"
                        },
                        "autoTranscriptEnabled": {
                            "type": "boolean"
                        },
                        "subtitle": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "editableVideoAttributes": {
                            "type": {
                                "array": "com.linkedin.voyager.dash.feed.component.linkedinvideo.EditableVideoAttributeType"
                            }
                        },
                        "sponsoredLandingUrl": {
                            "type": "com.linkedin.common.Url"
                        },
                        "navigationContext": {
                            "type": "com.linkedin.8a612b4e445851d55ecf8b09571a05ee"
                        },
                        "autoTranscriptToggleable": {
                            "type": "boolean"
                        },
                        "insightText": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.linkedinvideo.LinkedInVideoComponent"
                },
                "com.linkedin.0229fe28a11bea61a508c08302192f7d": {
                    "fields": {
                        "elements": {
                            "type": {
                                "array": "com.linkedin.5c853aba2154c55483e72bf6cdfaaf3e"
                            }
                        }
                    },
                    "baseType": "com.linkedin.restli.common.CollectionResponse"
                },
                "com.linkedin.191c4aa50072107393c644d1284e6a09": {
                    "fields": {
                        "clickThroughActionText": {
                            "type": "string"
                        },
                        "shouldShowInterstitial": {
                            "type": "boolean"
                        },
                        "navigationClickThroughAction": {
                            "type": "com.linkedin.20a39c821c63e5f1da8b29c1b05ff0ad"
                        },
                        "shouldBlurContent": {
                            "type": "boolean"
                        },
                        "icon": {
                            "type": "com.linkedin.voyager.dash.common.SystemImageName"
                        },
                        "title": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "trackingId": {
                            "type": "com.linkedin.common.TrackingId"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.interstitial.InterstitialViewModel"
                },
                "com.linkedin.5900d2a09d6af2333ee95a4de2785dc0": {
                    "fields": {
                        "subscribed": {
                            "type": "boolean"
                        },
                        "showManageAlerts": {
                            "type": "boolean"
                        },
                        "showBanner": {
                            "type": "boolean"
                        },
                        "keywords": {
                            "type": "string"
                        },
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.SearchAlertUrn"
                        },
                        "trackingId": {
                            "type": "com.linkedin.common.TrackingId"
                        },
                        "frequency": {
                            "type": "com.linkedin.voyager.dash.search.SearchAlertFrequency"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.SearchAlert"
                },
                "com.linkedin.e58399cfa33284b0ebcc7a60779f763b": {
                    "fields": {
                        "captionFormat": {
                            "type": "com.linkedin.videocontent.CaptionFormat"
                        },
                        "locale": {
                            "type": "com.linkedin.f77b3da15411c8424bc6239fecafe2db"
                        },
                        "lines": {
                            "type": {
                                "array": "com.linkedin.e0f66be580bd7d47ebba01fec6a204e4"
                            }
                        },
                        "isAutogenerated": {
                            "type": "boolean"
                        },
                        "captionFile": {
                            "type": "com.linkedin.common.Url"
                        }
                    },
                    "baseType": "com.linkedin.videocontent.Transcript"
                },
                "com.linkedin.bf4a9da37c7bd305a433eb83fc687ec9": {
                    "fields": {
                        "questions": {
                            "type": {
                                "array": "com.linkedin.4800cf47c45b503f71b557dd2e8d1a53"
                            }
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.sponsoredcontent.leadgen.LeadGenFormSection"
                },
                "com.linkedin.2f237373fe71eba70adab84023a31b11": {
                    "fields": {
                        "width": {
                            "type": "int"
                        },
                        "imageUrls": {
                            "type": {
                                "array": "com.linkedin.common.Url"
                            }
                        },
                        "height": {
                            "type": "int"
                        }
                    },
                    "baseType": "com.linkedin.documentcontent.DocumentResolutionPages"
                },
                "com.linkedin.7f0cc4bcf6aef643d5c454ff48c96941": {
                    "fields": {
                        "navigationContext": {
                            "type": "com.linkedin.8a612b4e445851d55ecf8b09571a05ee"
                        },
                        "description": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "actorImage": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "title": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "followAction": {
                            "type": "com.linkedin.d50733b664c8019ae5d38b1804596f0b"
                        },
                        "trackingId": {
                            "type": "com.linkedin.common.TrackingId"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.followprompt.FollowPromptComponent"
                },
                "com.linkedin.56970f4601ade63e2f097f9ecfc9be75": {
                    "fields": {
                        "transcribedDocumentUrl": {
                            "type": "com.linkedin.common.Url"
                        },
                        "urn": {
                            "type": "com.linkedin.common.Urn"
                        },
                        "sliced": {
                            "type": "boolean"
                        },
                        "manifestUrl": {
                            "type": "com.linkedin.common.Url"
                        },
                        "scanRequiredForDownload": {
                            "type": "boolean"
                        },
                        "totalPageCount": {
                            "type": "int"
                        },
                        "manifestUrlExpiresAt": {
                            "type": "com.linkedin.common.Time"
                        },
                        "title": {
                            "type": "string"
                        },
                        "fullDocumentPageCount": {
                            "type": "int"
                        },
                        "coverPages": {
                            "type": "com.linkedin.b6bf8ef542d64cafbaf37dcc36abf642"
                        },
                        "transcribedDocumentUrlExpiresAt": {
                            "type": "com.linkedin.common.Time"
                        }
                    },
                    "baseType": "com.linkedin.documentcontent.Document"
                },
                "com.linkedin.2ad3fd8797b9b4ab88c9029eab02f2ee": {
                    "fields": {
                        "title": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "subtext": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "text": {
                            "type": "string"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.DebugDataPoint"
                },
                "com.linkedin.c03d6d673ac4f7503bd4aeb7d200cfd7": {
                    "fields": {
                        "memberRelationshipUnion": {
                            "type": {
                                "union": {
                                    "self": "com.linkedin.7f6822f991ba515653ea40e7a6f66203",
                                    "connection": "com.linkedin.222901e411e8a1fbd130cb14efdb6c72",
                                    "noConnection": "com.linkedin.05a26c8d0e313e91515bf71c4ea8b9c4"
                                }
                            }
                        },
                        "memberRelationshipDataResolutionResult": {
                            "derivedFrom": "memberRelationshipData",
                            "type": {
                                "union": {
                                    "noInvitation": "com.linkedin.a33c5676b727948bb8920b5502949103",
                                    "connection": "com.linkedin.222901e411e8a1fbd130cb14efdb6c72",
                                    "invitation": "com.linkedin.b95815644054b75e89af04b98b438272"
                                }
                            }
                        },
                        "memberRelationshipData": {
                            "type": {
                                "union": {
                                    "noInvitation": "com.linkedin.a33c5676b727948bb8920b5502949103",
                                    "connection": "com.linkedin.222901e411e8a1fbd130cb14efdb6c72",
                                    "invitation": "com.linkedin.b95815644054b75e89af04b98b438272"
                                }
                            }
                        },
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.MemberRelationshipUrn"
                        },
                        "memberRelationship": {
                            "derivedFrom": "memberRelationshipUnion",
                            "type": {
                                "union": {
                                    "self": "com.linkedin.7f6822f991ba515653ea40e7a6f66203",
                                    "connection": "com.linkedin.222901e411e8a1fbd130cb14efdb6c72",
                                    "noConnection": "com.linkedin.05a26c8d0e313e91515bf71c4ea8b9c4"
                                }
                            }
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.relationships.MemberRelationship"
                },
                "com.linkedin.dacb8097355f9a4b84257dcd4a72e01d": {
                    "fields": {
                        "ctaButton": {
                            "type": "com.linkedin.280548a5c822f61a54f7d2022f1e02a5"
                        },
                        "feedDiscoveryEntityComponents": {
                            "type": {
                                "array": "com.linkedin.5b82b762410287f21f34b3d755f164dc"
                            }
                        },
                        "title": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "subtitle": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.discoverygrid.FeedDiscoveryGridComponent"
                },
                "com.linkedin.093e0b8e090aa84ca579dd651a03deb7": {
                    "fields": {
                        "icon": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "headlineV2": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.premium.plans.PremiumFeature"
                },
                "com.linkedin.ab57de991a452be4a5e752f1671b1e62": {
                    "fields": {
                        "displayImageWithFrameReferenceUnion": {
                            "type": {
                                "union": {
                                    "url": "com.linkedin.common.Url",
                                    "vectorImage": "com.linkedin.28db8575bcf1c65bdc4bc15948d50ee9"
                                }
                            }
                        },
                        "originalImageUrn": {
                            "type": "com.linkedin.common.Urn"
                        },
                        "displayImageReferenceResolutionResult": {
                            "derivedFrom": "displayImageReference",
                            "type": {
                                "union": {
                                    "url": "com.linkedin.common.Url",
                                    "vectorImage": "com.linkedin.28db8575bcf1c65bdc4bc15948d50ee9"
                                }
                            }
                        },
                        "displayImageWithFrameReference": {
                            "derivedFrom": "displayImageWithFrameReferenceUnion",
                            "type": {
                                "union": {
                                    "url": "com.linkedin.common.Url",
                                    "vectorImage": "com.linkedin.28db8575bcf1c65bdc4bc15948d50ee9"
                                }
                            }
                        },
                        "a11yText": {
                            "type": "string"
                        },
                        "displayImageReference": {
                            "type": {
                                "union": {
                                    "url": "com.linkedin.common.Url",
                                    "vectorImage": "com.linkedin.28db8575bcf1c65bdc4bc15948d50ee9"
                                }
                            }
                        },
                        "frameType": {
                            "type": "com.linkedin.voyager.dash.identity.profile.PhotoFrameType"
                        },
                        "displayImageUrn": {
                            "type": "com.linkedin.common.Urn"
                        },
                        "isGeneratedOrModifiedByAi": {
                            "type": "boolean"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.identity.profile.PhotoFilterPicture"
                },
                "com.linkedin.782605f8edce467fd20512c8e7dd06c2": {
                    "fields": {
                        "controlName": {
                            "type": "com.linkedin.voyager.dash.common.tracking.ControlName"
                        },
                        "message": {
                            "type": "string"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.DialogCTA"
                },
                "com.linkedin.51e42327aac2bfbade58f05c0e5df6d5": {
                    "fields": {
                        "displayText": {
                            "type": "string"
                        },
                        "trackingId": {
                            "type": "com.linkedin.common.TrackingId"
                        },
                        "text": {
                            "type": "string"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.social.ConversationStarter"
                },
                "com.linkedin.f0f435b4425ee2990eba8f0a4d614944": {
                    "fields": {
                        "width": {
                            "type": "int"
                        },
                        "fileIdentifyingUrlPathSegment": {
                            "type": "string"
                        },
                        "expiresAt": {
                            "type": "com.linkedin.common.Time"
                        },
                        "height": {
                            "type": "int"
                        }
                    },
                    "baseType": "com.linkedin.common.VectorArtifact"
                },
                "com.linkedin.0ee870519ed5910d9150d68cc65332f5": {
                    "fields": {
                        "message": {
                            "type": "string"
                        },
                        "icon": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "text": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.ShareViaPostAction"
                },
                "com.linkedin.9a5cfd1782f34ef4cc794e99854515b7": {
                    "fields": {
                        "readIndicatorAccessibilityText": {
                            "type": "string"
                        },
                        "unread": {
                            "type": "boolean"
                        },
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.MarketplaceProjectStateUrn"
                        },
                        "open": {
                            "type": "boolean"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.marketplaces.projects.MarketplaceProjectState"
                },
                "com.linkedin.5b25413c8b10039f1c2b38d4a221c06f": {
                    "fields": {
                        "initialBitRate": {
                            "type": "int"
                        },
                        "mediaType": {
                            "type": "string"
                        },
                        "protocol": {
                            "type": "com.linkedin.videocontent.AdaptiveStreamProtocol"
                        },
                        "masterPlaylists": {
                            "type": {
                                "array": "com.linkedin.b75375948b8af489d842205d21abee34"
                            }
                        }
                    },
                    "baseType": "com.linkedin.videocontent.AdaptiveStream"
                },
                "com.linkedin.a33c5676b727948bb8920b5502949103": {
                    "fields": {
                        "targetInviteeResolutionResult": {
                            "resolvedFrom": "targetInvitee",
                            "type": "com.linkedin.e0372afc4a18480b00ca7e4906904fd7"
                        },
                        "inviter": {
                            "type": "string"
                        },
                        "targetInvitee": {
                            "type": "string"
                        },
                        "invitationRelationshipForm": {
                            "type": "com.linkedin.40871a3bc360eff8b27a30f69792683e"
                        },
                        "inviterResolutionResult": {
                            "resolvedFrom": "inviter",
                            "type": "com.linkedin.e0372afc4a18480b00ca7e4906904fd7"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.relationships.invitation.NoInvitation"
                },
                "com.linkedin.28db8575bcf1c65bdc4bc15948d50ee9": {
                    "fields": {
                        "attribution": {
                            "type": "string"
                        },
                        "c2paManifestData": {
                            "type": "com.linkedin.6682f4c299a743c2d0af15465ee7b16d"
                        },
                        "digitalmediaAsset": {
                            "type": "com.linkedin.common.DigitalmediaAssetUrn"
                        },
                        "rootUrl": {
                            "type": "string"
                        },
                        "artifacts": {
                            "type": {
                                "array": "com.linkedin.f0f435b4425ee2990eba8f0a4d614944"
                            }
                        }
                    },
                    "baseType": "com.linkedin.common.VectorImage"
                },
                "com.linkedin.efdd020b9332e11832dc0f931a05622c": {
                    "fields": {
                        "dataPoints": {
                            "type": {
                                "array": "com.linkedin.2ad3fd8797b9b4ab88c9029eab02f2ee"
                            }
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.DebugComponent"
                },
                "com.linkedin.dc97b0d2074b2777db3e7e9da9a583ed": {
                    "fields": {
                        "urn": {
                            "type": "com.linkedin.common.Urn"
                        },
                        "modelName": {
                            "type": "string"
                        },
                        "fieldName": {
                            "type": "string"
                        },
                        "value": {
                            "type": "string"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.common.StringFieldReference"
                },
                "com.linkedin.0a96d009c911ac54d5adcea16e939124": {
                    "fields": {
                        "callToActionSubtext": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "callToActionNavigationContext": {
                            "type": "com.linkedin.8a612b4e445851d55ecf8b09571a05ee"
                        },
                        "callToActionText": {
                            "type": "string"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.linkedinvideo.SponsoredVideoCompletionCta"
                },
                "com.linkedin.ee5bba1694c397d20c1a9f36d23cc16d": {
                    "fields": {
                        "insight": {
                            "type": "com.linkedin.bd9a707a5b119c1f331373113f57344a"
                        },
                        "carousel": {
                            "type": "com.linkedin.5c853aba2154c55483e72bf6cdfaaf3e"
                        },
                        "answer": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "question": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.SearchQuestionAndAnswerUrn"
                        },
                        "trackingId": {
                            "type": "com.linkedin.common.TrackingId"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.SearchQuestionAndAnswerCard"
                },
                "com.linkedin.87379e51008ea9e2f1313627bb4cab8b": {
                    "fields": {
                        "groupPostUrn": {
                            "type": "com.linkedin.common.Urn"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.actions.recommend.RecommendGroupPostAction"
                },
                "com.linkedin.cb566040fbbf36857f28249822e9b046": {
                    "fields": {
                        "tapTargets": {
                            "type": {
                                "array": "com.linkedin.c47b47d5266a72a0c07dc72ecee637c0"
                            }
                        },
                        "videoPlayMetadata": {
                            "type": "com.linkedin.762fc611b9734ba7fde2123ce919a75e"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.slideshow.VideoSlide"
                },
                "com.linkedin.71b94ae4069ecc57933235cd51a72aee": {
                    "fields": {
                        "connectAction": {
                            "type": "com.linkedin.c97d64dfd15204616a896fea6339d850"
                        },
                        "image": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "supplementaryActorInfo": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "description": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "backendUrn": {
                            "type": "com.linkedin.common.Urn"
                        },
                        "followAction": {
                            "type": "com.linkedin.d50733b664c8019ae5d38b1804596f0b"
                        },
                        "subDescriptionButton": {
                            "type": "com.linkedin.280548a5c822f61a54f7d2022f1e02a5"
                        },
                        "groupMembershipForJoinActionUrn": {
                            "type": "string"
                        },
                        "subDescription": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "name": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "navigationContext": {
                            "type": "com.linkedin.8a612b4e445851d55ecf8b09571a05ee"
                        },
                        "ringStatus": {
                            "type": "com.linkedin.9d67b80fb82e3d96227749fd6d468116"
                        },
                        "groupMembershipForJoinAction": {
                            "resolvedFrom": "groupMembershipForJoinActionUrn",
                            "type": "com.linkedin.7f12f9be2e6b0e371ad2f98ce1324e16"
                        },
                        "showSmallActorPortrait": {
                            "type": "boolean"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.actor.ActorComponent"
                },
                "com.linkedin.36822f6ade039002d5290c479023c95f": {
                    "fields": {
                        "cancelCTA": {
                            "type": "com.linkedin.782605f8edce467fd20512c8e7dd06c2"
                        },
                        "message": {
                            "type": "string"
                        },
                        "title": {
                            "type": "string"
                        },
                        "confirmCTA": {
                            "type": "com.linkedin.782605f8edce467fd20512c8e7dd06c2"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.ConfirmationDialog"
                },
                "com.linkedin.292ed207e90e51c83f267296fa0c7940": {
                    "fields": {
                        "ctaButton": {
                            "type": "com.linkedin.280548a5c822f61a54f7d2022f1e02a5"
                        },
                        "insight": {
                            "type": "com.linkedin.7737d1abf743001bc78e672aaeea5e65"
                        },
                        "image": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "footer": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "subdescription": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "backgroundImage": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "subtitle": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "navigationContext": {
                            "type": "com.linkedin.8a612b4e445851d55ecf8b09571a05ee"
                        },
                        "description": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "title": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.job.JobComponent"
                },
                "com.linkedin.0134fedeb876326e67efb0b562630cc0": {
                    "fields": {
                        "viewImpressionEventName": {
                            "type": "string"
                        },
                        "appliedCount": {
                            "type": "int"
                        },
                        "highlighted": {
                            "type": "boolean"
                        },
                        "filterClickControlName": {
                            "type": "string"
                        },
                        "displayName": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "secondaryFilterValues": {
                            "type": {
                                "array": "com.linkedin.83d0ac7bcab35bfe2d9bcd29421a7f1f"
                            }
                        },
                        "typeaheadFilterQuery": {
                            "type": "com.linkedin.ef90ea21b3b3f3c01953959ef696d447"
                        },
                        "startIcon": {
                            "type": "com.linkedin.voyager.dash.common.SystemImageName"
                        },
                        "typeaheadHint": {
                            "type": "string"
                        },
                        "typeaheadType": {
                            "type": "com.linkedin.voyager.dash.search.TypeaheadType"
                        },
                        "parameterName": {
                            "type": "string"
                        },
                        "title": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "searchActionType": {
                            "type": "string"
                        },
                        "flatten": {
                            "type": "boolean"
                        },
                        "filterApplyControlName": {
                            "type": "string"
                        },
                        "primaryFilterValues": {
                            "type": {
                                "array": "com.linkedin.83d0ac7bcab35bfe2d9bcd29421a7f1f"
                            }
                        },
                        "renderType": {
                            "type": "com.linkedin.voyager.dash.search.SearchFilterRenderType"
                        },
                        "trackingId": {
                            "type": "com.linkedin.voyager.dash.common.Base64String"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.SearchFilterViewModel"
                },
                "com.linkedin.c57f38371161fd69925d6e010ce4c0b9": {
                    "fields": {
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.KnowledgeCardUrn"
                        },
                        "rightRail": {
                            "type": "com.linkedin.0229fe28a11bea61a508c08302192f7d",
                            "isInjection": true
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.KnowledgeCardRightRail"
                },
                "com.linkedin.a780c129a85db3680157820ba19315f2": {
                    "fields": {
                        "logoImage": {
                            "type": {
                                "union": {
                                    "url": "com.linkedin.common.Url",
                                    "vectorImage": "com.linkedin.28db8575bcf1c65bdc4bc15948d50ee9"
                                }
                            }
                        },
                        "logoImageResolutionResult": {
                            "derivedFrom": "logoImage",
                            "type": {
                                "union": {
                                    "url": "com.linkedin.common.Url",
                                    "vectorImage": "com.linkedin.28db8575bcf1c65bdc4bc15948d50ee9"
                                }
                            }
                        },
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.ProfessionalEventUrn"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.events.ProfessionalEvent"
                },
                "com.linkedin.dd33c2c61db4a0cb731453b4b29786f5": {
                    "fields": {
                        "image": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "socialProofInsight": {
                            "type": "com.linkedin.7737d1abf743001bc78e672aaeea5e65"
                        },
                        "subtext": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "ctaText": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "upsellOrderOrigin": {
                            "type": "string"
                        },
                        "controlName": {
                            "type": "com.linkedin.voyager.dash.common.tracking.ControlName"
                        },
                        "actionUrl": {
                            "type": "com.linkedin.common.Url"
                        },
                        "legoTrackingToken": {
                            "type": "string"
                        },
                        "title": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "cancelCta": {
                            "type": "com.linkedin.bb9a15e3b05ba04c5e385ae638d7c325"
                        },
                        "globalLegoTrackingToken": {
                            "type": "string"
                        },
                        "highlightedValues": {
                            "type": {
                                "array": "com.linkedin.093e0b8e090aa84ca579dd651a03deb7"
                            }
                        },
                        "promotionLegoTrackingToken": {
                            "type": "string"
                        },
                        "chameleonVariantId": {
                            "type": "string"
                        },
                        "funnelCommonHeader": {
                            "type": "com.linkedin.f1ad523ada0160376aa5abe5356f3115"
                        },
                        "fireDiscoveryImpressionEvent": {
                            "type": "boolean"
                        },
                        "subtitle": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "dismissible": {
                            "type": "boolean"
                        },
                        "multiValuePropsContent": {
                            "type": "com.linkedin.f40d9a9b8ba56a1c0227ad3ad8c3396a"
                        },
                        "layoutStyle": {
                            "type": "com.linkedin.voyager.dash.premium.PremiumUpsellLayoutStyle"
                        },
                        "ctaButtonSecondaryEmphasizedTheme": {
                            "type": "boolean"
                        },
                        "colorScheme": {
                            "type": "com.linkedin.voyager.dash.premium.plans.PremiumColorToken"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.premium.PremiumUpsellCard"
                },
                "com.linkedin.38c32cf9808204fff187465f6ac6683c": {
                    "fields": {
                        "currentPollQuestion": {
                            "type": "com.linkedin.055f25d019920e58d653dd2fa062dd53"
                        },
                        "visibilityInfo": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.dynamicpolls.DynamicPollComponent"
                },
                "com.linkedin.d1cd6153f102beacf3fed6989c004d45": {
                    "fields": {
                        "value": {
                            "type": "string"
                        },
                        "key": {
                            "type": "com.linkedin.voyager.dash.common.coach.PremiumGeneratedMessageContextKey"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.common.coach.PremiumGeneratedMessageContextAttribute"
                },
                "com.linkedin.22c67ecdc465511502017dd8f5900eee": {
                    "fields": {
                        "ownerOrganization": {
                            "resolvedFrom": "ownerOrganizationUnion",
                            "type": {
                                "union": {
                                    "company": "com.linkedin.2c2374bef3eaba3e079b4a11e2f7bea8",
                                    "organizationalPage": "com.linkedin.5af8ef0ab96fc30191b92b12e1d5d6f4"
                                }
                            }
                        },
                        "messagingEnabled": {
                            "type": "boolean"
                        },
                        "ownerOrganizationUnion": {
                            "type": {
                                "union": {
                                    "company": "string",
                                    "organizationalPage": "string"
                                }
                            }
                        },
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.PageMailboxUrn"
                        },
                        "averageResponseTimeText": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.organization.PageMailbox"
                },
                "com.linkedin.deb8eb9003441a9260de30afd884b7bb": {
                    "fields": {
                        "clusterPosition": {
                            "type": "int"
                        },
                        "itemPosition": {
                            "type": "int"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.BserpPaginationContext"
                },
                "com.linkedin.67d1c9126e7e5213988926a2c6323fed": {
                    "fields": {
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.AdServingUrn"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.AdServing"
                },
                "com.linkedin.df5af7a43b6b31d806d7641be145efb3": {
                    "fields": {
                        "salesListNavigationUrl": {
                            "type": "com.linkedin.common.Url"
                        },
                        "saved": {
                            "type": "boolean"
                        },
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.SalesNavigatorSaveStateUrn"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.identity.profile.actions.SalesNavigatorSaveState"
                },
                "com.linkedin.30dee75e249786a8e1ceb4c1d056ab57": {
                    "fields": {
                        "searchActionType": {
                            "type": "string"
                        },
                        "actionBannerFeedback": {
                            "type": "com.linkedin.338f0409c0e49a21897c3cb97c10366a"
                        },
                        "actionDetailsUnion": {
                            "type": {
                                "union": {
                                    "notificationSubscribeAction": "string",
                                    "magicWandAction": "com.linkedin.aaad418ca3e178dc0877beb6e1e29026",
                                    "shareViaLinkAction": "com.linkedin.70640e3147f8e16b1771da60f669f41c",
                                    "embedHTMLAction": "com.linkedin.common.Urn",
                                    "statefulFollowAction": "com.linkedin.0a6bf75f2372f1c4ba5a251882c0a894",
                                    "primaryProfileAction": "string",
                                    "removeConnectionAction": "string",
                                    "navigationAction": "com.linkedin.beb995e9eea7ce0c86eeb7189d9eeed9",
                                    "followAction": "string",
                                    "saveAction": "string",
                                    "upsellAction": "string",
                                    "newsletterSubscribeAction": "string",
                                    "addLearningCourseToProfileAction": "string",
                                    "closeProjectAction": "com.linkedin.b9da42623b690cc1c112e7c1c656c4df",
                                    "primaryProfileActionV2": "string",
                                    "shareViaPostAction": "com.linkedin.0ee870519ed5910d9150d68cc65332f5",
                                    "reportAction": "com.linkedin.f4b0bc15ad9bff87e37f0fbe3390c14b",
                                    "leaveGroupAction": "string",
                                    "messagePageAction": "com.linkedin.411dc66f72c06183b0002b6c517e33c1",
                                    "shareViaMessageAction": "com.linkedin.097bfff3e704fd2f8e33db38806d2312"
                                }
                            }
                        },
                        "buttonCategory": {
                            "type": "com.linkedin.voyager.dash.common.ux.button.ButtonCategory"
                        },
                        "trackingUrn": {
                            "type": "com.linkedin.common.Urn"
                        },
                        "icon": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "controlName": {
                            "type": "com.linkedin.voyager.dash.common.tracking.ControlName"
                        },
                        "actionRenderStyle": {
                            "type": "com.linkedin.voyager.dash.search.EntityActionRenderStyle"
                        },
                        "actionDetails": {
                            "resolvedFrom": "actionDetailsUnion",
                            "type": {
                                "union": {
                                    "notificationSubscribeAction": "com.linkedin.97c03ebc33ae0e5d11a4485b5918f0b2",
                                    "magicWandAction": "com.linkedin.aaad418ca3e178dc0877beb6e1e29026",
                                    "shareViaLinkAction": "com.linkedin.70640e3147f8e16b1771da60f669f41c",
                                    "embedHTMLAction": "com.linkedin.common.Urn",
                                    "statefulFollowAction": "com.linkedin.0a6bf75f2372f1c4ba5a251882c0a894",
                                    "primaryProfileAction": "com.linkedin.e0372afc4a18480b00ca7e4906904fd7",
                                    "removeConnectionAction": "com.linkedin.c03d6d673ac4f7503bd4aeb7d200cfd7",
                                    "navigationAction": "com.linkedin.beb995e9eea7ce0c86eeb7189d9eeed9",
                                    "followAction": "com.linkedin.1a9edf7c4fc5f73ec859a1ae4c8105fe",
                                    "saveAction": "com.linkedin.f1b2492c05b41398477b887761d337a9",
                                    "upsellAction": "com.linkedin.0b2f76bd70fd4528e6bb2b0121d2241f",
                                    "newsletterSubscribeAction": "com.linkedin.6f5340bf6dde14897b3d4dde77e536d0",
                                    "addLearningCourseToProfileAction": "com.linkedin.2d331c9a5947ca4956358ddacabe40ee",
                                    "closeProjectAction": "com.linkedin.b9da42623b690cc1c112e7c1c656c4df",
                                    "primaryProfileActionV2": "com.linkedin.7c5d61c24e802281df7618578f2459db",
                                    "shareViaPostAction": "com.linkedin.0ee870519ed5910d9150d68cc65332f5",
                                    "reportAction": "com.linkedin.f4b0bc15ad9bff87e37f0fbe3390c14b",
                                    "leaveGroupAction": "com.linkedin.7f12f9be2e6b0e371ad2f98ce1324e16",
                                    "messagePageAction": "com.linkedin.411dc66f72c06183b0002b6c517e33c1",
                                    "shareViaMessageAction": "com.linkedin.097bfff3e704fd2f8e33db38806d2312"
                                }
                            }
                        },
                        "text": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "actionConfirmationDialog": {
                            "type": "com.linkedin.36822f6ade039002d5290c479023c95f"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.EntityAction"
                },
                "com.linkedin.d50733b664c8019ae5d38b1804596f0b": {
                    "fields": {
                        "unmuteTrackingActionType": {
                            "type": "string"
                        },
                        "unfollowTrackingActionType": {
                            "type": "string"
                        },
                        "muteTrackingActionType": {
                            "type": "string"
                        },
                        "followingState": {
                            "type": "com.linkedin.1a9edf7c4fc5f73ec859a1ae4c8105fe"
                        },
                        "followTrackingActionType": {
                            "type": "string"
                        },
                        "companyFollowingTrackingContext": {
                            "type": "com.linkedin.voyager.dash.feed.actions.follow.CompanyFollowingTrackingContextModule"
                        },
                        "type": {
                            "type": "com.linkedin.voyager.dash.feed.actions.follow.FollowActionType"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.actions.follow.FollowAction"
                },
                "com.linkedin.77f24fd65949d0f1cc3ca16da60fde58": {
                    "fields": {
                        "secondaryFilterGroups": {
                            "type": {
                                "array": "com.linkedin.6caaeab285566e3922584bf512297d62"
                            }
                        },
                        "primaryFilterGroups": {
                            "type": {
                                "array": "com.linkedin.6caaeab285566e3922584bf512297d62"
                            }
                        },
                        "appliedCount": {
                            "type": "int"
                        },
                        "icon": {
                            "type": "com.linkedin.voyager.dash.common.SystemImageName"
                        },
                        "subsequentRefresh": {
                            "type": "boolean"
                        },
                        "primaryFilters": {
                            "type": {
                                "array": "com.linkedin.0134fedeb876326e67efb0b562630cc0"
                            }
                        },
                        "secondaryFilters": {
                            "type": {
                                "array": "com.linkedin.0134fedeb876326e67efb0b562630cc0"
                            }
                        },
                        "title": {
                            "type": "string"
                        },
                        "showAdvanceFilter": {
                            "type": "boolean"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.SearchFilterCluster"
                },
                "com.linkedin.1bca01c8205c4ce1116a059cca10e725": {
                    "fields": {
                        "optionText": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "trackingActionType": {
                            "type": "string"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.survey.SurveySelectOption"
                },
                "com.linkedin.3b0c42a23baf5421629e62972e26b58b": {
                    "fields": {
                        "premiumStyle": {
                            "type": "boolean"
                        },
                        "size": {
                            "type": "com.linkedin.voyager.dash.common.ux.button.ButtonSize"
                        },
                        "icon": {
                            "type": "com.linkedin.voyager.dash.common.SystemImageName"
                        },
                        "text": {
                            "type": "string"
                        },
                        "iconAfterText": {
                            "type": "boolean"
                        },
                        "emphasize": {
                            "type": "boolean"
                        },
                        "category": {
                            "type": "com.linkedin.voyager.dash.common.ux.button.ButtonCategory"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.common.ux.button.ButtonAppearance"
                },
                "com.linkedin.3f4ae0934d738b90cbec63f10776b7ae": {
                    "fields": {
                        "ctaText": {
                            "type": "string"
                        },
                        "socialProofText": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.postcta.PostCtaComponent"
                },
                "com.linkedin.79dc13b17813e9f911798452d89dfd25": {
                    "fields": {
                        "reactionType": {
                            "type": "com.linkedin.voyager.dash.feed.social.ReactionType"
                        },
                        "count": {
                            "type": "long"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.social.ReactionTypeCount"
                },
                "com.linkedin.63dce7437c938cc483a7449c237eac59": {
                    "fields": {
                        "callToActionButton": {
                            "type": "com.linkedin.280548a5c822f61a54f7d2022f1e02a5"
                        },
                        "text": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "tooltipText": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "preDashEntityUrn": {
                            "type": "com.linkedin.voyager.dash.common.PreDashUrn"
                        },
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.BoostComponentUrn"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.boost.BoostComponent"
                },
                "com.linkedin.763d05b15c48f0290ff8e9d7c1b3b2e2": {
                    "fields": {
                        "image": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "ampUrl": {
                            "type": "com.linkedin.common.Url"
                        },
                        "subtitle": {
                            "type": "string"
                        },
                        "description": {
                            "type": "string"
                        },
                        "title": {
                            "type": "string"
                        },
                        "backendUrn": {
                            "type": "com.linkedin.common.Urn"
                        },
                        "url": {
                            "type": "com.linkedin.common.Url"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.social.CommentArticle"
                },
                "com.linkedin.57397516101a62ce38ea32c68aecdfab": {
                    "fields": {
                        "showPremiumBranding": {
                            "type": "boolean"
                        },
                        "image": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "showDivider": {
                            "type": "boolean"
                        },
                        "actionButton": {
                            "type": "com.linkedin.280548a5c822f61a54f7d2022f1e02a5"
                        },
                        "navigationContext": {
                            "type": "com.linkedin.8a612b4e445851d55ecf8b09571a05ee"
                        },
                        "headerTextStyle": {
                            "type": "com.linkedin.voyager.dash.feed.component.header.HeaderTextStyle"
                        },
                        "text": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "premiumBrandingStyle": {
                            "type": "com.linkedin.voyager.dash.feed.component.header.HeaderPremiumStyle"
                        },
                        "imageNavigationContext": {
                            "type": "com.linkedin.8a612b4e445851d55ecf8b09571a05ee"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.header.HeaderComponent"
                },
                "com.linkedin.83d0ac7bcab35bfe2d9bcd29421a7f1f": {
                    "fields": {
                        "image": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "default": {
                            "type": "boolean"
                        },
                        "tooltipText": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "displayName": {
                            "type": "string"
                        },
                        "icon": {
                            "type": "com.linkedin.voyager.dash.common.SystemImageName"
                        },
                        "count": {
                            "type": "int"
                        },
                        "disabled": {
                            "type": "boolean"
                        },
                        "value": {
                            "type": "string"
                        },
                        "selected": {
                            "type": "boolean"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.SearchFilterValue"
                },
                "com.linkedin.2c2374bef3eaba3e079b4a11e2f7bea8": {
                    "fields": {
                        "followingStateUrn": {
                            "type": "string"
                        },
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.CompanyUrn"
                        },
                        "followingState": {
                            "resolvedFrom": "followingStateUrn",
                            "type": "com.linkedin.1a9edf7c4fc5f73ec859a1ae4c8105fe"
                        },
                        "name": {
                            "type": "string"
                        },
                        "logo": {
                            "type": {
                                "union": {
                                    "url": "com.linkedin.common.Url",
                                    "vectorImage": "com.linkedin.28db8575bcf1c65bdc4bc15948d50ee9"
                                }
                            }
                        },
                        "logoResolutionResult": {
                            "derivedFrom": "logo",
                            "type": {
                                "union": {
                                    "url": "com.linkedin.common.Url",
                                    "vectorImage": "com.linkedin.28db8575bcf1c65bdc4bc15948d50ee9"
                                }
                            }
                        },
                        "universalName": {
                            "type": "string"
                        },
                        "url": {
                            "type": "com.linkedin.common.Url"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.organization.Company"
                },
                "com.linkedin.f3334456de9f114682f0aa58b456eacf": {
                    "fields": {
                        "image": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "commenterProfileId": {
                            "type": "string"
                        },
                        "author": {
                            "type": "boolean"
                        },
                        "supplementaryActorInfo": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "actorUnion": {
                            "type": {
                                "union": {
                                    "companyUrn": "string",
                                    "profileUrn": "string"
                                }
                            }
                        },
                        "navigationUrl": {
                            "type": "com.linkedin.common.Url"
                        },
                        "title": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "accessibilityText": {
                            "type": "string"
                        },
                        "followAction": {
                            "type": "com.linkedin.d50733b664c8019ae5d38b1804596f0b"
                        },
                        "urn": {
                            "type": "com.linkedin.common.Urn"
                        },
                        "actor": {
                            "resolvedFrom": "actorUnion",
                            "type": {
                                "union": {
                                    "companyUrn": "com.linkedin.2c2374bef3eaba3e079b4a11e2f7bea8",
                                    "profileUrn": "com.linkedin.e0372afc4a18480b00ca7e4906904fd7"
                                }
                            }
                        },
                        "subtitle": {
                            "type": "string"
                        },
                        "trackingActionType": {
                            "type": "string"
                        },
                        "trackingId": {
                            "type": "com.linkedin.common.TrackingId"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.social.Commenter"
                },
                "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b": {
                    "fields": {
                        "editableAccessibilityText": {
                            "type": "boolean"
                        },
                        "attributes": {
                            "type": {
                                "array": "com.linkedin.eb94fbb1518f790c4545aafdf571c64e"
                            }
                        },
                        "actionTarget": {
                            "type": "com.linkedin.common.Url"
                        },
                        "accessibilityTextAttributes": {
                            "type": {
                                "array": "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                            }
                        },
                        "totalCount": {
                            "type": "int"
                        },
                        "accessibilityText": {
                            "type": "string"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.common.image.ImageViewModel"
                },
                "com.linkedin.d76ca50a521fc6f378c056280cb05897": {
                    "fields": {
                        "image": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "socialActivityCounts": {
                            "type": "com.linkedin.60216d4fa134df147fcc8c39e71c7139"
                        },
                        "dwellTriggerTime": {
                            "type": "long"
                        },
                        "text": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "legoTrackingToken": {
                            "type": "string"
                        },
                        "nudgeTarget": {
                            "type": "com.linkedin.voyager.dash.feed.component.nudge.NudgeTarget"
                        },
                        "trackingId": {
                            "type": "com.linkedin.common.TrackingId"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.nudge.NudgeComponent"
                },
                "com.linkedin.c3ca265f1d14f57e9246103e6f28929a": {
                    "fields": {
                        "hideSocialCountsIfAllowed": {
                            "type": "boolean"
                        },
                        "comments": {
                            "type": "com.linkedin.0b8e259b5baac26e5afa8bef054b6563",
                            "isInjection": true
                        },
                        "socialPermissions": {
                            "type": "com.linkedin.fdd9baf01d9a7fb371cf38f9ea53994d"
                        },
                        "threadUrn": {
                            "type": "com.linkedin.common.Urn"
                        },
                        "quickComments": {
                            "type": {
                                "array": "string"
                            }
                        },
                        "socialPermissionsPersonalTopicUrn": {
                            "type": "com.linkedin.common.SocialPermissionsPersonalTopicUrn"
                        },
                        "showPremiumAnalytics": {
                            "type": "boolean"
                        },
                        "feedDetailSocialActionPromptType": {
                            "type": "com.linkedin.voyager.dash.social.SocialActionPromptType"
                        },
                        "reactionsOnCommentsTopicUrn": {
                            "type": "com.linkedin.common.ReactionsOnCommentsTopicUrn"
                        },
                        "allowedCommentersScope": {
                            "type": "com.linkedin.voyager.dash.contentcreation.AllowedScope"
                        },
                        "totalSocialActivityCounts": {
                            "type": "com.linkedin.60216d4fa134df147fcc8c39e71c7139"
                        },
                        "socialUpdateType": {
                            "type": "com.linkedin.voyager.dash.social.SocialUpdateType"
                        },
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.SocialDetailUrn"
                        },
                        "reactionSummariesTopicUrn": {
                            "type": "com.linkedin.common.ReactionSummariesTopicUrn"
                        },
                        "commentsTopicUrn": {
                            "type": "com.linkedin.common.CommentsTopicUrn"
                        },
                        "reactionsTopicUrn": {
                            "type": "com.linkedin.common.ReactionsTopicUrn"
                        },
                        "reshareUpdateUrn": {
                            "type": "com.linkedin.common.Urn"
                        },
                        "socialDetailsTopicUrn": {
                            "type": "com.linkedin.common.SocialDetailsTopicUrn"
                        },
                        "preDashEntityUrn": {
                            "type": "com.linkedin.voyager.dash.common.PreDashUrn"
                        },
                        "commentSocialPermissionsTopicUrn": {
                            "type": "com.linkedin.common.CommentSocialPermissionsTopicUrn"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.social.SocialDetail"
                },
                "com.linkedin.338f0409c0e49a21897c3cb97c10366a": {
                    "fields": {
                        "successCtaText": {
                            "type": "string"
                        },
                        "successNavigationUrl": {
                            "type": "com.linkedin.common.Url"
                        },
                        "failureNavigationUrl": {
                            "type": "com.linkedin.common.Url"
                        },
                        "successUndoneMessage": {
                            "type": "string"
                        },
                        "failureCtaText": {
                            "type": "string"
                        },
                        "failureMessage": {
                            "type": "string"
                        },
                        "successMessage": {
                            "type": "string"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.EntityActionBannerFeedback"
                },
                "com.linkedin.c3576e4eb1959675613cf442c15650b9": {
                    "fields": {
                        "navigationContext": {
                            "type": "com.linkedin.8a612b4e445851d55ecf8b09571a05ee"
                        },
                        "buttonText": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "description": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "image": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "title": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "subtitle": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.textoverlayimage.TextOverlayImageComponent"
                },
                "com.linkedin.49cdf97a1e242987c91d2131983a05b0": {
                    "fields": {
                        "loadingMessages": {
                            "type": "com.linkedin.ff3ddd6bcb4eec2cfd2f0aa181d466aa"
                        },
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.CoachRealtimeResponseUrn"
                        },
                        "id": {
                            "type": "com.linkedin.common.UUID"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.common.coach.CoachRealtimeResponse"
                },
                "com.linkedin.2d3e7b4bccc9c85f103b0dc9fdfd3669": {
                    "fields": {
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.FeedbackCardUrn"
                        },
                        "trackingId": {
                            "type": "com.linkedin.common.TrackingId"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.FeedbackCard"
                },
                "com.linkedin.a6388bc756287a778617ae66ac0b9806": {
                    "fields": {
                        "image": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "trackingUrn": {
                            "type": "com.linkedin.common.Urn"
                        },
                        "subtitle": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "navigationUrl": {
                            "type": "com.linkedin.common.Url"
                        },
                        "label": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "title": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "trackingId": {
                            "type": "com.linkedin.voyager.dash.common.Base64String"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.common.ux.EntityLockupViewModel"
                },
                "com.linkedin.1c85062c2fd2eabbef5700e6d7e8cf18": {
                    "fields": {
                        "hideTrackingActionType": {
                            "type": "string"
                        },
                        "preDashEntityUrn": {
                            "type": "com.linkedin.voyager.dash.common.PreDashUrn"
                        },
                        "inlineConfirmation": {
                            "type": "com.linkedin.2f504e1a87d0f08b5ece5c874db6865f"
                        },
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.HideCommentActionUrn"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.social.HideCommentAction"
                },
                "com.linkedin.74024cf712e3b910b92188d657a36b48": {
                    "fields": {
                        "ctaButton": {
                            "type": "com.linkedin.280548a5c822f61a54f7d2022f1e02a5"
                        },
                        "ratingLabel": {
                            "type": "string"
                        },
                        "lockupImage": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "lockupTitle": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "roundedRating": {
                            "type": "double"
                        },
                        "navigationContext": {
                            "type": "com.linkedin.8a612b4e445851d55ecf8b09571a05ee"
                        },
                        "lockupSubtitle": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "title": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "reviewText": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "lockupInsight": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.review.ReviewComponent"
                },
                "com.linkedin.0c8279c2434e0b6cfc1d66af503e1cff": {
                    "fields": {
                        "updateUrn": {
                            "type": "string"
                        },
                        "update": {
                            "resolvedFrom": "updateUrn",
                            "type": "com.linkedin.757852411fb0feeedcbd4df1cbcfcd54"
                        },
                        "trackingId": {
                            "type": "com.linkedin.voyager.dash.common.Base64String"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.SearchUpdateWrapper"
                },
                "com.linkedin.f2e92768122faa3236a3da8d98ae1bad": {
                    "fields": {
                        "originalImageUrl": {
                            "type": "com.linkedin.common.Url"
                        },
                        "originalHeight": {
                            "type": "int"
                        },
                        "originalWidth": {
                            "type": "int"
                        },
                        "url": {
                            "type": "com.linkedin.common.Url"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.common.ImageUrl"
                },
                "com.linkedin.544f3f6642d8f7a8ebf2647e5655495a": {
                    "fields": {
                        "image": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "secondarySubtitle": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "insights": {
                            "type": {
                                "array": {
                                    "union": {
                                        "jobPostingInsight": "string",
                                        "relationshipsInsight": "string",
                                        "jobPostingFooterInsight": "string",
                                        "socialActivityCountsInsight": "string",
                                        "simpleInsight": "com.linkedin.bd9a707a5b119c1f331373113f57344a"
                                    }
                                }
                            }
                        },
                        "trackingUrn": {
                            "type": "com.linkedin.common.Urn"
                        },
                        "controlName": {
                            "type": "com.linkedin.voyager.dash.common.tracking.ControlName"
                        },
                        "primaryActions": {
                            "type": {
                                "array": "com.linkedin.30dee75e249786a8e1ceb4c1d056ab57"
                            }
                        },
                        "entityCustomTrackingInfo": {
                            "type": "com.linkedin.4caf791202c7b71e3874d4551f078f32"
                        },
                        "navigationUrl": {
                            "type": "com.linkedin.common.Url"
                        },
                        "overflowActions": {
                            "type": {
                                "array": "com.linkedin.30dee75e249786a8e1ceb4c1d056ab57"
                            }
                        },
                        "title": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "insightsResolutionResults": {
                            "resolvedFrom": "insights",
                            "type": {
                                "array": {
                                    "union": {
                                        "jobPostingInsight": "com.linkedin.352de81121adae09c8392d6f11d028a0",
                                        "relationshipsInsight": "com.linkedin.8bb7af21154573d49987b03117f5d1cf",
                                        "jobPostingFooterInsight": "com.linkedin.791d0c903911aab58f40e6744715af71",
                                        "socialActivityCountsInsight": "com.linkedin.60216d4fa134df147fcc8c39e71c7139",
                                        "simpleInsight": "com.linkedin.bd9a707a5b119c1f331373113f57344a"
                                    }
                                }
                            }
                        },
                        "badgeIcon": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "primarySubtitle": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "badgeText": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "trackingId": {
                            "type": "com.linkedin.voyager.dash.common.Base64String"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.HeroEntityCard"
                },
                "com.linkedin.f40d9a9b8ba56a1c0227ad3ad8c3396a": {
                    "fields": {
                        "valueProps": {
                            "type": {
                                "array": "com.linkedin.75f2a2c151047532fd7bb6314306feae"
                            }
                        },
                        "headline": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.premium.PremiumUpsellMultiValuePropsContent"
                },
                "com.linkedin.c50d1c05ff73d93791979ed1aa968a68": {
                    "fields": {
                        "templateType": {
                            "type": "com.linkedin.voyager.dash.search.EntityResultTemplate"
                        },
                        "entityCardStyle": {
                            "type": "com.linkedin.voyager.dash.search.EntityResultCardStyle"
                        },
                        "summarySuggestedNumLines": {
                            "type": "int"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.EntityResultAttributes"
                },
                "com.linkedin.70640e3147f8e16b1771da60f669f41c": {
                    "fields": {
                        "icon": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "text": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "message": {
                            "type": "string"
                        },
                        "url": {
                            "type": "com.linkedin.common.Url"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.ShareViaLinkAction"
                },
                "com.linkedin.411dc66f72c06183b0002b6c517e33c1": {
                    "fields": {
                        "pageMailbox": {
                            "resolvedFrom": "pageMailboxUrn",
                            "type": "com.linkedin.22c67ecdc465511502017dd8f5900eee"
                        },
                        "pageName": {
                            "type": "string"
                        },
                        "pageMailboxUrn": {
                            "type": "string"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.MessagePageAction"
                },
                "com.linkedin.9268b913957ab7557294a0063e05e100": {
                    "fields": {
                        "start": {
                            "type": "int"
                        },
                        "count": {
                            "type": "int"
                        },
                        "total": {
                            "type": "int"
                        }
                    },
                    "baseType": "com.linkedin.restli.common.CollectionMetadata"
                },
                "com.linkedin.14a475ec64857ded5e4565d932f4f2cc": {
                    "fields": {
                        "displayText": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "navigationUrl": {
                            "type": "com.linkedin.common.Url"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.KeywordValue"
                },
                "com.linkedin.ef90ea21b3b3f3c01953959ef696d447": {
                    "fields": {
                        "segmentAttributeUrn": {
                            "type": "string"
                        },
                        "segmentAttribute": {
                            "resolvedFrom": "segmentAttributeUrn",
                            "type": "com.linkedin.6ae8c37596566c4ce8b04bc5348f2b24"
                        },
                        "segmentProductSurface": {
                            "type": "com.linkedin.voyager.dash.search.SegmentProductSurface"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.TypeaheadFilterQuery"
                },
                "com.linkedin.6f08f9ec26b0f1c58494b5f6171c698e": {
                    "fields": {
                        "relationshipData": {
                            "resolvedFrom": "relationshipDataUnion",
                            "type": {
                                "union": {
                                    "connectionOrInvitation": "com.linkedin.c03d6d673ac4f7503bd4aeb7d200cfd7",
                                    "memberToEntityRelationship": "com.linkedin.3e907fa58f3cf80fda86c628de9593d1"
                                }
                            }
                        },
                        "relationshipsTrackingId": {
                            "type": "com.linkedin.common.TrackingId"
                        },
                        "relationshipDataUnion": {
                            "type": {
                                "union": {
                                    "connectionOrInvitation": "string",
                                    "memberToEntityRelationship": "string"
                                }
                            }
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.common.relationships.RelationshipActionData"
                },
                "com.linkedin.a4384b71875a73ae598fe7c0fa90316f": {
                    "fields": {
                        "optionType": {
                            "type": "com.linkedin.voyager.dash.identity.notifications.edgesetting.EdgeSettingOptionType"
                        },
                        "successToastText": {
                            "type": "string"
                        },
                        "optionName": {
                            "type": "string"
                        },
                        "optionDescription": {
                            "type": "string"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.identity.notifications.edgesetting.EdgeSettingOption"
                },
                "com.linkedin.4cd241e0a8ad80a259b7f055e0fe1ec0": {
                    "fields": {
                        "update": {
                            "type": "com.linkedin.757852411fb0feeedcbd4df1cbcfcd54"
                        },
                        "contentUnion": {
                            "type": {
                                "union": {
                                    "feedDiscoveryEntityComponent": "com.linkedin.5b82b762410287f21f34b3d755f164dc",
                                    "jobComponent": "com.linkedin.292ed207e90e51c83f267296fa0c7940",
                                    "articleComponent": "com.linkedin.86b903c46b5240b03037ec8656976681",
                                    "eventComponent": "com.linkedin.827d2df06cbbd8888b228aac56a99cb5",
                                    "seeMoreComponent": "com.linkedin.dbe3dc7ec313938618c482695c80e952",
                                    "promoComponent": "com.linkedin.8ff002aafcb203f2b95c57c175c2f91c",
                                    "creativeComponent": "com.linkedin.2c018138fdfa8396a9d8fc5fa0311e71"
                                }
                            }
                        },
                        "content": {
                            "derivedFrom": "contentUnion",
                            "type": {
                                "union": {
                                    "feedDiscoveryEntityComponent": "com.linkedin.5b82b762410287f21f34b3d755f164dc",
                                    "jobComponent": "com.linkedin.292ed207e90e51c83f267296fa0c7940",
                                    "articleComponent": "com.linkedin.86b903c46b5240b03037ec8656976681",
                                    "eventComponent": "com.linkedin.827d2df06cbbd8888b228aac56a99cb5",
                                    "seeMoreComponent": "com.linkedin.dbe3dc7ec313938618c482695c80e952",
                                    "promoComponent": "com.linkedin.8ff002aafcb203f2b95c57c175c2f91c",
                                    "creativeComponent": "com.linkedin.2c018138fdfa8396a9d8fc5fa0311e71"
                                }
                            }
                        },
                        "trackingData": {
                            "type": "com.linkedin.6bf32d88af325c3a70ac92d1594add6d"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.carousel.CarouselItem"
                },
                "com.linkedin.7c5d61c24e802281df7618578f2459db": {
                    "fields": {
                        "primaryActionResolutionResult": {
                            "resolvedFrom": "primaryAction",
                            "type": {
                                "union": {
                                    "personalizedConnect": "com.linkedin.c03d6d673ac4f7503bd4aeb7d200cfd7",
                                    "saveToPdf": "com.linkedin.e0372afc4a18480b00ca7e4906904fd7",
                                    "shareProfileUrlViaMessage": "com.linkedin.common.Url",
                                    "composeOption": "com.linkedin.0fbb066482da3106482c7cfb8f69e70f",
                                    "saveToPdfUrl": "com.linkedin.common.Url",
                                    "statefulAction": "com.linkedin.0a6bf75f2372f1c4ba5a251882c0a894",
                                    "saveInSalesNavigatorState": "com.linkedin.df5af7a43b6b31d806d7641be145efb3",
                                    "viewProfileInExternalContext": "com.linkedin.cf49e2720a644b4a12dc9c8ac3f90543",
                                    "statelessAction": "com.linkedin.voyager.dash.identity.profile.actions.ProfileActionType",
                                    "followingState": "com.linkedin.1a9edf7c4fc5f73ec859a1ae4c8105fe",
                                    "report": "com.linkedin.4acb03668cbf076750aad6513cd36f43",
                                    "ignore": "com.linkedin.c03d6d673ac4f7503bd4aeb7d200cfd7",
                                    "connection": "com.linkedin.0d4ab2c158752b17b06ddd97bd989146",
                                    "shareProfileUrl": "com.linkedin.common.Url",
                                    "withdraw": "com.linkedin.c03d6d673ac4f7503bd4aeb7d200cfd7"
                                }
                            }
                        },
                        "primaryAction": {
                            "type": {
                                "union": {
                                    "personalizedConnect": "string",
                                    "saveToPdf": "string",
                                    "shareProfileUrlViaMessage": "com.linkedin.common.Url",
                                    "composeOption": "string",
                                    "saveToPdfUrl": "com.linkedin.common.Url",
                                    "statefulAction": "com.linkedin.0a6bf75f2372f1c4ba5a251882c0a894",
                                    "saveInSalesNavigatorState": "string",
                                    "viewProfileInExternalContext": "com.linkedin.cf49e2720a644b4a12dc9c8ac3f90543",
                                    "statelessAction": "com.linkedin.voyager.dash.identity.profile.actions.ProfileActionType",
                                    "followingState": "string",
                                    "report": "com.linkedin.4acb03668cbf076750aad6513cd36f43",
                                    "ignore": "string",
                                    "connection": "com.linkedin.0d4ab2c158752b17b06ddd97bd989146",
                                    "shareProfileUrl": "com.linkedin.common.Url",
                                    "withdraw": "string"
                                }
                            }
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.identity.profile.actions.ProfileActions"
                },
                "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12": {
                    "fields": {
                        "detailData": {
                            "resolvedFrom": "detailDataUnion",
                            "type": {
                                "union": {
                                    "jobPostingName": "com.linkedin.352de81121adae09c8392d6f11d028a0",
                                    "profileFamiliarName": "com.linkedin.e0372afc4a18480b00ca7e4906904fd7",
                                    "hyperlink": "com.linkedin.common.Url",
                                    "color": "com.linkedin.voyager.dash.common.text.TextColor",
                                    "companyName": "com.linkedin.2c2374bef3eaba3e079b4a11e2f7bea8",
                                    "icon": "com.linkedin.voyager.dash.common.ArtDecoIconName",
                                    "epoch": "com.linkedin.6923f8904eacad15ebec50462e5cb990",
                                    "systemImage": "com.linkedin.voyager.dash.common.SystemImageName",
                                    "textLink": "com.linkedin.9f8aac2973836344836ca4eae9664da3",
                                    "listItemStyle": "com.linkedin.fce42282743d6566d0809f9f30cac942",
                                    "listStyle": "com.linkedin.voyager.dash.common.text.ListStyleType",
                                    "groupName": "com.linkedin.c8f5bf5a9d5e0dbbc3c824c2dfd751a8",
                                    "hyperlinkOpenExternally": "com.linkedin.common.Url",
                                    "stringFieldReference": "com.linkedin.dc97b0d2074b2777db3e7e9da9a583ed",
                                    "profileFullName": "com.linkedin.e0372afc4a18480b00ca7e4906904fd7",
                                    "learningCourseName": "com.linkedin.2d331c9a5947ca4956358ddacabe40ee",
                                    "profileMention": "com.linkedin.e0372afc4a18480b00ca7e4906904fd7",
                                    "style": "com.linkedin.voyager.dash.common.text.TextStyle",
                                    "schoolName": "com.linkedin.daa3a2cada5a579731c11a78fbd82e2d",
                                    "hashtag": "com.linkedin.7d211d7e5c235f2e6b597ae8905543f1"
                                }
                            }
                        },
                        "length": {
                            "type": "int"
                        },
                        "start": {
                            "type": "int"
                        },
                        "detailDataUnion": {
                            "type": {
                                "union": {
                                    "jobPostingName": "string",
                                    "profileFamiliarName": "string",
                                    "hyperlink": "com.linkedin.common.Url",
                                    "color": "com.linkedin.voyager.dash.common.text.TextColor",
                                    "companyName": "string",
                                    "icon": "com.linkedin.voyager.dash.common.ArtDecoIconName",
                                    "epoch": "com.linkedin.6923f8904eacad15ebec50462e5cb990",
                                    "systemImage": "com.linkedin.voyager.dash.common.SystemImageName",
                                    "textLink": "com.linkedin.9f8aac2973836344836ca4eae9664da3",
                                    "listItemStyle": "com.linkedin.fce42282743d6566d0809f9f30cac942",
                                    "listStyle": "com.linkedin.voyager.dash.common.text.ListStyleType",
                                    "groupName": "string",
                                    "hyperlinkOpenExternally": "com.linkedin.common.Url",
                                    "stringFieldReference": "com.linkedin.dc97b0d2074b2777db3e7e9da9a583ed",
                                    "profileFullName": "string",
                                    "learningCourseName": "string",
                                    "profileMention": "string",
                                    "style": "com.linkedin.voyager.dash.common.text.TextStyle",
                                    "schoolName": "string",
                                    "hashtag": "string"
                                }
                            }
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.common.text.TextAttribute"
                },
                "com.linkedin.86eb7bbd81c72ab573af04d5a3284dba": {
                    "fields": {
                        "displayText": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "promptText": {
                            "type": "string"
                        },
                        "serverIntent": {
                            "type": "string"
                        },
                        "trackingId": {
                            "type": "com.linkedin.common.TrackingId"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.gai.CoachSearchPrompt"
                },
                "com.linkedin.5b82b762410287f21f34b3d755f164dc": {
                    "fields": {
                        "connectAction": {
                            "type": "com.linkedin.c97d64dfd15204616a896fea6339d850"
                        },
                        "insights": {
                            "type": "com.linkedin.7737d1abf743001bc78e672aaeea5e65"
                        },
                        "backgroundImage": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "description": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "followAction": {
                            "type": "com.linkedin.d50733b664c8019ae5d38b1804596f0b"
                        },
                        "trackingData": {
                            "type": "com.linkedin.6bf32d88af325c3a70ac92d1594add6d"
                        },
                        "entityImage": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "addProfileInfoButton": {
                            "type": "com.linkedin.280548a5c822f61a54f7d2022f1e02a5"
                        },
                        "supplementaryEntityInfo": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "subDescription": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "groupMembershipForJoinActionUrn": {
                            "type": "string"
                        },
                        "name": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "navigationContext": {
                            "type": "com.linkedin.8a612b4e445851d55ecf8b09571a05ee"
                        },
                        "groupMembershipForJoinAction": {
                            "resolvedFrom": "groupMembershipForJoinActionUrn",
                            "type": "com.linkedin.7f12f9be2e6b0e371ad2f98ce1324e16"
                        },
                        "headline": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.discoveryentity.FeedDiscoveryEntityComponent"
                },
                "com.linkedin.c8bd17969c41cd526ddc4a7b36c8cdbe": {
                    "fields": {
                        "linkUrl": {
                            "type": "com.linkedin.common.Url"
                        },
                        "controlName": {
                            "type": "com.linkedin.voyager.dash.common.tracking.ControlName"
                        },
                        "linkText": {
                            "type": "string"
                        },
                        "text": {
                            "type": "string"
                        },
                        "type": {
                            "type": "com.linkedin.voyager.dash.common.ux.InlineFeedbackType"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.common.ux.InlineFeedbackViewModel"
                },
                "com.linkedin.e6bc62c2917d46b312c7306363820a83": {
                    "fields": {
                        "title": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "image": {
                            "type": "com.linkedin.voyager.dash.common.SystemImageName"
                        },
                        "subtitle": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.BlockedQueryError"
                },
                "com.linkedin.3623b786d2323fb52c13099cf2752b53": {
                    "fields": {
                        "ctaButton": {
                            "type": "com.linkedin.280548a5c822f61a54f7d2022f1e02a5"
                        },
                        "showDownloadCTA": {
                            "type": "boolean"
                        },
                        "documentSource": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "document": {
                            "type": "com.linkedin.56970f4601ade63e2f097f9ecfc9be75"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.document.DocumentComponent"
                },
                "com.linkedin.d853c03d4547334c4f244bc136796f0b": {
                    "fields": {
                        "impressionId": {
                            "type": "string"
                        },
                        "unwrappedUrlDomain": {
                            "type": "string"
                        },
                        "creativeId": {
                            "type": "string"
                        },
                        "campaignId": {
                            "type": "string"
                        },
                        "memberId": {
                            "type": "string"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.common.sponsored.SponsoredUrlAttributes"
                },
                "com.linkedin.05a26c8d0e313e91515bf71c4ea8b9c4": {
                    "fields": {
                        "memberDistance": {
                            "type": "com.linkedin.voyager.dash.relationships.NoConnectionMemberDistance"
                        },
                        "invitation": {
                            "derivedFrom": "invitationUnion",
                            "type": {
                                "union": {
                                    "noInvitation": "com.linkedin.a33c5676b727948bb8920b5502949103",
                                    "invitation": "com.linkedin.b95815644054b75e89af04b98b438272"
                                }
                            }
                        },
                        "invitationUnion": {
                            "type": {
                                "union": {
                                    "noInvitation": "com.linkedin.a33c5676b727948bb8920b5502949103",
                                    "invitation": "com.linkedin.b95815644054b75e89af04b98b438272"
                                }
                            }
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.relationships.NoConnection"
                },
                "com.linkedin.422f035ceb29d58b6e1cb2b89ed1b336": {
                    "fields": {
                        "entityLabels": {
                            "type": {
                                "array": "string"
                            }
                        },
                        "accessibilityText": {
                            "type": "string"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.LabelsInsight"
                },
                "com.linkedin.0b2f76bd70fd4528e6bb2b0121d2241f": {
                    "fields": {
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.PremiumUpsellSlotUrn"
                        },
                        "upsellCard": {
                            "type": "com.linkedin.dd33c2c61db4a0cb731453b4b29786f5"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.premium.PremiumUpsellSlotContent"
                },
                "com.linkedin.5bb56b584256b9eecd366c99b363e946": {
                    "fields": {
                        "promptText": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "targetUrl": {
                            "type": "com.linkedin.common.Url"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.conversations.CommentPrompt"
                },
                "com.linkedin.f70de4d604689acbffc0dcd8115c319d": {
                    "fields": {
                        "slidesUnions": {
                            "type": {
                                "array": {
                                    "union": {
                                        "imageSlide": "com.linkedin.ad074a161dc3cbca5463a3d8566bf68f",
                                        "videoSlide": "com.linkedin.cb566040fbbf36857f28249822e9b046"
                                    }
                                }
                            }
                        },
                        "slides": {
                            "derivedFrom": "slidesUnions",
                            "type": {
                                "array": {
                                    "union": {
                                        "imageSlide": "com.linkedin.ad074a161dc3cbca5463a3d8566bf68f",
                                        "videoSlide": "com.linkedin.cb566040fbbf36857f28249822e9b046"
                                    }
                                }
                            }
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.slideshow.SlideshowComponent"
                },
                "com.linkedin.222901e411e8a1fbd130cb14efdb6c72": {
                    "fields": {
                        "connectedMemberResolutionResult": {
                            "resolvedFrom": "connectedMember",
                            "type": "com.linkedin.e0372afc4a18480b00ca7e4906904fd7"
                        },
                        "createdAt": {
                            "type": "com.linkedin.common.Time"
                        },
                        "connectedMember": {
                            "type": "string"
                        },
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.ConnectionUrn"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.relationships.Connection"
                },
                "com.linkedin.0337116cb8f03f02a7efa1361f45850f": {
                    "fields": {
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.ConversationUrn"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.messaging.Conversation"
                },
                "com.linkedin.bd93318ac5710b71fba68ebb50fd5bfd": {
                    "fields": {
                        "summary": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "image": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "headerThumbnail": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "secondarySubtitle": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "trackingUrn": {
                            "type": "com.linkedin.common.Urn"
                        },
                        "primaryActions": {
                            "type": {
                                "array": "com.linkedin.30dee75e249786a8e1ceb4c1d056ab57"
                            }
                        },
                        "primarySubtitle": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "title": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "showPlayButton": {
                            "type": "boolean"
                        },
                        "headerTitle": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "renderStyle": {
                            "type": "com.linkedin.voyager.dash.search.EmbeddedObjectRenderStyle"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.EntityEmbeddedObject"
                },
                "com.linkedin.ff3ddd6bcb4eec2cfd2f0aa181d466aa": {
                    "fields": {
                        "loadingMessages": {
                            "type": {
                                "array": "com.linkedin.f0ea208d22501bf7318e3df763a071db"
                            }
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.common.coach.LoadingMessages"
                },
                "com.linkedin.d067ea339aae1c25da65a9f86eb786ad": {
                    "fields": {
                        "accessoryTrackingId": {
                            "type": "com.linkedin.common.TrackingId"
                        },
                        "actionType": {
                            "type": "string"
                        },
                        "legoTrackingToken": {
                            "type": "string"
                        },
                        "inlineFeedBackComponent": {
                            "type": "com.linkedin.c8bd17969c41cd526ddc4a7b36c8cdbe"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.annotation.AnnotationComponent"
                },
                "com.linkedin.f527e0fb798181c7a317905f54d4ecc5": {
                    "fields": {
                        "pollOptionUrn": {
                            "type": "com.linkedin.voyager.dash.common.PollOptionUrn"
                        },
                        "option": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "preDashPollOptionUrn": {
                            "type": "com.linkedin.voyager.dash.common.PreDashUrn"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.polls.PollOption"
                },
                "com.linkedin.097bfff3e704fd2f8e33db38806d2312": {
                    "fields": {
                        "messageComposeOption": {
                            "resolvedFrom": "messageComposeOptionUrn",
                            "type": "com.linkedin.0fbb066482da3106482c7cfb8f69e70f"
                        },
                        "icon": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "text": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "message": {
                            "type": "string"
                        },
                        "messageComposeOptionUrn": {
                            "type": "string"
                        },
                        "referringModuleKey": {
                            "type": "string"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.ShareViaMessageAction"
                },
                "com.linkedin.7f6822f991ba515653ea40e7a6f66203": {
                    "fields": {},
                    "baseType": "com.linkedin.restli.common.EmptyRecord"
                },
                "com.linkedin.b75375948b8af489d842205d21abee34": {
                    "fields": {
                        "expiresAt": {
                            "type": "com.linkedin.common.Time"
                        },
                        "url": {
                            "type": "com.linkedin.common.Url"
                        }
                    },
                    "baseType": "com.linkedin.videocontent.StreamingLocation"
                },
                "com.linkedin.1734179c2744199ea6708a6613bdcede": {
                    "fields": {
                        "detailText": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "text": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.creationstatus.CreationStatusComponent"
                },
                "com.linkedin.1fa80808336987035f8b6c929b168560": {
                    "fields": {
                        "viewer": {
                            "resolvedFrom": "viewerUrn",
                            "type": "com.linkedin.e0372afc4a18480b00ca7e4906904fd7"
                        },
                        "vieweeFollowingViewer": {
                            "type": "boolean"
                        },
                        "viewerUrn": {
                            "type": "string"
                        },
                        "viewee": {
                            "resolvedFrom": "vieweeUrn",
                            "type": "com.linkedin.e0372afc4a18480b00ca7e4906904fd7"
                        },
                        "vieweeUrn": {
                            "type": "string"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.relationships.MemberToMemberFollowMetadata"
                },
                "com.linkedin.37da0dcf9c4df3c725740cceef3f71e1": {
                    "fields": {
                        "image": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "dismissTrackingActionType": {
                            "type": "string"
                        },
                        "description": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "legoTrackingToken": {
                            "type": "string"
                        },
                        "promptAction": {
                            "derivedFrom": "promptActionUnion",
                            "type": {
                                "union": {
                                    "recommendGroupPostAction": "com.linkedin.87379e51008ea9e2f1313627bb4cab8b",
                                    "navigate": "com.linkedin.280548a5c822f61a54f7d2022f1e02a5",
                                    "postGroupQuestionAction": "com.linkedin.389ba11b58ada97b0b37c2f75579b199",
                                    "follow": "com.linkedin.d50733b664c8019ae5d38b1804596f0b",
                                    "subscribe": "com.linkedin.6f5340bf6dde14897b3d4dde77e536d0",
                                    "connect": "com.linkedin.c97d64dfd15204616a896fea6339d850"
                                }
                            }
                        },
                        "promptActionUnion": {
                            "type": {
                                "union": {
                                    "recommendGroupPostAction": "com.linkedin.87379e51008ea9e2f1313627bb4cab8b",
                                    "navigate": "com.linkedin.280548a5c822f61a54f7d2022f1e02a5",
                                    "postGroupQuestionAction": "com.linkedin.389ba11b58ada97b0b37c2f75579b199",
                                    "follow": "com.linkedin.d50733b664c8019ae5d38b1804596f0b",
                                    "subscribe": "com.linkedin.6f5340bf6dde14897b3d4dde77e536d0",
                                    "connect": "com.linkedin.c97d64dfd15204616a896fea6339d850"
                                }
                            }
                        },
                        "title": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "imageNavigationContext": {
                            "type": "com.linkedin.8a612b4e445851d55ecf8b09571a05ee"
                        },
                        "trackingId": {
                            "type": "com.linkedin.common.TrackingId"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.prompt.PromptComponent"
                },
                "com.linkedin.89bd4e6ae57b7564ed65f21b35c3301f": {
                    "fields": {
                        "connectAction": {
                            "type": "com.linkedin.c97d64dfd15204616a896fea6339d850"
                        },
                        "annotationActionType": {
                            "type": "string"
                        },
                        "commentPrompt": {
                            "type": "com.linkedin.5bb56b584256b9eecd366c99b363e946"
                        },
                        "content": {
                            "derivedFrom": "contentUnion",
                            "type": {
                                "union": {
                                    "image": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b",
                                    "article": "com.linkedin.763d05b15c48f0290ff8e9d7c1b3b2e2"
                                }
                            }
                        },
                        "hideCommentActionUrn": {
                            "type": "string"
                        },
                        "followAction": {
                            "type": "com.linkedin.d50733b664c8019ae5d38b1804596f0b"
                        },
                        "createdAt": {
                            "type": "com.linkedin.common.Time"
                        },
                        "contentUnion": {
                            "type": {
                                "union": {
                                    "image": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b",
                                    "article": "com.linkedin.763d05b15c48f0290ff8e9d7c1b3b2e2"
                                }
                            }
                        },
                        "parentCommentUrn": {
                            "type": "string"
                        },
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.CommentUrn"
                        },
                        "parentComment": {
                            "resolvedFrom": "parentCommentUrn",
                            "type": "com.linkedin.89bd4e6ae57b7564ed65f21b35c3301f"
                        },
                        "headline": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "contributed": {
                            "type": "boolean"
                        },
                        "trackingId": {
                            "type": "com.linkedin.common.TrackingId"
                        },
                        "annotation": {
                            "type": "com.linkedin.c8bd17969c41cd526ddc4a7b36c8cdbe"
                        },
                        "edited": {
                            "type": "boolean"
                        },
                        "threadUrn": {
                            "type": "com.linkedin.common.Urn"
                        },
                        "translationUrn": {
                            "type": "string"
                        },
                        "timeOffset": {
                            "type": "long"
                        },
                        "rootSocialPermissions": {
                            "type": "com.linkedin.fdd9baf01d9a7fb371cf38f9ea53994d"
                        },
                        "commenter": {
                            "type": "com.linkedin.f3334456de9f114682f0aa58b456eacf"
                        },
                        "socialDetail": {
                            "type": "com.linkedin.c3ca265f1d14f57e9246103e6f28929a"
                        },
                        "displayReason": {
                            "type": "com.linkedin.voyager.dash.social.CommentDisplayReason"
                        },
                        "urn": {
                            "type": "com.linkedin.common.Urn"
                        },
                        "translation": {
                            "resolvedFrom": "translationUrn",
                            "type": "com.linkedin.581848b3153acfd08f0aa73ed2c8fb51"
                        },
                        "hideCommentAction": {
                            "resolvedFrom": "hideCommentActionUrn",
                            "type": "com.linkedin.1c85062c2fd2eabbef5700e6d7e8cf18"
                        },
                        "permalink": {
                            "type": "com.linkedin.common.Url"
                        },
                        "actions": {
                            "type": {
                                "array": "com.linkedin.voyager.dash.social.CommentAction"
                            }
                        },
                        "commentary": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.social.Comment"
                },
                "com.linkedin.56ed1d753079896e9ad350e6f461c483": {
                    "fields": {
                        "videoAspectRatio": {
                            "type": "double"
                        },
                        "swapTitleAndSubtitle": {
                            "type": "boolean"
                        },
                        "thumbnail": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "saveState": {
                            "type": "com.linkedin.f1b2492c05b41398477b887761d337a9"
                        },
                        "provider": {
                            "type": "string"
                        },
                        "subtitle": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "description": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "navigationContext": {
                            "type": "com.linkedin.8a612b4e445851d55ecf8b09571a05ee"
                        },
                        "showSmallTitle": {
                            "type": "boolean"
                        },
                        "inlineCtaButton": {
                            "type": "com.linkedin.280548a5c822f61a54f7d2022f1e02a5"
                        },
                        "title": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "backendUrn": {
                            "type": "com.linkedin.common.Urn"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.externalvideo.ExternalVideoComponent"
                },
                "com.linkedin.beb995e9eea7ce0c86eeb7189d9eeed9": {
                    "fields": {
                        "icon": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "url": {
                            "type": "com.linkedin.common.Url"
                        },
                        "text": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.NavigationAction"
                },
                "com.linkedin.b9da42623b690cc1c112e7c1c656c4df": {
                    "fields": {
                        "projectStateUrn": {
                            "type": "string"
                        },
                        "url": {
                            "type": "com.linkedin.common.Url"
                        },
                        "projectState": {
                            "resolvedFrom": "projectStateUrn",
                            "type": "com.linkedin.9a5cfd1782f34ef4cc794e99854515b7"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.CloseProjectAction"
                },
                "com.linkedin.aaad418ca3e178dc0877beb6e1e29026": {
                    "fields": {
                        "recipientProfileUrn": {
                            "type": "string"
                        },
                        "contextAttributes": {
                            "type": {
                                "array": "com.linkedin.d1cd6153f102beacf3fed6989c004d45"
                            }
                        },
                        "recipientProfile": {
                            "resolvedFrom": "recipientProfileUrn",
                            "type": "com.linkedin.e0372afc4a18480b00ca7e4906904fd7"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.common.coach.MagicWandActionParams"
                },
                "com.linkedin.abb1b649ad52210bbeb6ed9916741aa1": {
                    "fields": {
                        "unselectTrackingActionType": {
                            "type": "string"
                        },
                        "nextSurveyContent": {
                            "type": "com.linkedin.835a5c8d818060d54aaeabea1042afee"
                        },
                        "trackingActionType": {
                            "type": "string"
                        },
                        "optionsText": {
                            "type": "string"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.survey.SurveyPillOption"
                },
                "com.linkedin.4caf791202c7b71e3874d4551f078f32": {
                    "fields": {
                        "memberDistance": {
                            "type": "string"
                        },
                        "privacySettingsInjectionHolder": {
                            "type": "com.linkedin.c295a70635e475ee5248caf52e8b437c"
                        },
                        "nameMatch": {
                            "type": "boolean"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.EntityCustomTrackingInfo"
                },
                "com.linkedin.27ecf646f184ae13f7c56bd49482ba4d": {
                    "fields": {
                        "text": {
                            "type": "string"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.sponsoredcontent.leadgen.TextFieldComponent"
                },
                "com.linkedin.0b8e259b5baac26e5afa8bef054b6563": {
                    "fields": {
                        "paging": {
                            "type": "com.linkedin.9268b913957ab7557294a0063e05e100"
                        },
                        "metadata": {
                            "type": "com.linkedin.a8c1e0de3678025a4e773d45a672bedf"
                        },
                        "elements": {
                            "type": {
                                "array": "com.linkedin.89bd4e6ae57b7564ed65f21b35c3301f"
                            }
                        }
                    },
                    "baseType": "com.linkedin.restli.common.CollectionResponse"
                },
                "com.linkedin.352de81121adae09c8392d6f11d028a0": {
                    "fields": {
                        "localizedLastUpdatedDisplayText": {
                            "type": "string"
                        },
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.JobPostingUrn"
                        },
                        "jobState": {
                            "type": "com.linkedin.voyager.dash.jobs.JobState"
                        },
                        "trustReview": {
                            "type": "com.linkedin.68fad358e2fc4bf4a75296c8e83879a4"
                        },
                        "formattedJobStateDisplayText": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "localizedTotalChargeDisplayText": {
                            "type": "string"
                        },
                        "trustReviewDecision": {
                            "type": "com.linkedin.voyager.dash.jobs.JobPostingTrustClassification"
                        },
                        "title": {
                            "type": "string"
                        },
                        "localizedJobStateDisplayText": {
                            "type": "string"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.jobs.JobPosting"
                },
                "com.linkedin.0d4ab2c158752b17b06ddd97bd989146": {
                    "fields": {
                        "memberRelationshipUrn": {
                            "type": "string"
                        },
                        "memberRelationship": {
                            "resolvedFrom": "memberRelationshipUrn",
                            "type": "com.linkedin.c03d6d673ac4f7503bd4aeb7d200cfd7"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.relationships.MemberRelationshipWrapper"
                },
                "com.linkedin.7737d1abf743001bc78e672aaeea5e65": {
                    "fields": {
                        "image": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "text": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.common.ux.InsightViewModel"
                },
                "com.linkedin.b6bf8ef542d64cafbaf37dcc36abf642": {
                    "fields": {
                        "transcripts": {
                            "type": {
                                "array": "string"
                            }
                        },
                        "pagesPerResolution": {
                            "type": {
                                "array": "com.linkedin.2f237373fe71eba70adab84023a31b11"
                            }
                        }
                    },
                    "baseType": "com.linkedin.documentcontent.DocumentPages"
                },
                "com.linkedin.3e907fa58f3cf80fda86c628de9593d1": {
                    "fields": {
                        "invitationUrn": {
                            "type": "string"
                        },
                        "relationshipData": {
                            "derivedFrom": "relationshipDataUnion",
                            "type": {
                                "union": {
                                    "follow": "com.linkedin.dc25bfd4efdb653930120656f4715cad"
                                }
                            }
                        },
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.DirectionalEntityRelationshipUrn"
                        },
                        "invitation": {
                            "resolvedFrom": "invitationUrn",
                            "type": "com.linkedin.b95815644054b75e89af04b98b438272"
                        },
                        "relationshipDataUnion": {
                            "type": {
                                "union": {
                                    "follow": "com.linkedin.dc25bfd4efdb653930120656f4715cad"
                                }
                            }
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.relationships.DirectionalEntityRelationship"
                },
                "com.linkedin.835a5c8d818060d54aaeabea1042afee": {
                    "fields": {
                        "options": {
                            "type": {
                                "array": "com.linkedin.abb1b649ad52210bbeb6ed9916741aa1"
                            }
                        },
                        "titleImage": {
                            "type": "com.linkedin.voyager.dash.common.SystemImageName"
                        },
                        "titleA11yText": {
                            "type": "string"
                        },
                        "multiSelectCheckbox": {
                            "type": "boolean"
                        },
                        "titleText": {
                            "type": "string"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.survey.MultiSelectSurveyContent"
                },
                "com.linkedin.97c03ebc33ae0e5d11a4485b5918f0b2": {
                    "fields": {
                        "edgeSettingOptions": {
                            "type": {
                                "array": "com.linkedin.a4384b71875a73ae598fe7c0fa90316f"
                            }
                        },
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.EdgeSettingUrn"
                        },
                        "selectedOptionType": {
                            "type": "com.linkedin.voyager.dash.identity.notifications.edgesetting.EdgeSettingOptionType"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.identity.notifications.edgesetting.EdgeSetting"
                },
                "com.linkedin.0f36f2dc6be4ed6af3361a6356cb19e0": {
                    "fields": {
                        "buttonUnion": {
                            "type": {
                                "union": {
                                    "follow": "com.linkedin.d50733b664c8019ae5d38b1804596f0b"
                                }
                            }
                        },
                        "button": {
                            "derivedFrom": "buttonUnion",
                            "type": {
                                "union": {
                                    "follow": "com.linkedin.d50733b664c8019ae5d38b1804596f0b"
                                }
                            }
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.togglebutton.ToggleButtonComponent"
                },
                "com.linkedin.581848b3153acfd08f0aa73ed2c8fb51": {
                    "fields": {
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.TranslationUrn"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.TranslatedTextViewModel"
                },
                "com.linkedin.4aad72588c95348a1c39f08789b66191": {
                    "fields": {
                        "navigationContext": {
                            "type": "com.linkedin.7d07a0360cd523ec5f0f30948903dfe4"
                        },
                        "image": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "commentaryText": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.miniupdate.MiniUpdateCommentaryComponent"
                },
                "com.linkedin.8ff002aafcb203f2b95c57c175c2f91c": {
                    "fields": {
                        "image": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "backgroundColor": {
                            "type": "com.linkedin.voyager.dash.feed.component.promo.PromoBackgroundColor"
                        },
                        "useExperimentalTemplate": {
                            "type": "boolean"
                        },
                        "subtitle": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "logo": {
                            "type": "com.linkedin.voyager.dash.common.SystemImageName"
                        },
                        "socialProof": {
                            "type": "com.linkedin.7737d1abf743001bc78e672aaeea5e65"
                        },
                        "primaryCta": {
                            "type": "com.linkedin.280548a5c822f61a54f7d2022f1e02a5"
                        },
                        "title": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.promo.PromoComponent"
                },
                "com.linkedin.60216d4fa134df147fcc8c39e71c7139": {
                    "fields": {
                        "urn": {
                            "type": "com.linkedin.common.Urn"
                        },
                        "highlightedReactorName": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "numComments": {
                            "type": "long"
                        },
                        "reactionTypeCounts": {
                            "type": {
                                "array": "com.linkedin.79dc13b17813e9f911798452d89dfd25"
                            }
                        },
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.SocialActivityCountsUrn"
                        },
                        "reactionByOrganizationActor": {
                            "type": "com.linkedin.voyager.dash.feed.social.ReactionType"
                        },
                        "numShares": {
                            "type": "long"
                        },
                        "numImpressions": {
                            "type": "long"
                        },
                        "reacted": {
                            "type": "com.linkedin.voyager.dash.feed.social.ReactionType"
                        },
                        "numLikes": {
                            "type": "long"
                        },
                        "preDashEntityUrn": {
                            "type": "com.linkedin.voyager.dash.common.PreDashUrn"
                        },
                        "liked": {
                            "type": "boolean"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.SocialActivityCounts"
                },
                "com.linkedin.b7c96922cb665f0dfc163d5e56e6c473": {
                    "fields": {
                        "formSections": {
                            "type": {
                                "array": "com.linkedin.bf4a9da37c7bd305a433eb83fc687ec9"
                            }
                        },
                        "submitted": {
                            "type": "boolean"
                        },
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.LeadGenFormUrn"
                        },
                        "privacyPolicy": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "postSubmissionContent": {
                            "type": "com.linkedin.bed8a76f30dfd26b202f7fce1ff36982"
                        },
                        "lastSubmittedAt": {
                            "type": "com.linkedin.common.Time"
                        },
                        "banner": {
                            "type": "com.linkedin.ae6cfa93b0c5d4019f8f664ba38e4ec1"
                        },
                        "header": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "trackingMetadata": {
                            "type": "string"
                        },
                        "submitButtonText": {
                            "type": "string"
                        },
                        "customPrivacyPolicy": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "consentSection": {
                            "type": "com.linkedin.bf4a9da37c7bd305a433eb83fc687ec9"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.sponsoredcontent.leadgen.LeadGenForm"
                },
                "com.linkedin.65bd51e43ed8142eb9d37a29845f6c04": {
                    "fields": {
                        "featuredComments": {
                            "type": {
                                "array": "com.linkedin.89bd4e6ae57b7564ed65f21b35c3301f"
                            }
                        },
                        "socialActivityCounts": {
                            "type": "com.linkedin.60216d4fa134df147fcc8c39e71c7139"
                        },
                        "coverImage": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "navigationContext": {
                            "type": "com.linkedin.8a612b4e445851d55ecf8b09571a05ee"
                        },
                        "showContributionExperience": {
                            "type": "boolean"
                        },
                        "title": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "bottomCta": {
                            "type": "com.linkedin.280548a5c822f61a54f7d2022f1e02a5"
                        },
                        "headline": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.conversations.ConversationsComponent"
                },
                "com.linkedin.4800cf47c45b503f71b557dd2e8d1a53": {
                    "fields": {
                        "formComponent": {
                            "derivedFrom": "formComponentUnion",
                            "type": {
                                "union": {
                                    "textFieldComponent": "com.linkedin.27ecf646f184ae13f7c56bd49482ba4d",
                                    "dropdownSelectComponent": "com.linkedin.25265028140e76f7b439f0b94f7744c1",
                                    "textInputComponent": "com.linkedin.7ac947f07f51a4f901ec34224c82f187",
                                    "checkboxComponent": "com.linkedin.d2f69f81cddf8b512448d332a9bf5d15"
                                }
                            }
                        },
                        "requiredFieldMissingErrorText": {
                            "type": "string"
                        },
                        "question": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "editable": {
                            "type": "boolean"
                        },
                        "leadGenFormQuestionUrn": {
                            "type": "com.linkedin.voyager.dash.common.LeadGenFormQuestionUrn"
                        },
                        "formComponentUnion": {
                            "type": {
                                "union": {
                                    "textFieldComponent": "com.linkedin.27ecf646f184ae13f7c56bd49482ba4d",
                                    "dropdownSelectComponent": "com.linkedin.25265028140e76f7b439f0b94f7744c1",
                                    "textInputComponent": "com.linkedin.7ac947f07f51a4f901ec34224c82f187",
                                    "checkboxComponent": "com.linkedin.d2f69f81cddf8b512448d332a9bf5d15"
                                }
                            }
                        },
                        "required": {
                            "type": "boolean"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.sponsoredcontent.leadgen.LeadGenFormQuestion"
                },
                "com.linkedin.dfac8c8d5d692ba68fedb94e12f20ffc": {
                    "fields": {
                        "simpleInsights": {
                            "type": {
                                "array": "com.linkedin.bd9a707a5b119c1f331373113f57344a"
                            }
                        },
                        "title": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "overflowActions": {
                            "type": {
                                "array": "com.linkedin.30dee75e249786a8e1ceb4c1d056ab57"
                            }
                        },
                        "entityInsight": {
                            "type": "com.linkedin.cf4b25c18907ea8eafe915c8bfa24109"
                        },
                        "trackingId": {
                            "type": "com.linkedin.common.TrackingId"
                        },
                        "trackingUrn": {
                            "type": "com.linkedin.common.Urn"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.KnowledgeCard"
                },
                "com.linkedin.dc25bfd4efdb653930120656f4715cad": {
                    "fields": {
                        "metadata": {
                            "derivedFrom": "metadataUnion",
                            "type": {
                                "union": {
                                    "memberToMemberFollow": "com.linkedin.1fa80808336987035f8b6c929b168560",
                                    "memberToCompanyFollow": "com.linkedin.d5750a45700fb234845060fc6e66e87d"
                                }
                            }
                        },
                        "metadataUnion": {
                            "type": {
                                "union": {
                                    "memberToMemberFollow": "com.linkedin.1fa80808336987035f8b6c929b168560",
                                    "memberToCompanyFollow": "com.linkedin.d5750a45700fb234845060fc6e66e87d"
                                }
                            }
                        },
                        "followingStateUrn": {
                            "type": "string"
                        },
                        "followingState": {
                            "resolvedFrom": "followingStateUrn",
                            "type": "com.linkedin.1a9edf7c4fc5f73ec859a1ae4c8105fe"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.relationships.FollowRelationship"
                },
                "com.linkedin.40aec9fadea85bb6c6cc433e84fa91b7": {
                    "fields": {
                        "school": {
                            "resolvedFrom": "schoolUrn",
                            "type": "com.linkedin.daa3a2cada5a579731c11a78fbd82e2d"
                        },
                        "vectorImage": {
                            "type": "com.linkedin.28db8575bcf1c65bdc4bc15948d50ee9"
                        },
                        "schoolUrn": {
                            "type": "string"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.common.image.NonEntitySchoolLogo"
                },
                "com.linkedin.7ffe66f430e869d947d257aaf7c1e2b8": {
                    "fields": {
                        "lastComponentUnion": {
                            "type": {
                                "union": {
                                    "buttonComponent": "com.linkedin.280548a5c822f61a54f7d2022f1e02a5"
                                }
                            }
                        },
                        "updates": {
                            "type": {
                                "array": "com.linkedin.757852411fb0feeedcbd4df1cbcfcd54"
                            }
                        },
                        "lastComponent": {
                            "derivedFrom": "lastComponentUnion",
                            "type": {
                                "union": {
                                    "buttonComponent": "com.linkedin.280548a5c822f61a54f7d2022f1e02a5"
                                }
                            }
                        },
                        "type": {
                            "type": "com.linkedin.voyager.dash.feed.aggregated.AggregatedContentDisplayType"
                        },
                        "visibleCount": {
                            "type": "int"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.aggregated.AggregatedContent"
                },
                "com.linkedin.4acb03668cbf076750aad6513cd36f43": {
                    "fields": {
                        "authorProfileId": {
                            "type": "string"
                        },
                        "contentSource": {
                            "type": "com.linkedin.voyager.dash.common.semaphore.ContentSource"
                        },
                        "targetUrn": {
                            "type": "com.linkedin.common.Urn"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.common.semaphore.SemaphoreContext"
                },
                "com.linkedin.59743104bf85ef6a7c2a2bb2b2491b8d": {
                    "fields": {
                        "controlName": {
                            "type": "com.linkedin.voyager.dash.common.tracking.ControlName"
                        },
                        "type": {
                            "type": "com.linkedin.voyager.dash.relationships.invitation.InvitationRelationshipOptionType"
                        },
                        "name": {
                            "type": "string"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.relationships.invitation.InvitationRelationshipOption"
                },
                "com.linkedin.cd89160de71b547693b54b81d054de0b": {
                    "fields": {
                        "subscribeAction": {
                            "type": "com.linkedin.6f5340bf6dde14897b3d4dde77e536d0"
                        },
                        "authorByline": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "viewCtaButton": {
                            "type": "com.linkedin.280548a5c822f61a54f7d2022f1e02a5"
                        },
                        "navigationContext": {
                            "type": "com.linkedin.8a612b4e445851d55ecf8b09571a05ee"
                        },
                        "description": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "logo": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "title": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "cadence": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.newsletter.NewsletterComponent"
                },
                "com.linkedin.762fc611b9734ba7fde2123ce919a75e": {
                    "fields": {
                        "thumbnail": {
                            "type": "com.linkedin.28db8575bcf1c65bdc4bc15948d50ee9"
                        },
                        "progressiveStreams": {
                            "type": {
                                "array": "com.linkedin.bc0bbec78a9509f86af3f11c12b1caee"
                            }
                        },
                        "liveStreamCreatedAt": {
                            "type": "com.linkedin.common.Time"
                        },
                        "prevMedia": {
                            "type": "com.linkedin.common.Urn"
                        },
                        "transcripts": {
                            "type": {
                                "array": "com.linkedin.e58399cfa33284b0ebcc7a60779f763b"
                            }
                        },
                        "aspectRatio": {
                            "type": "float"
                        },
                        "media": {
                            "type": "com.linkedin.common.Urn"
                        },
                        "c2paManifestData": {
                            "type": "com.linkedin.6682f4c299a743c2d0af15465ee7b16d"
                        },
                        "adaptiveStreams": {
                            "type": {
                                "array": "com.linkedin.5b25413c8b10039f1c2b38d4a221c06f"
                            }
                        },
                        "liveStreamEndedAt": {
                            "type": "com.linkedin.common.Time"
                        },
                        "duration": {
                            "type": "long"
                        },
                        "provider": {
                            "type": "com.linkedin.videocontent.MediaSource"
                        },
                        "entityUrn": {
                            "type": "com.linkedin.common.Urn"
                        },
                        "nextMedia": {
                            "type": "com.linkedin.common.Urn"
                        },
                        "thumbnails": {
                            "type": {
                                "array": "com.linkedin.dc2d3fd81a613be5ab390adced48f313"
                            }
                        },
                        "trackingId": {
                            "type": "string"
                        }
                    },
                    "baseType": "com.linkedin.videocontent.VideoPlayMetadata"
                },
                "com.linkedin.dbc196cb1403f434db1f269623b4a620": {
                    "fields": {
                        "paidInMail": {
                            "type": "boolean"
                        },
                        "extensionContentContextUrn": {
                            "type": "com.linkedin.common.Urn"
                        },
                        "recipient": {
                            "resolvedFrom": "recipientUrns",
                            "type": {
                                "array": "com.linkedin.e0372afc4a18480b00ca7e4906904fd7"
                            }
                        },
                        "messageRequestContextUrn": {
                            "type": "com.linkedin.common.Urn"
                        },
                        "recipientUrns": {
                            "type": {
                                "array": "string"
                            }
                        },
                        "targetUrl": {
                            "type": "com.linkedin.common.Url"
                        },
                        "existingConversation": {
                            "resolvedFrom": "existingConversationUrn",
                            "type": "com.linkedin.0337116cb8f03f02a7efa1361f45850f"
                        },
                        "existingConversationUrn": {
                            "type": "string"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.messaging.compose.ComposeNavigationContext"
                },
                "com.linkedin.389ba11b58ada97b0b37c2f75579b199": {
                    "fields": {
                        "buttonText": {
                            "type": "string"
                        },
                        "questionUrn": {
                            "type": "com.linkedin.common.Urn"
                        },
                        "questionText": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.actions.postquestion.PostGroupQuestionAction"
                },
                "com.linkedin.dbe3dc7ec313938618c482695c80e952": {
                    "fields": {
                        "description": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "image": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "largeCtaButton": {
                            "type": "com.linkedin.280548a5c822f61a54f7d2022f1e02a5"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.seemore.SeeMoreComponent"
                },
                "com.linkedin.4b009c1d6ea192a94bda77fb9ace3a7d": {
                    "fields": {
                        "ringStatus": {
                            "type": "com.linkedin.9d67b80fb82e3d96227749fd6d468116"
                        },
                        "profileUrn": {
                            "type": "string"
                        },
                        "vectorImage": {
                            "type": "com.linkedin.28db8575bcf1c65bdc4bc15948d50ee9"
                        },
                        "profile": {
                            "resolvedFrom": "profileUrn",
                            "type": "com.linkedin.e0372afc4a18480b00ca7e4906904fd7"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.common.image.NonEntityProfilePicture"
                },
                "com.linkedin.499a0be5e49d2be9202b331ff124e675": {
                    "fields": {
                        "cta": {
                            "type": "com.linkedin.280548a5c822f61a54f7d2022f1e02a5"
                        },
                        "backgroundTopColor": {
                            "type": "com.linkedin.voyager.dash.feed.component.showcase.ShowcaseBackgroundColor"
                        },
                        "backgroundImage": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "subtitle": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "backgroundBottomColor": {
                            "type": "com.linkedin.voyager.dash.feed.component.showcase.ShowcaseBackgroundColor"
                        },
                        "icon": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "navigationContext": {
                            "type": "com.linkedin.8a612b4e445851d55ecf8b09571a05ee"
                        },
                        "iconNavigationContext": {
                            "type": "com.linkedin.8a612b4e445851d55ecf8b09571a05ee"
                        },
                        "title": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "supplementaryIcon": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.showcase.ShowcaseComponent"
                },
                "com.linkedin.055f25d019920e58d653dd2fa062dd53": {
                    "fields": {
                        "instructions": {
                            "type": "string"
                        },
                        "question": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.DynamicPollCurrentQuestionUrn"
                        },
                        "voteCompletionMessage": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "noneOfTheAbovePollOption": {
                            "type": "com.linkedin.f527e0fb798181c7a317905f54d4ecc5"
                        },
                        "pollOptions": {
                            "type": {
                                "array": "com.linkedin.f527e0fb798181c7a317905f54d4ecc5"
                            }
                        },
                        "submitVoteButton": {
                            "type": "string"
                        },
                        "preDashEntityUrn": {
                            "type": "com.linkedin.voyager.dash.common.PreDashUrn"
                        },
                        "pollOptionButtonType": {
                            "type": "com.linkedin.voyager.dash.feed.component.dynamicpolls.PollOptionButtonType"
                        },
                        "multiSelect": {
                            "type": "boolean"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.dynamicpolls.DynamicPollCurrentQuestion"
                },
                "com.linkedin.14537f958f34fe6d11e2a5ec02e5ca16": {
                    "fields": {
                        "groupUrn": {
                            "type": "string"
                        },
                        "vectorImage": {
                            "type": "com.linkedin.28db8575bcf1c65bdc4bc15948d50ee9"
                        },
                        "group": {
                            "resolvedFrom": "groupUrn",
                            "type": "com.linkedin.c8f5bf5a9d5e0dbbc3c824c2dfd751a8"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.common.image.NonEntityGroupLogo"
                },
                "com.linkedin.17602d9bd6fd3c2435cab1748e7900cf": {
                    "fields": {
                        "image": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "navigationContext": {
                            "type": "com.linkedin.8a612b4e445851d55ecf8b09571a05ee"
                        },
                        "legoTrackingToken": {
                            "type": "string"
                        },
                        "headline": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "subHeadline": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.ctaComponent.CallToActionComponent"
                },
                "com.linkedin.0a6bf75f2372f1c4ba5a251882c0a894": {
                    "fields": {
                        "actionDataModel": {
                            "resolvedFrom": "actionDataModelUnion",
                            "type": {
                                "union": {
                                    "connectionOrInvitation": "com.linkedin.c03d6d673ac4f7503bd4aeb7d200cfd7",
                                    "relationshipActionData": "com.linkedin.6f08f9ec26b0f1c58494b5f6171c698e",
                                    "memberToEntityRelationship": "com.linkedin.3e907fa58f3cf80fda86c628de9593d1",
                                    "follow": "com.linkedin.1a9edf7c4fc5f73ec859a1ae4c8105fe"
                                }
                            }
                        },
                        "actionDataModelUnion": {
                            "type": {
                                "union": {
                                    "connectionOrInvitation": "string",
                                    "relationshipActionData": "com.linkedin.6f08f9ec26b0f1c58494b5f6171c698e",
                                    "memberToEntityRelationship": "string",
                                    "follow": "string"
                                }
                            }
                        },
                        "emphasisStyle": {
                            "type": "com.linkedin.voyager.dash.common.ux.button.StatefulButtonHierarchy"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.common.ux.button.StatefulButtonModel"
                },
                "com.linkedin.c8f5bf5a9d5e0dbbc3c824c2dfd751a8": {
                    "fields": {
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.GroupUrn"
                        },
                        "backendGroupUrn": {
                            "type": "com.linkedin.common.GroupUrn"
                        },
                        "publicVisibility": {
                            "type": "boolean"
                        },
                        "name": {
                            "type": "string"
                        },
                        "logo": {
                            "type": {
                                "union": {
                                    "url": "com.linkedin.common.Url",
                                    "vectorImage": "com.linkedin.28db8575bcf1c65bdc4bc15948d50ee9"
                                }
                            }
                        },
                        "heroImage": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "logoResolutionResult": {
                            "derivedFrom": "logo",
                            "type": {
                                "union": {
                                    "url": "com.linkedin.common.Url",
                                    "vectorImage": "com.linkedin.28db8575bcf1c65bdc4bc15948d50ee9"
                                }
                            }
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.groups.Group"
                },
                "com.linkedin.795aca8b0690435f405c793a8ffcf615": {
                    "fields": {
                        "scheduledContentViewerStatus": {
                            "type": "com.linkedin.voyager.dash.scheduledcontent.ScheduledContentViewerStatus"
                        },
                        "preDashEntityUrn": {
                            "type": "com.linkedin.voyager.dash.common.PreDashUrn"
                        },
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.ScheduledContentViewerStateUrn"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.scheduledcontent.ScheduledContentViewerState"
                },
                "com.linkedin.6caaeab285566e3922584bf512297d62": {
                    "fields": {
                        "title": {
                            "type": "string"
                        },
                        "filters": {
                            "type": {
                                "array": "com.linkedin.0134fedeb876326e67efb0b562630cc0"
                            }
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.SearchFilterGroupViewModel"
                },
                "com.linkedin.b5f458ef8275d3ac65c2a01df1d9328d": {
                    "fields": {
                        "title": {
                            "type": "string"
                        },
                        "icon": {
                            "type": "com.linkedin.voyager.dash.common.SystemImageName"
                        },
                        "description": {
                            "type": "string"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.SearchIllustrationCard"
                },
                "com.linkedin.6eee18f6ca0e23d5f86fb04aa22c5516": {
                    "fields": {
                        "updateSaveState": {
                            "type": "com.linkedin.f1b2492c05b41398477b887761d337a9"
                        },
                        "hideCommentsCount": {
                            "type": "boolean"
                        },
                        "hideReactionsCount": {
                            "type": "boolean"
                        },
                        "hideSocialActivityCounts": {
                            "type": "boolean"
                        },
                        "hideShareAction": {
                            "type": "boolean"
                        },
                        "hideSendAction": {
                            "type": "boolean"
                        },
                        "hideRepostsCount": {
                            "type": "boolean"
                        },
                        "hideViewsCount": {
                            "type": "boolean"
                        },
                        "trustInterventionBanner": {
                            "type": "com.linkedin.d067ea339aae1c25da65a9f86eb786ad"
                        },
                        "hideReactAction": {
                            "type": "boolean"
                        },
                        "coachAction": {
                            "type": "com.linkedin.ff4c51d111da4ffaaae179a2eaf9a303"
                        },
                        "hideCommentAction": {
                            "type": "boolean"
                        },
                        "shareUrl": {
                            "type": "com.linkedin.common.Url"
                        },
                        "showContributionExperience": {
                            "type": "boolean"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.social.SocialContent"
                },
                "com.linkedin.ae6cfa93b0c5d4019f8f664ba38e4ec1": {
                    "fields": {
                        "entityImage": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "backgroundImage": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "subtitle": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "subDescription": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "description": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "contentHorizontallyCentered": {
                            "type": "boolean"
                        },
                        "title": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.sponsoredcontent.leadgen.LeadGenBannerComponent"
                },
                "com.linkedin.a61eaf39f1cf127adaf1233791804a39": {
                    "fields": {
                        "highlightedMessage": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "headline": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "image": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.celebration.CelebrationComponent"
                },
                "com.linkedin.fce42282743d6566d0809f9f30cac942": {
                    "fields": {
                        "type": {
                            "type": "com.linkedin.voyager.dash.common.text.ListStyleType"
                        },
                        "index": {
                            "type": "int"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.common.text.ListItemStyle"
                },
                "com.linkedin.02ae76f0e0810b81c62a4dd5f1cc509f": {
                    "fields": {
                        "endImage": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "navigationContext": {
                            "type": "com.linkedin.8a612b4e445851d55ecf8b09571a05ee"
                        },
                        "startImage": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "text": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.linkedinvideo.InPlayerCta"
                },
                "com.linkedin.fd4f461137d628e214f2c67640064f40": {
                    "fields": {
                        "cta": {
                            "type": "com.linkedin.280548a5c822f61a54f7d2022f1e02a5"
                        },
                        "description": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "image": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "title": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.divider.FeedDividerComponent"
                },
                "com.linkedin.fdd9baf01d9a7fb371cf38f9ea53994d": {
                    "fields": {
                        "canPostComments": {
                            "type": "boolean"
                        },
                        "preDashEntityUrn": {
                            "type": "com.linkedin.voyager.dash.common.PreDashUrn"
                        },
                        "messagePermission": {
                            "type": "com.linkedin.voyager.dash.social.MessagePermission"
                        },
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.SocialPermissionsUrn"
                        },
                        "canShare": {
                            "type": "boolean"
                        },
                        "canReact": {
                            "type": "boolean"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.social.SocialPermissions"
                },
                "com.linkedin.f77b3da15411c8424bc6239fecafe2db": {
                    "fields": {
                        "variant": {
                            "type": "string"
                        },
                        "country": {
                            "type": "string"
                        },
                        "language": {
                            "type": "string"
                        }
                    },
                    "baseType": "com.linkedin.common.Locale"
                },
                "com.linkedin.3be27b5a0eb7edd91e98b14c0290096c": {
                    "fields": {
                        "companyUrn": {
                            "type": "string"
                        },
                        "company": {
                            "resolvedFrom": "companyUrn",
                            "type": "com.linkedin.2c2374bef3eaba3e079b4a11e2f7bea8"
                        },
                        "vectorImage": {
                            "type": "com.linkedin.28db8575bcf1c65bdc4bc15948d50ee9"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.common.image.NonEntityCompanyLogo"
                },
                "com.linkedin.ae028897a212c87f2a4f1a573b71652d": {
                    "fields": {
                        "type": {
                            "type": "com.linkedin.voyager.dash.jobs.JobPostingCardFooterItemType"
                        },
                        "timeAt": {
                            "type": "com.linkedin.common.Time"
                        },
                        "text": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.jobs.JobPostingCardFooterItem"
                },
                "com.linkedin.49b164ca1d0b5ff5bc8c1f97c55b7c32": {
                    "fields": {
                        "actionType": {
                            "type": "string"
                        },
                        "type": {
                            "type": "com.linkedin.voyager.dash.feed.controlmenu.HidePostActionType"
                        },
                        "preDashEntityUrn": {
                            "type": "com.linkedin.voyager.dash.common.PreDashUrn"
                        },
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.HidePostActionUrn"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.controlmenu.HidePostAction"
                },
                "com.linkedin.3a88e7bf8b5e1c81be38f30d05a7155c": {
                    "fields": {
                        "submitted": {
                            "type": "boolean"
                        },
                        "footerText": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "question": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "headerText": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "confirmationCtaButton": {
                            "type": "com.linkedin.280548a5c822f61a54f7d2022f1e02a5"
                        },
                        "surveyResponse": {
                            "type": {
                                "array": "com.linkedin.1bca01c8205c4ce1116a059cca10e725"
                            }
                        },
                        "confirmationSubtext": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "confirmationText": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.survey.SurveyComponent"
                },
                "com.linkedin.f1ad523ada0160376aa5abe5356f3115": {
                    "fields": {
                        "utype": {
                            "type": "string"
                        },
                        "referenceId": {
                            "type": "com.linkedin.common.TrackingId"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.premium.PremiumFunnelCommonHeader"
                },
                "com.linkedin.d81debcec40db70c10df9aafd5fc6fdb": {
                    "fields": {
                        "subtitle": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "titleActionType": {
                            "type": "string"
                        },
                        "subtitleControlName": {
                            "type": "com.linkedin.voyager.dash.common.tracking.ControlName"
                        },
                        "title": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "subtitleActionType": {
                            "type": "string"
                        },
                        "titleControlName": {
                            "type": "com.linkedin.voyager.dash.common.tracking.ControlName"
                        },
                        "trackingId": {
                            "type": "com.linkedin.common.TrackingId"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.QueryClarificationCard"
                },
                "com.linkedin.c293aa010e51bae32433eeb13b1682fa": {
                    "fields": {
                        "searchDashClustersByAll": {
                            "type": "com.linkedin.5f1d22f924ecb6a031ee124b8b767900"
                        }
                    },
                    "baseType": "com.linkedin.graphql.Query"
                },
                "com.linkedin.25265028140e76f7b439f0b94f7744c1": {
                    "fields": {
                        "multipleChoiceQuestionOptions": {
                            "type": {
                                "array": "com.linkedin.0da2d18a70c6934158f5d9caa1264add"
                            }
                        },
                        "placeholderText": {
                            "type": "string"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.sponsoredcontent.leadgen.DropdownSelectComponent"
                },
                "com.linkedin.c47b47d5266a72a0c07dc72ecee637c0": {
                    "fields": {
                        "tapTargetEntityUnion": {
                            "type": {
                                "union": {
                                    "companyUrn": "string",
                                    "profileUrn": "string"
                                }
                            }
                        },
                        "firstCornerXOffsetPercentage": {
                            "type": "float"
                        },
                        "type": {
                            "type": "com.linkedin.voyager.dash.common.TapTargetAttributeType"
                        },
                        "thirdCornerYOffsetPercentage": {
                            "type": "float"
                        },
                        "url": {
                            "type": "com.linkedin.common.Url"
                        },
                        "urn": {
                            "type": "com.linkedin.common.Urn"
                        },
                        "thirdCornerXOffsetPercentage": {
                            "type": "float"
                        },
                        "secondCornerYOffsetPercentage": {
                            "type": "float"
                        },
                        "fourthCornerXOffsetPercentage": {
                            "type": "float"
                        },
                        "tapTargetEntity": {
                            "resolvedFrom": "tapTargetEntityUnion",
                            "type": {
                                "union": {
                                    "companyUrn": "com.linkedin.2c2374bef3eaba3e079b4a11e2f7bea8",
                                    "profileUrn": "com.linkedin.e0372afc4a18480b00ca7e4906904fd7"
                                }
                            }
                        },
                        "firstCornerYOffsetPercentage": {
                            "type": "float"
                        },
                        "rank": {
                            "type": "int"
                        },
                        "untaggable": {
                            "type": "boolean"
                        },
                        "fourthCornerYOffsetPercentage": {
                            "type": "float"
                        },
                        "text": {
                            "type": "string"
                        },
                        "secondCornerXOffsetPercentage": {
                            "type": "float"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.common.TapTarget"
                },
                "com.linkedin.81b214c2cdd4f02cdb7d827958d2f3a1": {
                    "fields": {
                        "start": {
                            "type": "int"
                        },
                        "count": {
                            "type": "int"
                        },
                        "total": {
                            "type": "int"
                        }
                    },
                    "baseType": "com.linkedin.restli.common.CollectionMetadata"
                },
                "com.linkedin.6ad8529dd2cb1e17dae165dbe981c7ff": {
                    "fields": {
                        "playCount": {
                            "type": "int"
                        },
                        "actorImage": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "commentaryLines": {
                            "type": "int"
                        },
                        "videoPlayMetadata": {
                            "type": "com.linkedin.762fc611b9734ba7fde2123ce919a75e"
                        },
                        "actorName": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "commentary": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "actorDescription": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "socialDetail": {
                            "type": "com.linkedin.c3ca265f1d14f57e9246103e6f28929a"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.linkedinvideo.VideoCarouselItemComponent"
                },
                "com.linkedin.2f504e1a87d0f08b5ece5c874db6865f": {
                    "fields": {
                        "description": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "undoTrackingActionType": {
                            "type": "string"
                        },
                        "undoA11yText": {
                            "type": "string"
                        },
                        "title": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.social.HideCommentConfirmation"
                },
                "com.linkedin.e3bf41d90ee4ffc0edf0c6e16c6a18c1": {
                    "fields": {
                        "instructions": {
                            "type": "string"
                        },
                        "creatorView": {
                            "type": "boolean"
                        },
                        "pollSummary": {
                            "type": "com.linkedin.28bac58e0d18d7324652c1411b75d180"
                        },
                        "question": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "uniqueVotersCountNavigationLink": {
                            "type": "com.linkedin.8a612b4e445851d55ecf8b09571a05ee"
                        },
                        "voteCompletionMessage": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "noneOfTheAbovePollOption": {
                            "type": "com.linkedin.f527e0fb798181c7a317905f54d4ecc5"
                        },
                        "showPollSummaryInfo": {
                            "type": "boolean"
                        },
                        "pollOptions": {
                            "type": {
                                "array": "com.linkedin.f527e0fb798181c7a317905f54d4ecc5"
                            }
                        },
                        "submitVoteButton": {
                            "type": "string"
                        },
                        "visibilityInfo": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "multiSelect": {
                            "type": "boolean"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.polls.PollComponent"
                },
                "com.linkedin.8e45407c0ff4b66154fdb557947fc44c": {
                    "fields": {
                        "summary": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "cardExpandability": {
                            "type": "boolean"
                        },
                        "trackingUrn": {
                            "type": "com.linkedin.common.Urn"
                        },
                        "cardExpanded": {
                            "type": "boolean"
                        },
                        "navigationContext": {
                            "type": "com.linkedin.55ee9afd4182671fe7e271f615659525"
                        },
                        "renderPrimaryQuestion": {
                            "type": "boolean"
                        },
                        "entityEmbeddedObject": {
                            "type": "com.linkedin.bd93318ac5710b71fba68ebb50fd5bfd"
                        },
                        "title": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "trackingId": {
                            "type": "com.linkedin.common.TrackingId"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.TopicalQuestionCard"
                },
                "com.linkedin.5af8ef0ab96fc30191b92b12e1d5d6f4": {
                    "fields": {
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.OrganizationalPageUrn"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.organization.OrganizationalPage"
                },
                "com.linkedin.edd11a570456ce19ca1f5ec3c9bb03c1": {
                    "fields": {
                        "itemUnion": {
                            "type": {
                                "union": {
                                    "entityResult": "com.linkedin.cf4b25c18907ea8eafe915c8bfa24109",
                                    "cluster": "com.linkedin.5c853aba2154c55483e72bf6cdfaaf3e",
                                    "searchAlert": "com.linkedin.5900d2a09d6af2333ee95a4de2785dc0",
                                    "bannerCard": "com.linkedin.6a3fa261802e4186dff97b17e0a2a17d",
                                    "upsellSlot": "string",
                                    "searchSuggestionCard": "com.linkedin.0cf29c4912dd382688cfe0e6d63f710a",
                                    "coachRealtimeResponse": "com.linkedin.49cdf97a1e242987c91d2131983a05b0",
                                    "feedbackCard": "com.linkedin.2d3e7b4bccc9c85f103b0dc9fdfd3669",
                                    "knowledgeCardV2": "com.linkedin.e49fee013ecbe8034dac8d0f31d5b5a7",
                                    "coachPromptCluster": "com.linkedin.142aa0a1e9459eddfd8a401a5f79a836",
                                    "keywordsSuggestionCard": "com.linkedin.cfe97a2796732c7129fc01f295e6b6bb",
                                    "queryClarificationCard": "com.linkedin.d81debcec40db70c10df9aafd5fc6fdb",
                                    "topicalQuestionCard": "com.linkedin.8e45407c0ff4b66154fdb557947fc44c",
                                    "illustrationCard": "com.linkedin.b5f458ef8275d3ac65c2a01df1d9328d",
                                    "simpleTextV2": "com.linkedin.5bbb553a55f0e4d13343716ac69b5f48",
                                    "promoCard": "com.linkedin.eac81a502f37713c69cdf36d1c92ee0b",
                                    "searchFeedUpdate": "com.linkedin.0c8279c2434e0b6cfc1d66af503e1cff",
                                    "searchQuestionAndAnswerCard": "com.linkedin.ee5bba1694c397d20c1a9f36d23cc16d",
                                    "centeredText": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846",
                                    "simpleImage": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                                }
                            }
                        },
                        "item": {
                            "resolvedFrom": "itemUnion",
                            "derivedFrom": "itemUnion",
                            "type": {
                                "union": {
                                    "entityResult": "com.linkedin.cf4b25c18907ea8eafe915c8bfa24109",
                                    "cluster": "com.linkedin.5c853aba2154c55483e72bf6cdfaaf3e",
                                    "searchAlert": "com.linkedin.5900d2a09d6af2333ee95a4de2785dc0",
                                    "bannerCard": "com.linkedin.6a3fa261802e4186dff97b17e0a2a17d",
                                    "upsellSlot": "com.linkedin.0b2f76bd70fd4528e6bb2b0121d2241f",
                                    "searchSuggestionCard": "com.linkedin.0cf29c4912dd382688cfe0e6d63f710a",
                                    "coachRealtimeResponse": "com.linkedin.49cdf97a1e242987c91d2131983a05b0",
                                    "feedbackCard": "com.linkedin.2d3e7b4bccc9c85f103b0dc9fdfd3669",
                                    "knowledgeCardV2": "com.linkedin.e49fee013ecbe8034dac8d0f31d5b5a7",
                                    "coachPromptCluster": "com.linkedin.142aa0a1e9459eddfd8a401a5f79a836",
                                    "keywordsSuggestionCard": "com.linkedin.cfe97a2796732c7129fc01f295e6b6bb",
                                    "queryClarificationCard": "com.linkedin.d81debcec40db70c10df9aafd5fc6fdb",
                                    "topicalQuestionCard": "com.linkedin.8e45407c0ff4b66154fdb557947fc44c",
                                    "illustrationCard": "com.linkedin.b5f458ef8275d3ac65c2a01df1d9328d",
                                    "simpleTextV2": "com.linkedin.5bbb553a55f0e4d13343716ac69b5f48",
                                    "promoCard": "com.linkedin.eac81a502f37713c69cdf36d1c92ee0b",
                                    "searchFeedUpdate": "com.linkedin.0c8279c2434e0b6cfc1d66af503e1cff",
                                    "searchQuestionAndAnswerCard": "com.linkedin.ee5bba1694c397d20c1a9f36d23cc16d",
                                    "centeredText": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846",
                                    "simpleImage": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                                }
                            }
                        },
                        "position": {
                            "type": "int"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.SearchItem"
                },
                "com.linkedin.20a39c821c63e5f1da8b29c1b05ff0ad": {
                    "fields": {
                        "actionText": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "text": {
                            "type": "string"
                        },
                        "accessibilityText": {
                            "type": "string"
                        },
                        "url": {
                            "type": "com.linkedin.common.Url"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.interstitial.InterstitialNavigationClickThroughAction"
                },
                "com.linkedin.6a3fa261802e4186dff97b17e0a2a17d": {
                    "fields": {
                        "searchActionType": {
                            "type": "string"
                        },
                        "image": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "subtitle": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "cardType": {
                            "type": "com.linkedin.voyager.dash.search.BannerCardType"
                        },
                        "controlName": {
                            "type": "com.linkedin.voyager.dash.common.tracking.ControlName"
                        },
                        "title": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "chevron": {
                            "type": "boolean"
                        },
                        "url": {
                            "type": "com.linkedin.common.Url"
                        },
                        "trackingId": {
                            "type": "com.linkedin.common.TrackingId"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.BannerCard"
                },
                "com.linkedin.a8c1e0de3678025a4e773d45a672bedf": {
                    "fields": {
                        "paginationToken": {
                            "type": "string"
                        },
                        "socialActivityCounts": {
                            "resolvedFrom": "socialActivityCountsUrn",
                            "type": "com.linkedin.60216d4fa134df147fcc8c39e71c7139"
                        },
                        "replyPreviousCursor": {
                            "type": "string"
                        },
                        "sortOrder": {
                            "type": "com.linkedin.voyager.dash.social.CommentSortOrder"
                        },
                        "updatedCommentCount": {
                            "type": "long"
                        },
                        "replyNextCursor": {
                            "type": "string"
                        },
                        "socialActivityCountsUrn": {
                            "type": "string"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.social.CommentsMetadata"
                },
                "com.linkedin.2d331c9a5947ca4956358ddacabe40ee": {
                    "fields": {
                        "title": {
                            "type": "string"
                        },
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.LearningCourseUrn"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.learning.LearningCourse"
                },
                "com.linkedin.e7255825e31731ce221bd0a581bbdd47": {
                    "fields": {
                        "searchActionType": {
                            "type": "string"
                        },
                        "navigationContext": {
                            "type": "com.linkedin.55ee9afd4182671fe7e271f615659525"
                        },
                        "title": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "titleFontSize": {
                            "type": "com.linkedin.voyager.dash.search.FontSize"
                        },
                        "titleMaxNumLines": {
                            "type": "int"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.premium.PremiumCustomCtaInsight"
                },
                "com.linkedin.75855d69ba1db62fafb8b6904560ca74": {
                    "fields": {
                        "discloseAsProfileViewer": {
                            "type": "com.linkedin.voyager.dash.identity.profile.DiscloseAsProfileViewerInfo"
                        },
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.PrivacySettingsUrn"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.identity.profile.PrivacySettings"
                },
                "com.linkedin.25e46f67641278b642032923b20f3538": {
                    "fields": {
                        "ctaButton": {
                            "type": "com.linkedin.280548a5c822f61a54f7d2022f1e02a5"
                        },
                        "contentUnion": {
                            "type": {
                                "union": {
                                    "externalVideoComponent": "com.linkedin.56ed1d753079896e9ad350e6f461c483",
                                    "linkedInVideoComponent": "com.linkedin.833e5a7fd479a007d026abce564deea5",
                                    "scheduledLiveContentComponent": "com.linkedin.0af9905c7ec2db45db6070cde87109b5",
                                    "documentComponent": "com.linkedin.3623b786d2323fb52c13099cf2752b53",
                                    "imageComponent": "com.linkedin.d388328a98f556cd5d952549ba61eff0",
                                    "articleComponent": "com.linkedin.86b903c46b5240b03037ec8656976681"
                                }
                            }
                        },
                        "carouselContent": {
                            "type": "com.linkedin.85452cafea09accebe0a8082a8d9898f"
                        },
                        "leadGenForm": {
                            "type": "com.linkedin.b7c96922cb665f0dfc163d5e56e6c473"
                        },
                        "content": {
                            "derivedFrom": "contentUnion",
                            "type": {
                                "union": {
                                    "externalVideoComponent": "com.linkedin.56ed1d753079896e9ad350e6f461c483",
                                    "linkedInVideoComponent": "com.linkedin.833e5a7fd479a007d026abce564deea5",
                                    "scheduledLiveContentComponent": "com.linkedin.0af9905c7ec2db45db6070cde87109b5",
                                    "documentComponent": "com.linkedin.3623b786d2323fb52c13099cf2752b53",
                                    "imageComponent": "com.linkedin.d388328a98f556cd5d952549ba61eff0",
                                    "articleComponent": "com.linkedin.86b903c46b5240b03037ec8656976681"
                                }
                            }
                        },
                        "commentary": {
                            "type": "com.linkedin.5ce31f49adf6bd8cb496962bdde69707"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.sponsored.LeadGenFormContent"
                },
                "com.linkedin.e0372afc4a18480b00ca7e4906904fd7": {
                    "fields": {
                        "memorialized": {
                            "type": "boolean"
                        },
                        "lastName": {
                            "type": "string"
                        },
                        "creator": {
                            "type": "boolean"
                        },
                        "searchProfileActions": {
                            "type": "com.linkedin.7c5d61c24e802281df7618578f2459db",
                            "isInjection": true
                        },
                        "tempStatusEmoji": {
                            "type": "string"
                        },
                        "iweWarned": {
                            "type": "boolean"
                        },
                        "pronounUnion": {
                            "type": {
                                "union": {
                                    "customPronoun": "string",
                                    "standardizedPronoun": "com.linkedin.voyager.dash.identity.profile.StandardizedPronoun"
                                }
                            }
                        },
                        "tempStatusExpiredAtUnion": {
                            "type": {
                                "union": {
                                    "customizedExpiredAt": "com.linkedin.common.Time",
                                    "standardizedExpiration": "com.linkedin.voyager.dash.identity.profile.StandardizedExpiration"
                                }
                            }
                        },
                        "profilePicture": {
                            "type": "com.linkedin.ab57de991a452be4a5e752f1671b1e62"
                        },
                        "firstName": {
                            "type": "string"
                        },
                        "tempStatus": {
                            "type": "string"
                        },
                        "pronoun": {
                            "derivedFrom": "pronounUnion",
                            "type": {
                                "union": {
                                    "customPronoun": "string",
                                    "standardizedPronoun": "com.linkedin.voyager.dash.identity.profile.StandardizedPronoun"
                                }
                            }
                        },
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.ProfileUrn"
                        },
                        "memberRelationship": {
                            "type": "com.linkedin.c03d6d673ac4f7503bd4aeb7d200cfd7",
                            "isInjection": true
                        },
                        "ringStatus": {
                            "type": "com.linkedin.9d67b80fb82e3d96227749fd6d468116",
                            "isInjection": true
                        },
                        "headline": {
                            "type": "string"
                        },
                        "emailRequired": {
                            "type": "boolean"
                        },
                        "publicIdentifier": {
                            "type": "string"
                        },
                        "tempStatusExpiredAt": {
                            "derivedFrom": "tempStatusExpiredAtUnion",
                            "type": {
                                "union": {
                                    "customizedExpiredAt": "com.linkedin.common.Time",
                                    "standardizedExpiration": "com.linkedin.voyager.dash.identity.profile.StandardizedExpiration"
                                }
                            }
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.identity.profile.Profile"
                },
                "com.linkedin.dfce49e2c6bb412fb4161cbbc7190d0d": {
                    "fields": {
                        "entityResultAttributes": {
                            "type": "com.linkedin.c50d1c05ff73d93791979ed1aa968a68"
                        },
                        "bserpPaginationContext": {
                            "type": "com.linkedin.deb8eb9003441a9260de30afd884b7bb"
                        },
                        "searchAlert": {
                            "type": "com.linkedin.5900d2a09d6af2333ee95a4de2785dc0"
                        },
                        "totalResultCount": {
                            "type": "long"
                        },
                        "secondaryFilterCluster": {
                            "type": "com.linkedin.77f24fd65949d0f1cc3ca16da60fde58"
                        },
                        "blockedQueryError": {
                            "type": "com.linkedin.e6bc62c2917d46b312c7306363820a83"
                        },
                        "lazyRightRail": {
                            "resolvedFrom": "lazyRightRailUrn",
                            "type": "com.linkedin.c57f38371161fd69925d6e010ce4c0b9"
                        },
                        "queryType": {
                            "type": "com.linkedin.voyager.dash.search.SearchQueryType"
                        },
                        "primaryResultType": {
                            "type": "string"
                        },
                        "paginationToken": {
                            "type": "string"
                        },
                        "primaryFilterCluster": {
                            "type": "com.linkedin.77f24fd65949d0f1cc3ca16da60fde58"
                        },
                        "entityActionButtonStyle": {
                            "type": "com.linkedin.voyager.dash.search.EntityActionButtonStyle"
                        },
                        "blockedQuery": {
                            "type": "boolean"
                        },
                        "filterAppliedCount": {
                            "type": "int"
                        },
                        "searchId": {
                            "type": "string"
                        },
                        "lazyRightRailUrn": {
                            "type": "string"
                        },
                        "simpleInsightAttributes": {
                            "type": "com.linkedin.16d7d07baef648aa182105f6f1c2da66"
                        },
                        "clusterTitleFontSize": {
                            "type": "com.linkedin.voyager.dash.search.FontSize"
                        },
                        "desktopNavigationPanelTrackingId": {
                            "type": "com.linkedin.voyager.dash.common.Base64String"
                        },
                        "knowledgeCardRightRail": {
                            "type": "com.linkedin.c57f38371161fd69925d6e010ce4c0b9"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.SearchClusterCollectionMetadata"
                },
                "com.linkedin.5afa622044b87152ca004741a0def2a9": {
                    "fields": {
                        "adRequestId": {
                            "type": "string"
                        },
                        "externalImpressionTrackingUrl": {
                            "type": "string"
                        },
                        "videoBehavior": {
                            "type": "com.linkedin.voyager.dash.sponsoredcontent.metadata.SponsoredVideoBehavior"
                        },
                        "leadTrackingCode": {
                            "type": "string"
                        },
                        "adUrn": {
                            "type": "com.linkedin.common.SponsoredCreativeUrn"
                        },
                        "version": {
                            "type": "string"
                        },
                        "adServingUrn": {
                            "type": "string"
                        },
                        "shouldTrackMultiThresholds": {
                            "type": "boolean"
                        },
                        "tscpUrl": {
                            "type": "string"
                        },
                        "sponsoredCampaignUrn": {
                            "type": "com.linkedin.common.SponsoredCampaignUrn"
                        },
                        "adTrackingCode": {
                            "type": "string"
                        },
                        "adServing": {
                            "resolvedFrom": "adServingUrn",
                            "type": "com.linkedin.67d1c9126e7e5213988926a2c6323fed"
                        },
                        "leadTrackingParams": {
                            "type": "string"
                        },
                        "shouldPopulateVideoMrcMetadata": {
                            "type": "boolean"
                        },
                        "activityType": {
                            "type": "com.linkedin.voyager.dash.sponsoredcontent.metadata.SponsoredActivityType"
                        },
                        "internalExperimentAssignmentKeyValuePairs": {
                            "type": "string"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.sponsoredcontent.metadata.SponsoredMetadata"
                },
                "com.linkedin.eac81a502f37713c69cdf36d1c92ee0b": {
                    "fields": {
                        "image": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "secondaryCta": {
                            "type": "com.linkedin.2b480b3cde698a1a539b07ea20530065"
                        },
                        "secondarySubtitle": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.PromoCardUrn"
                        },
                        "backgroundImage": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "subtitle": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "dismiss": {
                            "type": "com.linkedin.2b480b3cde698a1a539b07ea20530065"
                        },
                        "legoTrackingToken": {
                            "type": "string"
                        },
                        "primaryCta": {
                            "type": "com.linkedin.2b480b3cde698a1a539b07ea20530065"
                        },
                        "title": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "trackingId": {
                            "type": "com.linkedin.common.TrackingId"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.PromoCard"
                },
                "com.linkedin.e461eb42e2668e3b6817d743d334f60d": {
                    "fields": {
                        "image": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "subtitle": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "context": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "navigationContext": {
                            "type": "com.linkedin.7d07a0360cd523ec5f0f30948903dfe4"
                        },
                        "description": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "video": {
                            "type": "boolean"
                        },
                        "title": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.miniupdate.MiniUpdateContentComponent"
                },
                "com.linkedin.bed8a76f30dfd26b202f7fce1ff36982": {
                    "fields": {
                        "navigateDirectlyToLandingUrl": {
                            "type": "boolean"
                        },
                        "bookCompletionConfirmationDescription": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "bookAppointmentURL": {
                            "type": "com.linkedin.f72668082d3f0ea7feb3a402e4555a6f"
                        },
                        "ctaText": {
                            "type": "string"
                        },
                        "landingPage": {
                            "type": "com.linkedin.f72668082d3f0ea7feb3a402e4555a6f"
                        },
                        "document": {
                            "type": "com.linkedin.56970f4601ade63e2f097f9ecfc9be75"
                        },
                        "confirmationTitle": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "isBookAppointmentEnabled": {
                            "type": "boolean"
                        },
                        "urlViewingBehavior": {
                            "type": "com.linkedin.voyager.dash.common.ux.UrlViewingBehavior"
                        },
                        "sponsoredUrlAttributes": {
                            "type": "com.linkedin.d853c03d4547334c4f244bc136796f0b"
                        },
                        "isBookingCompleted": {
                            "type": "boolean"
                        },
                        "confirmationDescription": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.sponsoredcontent.leadgen.LeadGenGatedContent"
                },
                "com.linkedin.92ece182782ae4412e712925cd97f9fe": {
                    "fields": {
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.LazyLoadedActionsUrn"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.LazyLoadedActions"
                },
                "com.linkedin.86b903c46b5240b03037ec8656976681": {
                    "fields": {
                        "headlineBackgroundColor": {
                            "type": "com.linkedin.voyager.dash.feed.palette.ux.HeadlineBackgroundColor"
                        },
                        "newsletterNavigationContext": {
                            "type": "com.linkedin.8a612b4e445851d55ecf8b09571a05ee"
                        },
                        "largeImage": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "smallImage": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "subdescription": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "description": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "inlineCta": {
                            "type": "com.linkedin.280548a5c822f61a54f7d2022f1e02a5"
                        },
                        "bylineImage": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "video": {
                            "type": "com.linkedin.762fc611b9734ba7fde2123ce919a75e"
                        },
                        "title": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "type": {
                            "type": "com.linkedin.voyager.dash.feed.component.article.ArticleType"
                        },
                        "newsletterLogo": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "animatedOverlay": {
                            "type": "com.linkedin.voyager.dash.feed.component.article.AnimationType"
                        },
                        "articleUrn": {
                            "type": "com.linkedin.common.Urn"
                        },
                        "swapTitleAndSubtitle": {
                            "type": "boolean"
                        },
                        "newsletterTitle": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "showChevron": {
                            "type": "boolean"
                        },
                        "subtitle": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "subscribeAction": {
                            "type": "com.linkedin.6f5340bf6dde14897b3d4dde77e536d0"
                        },
                        "navigationContext": {
                            "type": "com.linkedin.8a612b4e445851d55ecf8b09571a05ee"
                        },
                        "showSmallTitle": {
                            "type": "boolean"
                        },
                        "byline": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.article.ArticleComponent"
                },
                "com.linkedin.b023a540cfe197e815b01a45eebe74b3": {
                    "fields": {
                        "navigationContext": {
                            "type": "com.linkedin.8a612b4e445851d55ecf8b09571a05ee"
                        },
                        "legoTrackingToken": {
                            "type": "string"
                        },
                        "saveState": {
                            "type": "com.linkedin.f1b2492c05b41398477b887761d337a9"
                        },
                        "title": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "subtitle": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.learning.LearningRecommendationComponent"
                },
                "com.linkedin.c5e4a4faa8b2edc4e2cf14cd7351f556": {
                    "fields": {
                        "credentialIssuedAt": {
                            "type": "long"
                        },
                        "credentialIssuer": {
                            "type": "string"
                        },
                        "issuedAt": {
                            "type": "long"
                        },
                        "issuer": {
                            "type": "string"
                        },
                        "expiresAt": {
                            "type": "long"
                        },
                        "signer": {
                            "type": "string"
                        }
                    },
                    "baseType": "pegasus.com.linkedin.mediaInfra.C2paSignature"
                },
                "com.linkedin.5bbb553a55f0e4d13343716ac69b5f48": {
                    "fields": {
                        "numDashes": {
                            "type": "int"
                        },
                        "text": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "showDashes": {
                            "type": "boolean"
                        },
                        "renderStyle": {
                            "type": "com.linkedin.voyager.dash.search.SimpleTextStyle"
                        },
                        "textAlignment": {
                            "type": "com.linkedin.voyager.dash.search.TextAlignment"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.SimpleText"
                },
                "com.linkedin.7d07a0360cd523ec5f0f30948903dfe4": {
                    "fields": {
                        "trackingActionType": {
                            "type": "string"
                        },
                        "accessibilityText": {
                            "type": "string"
                        },
                        "target": {
                            "type": "com.linkedin.common.Url"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.miniupdate.MiniUpdateFeedNavigationContext"
                },
                "com.linkedin.5ce31f49adf6bd8cb496962bdde69707": {
                    "fields": {
                        "translation": {
                            "resolvedFrom": "translationUrn",
                            "type": "com.linkedin.581848b3153acfd08f0aa73ed2c8fb51"
                        },
                        "navigationContext": {
                            "type": "com.linkedin.8a612b4e445851d55ecf8b09571a05ee"
                        },
                        "translationUrn": {
                            "type": "string"
                        },
                        "metadataText": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "text": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "numLines": {
                            "type": "int"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.commentary.CommentaryComponent"
                },
                "com.linkedin.280548a5c822f61a54f7d2022f1e02a5": {
                    "fields": {
                        "accessoryTrackingId": {
                            "type": "com.linkedin.common.TrackingId"
                        },
                        "navigationContext": {
                            "type": "com.linkedin.8a612b4e445851d55ecf8b09571a05ee"
                        },
                        "startIconName": {
                            "type": "com.linkedin.voyager.dash.common.SystemImageName"
                        },
                        "text": {
                            "type": "string"
                        },
                        "iconName": {
                            "type": "com.linkedin.voyager.dash.common.ArtDecoIconName"
                        },
                        "endIconName": {
                            "type": "com.linkedin.voyager.dash.common.SystemImageName"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.button.ButtonComponent"
                },
                "com.linkedin.cf4b25c18907ea8eafe915c8bfa24109": {
                    "fields": {
                        "template": {
                            "type": "com.linkedin.voyager.dash.search.EntityResultTemplate"
                        },
                        "actorNavigationContext": {
                            "type": "com.linkedin.55ee9afd4182671fe7e271f615659525"
                        },
                        "bserpEntityNavigationalUrl": {
                            "type": "com.linkedin.common.Url"
                        },
                        "trackingUrn": {
                            "type": "com.linkedin.common.Urn"
                        },
                        "controlName": {
                            "type": "com.linkedin.voyager.dash.common.tracking.ControlName"
                        },
                        "interstitialComponent": {
                            "type": "com.linkedin.0b0b1ff1bc3680ba45bd418512ffc8ca"
                        },
                        "primaryActions": {
                            "type": {
                                "array": "com.linkedin.30dee75e249786a8e1ceb4c1d056ab57"
                            }
                        },
                        "entityCustomTrackingInfo": {
                            "type": "com.linkedin.4caf791202c7b71e3874d4551f078f32"
                        },
                        "badgeData": {
                            "type": "com.linkedin.ceb5a874eede0a2b820bbc8d28d19fb9"
                        },
                        "title": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "overflowActions": {
                            "type": {
                                "array": "com.linkedin.30dee75e249786a8e1ceb4c1d056ab57"
                            }
                        },
                        "targetUnion": {
                            "type": {
                                "union": {
                                    "updateV2Urn": "com.linkedin.voyager.dash.common.PreDashUrn",
                                    "profile": "string"
                                }
                            }
                        },
                        "searchActionType": {
                            "type": "string"
                        },
                        "insightsResolutionResults": {
                            "resolvedFrom": "insights",
                            "type": {
                                "array": {
                                    "union": {
                                        "jobPostingInsight": "com.linkedin.352de81121adae09c8392d6f11d028a0",
                                        "relationshipsInsight": "com.linkedin.8bb7af21154573d49987b03117f5d1cf",
                                        "serviceProviderRatingInsight": "com.linkedin.f023e0f4e1b3b52579ab54428a778977",
                                        "simpleInsight": "com.linkedin.bd9a707a5b119c1f331373113f57344a",
                                        "jobPostingFooterInsight": "com.linkedin.791d0c903911aab58f40e6744715af71",
                                        "socialActivityCountsInsight": "com.linkedin.60216d4fa134df147fcc8c39e71c7139",
                                        "labelsInsight": "com.linkedin.422f035ceb29d58b6e1cb2b89ed1b336",
                                        "premiumCustomCtaInsight": "com.linkedin.e7255825e31731ce221bd0a581bbdd47"
                                    }
                                }
                            }
                        },
                        "actorInsights": {
                            "resolvedFrom": "actorInsightsUnions",
                            "type": {
                                "array": {
                                    "union": {
                                        "jobPostingInsight": "com.linkedin.352de81121adae09c8392d6f11d028a0",
                                        "relationshipsInsight": "com.linkedin.8bb7af21154573d49987b03117f5d1cf",
                                        "serviceProviderRatingInsight": "com.linkedin.f023e0f4e1b3b52579ab54428a778977",
                                        "simpleInsight": "com.linkedin.bd9a707a5b119c1f331373113f57344a",
                                        "jobPostingFooterInsight": "com.linkedin.791d0c903911aab58f40e6744715af71",
                                        "socialActivityCountsInsight": "com.linkedin.60216d4fa134df147fcc8c39e71c7139",
                                        "labelsInsight": "com.linkedin.422f035ceb29d58b6e1cb2b89ed1b336",
                                        "premiumCustomCtaInsight": "com.linkedin.e7255825e31731ce221bd0a581bbdd47"
                                    }
                                }
                            }
                        },
                        "badgeIcon": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.EntityResultViewModelUrn"
                        },
                        "showAdditionalCluster": {
                            "type": "boolean"
                        },
                        "lazyLoadedActionsUrn": {
                            "type": "string"
                        },
                        "ringStatus": {
                            "type": "com.linkedin.9d67b80fb82e3d96227749fd6d468116"
                        },
                        "primarySubtitle": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "badgeText": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "trackingId": {
                            "type": "com.linkedin.voyager.dash.common.Base64String"
                        },
                        "addEntityToSearchHistory": {
                            "type": "boolean"
                        },
                        "summary": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "actorNavigationUrl": {
                            "type": "com.linkedin.common.Url"
                        },
                        "image": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "lazyLoadedActions": {
                            "resolvedFrom": "lazyLoadedActionsUrn",
                            "type": "com.linkedin.92ece182782ae4412e712925cd97f9fe"
                        },
                        "secondarySubtitle": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "insights": {
                            "type": {
                                "array": {
                                    "union": {
                                        "jobPostingInsight": "string",
                                        "relationshipsInsight": "string",
                                        "serviceProviderRatingInsight": "com.linkedin.f023e0f4e1b3b52579ab54428a778977",
                                        "simpleInsight": "com.linkedin.bd9a707a5b119c1f331373113f57344a",
                                        "jobPostingFooterInsight": "string",
                                        "socialActivityCountsInsight": "string",
                                        "labelsInsight": "com.linkedin.422f035ceb29d58b6e1cb2b89ed1b336",
                                        "premiumCustomCtaInsight": "com.linkedin.e7255825e31731ce221bd0a581bbdd47"
                                    }
                                }
                            }
                        },
                        "entityEmbeddedObject": {
                            "type": "com.linkedin.bd93318ac5710b71fba68ebb50fd5bfd"
                        },
                        "unreadIndicatorDetails": {
                            "resolvedFrom": "unreadIndicatorDetailsUnion",
                            "type": {
                                "union": {
                                    "marketplaceProjectUnreadIndicator": "com.linkedin.9a5cfd1782f34ef4cc794e99854515b7",
                                    "jobPostingUnreadIndicator": "com.linkedin.c0eb7f9edecfa9e869f6b58f4a26bc93"
                                }
                            }
                        },
                        "navigationUrl": {
                            "type": "com.linkedin.common.Url"
                        },
                        "unreadIndicatorDetailsUnion": {
                            "type": {
                                "union": {
                                    "marketplaceProjectUnreadIndicator": "string",
                                    "jobPostingUnreadIndicator": "string"
                                }
                            }
                        },
                        "target": {
                            "resolvedFrom": "targetUnion",
                            "type": {
                                "union": {
                                    "updateV2Urn": "com.linkedin.voyager.dash.common.PreDashUrn",
                                    "profile": "com.linkedin.e0372afc4a18480b00ca7e4906904fd7"
                                }
                            }
                        },
                        "actorInsightsUnions": {
                            "type": {
                                "array": {
                                    "union": {
                                        "jobPostingInsight": "string",
                                        "relationshipsInsight": "string",
                                        "serviceProviderRatingInsight": "com.linkedin.f023e0f4e1b3b52579ab54428a778977",
                                        "simpleInsight": "com.linkedin.bd9a707a5b119c1f331373113f57344a",
                                        "jobPostingFooterInsight": "string",
                                        "socialActivityCountsInsight": "string",
                                        "labelsInsight": "com.linkedin.422f035ceb29d58b6e1cb2b89ed1b336",
                                        "premiumCustomCtaInsight": "com.linkedin.e7255825e31731ce221bd0a581bbdd47"
                                    }
                                }
                            }
                        },
                        "actorTrackingUrn": {
                            "type": "com.linkedin.common.Urn"
                        },
                        "navigationContext": {
                            "type": "com.linkedin.55ee9afd4182671fe7e271f615659525"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.EntityResultViewModel"
                },
                "com.linkedin.c97d64dfd15204616a896fea6339d850": {
                    "fields": {
                        "publicProfileIdentifier": {
                            "type": "string"
                        },
                        "type": {
                            "type": "com.linkedin.voyager.dash.feed.actions.connect.ConnectActionStateType"
                        },
                        "preDashEntityUrn": {
                            "type": "com.linkedin.voyager.dash.common.PreDashUrn"
                        },
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.ConnectActionUrn"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.actions.connect.ConnectAction"
                },
                "com.linkedin.55ee9afd4182671fe7e271f615659525": {
                    "fields": {
                        "url": {
                            "type": "com.linkedin.common.Url"
                        },
                        "openExternally": {
                            "type": "boolean"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.NavigationContext"
                },
                "com.linkedin.85452cafea09accebe0a8082a8d9898f": {
                    "fields": {
                        "showPaginationIndicator": {
                            "type": "boolean"
                        },
                        "type": {
                            "type": "com.linkedin.voyager.dash.feed.carousel.CarouselContentType"
                        },
                        "navigationPosition": {
                            "type": "com.linkedin.voyager.dash.feed.carousel.CarouselNavigationPosition"
                        },
                        "items": {
                            "type": {
                                "array": "com.linkedin.4cd241e0a8ad80a259b7f055e0fe1ec0"
                            }
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.carousel.CarouselContent"
                },
                "com.linkedin.830169c9243be1975114d187616fcf29": {
                    "fields": {
                        "templateType": {
                            "type": "com.linkedin.voyager.dash.feed.component.interstitial.InterstitialTemplateType"
                        },
                        "coverageType": {
                            "type": "com.linkedin.voyager.dash.feed.component.interstitial.InterstitialCoverageType"
                        },
                        "navigationCtaActionType": {
                            "type": "string"
                        },
                        "interstitial": {
                            "type": "com.linkedin.191c4aa50072107393c644d1284e6a09"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.interstitial.InterstitialComponent"
                },
                "com.linkedin.21842cae337b7d35a349900ddee48af6": {
                    "fields": {
                        "contentUnion": {
                            "type": {
                                "union": {
                                    "toggleButtonComponent": "com.linkedin.0f36f2dc6be4ed6af3361a6356cb19e0",
                                    "feedDividerComponent": "com.linkedin.fd4f461137d628e214f2c67640064f40",
                                    "articleComponent": "com.linkedin.86b903c46b5240b03037ec8656976681",
                                    "eventComponent": "com.linkedin.827d2df06cbbd8888b228aac56a99cb5",
                                    "conversationStartersComponent": "com.linkedin.ed74e3ca52f62abc923f3cfacd4628e0",
                                    "promoComponent": "com.linkedin.8ff002aafcb203f2b95c57c175c2f91c",
                                    "seeMoreComponent": "com.linkedin.dbe3dc7ec313938618c482695c80e952",
                                    "reviewComponent": "com.linkedin.74024cf712e3b910b92188d657a36b48",
                                    "feedDiscoveryGridComponent": "com.linkedin.dacb8097355f9a4b84257dcd4a72e01d",
                                    "followPromptComponent": "com.linkedin.7f0cc4bcf6aef643d5c454ff48c96941",
                                    "jobComponent": "com.linkedin.292ed207e90e51c83f267296fa0c7940",
                                    "learningRecommendationComponent": "com.linkedin.b023a540cfe197e815b01a45eebe74b3",
                                    "surveyComponent": "com.linkedin.3a88e7bf8b5e1c81be38f30d05a7155c",
                                    "buttonComponent": "com.linkedin.280548a5c822f61a54f7d2022f1e02a5",
                                    "celebrationComponent": "com.linkedin.a61eaf39f1cf127adaf1233791804a39",
                                    "actorComponent": "com.linkedin.71b94ae4069ecc57933235cd51a72aee",
                                    "documentComponent": "com.linkedin.3623b786d2323fb52c13099cf2752b53",
                                    "creationStatusComponent": "com.linkedin.1734179c2744199ea6708a6613bdcede",
                                    "dynamicPollComponent": "com.linkedin.38c32cf9808204fff187465f6ac6683c",
                                    "postCtaComponent": "com.linkedin.3f4ae0934d738b90cbec63f10776b7ae",
                                    "scheduledLiveContentComponent": "com.linkedin.0af9905c7ec2db45db6070cde87109b5",
                                    "entityComponent": "com.linkedin.4f55a752e41ac24988f152a28efd3398",
                                    "externalVideoComponent": "com.linkedin.56ed1d753079896e9ad350e6f461c483",
                                    "linkedInVideoComponent": "com.linkedin.833e5a7fd479a007d026abce564deea5",
                                    "textOverlayImageComponent": "com.linkedin.c3576e4eb1959675613cf442c15650b9",
                                    "annotationComponent": "com.linkedin.d067ea339aae1c25da65a9f86eb786ad",
                                    "detailedSurveyComponent": "com.linkedin.ce17b3b18736cc798de33ecc17836156",
                                    "imageComponent": "com.linkedin.d388328a98f556cd5d952549ba61eff0",
                                    "pollComponent": "com.linkedin.e3bf41d90ee4ffc0edf0c6e16c6a18c1",
                                    "feedDiscoveryEntityComponent": "com.linkedin.5b82b762410287f21f34b3d755f164dc",
                                    "promptComponent": "com.linkedin.37da0dcf9c4df3c725740cceef3f71e1",
                                    "contextualActionComponent": "com.linkedin.2aa0f2389f8b1f7666d3ba41965d9958",
                                    "commentaryComponent": "com.linkedin.5ce31f49adf6bd8cb496962bdde69707",
                                    "announcementComponent": "com.linkedin.f6c622cdcd9214c3ee563a8875d24fb3",
                                    "slideshowComponent": "com.linkedin.f70de4d604689acbffc0dcd8115c319d",
                                    "callToActionComponent": "com.linkedin.17602d9bd6fd3c2435cab1748e7900cf"
                                }
                            }
                        },
                        "headerText": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.UpdateAttachmentUrn"
                        },
                        "update": {
                            "type": "com.linkedin.757852411fb0feeedcbd4df1cbcfcd54"
                        },
                        "carouselContent": {
                            "type": "com.linkedin.85452cafea09accebe0a8082a8d9898f"
                        },
                        "preDashEntityUrn": {
                            "type": "com.linkedin.voyager.dash.common.PreDashUrn"
                        },
                        "content": {
                            "derivedFrom": "contentUnion",
                            "type": {
                                "union": {
                                    "toggleButtonComponent": "com.linkedin.0f36f2dc6be4ed6af3361a6356cb19e0",
                                    "feedDividerComponent": "com.linkedin.fd4f461137d628e214f2c67640064f40",
                                    "articleComponent": "com.linkedin.86b903c46b5240b03037ec8656976681",
                                    "eventComponent": "com.linkedin.827d2df06cbbd8888b228aac56a99cb5",
                                    "conversationStartersComponent": "com.linkedin.ed74e3ca52f62abc923f3cfacd4628e0",
                                    "promoComponent": "com.linkedin.8ff002aafcb203f2b95c57c175c2f91c",
                                    "seeMoreComponent": "com.linkedin.dbe3dc7ec313938618c482695c80e952",
                                    "reviewComponent": "com.linkedin.74024cf712e3b910b92188d657a36b48",
                                    "feedDiscoveryGridComponent": "com.linkedin.dacb8097355f9a4b84257dcd4a72e01d",
                                    "followPromptComponent": "com.linkedin.7f0cc4bcf6aef643d5c454ff48c96941",
                                    "jobComponent": "com.linkedin.292ed207e90e51c83f267296fa0c7940",
                                    "learningRecommendationComponent": "com.linkedin.b023a540cfe197e815b01a45eebe74b3",
                                    "surveyComponent": "com.linkedin.3a88e7bf8b5e1c81be38f30d05a7155c",
                                    "buttonComponent": "com.linkedin.280548a5c822f61a54f7d2022f1e02a5",
                                    "celebrationComponent": "com.linkedin.a61eaf39f1cf127adaf1233791804a39",
                                    "actorComponent": "com.linkedin.71b94ae4069ecc57933235cd51a72aee",
                                    "documentComponent": "com.linkedin.3623b786d2323fb52c13099cf2752b53",
                                    "creationStatusComponent": "com.linkedin.1734179c2744199ea6708a6613bdcede",
                                    "dynamicPollComponent": "com.linkedin.38c32cf9808204fff187465f6ac6683c",
                                    "postCtaComponent": "com.linkedin.3f4ae0934d738b90cbec63f10776b7ae",
                                    "scheduledLiveContentComponent": "com.linkedin.0af9905c7ec2db45db6070cde87109b5",
                                    "entityComponent": "com.linkedin.4f55a752e41ac24988f152a28efd3398",
                                    "externalVideoComponent": "com.linkedin.56ed1d753079896e9ad350e6f461c483",
                                    "linkedInVideoComponent": "com.linkedin.833e5a7fd479a007d026abce564deea5",
                                    "textOverlayImageComponent": "com.linkedin.c3576e4eb1959675613cf442c15650b9",
                                    "annotationComponent": "com.linkedin.d067ea339aae1c25da65a9f86eb786ad",
                                    "detailedSurveyComponent": "com.linkedin.ce17b3b18736cc798de33ecc17836156",
                                    "imageComponent": "com.linkedin.d388328a98f556cd5d952549ba61eff0",
                                    "pollComponent": "com.linkedin.e3bf41d90ee4ffc0edf0c6e16c6a18c1",
                                    "feedDiscoveryEntityComponent": "com.linkedin.5b82b762410287f21f34b3d755f164dc",
                                    "promptComponent": "com.linkedin.37da0dcf9c4df3c725740cceef3f71e1",
                                    "contextualActionComponent": "com.linkedin.2aa0f2389f8b1f7666d3ba41965d9958",
                                    "commentaryComponent": "com.linkedin.5ce31f49adf6bd8cb496962bdde69707",
                                    "announcementComponent": "com.linkedin.f6c622cdcd9214c3ee563a8875d24fb3",
                                    "slideshowComponent": "com.linkedin.f70de4d604689acbffc0dcd8115c319d",
                                    "callToActionComponent": "com.linkedin.17602d9bd6fd3c2435cab1748e7900cf"
                                }
                            }
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.content.UpdateAttachment"
                },
                "com.linkedin.d6ed2ae9c1ec5545f0d810302f1c2b7d": {
                    "fields": {
                        "actionsPosition": {
                            "type": "com.linkedin.voyager.dash.feed.controlmenu.UpdateActionPosition"
                        },
                        "shareMediaUrn": {
                            "type": "com.linkedin.common.Urn"
                        },
                        "updateActions": {
                            "resolvedFrom": "updateActionsUrn",
                            "type": "com.linkedin.c29d5d493cf660fcc187ed3514170ff2"
                        },
                        "coachSummaryText": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "actionTriggerEnabled": {
                            "type": "boolean"
                        },
                        "shareAudience": {
                            "type": "com.linkedin.voyager.dash.feed.metadata.ShareAudience"
                        },
                        "legoTrackingToken": {
                            "type": "string"
                        },
                        "coachSummaryUrn": {
                            "type": "com.linkedin.voyager.dash.common.CoachSummaryUrn"
                        },
                        "backendUrn": {
                            "type": "com.linkedin.common.Urn"
                        },
                        "trackingData": {
                            "type": "com.linkedin.6bf32d88af325c3a70ac92d1594add6d"
                        },
                        "detailPageType": {
                            "type": "com.linkedin.voyager.dash.feed.metadata.DetailPageType"
                        },
                        "hidePostActionUrn": {
                            "type": "string"
                        },
                        "shouldForceRefetchFromNetwork": {
                            "type": "boolean"
                        },
                        "updateActionsUrn": {
                            "type": "string"
                        },
                        "excludedFromSeen": {
                            "type": "boolean"
                        },
                        "coachAction": {
                            "type": "com.linkedin.ff4c51d111da4ffaaae179a2eaf9a303"
                        },
                        "shareUrn": {
                            "type": "com.linkedin.common.Urn"
                        },
                        "rootShare": {
                            "type": "boolean"
                        },
                        "groupUrn": {
                            "type": "string"
                        },
                        "hidePostAction": {
                            "resolvedFrom": "hidePostActionUrn",
                            "type": "com.linkedin.49b164ca1d0b5ff5bc8c1f97c55b7c32"
                        },
                        "group": {
                            "resolvedFrom": "groupUrn",
                            "type": "com.linkedin.c8f5bf5a9d5e0dbbc3c824c2dfd751a8"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.metadata.UpdateMetadata"
                },
                "com.linkedin.0af9905c7ec2db45db6070cde87109b5": {
                    "fields": {
                        "image": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "scheduledTimestamp": {
                            "type": "long"
                        },
                        "viewerState": {
                            "resolvedFrom": "viewerStateUrn",
                            "type": "com.linkedin.795aca8b0690435f405c793a8ffcf615"
                        },
                        "description": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "liveVideoFeedPostTopicUrn": {
                            "type": "com.linkedin.common.LiveVideoFeedPostTopicUrn"
                        },
                        "title": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "titleContext": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "scheduledTimeTag": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "viewerStateUrn": {
                            "type": "string"
                        },
                        "insight": {
                            "type": "com.linkedin.7737d1abf743001bc78e672aaeea5e65"
                        },
                        "reminded": {
                            "type": "boolean"
                        },
                        "liveVideoPostTopicUrn": {
                            "type": "com.linkedin.common.LiveVideoPostTopicUrn"
                        },
                        "showRemindMe": {
                            "type": "boolean"
                        },
                        "subtitle": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "viewerTrackingTopicUrn": {
                            "type": "com.linkedin.common.ViewerTrackingTopicUrn"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.scheduledlive.ScheduledLiveContentComponent"
                },
                "com.linkedin.c29d5d493cf660fcc187ed3514170ff2": {
                    "fields": {
                        "preDashEntityUrn": {
                            "type": "com.linkedin.voyager.dash.common.PreDashUrn"
                        },
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.UpdateActionsUrn"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.controlmenu.UpdateActions"
                },
                "com.linkedin.1a9edf7c4fc5f73ec859a1ae4c8105fe": {
                    "fields": {
                        "followeeCount": {
                            "type": "long"
                        },
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.FollowingStateUrn"
                        },
                        "trackingUrn": {
                            "type": "com.linkedin.common.Urn"
                        },
                        "preDashFollowingInfoUrn": {
                            "type": "com.linkedin.voyager.dash.common.PreDashUrn"
                        },
                        "following": {
                            "type": "boolean"
                        },
                        "followingType": {
                            "type": "com.linkedin.voyager.dash.feed.FollowingType"
                        },
                        "followerCount": {
                            "type": "long"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.FollowingState"
                },
                "com.linkedin.ceb5a874eede0a2b820bbc8d28d19fb9": {
                    "fields": {
                        "badgeHoverText": {
                            "type": "string"
                        },
                        "targetUrn": {
                            "type": "com.linkedin.common.Urn"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.BadgeData"
                },
                "com.linkedin.6682f4c299a743c2d0af15465ee7b16d": {
                    "fields": {
                        "isAiGenerated": {
                            "type": "boolean"
                        },
                        "signature": {
                            "type": "com.linkedin.c5e4a4faa8b2edc4e2cf14cd7351f556"
                        },
                        "appOrDeviceUsed": {
                            "type": "string"
                        },
                        "aiUsageType": {
                            "type": "pegasus.com.linkedin.mediaInfra.AiUsageType"
                        },
                        "isValid": {
                            "type": "boolean"
                        }
                    },
                    "baseType": "pegasus.com.linkedin.mediaInfra.C2paManifestData"
                },
                "com.linkedin.ad971ca555acf30934fdee34cee9d67d": {
                    "fields": {
                        "skippableAfter": {
                            "type": "long"
                        },
                        "startTime": {
                            "type": "long"
                        },
                        "sponsoredTracking": {
                            "type": "com.linkedin.5afa622044b87152ca004741a0def2a9"
                        },
                        "videoCta": {
                            "type": "com.linkedin.02ae76f0e0810b81c62a4dd5f1cc509f"
                        },
                        "videoPlayMetadata": {
                            "type": "com.linkedin.762fc611b9734ba7fde2123ce919a75e"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.linkedinvideo.InsertableVideo"
                },
                "com.linkedin.d9d0d5044f5a15e3db4ff2b1e0a84438": {
                    "fields": {
                        "optionThatReceivedMostVotes": {
                            "type": "boolean"
                        },
                        "voteCount": {
                            "type": "long"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.polls.PollOptionSummary"
                },
                "com.linkedin.dc2d3fd81a613be5ab390adced48f313": {
                    "fields": {
                        "resolution": {
                            "type": "com.linkedin.7df670073fe1dd4babd92d4abd46078a"
                        },
                        "url": {
                            "type": "com.linkedin.common.Url"
                        }
                    },
                    "baseType": "com.linkedin.videocontent.Thumbnail"
                },
                "com.linkedin.c295a70635e475ee5248caf52e8b437c": {
                    "fields": {
                        "privacySettings": {
                            "type": "com.linkedin.75855d69ba1db62fafb8b6904560ca74",
                            "isInjection": true
                        },
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.InjectionHolderUrn"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.common.InjectionHolder"
                },
                "com.linkedin.7ac947f07f51a4f901ec34224c82f187": {
                    "fields": {
                        "saveResponseAsWorkEmail": {
                            "type": "boolean"
                        },
                        "maxResponseLength": {
                            "type": "int"
                        },
                        "response": {
                            "type": "string"
                        },
                        "validationType": {
                            "type": "com.linkedin.voyager.dash.sponsoredcontent.leadgen.TextFieldType"
                        },
                        "minResponseLength": {
                            "type": "int"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.sponsoredcontent.leadgen.TextInputComponent"
                },
                "com.linkedin.b95815644054b75e89af04b98b438272": {
                    "fields": {
                        "inviteeMemberResolutionResult": {
                            "resolvedFrom": "inviteeMember",
                            "type": "com.linkedin.e0372afc4a18480b00ca7e4906904fd7"
                        },
                        "invitationType": {
                            "type": "com.linkedin.voyager.dash.relationships.invitation.InvitationType"
                        },
                        "inviteeMember": {
                            "type": "string"
                        },
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.InvitationUrn"
                        },
                        "invitationState": {
                            "type": "com.linkedin.voyager.dash.relationships.invitation.InvitationState"
                        },
                        "genericInvitationType": {
                            "type": "com.linkedin.voyager.dash.relationships.invitation.GenericInvitationType"
                        },
                        "invitationId": {
                            "type": "long"
                        },
                        "sharedSecret": {
                            "type": "string"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.relationships.invitation.Invitation"
                },
                "com.linkedin.d388328a98f556cd5d952549ba61eff0": {
                    "fields": {
                        "navigationContext": {
                            "type": "com.linkedin.8a612b4e445851d55ecf8b09571a05ee"
                        },
                        "images": {
                            "type": {
                                "array": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                            }
                        },
                        "multiphotoRenderingFormat": {
                            "type": "com.linkedin.voyager.dash.feed.component.image.MultiPhotoRenderingFormat"
                        },
                        "showTemplateCta": {
                            "type": "boolean"
                        },
                        "largeCtaButton": {
                            "type": "com.linkedin.280548a5c822f61a54f7d2022f1e02a5"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.image.ImageComponent"
                },
                "com.linkedin.ed74e3ca52f62abc923f3cfacd4628e0": {
                    "fields": {
                        "conversationStarters": {
                            "type": {
                                "array": "com.linkedin.51e42327aac2bfbade58f05c0e5df6d5"
                            }
                        },
                        "trackingId": {
                            "type": "com.linkedin.common.TrackingId"
                        },
                        "legoTrackingToken": {
                            "type": "string"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.conversationstarter.ConversationStartersComponent"
                },
                "com.linkedin.2b480b3cde698a1a539b07ea20530065": {
                    "fields": {
                        "controlName": {
                            "type": "com.linkedin.voyager.dash.common.tracking.ControlName"
                        },
                        "actionType": {
                            "type": "string"
                        },
                        "navigationUrl": {
                            "type": "com.linkedin.common.Url"
                        },
                        "text": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.NonEntityCardAction"
                },
                "com.linkedin.9d67b80fb82e3d96227749fd6d468116": {
                    "fields": {
                        "ringContentType": {
                            "type": "com.linkedin.voyager.dash.common.image.RingContentType"
                        },
                        "actionTarget": {
                            "type": "com.linkedin.common.Url"
                        },
                        "preDashEntityUrn": {
                            "type": "com.linkedin.voyager.dash.common.PreDashUrn"
                        },
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.RingStatusUrn"
                        },
                        "emphasized": {
                            "type": "boolean"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.common.image.RingStatus"
                },
                "com.linkedin.cf49e2720a644b4a12dc9c8ac3f90543": {
                    "fields": {
                        "deeplinkUrl": {
                            "type": "com.linkedin.common.Url"
                        },
                        "recruiterContext": {
                            "type": "boolean"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.identity.profile.actions.ViewProfileInExternalContextAction"
                },
                "com.linkedin.fd159a3b501495478a862571293c7307": {
                    "fields": {
                        "previewEndText": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "previewDurationInSeconds": {
                            "type": "long"
                        },
                        "previewEndIcon": {
                            "type": "com.linkedin.voyager.dash.common.SystemImageName"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.linkedinvideo.VideoPreviewMetadata"
                },
                "com.linkedin.8bb7af21154573d49987b03117f5d1cf": {
                    "fields": {
                        "insightImage": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "sharedConnectionDetailTarget": {
                            "type": "string"
                        },
                        "text": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "navigationUrl": {
                            "type": "com.linkedin.common.Url"
                        },
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.RelInsightUrn"
                        },
                        "sharedConnectionDetailTargetResolutionResult": {
                            "resolvedFrom": "sharedConnectionDetailTarget",
                            "type": "com.linkedin.e0372afc4a18480b00ca7e4906904fd7"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.relationships.Insight"
                },
                "com.linkedin.f4b0bc15ad9bff87e37f0fbe3390c14b": {
                    "fields": {
                        "urn": {
                            "type": "com.linkedin.common.Urn"
                        },
                        "contentSource": {
                            "type": "com.linkedin.voyager.dash.search.ContentSource"
                        },
                        "authorProfileId": {
                            "type": "string"
                        },
                        "authorUrn": {
                            "type": "com.linkedin.common.Urn"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.ReportAction"
                },
                "com.linkedin.7df670073fe1dd4babd92d4abd46078a": {
                    "fields": {
                        "width": {
                            "type": "int"
                        },
                        "height": {
                            "type": "int"
                        }
                    },
                    "baseType": "com.linkedin.videocontent.Resolution"
                },
                "com.linkedin.bd9a707a5b119c1f331373113f57344a": {
                    "fields": {
                        "searchActionType": {
                            "type": "string"
                        },
                        "image": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "subtitleMaxNumLines": {
                            "type": "int"
                        },
                        "titleFontSize": {
                            "type": "com.linkedin.voyager.dash.search.FontSize"
                        },
                        "subtitle": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "controlName": {
                            "type": "com.linkedin.voyager.dash.common.tracking.ControlName"
                        },
                        "subtitleFontSize": {
                            "type": "com.linkedin.voyager.dash.search.FontSize"
                        },
                        "navigationUrl": {
                            "type": "com.linkedin.common.Url"
                        },
                        "title": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "titleMaxNumLines": {
                            "type": "int"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.SimpleInsight"
                },
                "com.linkedin.4f55a752e41ac24988f152a28efd3398": {
                    "fields": {
                        "ctaButton": {
                            "type": "com.linkedin.280548a5c822f61a54f7d2022f1e02a5"
                        },
                        "image": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "subdescription": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "description": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "banner": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "title": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "titleContext": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "bannerEntityImage": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "subtitle": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "insightImage": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "navigationContext": {
                            "type": "com.linkedin.8a612b4e445851d55ecf8b09571a05ee"
                        },
                        "insightText": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        },
                        "timestamp": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.entity.EntityComponent"
                },
                "com.linkedin.6ae8c37596566c4ce8b04bc5348f2b24": {
                    "fields": {
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.SegmentAttributeUrn"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.hiring.SegmentAttribute"
                },
                "com.linkedin.0b0b1ff1bc3680ba45bd418512ffc8ca": {
                    "fields": {
                        "templateType": {
                            "type": "com.linkedin.voyager.dash.feed.component.interstitial.InterstitialTemplateType"
                        },
                        "interstitial": {
                            "type": "com.linkedin.191c4aa50072107393c644d1284e6a09"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.SearchInterstitialComponent"
                },
                "com.linkedin.40871a3bc360eff8b27a30f69792683e": {
                    "fields": {
                        "title": {
                            "type": "string"
                        },
                        "invitationRelationshipOptions": {
                            "type": {
                                "array": "com.linkedin.59743104bf85ef6a7c2a2bb2b2491b8d"
                            }
                        },
                        "subtitle": {
                            "type": "string"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.relationships.invitation.InvitationRelationshipForm"
                },
                "com.linkedin.f023e0f4e1b3b52579ab54428a778977": {
                    "fields": {
                        "rating": {
                            "type": "double"
                        },
                        "ratingSubtext": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.ServiceProviderRatingInsight"
                },
                "com.linkedin.ec44aca6a639309aabe15e50093f4e6a": {
                    "fields": {
                        "professionalEvent": {
                            "resolvedFrom": "professionalEventUrn",
                            "type": "com.linkedin.a780c129a85db3680157820ba19315f2"
                        },
                        "vectorImage": {
                            "type": "com.linkedin.28db8575bcf1c65bdc4bc15948d50ee9"
                        },
                        "professionalEventUrn": {
                            "type": "string"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.common.image.NonEntityProfessionalEventLogo"
                },
                "com.linkedin.2c018138fdfa8396a9d8fc5fa0311e71": {
                    "fields": {
                        "ctaButton": {
                            "type": "com.linkedin.280548a5c822f61a54f7d2022f1e02a5"
                        },
                        "navigationContext": {
                            "type": "com.linkedin.8a612b4e445851d55ecf8b09571a05ee"
                        },
                        "image": {
                            "type": "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                        },
                        "originalIndex": {
                            "type": "int"
                        },
                        "headline": {
                            "type": "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.feed.component.creative.CreativeComponent"
                },
                "com.linkedin.142aa0a1e9459eddfd8a401a5f79a836": {
                    "fields": {
                        "placeholderText": {
                            "type": "string"
                        },
                        "entityUrn": {
                            "type": "com.linkedin.voyager.dash.common.CoachPromptClusterUrn"
                        },
                        "prompts": {
                            "type": {
                                "array": "com.linkedin.86eb7bbd81c72ab573af04d5a3284dba"
                            }
                        },
                        "trackingId": {
                            "type": "com.linkedin.common.TrackingId"
                        }
                    },
                    "baseType": "com.linkedin.voyager.dash.search.gai.CoachPromptCluster"
                }
            }
        }
    },
    "included": [
        {
            "entityUrn": "urn:li:fsd_company:18652742",
            "$recipeTypes": [
                "com.linkedin.2c2374bef3eaba3e079b4a11e2f7bea8"
            ],
            "$type": "com.linkedin.voyager.dash.organization.Company"
        },
        {
            "entityUrn": "urn:li:fsd_company:18733434",
            "$recipeTypes": [
                "com.linkedin.2c2374bef3eaba3e079b4a11e2f7bea8"
            ],
            "$type": "com.linkedin.voyager.dash.organization.Company"
        },
        {
            "entityUrn": "urn:li:fsd_company:437912",
            "$recipeTypes": [
                "com.linkedin.2c2374bef3eaba3e079b4a11e2f7bea8"
            ],
            "$type": "com.linkedin.voyager.dash.organization.Company"
        },
        {
            "entityUrn": "urn:li:fsd_company:74884576",
            "$recipeTypes": [
                "com.linkedin.2c2374bef3eaba3e079b4a11e2f7bea8"
            ],
            "$type": "com.linkedin.voyager.dash.organization.Company"
        },
        {
            "entityUrn": "urn:li:fsd_company:40674246",
            "$recipeTypes": [
                "com.linkedin.2c2374bef3eaba3e079b4a11e2f7bea8"
            ],
            "$type": "com.linkedin.voyager.dash.organization.Company"
        },
        {
            "entityUrn": "urn:li:fsd_company:3317828",
            "$recipeTypes": [
                "com.linkedin.2c2374bef3eaba3e079b4a11e2f7bea8"
            ],
            "$type": "com.linkedin.voyager.dash.organization.Company"
        },
        {
            "entityUrn": "urn:li:fsd_company:12590830",
            "$recipeTypes": [
                "com.linkedin.2c2374bef3eaba3e079b4a11e2f7bea8"
            ],
            "$type": "com.linkedin.voyager.dash.organization.Company"
        },
        {
            "entityUrn": "urn:li:fsd_company:134456",
            "$recipeTypes": [
                "com.linkedin.2c2374bef3eaba3e079b4a11e2f7bea8"
            ],
            "$type": "com.linkedin.voyager.dash.organization.Company"
        },
        {
            "entityUrn": "urn:li:fsd_company:27182818",
            "$recipeTypes": [
                "com.linkedin.2c2374bef3eaba3e079b4a11e2f7bea8"
            ],
            "$type": "com.linkedin.voyager.dash.organization.Company"
        },
        {
            "entityUrn": "urn:li:fsd_company:6346618",
            "$recipeTypes": [
                "com.linkedin.2c2374bef3eaba3e079b4a11e2f7bea8"
            ],
            "$type": "com.linkedin.voyager.dash.organization.Company"
        },
        {
            "template": "UNIVERSAL",
            "actorNavigationContext": null,
            "bserpEntityNavigationalUrl": "https://www.linkedin.com/search/results/all/?keywords=Morphic%20Medical&origin=ENTITY_SEARCH_HOME_HISTORY&heroEntityKey=urn%3Ali%3Aorganization%3A134456",
            "trackingUrn": "urn:li:company:134456",
            "controlName": null,
            "interstitialComponent": null,
            "primaryActions": [],
            "entityCustomTrackingInfo": null,
            "badgeData": null,
            "title": {
                "textDirection": "USER_LOCALE",
                "text": "Morphic Medical",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "overflowActions": [],
            "*lazyLoadedActions": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:134456,COMPANIES,SEARCH_SRP)",
            "searchActionType": null,
            "actorInsights": [],
            "insightsResolutionResults": [],
            "badgeIcon": null,
            "entityUrn": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:134456,SEARCH_SRP,DEFAULT)",
            "showAdditionalCluster": false,
            "ringStatus": null,
            "primarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "Medical Device • Boston, Massachusetts",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "badgeText": null,
            "trackingId": "ke9/KhhhT1iQbMLQeTUDnQ==",
            "summary": {
                "textDirection": "USER_LOCALE",
                "text": "Morphic Medical (formerly GI Dynamics Inc.) is the developer of RESET® (EndoBarrier), an endoscopically delivered device therapy that offers a non-surgical...",
                "attributesV2": [
                    {
                        "start": 8,
                        "length": 7,
                        "detailData": {
                            "jobPostingName": null,
                            "hyperlink": null,
                            "profileFamiliarName": null,
                            "color": null,
                            "companyName": null,
                            "icon": null,
                            "epoch": null,
                            "systemImage": null,
                            "textLink": null,
                            "listItemStyle": null,
                            "groupName": null,
                            "hyperlinkOpenExternally": null,
                            "listStyle": null,
                            "profileFullName": null,
                            "stringFieldReference": null,
                            "learningCourseName": null,
                            "profileMention": null,
                            "style": "BOLD",
                            "schoolName": null,
                            "hashtag": null
                        },
                        "$recipeTypes": [
                            "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                        ],
                        "$type": "com.linkedin.voyager.dash.common.text.TextAttribute"
                    }
                ],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "addEntityToSearchHistory": true,
            "actorNavigationUrl": null,
            "image": {
                "attributes": [
                    {
                        "scalingType": null,
                        "detailData": {
                            "profilePictureWithoutFrame": null,
                            "profilePictureWithRingStatus": null,
                            "companyLogo": null,
                            "icon": null,
                            "systemImage": null,
                            "nonEntityGroupLogo": null,
                            "vectorImage": null,
                            "nonEntityProfessionalEventLogo": null,
                            "profilePicture": null,
                            "imageUrl": null,
                            "professionalEventLogo": null,
                            "nonEntityCompanyLogo": {
                                "*company": "urn:li:fsd_company:134456",
                                "$recipeTypes": [
                                    "com.linkedin.3be27b5a0eb7edd91e98b14c0290096c"
                                ],
                                "vectorImage": {
                                    "digitalmediaAsset": null,
                                    "attribution": null,
                                    "c2paManifestData": null,
                                    "$recipeTypes": [
                                        "com.linkedin.28db8575bcf1c65bdc4bc15948d50ee9"
                                    ],
                                    "artifacts": [
                                        {
                                            "width": 100,
                                            "$recipeTypes": [
                                                "com.linkedin.f0f435b4425ee2990eba8f0a4d614944"
                                            ],
                                            "fileIdentifyingUrlPathSegment": "https://media.licdn.com/dms/image/v2/D4E0BAQHlOR2l3w8ByA/company-logo_100_100/company-logo_100_100/0/1688580238985/gi_dynamics_logo?e=1769644800&v=beta&t=PQG0XLHGJB5Tf7wNyT1TGymGYS3-M2OmTK-p1GstlbQ",
                                            "expiresAt": 1769644800000,
                                            "height": 100,
                                            "$type": "com.linkedin.common.VectorArtifact"
                                        }
                                    ],
                                    "rootUrl": "",
                                    "$type": "com.linkedin.common.VectorImage"
                                },
                                "$type": "com.linkedin.voyager.dash.common.image.NonEntityCompanyLogo"
                            },
                            "nonEntitySchoolLogo": null,
                            "groupLogo": null,
                            "schoolLogo": null,
                            "ghostImage": null,
                            "nonEntityProfilePicture": null
                        },
                        "tintColor": null,
                        "$recipeTypes": [
                            "com.linkedin.eb94fbb1518f790c4545aafdf571c64e"
                        ],
                        "tapTargets": [],
                        "displayAspectRatio": null,
                        "$type": "com.linkedin.voyager.dash.common.image.ImageAttribute"
                    }
                ],
                "editableAccessibilityText": false,
                "actionTarget": null,
                "accessibilityTextAttributes": [],
                "totalCount": null,
                "accessibilityText": "Morphic Medical",
                "$recipeTypes": [
                    "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                ],
                "$type": "com.linkedin.voyager.dash.common.image.ImageViewModel"
            },
            "secondarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "4K followers",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "navigationUrl": "https://www.linkedin.com/company/morphic-medical/",
            "entityEmbeddedObject": null,
            "unreadIndicatorDetails": null,
            "$recipeTypes": [
                "com.linkedin.cf4b25c18907ea8eafe915c8bfa24109"
            ],
            "target": null,
            "$type": "com.linkedin.voyager.dash.search.EntityResultViewModel",
            "actorTrackingUrn": null,
            "navigationContext": {
                "openExternally": false,
                "$recipeTypes": [
                    "com.linkedin.55ee9afd4182671fe7e271f615659525"
                ],
                "url": "https://www.linkedin.com/company/morphic-medical/",
                "$type": "com.linkedin.voyager.dash.search.NavigationContext"
            }
        },
        {
            "template": "UNIVERSAL",
            "actorNavigationContext": null,
            "bserpEntityNavigationalUrl": "https://www.linkedin.com/search/results/all/?keywords=Medical%20Aesthetic&origin=ENTITY_SEARCH_HOME_HISTORY&heroEntityKey=urn%3Ali%3Aorganization%3A18652742",
            "trackingUrn": "urn:li:company:18652742",
            "controlName": null,
            "interstitialComponent": null,
            "primaryActions": [],
            "entityCustomTrackingInfo": null,
            "badgeData": null,
            "title": {
                "textDirection": "USER_LOCALE",
                "text": "Medical Aesthetic",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "overflowActions": [],
            "*lazyLoadedActions": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:18652742,COMPANIES,SEARCH_SRP)",
            "searchActionType": null,
            "actorInsights": [],
            "insightsResolutionResults": [],
            "badgeIcon": null,
            "entityUrn": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:18652742,SEARCH_SRP,DEFAULT)",
            "showAdditionalCluster": false,
            "ringStatus": null,
            "primarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "Medical Practices • South Melbourne, Victoria",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "badgeText": null,
            "trackingId": "pSjSkrkHSB2lbdxkup3p9A==",
            "summary": {
                "textDirection": "USER_LOCALE",
                "text": "With over 33 years of experience in Melbourne, performing laser hair removal using medical grade lasers, Medical Aesthetic Laser Clinic has become the leading...",
                "attributesV2": [
                    {
                        "start": 83,
                        "length": 7,
                        "detailData": {
                            "jobPostingName": null,
                            "hyperlink": null,
                            "profileFamiliarName": null,
                            "color": null,
                            "companyName": null,
                            "icon": null,
                            "epoch": null,
                            "systemImage": null,
                            "textLink": null,
                            "listItemStyle": null,
                            "groupName": null,
                            "hyperlinkOpenExternally": null,
                            "listStyle": null,
                            "profileFullName": null,
                            "stringFieldReference": null,
                            "learningCourseName": null,
                            "profileMention": null,
                            "style": "BOLD",
                            "schoolName": null,
                            "hashtag": null
                        },
                        "$recipeTypes": [
                            "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                        ],
                        "$type": "com.linkedin.voyager.dash.common.text.TextAttribute"
                    },
                    {
                        "start": 105,
                        "length": 7,
                        "detailData": {
                            "jobPostingName": null,
                            "hyperlink": null,
                            "profileFamiliarName": null,
                            "color": null,
                            "companyName": null,
                            "icon": null,
                            "epoch": null,
                            "systemImage": null,
                            "textLink": null,
                            "listItemStyle": null,
                            "groupName": null,
                            "hyperlinkOpenExternally": null,
                            "listStyle": null,
                            "profileFullName": null,
                            "stringFieldReference": null,
                            "learningCourseName": null,
                            "profileMention": null,
                            "style": "BOLD",
                            "schoolName": null,
                            "hashtag": null
                        },
                        "$recipeTypes": [
                            "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                        ],
                        "$type": "com.linkedin.voyager.dash.common.text.TextAttribute"
                    }
                ],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "addEntityToSearchHistory": true,
            "actorNavigationUrl": null,
            "image": {
                "attributes": [
                    {
                        "scalingType": null,
                        "detailData": {
                            "profilePictureWithoutFrame": null,
                            "profilePictureWithRingStatus": null,
                            "companyLogo": null,
                            "icon": null,
                            "systemImage": null,
                            "nonEntityGroupLogo": null,
                            "vectorImage": null,
                            "nonEntityProfessionalEventLogo": null,
                            "profilePicture": null,
                            "imageUrl": null,
                            "professionalEventLogo": null,
                            "nonEntityCompanyLogo": {
                                "*company": "urn:li:fsd_company:18652742",
                                "$recipeTypes": [
                                    "com.linkedin.3be27b5a0eb7edd91e98b14c0290096c"
                                ],
                                "vectorImage": {
                                    "digitalmediaAsset": null,
                                    "attribution": null,
                                    "c2paManifestData": null,
                                    "$recipeTypes": [
                                        "com.linkedin.28db8575bcf1c65bdc4bc15948d50ee9"
                                    ],
                                    "artifacts": [
                                        {
                                            "width": 100,
                                            "$recipeTypes": [
                                                "com.linkedin.f0f435b4425ee2990eba8f0a4d614944"
                                            ],
                                            "fileIdentifyingUrlPathSegment": "https://media.licdn.com/dms/image/v2/C560BAQFaA9f88c_msg/company-logo_100_100/company-logo_100_100/0/1630635312403/medical_aesthetic_laser_clinic_logo?e=1769644800&v=beta&t=tsRnJ1xwXIkrtwl2ix1yhqtB6zlAMZOpeu4VidCVFCA",
                                            "expiresAt": 1769644800000,
                                            "height": 100,
                                            "$type": "com.linkedin.common.VectorArtifact"
                                        }
                                    ],
                                    "rootUrl": "",
                                    "$type": "com.linkedin.common.VectorImage"
                                },
                                "$type": "com.linkedin.voyager.dash.common.image.NonEntityCompanyLogo"
                            },
                            "nonEntitySchoolLogo": null,
                            "groupLogo": null,
                            "schoolLogo": null,
                            "ghostImage": null,
                            "nonEntityProfilePicture": null
                        },
                        "tintColor": null,
                        "$recipeTypes": [
                            "com.linkedin.eb94fbb1518f790c4545aafdf571c64e"
                        ],
                        "tapTargets": [],
                        "displayAspectRatio": null,
                        "$type": "com.linkedin.voyager.dash.common.image.ImageAttribute"
                    }
                ],
                "editableAccessibilityText": false,
                "actionTarget": null,
                "accessibilityTextAttributes": [],
                "totalCount": null,
                "accessibilityText": "Medical Aesthetic",
                "$recipeTypes": [
                    "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                ],
                "$type": "com.linkedin.voyager.dash.common.image.ImageViewModel"
            },
            "secondarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "117 followers",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "navigationUrl": "https://www.linkedin.com/company/medical-aesthetic-laser-clinic/",
            "entityEmbeddedObject": null,
            "unreadIndicatorDetails": null,
            "$recipeTypes": [
                "com.linkedin.cf4b25c18907ea8eafe915c8bfa24109"
            ],
            "target": null,
            "$type": "com.linkedin.voyager.dash.search.EntityResultViewModel",
            "actorTrackingUrn": null,
            "navigationContext": {
                "openExternally": false,
                "$recipeTypes": [
                    "com.linkedin.55ee9afd4182671fe7e271f615659525"
                ],
                "url": "https://www.linkedin.com/company/medical-aesthetic-laser-clinic/",
                "$type": "com.linkedin.voyager.dash.search.NavigationContext"
            }
        },
        {
            "template": "UNIVERSAL",
            "actorNavigationContext": null,
            "bserpEntityNavigationalUrl": "https://www.linkedin.com/search/results/all/?keywords=OncoRes%20Medical&origin=ENTITY_SEARCH_HOME_HISTORY&heroEntityKey=urn%3Ali%3Aorganization%3A18733434",
            "trackingUrn": "urn:li:company:18733434",
            "controlName": null,
            "interstitialComponent": null,
            "primaryActions": [],
            "entityCustomTrackingInfo": null,
            "badgeData": null,
            "title": {
                "textDirection": "USER_LOCALE",
                "text": "OncoRes Medical",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "overflowActions": [],
            "*lazyLoadedActions": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:18733434,COMPANIES,SEARCH_SRP)",
            "searchActionType": null,
            "actorInsights": [],
            "insightsResolutionResults": [],
            "badgeIcon": null,
            "entityUrn": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:18733434,SEARCH_SRP,DEFAULT)",
            "showAdditionalCluster": false,
            "ringStatus": null,
            "primarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "Medical Equipment Manufacturing • Nedlands, Western Australia",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "badgeText": null,
            "trackingId": "peTS1l3DSLqad9SMbTGPOw==",
            "summary": {
                "textDirection": "USER_LOCALE",
                "text": "OncoRes Medical is developing an intraoperative imaging tool that translates the surgeon's sense of touch into a microscale image - improving surgical accuracy and reducing complication rates.  Founded in 2016, OncoRes is a medical device company funded by the Medical Research Commercialisation Fund, developing patent...",
                "attributesV2": [
                    {
                        "start": 8,
                        "length": 7,
                        "detailData": {
                            "jobPostingName": null,
                            "hyperlink": null,
                            "profileFamiliarName": null,
                            "color": null,
                            "companyName": null,
                            "icon": null,
                            "epoch": null,
                            "systemImage": null,
                            "textLink": null,
                            "listItemStyle": null,
                            "groupName": null,
                            "hyperlinkOpenExternally": null,
                            "listStyle": null,
                            "profileFullName": null,
                            "stringFieldReference": null,
                            "learningCourseName": null,
                            "profileMention": null,
                            "style": "BOLD",
                            "schoolName": null,
                            "hashtag": null
                        },
                        "$recipeTypes": [
                            "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                        ],
                        "$type": "com.linkedin.voyager.dash.common.text.TextAttribute"
                    },
                    {
                        "start": 224,
                        "length": 7,
                        "detailData": {
                            "jobPostingName": null,
                            "hyperlink": null,
                            "profileFamiliarName": null,
                            "color": null,
                            "companyName": null,
                            "icon": null,
                            "epoch": null,
                            "systemImage": null,
                            "textLink": null,
                            "listItemStyle": null,
                            "groupName": null,
                            "hyperlinkOpenExternally": null,
                            "listStyle": null,
                            "profileFullName": null,
                            "stringFieldReference": null,
                            "learningCourseName": null,
                            "profileMention": null,
                            "style": "BOLD",
                            "schoolName": null,
                            "hashtag": null
                        },
                        "$recipeTypes": [
                            "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                        ],
                        "$type": "com.linkedin.voyager.dash.common.text.TextAttribute"
                    },
                    {
                        "start": 261,
                        "length": 7,
                        "detailData": {
                            "jobPostingName": null,
                            "hyperlink": null,
                            "profileFamiliarName": null,
                            "color": null,
                            "companyName": null,
                            "icon": null,
                            "epoch": null,
                            "systemImage": null,
                            "textLink": null,
                            "listItemStyle": null,
                            "groupName": null,
                            "hyperlinkOpenExternally": null,
                            "listStyle": null,
                            "profileFullName": null,
                            "stringFieldReference": null,
                            "learningCourseName": null,
                            "profileMention": null,
                            "style": "BOLD",
                            "schoolName": null,
                            "hashtag": null
                        },
                        "$recipeTypes": [
                            "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                        ],
                        "$type": "com.linkedin.voyager.dash.common.text.TextAttribute"
                    }
                ],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "addEntityToSearchHistory": true,
            "actorNavigationUrl": null,
            "image": {
                "attributes": [
                    {
                        "scalingType": null,
                        "detailData": {
                            "profilePictureWithoutFrame": null,
                            "profilePictureWithRingStatus": null,
                            "companyLogo": null,
                            "icon": null,
                            "systemImage": null,
                            "nonEntityGroupLogo": null,
                            "vectorImage": null,
                            "nonEntityProfessionalEventLogo": null,
                            "profilePicture": null,
                            "imageUrl": null,
                            "professionalEventLogo": null,
                            "nonEntityCompanyLogo": {
                                "*company": "urn:li:fsd_company:18733434",
                                "$recipeTypes": [
                                    "com.linkedin.3be27b5a0eb7edd91e98b14c0290096c"
                                ],
                                "vectorImage": {
                                    "digitalmediaAsset": null,
                                    "attribution": null,
                                    "c2paManifestData": null,
                                    "$recipeTypes": [
                                        "com.linkedin.28db8575bcf1c65bdc4bc15948d50ee9"
                                    ],
                                    "artifacts": [
                                        {
                                            "width": 100,
                                            "$recipeTypes": [
                                                "com.linkedin.f0f435b4425ee2990eba8f0a4d614944"
                                            ],
                                            "fileIdentifyingUrlPathSegment": "https://media.licdn.com/dms/image/v2/C560BAQGGlw_m9UTVag/company-logo_100_100/company-logo_100_100/0/1631405719300/oncoresmedical_logo?e=1769644800&v=beta&t=T-Uj29lhaispEi6xMs7eNusy3oItwovXCotIi4XKRWY",
                                            "expiresAt": 1769644800000,
                                            "height": 100,
                                            "$type": "com.linkedin.common.VectorArtifact"
                                        }
                                    ],
                                    "rootUrl": "",
                                    "$type": "com.linkedin.common.VectorImage"
                                },
                                "$type": "com.linkedin.voyager.dash.common.image.NonEntityCompanyLogo"
                            },
                            "nonEntitySchoolLogo": null,
                            "groupLogo": null,
                            "schoolLogo": null,
                            "ghostImage": null,
                            "nonEntityProfilePicture": null
                        },
                        "tintColor": null,
                        "$recipeTypes": [
                            "com.linkedin.eb94fbb1518f790c4545aafdf571c64e"
                        ],
                        "tapTargets": [],
                        "displayAspectRatio": null,
                        "$type": "com.linkedin.voyager.dash.common.image.ImageAttribute"
                    }
                ],
                "editableAccessibilityText": false,
                "actionTarget": null,
                "accessibilityTextAttributes": [],
                "totalCount": null,
                "accessibilityText": "OncoRes Medical",
                "$recipeTypes": [
                    "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                ],
                "$type": "com.linkedin.voyager.dash.common.image.ImageViewModel"
            },
            "secondarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "4K followers",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "navigationUrl": "https://www.linkedin.com/company/oncoresmedical/",
            "entityEmbeddedObject": null,
            "unreadIndicatorDetails": null,
            "$recipeTypes": [
                "com.linkedin.cf4b25c18907ea8eafe915c8bfa24109"
            ],
            "target": null,
            "$type": "com.linkedin.voyager.dash.search.EntityResultViewModel",
            "actorTrackingUrn": null,
            "navigationContext": {
                "openExternally": false,
                "$recipeTypes": [
                    "com.linkedin.55ee9afd4182671fe7e271f615659525"
                ],
                "url": "https://www.linkedin.com/company/oncoresmedical/",
                "$type": "com.linkedin.voyager.dash.search.NavigationContext"
            }
        },
        {
            "template": "UNIVERSAL",
            "actorNavigationContext": null,
            "bserpEntityNavigationalUrl": "https://www.linkedin.com/search/results/all/?keywords=MEDICAL%20AND%20SURGICAL%20REQUISITES%20PTY%2E%20LIMITED&origin=ENTITY_SEARCH_HOME_HISTORY&heroEntityKey=urn%3Ali%3Aorganization%3A6346618",
            "trackingUrn": "urn:li:company:6346618",
            "controlName": null,
            "interstitialComponent": null,
            "primaryActions": [],
            "entityCustomTrackingInfo": null,
            "badgeData": null,
            "title": {
                "textDirection": "USER_LOCALE",
                "text": "MEDICAL AND SURGICAL REQUISITES PTY. LIMITED",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "overflowActions": [],
            "*lazyLoadedActions": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:6346618,COMPANIES,SEARCH_SRP)",
            "searchActionType": null,
            "actorInsights": [],
            "insightsResolutionResults": [],
            "badgeIcon": null,
            "entityUrn": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:6346618,SEARCH_SRP,DEFAULT)",
            "showAdditionalCluster": false,
            "ringStatus": null,
            "primarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "Medical Equipment Manufacturing • RICHLANDS, QLD",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "badgeText": null,
            "trackingId": "fZ8Sh21xSim5B7tiQ+6MTw==",
            "summary": {
                "textDirection": "USER_LOCALE",
                "text": "MSR provides service, products and support to General Practices, Day Surgeries, Skin Cancer and Cosmetic Clinics.",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "addEntityToSearchHistory": true,
            "actorNavigationUrl": null,
            "image": {
                "attributes": [
                    {
                        "scalingType": null,
                        "detailData": {
                            "profilePictureWithoutFrame": null,
                            "profilePictureWithRingStatus": null,
                            "companyLogo": null,
                            "icon": null,
                            "systemImage": null,
                            "nonEntityGroupLogo": null,
                            "vectorImage": null,
                            "nonEntityProfessionalEventLogo": null,
                            "profilePicture": null,
                            "imageUrl": null,
                            "professionalEventLogo": null,
                            "nonEntityCompanyLogo": {
                                "*company": "urn:li:fsd_company:6346618",
                                "$recipeTypes": [
                                    "com.linkedin.3be27b5a0eb7edd91e98b14c0290096c"
                                ],
                                "vectorImage": {
                                    "digitalmediaAsset": null,
                                    "attribution": null,
                                    "c2paManifestData": null,
                                    "$recipeTypes": [
                                        "com.linkedin.28db8575bcf1c65bdc4bc15948d50ee9"
                                    ],
                                    "artifacts": [
                                        {
                                            "width": 100,
                                            "$recipeTypes": [
                                                "com.linkedin.f0f435b4425ee2990eba8f0a4d614944"
                                            ],
                                            "fileIdentifyingUrlPathSegment": "https://media.licdn.com/dms/image/v2/C560BAQHd2FcTA6Eegg/company-logo_100_100/company-logo_100_100/0/1630570644447/medical_and_surgical_requisites_pty_limited_logo?e=1769644800&v=beta&t=pvQkoC8HRqBHGfq75I6dVHHDBtrSpCqgg4_q2t2jaJI",
                                            "expiresAt": 1769644800000,
                                            "height": 100,
                                            "$type": "com.linkedin.common.VectorArtifact"
                                        }
                                    ],
                                    "rootUrl": "",
                                    "$type": "com.linkedin.common.VectorImage"
                                },
                                "$type": "com.linkedin.voyager.dash.common.image.NonEntityCompanyLogo"
                            },
                            "nonEntitySchoolLogo": null,
                            "groupLogo": null,
                            "schoolLogo": null,
                            "ghostImage": null,
                            "nonEntityProfilePicture": null
                        },
                        "tintColor": null,
                        "$recipeTypes": [
                            "com.linkedin.eb94fbb1518f790c4545aafdf571c64e"
                        ],
                        "tapTargets": [],
                        "displayAspectRatio": null,
                        "$type": "com.linkedin.voyager.dash.common.image.ImageAttribute"
                    }
                ],
                "editableAccessibilityText": false,
                "actionTarget": null,
                "accessibilityTextAttributes": [],
                "totalCount": null,
                "accessibilityText": "MEDICAL AND SURGICAL REQUISITES PTY. LIMITED",
                "$recipeTypes": [
                    "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                ],
                "$type": "com.linkedin.voyager.dash.common.image.ImageViewModel"
            },
            "secondarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "150 followers",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "navigationUrl": "https://www.linkedin.com/company/medical-and-surgical-requisites-pty-limited/",
            "entityEmbeddedObject": null,
            "unreadIndicatorDetails": null,
            "$recipeTypes": [
                "com.linkedin.cf4b25c18907ea8eafe915c8bfa24109"
            ],
            "target": null,
            "$type": "com.linkedin.voyager.dash.search.EntityResultViewModel",
            "actorTrackingUrn": null,
            "navigationContext": {
                "openExternally": false,
                "$recipeTypes": [
                    "com.linkedin.55ee9afd4182671fe7e271f615659525"
                ],
                "url": "https://www.linkedin.com/company/medical-and-surgical-requisites-pty-limited/",
                "$type": "com.linkedin.voyager.dash.search.NavigationContext"
            }
        },
        {
            "template": "UNIVERSAL",
            "actorNavigationContext": null,
            "bserpEntityNavigationalUrl": "https://www.linkedin.com/search/results/all/?keywords=Lenexa%20Medical&origin=ENTITY_SEARCH_HOME_HISTORY&heroEntityKey=urn%3Ali%3Aorganization%3A12590830",
            "trackingUrn": "urn:li:company:12590830",
            "controlName": null,
            "interstitialComponent": null,
            "primaryActions": [],
            "entityCustomTrackingInfo": null,
            "badgeData": null,
            "title": {
                "textDirection": "USER_LOCALE",
                "text": "Lenexa Medical",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "overflowActions": [],
            "*lazyLoadedActions": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:12590830,COMPANIES,SEARCH_SRP)",
            "searchActionType": null,
            "actorInsights": [],
            "insightsResolutionResults": [
                {
                    "jobPostingInsight": null,
                    "relationshipsInsight": null,
                    "serviceProviderRatingInsight": null,
                    "simpleInsight": null,
                    "jobPostingFooterInsight": null,
                    "socialActivityCountsInsight": null,
                    "premiumCustomCtaInsight": {
                        "searchActionType": "PREMIUM_VISIT_WEBSITE",
                        "titleFontSize": "SMALL",
                        "navigationContext": {
                            "openExternally": false,
                            "$recipeTypes": [
                                "com.linkedin.55ee9afd4182671fe7e271f615659525"
                            ],
                            "url": "https://www.lenexamedical.com",
                            "$type": "com.linkedin.voyager.dash.search.NavigationContext"
                        },
                        "title": {
                            "textDirection": "USER_LOCALE",
                            "text": "Visit website",
                            "attributesV2": [
                                {
                                    "start": 0,
                                    "length": 13,
                                    "detailData": {
                                        "jobPostingName": null,
                                        "hyperlink": null,
                                        "profileFamiliarName": null,
                                        "color": null,
                                        "companyName": null,
                                        "icon": null,
                                        "epoch": null,
                                        "systemImage": null,
                                        "textLink": null,
                                        "listItemStyle": null,
                                        "groupName": null,
                                        "hyperlinkOpenExternally": null,
                                        "listStyle": null,
                                        "profileFullName": null,
                                        "stringFieldReference": null,
                                        "learningCourseName": null,
                                        "profileMention": null,
                                        "style": "BOLD",
                                        "schoolName": null,
                                        "hashtag": null
                                    },
                                    "$recipeTypes": [
                                        "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                                    ],
                                    "$type": "com.linkedin.voyager.dash.common.text.TextAttribute"
                                }
                            ],
                            "accessibilityTextAttributesV2": [],
                            "accessibilityText": "Visit website",
                            "$recipeTypes": [
                                "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                            ],
                            "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
                        },
                        "$recipeTypes": [
                            "com.linkedin.e7255825e31731ce221bd0a581bbdd47"
                        ],
                        "titleMaxNumLines": 1,
                        "$type": "com.linkedin.voyager.dash.search.premium.PremiumCustomCtaInsight"
                    },
                    "labelsInsight": null
                }
            ],
            "badgeIcon": {
                "attributes": [
                    {
                        "scalingType": null,
                        "detailData": {
                            "profilePictureWithoutFrame": null,
                            "profilePictureWithRingStatus": null,
                            "companyLogo": null,
                            "icon": "IC_LINKEDIN_PREMIUM_GOLD_ICON_16DP",
                            "systemImage": null,
                            "nonEntityGroupLogo": null,
                            "vectorImage": null,
                            "nonEntityProfessionalEventLogo": null,
                            "profilePicture": null,
                            "imageUrl": null,
                            "professionalEventLogo": null,
                            "nonEntityCompanyLogo": null,
                            "nonEntitySchoolLogo": null,
                            "groupLogo": null,
                            "schoolLogo": null,
                            "ghostImage": null,
                            "nonEntityProfilePicture": null
                        },
                        "tintColor": null,
                        "$recipeTypes": [
                            "com.linkedin.eb94fbb1518f790c4545aafdf571c64e"
                        ],
                        "tapTargets": [],
                        "displayAspectRatio": null,
                        "$type": "com.linkedin.voyager.dash.common.image.ImageAttribute"
                    }
                ],
                "editableAccessibilityText": false,
                "actionTarget": null,
                "accessibilityTextAttributes": [],
                "totalCount": null,
                "accessibilityText": "Premium page",
                "$recipeTypes": [
                    "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                ],
                "$type": "com.linkedin.voyager.dash.common.image.ImageViewModel"
            },
            "entityUrn": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:12590830,SEARCH_SRP,DEFAULT)",
            "showAdditionalCluster": false,
            "ringStatus": null,
            "primarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "Medical Equipment Manufacturing • Burnley, Victoria",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "badgeText": null,
            "trackingId": "w9WdZ5vMQl28wypGl4Ir7g==",
            "summary": {
                "textDirection": "USER_LOCALE",
                "text": "Lenexa Medical is an Australian-based MedTech company that has developed the LenexaCARE technology to empower clinicians to deliver targeted, long-term solutions for personalised pressure injury prevention and patient monitoring.    Pressure injuries are mostly preventable, however affect millions of people globally...",
                "attributesV2": [
                    {
                        "start": 7,
                        "length": 7,
                        "detailData": {
                            "jobPostingName": null,
                            "hyperlink": null,
                            "profileFamiliarName": null,
                            "color": null,
                            "companyName": null,
                            "icon": null,
                            "epoch": null,
                            "systemImage": null,
                            "textLink": null,
                            "listItemStyle": null,
                            "groupName": null,
                            "hyperlinkOpenExternally": null,
                            "listStyle": null,
                            "profileFullName": null,
                            "stringFieldReference": null,
                            "learningCourseName": null,
                            "profileMention": null,
                            "style": "BOLD",
                            "schoolName": null,
                            "hashtag": null
                        },
                        "$recipeTypes": [
                            "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                        ],
                        "$type": "com.linkedin.voyager.dash.common.text.TextAttribute"
                    }
                ],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "addEntityToSearchHistory": true,
            "actorNavigationUrl": null,
            "image": {
                "attributes": [
                    {
                        "scalingType": null,
                        "detailData": {
                            "profilePictureWithoutFrame": null,
                            "profilePictureWithRingStatus": null,
                            "companyLogo": null,
                            "icon": null,
                            "systemImage": null,
                            "nonEntityGroupLogo": null,
                            "vectorImage": null,
                            "nonEntityProfessionalEventLogo": null,
                            "profilePicture": null,
                            "imageUrl": null,
                            "professionalEventLogo": null,
                            "nonEntityCompanyLogo": {
                                "*company": "urn:li:fsd_company:12590830",
                                "$recipeTypes": [
                                    "com.linkedin.3be27b5a0eb7edd91e98b14c0290096c"
                                ],
                                "vectorImage": {
                                    "digitalmediaAsset": null,
                                    "attribution": null,
                                    "c2paManifestData": null,
                                    "$recipeTypes": [
                                        "com.linkedin.28db8575bcf1c65bdc4bc15948d50ee9"
                                    ],
                                    "artifacts": [
                                        {
                                            "width": 100,
                                            "$recipeTypes": [
                                                "com.linkedin.f0f435b4425ee2990eba8f0a4d614944"
                                            ],
                                            "fileIdentifyingUrlPathSegment": "https://media.licdn.com/dms/image/v2/C4D0BAQHVt6esXtucow/company-logo_100_100/company-logo_100_100/0/1646005990613/lenexamedical_logo?e=1769644800&v=beta&t=u0lKpb3BRiXuT7B4442_kxsf3tgvx74oF5tgFgzXkGg",
                                            "expiresAt": 1769644800000,
                                            "height": 100,
                                            "$type": "com.linkedin.common.VectorArtifact"
                                        }
                                    ],
                                    "rootUrl": "",
                                    "$type": "com.linkedin.common.VectorImage"
                                },
                                "$type": "com.linkedin.voyager.dash.common.image.NonEntityCompanyLogo"
                            },
                            "nonEntitySchoolLogo": null,
                            "groupLogo": null,
                            "schoolLogo": null,
                            "ghostImage": null,
                            "nonEntityProfilePicture": null
                        },
                        "tintColor": null,
                        "$recipeTypes": [
                            "com.linkedin.eb94fbb1518f790c4545aafdf571c64e"
                        ],
                        "tapTargets": [],
                        "displayAspectRatio": null,
                        "$type": "com.linkedin.voyager.dash.common.image.ImageAttribute"
                    }
                ],
                "editableAccessibilityText": false,
                "actionTarget": null,
                "accessibilityTextAttributes": [],
                "totalCount": null,
                "accessibilityText": "Lenexa Medical",
                "$recipeTypes": [
                    "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                ],
                "$type": "com.linkedin.voyager.dash.common.image.ImageViewModel"
            },
            "secondarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "3K followers",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "navigationUrl": "https://www.linkedin.com/company/lenexamedical/",
            "entityEmbeddedObject": null,
            "unreadIndicatorDetails": null,
            "$recipeTypes": [
                "com.linkedin.cf4b25c18907ea8eafe915c8bfa24109"
            ],
            "target": null,
            "$type": "com.linkedin.voyager.dash.search.EntityResultViewModel",
            "actorTrackingUrn": null,
            "navigationContext": {
                "openExternally": false,
                "$recipeTypes": [
                    "com.linkedin.55ee9afd4182671fe7e271f615659525"
                ],
                "url": "https://www.linkedin.com/company/lenexamedical/",
                "$type": "com.linkedin.voyager.dash.search.NavigationContext"
            }
        },
        {
            "template": "UNIVERSAL",
            "actorNavigationContext": null,
            "bserpEntityNavigationalUrl": "https://www.linkedin.com/search/results/all/?keywords=Canon%20Medical%20Systems%20ANZ%20Pty%20Limited&origin=ENTITY_SEARCH_HOME_HISTORY&heroEntityKey=urn%3Ali%3Aorganization%3A27182818",
            "trackingUrn": "urn:li:company:27182818",
            "controlName": null,
            "interstitialComponent": null,
            "primaryActions": [],
            "entityCustomTrackingInfo": null,
            "badgeData": null,
            "title": {
                "textDirection": "USER_LOCALE",
                "text": "Canon Medical Systems ANZ Pty Limited",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "overflowActions": [],
            "*lazyLoadedActions": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:27182818,COMPANIES,SEARCH_SRP)",
            "searchActionType": null,
            "actorInsights": [],
            "insightsResolutionResults": [
                {
                    "jobPostingInsight": null,
                    "relationshipsInsight": null,
                    "serviceProviderRatingInsight": null,
                    "simpleInsight": {
                        "image": {
                            "attributes": [
                                {
                                    "scalingType": "ASPECT_FIT",
                                    "detailData": {
                                        "profilePictureWithoutFrame": null,
                                        "profilePictureWithRingStatus": null,
                                        "companyLogo": null,
                                        "icon": "IC_BRIEFCASE_16DP",
                                        "systemImage": null,
                                        "nonEntityGroupLogo": null,
                                        "vectorImage": null,
                                        "nonEntityProfessionalEventLogo": null,
                                        "profilePicture": null,
                                        "imageUrl": null,
                                        "professionalEventLogo": null,
                                        "nonEntityCompanyLogo": null,
                                        "nonEntitySchoolLogo": null,
                                        "groupLogo": null,
                                        "schoolLogo": null,
                                        "ghostImage": null,
                                        "nonEntityProfilePicture": null
                                    },
                                    "tintColor": null,
                                    "$recipeTypes": [
                                        "com.linkedin.eb94fbb1518f790c4545aafdf571c64e"
                                    ],
                                    "tapTargets": [],
                                    "displayAspectRatio": null,
                                    "$type": "com.linkedin.voyager.dash.common.image.ImageAttribute"
                                }
                            ],
                            "editableAccessibilityText": false,
                            "actionTarget": null,
                            "accessibilityTextAttributes": [],
                            "totalCount": null,
                            "accessibilityText": null,
                            "$recipeTypes": [
                                "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                            ],
                            "$type": "com.linkedin.voyager.dash.common.image.ImageViewModel"
                        },
                        "controlName": null,
                        "navigationUrl": "https://www.linkedin.com/jobs/search?geoId=92000000&f_C=27182818",
                        "title": {
                            "textDirection": "USER_LOCALE",
                            "text": "1 job",
                            "attributesV2": [],
                            "accessibilityTextAttributesV2": [],
                            "accessibilityText": null,
                            "$recipeTypes": [
                                "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                            ],
                            "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
                        },
                        "$recipeTypes": [
                            "com.linkedin.bd9a707a5b119c1f331373113f57344a"
                        ],
                        "$type": "com.linkedin.voyager.dash.search.SimpleInsight",
                        "searchActionType": "SEE_JOBS_AT_COMPANY",
                        "subtitleMaxNumLines": 1,
                        "titleFontSize": null,
                        "subtitle": null,
                        "subtitleFontSize": null,
                        "titleMaxNumLines": 1
                    },
                    "jobPostingFooterInsight": null,
                    "socialActivityCountsInsight": null,
                    "labelsInsight": null,
                    "premiumCustomCtaInsight": null
                }
            ],
            "badgeIcon": null,
            "entityUrn": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:27182818,SEARCH_SRP,DEFAULT)",
            "showAdditionalCluster": false,
            "ringStatus": null,
            "primarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "Medical Equipment Manufacturing • Castle Hill  , NSW",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "badgeText": null,
            "trackingId": "YydOREf8T3ezEXRXn2PUBg==",
            "summary": {
                "textDirection": "USER_LOCALE",
                "text": "Mission Canon Medical Systems ANZ delivers innovative imaging solutions and services through our Made for Life philosophy to improve the quality of life for all people.  Our Heritage Canon Medical Systems is born from two global leaders—Canon and Toshiba Medical.  In business for more than 100 years, Toshiba Medical...",
                "attributesV2": [
                    {
                        "start": 14,
                        "length": 7,
                        "detailData": {
                            "jobPostingName": null,
                            "hyperlink": null,
                            "profileFamiliarName": null,
                            "color": null,
                            "companyName": null,
                            "icon": null,
                            "epoch": null,
                            "systemImage": null,
                            "textLink": null,
                            "listItemStyle": null,
                            "groupName": null,
                            "hyperlinkOpenExternally": null,
                            "listStyle": null,
                            "profileFullName": null,
                            "stringFieldReference": null,
                            "learningCourseName": null,
                            "profileMention": null,
                            "style": "BOLD",
                            "schoolName": null,
                            "hashtag": null
                        },
                        "$recipeTypes": [
                            "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                        ],
                        "$type": "com.linkedin.voyager.dash.common.text.TextAttribute"
                    },
                    {
                        "start": 189,
                        "length": 7,
                        "detailData": {
                            "jobPostingName": null,
                            "hyperlink": null,
                            "profileFamiliarName": null,
                            "color": null,
                            "companyName": null,
                            "icon": null,
                            "epoch": null,
                            "systemImage": null,
                            "textLink": null,
                            "listItemStyle": null,
                            "groupName": null,
                            "hyperlinkOpenExternally": null,
                            "listStyle": null,
                            "profileFullName": null,
                            "stringFieldReference": null,
                            "learningCourseName": null,
                            "profileMention": null,
                            "style": "BOLD",
                            "schoolName": null,
                            "hashtag": null
                        },
                        "$recipeTypes": [
                            "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                        ],
                        "$type": "com.linkedin.voyager.dash.common.text.TextAttribute"
                    },
                    {
                        "start": 255,
                        "length": 7,
                        "detailData": {
                            "jobPostingName": null,
                            "hyperlink": null,
                            "profileFamiliarName": null,
                            "color": null,
                            "companyName": null,
                            "icon": null,
                            "epoch": null,
                            "systemImage": null,
                            "textLink": null,
                            "listItemStyle": null,
                            "groupName": null,
                            "hyperlinkOpenExternally": null,
                            "listStyle": null,
                            "profileFullName": null,
                            "stringFieldReference": null,
                            "learningCourseName": null,
                            "profileMention": null,
                            "style": "BOLD",
                            "schoolName": null,
                            "hashtag": null
                        },
                        "$recipeTypes": [
                            "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                        ],
                        "$type": "com.linkedin.voyager.dash.common.text.TextAttribute"
                    },
                    {
                        "start": 310,
                        "length": 7,
                        "detailData": {
                            "jobPostingName": null,
                            "hyperlink": null,
                            "profileFamiliarName": null,
                            "color": null,
                            "companyName": null,
                            "icon": null,
                            "epoch": null,
                            "systemImage": null,
                            "textLink": null,
                            "listItemStyle": null,
                            "groupName": null,
                            "hyperlinkOpenExternally": null,
                            "listStyle": null,
                            "profileFullName": null,
                            "stringFieldReference": null,
                            "learningCourseName": null,
                            "profileMention": null,
                            "style": "BOLD",
                            "schoolName": null,
                            "hashtag": null
                        },
                        "$recipeTypes": [
                            "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                        ],
                        "$type": "com.linkedin.voyager.dash.common.text.TextAttribute"
                    }
                ],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "addEntityToSearchHistory": true,
            "actorNavigationUrl": null,
            "image": {
                "attributes": [
                    {
                        "scalingType": null,
                        "detailData": {
                            "profilePictureWithoutFrame": null,
                            "profilePictureWithRingStatus": null,
                            "companyLogo": null,
                            "icon": null,
                            "systemImage": null,
                            "nonEntityGroupLogo": null,
                            "vectorImage": null,
                            "nonEntityProfessionalEventLogo": null,
                            "profilePicture": null,
                            "imageUrl": null,
                            "professionalEventLogo": null,
                            "nonEntityCompanyLogo": {
                                "*company": "urn:li:fsd_company:27182818",
                                "$recipeTypes": [
                                    "com.linkedin.3be27b5a0eb7edd91e98b14c0290096c"
                                ],
                                "vectorImage": {
                                    "digitalmediaAsset": null,
                                    "attribution": null,
                                    "c2paManifestData": null,
                                    "$recipeTypes": [
                                        "com.linkedin.28db8575bcf1c65bdc4bc15948d50ee9"
                                    ],
                                    "artifacts": [
                                        {
                                            "width": 100,
                                            "$recipeTypes": [
                                                "com.linkedin.f0f435b4425ee2990eba8f0a4d614944"
                                            ],
                                            "fileIdentifyingUrlPathSegment": "https://media.licdn.com/dms/image/v2/C4E0BAQFnGtTmFM_3-w/company-logo_100_100/company-logo_100_100/0/1631323781312?e=1769644800&v=beta&t=70vd7y8WDHt5dnNNgsPr1VbEBUkOq0egjGfizLVeF4M",
                                            "expiresAt": 1769644800000,
                                            "height": 100,
                                            "$type": "com.linkedin.common.VectorArtifact"
                                        }
                                    ],
                                    "rootUrl": "",
                                    "$type": "com.linkedin.common.VectorImage"
                                },
                                "$type": "com.linkedin.voyager.dash.common.image.NonEntityCompanyLogo"
                            },
                            "nonEntitySchoolLogo": null,
                            "groupLogo": null,
                            "schoolLogo": null,
                            "ghostImage": null,
                            "nonEntityProfilePicture": null
                        },
                        "tintColor": null,
                        "$recipeTypes": [
                            "com.linkedin.eb94fbb1518f790c4545aafdf571c64e"
                        ],
                        "tapTargets": [],
                        "displayAspectRatio": null,
                        "$type": "com.linkedin.voyager.dash.common.image.ImageAttribute"
                    }
                ],
                "editableAccessibilityText": false,
                "actionTarget": null,
                "accessibilityTextAttributes": [],
                "totalCount": null,
                "accessibilityText": "Canon Medical Systems ANZ Pty Limited",
                "$recipeTypes": [
                    "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                ],
                "$type": "com.linkedin.voyager.dash.common.image.ImageViewModel"
            },
            "secondarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "11K followers",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "navigationUrl": "https://www.linkedin.com/company/canonmedicalanz/",
            "entityEmbeddedObject": null,
            "unreadIndicatorDetails": null,
            "$recipeTypes": [
                "com.linkedin.cf4b25c18907ea8eafe915c8bfa24109"
            ],
            "target": null,
            "$type": "com.linkedin.voyager.dash.search.EntityResultViewModel",
            "actorTrackingUrn": null,
            "navigationContext": {
                "openExternally": false,
                "$recipeTypes": [
                    "com.linkedin.55ee9afd4182671fe7e271f615659525"
                ],
                "url": "https://www.linkedin.com/company/canonmedicalanz/",
                "$type": "com.linkedin.voyager.dash.search.NavigationContext"
            }
        },
        {
            "template": "UNIVERSAL",
            "actorNavigationContext": null,
            "bserpEntityNavigationalUrl": "https://www.linkedin.com/search/results/all/?keywords=Medical%20on%20Burleigh&origin=ENTITY_SEARCH_HOME_HISTORY&heroEntityKey=urn%3Ali%3Aorganization%3A74884576",
            "trackingUrn": "urn:li:company:74884576",
            "controlName": null,
            "interstitialComponent": null,
            "primaryActions": [],
            "entityCustomTrackingInfo": null,
            "badgeData": null,
            "title": {
                "textDirection": "USER_LOCALE",
                "text": "Medical on Burleigh",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "overflowActions": [],
            "*lazyLoadedActions": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:74884576,COMPANIES,SEARCH_SRP)",
            "searchActionType": null,
            "actorInsights": [],
            "insightsResolutionResults": [],
            "badgeIcon": null,
            "entityUrn": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:74884576,SEARCH_SRP,DEFAULT)",
            "showAdditionalCluster": false,
            "ringStatus": null,
            "primarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "Medical Practices • Burleigh Heads, Queensland",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "badgeText": null,
            "trackingId": "gkQrpjQQToekdiy/HBjCnQ==",
            "summary": {
                "textDirection": "USER_LOCALE",
                "text": "The next jewel in the crown of the ‘Medical on’ series, has brought to the community, Medical on Burleigh. A place of distinction for practitioners to enjoy the place they practice and share it with our community.",
                "attributesV2": [
                    {
                        "start": 36,
                        "length": 7,
                        "detailData": {
                            "jobPostingName": null,
                            "hyperlink": null,
                            "profileFamiliarName": null,
                            "color": null,
                            "companyName": null,
                            "icon": null,
                            "epoch": null,
                            "systemImage": null,
                            "textLink": null,
                            "listItemStyle": null,
                            "groupName": null,
                            "hyperlinkOpenExternally": null,
                            "listStyle": null,
                            "profileFullName": null,
                            "stringFieldReference": null,
                            "learningCourseName": null,
                            "profileMention": null,
                            "style": "BOLD",
                            "schoolName": null,
                            "hashtag": null
                        },
                        "$recipeTypes": [
                            "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                        ],
                        "$type": "com.linkedin.voyager.dash.common.text.TextAttribute"
                    },
                    {
                        "start": 86,
                        "length": 7,
                        "detailData": {
                            "jobPostingName": null,
                            "hyperlink": null,
                            "profileFamiliarName": null,
                            "color": null,
                            "companyName": null,
                            "icon": null,
                            "epoch": null,
                            "systemImage": null,
                            "textLink": null,
                            "listItemStyle": null,
                            "groupName": null,
                            "hyperlinkOpenExternally": null,
                            "listStyle": null,
                            "profileFullName": null,
                            "stringFieldReference": null,
                            "learningCourseName": null,
                            "profileMention": null,
                            "style": "BOLD",
                            "schoolName": null,
                            "hashtag": null
                        },
                        "$recipeTypes": [
                            "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                        ],
                        "$type": "com.linkedin.voyager.dash.common.text.TextAttribute"
                    }
                ],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "addEntityToSearchHistory": true,
            "actorNavigationUrl": null,
            "image": {
                "attributes": [
                    {
                        "scalingType": null,
                        "detailData": {
                            "profilePictureWithoutFrame": null,
                            "profilePictureWithRingStatus": null,
                            "companyLogo": null,
                            "icon": null,
                            "systemImage": null,
                            "nonEntityGroupLogo": null,
                            "vectorImage": null,
                            "nonEntityProfessionalEventLogo": null,
                            "profilePicture": null,
                            "imageUrl": null,
                            "professionalEventLogo": null,
                            "nonEntityCompanyLogo": {
                                "*company": "urn:li:fsd_company:74884576",
                                "$recipeTypes": [
                                    "com.linkedin.3be27b5a0eb7edd91e98b14c0290096c"
                                ],
                                "vectorImage": {
                                    "digitalmediaAsset": null,
                                    "attribution": null,
                                    "c2paManifestData": null,
                                    "$recipeTypes": [
                                        "com.linkedin.28db8575bcf1c65bdc4bc15948d50ee9"
                                    ],
                                    "artifacts": [
                                        {
                                            "width": 100,
                                            "$recipeTypes": [
                                                "com.linkedin.f0f435b4425ee2990eba8f0a4d614944"
                                            ],
                                            "fileIdentifyingUrlPathSegment": "https://media.licdn.com/dms/image/v2/C560BAQHFybEwNZEkAA/company-logo_100_100/company-logo_100_100/0/1649424116119?e=1769644800&v=beta&t=kN-M9FXVJs4lbSqJPHKDUvQttef34fHaNdaJI-B7jL0",
                                            "expiresAt": 1769644800000,
                                            "height": 100,
                                            "$type": "com.linkedin.common.VectorArtifact"
                                        }
                                    ],
                                    "rootUrl": "",
                                    "$type": "com.linkedin.common.VectorImage"
                                },
                                "$type": "com.linkedin.voyager.dash.common.image.NonEntityCompanyLogo"
                            },
                            "nonEntitySchoolLogo": null,
                            "groupLogo": null,
                            "schoolLogo": null,
                            "ghostImage": null,
                            "nonEntityProfilePicture": null
                        },
                        "tintColor": null,
                        "$recipeTypes": [
                            "com.linkedin.eb94fbb1518f790c4545aafdf571c64e"
                        ],
                        "tapTargets": [],
                        "displayAspectRatio": null,
                        "$type": "com.linkedin.voyager.dash.common.image.ImageAttribute"
                    }
                ],
                "editableAccessibilityText": false,
                "actionTarget": null,
                "accessibilityTextAttributes": [],
                "totalCount": null,
                "accessibilityText": "Medical on Burleigh",
                "$recipeTypes": [
                    "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                ],
                "$type": "com.linkedin.voyager.dash.common.image.ImageViewModel"
            },
            "secondarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "135 followers",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "navigationUrl": "https://www.linkedin.com/company/medical-on-burleigh/",
            "entityEmbeddedObject": null,
            "unreadIndicatorDetails": null,
            "$recipeTypes": [
                "com.linkedin.cf4b25c18907ea8eafe915c8bfa24109"
            ],
            "target": null,
            "$type": "com.linkedin.voyager.dash.search.EntityResultViewModel",
            "actorTrackingUrn": null,
            "navigationContext": {
                "openExternally": false,
                "$recipeTypes": [
                    "com.linkedin.55ee9afd4182671fe7e271f615659525"
                ],
                "url": "https://www.linkedin.com/company/medical-on-burleigh/",
                "$type": "com.linkedin.voyager.dash.search.NavigationContext"
            }
        },
        {
            "template": "UNIVERSAL",
            "actorNavigationContext": null,
            "bserpEntityNavigationalUrl": "https://www.linkedin.com/search/results/all/?keywords=Medical%20Hub%20%40RMIT&origin=ENTITY_SEARCH_HOME_HISTORY&heroEntityKey=urn%3Ali%3Aorganization%3A40674246",
            "trackingUrn": "urn:li:company:40674246",
            "controlName": null,
            "interstitialComponent": null,
            "primaryActions": [],
            "entityCustomTrackingInfo": null,
            "badgeData": null,
            "title": {
                "textDirection": "USER_LOCALE",
                "text": "Medical Hub @RMIT",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "overflowActions": [],
            "*lazyLoadedActions": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:40674246,COMPANIES,SEARCH_SRP)",
            "searchActionType": null,
            "actorInsights": [],
            "insightsResolutionResults": [],
            "badgeIcon": null,
            "entityUrn": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:40674246,SEARCH_SRP,DEFAULT)",
            "showAdditionalCluster": false,
            "ringStatus": null,
            "primarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "Medical Practices • Melbourne, Victoria",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "badgeText": null,
            "trackingId": "NK1zJKHlToOsEP6VR2IC4g==",
            "summary": {
                "textDirection": "USER_LOCALE",
                "text": "Medical Hub @ RMIT opening soon!",
                "attributesV2": [
                    {
                        "start": 0,
                        "length": 7,
                        "detailData": {
                            "jobPostingName": null,
                            "hyperlink": null,
                            "profileFamiliarName": null,
                            "color": null,
                            "companyName": null,
                            "icon": null,
                            "epoch": null,
                            "systemImage": null,
                            "textLink": null,
                            "listItemStyle": null,
                            "groupName": null,
                            "hyperlinkOpenExternally": null,
                            "listStyle": null,
                            "profileFullName": null,
                            "stringFieldReference": null,
                            "learningCourseName": null,
                            "profileMention": null,
                            "style": "BOLD",
                            "schoolName": null,
                            "hashtag": null
                        },
                        "$recipeTypes": [
                            "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                        ],
                        "$type": "com.linkedin.voyager.dash.common.text.TextAttribute"
                    }
                ],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "addEntityToSearchHistory": true,
            "actorNavigationUrl": null,
            "image": {
                "attributes": [
                    {
                        "scalingType": null,
                        "detailData": {
                            "profilePictureWithoutFrame": null,
                            "profilePictureWithRingStatus": null,
                            "companyLogo": null,
                            "icon": null,
                            "systemImage": null,
                            "nonEntityGroupLogo": null,
                            "vectorImage": null,
                            "nonEntityProfessionalEventLogo": null,
                            "profilePicture": null,
                            "imageUrl": null,
                            "professionalEventLogo": null,
                            "nonEntityCompanyLogo": {
                                "*company": "urn:li:fsd_company:40674246",
                                "$recipeTypes": [
                                    "com.linkedin.3be27b5a0eb7edd91e98b14c0290096c"
                                ],
                                "vectorImage": {
                                    "digitalmediaAsset": null,
                                    "attribution": null,
                                    "c2paManifestData": null,
                                    "$recipeTypes": [
                                        "com.linkedin.28db8575bcf1c65bdc4bc15948d50ee9"
                                    ],
                                    "artifacts": [
                                        {
                                            "width": 100,
                                            "$recipeTypes": [
                                                "com.linkedin.f0f435b4425ee2990eba8f0a4d614944"
                                            ],
                                            "fileIdentifyingUrlPathSegment": "https://media.licdn.com/dms/image/v2/C4E0BAQEaxcS1Gq78aA/company-logo_100_100/company-logo_100_100/0/1630563420153?e=1769644800&v=beta&t=YqLhpZt8tvtMAL4yYsD8IOLAsP_uazkBj0pL7mzAY50",
                                            "expiresAt": 1769644800000,
                                            "height": 100,
                                            "$type": "com.linkedin.common.VectorArtifact"
                                        }
                                    ],
                                    "rootUrl": "",
                                    "$type": "com.linkedin.common.VectorImage"
                                },
                                "$type": "com.linkedin.voyager.dash.common.image.NonEntityCompanyLogo"
                            },
                            "nonEntitySchoolLogo": null,
                            "groupLogo": null,
                            "schoolLogo": null,
                            "ghostImage": null,
                            "nonEntityProfilePicture": null
                        },
                        "tintColor": null,
                        "$recipeTypes": [
                            "com.linkedin.eb94fbb1518f790c4545aafdf571c64e"
                        ],
                        "tapTargets": [],
                        "displayAspectRatio": null,
                        "$type": "com.linkedin.voyager.dash.common.image.ImageAttribute"
                    }
                ],
                "editableAccessibilityText": false,
                "actionTarget": null,
                "accessibilityTextAttributes": [],
                "totalCount": null,
                "accessibilityText": "Medical Hub @RMIT",
                "$recipeTypes": [
                    "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                ],
                "$type": "com.linkedin.voyager.dash.common.image.ImageViewModel"
            },
            "secondarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "121 followers",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "navigationUrl": "https://www.linkedin.com/company/medical-hub-rmit/",
            "entityEmbeddedObject": null,
            "unreadIndicatorDetails": null,
            "$recipeTypes": [
                "com.linkedin.cf4b25c18907ea8eafe915c8bfa24109"
            ],
            "target": null,
            "$type": "com.linkedin.voyager.dash.search.EntityResultViewModel",
            "actorTrackingUrn": null,
            "navigationContext": {
                "openExternally": false,
                "$recipeTypes": [
                    "com.linkedin.55ee9afd4182671fe7e271f615659525"
                ],
                "url": "https://www.linkedin.com/company/medical-hub-rmit/",
                "$type": "com.linkedin.voyager.dash.search.NavigationContext"
            }
        },
        {
            "template": "UNIVERSAL",
            "actorNavigationContext": null,
            "bserpEntityNavigationalUrl": "https://www.linkedin.com/search/results/all/?keywords=Multigate%20Medical%20Products%20Pty%20Ltd&origin=ENTITY_SEARCH_HOME_HISTORY&heroEntityKey=urn%3Ali%3Aorganization%3A3317828",
            "trackingUrn": "urn:li:company:3317828",
            "controlName": null,
            "interstitialComponent": null,
            "primaryActions": [],
            "entityCustomTrackingInfo": null,
            "badgeData": null,
            "title": {
                "textDirection": "USER_LOCALE",
                "text": "Multigate Medical Products Pty Ltd",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "overflowActions": [],
            "*lazyLoadedActions": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:3317828,COMPANIES,SEARCH_SRP)",
            "searchActionType": null,
            "actorInsights": [],
            "insightsResolutionResults": [],
            "badgeIcon": null,
            "entityUrn": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:3317828,SEARCH_SRP,DEFAULT)",
            "showAdditionalCluster": false,
            "ringStatus": null,
            "primarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "Medical Device • Villawood, NSW",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "badgeText": null,
            "trackingId": "g5gUY8bzR8efeJj8UAG3VQ==",
            "summary": {
                "textDirection": "USER_LOCALE",
                "text": "Multigate Medical Products Pty Ltd is a privately owned Australian company, established in 1986 and employing approx 500 staff in Australia and New Zealand. We are the largest supplier of Custom Procedure Packs (CPP) and a leading supplier of Single Use Medical and Surgical Consumables to Australian public and private...",
                "attributesV2": [
                    {
                        "start": 10,
                        "length": 7,
                        "detailData": {
                            "jobPostingName": null,
                            "hyperlink": null,
                            "profileFamiliarName": null,
                            "color": null,
                            "companyName": null,
                            "icon": null,
                            "epoch": null,
                            "systemImage": null,
                            "textLink": null,
                            "listItemStyle": null,
                            "groupName": null,
                            "hyperlinkOpenExternally": null,
                            "listStyle": null,
                            "profileFullName": null,
                            "stringFieldReference": null,
                            "learningCourseName": null,
                            "profileMention": null,
                            "style": "BOLD",
                            "schoolName": null,
                            "hashtag": null
                        },
                        "$recipeTypes": [
                            "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                        ],
                        "$type": "com.linkedin.voyager.dash.common.text.TextAttribute"
                    },
                    {
                        "start": 254,
                        "length": 7,
                        "detailData": {
                            "jobPostingName": null,
                            "hyperlink": null,
                            "profileFamiliarName": null,
                            "color": null,
                            "companyName": null,
                            "icon": null,
                            "epoch": null,
                            "systemImage": null,
                            "textLink": null,
                            "listItemStyle": null,
                            "groupName": null,
                            "hyperlinkOpenExternally": null,
                            "listStyle": null,
                            "profileFullName": null,
                            "stringFieldReference": null,
                            "learningCourseName": null,
                            "profileMention": null,
                            "style": "BOLD",
                            "schoolName": null,
                            "hashtag": null
                        },
                        "$recipeTypes": [
                            "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                        ],
                        "$type": "com.linkedin.voyager.dash.common.text.TextAttribute"
                    }
                ],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "addEntityToSearchHistory": true,
            "actorNavigationUrl": null,
            "image": {
                "attributes": [
                    {
                        "scalingType": null,
                        "detailData": {
                            "profilePictureWithoutFrame": null,
                            "profilePictureWithRingStatus": null,
                            "companyLogo": null,
                            "icon": null,
                            "systemImage": null,
                            "nonEntityGroupLogo": null,
                            "vectorImage": null,
                            "nonEntityProfessionalEventLogo": null,
                            "profilePicture": null,
                            "imageUrl": null,
                            "professionalEventLogo": null,
                            "nonEntityCompanyLogo": {
                                "*company": "urn:li:fsd_company:3317828",
                                "$recipeTypes": [
                                    "com.linkedin.3be27b5a0eb7edd91e98b14c0290096c"
                                ],
                                "vectorImage": {
                                    "digitalmediaAsset": null,
                                    "attribution": null,
                                    "c2paManifestData": null,
                                    "$recipeTypes": [
                                        "com.linkedin.28db8575bcf1c65bdc4bc15948d50ee9"
                                    ],
                                    "artifacts": [
                                        {
                                            "width": 100,
                                            "$recipeTypes": [
                                                "com.linkedin.f0f435b4425ee2990eba8f0a4d614944"
                                            ],
                                            "fileIdentifyingUrlPathSegment": "https://media.licdn.com/dms/image/v2/C4E0BAQH44Ferv0bl5g/company-logo_100_100/company-logo_100_100/0/1631311124020?e=1769644800&v=beta&t=cOq6dXAcR-kBNkMHzPKxB-SvVD2FP6fAt1yF1ueOMOA",
                                            "expiresAt": 1769644800000,
                                            "height": 100,
                                            "$type": "com.linkedin.common.VectorArtifact"
                                        }
                                    ],
                                    "rootUrl": "",
                                    "$type": "com.linkedin.common.VectorImage"
                                },
                                "$type": "com.linkedin.voyager.dash.common.image.NonEntityCompanyLogo"
                            },
                            "nonEntitySchoolLogo": null,
                            "groupLogo": null,
                            "schoolLogo": null,
                            "ghostImage": null,
                            "nonEntityProfilePicture": null
                        },
                        "tintColor": null,
                        "$recipeTypes": [
                            "com.linkedin.eb94fbb1518f790c4545aafdf571c64e"
                        ],
                        "tapTargets": [],
                        "displayAspectRatio": null,
                        "$type": "com.linkedin.voyager.dash.common.image.ImageAttribute"
                    }
                ],
                "editableAccessibilityText": false,
                "actionTarget": null,
                "accessibilityTextAttributes": [],
                "totalCount": null,
                "accessibilityText": "Multigate Medical Products Pty Ltd",
                "$recipeTypes": [
                    "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                ],
                "$type": "com.linkedin.voyager.dash.common.image.ImageViewModel"
            },
            "secondarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "3K followers",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "navigationUrl": "https://www.linkedin.com/company/multigate-medical-products-pty-ltd/",
            "entityEmbeddedObject": null,
            "unreadIndicatorDetails": null,
            "$recipeTypes": [
                "com.linkedin.cf4b25c18907ea8eafe915c8bfa24109"
            ],
            "target": null,
            "$type": "com.linkedin.voyager.dash.search.EntityResultViewModel",
            "actorTrackingUrn": null,
            "navigationContext": {
                "openExternally": false,
                "$recipeTypes": [
                    "com.linkedin.55ee9afd4182671fe7e271f615659525"
                ],
                "url": "https://www.linkedin.com/company/multigate-medical-products-pty-ltd/",
                "$type": "com.linkedin.voyager.dash.search.NavigationContext"
            }
        },
        {
            "template": "UNIVERSAL",
            "actorNavigationContext": null,
            "bserpEntityNavigationalUrl": "https://www.linkedin.com/search/results/all/?keywords=IPN%20Medical%20Centres&origin=ENTITY_SEARCH_HOME_HISTORY&heroEntityKey=urn%3Ali%3Aorganization%3A437912",
            "trackingUrn": "urn:li:company:437912",
            "controlName": null,
            "interstitialComponent": null,
            "primaryActions": [],
            "entityCustomTrackingInfo": null,
            "badgeData": null,
            "title": {
                "textDirection": "USER_LOCALE",
                "text": "IPN Medical Centres",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "overflowActions": [],
            "*lazyLoadedActions": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:437912,COMPANIES,SEARCH_SRP)",
            "searchActionType": null,
            "actorInsights": [],
            "insightsResolutionResults": [],
            "badgeIcon": null,
            "entityUrn": "urn:li:fsd_entityResultViewModel:(urn:li:fsd_company:437912,SEARCH_SRP,DEFAULT)",
            "showAdditionalCluster": false,
            "ringStatus": null,
            "primarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "Medical Practices • Sydney, NSW",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "badgeText": null,
            "trackingId": "T3Bst3y8Stmr5znYW18Skg==",
            "summary": {
                "textDirection": "USER_LOCALE",
                "text": "At IPN, we are always looking for passionate and qualified general practitioners to join our dedicated collegiate network and independently provide quality healthcare to local communities right across Australia.  Operating over 150 medical centres, IPN is Australia’s largest clinic network and provider of quality...",
                "attributesV2": [
                    {
                        "start": 232,
                        "length": 7,
                        "detailData": {
                            "jobPostingName": null,
                            "hyperlink": null,
                            "profileFamiliarName": null,
                            "color": null,
                            "companyName": null,
                            "icon": null,
                            "epoch": null,
                            "systemImage": null,
                            "textLink": null,
                            "listItemStyle": null,
                            "groupName": null,
                            "hyperlinkOpenExternally": null,
                            "listStyle": null,
                            "profileFullName": null,
                            "stringFieldReference": null,
                            "learningCourseName": null,
                            "profileMention": null,
                            "style": "BOLD",
                            "schoolName": null,
                            "hashtag": null
                        },
                        "$recipeTypes": [
                            "com.linkedin.b8a09c2c7547138a1c3aebdda8a94e12"
                        ],
                        "$type": "com.linkedin.voyager.dash.common.text.TextAttribute"
                    }
                ],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "addEntityToSearchHistory": true,
            "actorNavigationUrl": null,
            "image": {
                "attributes": [
                    {
                        "scalingType": null,
                        "detailData": {
                            "profilePictureWithoutFrame": null,
                            "profilePictureWithRingStatus": null,
                            "companyLogo": null,
                            "icon": null,
                            "systemImage": null,
                            "nonEntityGroupLogo": null,
                            "vectorImage": null,
                            "nonEntityProfessionalEventLogo": null,
                            "profilePicture": null,
                            "imageUrl": null,
                            "professionalEventLogo": null,
                            "nonEntityCompanyLogo": {
                                "*company": "urn:li:fsd_company:437912",
                                "$recipeTypes": [
                                    "com.linkedin.3be27b5a0eb7edd91e98b14c0290096c"
                                ],
                                "vectorImage": {
                                    "digitalmediaAsset": null,
                                    "attribution": null,
                                    "c2paManifestData": null,
                                    "$recipeTypes": [
                                        "com.linkedin.28db8575bcf1c65bdc4bc15948d50ee9"
                                    ],
                                    "artifacts": [
                                        {
                                            "width": 100,
                                            "$recipeTypes": [
                                                "com.linkedin.f0f435b4425ee2990eba8f0a4d614944"
                                            ],
                                            "fileIdentifyingUrlPathSegment": "https://media.licdn.com/dms/image/v2/C4E0BAQEHXE1nP-8YPg/company-logo_100_100/company-logo_100_100/0/1631341528495?e=1769644800&v=beta&t=qdqOeCSqiuy7SOtFozPs9hfoNR6siBP3WfiuP0Tq_4k",
                                            "expiresAt": 1769644800000,
                                            "height": 100,
                                            "$type": "com.linkedin.common.VectorArtifact"
                                        }
                                    ],
                                    "rootUrl": "",
                                    "$type": "com.linkedin.common.VectorImage"
                                },
                                "$type": "com.linkedin.voyager.dash.common.image.NonEntityCompanyLogo"
                            },
                            "nonEntitySchoolLogo": null,
                            "groupLogo": null,
                            "schoolLogo": null,
                            "ghostImage": null,
                            "nonEntityProfilePicture": null
                        },
                        "tintColor": null,
                        "$recipeTypes": [
                            "com.linkedin.eb94fbb1518f790c4545aafdf571c64e"
                        ],
                        "tapTargets": [],
                        "displayAspectRatio": null,
                        "$type": "com.linkedin.voyager.dash.common.image.ImageAttribute"
                    }
                ],
                "editableAccessibilityText": false,
                "actionTarget": null,
                "accessibilityTextAttributes": [],
                "totalCount": null,
                "accessibilityText": "IPN Medical Centres",
                "$recipeTypes": [
                    "com.linkedin.fe5b8a3ac5a4a165c17f53b7eae4209b"
                ],
                "$type": "com.linkedin.voyager.dash.common.image.ImageViewModel"
            },
            "secondarySubtitle": {
                "textDirection": "USER_LOCALE",
                "text": "7K followers",
                "attributesV2": [],
                "accessibilityTextAttributesV2": [],
                "accessibilityText": null,
                "$recipeTypes": [
                    "com.linkedin.6a224ca38654a84754a1eb3e97c0f846"
                ],
                "$type": "com.linkedin.voyager.dash.common.text.TextViewModel"
            },
            "navigationUrl": "https://www.linkedin.com/company/independent-practitioner-network/",
            "entityEmbeddedObject": null,
            "unreadIndicatorDetails": null,
            "$recipeTypes": [
                "com.linkedin.cf4b25c18907ea8eafe915c8bfa24109"
            ],
            "target": null,
            "$type": "com.linkedin.voyager.dash.search.EntityResultViewModel",
            "actorTrackingUrn": null,
            "navigationContext": {
                "openExternally": false,
                "$recipeTypes": [
                    "com.linkedin.55ee9afd4182671fe7e271f615659525"
                ],
                "url": "https://www.linkedin.com/company/independent-practitioner-network/",
                "$type": "com.linkedin.voyager.dash.search.NavigationContext"
            }
        },
        {
            "entityUrn": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:18652742,COMPANIES,SEARCH_SRP)",
            "$recipeTypes": [
                "com.linkedin.92ece182782ae4412e712925cd97f9fe"
            ],
            "$type": "com.linkedin.voyager.dash.search.LazyLoadedActions"
        },
        {
            "entityUrn": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:18733434,COMPANIES,SEARCH_SRP)",
            "$recipeTypes": [
                "com.linkedin.92ece182782ae4412e712925cd97f9fe"
            ],
            "$type": "com.linkedin.voyager.dash.search.LazyLoadedActions"
        },
        {
            "entityUrn": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:12590830,COMPANIES,SEARCH_SRP)",
            "$recipeTypes": [
                "com.linkedin.92ece182782ae4412e712925cd97f9fe"
            ],
            "$type": "com.linkedin.voyager.dash.search.LazyLoadedActions"
        },
        {
            "entityUrn": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:6346618,COMPANIES,SEARCH_SRP)",
            "$recipeTypes": [
                "com.linkedin.92ece182782ae4412e712925cd97f9fe"
            ],
            "$type": "com.linkedin.voyager.dash.search.LazyLoadedActions"
        },
        {
            "entityUrn": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:437912,COMPANIES,SEARCH_SRP)",
            "$recipeTypes": [
                "com.linkedin.92ece182782ae4412e712925cd97f9fe"
            ],
            "$type": "com.linkedin.voyager.dash.search.LazyLoadedActions"
        },
        {
            "entityUrn": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:27182818,COMPANIES,SEARCH_SRP)",
            "$recipeTypes": [
                "com.linkedin.92ece182782ae4412e712925cd97f9fe"
            ],
            "$type": "com.linkedin.voyager.dash.search.LazyLoadedActions"
        },
        {
            "entityUrn": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:74884576,COMPANIES,SEARCH_SRP)",
            "$recipeTypes": [
                "com.linkedin.92ece182782ae4412e712925cd97f9fe"
            ],
            "$type": "com.linkedin.voyager.dash.search.LazyLoadedActions"
        },
        {
            "entityUrn": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:3317828,COMPANIES,SEARCH_SRP)",
            "$recipeTypes": [
                "com.linkedin.92ece182782ae4412e712925cd97f9fe"
            ],
            "$type": "com.linkedin.voyager.dash.search.LazyLoadedActions"
        },
        {
            "entityUrn": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:134456,COMPANIES,SEARCH_SRP)",
            "$recipeTypes": [
                "com.linkedin.92ece182782ae4412e712925cd97f9fe"
            ],
            "$type": "com.linkedin.voyager.dash.search.LazyLoadedActions"
        },
        {
            "entityUrn": "urn:li:fsd_lazyLoadedActions:(urn:li:fsd_company:40674246,COMPANIES,SEARCH_SRP)",
            "$recipeTypes": [
                "com.linkedin.92ece182782ae4412e712925cd97f9fe"
            ],
            "$type": "com.linkedin.voyager.dash.search.LazyLoadedActions"
        }
    ]
},


]

# %%
import requests
headers = {
    "accept": "application/vnd.linkedin.normalized+json+2.1",
    "accept-encoding": "gzip, deflate, br, zstd",
    "accept-language": "en-US,en;q=0.9,id;q=0.8,fa;q=0.7,ar;q=0.6,ms;q=0.5,ja;q=0.4,es;q=0.3",
    "cookie": 'bcookie="v=2&e6911dbb-f554-4382-8632-6a208824379f"; bscookie="v=1&202601120702493fd6db80-8392-43e7-8c08-6cc1c54b8e2cAQHrNBZvwOcfuWBqBYmDIDorKu_EwklO"; li_rm=AQGMWJg1jKl9hAAAAZuxBCJxZ3DSv9GOME_Ro_onvvVMx5o46EdgBYMjFQ8IxfuGg5J7m17fCw-GPQmqF0zxiBGSeiAso1X3rHOLafSG4gtmYIFWnUArRzbBEDBwlU-k2Ks8GFL7aeC4go9H64VR1uA6AkLa7VFyUr3jqjZZ0wyveAQEkkZqsadVlGKe6S53WJYTpUzwxNU87obEPbxDttEECoBvWyPpmUgvQjIhlsacuSAeyo5eqqdMg3Brm9Jp96aTVA0U4OVHv-XHb9VLR0KfY32P3toxarryZ9339OrWOey9dWeDY5CpEMAF9Dl2EAPoIVwhwBpo8zNNOwC8dA; li_at=AQEDAS6WHA8CyJ6mAAABm7EEIjcAAAGb1RCmN1YAVEpBs14b17p9_HOspLo2ZIoAXEd7wLmw_FGiAbb-4lYai1_S5P47S4qnffKOEmMFHCALFLhlde68PvU_Zjwu1zm7IrWu5RZfoqN3irZ-rGTrvRjJ; liap=true; JSESSIONID="ajax:5256081897796009679"; timezone=Asia/Shanghai; li_theme=light; li_theme_set=app; dfpfpt=1b7fdb9b01834269ae0393c3e5f1bc8c; lang=v=2&lang=en-us; lidc="b=OB19:s=O:r=O:a=O:p=O:g=4258:u=772:x=1:i=1768226975:t=1768306621:v=2:sig=AQHH9mCfoN3y2DAQW3cD4YOI_eO6npSX"; __cf_bm=p0jW3bLsKpzzbWiE4lzie_RkYJAdFA2QBk_R9.8Zzqk-1768226976-1.0.1.1-zhDagI9l1uvtrHh5VUnCoN7lWv4pinV4KGADzFYnRltu7yzi6sfOJDYNMNYuAm0TaHqlAD3otjgUThKEwzbHr7GcyCBV67.FAAcyqQT0Ca8; UserMatchHistory=AQIHkYS4L2NTHAAAAZuyituVe1076jZac4GgVvCEfvqUAA0YD7iwfFOlL8-W2ypA7Cb6Q7j_ecc6VD9H8uCTsNDIi12OUoTPXcVwiJ9ojAyiqIjM8B_rZlVcz7WkYF0R7E27l27ymCV7BkpLHgTEG58rijNkzQIpQ6MYsdOtXD5hDasqkL0I3tcjtnQBw9lOG6xvRQK1WLIgqHX55sr8jLNbHB5ETjfyPs4ZLfLp3XD_c9jsh7lR3YAJCKZIq9k2nAHQmoQq7b_k130XSc3DtDXDT5aXaXzjVVY443sdoH6-KX8_nbqV2oxrfzYsSndhGSS6ZddhBWw8B4dFKdXj; AMCVS_14215E3D5995C57C0A495C55%40AdobeOrg=1; AMCV_14215E3D5995C57C0A495C55%40AdobeOrg=-637568504%7CMCIDTS%7C20466%7CMCMID%7C88876232111397671427173994472428980681%7CMCOPTOUT-1768234228s%7CNONE%7CvVersion%7C5.1.1',
    "csrf-token": "ajax:5256081897796009679",
    "priority": "u=1, i",
    "referer": "https://www.linkedin.com/search/results/companies/?companyHqGeo=%5B%22101452733%22%5D&industryCompanyVertical=%5B%2213%22%2C%2217%22%2C%222069%22%5D&keywords=medical&origin=FACETED_SEARCH&page=1&sid=vit",
    "sec-ch-prefers-color-scheme": "light",
    "sec-ch-ua": '"Microsoft Edge";v="143", "Chromium";v="143", "Not A(Brand";v="24"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": "Windows",
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-origin",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/143.0.0.0 Safari/537.36 Edg/143.0.0.0",
    "x-li-lang": "en_US",
    "x-li-page-instance": "urn:li:page:d_flagship3_search_srp_companies_load_more;ZqWn90dvTcGPRyjHHF5LlA==",
    "x-li-pem-metadata": "Voyager - Companies SRP=search-results",
    "x-li-track": '{"clientVersion":"1.13.41887","mpVersion":"1.13.41887","osName":"web","timezoneOffset":8,"timezone":"Asia/Shanghai","deviceFormFactor":"DESKTOP","mpName":"voyager-web","displayDensity":1,"displayWidth":1366,"displayHeight":768}',
    "x-restli-protocol-version": "2.0.0"
}
url = "https://www.linkedin.com/voyager/api/graphql?variables=(start:10,origin:FACETED_SEARCH,query:(keywords:medical,flagshipSearchIntent:SEARCH_SRP,queryParameters:List((key:companyHqGeo,value:List(101452733)),(key:industryCompanyVertical,value:List(13,17,2069)),(key:resultType,value:List(COMPANIES))),includeFiltersInResponse:false))&queryId=voyagerSearchDashClusters.ef3d0937fb65bd7812e32e5a85028e79"
res = requests.get(url, headers=headers)
res
# Out:
# <Response [200]>

# %%
res.json()
# Out:
# {'data': {'data': {'searchDashClustersByAll': {'metadata': {'entityResultAttributes': None,
#      'bserpPaginationContext': None,
#      'totalResultCount': 5032,
#      'searchAlert': None,
#      'blockedQueryError': None,
#      'secondaryFilterCluster': None,
#      '$recipeTypes': ['com.linkedin.dfce49e2c6bb412fb4161cbbc7190d0d'],
#      'lazyRightRail': None,
#      'queryType': None,
#      '$type': 'com.linkedin.voyager.dash.search.SearchClusterCollectionMetadata',
#      'primaryResultType': 'COMPANIES',
#      'paginationToken': None,
#      'primaryFilterCluster': None,
#      'blockedQuery': False,
#      'entityActionButtonStyle': None,
#      'searchId': '74caeb05-ca70-4bc6-b15a-5f2839c4ce06',
#      'filterAppliedCount': 0,
#      'clusterTitleFontSize': None,
#      'simpleInsightAttributes': None,
#      'desktopNavigationPanelTrackingId': None,
#      'knowledgeCardRightRail': None},
#     'paging': {'count': 10,
#      'start': 10,
#      'total': 1000,
# ...
