# %%
import re
import requests

def validate_api_key(api_key):
    payload = {
        'api_key': api_key,
        'url': 'https://httpbin.org/ip'
    }
    r = requests.get('https://api.scraperapi.com', params=payload)
    if r.status_code != 200:
        return False
    return True

def find_api_keys(text):
    pattern = r'\b[a-f0-9]{32}\b'
    api_keys = re.findall(pattern, text)
    return set(list(api_keys))

# %%
url = "https://www.mercadolibre.com.ar/#from=homecom"
payload = {
    'api_key': '1f7befa6374a1d3832ce47ff2ddc44c7',
    'url': url
}
r = requests.get('https://api.scraperapi.com', params=payload)
r.text
# Out:
# 'You have exhausted the API Credits available in this monthly cycle. You can upgrade your subscription or enable overages from your dashboard (https://dashboard.scraperapi.com/billing). For custom plan upgrades, please contact support (https://www.scraperapi.com/support/).'

# %%
my_text = r"""

"""

api_keys = find_api_keys(my_text)
print(f"Found api keys: {len(api_keys)}")

for key in api_keys:
    is_valid = validate_api_key(key)
    if is_valid:
        print(key)
# Out:
# Found api keys: 2

# %%
import requests
proxies = {
"http": "http://scraperapi:3b5c821f62d1595c47a0277c0eedcaec@proxy-server.scraperapi.com:8001"
}
r = requests.get('http://httpbin.org/ip', proxies=proxies, verify=False)
print(r.text)
# Out:
# Unauthorized request, please make sure your API key is valid.
