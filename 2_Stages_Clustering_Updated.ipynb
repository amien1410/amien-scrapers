# %% [markdown]
# <a href="https://colab.research.google.com/github/amien1410/amien-scrapers/blob/main/2_Stages_Clustering_Updated.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install python-geohash
import geohash
import logging
import numpy as np
import pandas as pd
from tqdm import tqdm
import seaborn as sns
from datetime import datetime
import matplotlib.pyplot as plt
from dataclasses import dataclass
from sklearn.cluster import DBSCAN
from geopy.distance import geodesic
from typing import Optional, List, Dict, Union, Tuple
# Out:
# Collecting python-geohash
#   Downloading python-geohash-0.8.5.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: python-geohash
#   Building wheel for python-geohash (setup.py) ... done
#   Created wheel for python-geohash: filename=python_geohash-0.8.5-cp310-cp310-linux_x86_64.whl size=41538 sha256=3d8137d859e6a822ff5885f3df00ce36b20123d29011b3b1dd8e64a145a2ce4d
#   Stored in directory: /root/.cache/pip/wheels/19/e8/74/3f800ffdbb57c27a3fee3a695c7009769356448837c1f4f899
# Successfully built python-geohash
# Installing collected packages: python-geohash
# Successfully installed python-geohash-0.8.5

# %%
# @title
class TwoStageClustering:
    def __init__(self, eps: float = 50, min_samples: int = 10):
        """
        Initialize TwoStageClustering with DBSCAN parameters.
        """
        self.eps = eps / 6371000.0  # Convert meters to radians
        self.min_samples = min_samples
        self._setup_logging()

    def _setup_logging(self) -> None:
        """
        Configure logging for the clustering process.
        """
        logging.basicConfig(
            level=logging.INFO,
            format="%(asctime)s - %(levelname)s - %(message)s",
            force=True,
        )
        self.logger = logging.getLogger(__name__)

    def first_level_clustering(self, df: pd.DataFrame) -> pd.DataFrame:
        """
        Perform first-level clustering on individual vehicles.

        Args:
            df: Input dataframe containing stationary location data.

        Returns:
            Dataframe with first-level clustering results.
        """
        self.logger.info("Starting first-level clustering...")

        # Ensure sim_numbers is normalized (handle lists of identifiers)
        # df["sim_numbers"] = df["sim_numbers"].apply(
        #     lambda x: ast.literal_eval(x) if isinstance(x, str) and x.startswith("[") else x
        # )

        # # Extract the first element from the list to normalize sim_number
        # df["sim_number"] = df["sim_numbers"].apply(lambda x: x[0] if isinstance(x, list) else x)

        all_clusters = []

        for sim_number, group in df.groupby("sim_number"):
            coords = group[["latitude", "longitude"]].to_numpy()
            clustering = DBSCAN(
                eps=self.eps, min_samples=self.min_samples, metric="haversine"
            ).fit(np.radians(coords))

            group["first_level_cluster"] = clustering.labels_

            valid_clusters = group[group["first_level_cluster"] != -1]

            if not valid_clusters.empty:
                all_clusters.append(valid_clusters)
                self.logger.info(
                    f"Vehicle {sim_number}: Found "
                    f"{valid_clusters['first_level_cluster'].nunique()} clusters"
                )

        return pd.concat(all_clusters, ignore_index=True) if all_clusters else pd.DataFrame()

    def second_level_clustering(self, df: pd.DataFrame) -> pd.DataFrame:
        """
        Perform second-level clustering on centroids of first-level clusters.

        Args:
            df: Dataframe with first-level clustering results.

        Returns:
            Dataframe with second-level clustering results.
        """
        self.logger.info("Starting second-level clustering...")
        centroids = df.groupby(["sim_number", "first_level_cluster"]).agg(
            {"latitude": "mean", "longitude": "mean"}
        ).reset_index()

        coords = centroids[["latitude", "longitude"]].to_numpy()

        clustering = DBSCAN(
            eps=self.eps, min_samples=self.min_samples, metric="haversine"
        ).fit(np.radians(coords))

        centroids["second_level_cluster"] = clustering.labels_
        centroids = centroids[centroids["second_level_cluster"] != -1]
        centroids["cluster_id"] = [
            f"cluster_{i}" for i in range(len(centroids))
        ]  # Generate unique cluster IDs
        centroids["geohash"] = centroids.apply(
            lambda row: geohash.encode(row["latitude"], row["longitude"], precision=6),
            axis=1,
        )

        self.logger.info(
            f"Second-level clustering identified {centroids['second_level_cluster'].nunique()} clusters."
        )
        return centroids

    def process(self, df: pd.DataFrame) -> Tuple[pd.DataFrame, pd.DataFrame]:
        """
        Execute the two-stage clustering process.

        Args:
            df: Input dataframe containing stationary location data.

        Returns:
            Tuple of dataframes for first-level and second-level clustering results.
        """
        first_level_result = self.first_level_clustering(df)
        if first_level_result.empty:
            self.logger.warning("No clusters identified in the first-level clustering.")
            return pd.DataFrame(), pd.DataFrame()

        second_level_result = self.second_level_clustering(first_level_result)
        return first_level_result, second_level_result

# Load input data
df = pd.read_csv("cluster_df.csv")

# Initialize clustering process
clustering = TwoStageClustering(eps=50, min_samples=10)

# Perform clustering
first_level, second_level = clustering.process(df)

# Save and output results
if not first_level.empty:
    # first_level.to_csv("first_level_clustering.csv", index=False)
    print("First-level clustering results saved as 'first_level_clustering.csv'.")

if not second_level.empty:
    # second_level.to_csv("second_level_clustering.csv", index=False)
    print("Second-level clustering results saved as 'second_level_clustering.csv'.")

print("\nClustering process complete.")

# %%
import pandas as pd
import numpy as np
import logging
import geohash
from typing import Tuple, Optional
from sklearn.cluster import DBSCAN
import matplotlib.pyplot as plt
import seaborn as sns

class TwoStageClustering:
    def __init__(self,
                 first_level_eps: float = 50,
                 first_level_min_samples: int = 2,
                 second_level_eps: float = 150,
                 second_level_min_samples: int = 2):
        """
        Initialize TwoStageClustering with configurable DBSCAN parameters.

        Args:
            first_level_eps: Maximum distance (in meters) for first-level clustering
            first_level_min_samples: Minimum number of samples to form a cluster in first-level clustering
            second_level_eps: Maximum distance (in meters) for second-level clustering
            second_level_min_samples: Minimum number of samples to form a cluster in second-level clustering
        """
        # Convert meters to radians (Earth's radius)
        self.first_level_eps = first_level_eps / 6371000.0
        self.first_level_min_samples = first_level_min_samples
        self.second_level_eps = second_level_eps / 6371000.0
        self.second_level_min_samples = second_level_min_samples

        self._setup_logging()

    def _setup_logging(self) -> None:
        """
        Configure logging for the clustering process.
        """
        logging.basicConfig(
            level=logging.INFO,
            format="%(asctime)s - %(levelname)s - %(message)s",
            force=True
        )
        self.logger = logging.getLogger(__name__)

    def _normalize_coordinates(self, df: pd.DataFrame) -> pd.DataFrame:
        """
        Normalize and validate coordinate data.

        Args:
            df: Input dataframe with latitude and longitude columns

        Returns:
            Validated dataframe with cleaned coordinate data
        """
        # Remove rows with invalid or missing coordinates
        df = df.dropna(subset=['latitude', 'longitude'])

        # Optional: Add coordinate validation if needed
        df = df[
            (df['latitude'].between(-90, 90)) &
            (df['longitude'].between(-180, 180))
        ]

        return df

    def first_level_clustering(self, df: pd.DataFrame) -> pd.DataFrame:
        """
        Perform first-level clustering on individual vehicles.

        Args:
            df: Input dataframe containing stationary location data.

        Returns:
            Dataframe with first-level clustering results.
        """
        self.logger.info("Starting first-level clustering...")

        # Normalize coordinates
        df = self._normalize_coordinates(df)

        all_clusters = []

        for sim_number, group in df.groupby("sim_number"):
            coords = group[["latitude", "longitude"]].to_numpy()

            # Perform DBSCAN clustering
            clustering = DBSCAN(
                eps=self.first_level_eps,
                min_samples=self.first_level_min_samples,
                metric="haversine"
            ).fit(np.radians(coords))

            # Create first-level cluster labels
            group['first_level_cluster'] = clustering.labels_

            # Filter out noise points (label -1)
            valid_clusters = group[group['first_level_cluster'] != -1].copy()

            # Create unique cluster identifiers
            valid_clusters['first_level_cluster'] = (
                valid_clusters['sim_number'].astype(str) + '_' +
                valid_clusters['first_level_cluster'].astype(str)
            )

            if not valid_clusters.empty:
                # Calculate centroids for each first-level cluster
                centroids = valid_clusters.groupby('first_level_cluster').agg({
                    'latitude': 'mean',
                    'longitude': 'mean'
                }).reset_index()
                centroids.columns = ['first_level_cluster', 'centroid_latitude', 'centroid_longitude']

                # Merge centroids back to the original dataframe
                valid_clusters = valid_clusters.merge(
                    centroids, on='first_level_cluster', how='left'
                )

                all_clusters.append(valid_clusters)
                self.logger.info(
                    f"Vehicle {sim_number}: Found {valid_clusters['first_level_cluster'].nunique()} clusters"
                )

        return pd.concat(all_clusters, ignore_index=True) if all_clusters else pd.DataFrame()

    def second_level_clustering(self, df: pd.DataFrame) -> pd.DataFrame:
        """
        Perform second-level clustering on centroids of first-level clusters.

        Args:
            df: Dataframe with first-level clustering results.

        Returns:
            Dataframe with second-level clustering results.
        """
        self.logger.info("Starting second-level clustering...")

        # Extract centroids for second-level clustering
        centroids = df.groupby('first_level_cluster')[
            ['centroid_latitude', 'centroid_longitude']
        ].first().reset_index()

        coords = centroids[['centroid_latitude', 'centroid_longitude']].to_numpy()

        # Perform DBSCAN on centroids
        clustering = DBSCAN(
            eps=self.second_level_eps,
            min_samples=self.second_level_min_samples,
            metric="haversine"
        ).fit(np.radians(coords))

        centroids['second_level_cluster'] = clustering.labels_

        # Filter out noise points
        centroids = centroids[centroids['second_level_cluster'] != -1]

        # Generate unique geohashes for second-level clusters
        centroids['geohash'] = centroids.apply(
            lambda row: geohash.encode(
                row['centroid_latitude'],
                row['centroid_longitude'],
                precision=6
            ),
            axis=1
        )

        self.logger.info(
            f"Second-level clustering identified {centroids['second_level_cluster'].nunique()} clusters."
        )

        return centroids

    def visualize_first_level_clustering(self, df: pd.DataFrame) -> None:
        """
        Create a visualization of first-level clustering for each vehicle.

        Args:
            df: Dataframe with first-level clustering results
        """
        plt.figure(figsize=(15, 10))
        vehicles = df['sim_number'].unique()

        for i, vehicle in enumerate(vehicles, 1):
            plt.subplot(len(vehicles), 1, i)
            vehicle_data = df[df['sim_number'] == vehicle]

            sns.scatterplot(
                data=vehicle_data,
                x='longitude',
                y='latitude',
                hue='first_level_cluster',
                palette='deep'
            )
            plt.title(f'First-Level Clustering for Vehicle {vehicle}')
            plt.xlabel('Longitude')
            plt.ylabel('Latitude')

        plt.tight_layout()
        plt.savefig('first_level_clustering.png')
        plt.close()

    def visualize_second_level_clustering(self, first_level_df: pd.DataFrame, second_level_df: pd.DataFrame) -> None:
        """
        Create a visualization of second-level clustering of centroids.

        Args:
            first_level_df: Dataframe with first-level clustering results
            second_level_df: Dataframe with second-level clustering results
        """
        # Merge first-level centroids with second-level cluster labels
        centroids = first_level_df.groupby('first_level_cluster')[
            ['centroid_latitude', 'centroid_longitude']
        ].first().reset_index()

        centroids = centroids.merge(
            second_level_df[['first_level_cluster', 'second_level_cluster']],
            on='first_level_cluster',
            how='left'
        )

        plt.figure(figsize=(12, 8))
        sns.scatterplot(
            data=centroids,
            x='centroid_longitude',
            y='centroid_latitude',
            hue='second_level_cluster',
            palette='Set2'
        )
        plt.title('Second-Level Clustering of First-Level Cluster Centroids')
        plt.xlabel('Longitude')
        plt.ylabel('Latitude')
        plt.savefig('second_level_clustering.png')
        plt.close()

    def process(self, df: pd.DataFrame) -> Tuple[pd.DataFrame, Optional[pd.DataFrame]]:
        """
        Execute the two-stage clustering process.

        Args:
            df: Input dataframe containing stationary location data.

        Returns:
            Tuple of dataframes for first-level and second-level clustering results.
        """
        first_level_result = self.first_level_clustering(df)
        if first_level_result.empty:
            self.logger.warning("No clusters identified in the first-level clustering.")
            return pd.DataFrame(), None

        second_level_result = self.second_level_clustering(first_level_result)

        # Perform visualizations
        self.visualize_first_level_clustering(first_level_result)
        self.visualize_second_level_clustering(first_level_result, second_level_result)

        # Optional: Save results to CSV
        first_level_result.to_csv('first_level_clusters.csv', index=False)
        second_level_result.to_csv('second_level_clusters.csv', index=False)

        return first_level_result, second_level_result

def main():
    # Load input data
    df = pd.read_csv("/content/stationary_events_4mil_rows.csv")

    # Initialize clustering process with custom parameters
    clustering = TwoStageClustering(
        first_level_eps=50,      # 50 meters for first-level
        first_level_min_samples=10,
        second_level_eps=50,    # 50 meters for second-level
        second_level_min_samples=10
    )

    # Perform clustering
    first_level, second_level = clustering.process(df)

if __name__ == "__main__":
    main()
# Out:
# 2024-11-27 14:49:45,141 - INFO - Starting first-level clustering...
# 2024-11-27 14:49:45,286 - INFO - Vehicle 1: Found 1 clusters
# 2024-11-27 14:49:45,308 - INFO - Vehicle 4: Found 1 clusters
# 2024-11-27 14:49:45,320 - INFO - Vehicle 5: Found 1 clusters
# 2024-11-27 14:49:45,345 - INFO - Vehicle 9: Found 1 clusters
# 2024-11-27 14:49:45,368 - INFO - Vehicle 10: Found 1 clusters
# 2024-11-27 14:49:45,381 - INFO - Vehicle 11: Found 1 clusters
# 2024-11-27 14:49:45,394 - INFO - Vehicle 12: Found 1 clusters
# 2024-11-27 14:49:45,494 - INFO - Vehicle 19: Found 3 clusters
# 2024-11-27 14:49:45,507 - INFO - Vehicle 20: Found 2 clusters
# 2024-11-27 14:49:45,519 - INFO - Vehicle 21: Found 2 clusters
# 2024-11-27 14:49:45,542 - INFO - Vehicle 24: Found 2 clusters
# 2024-11-27 14:49:45,556 - INFO - Vehicle 25: Found 1 clusters
# 2024-11-27 14:49:45,570 - INFO - Vehicle 26: Found 1 clusters
# 2024-11-27 14:49:45,585 - INFO - Vehicle 27: Found 5 clusters
# 2024-11-27 14:49:45,600 - INFO - Vehicle 28: Found 9 clusters
# 2024-11-27 14:49:45,614 - INFO - Vehicle 29: Found 2 clusters
# 2024-11-27 14:49:45,626 - INFO - Vehicle 30: Found 1 clusters
# 2024-11-27 14:49:45,647 - INFO - Vehicle 33: Found 2 clusters
# 2024-11-27 14:49:45,677 - INFO - Vehicle 37: Found 1 clusters
# 2024-11-27 14:49:45,711 - INFO - Vehicle 43: Found 1 clusters
# 2024-11-27 14:49:45,738 - INFO - Vehicle 47: Found 2 clusters
# 2024-11-27 14:49:45,821 - INFO - Vehicle 57: Found 2 clusters
# 2024-11-27 14:49:45,839 - INFO - Vehicle 58: Found 3 clusters
# 2024-11-27 14:49:45,858 - INFO - Vehicle 59: Found 2 clusters
# 2024-11-27 14:49:45,886 - INFO - Vehicle 61: Found 1 clusters
# 2024-11-27 14:49:45,904 - INFO - Vehicle 62: Found 1 clusters
# 2024-11-27 14:49:45,922 - INFO - Vehicle 63: Found 2 clusters
# 2024-11-27 14:49:45,947 - INFO - Vehicle 65: Found 2 clusters
# 2024-11-27 14:49:45,982 - INFO - Vehicle 69: Found 2 clusters
# 2024-11-27 14:49:46,006 - INFO - Vehicle 71: Found 2 clusters
# 2024-11-27 14:49:46,024 - INFO - Vehicle 72: Found 2 clusters
# 2024-11-27 14:49:46,050 - INFO - Vehicle 75: Found 1 clusters
# 2024-11-27 14:49:46,065 - INFO - Vehicle 76: Found 1 clusters
# 2024-11-27 14:49:46,082 - INFO - Vehicle 77: Found 1 clusters
# 2024-11-27 14:49:46,100 - INFO - Vehicle 78: Found 2 clusters
# 2024-11-27 14:49:46,158 - INFO - Vehicle 84: Found 1 clusters
# 2024-11-27 14:49:46,176 - INFO - Vehicle 85: Found 1 clusters
# 2024-11-27 14:49:46,244 - INFO - Vehicle 90: Found 2 clusters
# 2024-11-27 14:49:46,267 - INFO - Vehicle 91: Found 1 clusters
# 2024-11-27 14:49:46,318 - INFO - Vehicle 95: Found 1 clusters
# 2024-11-27 14:49:46,335 - INFO - Vehicle 96: Found 1 clusters
# 2024-11-27 14:49:46,391 - INFO - Vehicle 101: Found 3 clusters
# 2024-11-27 14:49:46,471 - INFO - Vehicle 110: Found 1 clusters
# 2024-11-27 14:49:46,486 - INFO - Vehicle 111: Found 1 clusters
# 2024-11-27 14:49:46,501 - INFO - Vehicle 112: Found 1 clusters
# 2024-11-27 14:49:46,519 - INFO - Vehicle 113: Found 1 clusters
# 2024-11-27 14:49:46,537 - INFO - Vehicle 114: Found 1 clusters
# 2024-11-27 14:49:46,562 - INFO - Vehicle 116: Found 1 clusters
# 2024-11-27 14:49:46,592 - INFO - Vehicle 119: Found 3 clusters
# 2024-11-27 14:49:46,613 - INFO - Vehicle 121: Found 2 clusters
# 2024-11-27 14:49:46,628 - INFO - Vehicle 122: Found 1 clusters
# 2024-11-27 14:49:46,644 - INFO - Vehicle 123: Found 1 clusters
# 2024-11-27 14:49:46,671 - INFO - Vehicle 126: Found 2 clusters
# 2024-11-27 14:49:46,691 - INFO - Vehicle 128: Found 3 clusters
# 2024-11-27 14:49:46,732 - INFO - Vehicle 133: Found 5 clusters
# 2024-11-27 14:49:46,747 - INFO - Vehicle 134: Found 1 clusters
# 2024-11-27 14:49:46,766 - INFO - Vehicle 135: Found 3 clusters
# 2024-11-27 14:49:46,790 - INFO - Vehicle 137: Found 1 clusters
# 2024-11-27 14:49:46,805 - INFO - Vehicle 138: Found 1 clusters
# 2024-11-27 14:49:46,843 - INFO - Vehicle 143: Found 2 clusters
# 2024-11-27 14:49:46,866 - INFO - Vehicle 145: Found 1 clusters
# 2024-11-27 14:49:46,882 - INFO - Vehicle 146: Found 5 clusters
# 2024-11-27 14:49:46,897 - INFO - Vehicle 147: Found 1 clusters
# 2024-11-27 14:49:46,920 - INFO - Vehicle 149: Found 1 clusters
# 2024-11-27 14:49:46,965 - INFO - Vehicle 154: Found 1 clusters
# 2024-11-27 14:49:46,999 - INFO - Vehicle 156: Found 4 clusters
# 2024-11-27 14:49:47,018 - INFO - Vehicle 157: Found 1 clusters
# 2024-11-27 14:49:47,039 - INFO - Vehicle 158: Found 2 clusters
# 2024-11-27 14:49:47,056 - INFO - Vehicle 159: Found 1 clusters
# 2024-11-27 14:49:47,097 - INFO - Vehicle 164: Found 1 clusters
# 2024-11-27 14:49:47,116 - INFO - Vehicle 165: Found 1 clusters
# 2024-11-27 14:49:47,169 - INFO - Vehicle 170: Found 1 clusters
# 2024-11-27 14:49:47,189 - INFO - Vehicle 171: Found 1 clusters
# 2024-11-27 14:49:47,217 - INFO - Vehicle 173: Found 1 clusters
# 2024-11-27 14:49:47,283 - INFO - Vehicle 179: Found 2 clusters
# 2024-11-27 14:49:47,309 - INFO - Vehicle 180: Found 1 clusters
# 2024-11-27 14:49:47,332 - INFO - Vehicle 181: Found 2 clusters
# 2024-11-27 14:49:47,380 - INFO - Vehicle 185: Found 1 clusters
# 2024-11-27 14:49:47,411 - INFO - Vehicle 186: Found 4 clusters
# 2024-11-27 14:49:47,443 - INFO - Vehicle 189: Found 1 clusters
# 2024-11-27 14:49:47,475 - INFO - Vehicle 192: Found 1 clusters
# 2024-11-27 14:49:47,492 - INFO - Vehicle 193: Found 3 clusters
# 2024-11-27 14:49:47,522 - INFO - Vehicle 196: Found 1 clusters
# 2024-11-27 14:49:47,540 - INFO - Vehicle 197: Found 5 clusters
# 2024-11-27 14:49:47,569 - INFO - Vehicle 199: Found 2 clusters
# 2024-11-27 14:49:47,586 - INFO - Vehicle 200: Found 2 clusters
# 2024-11-27 14:49:47,602 - INFO - Vehicle 201: Found 2 clusters
# 2024-11-27 14:49:47,644 - INFO - Vehicle 206: Found 2 clusters
# 2024-11-27 14:49:47,666 - INFO - Vehicle 208: Found 1 clusters
# 2024-11-27 14:49:47,696 - INFO - Vehicle 211: Found 1 clusters
# 2024-11-27 14:49:47,720 - INFO - Vehicle 213: Found 2 clusters
# 2024-11-27 14:49:47,758 - INFO - Vehicle 218: Found 2 clusters
# 2024-11-27 14:49:47,775 - INFO - Vehicle 219: Found 1 clusters
# 2024-11-27 14:49:47,813 - INFO - Vehicle 222: Found 1 clusters
# 2024-11-27 14:49:47,831 - INFO - Vehicle 223: Found 4 clusters
# 2024-11-27 14:49:47,902 - INFO - Vehicle 230: Found 3 clusters
# 2024-11-27 14:49:47,933 - INFO - Vehicle 232: Found 2 clusters
# 2024-11-27 14:49:47,970 - INFO - Vehicle 235: Found 1 clusters
# 2024-11-27 14:49:48,003 - INFO - Vehicle 237: Found 1 clusters
# 2024-11-27 14:49:48,021 - INFO - Vehicle 238: Found 3 clusters
# 2024-11-27 14:49:48,056 - INFO - Vehicle 241: Found 2 clusters
# 2024-11-27 14:49:48,132 - INFO - Vehicle 249: Found 5 clusters
# 2024-11-27 14:49:48,199 - INFO - Vehicle 254: Found 1 clusters
# 2024-11-27 14:49:48,240 - INFO - Vehicle 258: Found 2 clusters
# 2024-11-27 14:49:48,264 - INFO - Vehicle 259: Found 5 clusters
# 2024-11-27 14:49:48,284 - INFO - Vehicle 260: Found 1 clusters
# 2024-11-27 14:49:48,325 - INFO - Vehicle 264: Found 1 clusters
# 2024-11-27 14:49:48,352 - INFO - Vehicle 266: Found 1 clusters
# 2024-11-27 14:49:48,375 - INFO - Vehicle 267: Found 1 clusters
# 2024-11-27 14:49:48,405 - INFO - Vehicle 270: Found 1 clusters
# 2024-11-27 14:49:48,437 - INFO - Vehicle 272: Found 5 clusters
# 2024-11-27 14:49:48,472 - INFO - Vehicle 274: Found 1 clusters
# 2024-11-27 14:49:48,494 - INFO - Vehicle 275: Found 4 clusters
# 2024-11-27 14:49:48,547 - INFO - Vehicle 280: Found 1 clusters
# 2024-11-27 14:49:48,564 - INFO - Vehicle 281: Found 2 clusters
# 2024-11-27 14:49:48,608 - INFO - Vehicle 286: Found 1 clusters
# 2024-11-27 14:49:48,654 - INFO - Vehicle 291: Found 1 clusters
# 2024-11-27 14:49:48,682 - INFO - Vehicle 293: Found 1 clusters
# 2024-11-27 14:49:48,702 - INFO - Vehicle 294: Found 1 clusters
# 2024-11-27 14:49:48,732 - INFO - Vehicle 296: Found 5 clusters
# 2024-11-27 14:49:48,753 - INFO - Vehicle 297: Found 2 clusters
# 2024-11-27 14:49:48,773 - INFO - Vehicle 298: Found 5 clusters
# 2024-11-27 14:49:48,793 - INFO - Vehicle 299: Found 3 clusters
# 2024-11-27 14:49:48,812 - INFO - Vehicle 300: Found 2 clusters
# 2024-11-27 14:49:48,829 - INFO - Vehicle 301: Found 1 clusters
# 2024-11-27 14:49:48,846 - INFO - Vehicle 302: Found 1 clusters
# 2024-11-27 14:49:48,863 - INFO - Vehicle 303: Found 2 clusters
# 2024-11-27 14:49:48,905 - INFO - Vehicle 308: Found 1 clusters
# 2024-11-27 14:49:48,924 - INFO - Vehicle 309: Found 2 clusters
# 2024-11-27 14:49:48,940 - INFO - Vehicle 310: Found 1 clusters
# 2024-11-27 14:49:48,973 - INFO - Vehicle 314: Found 1 clusters
# 2024-11-27 14:49:48,990 - INFO - Vehicle 315: Found 3 clusters
# 2024-11-27 14:49:49,009 - INFO - Vehicle 316: Found 1 clusters
# 2024-11-27 14:49:49,030 - INFO - Vehicle 317: Found 2 clusters
# 2024-11-27 14:49:49,078 - INFO - Vehicle 320: Found 5 clusters
# 2024-11-27 14:49:49,114 - INFO - Vehicle 322: Found 3 clusters
# 2024-11-27 14:49:49,137 - INFO - Vehicle 323: Found 1 clusters
# 2024-11-27 14:49:49,160 - INFO - Vehicle 324: Found 3 clusters
# 2024-11-27 14:49:49,183 - INFO - Vehicle 325: Found 1 clusters
# 2024-11-27 14:49:49,206 - INFO - Vehicle 326: Found 2 clusters
# 2024-11-27 14:49:49,227 - INFO - Vehicle 327: Found 2 clusters
# 2024-11-27 14:49:49,260 - INFO - Vehicle 329: Found 1 clusters
# 2024-11-27 14:49:49,304 - INFO - Vehicle 333: Found 2 clusters
# 2024-11-27 14:49:49,326 - INFO - Vehicle 334: Found 1 clusters
# 2024-11-27 14:49:49,356 - INFO - Vehicle 336: Found 3 clusters
# 2024-11-27 14:49:49,397 - INFO - Vehicle 339: Found 1 clusters
# 2024-11-27 14:49:49,415 - INFO - Vehicle 340: Found 2 clusters
# 2024-11-27 14:49:49,444 - INFO - Vehicle 343: Found 1 clusters
# 2024-11-27 14:49:49,469 - INFO - Vehicle 345: Found 4 clusters
# 2024-11-27 14:49:49,492 - INFO - Vehicle 346: Found 1 clusters
# 2024-11-27 14:49:49,529 - INFO - Vehicle 349: Found 1 clusters
# 2024-11-27 14:49:49,553 - INFO - Vehicle 351: Found 1 clusters
# 2024-11-27 14:49:49,570 - INFO - Vehicle 352: Found 1 clusters
# 2024-11-27 14:49:49,596 - INFO - Vehicle 353: Found 2 clusters
# 2024-11-27 14:49:49,619 - INFO - Vehicle 354: Found 1 clusters
# 2024-11-27 14:49:49,669 - INFO - Vehicle 359: Found 1 clusters
# 2024-11-27 14:49:49,704 - INFO - Vehicle 365: Found 1 clusters
# 2024-11-27 14:49:49,722 - INFO - Vehicle 367: Found 1 clusters
# 2024-11-27 14:49:49,746 - INFO - Vehicle 370: Found 3 clusters
# 2024-11-27 14:49:49,772 - INFO - Vehicle 374: Found 1 clusters
# 2024-11-27 14:49:49,808 - INFO - Vehicle 380: Found 3 clusters
# 2024-11-27 14:49:49,837 - INFO - Vehicle 384: Found 4 clusters
# 2024-11-27 14:49:49,863 - INFO - Vehicle 388: Found 4 clusters
# 2024-11-27 14:49:49,877 - INFO - Vehicle 389: Found 1 clusters
# 2024-11-27 14:49:49,890 - INFO - Vehicle 390: Found 1 clusters
# 2024-11-27 14:49:49,911 - INFO - Vehicle 392: Found 1 clusters
# 2024-11-27 14:49:49,926 - INFO - Vehicle 393: Found 1 clusters
# 2024-11-27 14:49:49,939 - INFO - Vehicle 394: Found 2 clusters
# 2024-11-27 14:49:49,957 - INFO - Vehicle 396: Found 1 clusters
# 2024-11-27 14:49:49,971 - INFO - Vehicle 397: Found 1 clusters
# 2024-11-27 14:49:49,987 - INFO - Vehicle 399: Found 1 clusters
# 2024-11-27 14:49:50,006 - INFO - Vehicle 401: Found 2 clusters
# 2024-11-27 14:49:50,018 - INFO - Vehicle 402: Found 2 clusters
# 2024-11-27 14:49:50,049 - INFO - Vehicle 407: Found 1 clusters
# 2024-11-27 14:49:50,085 - INFO - Vehicle 413: Found 3 clusters
# 2024-11-27 14:49:50,100 - INFO - Vehicle 414: Found 2 clusters
# 2024-11-27 14:49:50,129 - INFO - Vehicle 417: Found 3 clusters
# 2024-11-27 14:49:50,146 - INFO - Vehicle 418: Found 1 clusters
# 2024-11-27 14:49:50,163 - INFO - Vehicle 419: Found 3 clusters
# 2024-11-27 14:49:50,179 - INFO - Vehicle 420: Found 1 clusters
# 2024-11-27 14:49:50,194 - INFO - Vehicle 421: Found 1 clusters
# 2024-11-27 14:49:50,215 - INFO - Vehicle 422: Found 5 clusters
# 2024-11-27 14:49:50,232 - INFO - Vehicle 423: Found 3 clusters
# 2024-11-27 14:49:50,259 - INFO - Vehicle 426: Found 1 clusters
# 2024-11-27 14:49:50,283 - INFO - Vehicle 428: Found 2 clusters
# 2024-11-27 14:49:50,305 - INFO - Vehicle 430: Found 1 clusters
# 2024-11-27 14:49:50,323 - INFO - Vehicle 431: Found 2 clusters
# 2024-11-27 14:49:50,350 - INFO - Vehicle 434: Found 1 clusters
# 2024-11-27 14:49:50,375 - INFO - Vehicle 436: Found 1 clusters
# 2024-11-27 14:49:50,388 - INFO - Vehicle 437: Found 1 clusters
# 2024-11-27 14:49:50,406 - INFO - Vehicle 439: Found 2 clusters
# 2024-11-27 14:49:50,424 - INFO - Vehicle 441: Found 3 clusters
# 2024-11-27 14:49:50,448 - INFO - Vehicle 445: Found 2 clusters
# 2024-11-27 14:49:50,466 - INFO - Vehicle 447: Found 5 clusters
# 2024-11-27 14:49:50,479 - INFO - Vehicle 448: Found 3 clusters
# 2024-11-27 14:49:50,493 - INFO - Vehicle 449: Found 1 clusters
# 2024-11-27 14:49:50,517 - INFO - Vehicle 452: Found 2 clusters
# 2024-11-27 14:49:50,570 - INFO - Vehicle 460: Found 1 clusters
# 2024-11-27 14:49:50,583 - INFO - Vehicle 461: Found 3 clusters
# 2024-11-27 14:49:50,600 - INFO - Vehicle 463: Found 5 clusters
# 2024-11-27 14:49:50,621 - INFO - Vehicle 466: Found 1 clusters
# 2024-11-27 14:49:50,633 - INFO - Vehicle 467: Found 1 clusters
# 2024-11-27 14:49:50,646 - INFO - Vehicle 468: Found 2 clusters
# 2024-11-27 14:49:50,671 - INFO - Vehicle 472: Found 1 clusters
# 2024-11-27 14:49:50,688 - INFO - Vehicle 474: Found 2 clusters
# 2024-11-27 14:49:50,702 - INFO - Vehicle 475: Found 1 clusters
# 2024-11-27 14:49:50,717 - INFO - Vehicle 476: Found 2 clusters
# 2024-11-27 14:49:50,731 - INFO - Vehicle 477: Found 3 clusters
# 2024-11-27 14:49:50,752 - INFO - Vehicle 480: Found 1 clusters
# 2024-11-27 14:49:50,764 - INFO - Vehicle 481: Found 1 clusters
# 2024-11-27 14:49:50,777 - INFO - Vehicle 482: Found 1 clusters
# 2024-11-27 14:49:50,810 - INFO - Vehicle 487: Found 2 clusters
# 2024-11-27 14:49:50,830 - INFO - Vehicle 489: Found 3 clusters
# 2024-11-27 14:49:50,857 - INFO - Vehicle 493: Found 1 clusters
# 2024-11-27 14:49:50,870 - INFO - Vehicle 494: Found 2 clusters
# 2024-11-27 14:49:50,884 - INFO - Vehicle 495: Found 2 clusters
# 2024-11-27 14:49:50,897 - INFO - Vehicle 496: Found 1 clusters
# 2024-11-27 14:49:50,926 - INFO - Vehicle 500: Found 4 clusters
# 2024-11-27 14:49:50,948 - INFO - Vehicle 503: Found 2 clusters
# 2024-11-27 14:49:50,973 - INFO - Vehicle 507: Found 1 clusters
# 2024-11-27 14:49:50,998 - INFO - Vehicle 511: Found 2 clusters
# 2024-11-27 14:49:51,016 - INFO - Vehicle 512: Found 2 clusters
# 2024-11-27 14:49:51,047 - INFO - Vehicle 516: Found 3 clusters
# 2024-11-27 14:49:51,073 - INFO - Vehicle 519: Found 2 clusters
# 2024-11-27 14:49:51,089 - INFO - Vehicle 520: Found 2 clusters
# 2024-11-27 14:49:51,113 - INFO - Vehicle 522: Found 1 clusters
# 2024-11-27 14:49:51,137 - INFO - Vehicle 523: Found 3 clusters
# 2024-11-27 14:49:51,159 - INFO - Vehicle 524: Found 7 clusters
# 2024-11-27 14:49:51,185 - INFO - Vehicle 526: Found 2 clusters
# 2024-11-27 14:49:51,206 - INFO - Vehicle 527: Found 1 clusters
# 2024-11-27 14:49:51,232 - INFO - Vehicle 529: Found 2 clusters
# 2024-11-27 14:49:51,269 - INFO - Vehicle 532: Found 1 clusters
# 2024-11-27 14:49:51,287 - INFO - Vehicle 533: Found 1 clusters
# 2024-11-27 14:49:51,310 - INFO - Vehicle 534: Found 5 clusters
# 2024-11-27 14:49:51,354 - INFO - Vehicle 539: Found 2 clusters
# 2024-11-27 14:49:51,379 - INFO - Vehicle 541: Found 4 clusters
# 2024-11-27 14:49:51,416 - INFO - Vehicle 545: Found 3 clusters
# 2024-11-27 14:49:51,435 - INFO - Vehicle 546: Found 2 clusters
# 2024-11-27 14:49:51,459 - INFO - Vehicle 548: Found 1 clusters
# 2024-11-27 14:49:51,478 - INFO - Vehicle 550: Found 1 clusters
# 2024-11-27 14:49:51,498 - INFO - Vehicle 552: Found 3 clusters
# 2024-11-27 14:49:51,513 - INFO - Vehicle 553: Found 2 clusters
# 2024-11-27 14:49:51,528 - INFO - Vehicle 554: Found 2 clusters
# 2024-11-27 14:49:51,588 - INFO - Vehicle 562: Found 1 clusters
# 2024-11-27 14:49:51,612 - INFO - Vehicle 565: Found 2 clusters
# 2024-11-27 14:49:51,627 - INFO - Vehicle 566: Found 2 clusters
# 2024-11-27 14:49:51,646 - INFO - Vehicle 567: Found 2 clusters
# 2024-11-27 14:49:51,671 - INFO - Vehicle 569: Found 1 clusters
# 2024-11-27 14:49:51,699 - INFO - Vehicle 572: Found 1 clusters
# 2024-11-27 14:49:51,757 - INFO - Vehicle 581: Found 1 clusters
# 2024-11-27 14:49:51,772 - INFO - Vehicle 582: Found 1 clusters
# 2024-11-27 14:49:51,802 - INFO - Vehicle 586: Found 5 clusters
# 2024-11-27 14:49:51,837 - INFO - Vehicle 590: Found 1 clusters
# 2024-11-27 14:49:51,853 - INFO - Vehicle 591: Found 1 clusters
# 2024-11-27 14:49:51,877 - INFO - Vehicle 594: Found 3 clusters
# 2024-11-27 14:49:51,898 - INFO - Vehicle 596: Found 1 clusters
# 2024-11-27 14:49:51,914 - INFO - Vehicle 597: Found 1 clusters
# 2024-11-27 14:49:51,932 - INFO - Vehicle 598: Found 1 clusters
# 2024-11-27 14:49:51,950 - INFO - Vehicle 599: Found 2 clusters
# 2024-11-27 14:49:51,978 - INFO - Vehicle 602: Found 1 clusters
# 2024-11-27 14:49:51,994 - INFO - Vehicle 603: Found 3 clusters
# 2024-11-27 14:49:52,010 - INFO - Vehicle 604: Found 1 clusters
# 2024-11-27 14:49:52,028 - INFO - Vehicle 605: Found 6 clusters
# 2024-11-27 14:49:52,045 - INFO - Vehicle 606: Found 4 clusters
# 2024-11-27 14:49:52,065 - INFO - Vehicle 608: Found 2 clusters
# 2024-11-27 14:49:52,082 - INFO - Vehicle 609: Found 1 clusters
# 2024-11-27 14:49:52,096 - INFO - Vehicle 610: Found 2 clusters
# 2024-11-27 14:49:52,111 - INFO - Vehicle 611: Found 1 clusters
# 2024-11-27 14:49:52,156 - INFO - Vehicle 615: Found 6 clusters
# 2024-11-27 14:49:52,174 - INFO - Vehicle 616: Found 3 clusters
# 2024-11-27 14:49:52,192 - INFO - Vehicle 617: Found 1 clusters
# 2024-11-27 14:49:52,206 - INFO - Vehicle 618: Found 1 clusters
# 2024-11-27 14:49:52,241 - INFO - Vehicle 622: Found 2 clusters
# 2024-11-27 14:49:52,264 - INFO - Vehicle 624: Found 1 clusters
# 2024-11-27 14:49:52,280 - INFO - Vehicle 625: Found 1 clusters
# 2024-11-27 14:49:52,296 - INFO - Vehicle 626: Found 2 clusters
# 2024-11-27 14:49:52,319 - INFO - Vehicle 628: Found 2 clusters
# 2024-11-27 14:49:52,335 - INFO - Vehicle 629: Found 2 clusters
# 2024-11-27 14:49:52,361 - INFO - Vehicle 632: Found 4 clusters
# 2024-11-27 14:49:52,396 - INFO - Vehicle 638: Found 4 clusters
# 2024-11-27 14:49:52,414 - INFO - Vehicle 640: Found 1 clusters
# 2024-11-27 14:49:52,436 - INFO - Vehicle 643: Found 2 clusters
# 2024-11-27 14:49:52,470 - INFO - Vehicle 649: Found 1 clusters
# 2024-11-27 14:49:52,482 - INFO - Vehicle 650: Found 1 clusters
# 2024-11-27 14:49:52,500 - INFO - Vehicle 652: Found 1 clusters
# 2024-11-27 14:49:52,516 - INFO - Vehicle 654: Found 1 clusters
# 2024-11-27 14:49:52,552 - INFO - Vehicle 659: Found 2 clusters
# 2024-11-27 14:49:52,566 - INFO - Vehicle 660: Found 1 clusters
# 2024-11-27 14:49:52,592 - INFO - Vehicle 662: Found 1 clusters
# 2024-11-27 14:49:52,620 - INFO - Vehicle 665: Found 3 clusters
# 2024-11-27 14:49:52,635 - INFO - Vehicle 666: Found 1 clusters
# 2024-11-27 14:49:52,650 - INFO - Vehicle 667: Found 4 clusters
# 2024-11-27 14:49:52,670 - INFO - Vehicle 668: Found 2 clusters
# 2024-11-27 14:49:52,693 - INFO - Vehicle 671: Found 1 clusters
# 2024-11-27 14:49:52,712 - INFO - Vehicle 673: Found 1 clusters
# 2024-11-27 14:49:52,751 - INFO - Vehicle 679: Found 1 clusters
# 2024-11-27 14:49:52,765 - INFO - Vehicle 680: Found 5 clusters
# 2024-11-27 14:49:52,788 - INFO - Vehicle 683: Found 3 clusters
# 2024-11-27 14:49:52,806 - INFO - Vehicle 685: Found 2 clusters
# 2024-11-27 14:49:52,840 - INFO - Vehicle 690: Found 1 clusters
# 2024-11-27 14:49:52,868 - INFO - Vehicle 694: Found 1 clusters
# 2024-11-27 14:49:52,881 - INFO - Vehicle 695: Found 4 clusters
# 2024-11-27 14:49:52,895 - INFO - Vehicle 696: Found 2 clusters
# 2024-11-27 14:49:52,909 - INFO - Vehicle 697: Found 2 clusters
# 2024-11-27 14:49:52,941 - INFO - Vehicle 703: Found 3 clusters
# 2024-11-27 14:49:52,957 - INFO - Vehicle 704: Found 5 clusters
# 2024-11-27 14:49:52,994 - INFO - Vehicle 710: Found 2 clusters
# 2024-11-27 14:49:53,012 - INFO - Vehicle 711: Found 2 clusters
# 2024-11-27 14:49:53,027 - INFO - Vehicle 712: Found 5 clusters
# 2024-11-27 14:49:53,055 - INFO - Vehicle 716: Found 1 clusters
# 2024-11-27 14:49:53,075 - INFO - Vehicle 718: Found 2 clusters
# 2024-11-27 14:49:53,094 - INFO - Vehicle 720: Found 1 clusters
# 2024-11-27 14:49:53,108 - INFO - Vehicle 721: Found 1 clusters
# 2024-11-27 14:49:53,138 - INFO - Vehicle 724: Found 3 clusters
# 2024-11-27 14:49:53,164 - INFO - Vehicle 726: Found 1 clusters
# 2024-11-27 14:49:53,186 - INFO - Vehicle 728: Found 1 clusters
# 2024-11-27 14:49:53,204 - INFO - Vehicle 729: Found 2 clusters
# 2024-11-27 14:49:53,232 - INFO - Vehicle 732: Found 2 clusters
# 2024-11-27 14:49:53,248 - INFO - Vehicle 733: Found 2 clusters
# 2024-11-27 14:49:53,266 - INFO - Vehicle 734: Found 2 clusters
# 2024-11-27 14:49:53,282 - INFO - Vehicle 735: Found 1 clusters
# 2024-11-27 14:49:53,299 - INFO - Vehicle 736: Found 3 clusters
# 2024-11-27 14:49:53,328 - INFO - Vehicle 739: Found 1 clusters
# 2024-11-27 14:49:53,346 - INFO - Vehicle 740: Found 1 clusters
# 2024-11-27 14:49:53,371 - INFO - Vehicle 742: Found 1 clusters
# 2024-11-27 14:49:53,386 - INFO - Vehicle 743: Found 1 clusters
# 2024-11-27 14:49:53,403 - INFO - Vehicle 744: Found 1 clusters
# 2024-11-27 14:49:53,430 - INFO - Vehicle 747: Found 2 clusters
# 2024-11-27 14:49:53,443 - INFO - Vehicle 748: Found 1 clusters
# 2024-11-27 14:49:53,457 - INFO - Vehicle 749: Found 4 clusters
# 2024-11-27 14:49:53,472 - INFO - Vehicle 750: Found 3 clusters
# 2024-11-27 14:49:53,487 - INFO - Vehicle 751: Found 2 clusters
# 2024-11-27 14:49:53,502 - INFO - Vehicle 752: Found 1 clusters
# 2024-11-27 14:49:53,515 - INFO - Vehicle 753: Found 1 clusters
# 2024-11-27 14:49:53,537 - INFO - Vehicle 756: Found 1 clusters
# 2024-11-27 14:49:53,564 - INFO - Vehicle 759: Found 1 clusters
# 2024-11-27 14:49:53,587 - INFO - Vehicle 762: Found 1 clusters
# 2024-11-27 14:49:53,604 - INFO - Vehicle 764: Found 3 clusters
# 2024-11-27 14:49:53,632 - INFO - Vehicle 766: Found 3 clusters
# 2024-11-27 14:49:53,658 - INFO - Vehicle 769: Found 1 clusters
# 2024-11-27 14:49:53,679 - INFO - Vehicle 772: Found 1 clusters
# 2024-11-27 14:49:53,693 - INFO - Vehicle 773: Found 1 clusters
# 2024-11-27 14:49:53,734 - INFO - Vehicle 780: Found 1 clusters
# 2024-11-27 14:49:53,760 - INFO - Vehicle 784: Found 1 clusters
# 2024-11-27 14:49:53,778 - INFO - Vehicle 786: Found 1 clusters
# 2024-11-27 14:49:53,797 - INFO - Vehicle 788: Found 1 clusters
# 2024-11-27 14:49:53,817 - INFO - Vehicle 790: Found 1 clusters
# 2024-11-27 14:49:53,839 - INFO - Vehicle 792: Found 1 clusters
# 2024-11-27 14:49:53,855 - INFO - Vehicle 793: Found 2 clusters
# 2024-11-27 14:49:53,878 - INFO - Vehicle 796: Found 1 clusters
# 2024-11-27 14:49:53,893 - INFO - Vehicle 797: Found 1 clusters
# 2024-11-27 14:49:53,905 - INFO - Vehicle 798: Found 1 clusters
# 2024-11-27 14:49:53,943 - INFO - Vehicle 805: Found 1 clusters
# 2024-11-27 14:49:53,981 - INFO - Vehicle 812: Found 4 clusters
# 2024-11-27 14:49:54,027 - INFO - Vehicle 819: Found 1 clusters
# 2024-11-27 14:49:54,059 - INFO - Vehicle 823: Found 1 clusters
# 2024-11-27 14:49:54,077 - INFO - Vehicle 825: Found 1 clusters
# 2024-11-27 14:49:54,095 - INFO - Vehicle 827: Found 2 clusters
# 2024-11-27 14:49:54,117 - INFO - Vehicle 829: Found 2 clusters
# 2024-11-27 14:49:54,135 - INFO - Vehicle 830: Found 3 clusters
# 2024-11-27 14:49:54,153 - INFO - Vehicle 831: Found 2 clusters
# 2024-11-27 14:49:54,171 - INFO - Vehicle 832: Found 4 clusters
# 2024-11-27 14:49:54,192 - INFO - Vehicle 834: Found 2 clusters
# 2024-11-27 14:49:54,218 - INFO - Vehicle 837: Found 3 clusters
# 2024-11-27 14:49:54,247 - INFO - Vehicle 840: Found 2 clusters
# 2024-11-27 14:49:54,271 - INFO - Vehicle 842: Found 1 clusters
# 2024-11-27 14:49:54,291 - INFO - Vehicle 844: Found 1 clusters
# 2024-11-27 14:49:54,343 - INFO - Vehicle 851: Found 1 clusters
# 2024-11-27 14:49:54,366 - INFO - Vehicle 853: Found 1 clusters
# 2024-11-27 14:49:54,383 - INFO - Vehicle 854: Found 1 clusters
# 2024-11-27 14:49:54,400 - INFO - Vehicle 855: Found 3 clusters
# 2024-11-27 14:49:54,412 - INFO - Vehicle 856: Found 1 clusters
# 2024-11-27 14:49:54,425 - INFO - Vehicle 857: Found 1 clusters
# 2024-11-27 14:49:54,442 - INFO - Vehicle 859: Found 1 clusters
# 2024-11-27 14:49:54,455 - INFO - Vehicle 860: Found 1 clusters
# 2024-11-27 14:49:54,473 - INFO - Vehicle 862: Found 2 clusters
# 2024-11-27 14:49:54,521 - INFO - Vehicle 872: Found 2 clusters
# 2024-11-27 14:49:54,542 - INFO - Vehicle 875: Found 1 clusters
# 2024-11-27 14:49:54,556 - INFO - Vehicle 876: Found 2 clusters
# 2024-11-27 14:49:54,570 - INFO - Vehicle 877: Found 1 clusters
# 2024-11-27 14:49:54,594 - INFO - Vehicle 880: Found 1 clusters
# 2024-11-27 14:49:54,652 - INFO - Vehicle 889: Found 1 clusters
# 2024-11-27 14:49:54,677 - INFO - Vehicle 890: Found 4 clusters
# 2024-11-27 14:49:54,689 - INFO - Vehicle 891: Found 1 clusters
# 2024-11-27 14:49:54,707 - INFO - Vehicle 893: Found 1 clusters
# 2024-11-27 14:49:54,729 - INFO - Vehicle 896: Found 1 clusters
# 2024-11-27 14:49:54,747 - INFO - Vehicle 898: Found 1 clusters
# 2024-11-27 14:49:54,765 - INFO - Vehicle 900: Found 2 clusters
# 2024-11-27 14:49:54,790 - INFO - Vehicle 903: Found 3 clusters
# 2024-11-27 14:49:54,806 - INFO - Vehicle 904: Found 4 clusters
# 2024-11-27 14:49:54,820 - INFO - Vehicle 905: Found 1 clusters
# 2024-11-27 14:49:54,849 - INFO - Vehicle 908: Found 4 clusters
# 2024-11-27 14:49:54,881 - INFO - Vehicle 912: Found 1 clusters
# 2024-11-27 14:49:54,916 - INFO - Vehicle 916: Found 1 clusters
# 2024-11-27 14:49:54,934 - INFO - Vehicle 918: Found 1 clusters
# 2024-11-27 14:49:54,956 - INFO - Vehicle 921: Found 2 clusters
# 2024-11-27 14:49:54,970 - INFO - Vehicle 922: Found 1 clusters
# 2024-11-27 14:49:54,988 - INFO - Vehicle 924: Found 1 clusters
# 2024-11-27 14:49:55,004 - INFO - Vehicle 925: Found 4 clusters
# 2024-11-27 14:49:55,029 - INFO - Vehicle 928: Found 1 clusters
# 2024-11-27 14:49:55,045 - INFO - Vehicle 929: Found 1 clusters
# 2024-11-27 14:49:55,068 - INFO - Vehicle 931: Found 2 clusters
# 2024-11-27 14:49:55,086 - INFO - Vehicle 932: Found 1 clusters
# 2024-11-27 14:49:55,104 - INFO - Vehicle 934: Found 1 clusters
# 2024-11-27 14:49:55,132 - INFO - Vehicle 937: Found 3 clusters
# 2024-11-27 14:49:55,164 - INFO - Vehicle 940: Found 1 clusters
# 2024-11-27 14:49:55,185 - INFO - Vehicle 941: Found 1 clusters
# 2024-11-27 14:49:55,219 - INFO - Vehicle 945: Found 3 clusters
# 2024-11-27 14:49:55,291 - INFO - Vehicle 955: Found 1 clusters
# 2024-11-27 14:49:55,320 - INFO - Vehicle 958: Found 3 clusters
# 2024-11-27 14:49:55,342 - INFO - Vehicle 960: Found 4 clusters
# 2024-11-27 14:49:55,365 - INFO - Vehicle 963: Found 1 clusters
# 2024-11-27 14:49:55,378 - INFO - Vehicle 964: Found 3 clusters
# 2024-11-27 14:49:55,397 - INFO - Vehicle 966: Found 1 clusters
# 2024-11-27 14:49:55,419 - INFO - Vehicle 969: Found 5 clusters
# 2024-11-27 14:49:55,432 - INFO - Vehicle 970: Found 1 clusters
# 2024-11-27 14:49:55,445 - INFO - Vehicle 971: Found 2 clusters
# 2024-11-27 14:49:55,460 - INFO - Vehicle 972: Found 8 clusters
# 2024-11-27 14:49:55,490 - INFO - Vehicle 977: Found 1 clusters
# 2024-11-27 14:49:55,520 - INFO - Vehicle 982: Found 1 clusters
# 2024-11-27 14:49:55,533 - INFO - Vehicle 983: Found 1 clusters
# 2024-11-27 14:49:55,549 - INFO - Vehicle 984: Found 2 clusters
# 2024-11-27 14:49:55,573 - INFO - Vehicle 987: Found 1 clusters
# 2024-11-27 14:49:55,587 - INFO - Vehicle 988: Found 3 clusters
# 2024-11-27 14:49:55,609 - INFO - Vehicle 990: Found 1 clusters
# 2024-11-27 14:49:55,627 - INFO - Vehicle 992: Found 1 clusters
# 2024-11-27 14:49:55,655 - INFO - Vehicle 996: Found 2 clusters
# 2024-11-27 14:49:55,671 - INFO - Vehicle 997: Found 1 clusters
# 2024-11-27 14:49:55,691 - INFO - Vehicle 998: Found 1 clusters
# 2024-11-27 14:49:55,711 - INFO - Vehicle 999: Found 3 clusters
# 2024-11-27 14:49:55,725 - INFO - Vehicle 1000: Found 1 clusters
# 2024-11-27 14:49:55,743 - INFO - Vehicle 1002: Found 4 clusters
# 2024-11-27 14:49:55,765 - INFO - Vehicle 1005: Found 1 clusters
# 2024-11-27 14:49:55,792 - INFO - Vehicle 1009: Found 3 clusters
# 2024-11-27 14:49:55,822 - INFO - Vehicle 1014: Found 1 clusters
# 2024-11-27 14:49:55,849 - INFO - Vehicle 1018: Found 1 clusters
# 2024-11-27 14:49:55,877 - INFO - Vehicle 1022: Found 1 clusters
# 2024-11-27 14:49:55,905 - INFO - Vehicle 1026: Found 1 clusters
# 2024-11-27 14:49:55,920 - INFO - Vehicle 1027: Found 1 clusters
# 2024-11-27 14:49:55,945 - INFO - Vehicle 1030: Found 1 clusters
# 2024-11-27 14:49:55,964 - INFO - Vehicle 1032: Found 1 clusters
# 2024-11-27 14:49:55,985 - INFO - Vehicle 1034: Found 2 clusters
# 2024-11-27 14:49:56,015 - INFO - Vehicle 1038: Found 3 clusters
# 2024-11-27 14:49:56,031 - INFO - Vehicle 1039: Found 1 clusters
# 2024-11-27 14:49:56,052 - INFO - Vehicle 1041: Found 6 clusters
# 2024-11-27 14:49:56,065 - INFO - Vehicle 1042: Found 2 clusters
# 2024-11-27 14:49:56,084 - INFO - Vehicle 1044: Found 4 clusters
# 2024-11-27 14:49:56,128 - INFO - Vehicle 1049: Found 3 clusters
# 2024-11-27 14:49:56,155 - INFO - Vehicle 1051: Found 1 clusters
# 2024-11-27 14:49:56,173 - INFO - Vehicle 1052: Found 1 clusters
# 2024-11-27 14:49:56,205 - INFO - Vehicle 1056: Found 1 clusters
# 2024-11-27 14:49:56,222 - INFO - Vehicle 1057: Found 4 clusters
# 2024-11-27 14:49:56,270 - INFO - Vehicle 1063: Found 1 clusters
# 2024-11-27 14:49:56,307 - INFO - Vehicle 1068: Found 1 clusters
# 2024-11-27 14:49:56,339 - INFO - Vehicle 1072: Found 1 clusters
# 2024-11-27 14:49:56,354 - INFO - Vehicle 1073: Found 2 clusters
# 2024-11-27 14:49:56,391 - INFO - Vehicle 1078: Found 1 clusters
# 2024-11-27 14:49:56,403 - INFO - Vehicle 1079: Found 1 clusters
# 2024-11-27 14:49:56,417 - INFO - Vehicle 1080: Found 1 clusters
# 2024-11-27 14:49:56,435 - INFO - Vehicle 1082: Found 2 clusters
# 2024-11-27 14:49:56,460 - INFO - Vehicle 1086: Found 1 clusters
# 2024-11-27 14:49:56,494 - INFO - Vehicle 1092: Found 1 clusters
# 2024-11-27 14:49:56,518 - INFO - Vehicle 1096: Found 1 clusters
# 2024-11-27 14:49:56,541 - INFO - Vehicle 1099: Found 1 clusters
# 2024-11-27 14:49:56,568 - INFO - Vehicle 1103: Found 2 clusters
# 2024-11-27 14:49:56,581 - INFO - Vehicle 1104: Found 4 clusters
# 2024-11-27 14:49:56,607 - INFO - Vehicle 1108: Found 2 clusters
# 2024-11-27 14:49:56,620 - INFO - Vehicle 1109: Found 2 clusters
# 2024-11-27 14:49:56,632 - INFO - Vehicle 1110: Found 1 clusters
# 2024-11-27 14:49:56,646 - INFO - Vehicle 1111: Found 2 clusters
# 2024-11-27 14:49:56,672 - INFO - Vehicle 1114: Found 1 clusters
# 2024-11-27 14:49:56,686 - INFO - Vehicle 1115: Found 1 clusters
# 2024-11-27 14:49:56,703 - INFO - Vehicle 1116: Found 1 clusters
# 2024-11-27 14:49:56,727 - INFO - Vehicle 1117: Found 5 clusters
# 2024-11-27 14:49:56,759 - INFO - Vehicle 1122: Found 1 clusters
# 2024-11-27 14:49:56,774 - INFO - Vehicle 1123: Found 1 clusters
# 2024-11-27 14:49:56,800 - INFO - Vehicle 1127: Found 2 clusters
# 2024-11-27 14:49:56,815 - INFO - Vehicle 1128: Found 2 clusters
# 2024-11-27 14:49:56,830 - INFO - Vehicle 1129: Found 3 clusters
# 2024-11-27 14:49:56,843 - INFO - Vehicle 1130: Found 1 clusters
# 2024-11-27 14:49:56,871 - INFO - Vehicle 1134: Found 1 clusters
# 2024-11-27 14:49:56,889 - INFO - Vehicle 1136: Found 1 clusters
# 2024-11-27 14:49:56,907 - INFO - Vehicle 1138: Found 3 clusters
# 2024-11-27 14:49:56,920 - INFO - Vehicle 1139: Found 1 clusters
# 2024-11-27 14:49:56,954 - INFO - Vehicle 1145: Found 2 clusters
# 2024-11-27 14:49:56,972 - INFO - Vehicle 1147: Found 1 clusters
# 2024-11-27 14:49:56,989 - INFO - Vehicle 1149: Found 2 clusters
# 2024-11-27 14:49:57,013 - INFO - Vehicle 1152: Found 1 clusters
# 2024-11-27 14:49:57,049 - INFO - Vehicle 1158: Found 5 clusters
# 2024-11-27 14:49:57,068 - INFO - Vehicle 1160: Found 3 clusters
# 2024-11-27 14:49:57,092 - INFO - Vehicle 1162: Found 1 clusters
# 2024-11-27 14:49:57,120 - INFO - Vehicle 1165: Found 1 clusters
# 2024-11-27 14:49:57,137 - INFO - Vehicle 1166: Found 1 clusters
# 2024-11-27 14:49:57,155 - INFO - Vehicle 1167: Found 1 clusters
# 2024-11-27 14:49:57,173 - INFO - Vehicle 1168: Found 1 clusters
# 2024-11-27 14:49:57,224 - INFO - Vehicle 1172: Found 1 clusters
# 2024-11-27 14:49:57,252 - INFO - Vehicle 1175: Found 1 clusters
# 2024-11-27 14:49:57,277 - INFO - Vehicle 1177: Found 1 clusters
# 2024-11-27 14:49:57,293 - INFO - Vehicle 1178: Found 1 clusters
# 2024-11-27 14:49:57,322 - INFO - Vehicle 1181: Found 1 clusters
# 2024-11-27 14:49:57,371 - INFO - Vehicle 1187: Found 1 clusters
# 2024-11-27 14:49:57,387 - INFO - Vehicle 1188: Found 2 clusters
# 2024-11-27 14:49:57,419 - INFO - Vehicle 1191: Found 1 clusters
# 2024-11-27 14:49:57,451 - INFO - Vehicle 1195: Found 1 clusters
# 2024-11-27 14:49:57,473 - INFO - Vehicle 1197: Found 1 clusters
# 2024-11-27 14:49:57,492 - INFO - Vehicle 1199: Found 2 clusters
# 2024-11-27 14:49:57,509 - INFO - Vehicle 1201: Found 1 clusters
# 2024-11-27 14:49:57,532 - INFO - Vehicle 1204: Found 4 clusters
# 2024-11-27 14:49:57,548 - INFO - Vehicle 1205: Found 2 clusters
# 2024-11-27 14:49:57,568 - INFO - Vehicle 1207: Found 8 clusters
# 2024-11-27 14:49:57,585 - INFO - Vehicle 1209: Found 3 clusters
# 2024-11-27 14:49:57,607 - INFO - Vehicle 1212: Found 2 clusters
# 2024-11-27 14:49:57,620 - INFO - Vehicle 1213: Found 1 clusters
# 2024-11-27 14:49:57,633 - INFO - Vehicle 1214: Found 1 clusters
# 2024-11-27 14:49:57,664 - INFO - Vehicle 1219: Found 1 clusters
# 2024-11-27 14:49:57,685 - INFO - Vehicle 1222: Found 1 clusters
# 2024-11-27 14:49:57,702 - INFO - Vehicle 1224: Found 3 clusters
# 2024-11-27 14:49:57,726 - INFO - Vehicle 1227: Found 1 clusters
# 2024-11-27 14:49:57,743 - INFO - Vehicle 1228: Found 2 clusters
# 2024-11-27 14:49:57,761 - INFO - Vehicle 1229: Found 1 clusters
# 2024-11-27 14:49:57,781 - INFO - Vehicle 1231: Found 3 clusters
# 2024-11-27 14:49:57,794 - INFO - Vehicle 1232: Found 1 clusters
# 2024-11-27 14:49:57,807 - INFO - Vehicle 1233: Found 2 clusters
# 2024-11-27 14:49:57,833 - INFO - Vehicle 1237: Found 1 clusters
# 2024-11-27 14:49:57,851 - INFO - Vehicle 1239: Found 2 clusters
# 2024-11-27 14:49:57,870 - INFO - Vehicle 1241: Found 2 clusters
# 2024-11-27 14:49:57,883 - INFO - Vehicle 1242: Found 2 clusters
# 2024-11-27 14:49:57,917 - INFO - Vehicle 1247: Found 4 clusters
# 2024-11-27 14:49:57,940 - INFO - Vehicle 1249: Found 1 clusters
# 2024-11-27 14:49:57,958 - INFO - Vehicle 1251: Found 1 clusters
# 2024-11-27 14:49:57,971 - INFO - Vehicle 1252: Found 3 clusters
# 2024-11-27 14:49:57,989 - INFO - Vehicle 1254: Found 1 clusters
# 2024-11-27 14:49:58,010 - INFO - Vehicle 1256: Found 1 clusters
# 2024-11-27 14:49:58,067 - INFO - Vehicle 1267: Found 2 clusters
# 2024-11-27 14:49:58,094 - INFO - Vehicle 1271: Found 1 clusters
# 2024-11-27 14:49:58,109 - INFO - Vehicle 1272: Found 1 clusters
# 2024-11-27 14:49:58,132 - INFO - Vehicle 1274: Found 1 clusters
# 2024-11-27 14:49:58,149 - INFO - Vehicle 1275: Found 3 clusters
# 2024-11-27 14:49:58,166 - INFO - Vehicle 1276: Found 1 clusters
# 2024-11-27 14:49:58,188 - INFO - Vehicle 1278: Found 2 clusters
# 2024-11-27 14:49:58,207 - INFO - Vehicle 1279: Found 2 clusters
# 2024-11-27 14:49:58,224 - INFO - Vehicle 1280: Found 7 clusters
# 2024-11-27 14:49:58,243 - INFO - Vehicle 1281: Found 3 clusters
# 2024-11-27 14:49:58,261 - INFO - Vehicle 1282: Found 1 clusters
# 2024-11-27 14:49:58,279 - INFO - Vehicle 1283: Found 3 clusters
# 2024-11-27 14:49:58,297 - INFO - Vehicle 1284: Found 1 clusters
# 2024-11-27 14:49:58,331 - INFO - Vehicle 1288: Found 5 clusters
# 2024-11-27 14:49:58,352 - INFO - Vehicle 1290: Found 2 clusters
# 2024-11-27 14:49:58,399 - INFO - Vehicle 1296: Found 2 clusters
# 2024-11-27 14:49:58,419 - INFO - Vehicle 1298: Found 1 clusters
# 2024-11-27 14:49:58,439 - INFO - Vehicle 1300: Found 2 clusters
# 2024-11-27 14:49:58,451 - INFO - Vehicle 1301: Found 1 clusters
# 2024-11-27 14:49:58,470 - INFO - Vehicle 1303: Found 1 clusters
# 2024-11-27 14:49:58,487 - INFO - Vehicle 1304: Found 2 clusters
# 2024-11-27 14:49:58,511 - INFO - Vehicle 1307: Found 1 clusters
# 2024-11-27 14:49:58,544 - INFO - Vehicle 1312: Found 2 clusters
# 2024-11-27 14:49:58,566 - INFO - Vehicle 1314: Found 1 clusters
# 2024-11-27 14:49:58,580 - INFO - Vehicle 1315: Found 1 clusters
# 2024-11-27 14:49:58,601 - INFO - Vehicle 1318: Found 1 clusters
# 2024-11-27 14:49:58,615 - INFO - Vehicle 1319: Found 1 clusters
# 2024-11-27 14:49:58,639 - INFO - Vehicle 1323: Found 2 clusters
# 2024-11-27 14:49:58,653 - INFO - Vehicle 1324: Found 2 clusters
# 2024-11-27 14:49:58,667 - INFO - Vehicle 1325: Found 1 clusters
# 2024-11-27 14:49:58,684 - INFO - Vehicle 1327: Found 4 clusters
# 2024-11-27 14:49:58,699 - INFO - Vehicle 1328: Found 4 clusters
# 2024-11-27 14:49:58,714 - INFO - Vehicle 1329: Found 3 clusters
# 2024-11-27 14:49:58,727 - INFO - Vehicle 1330: Found 1 clusters
# 2024-11-27 14:49:58,741 - INFO - Vehicle 1331: Found 1 clusters
# 2024-11-27 14:49:58,759 - INFO - Vehicle 1333: Found 1 clusters
# 2024-11-27 14:49:58,780 - INFO - Vehicle 1335: Found 1 clusters
# 2024-11-27 14:49:58,824 - INFO - Vehicle 1341: Found 1 clusters
# 2024-11-27 14:49:58,839 - INFO - Vehicle 1342: Found 2 clusters
# 2024-11-27 14:49:58,862 - INFO - Vehicle 1343: Found 5 clusters
# 2024-11-27 14:49:58,879 - INFO - Vehicle 1344: Found 3 clusters
# 2024-11-27 14:49:58,892 - INFO - Vehicle 1345: Found 2 clusters
# 2024-11-27 14:49:58,911 - INFO - Vehicle 1347: Found 1 clusters
# 2024-11-27 14:49:58,928 - INFO - Vehicle 1349: Found 2 clusters
# 2024-11-27 14:49:58,951 - INFO - Vehicle 1352: Found 1 clusters
# 2024-11-27 14:49:58,967 - INFO - Vehicle 1353: Found 5 clusters
# 2024-11-27 14:49:58,990 - INFO - Vehicle 1356: Found 1 clusters
# 2024-11-27 14:49:59,004 - INFO - Vehicle 1357: Found 1 clusters
# 2024-11-27 14:49:59,017 - INFO - Vehicle 1358: Found 1 clusters
# 2024-11-27 14:49:59,059 - INFO - Vehicle 1364: Found 2 clusters
# 2024-11-27 14:49:59,083 - INFO - Vehicle 1367: Found 3 clusters
# 2024-11-27 14:49:59,097 - INFO - Vehicle 1368: Found 1 clusters
# 2024-11-27 14:49:59,122 - INFO - Vehicle 1370: Found 3 clusters
# 2024-11-27 14:49:59,150 - INFO - Vehicle 1373: Found 1 clusters
# 2024-11-27 14:49:59,171 - INFO - Vehicle 1374: Found 4 clusters
# 2024-11-27 14:49:59,234 - INFO - Vehicle 1383: Found 1 clusters
# 2024-11-27 14:49:59,264 - INFO - Vehicle 1386: Found 1 clusters
# 2024-11-27 14:49:59,283 - INFO - Vehicle 1387: Found 2 clusters
# 2024-11-27 14:49:59,312 - INFO - Vehicle 1390: Found 1 clusters
# 2024-11-27 14:49:59,334 - INFO - Vehicle 1392: Found 1 clusters
# 2024-11-27 14:49:59,369 - INFO - Vehicle 1396: Found 1 clusters
# 2024-11-27 14:49:59,396 - INFO - Vehicle 1399: Found 1 clusters
# 2024-11-27 14:49:59,410 - INFO - Vehicle 1400: Found 1 clusters
# 2024-11-27 14:49:59,437 - INFO - Vehicle 1404: Found 1 clusters
# 2024-11-27 14:49:59,472 - INFO - Vehicle 1409: Found 7 clusters
# 2024-11-27 14:49:59,490 - INFO - Vehicle 1410: Found 1 clusters
# 2024-11-27 14:49:59,505 - INFO - Vehicle 1411: Found 1 clusters
# 2024-11-27 14:49:59,523 - INFO - Vehicle 1413: Found 1 clusters
# 2024-11-27 14:49:59,545 - INFO - Vehicle 1415: Found 3 clusters
# 2024-11-27 14:49:59,558 - INFO - Vehicle 1416: Found 2 clusters
# 2024-11-27 14:49:59,577 - INFO - Vehicle 1418: Found 2 clusters
# 2024-11-27 14:49:59,590 - INFO - Vehicle 1419: Found 1 clusters
# 2024-11-27 14:49:59,609 - INFO - Vehicle 1421: Found 4 clusters
# 2024-11-27 14:49:59,623 - INFO - Vehicle 1422: Found 2 clusters
# 2024-11-27 14:49:59,638 - INFO - Vehicle 1423: Found 3 clusters
# 2024-11-27 14:49:59,659 - INFO - Vehicle 1425: Found 4 clusters
# 2024-11-27 14:49:59,671 - INFO - Vehicle 1426: Found 3 clusters
# 2024-11-27 14:49:59,699 - INFO - Vehicle 1429: Found 1 clusters
# 2024-11-27 14:49:59,744 - INFO - Vehicle 1433: Found 1 clusters
# 2024-11-27 14:49:59,768 - INFO - Vehicle 1435: Found 1 clusters
# 2024-11-27 14:49:59,788 - INFO - Vehicle 1436: Found 4 clusters
# 2024-11-27 14:49:59,831 - INFO - Vehicle 1440: Found 1 clusters
# 2024-11-27 14:49:59,867 - INFO - Vehicle 1443: Found 3 clusters
# 2024-11-27 14:49:59,915 - INFO - Vehicle 1447: Found 1 clusters
# 2024-11-27 14:49:59,930 - INFO - Vehicle 1448: Found 1 clusters
# 2024-11-27 14:49:59,947 - INFO - Vehicle 1449: Found 2 clusters
# 2024-11-27 14:49:59,981 - INFO - Vehicle 1452: Found 2 clusters
# 2024-11-27 14:49:59,999 - INFO - Vehicle 1453: Found 2 clusters
# 2024-11-27 14:50:00,017 - INFO - Vehicle 1454: Found 1 clusters
# 2024-11-27 14:50:00,036 - INFO - Vehicle 1455: Found 1 clusters
# 2024-11-27 14:50:00,088 - INFO - Vehicle 1459: Found 3 clusters
# 2024-11-27 14:50:00,114 - INFO - Vehicle 1460: Found 4 clusters
# 2024-11-27 14:50:00,139 - INFO - Vehicle 1461: Found 1 clusters
# 2024-11-27 14:50:00,163 - INFO - Vehicle 1462: Found 1 clusters
# 2024-11-27 14:50:00,184 - INFO - Vehicle 1463: Found 2 clusters
# 2024-11-27 14:50:00,239 - INFO - Vehicle 1467: Found 1 clusters
# 2024-11-27 14:50:00,264 - INFO - Vehicle 1468: Found 4 clusters
# 2024-11-27 14:50:00,318 - INFO - Vehicle 1471: Found 4 clusters
# 2024-11-27 14:50:00,348 - INFO - Vehicle 1472: Found 1 clusters
# 2024-11-27 14:50:00,372 - INFO - Vehicle 1473: Found 1 clusters
# 2024-11-27 14:50:00,404 - INFO - Vehicle 1475: Found 1 clusters
# 2024-11-27 14:50:00,441 - INFO - Vehicle 1477: Found 2 clusters
# 2024-11-27 14:50:00,475 - INFO - Vehicle 1478: Found 1 clusters
# 2024-11-27 14:50:00,507 - INFO - Vehicle 1480: Found 1 clusters
# 2024-11-27 14:50:00,555 - INFO - Vehicle 1483: Found 2 clusters
# 2024-11-27 14:50:00,621 - INFO - Vehicle 1490: Found 1 clusters
# 2024-11-27 14:50:00,673 - INFO - Vehicle 1494: Found 1 clusters
# 2024-11-27 14:50:00,701 - INFO - Vehicle 1496: Found 3 clusters
# 2024-11-27 14:50:00,723 - INFO - Vehicle 1497: Found 2 clusters
# 2024-11-27 14:50:00,761 - INFO - Vehicle 1500: Found 5 clusters
# 2024-11-27 14:50:00,805 - INFO - Vehicle 1504: Found 2 clusters
# 2024-11-27 14:50:00,840 - INFO - Vehicle 1507: Found 2 clusters
# 2024-11-27 14:50:00,889 - INFO - Vehicle 1512: Found 1 clusters
# 2024-11-27 14:50:00,913 - INFO - Vehicle 1513: Found 1 clusters
# 2024-11-27 14:50:00,962 - INFO - Vehicle 1516: Found 1 clusters
# 2024-11-27 14:50:01,026 - INFO - Vehicle 1521: Found 1 clusters
# 2024-11-27 14:50:01,053 - INFO - Vehicle 1523: Found 1 clusters
# 2024-11-27 14:50:01,084 - INFO - Vehicle 1525: Found 4 clusters
# 2024-11-27 14:50:01,166 - INFO - Vehicle 1531: Found 1 clusters
# 2024-11-27 14:50:01,226 - INFO - Vehicle 1534: Found 2 clusters
# 2024-11-27 14:50:01,292 - INFO - Vehicle 1537: Found 3 clusters
# 2024-11-27 14:50:01,328 - INFO - Vehicle 1539: Found 1 clusters
# 2024-11-27 14:50:01,358 - INFO - Vehicle 1540: Found 3 clusters
# 2024-11-27 14:50:01,395 - INFO - Vehicle 1542: Found 1 clusters
# 2024-11-27 14:50:01,416 - INFO - Vehicle 1543: Found 1 clusters
# 2024-11-27 14:50:01,434 - INFO - Vehicle 1544: Found 1 clusters
# 2024-11-27 14:50:01,459 - INFO - Vehicle 1546: Found 1 clusters
# 2024-11-27 14:50:01,479 - INFO - Vehicle 1547: Found 2 clusters
# 2024-11-27 14:50:01,514 - INFO - Vehicle 1550: Found 2 clusters
# 2024-11-27 14:50:01,533 - INFO - Vehicle 1551: Found 1 clusters
# 2024-11-27 14:50:01,555 - INFO - Vehicle 1552: Found 3 clusters
# 2024-11-27 14:50:01,573 - INFO - Vehicle 1553: Found 2 clusters
# 2024-11-27 14:50:01,609 - INFO - Vehicle 1555: Found 1 clusters
# 2024-11-27 14:50:01,640 - INFO - Vehicle 1558: Found 1 clusters
# 2024-11-27 14:50:01,674 - INFO - Vehicle 1560: Found 1 clusters
# 2024-11-27 14:50:01,702 - INFO - Vehicle 1561: Found 1 clusters
# 2024-11-27 14:50:01,731 - INFO - Vehicle 1562: Found 2 clusters
# 2024-11-27 14:50:01,755 - INFO - Vehicle 1563: Found 1 clusters
# 2024-11-27 14:50:01,783 - INFO - Vehicle 1564: Found 1 clusters
# 2024-11-27 14:50:01,834 - INFO - Vehicle 1568: Found 1 clusters
# 2024-11-27 14:50:01,862 - INFO - Vehicle 1569: Found 3 clusters
# 2024-11-27 14:50:01,881 - INFO - Vehicle 1570: Found 2 clusters
# 2024-11-27 14:50:01,906 - INFO - Vehicle 1571: Found 2 clusters
# 2024-11-27 14:50:01,931 - INFO - Vehicle 1572: Found 2 clusters
# 2024-11-27 14:50:01,954 - INFO - Vehicle 1573: Found 1 clusters
# 2024-11-27 14:50:01,978 - INFO - Vehicle 1574: Found 1 clusters
# 2024-11-27 14:50:02,030 - INFO - Vehicle 1578: Found 1 clusters
# 2024-11-27 14:50:02,054 - INFO - Vehicle 1579: Found 2 clusters
# 2024-11-27 14:50:02,073 - INFO - Vehicle 1580: Found 1 clusters
# 2024-11-27 14:50:02,101 - INFO - Vehicle 1582: Found 3 clusters
# 2024-11-27 14:50:02,216 - INFO - Vehicle 1593: Found 1 clusters
# 2024-11-27 14:50:02,243 - INFO - Vehicle 1594: Found 2 clusters
# 2024-11-27 14:50:02,275 - INFO - Vehicle 1595: Found 5 clusters
# 2024-11-27 14:50:02,344 - INFO - Vehicle 1601: Found 1 clusters
# 2024-11-27 14:50:02,368 - INFO - Vehicle 1602: Found 2 clusters
# 2024-11-27 14:50:02,394 - INFO - Vehicle 1603: Found 1 clusters
# 2024-11-27 14:50:02,429 - INFO - Vehicle 1604: Found 1 clusters
# 2024-11-27 14:50:02,462 - INFO - Vehicle 1606: Found 1 clusters
# 2024-11-27 14:50:02,496 - INFO - Vehicle 1608: Found 2 clusters
# 2024-11-27 14:50:02,529 - INFO - Vehicle 1611: Found 1 clusters
# 2024-11-27 14:50:02,549 - INFO - Vehicle 1612: Found 1 clusters
# 2024-11-27 14:50:02,571 - INFO - Vehicle 1613: Found 1 clusters
# 2024-11-27 14:50:02,589 - INFO - Vehicle 1614: Found 1 clusters
# 2024-11-27 14:50:02,613 - INFO - Vehicle 1616: Found 2 clusters
# 2024-11-27 14:50:02,629 - INFO - Vehicle 1617: Found 1 clusters
# 2024-11-27 14:50:02,658 - INFO - Vehicle 1619: Found 1 clusters
# 2024-11-27 14:50:02,704 - INFO - Vehicle 1622: Found 2 clusters
# 2024-11-27 14:50:02,736 - INFO - Vehicle 1624: Found 1 clusters
# 2024-11-27 14:50:02,754 - INFO - Vehicle 1625: Found 2 clusters
# 2024-11-27 14:50:02,789 - INFO - Vehicle 1627: Found 1 clusters
# 2024-11-27 14:50:02,816 - INFO - Vehicle 1628: Found 2 clusters
# 2024-11-27 14:50:02,863 - INFO - Vehicle 1632: Found 1 clusters
# 2024-11-27 14:50:02,892 - INFO - Vehicle 1633: Found 2 clusters
# 2024-11-27 14:50:02,928 - INFO - Vehicle 1635: Found 1 clusters
# 2024-11-27 14:50:02,953 - INFO - Vehicle 1636: Found 4 clusters
# 2024-11-27 14:50:02,978 - INFO - Vehicle 1637: Found 2 clusters
# 2024-11-27 14:50:03,010 - INFO - Vehicle 1639: Found 6 clusters
# 2024-11-27 14:50:03,036 - INFO - Vehicle 1641: Found 2 clusters
# 2024-11-27 14:50:03,060 - INFO - Vehicle 1642: Found 2 clusters
# 2024-11-27 14:50:03,082 - INFO - Vehicle 1643: Found 1 clusters
# 2024-11-27 14:50:03,142 - INFO - Vehicle 1646: Found 6 clusters
# 2024-11-27 14:50:03,253 - INFO - Vehicle 1655: Found 2 clusters
# 2024-11-27 14:50:03,280 - INFO - Vehicle 1656: Found 1 clusters
# 2024-11-27 14:50:03,341 - INFO - Vehicle 1661: Found 2 clusters
# 2024-11-27 14:50:03,375 - INFO - Vehicle 1663: Found 3 clusters
# 2024-11-27 14:50:03,399 - INFO - Vehicle 1664: Found 1 clusters
# 2024-11-27 14:50:03,421 - INFO - Vehicle 1665: Found 1 clusters
# 2024-11-27 14:50:03,449 - INFO - Vehicle 1667: Found 1 clusters
# 2024-11-27 14:50:03,483 - INFO - Vehicle 1670: Found 1 clusters
# 2024-11-27 14:50:03,546 - INFO - Vehicle 1676: Found 4 clusters
# 2024-11-27 14:50:03,590 - INFO - Vehicle 1680: Found 1 clusters
# 2024-11-27 14:50:03,607 - INFO - Vehicle 1681: Found 1 clusters
# 2024-11-27 14:50:03,646 - INFO - Vehicle 1684: Found 1 clusters
# 2024-11-27 14:50:03,682 - INFO - Vehicle 1687: Found 1 clusters
# 2024-11-27 14:50:03,700 - INFO - Vehicle 1688: Found 5 clusters
# 2024-11-27 14:50:03,714 - INFO - Vehicle 1689: Found 2 clusters
# 2024-11-27 14:50:03,728 - INFO - Vehicle 1690: Found 1 clusters
# 2024-11-27 14:50:03,747 - INFO - Vehicle 1692: Found 2 clusters
# 2024-11-27 14:50:03,759 - INFO - Vehicle 1693: Found 2 clusters
# 2024-11-27 14:50:03,773 - INFO - Vehicle 1694: Found 1 clusters
# 2024-11-27 14:50:03,787 - INFO - Vehicle 1695: Found 2 clusters
# 2024-11-27 14:50:03,805 - INFO - Vehicle 1697: Found 1 clusters
# 2024-11-27 14:50:03,827 - INFO - Vehicle 1700: Found 3 clusters
# 2024-11-27 14:50:03,842 - INFO - Vehicle 1701: Found 2 clusters
# 2024-11-27 14:50:03,856 - INFO - Vehicle 1702: Found 1 clusters
# 2024-11-27 14:50:03,869 - INFO - Vehicle 1703: Found 2 clusters
# 2024-11-27 14:50:03,887 - INFO - Vehicle 1704: Found 2 clusters
# 2024-11-27 14:50:03,905 - INFO - Vehicle 1706: Found 3 clusters
# 2024-11-27 14:50:03,920 - INFO - Vehicle 1707: Found 2 clusters
# 2024-11-27 14:50:03,938 - INFO - Vehicle 1709: Found 2 clusters
# 2024-11-27 14:50:03,966 - INFO - Vehicle 1713: Found 6 clusters
# 2024-11-27 14:50:03,981 - INFO - Vehicle 1714: Found 3 clusters
# 2024-11-27 14:50:03,995 - INFO - Vehicle 1715: Found 1 clusters
# 2024-11-27 14:50:04,014 - INFO - Vehicle 1717: Found 1 clusters
# 2024-11-27 14:50:04,036 - INFO - Vehicle 1720: Found 1 clusters
# 2024-11-27 14:50:04,056 - INFO - Vehicle 1722: Found 1 clusters
# 2024-11-27 14:50:04,079 - INFO - Vehicle 1725: Found 1 clusters
# 2024-11-27 14:50:04,098 - INFO - Vehicle 1727: Found 1 clusters
# 2024-11-27 14:50:04,121 - INFO - Vehicle 1729: Found 1 clusters
# 2024-11-27 14:50:04,138 - INFO - Vehicle 1730: Found 1 clusters
# 2024-11-27 14:50:04,167 - INFO - Vehicle 1732: Found 4 clusters
# 2024-11-27 14:50:04,231 - INFO - Vehicle 1739: Found 2 clusters
# 2024-11-27 14:50:04,246 - INFO - Vehicle 1740: Found 1 clusters
# ...
# 2024-11-27 14:51:09,708 - INFO - Vehicle 8056: Found 1 clusters
# 2024-11-27 14:51:09,725 - INFO - Vehicle 8057: Found 1 clusters
# 2024-11-27 14:51:09,745 - INFO - Vehicle 8060: Found 1 clusters
# 2024-11-27 14:51:09,764 - INFO - Vehicle 8062: Found 2 clusters
# 2024-11-27 14:51:09,800 - INFO - Vehicle 8069: Found 1 clusters
# 2024-11-27 14:51:09,886 - INFO - Vehicle 8090: Found 1 clusters
# 2024-11-27 14:51:09,919 - INFO - Vehicle 8096: Found 1 clusters
# 2024-11-27 14:51:09,936 - INFO - Vehicle 8097: Found 2 clusters
# 2024-11-27 14:51:09,952 - INFO - Vehicle 8098: Found 1 clusters
# 2024-11-27 14:51:09,974 - INFO - Vehicle 8101: Found 3 clusters
# 2024-11-27 14:51:10,062 - INFO - Vehicle 8122: Found 1 clusters
# 2024-11-27 14:51:10,076 - INFO - Vehicle 8123: Found 1 clusters
# 2024-11-27 14:51:10,115 - INFO - Vehicle 8129: Found 1 clusters
# 2024-11-27 14:51:10,132 - INFO - Vehicle 8130: Found 1 clusters
# 2024-11-27 14:51:10,272 - INFO - Vehicle 8156: Found 1 clusters
# 2024-11-27 14:51:10,324 - INFO - Vehicle 8167: Found 1 clusters
# 2024-11-27 14:51:10,339 - INFO - Vehicle 8168: Found 1 clusters
# 2024-11-27 14:51:10,354 - INFO - Vehicle 8169: Found 1 clusters
# 2024-11-27 14:51:10,398 - INFO - Vehicle 8177: Found 2 clusters
# 2024-11-27 14:51:10,411 - INFO - Vehicle 8178: Found 1 clusters
# 2024-11-27 14:51:10,428 - INFO - Vehicle 8180: Found 1 clusters
# 2024-11-27 14:51:10,450 - INFO - Vehicle 8182: Found 1 clusters
# 2024-11-27 14:51:10,483 - INFO - Vehicle 8186: Found 1 clusters
# 2024-11-27 14:51:10,513 - INFO - Vehicle 8191: Found 1 clusters
# 2024-11-27 14:51:10,548 - INFO - Vehicle 8197: Found 2 clusters
# 2024-11-27 14:51:10,564 - INFO - Vehicle 8198: Found 2 clusters
# 2024-11-27 14:51:10,582 - INFO - Vehicle 8200: Found 2 clusters
# 2024-11-27 14:51:10,608 - INFO - Vehicle 8204: Found 1 clusters
# 2024-11-27 14:51:10,627 - INFO - Vehicle 8206: Found 1 clusters
# 2024-11-27 14:51:10,655 - INFO - Vehicle 8210: Found 1 clusters
# 2024-11-27 14:51:10,680 - INFO - Vehicle 8214: Found 1 clusters
# 2024-11-27 14:51:10,704 - INFO - Vehicle 8218: Found 1 clusters
# 2024-11-27 14:51:10,753 - INFO - Vehicle 8227: Found 2 clusters
# 2024-11-27 14:51:10,871 - INFO - Vehicle 8257: Found 1 clusters
# 2024-11-27 14:51:10,930 - INFO - Vehicle 8270: Found 1 clusters
# 2024-11-27 14:51:10,952 - INFO - Vehicle 8273: Found 1 clusters
# 2024-11-27 14:51:11,005 - INFO - Vehicle 8285: Found 2 clusters
# 2024-11-27 14:51:11,055 - INFO - Vehicle 8297: Found 1 clusters
# 2024-11-27 14:51:11,115 - INFO - Vehicle 8307: Found 1 clusters
# 2024-11-27 14:51:11,165 - INFO - Vehicle 8314: Found 1 clusters
# 2024-11-27 14:51:11,275 - INFO - Vehicle 8335: Found 1 clusters
# 2024-11-27 14:51:11,299 - INFO - Vehicle 8339: Found 2 clusters
# 2024-11-27 14:51:11,313 - INFO - Vehicle 8340: Found 1 clusters
# 2024-11-27 14:51:11,328 - INFO - Vehicle 8341: Found 1 clusters
# 2024-11-27 14:51:11,375 - INFO - Vehicle 8352: Found 1 clusters
# 2024-11-27 14:51:11,389 - INFO - Vehicle 8353: Found 1 clusters
# 2024-11-27 14:51:11,402 - INFO - Vehicle 8354: Found 1 clusters
# 2024-11-27 14:51:11,442 - INFO - Vehicle 8362: Found 1 clusters
# 2024-11-27 14:51:11,484 - INFO - Vehicle 8369: Found 1 clusters
# 2024-11-27 14:51:11,498 - INFO - Vehicle 8370: Found 1 clusters
# 2024-11-27 14:51:11,523 - INFO - Vehicle 8372: Found 1 clusters
# 2024-11-27 14:51:11,549 - INFO - Vehicle 8376: Found 1 clusters
# 2024-11-27 14:51:11,565 - INFO - Vehicle 8377: Found 1 clusters
# 2024-11-27 14:51:11,580 - INFO - Vehicle 8378: Found 1 clusters
# 2024-11-27 14:51:11,611 - INFO - Vehicle 8382: Found 2 clusters
# 2024-11-27 14:51:11,635 - INFO - Vehicle 8385: Found 1 clusters
# 2024-11-27 14:51:11,666 - INFO - Vehicle 8390: Found 1 clusters
# 2024-11-27 14:51:11,693 - INFO - Vehicle 8394: Found 1 clusters
# 2024-11-27 14:51:11,706 - INFO - Vehicle 8395: Found 1 clusters
# 2024-11-27 14:51:11,726 - INFO - Vehicle 8397: Found 1 clusters
# 2024-11-27 14:51:11,761 - INFO - Vehicle 8403: Found 1 clusters
# 2024-11-27 14:51:11,779 - INFO - Vehicle 8405: Found 1 clusters
# 2024-11-27 14:51:11,823 - INFO - Vehicle 8414: Found 1 clusters
# 2024-11-27 14:51:11,838 - INFO - Vehicle 8415: Found 1 clusters
# 2024-11-27 14:51:11,858 - INFO - Vehicle 8417: Found 1 clusters
# 2024-11-27 14:51:11,881 - INFO - Vehicle 8420: Found 1 clusters
# 2024-11-27 14:51:11,906 - INFO - Vehicle 8424: Found 1 clusters
# 2024-11-27 14:51:11,933 - INFO - Vehicle 8428: Found 1 clusters
# 2024-11-27 14:51:11,964 - INFO - Vehicle 8434: Found 1 clusters
# 2024-11-27 14:51:11,984 - INFO - Vehicle 8436: Found 1 clusters
# 2024-11-27 14:51:12,032 - INFO - Vehicle 8446: Found 1 clusters
# 2024-11-27 14:51:12,075 - INFO - Vehicle 8454: Found 1 clusters
# 2024-11-27 14:51:12,121 - INFO - Vehicle 8460: Found 1 clusters
# 2024-11-27 14:51:12,160 - INFO - Vehicle 8464: Found 2 clusters
# 2024-11-27 14:51:12,213 - INFO - Vehicle 8471: Found 1 clusters
# 2024-11-27 14:51:12,238 - INFO - Vehicle 8473: Found 1 clusters
# 2024-11-27 14:51:12,283 - INFO - Vehicle 8479: Found 1 clusters
# 2024-11-27 14:51:12,329 - INFO - Vehicle 8483: Found 1 clusters
# 2024-11-27 14:51:12,391 - INFO - Vehicle 8491: Found 1 clusters
# 2024-11-27 14:51:12,463 - INFO - Vehicle 8506: Found 2 clusters
# 2024-11-27 14:51:12,508 - INFO - Vehicle 8515: Found 1 clusters
# 2024-11-27 14:51:12,569 - INFO - Vehicle 8523: Found 3 clusters
# 2024-11-27 14:51:12,584 - INFO - Vehicle 8524: Found 2 clusters
# 2024-11-27 14:51:12,607 - INFO - Vehicle 8526: Found 1 clusters
# 2024-11-27 14:51:12,622 - INFO - Vehicle 8527: Found 2 clusters
# 2024-11-27 14:51:12,733 - INFO - Vehicle 8543: Found 1 clusters
# 2024-11-27 14:51:12,793 - INFO - Vehicle 8549: Found 1 clusters
# 2024-11-27 14:51:12,835 - INFO - Vehicle 8552: Found 2 clusters
# 2024-11-27 14:51:13,054 - INFO - Vehicle 8583: Found 1 clusters
# 2024-11-27 14:51:13,151 - INFO - Vehicle 8594: Found 1 clusters
# 2024-11-27 14:51:13,306 - INFO - Vehicle 8615: Found 1 clusters
# 2024-11-27 14:51:13,336 - INFO - Vehicle 8618: Found 1 clusters
# 2024-11-27 14:51:13,360 - INFO - Vehicle 8620: Found 2 clusters
# 2024-11-27 14:51:13,485 - INFO - Vehicle 8640: Found 1 clusters
# 2024-11-27 14:51:13,537 - INFO - Vehicle 8645: Found 1 clusters
# 2024-11-27 14:51:13,644 - INFO - Vehicle 8655: Found 1 clusters
# 2024-11-27 14:51:13,682 - INFO - Vehicle 8659: Found 1 clusters
# 2024-11-27 14:51:13,708 - INFO - Vehicle 8661: Found 1 clusters
# 2024-11-27 14:51:13,794 - INFO - Vehicle 8673: Found 1 clusters
# 2024-11-27 14:51:13,833 - INFO - Vehicle 8675: Found 2 clusters
# 2024-11-27 14:51:13,968 - INFO - Vehicle 8693: Found 1 clusters
# 2024-11-27 14:51:13,985 - INFO - Vehicle 8694: Found 1 clusters
# 2024-11-27 14:51:14,029 - INFO - Vehicle 8700: Found 2 clusters
# 2024-11-27 14:51:14,063 - INFO - Vehicle 8704: Found 1 clusters
# 2024-11-27 14:51:14,082 - INFO - Vehicle 8705: Found 1 clusters
# 2024-11-27 14:51:14,205 - INFO - Vehicle 8720: Found 2 clusters
# 2024-11-27 14:51:14,327 - INFO - Vehicle 8738: Found 1 clusters
# 2024-11-27 14:51:14,357 - INFO - Vehicle 8741: Found 1 clusters
# 2024-11-27 14:51:14,407 - INFO - Vehicle 8747: Found 1 clusters
# 2024-11-27 14:51:14,438 - INFO - Vehicle 8750: Found 2 clusters
# 2024-11-27 14:51:14,499 - INFO - Vehicle 8757: Found 1 clusters
# 2024-11-27 14:51:14,532 - INFO - Vehicle 8760: Found 1 clusters
# 2024-11-27 14:51:14,595 - INFO - Vehicle 8767: Found 1 clusters
# 2024-11-27 14:51:14,657 - INFO - Vehicle 8772: Found 2 clusters
# 2024-11-27 14:51:14,725 - INFO - Vehicle 8777: Found 1 clusters
# 2024-11-27 14:51:14,779 - INFO - Vehicle 8782: Found 1 clusters
# 2024-11-27 14:51:14,834 - INFO - Vehicle 8787: Found 1 clusters
# 2024-11-27 14:51:14,896 - INFO - Vehicle 8794: Found 1 clusters
# 2024-11-27 14:51:14,921 - INFO - Vehicle 8796: Found 1 clusters
# 2024-11-27 14:51:14,994 - INFO - Vehicle 8805: Found 1 clusters
# 2024-11-27 14:51:15,080 - INFO - Vehicle 8817: Found 1 clusters
# 2024-11-27 14:51:15,254 - INFO - Vehicle 8836: Found 1 clusters
# 2024-11-27 14:51:15,324 - INFO - Vehicle 8845: Found 1 clusters
# 2024-11-27 14:51:15,455 - INFO - Vehicle 8863: Found 1 clusters
# 2024-11-27 14:51:15,535 - INFO - Vehicle 8874: Found 1 clusters
# 2024-11-27 14:51:15,555 - INFO - Vehicle 8875: Found 1 clusters
# 2024-11-27 14:51:15,578 - INFO - Vehicle 8877: Found 1 clusters
# 2024-11-27 14:51:15,613 - INFO - Vehicle 8881: Found 1 clusters
# 2024-11-27 14:51:15,799 - INFO - Vehicle 8905: Found 1 clusters
# 2024-11-27 14:51:15,839 - INFO - Vehicle 8909: Found 1 clusters
# 2024-11-27 14:51:15,866 - INFO - Vehicle 8911: Found 1 clusters
# 2024-11-27 14:51:15,897 - INFO - Vehicle 8913: Found 1 clusters
# 2024-11-27 14:51:15,919 - INFO - Vehicle 8914: Found 1 clusters
# 2024-11-27 14:51:16,096 - INFO - Vehicle 8940: Found 1 clusters
# 2024-11-27 14:51:16,297 - INFO - Vehicle 8972: Found 1 clusters
# 2024-11-27 14:51:16,401 - INFO - Vehicle 8987: Found 2 clusters
# 2024-11-27 14:51:16,480 - INFO - Vehicle 8999: Found 1 clusters
# 2024-11-27 14:51:16,499 - INFO - Vehicle 9000: Found 1 clusters
# 2024-11-27 14:51:16,533 - INFO - Vehicle 9004: Found 1 clusters
# 2024-11-27 14:51:16,584 - INFO - Vehicle 9015: Found 1 clusters
# 2024-11-27 14:51:16,625 - INFO - Vehicle 9023: Found 1 clusters
# 2024-11-27 14:51:16,670 - INFO - Vehicle 9032: Found 1 clusters
# 2024-11-27 14:51:16,708 - INFO - Vehicle 9040: Found 2 clusters
# 2024-11-27 14:51:16,756 - INFO - Vehicle 9049: Found 1 clusters
# 2024-11-27 14:51:16,800 - INFO - Vehicle 9058: Found 2 clusters
# 2024-11-27 14:51:16,845 - INFO - Vehicle 9065: Found 1 clusters
# 2024-11-27 14:51:16,881 - INFO - Vehicle 9072: Found 1 clusters
# 2024-11-27 14:51:16,933 - INFO - Vehicle 9083: Found 1 clusters
# 2024-11-27 14:51:16,962 - INFO - Vehicle 9088: Found 2 clusters
# 2024-11-27 14:51:16,978 - INFO - Vehicle 9090: Found 1 clusters
# 2024-11-27 14:51:17,114 - INFO - Vehicle 9125: Found 2 clusters
# 2024-11-27 14:51:17,138 - INFO - Vehicle 9127: Found 1 clusters
# 2024-11-27 14:51:17,209 - INFO - Vehicle 9138: Found 1 clusters
# 2024-11-27 14:51:17,256 - INFO - Vehicle 9143: Found 1 clusters
# 2024-11-27 14:51:17,285 - INFO - Vehicle 9145: Found 1 clusters
# 2024-11-27 14:51:17,311 - INFO - Vehicle 9149: Found 1 clusters
# 2024-11-27 14:51:17,357 - INFO - Vehicle 9156: Found 1 clusters
# 2024-11-27 14:51:17,447 - INFO - Vehicle 9176: Found 2 clusters
# 2024-11-27 14:51:17,500 - INFO - Vehicle 9185: Found 1 clusters
# 2024-11-27 14:51:17,560 - INFO - Vehicle 9196: Found 2 clusters
# 2024-11-27 14:51:17,590 - INFO - Vehicle 9200: Found 2 clusters
# 2024-11-27 14:51:17,605 - INFO - Vehicle 9201: Found 1 clusters
# 2024-11-27 14:51:17,629 - INFO - Vehicle 9204: Found 1 clusters
# 2024-11-27 14:51:17,736 - INFO - Vehicle 9224: Found 1 clusters
# 2024-11-27 14:51:17,884 - INFO - Vehicle 9249: Found 1 clusters
# 2024-11-27 14:51:17,995 - INFO - Vehicle 9266: Found 1 clusters
# 2024-11-27 14:51:18,044 - INFO - Vehicle 9274: Found 1 clusters
# 2024-11-27 14:51:18,090 - INFO - Vehicle 9283: Found 1 clusters
# 2024-11-27 14:51:18,178 - INFO - Vehicle 9294: Found 2 clusters
# 2024-11-27 14:51:18,209 - INFO - Vehicle 9296: Found 1 clusters
# 2024-11-27 14:51:18,245 - INFO - Vehicle 9300: Found 1 clusters
# 2024-11-27 14:51:18,307 - INFO - Vehicle 9310: Found 1 clusters
# 2024-11-27 14:51:18,429 - INFO - Vehicle 9338: Found 1 clusters
# 2024-11-27 14:51:18,559 - INFO - Vehicle 9363: Found 1 clusters
# 2024-11-27 14:51:18,580 - INFO - Vehicle 9364: Found 5 clusters
# 2024-11-27 14:51:18,602 - INFO - Vehicle 9366: Found 1 clusters
# 2024-11-27 14:51:18,843 - INFO - Vehicle 9419: Found 1 clusters
# 2024-11-27 14:51:18,934 - INFO - Vehicle 9435: Found 1 clusters
# 2024-11-27 14:51:18,970 - INFO - Vehicle 9439: Found 2 clusters
# 2024-11-27 14:51:19,053 - INFO - Vehicle 9456: Found 1 clusters
# 2024-11-27 14:51:19,122 - INFO - Vehicle 9468: Found 1 clusters
# 2024-11-27 14:51:19,236 - INFO - Vehicle 9488: Found 1 clusters
# 2024-11-27 14:51:19,276 - INFO - Vehicle 9494: Found 1 clusters
# 2024-11-27 14:51:19,314 - INFO - Vehicle 9501: Found 1 clusters
# 2024-11-27 14:51:19,375 - INFO - Vehicle 9511: Found 1 clusters
# 2024-11-27 14:51:19,473 - INFO - Vehicle 9529: Found 1 clusters
# 2024-11-27 14:51:19,725 - INFO - Vehicle 9585: Found 1 clusters
# 2024-11-27 14:51:19,908 - INFO - Vehicle 9627: Found 2 clusters
# 2024-11-27 14:51:19,929 - INFO - Vehicle 9628: Found 1 clusters
# 2024-11-27 14:51:19,977 - INFO - Vehicle 9633: Found 1 clusters
# 2024-11-27 14:51:20,016 - INFO - Vehicle 9639: Found 1 clusters
# 2024-11-27 14:51:20,041 - INFO - Vehicle 9642: Found 1 clusters
# 2024-11-27 14:51:20,059 - INFO - Vehicle 9643: Found 2 clusters
# 2024-11-27 14:51:20,088 - INFO - Vehicle 9647: Found 1 clusters
# 2024-11-27 14:51:20,276 - INFO - Vehicle 9682: Found 1 clusters
# 2024-11-27 14:51:20,355 - INFO - Vehicle 9695: Found 1 clusters
# 2024-11-27 14:51:20,474 - INFO - Vehicle 9719: Found 1 clusters
# 2024-11-27 14:51:20,494 - INFO - Vehicle 9721: Found 1 clusters
# 2024-11-27 14:51:20,543 - INFO - Vehicle 9730: Found 1 clusters
# 2024-11-27 14:51:20,567 - INFO - Vehicle 9732: Found 1 clusters
# 2024-11-27 14:51:20,589 - INFO - Vehicle 9734: Found 1 clusters
# 2024-11-27 14:51:20,682 - INFO - Vehicle 9753: Found 1 clusters
# 2024-11-27 14:51:20,727 - INFO - Vehicle 9760: Found 1 clusters
# 2024-11-27 14:51:20,787 - INFO - Vehicle 9771: Found 1 clusters
# 2024-11-27 14:51:20,951 - INFO - Vehicle 9810: Found 1 clusters
# 2024-11-27 14:51:21,000 - INFO - Vehicle 9815: Found 1 clusters
# 2024-11-27 14:51:21,057 - INFO - Vehicle 9826: Found 1 clusters
# 2024-11-27 14:51:21,080 - INFO - Vehicle 9829: Found 1 clusters
# 2024-11-27 14:51:21,142 - INFO - Vehicle 9839: Found 1 clusters
# 2024-11-27 14:51:21,229 - INFO - Vehicle 9857: Found 1 clusters
# 2024-11-27 14:51:21,256 - INFO - Vehicle 9862: Found 1 clusters
# 2024-11-27 14:51:21,269 - INFO - Vehicle 9863: Found 1 clusters
# 2024-11-27 14:51:21,423 - INFO - Vehicle 9905: Found 1 clusters
# 2024-11-27 14:51:21,448 - INFO - Vehicle 9909: Found 1 clusters
# 2024-11-27 14:51:21,488 - INFO - Vehicle 9916: Found 1 clusters
# 2024-11-27 14:51:21,503 - INFO - Vehicle 9917: Found 1 clusters
# 2024-11-27 14:51:21,526 - INFO - Vehicle 9921: Found 1 clusters
# 2024-11-27 14:51:21,598 - INFO - Vehicle 9936: Found 1 clusters
# 2024-11-27 14:51:21,613 - INFO - Vehicle 9937: Found 1 clusters
# 2024-11-27 14:51:21,684 - INFO - Vehicle 9952: Found 1 clusters
# 2024-11-27 14:51:21,738 - INFO - Vehicle 9964: Found 1 clusters
# 2024-11-27 14:51:22,216 - INFO - Vehicle 10086: Found 1 clusters
# 2024-11-27 14:51:22,322 - INFO - Vehicle 10113: Found 1 clusters
# 2024-11-27 14:51:22,359 - INFO - Vehicle 10121: Found 1 clusters
# 2024-11-27 14:51:22,398 - INFO - Vehicle 10130: Found 1 clusters
# 2024-11-27 14:51:22,483 - INFO - Vehicle 10151: Found 1 clusters
# 2024-11-27 14:51:22,496 - INFO - Vehicle 10152: Found 1 clusters
# 2024-11-27 14:51:22,518 - INFO - Vehicle 10155: Found 1 clusters
# 2024-11-27 14:51:22,572 - INFO - Vehicle 10166: Found 1 clusters
# 2024-11-27 14:51:22,594 - INFO - Vehicle 10170: Found 1 clusters
# 2024-11-27 14:51:22,741 - INFO - Vehicle 10211: Found 1 clusters
# 2024-11-27 14:51:22,797 - INFO - Vehicle 10224: Found 1 clusters
# 2024-11-27 14:51:22,936 - INFO - Vehicle 10262: Found 2 clusters
# 2024-11-27 14:51:23,070 - INFO - Vehicle 10296: Found 1 clusters
# 2024-11-27 14:51:23,089 - INFO - Vehicle 10299: Found 1 clusters
# 2024-11-27 14:51:23,150 - INFO - Vehicle 10309: Found 1 clusters
# 2024-11-27 14:51:23,289 - INFO - Vehicle 10341: Found 1 clusters
# 2024-11-27 14:51:23,479 - INFO - Vehicle 10394: Found 1 clusters
# 2024-11-27 14:51:23,697 - INFO - Vehicle 10458: Found 1 clusters
# 2024-11-27 14:51:23,852 - INFO - Vehicle 10501: Found 1 clusters
# 2024-11-27 14:51:24,035 - INFO - Vehicle 10553: Found 1 clusters
# 2024-11-27 14:51:24,059 - INFO - Vehicle 10556: Found 1 clusters
# 2024-11-27 14:51:24,491 - INFO - Vehicle 10679: Found 1 clusters
# 2024-11-27 14:51:24,626 - INFO - Vehicle 10717: Found 1 clusters
# 2024-11-27 14:51:24,926 - INFO - Starting second-level clustering...
# 2024-11-27 14:51:25,069 - INFO - Second-level clustering identified 59 clusters.
# <ipython-input-2-b224c42cc3af>:196: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
df = pd.read_csv("/content/first_level_clusters.csv")
df
# Out:
#         sim_number   latitude  longitude first_level_cluster  \
# 0                1  53.313702  -6.360803                 1_0
# 1                1  53.313240  -6.360750                 1_0
# 2                1  53.313198  -6.360745                 1_0
# 3                1  53.313251  -6.360727                 1_0
# 4                1  53.313190  -6.360745                 1_0
# ...            ...        ...        ...                 ...
# 137151       10717  -0.466228 -78.566460             10717_0
# 137152       10717  -0.465613 -78.566444             10717_0
# 137153       10717  -0.465608 -78.566689             10717_0
# 137154       10717  -0.466165 -78.566391             10717_0
# 137155       10717  -0.465595 -78.566521             10717_0
#
#         centroid_latitude  centroid_longitude
# 0               53.313157           -6.360686
# 1               53.313157           -6.360686
# 2               53.313157           -6.360686
# 3               53.313157           -6.360686
# 4               53.313157           -6.360686
# ...                   ...                 ...
# 137151          -0.465864          -78.566503
# 137152          -0.465864          -78.566503
# 137153          -0.465864          -78.566503
# 137154          -0.465864          -78.566503
# 137155          -0.465864          -78.566503
#
# [137156 rows x 6 columns]

# %%
df2 = pd.read_csv("/content/second_level_clusters.csv")
df2
# Out:
#      first_level_cluster  centroid_latitude  centroid_longitude  \
# 0                 1005_0          52.811918           -0.137435
# 1                10086_0          51.460890           22.588274
# 2                10113_0          52.723634           -2.459501
# 3                 1034_0          -0.357352          -78.448765
# 4                 1038_2         -33.805353          150.836709
# ...                  ...                ...                 ...
# 1044               988_0          -0.357400          -78.448490
# 1045              9916_0          52.928826           -0.155520
# 1046               998_0         -26.018823           28.265842
# 1047               999_0          46.249305            3.614727
# 1048               999_1          46.248257            3.614555
#
#       second_level_cluster geohash
# 0                        0  gcruky
# 1                       58  u90hf0
# 2                        1  gcq7bn
# 3                        2  6rbjyy
# 4                        3  r3gr8m
# ...                    ...     ...
# 1044                     2  6rbjyy
# 1045                    14  gcrvh7
# 1046                    11  kek5gp
# 1047                    23  u04x47
# 1048                    23  u04x47
#
# [1049 rows x 5 columns]
